# %% [markdown]
# # Financial Model Calibration using ANNs (CaNN, Calibration Neural Network)
#
# ##### from "A neural network-based framework for financial model calibration", Liu et al. ([1])
# ##### and "Pricing options and computing implied volatilities using neural networks", Liu et al. ([2])

# %% [markdown]
# # -------------------------------------------------------

# %% [markdown]
# ## The framework consists of 3 Phases, i.e.:
#
# ### 1. Training (Forward pass)
# ### 2. Prediction (Forward pass)
# ### 3. Calibration (Backward pass)

# %% [markdown]
# # -------------------------------------------------------

# %% [markdown]
# Table of contents
#
# ### 1) Forward pass
# ###### a) Preperation
# ###### b) Data generation
# ###### c) Training Heston-IV-ANN
# ###### d) Prediction
# ###### e) Volatility Surface (In doing)
#
# ### 2) Backward pass
# ###### a) Preperation Market Quotes
# ###### b) Differential Evolution (DE)

# %% [markdown]
# # -------------------------------------------------------

# %% [markdown]
# # 1) Forward pass

# %% [markdown]
# ## a) Preperation

# %%
# Basic imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# Updating scipy to use module QMC for Latin hypercube sampling
#!pip install scipy==1.7
from scipy.stats import qmc

# Pytorch imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR, LinearLR, OneCycleLR, LambdaLR

from scipy.optimize import differential_evolution

# %%
# run on GPU
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### Black-Scholes

# %%
def bs_price_call(S, K, T, t, r, sigma):
  """
  Black-Scholes call option value price related to PDE (2). Returns option's price.
  S:     spot price
  K:     strike price
  T:     time to maturity
  t:     spot time
  r:     interest rate
  sigma: volatility of underlying asset
  """

  # Boundary condition of Black-Sholes PDE (2)
  if T == t:
    return np.maximum(0, S - K)  
  # Solution of the PDE (2) on the open interval [t, T)
  else : 
    d1 = ( np.log(S / K) + (r + 0.5 * sigma ** 2) * (T-t) ) / (sigma * np.sqrt(T-t))
    d2 = d1 - sigma*np.sqrt(T-t)
    value = S * norm.cdf(d1) - K * np.exp(-r * (T-t)) * norm.cdf(d2) 
  
  return value

def bs_moneyness_call(moneyness, tau, r, sigma):
  """
  Same function as bs_price_call but in terms of moneyness. Returns V/K and 
  has S/K instead of two seperate paremeters S and K.
  moneyness: S/K
  Tau: time to maturity minus spot time
  r: interest rate
  sigma: volatility of underlying asset
  """

  d1 = ( np.log(moneyness) + (r + 0.5 * sigma ** 2) * (tau) ) / (sigma * np.sqrt(tau))
  d2 = d1 - sigma*np.sqrt(tau)
  value_moneyness = moneyness * norm.cdf(d1) - np.exp(-r * (tau)) * norm.cdf(d2) 
  
  return value_moneyness

# %% [markdown]
# ##### Defining class Heston-IV-ANN

# %%
class Heston_ANN(nn.Module):
  def __init__(self):
    """
    Initilize Heston-IV-ANN netwwork with four hidden layers. 
    Same architecture as the one used in Table (2) [2].
    Weight are initialized using Glorot_uniform also known as Xavier_uniform.
    """
    super(Heston_ANN, self).__init__()
    # 4 layers
    self.fc1 = nn.Linear(8, 200)
    self.fc2 = nn.Linear(200, 200)
    self.fc3 = nn.Linear(200, 200)
    self.fc4 = nn.Linear(200, 200)
    self.fc5 = nn.Linear(200, 1)
    # initilizing the layer's weights
    torch.nn.init.xavier_uniform_(self.fc1.weight) 
    torch.nn.init.xavier_uniform_(self.fc2.weight)
    torch.nn.init.xavier_uniform_(self.fc3.weight)
    torch.nn.init.xavier_uniform_(self.fc4.weight)
    torch.nn.init.xavier_uniform_(self.fc5.weight)


  def forward(self, x):
    """
    Foward pass of the network. 
    Relu activations are used and a linear activation is used in the final layer.
    x: input torch tensor (CUDA or CPU)
    """
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = F.relu(self.fc3(x))
    x = F.relu(self.fc4(x))
    x = self.fc5(x)
    return x.flatten()

  def train_model(self, args, device, train_loader, optimizer, epoch):
    """
    Training over train_loader batches for one epoch.
    Returns average training loss.
    args: training parameters.
    device: CUDA or CPU.
    train_loader: train data loader.
    optimizer: gradient descent optmizer.
    epoch: current epoch.
    """
    # train mode
    self.train()
    train_loss = 0
    # loop over data loader
    for batch_idx, data in enumerate(train_loader):
      # extracting the inputs and target
      data, target = data[:,:-1].to(device), data[:,-1].to(device)
      # zeroing the gradients
      optimizer.zero_grad()
      # foward pass
      output = self(data)
      # computing the loss
      loss = F.mse_loss(output, target)
      train_loss += loss.item() * data.shape[0]
      # back propagation
      loss.backward()
      # updating the optimizer step
      optimizer.step()
      # printing batch information
      if batch_idx % args["log_interval"] == 0:
        print('Train Epoch: {} [{}/{} ({:.0f}%)]\tlog Loss: {:.6f}'.format(
            epoch, int(batch_idx / len(train_loader)*len(train_loader.dataset)), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), np.log(loss.item())))
        if args["dry_run"]:
          break
    train_loss /= len(train_loader.dataset)
    print('\nTrain set: Average log loss: {:.4f}\n'.format(np.log(train_loss))) 
    return train_loss


  def test_model(self, device, test_loader):
    """
    Testing over test_loader batches for one epoch. 
    Returns average test loss.
    device: CUDA or CPU.
    test_loader: test data loader.
    """
    # evaluation mode
    self.eval()
    test_loss = 0
    # freezing the gradients
    with torch.no_grad():
      # looping over the test laoder
      for data in test_loader:
        # extracting the inputs and target
        data, target = data[:,:-1].to(device), data[:,-1].to(device)
        # foward pass
        output = self(data)
        #computing the loss
        test_loss += F.mse_loss(output, target, reduction = 'sum').item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}\n'.format(np.log(test_loss))) 
    return test_loss

# %% [markdown]
# ## b) Data generation

# %% [markdown]
# ### Numerical method here: Heston and COS

# %% [markdown]
# #### COS Method

# %% [markdown]
# #### Vanilla call coefficients

# %% [markdown]
# $\begin{aligned} \chi_{k}(c, d):=& \frac{1}{1+\left(\frac{k \pi}{b-a}\right)^{2}}\left[\cos \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\cos \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right.\\ &\left.+\frac{k \pi}{b-a} \sin \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\frac{k \pi}{b-a} \sin \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right] \end{aligned}$

# %% [markdown]
# $\psi_{k}(c, d):= \begin{cases}{\left[\sin \left(k \pi \frac{d-a}{b-a}\right)-\sin \left(k \pi \frac{c-a}{b-a}\right)\right] \frac{b-a}{k \pi},} & k \neq 0, \\ (d-c), & k=0 .\end{cases}$

# %% [markdown]
# $V_{k}^{\text {call }}=\frac{2}{b-a} K\left(\chi_{k}(0, b)-\psi_{k}(0, b)\right)$

# %%
def call_cosine_coef(a, b, c, d, K, N):
  """
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  K: Strike.
  N: summing lenght.
  Returns V_k coefficient for call option.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*K*(chi_k-psi_k)

# %%
def call_cosine_coef_moy(a, b, c, d, N):
  """
  Moyeness version.
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  N: summing lenght.
  Returns V_k coefficient for call option devided by K.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*(chi_k-psi_k)

# %% [markdown]
# #### Charateristic function for Heston model

# %% [markdown]
# $\begin{aligned} \varphi_{h e s}\left(\omega ; u_{0}\right)=& \exp \left(i \omega \mu \Delta t+\frac{u_{0}}{\eta^{2}}\left(\frac{1-e^{-D \Delta t}}{1-G e^{-D \Delta t}}\right)(\lambda-i \rho \eta \omega-D)\right) \\ & \cdot \exp \left(\frac{\lambda \bar{u}}{\eta^{2}}\left(\Delta t(\lambda-i \rho \eta \omega-D)-2 \log \left(\frac{1-G e^{-D \Delta t}}{1-G}\right)\right)\right) \end{aligned}$

# %% [markdown]
# $D=\sqrt{(\lambda-i \rho \eta \omega)^{2}+\left(\omega^{2}+i \omega\right) \eta^{2}} \quad$ and $\quad G=\frac{\lambda-i \rho \eta \omega-D}{\lambda-i \rho \eta \omega+D} $

# %%
def phi_Heston(a ,b ,N ,r, tau, kappa, gamma, vbar, v0, rho):
  """
  Characteristic function of the log-asset price following the Heston model.
  Section 3.3, equation (33).
  a, b: truncation range parameters.
  N: summing lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns Charateristic function vector.
  """
  #if kappa < 1e-4:
  #  print("kapp < 1e-4")
  #  kappa = 1e-5
  k = np.arange(N).reshape(1,-1)
  u = np.pi*k/(b-a)
  i = complex(0.0,1.0)
  D = np.sqrt((kappa-gamma*rho*i*u)**2+(u**2+i*u)*gamma**2)
  G = (kappa-gamma*rho*i*u-D)/(kappa-gamma*rho*i*u+D)
  C = v0* (1-np.exp(-D*tau)) / (gamma**2*(1-G*np.exp(-D*tau)))*(kappa-gamma*rho*i*u-D)
  A = r*i*u*tau + kappa*vbar/(gamma**2)*(tau*(kappa-gamma*rho*i*u-D) -2*np.log( (1-G*np.exp(-D*tau))/(1-G) )   ) 
  phi = np.exp( A + C )
  return phi

# %% [markdown]
# #### Heston cumulants

# %% [markdown]
# $c_{1}=\mu T+\left(1-e^{-\lambda T}\right) \frac{\bar{u}-u_{0}}{2 \lambda}-\frac{1}{2} \bar{u} T$

# %% [markdown]
# $\begin{aligned} c_{2}=& \frac{1}{8 \lambda^{3}}\left(\eta T \lambda e^{-\lambda T}\left(u_{0}-\bar{u}\right)(8 \lambda \rho-4 \eta)\right.\\ &+\lambda \rho \eta\left(1-e^{-\lambda T}\right)\left(16 \bar{u}-8 u_{0}\right) \\ &+2 \bar{u} \lambda T\left(-4 \lambda \rho \eta+\eta^{2}+4 \lambda^{2}\right) \\ &+\eta^{2}\left(\left(\bar{u}-2 u_{0}\right) e^{-2 \lambda T}+\bar{u}\left(6 e^{-\lambda T}-7\right)+2 u_{0}\right) \\ &\left.+8 \lambda^{2}\left(u_{0}-\bar{u}\right)\left(1-e^{-\lambda T}\right)\right) \end{aligned}$

# %%
def Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho ):
  """
  Computes Heston cumulants as defined in the appendix A for the Heston model.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns cumulants c1 and c2.
  """

  #if kappa == 0:
  #  c1 = r * tau + tau * (vbar - v0) / 2 - 0.5 * vbar * tau
  #else: 
  #   c1 = r * tau + (1 - np.exp(- kappa * tau)) * (vbar - v0) / (2 * kappa) - 0.5 * vbar * tau
  
  c1 = r * tau + (1 - np.exp(- kappa * tau)) * (vbar - v0) / (2 * kappa) - 0.5 * vbar * tau


  #safe_kappa = np.max(kappa, 1e-5)
  safe_kappa = kappa
  c2 = 0.125 / safe_kappa ** 3 * (gamma * tau * np.exp(- safe_kappa * tau) * (v0 - vbar) * (8 * safe_kappa * rho - 4 * gamma) + \
     safe_kappa * rho * gamma * (1 - np.exp(- safe_kappa * tau)) * (16 * vbar - 8 * v0) + \
     2 * vbar * safe_kappa * tau * (- 4 * safe_kappa * rho * gamma + gamma ** 2 + 4 * safe_kappa ** 2) + \
     gamma ** 2 * ((vbar - 2 * v0) * np.exp(-2 * safe_kappa * tau) + vbar * (6 * np.exp(- safe_kappa * tau) - 7) + 2 * v0) + \
     8 * safe_kappa ** 2 * (v0 - vbar) * (1 - np.exp(-safe_kappa * tau)))
  return c1, c2

# %% [markdown]
# #### Truncation range

# %% [markdown]
# $[a, b]:=\left[c_{1}-L \sqrt{c_{2}+\sqrt{c_{4}}}, \quad c_{1}+L \sqrt{c_{2}+\sqrt{c_{4}}}\right]$

# %%
def Truncation_range(c1, c2, c4, L):
  """
  Computes the truncation range given the cumulants c1, c2, c4 and the truncation lenght L.
  c1, c2, c4: Model cumulants.
  L: truncation lenght.
  Returns tuncation interval sup b and inf a.
  """
  a = c1 - L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) )
  b = c1 + L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) ) 
  return a, b

# %% [markdown]
# #### Exponential coefficient

# %% [markdown]
# $e^{i k \pi \frac{\mathbf{x}-a}{b-a}}$

# %%
def exponential_coef(a, b, N, S0, K):
  """
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  S0: asset initial price.
  K: strike.
  Returns the exponential coefficient vector.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(S0/K)-a)/(b-a))

# %%
def exponential_coef_moy(a, b, N, moyeness):
  """
  Moyeness version.
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  moyeness: S/K.
  Returns the exponential coefficient vector devided by K.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(moyeness)-a)/(b-a))

# %% [markdown]
# #### Vanilla call price

# %% [markdown]
# $v\left(\mathbf{x}, t_{0}, u_{0}\right) \approx \mathbf{K} e^{-r \Delta t} \cdot \operatorname{Re}\left\{\sum_{k=0}^{N-1} \varphi_{h e s}\left(\frac{k \pi}{b-a} ; u_{0}\right) U_{k} \cdot e^{i k \pi \frac{\mathbf{x}-a}{b-a}}\right\}$

# %%
def call_option_Heston(N, L, r, tau, kappa, gamma, vbar, v0, rho, K, S0 ):
  """
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  S0: asset initial price.
  K: strike.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef(a, b, c, d, K, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef(a, b, N, S0, K)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, K = K, S0 = S0)
# Out:
# True
# array([[29.79261082]])

# %%
def call_option_Heston_moy(N, L, r, tau, kappa, gamma, vbar, v0, rho, moyeness ):
  """
  Moyeness version.
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  moyeness: S/K.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef_moy(a, b, c, d, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef_moy(a, b, N, moyeness)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston_moy(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = 1)
# Out:
# True
# array([[0.29792611]])

# %% [markdown]
# # Latin Hypercube Sampling

# %% [markdown]
# ### Generating Data

# %% [markdown]
# #### Sampling range for the Heston parameters (Table (3) in [1])

# %%
# here Table (3) of [1] is used, kappa is numerically sensitive to small values
eps = 1e-2 # is used to generate open intervals
def Heston_LHS_data_generator(n = 10**6, l_bounds = [.6+eps, .05+eps, .0+eps, -0.9+eps, 0.4+eps, .01+eps, .01+eps, .05+eps], u_bounds = [1.4-eps, 3.0-eps, .05-eps, 0.0-eps, 3.0-eps, .5-eps, .8-eps, .5-eps]):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,9) containig the inputs samples and the value of the call.
  The inputs are: Moyeness (S/K), time to maturity (tau), Risk free rate (r), Correlation (rho), reversion speed (kappa), Long average variance (vbar), Vol of vol (gamma), Initial variance (v0).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.
  """
  sampler = qmc.LatinHypercube(d = 8) #, seed = 0
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  indecies = np.argwhere(2*sample[:,4]*sample[:,5] <= sample[:,6]**2)
  sample = np.delete(sample, indecies, 0)
  hs_prices = call_option_Heston_moy(N = 500, L= 12, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa = sample[:,4].reshape((-1,1)),\
                                     gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
                                     rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  #hs_prices = call_option_Heston_moy(N = 1500, L= 50, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
  #                                    gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
  #                                    rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))

  # hs_dataset = np.concatenate((sample, hs_prices),axis=1)

  print("------ INPUT ------")
  print("S/K.......... [{:.2f}, {:.2f}]".format(sample[:,0].min(), sample[:,0].max()))
  print("Tau.......... [{:.2f}, {:.2f}]".format(sample[:,1].min(), sample[:,1].max()))
  print("r............ [{:.2f}, {:.2f}]".format(sample[:,2].min(), sample[:,2].max()))
  print("Corr ........ [{:.2f}, {:.2f}]".format(sample[:,3].min(), sample[:,3].max()))
  print("Kappa........ [{:.2f}, {:.2f}]".format(sample[:,4].min(), sample[:,4].max()))
  print("V_bar........ [{:.2f}, {:.2f}]".format(sample[:,5].min(), sample[:,5].max()))
  print("Gamma........ [{:.2f}, {:.2f}]".format(sample[:,6].min(), sample[:,6].max()))
  print("V_0 ......... [{:.2f}, {:.2f}]".format(sample[:,7].min(), sample[:,7].max()))
  print("------ OUTPUT ------")
  print("V/K.......... [{:.2f}, {:.2f}]".format(hs_prices.min(), hs_prices.max()))

  return sample, hs_prices


testset = Heston_LHS_data_generator(10**4)
# Out:
# ------ INPUT ------
# S/K.......... [0.61, 1.39]
# Tau.......... [0.06, 2.99]
# r............ [0.01, 0.04]
# Corr ........ [-0.89, -0.01]
# Kappa........ [0.41, 2.99]
# V_bar........ [0.02, 0.49]
# Gamma........ [0.02, 0.79]
# V_0 ......... [0.06, 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00, 0.75]

# %% [markdown]
# ## c) Training Heston-IV-ANN

# %% [markdown]
# ### Use Brent to inverse price to implied volatility (IV)

# %%
from scipy import optimize

def calcimpliedvol(dataset):
    """
    Computes the implied volatilities using the brent method.
    dataset: numpy array containing moneyness, time to maturity, risk free interest rate and V/K.
    Returns a vector of implied volatilities.
    """
    money = np.array(dataset[0])
    T = np.array(dataset[1])
    r = np.array(dataset[2])
    marketoptionPrice = np.array(dataset[3])
    def bs_price(sigma):
      d1 = ( np.log(money) + (r + 0.5 * sigma ** 2) * (T) ) / (sigma * np.sqrt(T))
      d2 = d1 - sigma*np.sqrt(T)
      value_moyeness = money * norm.cdf(d1) - np.exp(-r * (T)) * norm.cdf(d2) 
      fx = value_moyeness - marketoptionPrice
      return fx
    return optimize.brentq(bs_price, -1, 1, maxiter=100)

# %% [markdown]
# ### Add IV to final data OLD

# %%
sample, hs_prices = Heston_LHS_data_generator(n = 10**5)
# Convert to NumPy for processing
sample_np = sample
hs_prices_np = hs_prices

# Combine required inputs for Brent
brent_input = np.concatenate([sample_np[:, [0, 1, 2]], hs_prices_np], axis=1)  # shape (n, 4)

#print("brent_input shape:", brent_input.shape)

# Apply Brent row by row
implied_vols = np.array([
    calcimpliedvol(row) for row in brent_input
])

#print("V_0 ......... [{:.2f}, {:.2f}]".format(sample[:,7].min(), sample[:,7].max()))
print("------ ANN OUTPUT ------")

print("Black-scholes IV sigma.......... [{:.2f}, {:.2f}]".format(implied_vols.min(), implied_vols.max()))

# Filter out NaNs
valid_idx = ~np.isnan(implied_vols)
sample_np = sample_np[valid_idx]
implied_vols = implied_vols[valid_idx]

# Recombine into final dataset (input + IV target)
final_dataset = np.concatenate([sample_np, implied_vols.reshape(-1, 1)], axis=1)

# Convert to torch Tensor
hs_dataset = torch.FloatTensor(final_dataset)
# Out:
# ------ INPUT ------
# S/K.......... [0.61, 1.39]
# Tau.......... [0.06, 2.99]
# r............ [0.01, 0.04]
# Corr ........ [-0.89, -0.01]
# Kappa........ [0.41, 2.99]
# V_bar........ [0.02, 0.49]
# Gamma........ [0.02, 0.79]
# V_0 ......... [0.06, 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00, 0.76]
# ------ ANN OUTPUT ------
# Black-scholes IV sigma.......... [0.15, 0.73]

# %%
import matplotlib.pyplot as plt
plt.hist(implied_vols, bins=100)
plt.title("Histogram of Implied Vols (after Brent)")
plt.show()

# %%
num_total = len(implied_vols)
num_failed = np.sum(np.isnan(implied_vols))
num_success = num_total - num_failed

print(f"Total IVs:     {num_total}")
print(f"Failures (NaN): {num_failed}")
print(f"Successes:     {num_success}")
# Out:
# Total IVs:     86158
# Failures (NaN): 0
# Successes:     86158

# %%
print(f"Total IVs: {len(implied_vols)}")
print(f"Failures (NaN): {np.sum(np.isnan(implied_vols))}")
# Out:
# Total IVs: 86158
# Failures (NaN): 0

# %%
plt.figure(figsize=(8, 4))
plt.hist(implied_vols, bins=100, edgecolor='black')
plt.title("Distribution of Implied Volatilities (Brent)")
plt.xlabel("Implied Volatility")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
print("IV min:", implied_vols.min())
print("IV max:", implied_vols.max())
# Out:
# IV min: 0.6684203282102947
# IV max: 0.700986247637977

# %%
num_total = len(implied_vols)
num_failed = np.sum(np.isnan(implied_vols))
num_success = num_total - num_failed

print(f"Total IVs:     {num_total}")
print(f"Failures (NaN): {num_failed}")
print(f"Successes:     {num_success}")
# Out:
# Total IVs:     86158
# Failures (NaN): 0
# Successes:     86158

# %% [markdown]
# ### Training of the ANN

# %%
# Training parameters
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 8*10**3,
         "lr": 1e-4,
         "gamma": .5,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}


use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# torch.manual_seed(args["seed"])

# Loading Train / Test Data
hs_dataset = hs_dataset
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0] - train_size])

train_loader = torch.utils.data.DataLoader(train_dataset, args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])


# Model training
print(device)
model = Heston_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=args["lr"]) # Adam is found to be the best optimizer in the article
scheduler = StepLR(optimizer, step_size=500, gamma=args["gamma"]) # Deacreses the Learning rate by .5 every 500 epoch

train_losses = []
test_losses = []
for epoch in range(1, args["epochs"] + 1):
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
if args["save_model"] :
  torch.save(model.state_dict(), "ANN_weights/Heston_IV_ANN_DE_25_08_03.pt")
# Out:
# cuda
# Train Epoch: 1 [0/77542 (0%)]	log Loss: -0.537636
#
# Train set: Average log loss: -2.6634
#
#
# Test set: Average loss: -4.8417
#
# Current Learning rate 0.0001
# Train Epoch: 2 [0/77542 (0%)]	log Loss: -4.786133
#
# Train set: Average log loss: -5.0196
#
#
# Test set: Average loss: -5.2174
#
# Current Learning rate 0.0001
# Train Epoch: 3 [0/77542 (0%)]	log Loss: -5.206078
#
# Train set: Average log loss: -5.5057
#
#
# Test set: Average loss: -5.9664
#
# Current Learning rate 0.0001
# Train Epoch: 4 [0/77542 (0%)]	log Loss: -5.954901
#
# Train set: Average log loss: -6.3957
#
#
# Test set: Average loss: -6.8531
#
# Current Learning rate 0.0001
# Train Epoch: 5 [0/77542 (0%)]	log Loss: -6.835667
#
# Train set: Average log loss: -7.1428
#
#
# Test set: Average loss: -7.5048
#
# Current Learning rate 0.0001
# Train Epoch: 6 [0/77542 (0%)]	log Loss: -7.599491
#
# Train set: Average log loss: -7.7822
#
#
# Test set: Average loss: -8.0475
#
# Current Learning rate 0.0001
# Train Epoch: 7 [0/77542 (0%)]	log Loss: -8.139491
#
# Train set: Average log loss: -8.2838
#
#
# Test set: Average loss: -8.4791
#
# Current Learning rate 0.0001
# Train Epoch: 8 [0/77542 (0%)]	log Loss: -8.531996
#
# Train set: Average log loss: -8.6668
#
#
# Test set: Average loss: -8.8068
#
# Current Learning rate 0.0001
# Train Epoch: 9 [0/77542 (0%)]	log Loss: -8.813328
#
# Train set: Average log loss: -8.9436
#
#
# Test set: Average loss: -9.0407
#
# Current Learning rate 0.0001
# Train Epoch: 10 [0/77542 (0%)]	log Loss: -9.044267
#
# Train set: Average log loss: -9.1408
#
#
# Test set: Average loss: -9.2122
#
# Current Learning rate 0.0001
# Train Epoch: 11 [0/77542 (0%)]	log Loss: -9.224717
#
# Train set: Average log loss: -9.2877
#
#
# Test set: Average loss: -9.3296
#
# Current Learning rate 0.0001
# Train Epoch: 12 [0/77542 (0%)]	log Loss: -9.352998
#
# Train set: Average log loss: -9.4124
#
#
# Test set: Average loss: -9.4274
#
# Current Learning rate 0.0001
# Train Epoch: 13 [0/77542 (0%)]	log Loss: -9.452726
#
# Train set: Average log loss: -9.5213
#
#
# Test set: Average loss: -9.5384
#
# Current Learning rate 0.0001
# Train Epoch: 14 [0/77542 (0%)]	log Loss: -9.563278
#
# Train set: Average log loss: -9.6107
#
#
# Test set: Average loss: -9.6385
#
# Current Learning rate 0.0001
# Train Epoch: 15 [0/77542 (0%)]	log Loss: -9.654231
#
# Train set: Average log loss: -9.6883
#
#
# Test set: Average loss: -9.7180
#
# Current Learning rate 0.0001
# Train Epoch: 16 [0/77542 (0%)]	log Loss: -9.726348
#
# Train set: Average log loss: -9.7583
#
#
# Test set: Average loss: -9.7849
#
# Current Learning rate 0.0001
# Train Epoch: 17 [0/77542 (0%)]	log Loss: -9.784989
#
# Train set: Average log loss: -9.8212
#
#
# Test set: Average loss: -9.8428
#
# Current Learning rate 0.0001
# Train Epoch: 18 [0/77542 (0%)]	log Loss: -9.835359
#
# Train set: Average log loss: -9.8803
#
#
# Test set: Average loss: -9.8936
#
# Current Learning rate 0.0001
# Train Epoch: 19 [0/77542 (0%)]	log Loss: -9.877961
#
# Train set: Average log loss: -9.9352
#
#
# Test set: Average loss: -9.9307
#
# Current Learning rate 0.0001
# Train Epoch: 20 [0/77542 (0%)]	log Loss: -9.907384
#
# Train set: Average log loss: -9.9864
#
#
# Test set: Average loss: -9.9533
#
# Current Learning rate 0.0001
# Train Epoch: 21 [0/77542 (0%)]	log Loss: -9.928921
#
# Train set: Average log loss: -10.0354
#
#
# Test set: Average loss: -9.9915
#
# Current Learning rate 0.0001
# Train Epoch: 22 [0/77542 (0%)]	log Loss: -9.967276
#
# Train set: Average log loss: -10.0819
#
#
# Test set: Average loss: -10.0380
#
# Current Learning rate 0.0001
# Train Epoch: 23 [0/77542 (0%)]	log Loss: -10.013914
#
# Train set: Average log loss: -10.1244
#
#
# Test set: Average loss: -10.0904
#
# Current Learning rate 0.0001
# Train Epoch: 24 [0/77542 (0%)]	log Loss: -10.064463
#
# Train set: Average log loss: -10.1641
#
#
# Test set: Average loss: -10.1244
#
# Current Learning rate 0.0001
# Train Epoch: 25 [0/77542 (0%)]	log Loss: -10.103529
#
# Train set: Average log loss: -10.2012
#
#
# Test set: Average loss: -10.1494
#
# Current Learning rate 0.0001
# Train Epoch: 26 [0/77542 (0%)]	log Loss: -10.132613
#
# Train set: Average log loss: -10.2384
#
#
# Test set: Average loss: -10.1791
#
# Current Learning rate 0.0001
# Train Epoch: 27 [0/77542 (0%)]	log Loss: -10.168411
#
# Train set: Average log loss: -10.2773
#
#
# Test set: Average loss: -10.2102
#
# Current Learning rate 0.0001
# Train Epoch: 28 [0/77542 (0%)]	log Loss: -10.206730
#
# Train set: Average log loss: -10.3183
#
#
# Test set: Average loss: -10.2411
#
# Current Learning rate 0.0001
# Train Epoch: 29 [0/77542 (0%)]	log Loss: -10.251386
#
# Train set: Average log loss: -10.3608
#
#
# Test set: Average loss: -10.2969
#
# Current Learning rate 0.0001
# Train Epoch: 30 [0/77542 (0%)]	log Loss: -10.317261
#
# Train set: Average log loss: -10.4067
#
#
# Test set: Average loss: -10.3550
#
# Current Learning rate 0.0001
# Train Epoch: 31 [0/77542 (0%)]	log Loss: -10.385441
#
# Train set: Average log loss: -10.4511
#
#
# Test set: Average loss: -10.3951
#
# Current Learning rate 0.0001
# Train Epoch: 32 [0/77542 (0%)]	log Loss: -10.433993
#
# Train set: Average log loss: -10.4890
#
#
# Test set: Average loss: -10.4407
#
# Current Learning rate 0.0001
# Train Epoch: 33 [0/77542 (0%)]	log Loss: -10.486778
#
# Train set: Average log loss: -10.5234
#
#
# Test set: Average loss: -10.4795
#
# Current Learning rate 0.0001
# Train Epoch: 34 [0/77542 (0%)]	log Loss: -10.531740
#
# Train set: Average log loss: -10.5538
#
#
# Test set: Average loss: -10.5301
#
# Current Learning rate 0.0001
# Train Epoch: 35 [0/77542 (0%)]	log Loss: -10.587144
#
# Train set: Average log loss: -10.5800
#
#
# Test set: Average loss: -10.5649
#
# Current Learning rate 0.0001
# Train Epoch: 36 [0/77542 (0%)]	log Loss: -10.625653
#
# Train set: Average log loss: -10.6021
#
#
# Test set: Average loss: -10.5842
#
# Current Learning rate 0.0001
# Train Epoch: 37 [0/77542 (0%)]	log Loss: -10.645363
#
# Train set: Average log loss: -10.6189
#
#
# Test set: Average loss: -10.5994
#
# Current Learning rate 0.0001
# Train Epoch: 38 [0/77542 (0%)]	log Loss: -10.661905
#
# Train set: Average log loss: -10.6386
#
#
# Test set: Average loss: -10.6241
#
# Current Learning rate 0.0001
# Train Epoch: 39 [0/77542 (0%)]	log Loss: -10.687852
#
# Train set: Average log loss: -10.6607
#
#
# Test set: Average loss: -10.6517
#
# Current Learning rate 0.0001
# Train Epoch: 40 [0/77542 (0%)]	log Loss: -10.716810
#
# Train set: Average log loss: -10.6835
#
#
# Test set: Average loss: -10.6864
#
# Current Learning rate 0.0001
# Train Epoch: 41 [0/77542 (0%)]	log Loss: -10.751293
#
# Train set: Average log loss: -10.7057
#
#
# Test set: Average loss: -10.7207
#
# Current Learning rate 0.0001
# Train Epoch: 42 [0/77542 (0%)]	log Loss: -10.787323
#
# Train set: Average log loss: -10.7265
#
#
# Test set: Average loss: -10.7494
#
# Current Learning rate 0.0001
# Train Epoch: 43 [0/77542 (0%)]	log Loss: -10.815911
#
# Train set: Average log loss: -10.7443
#
#
# Test set: Average loss: -10.7750
#
# Current Learning rate 0.0001
# Train Epoch: 44 [0/77542 (0%)]	log Loss: -10.841210
#
# Train set: Average log loss: -10.7602
#
#
# Test set: Average loss: -10.7965
#
# Current Learning rate 0.0001
# Train Epoch: 45 [0/77542 (0%)]	log Loss: -10.864566
#
# Train set: Average log loss: -10.7787
#
#
# Test set: Average loss: -10.8122
#
# Current Learning rate 0.0001
# Train Epoch: 46 [0/77542 (0%)]	log Loss: -10.882057
#
# Train set: Average log loss: -10.7983
#
#
# Test set: Average loss: -10.8231
#
# Current Learning rate 0.0001
# Train Epoch: 47 [0/77542 (0%)]	log Loss: -10.894730
#
# Train set: Average log loss: -10.8168
#
#
# Test set: Average loss: -10.8313
#
# Current Learning rate 0.0001
# Train Epoch: 48 [0/77542 (0%)]	log Loss: -10.904436
#
# Train set: Average log loss: -10.8374
#
#
# Test set: Average loss: -10.8271
#
# Current Learning rate 0.0001
# Train Epoch: 49 [0/77542 (0%)]	log Loss: -10.902105
#
# Train set: Average log loss: -10.8632
#
#
# Test set: Average loss: -10.8134
#
# Current Learning rate 0.0001
# Train Epoch: 50 [0/77542 (0%)]	log Loss: -10.886868
#
# Train set: Average log loss: -10.8960
#
#
# Test set: Average loss: -10.8230
#
# Current Learning rate 0.0001
# Train Epoch: 51 [0/77542 (0%)]	log Loss: -10.896780
#
# Train set: Average log loss: -10.9241
#
#
# Test set: Average loss: -10.8324
#
# Current Learning rate 0.0001
# Train Epoch: 52 [0/77542 (0%)]	log Loss: -10.905077
#
# Train set: Average log loss: -10.9363
#
#
# Test set: Average loss: -10.8589
#
# Current Learning rate 0.0001
# Train Epoch: 53 [0/77542 (0%)]	log Loss: -10.933783
#
# Train set: Average log loss: -10.9381
#
#
# Test set: Average loss: -10.9180
#
# Current Learning rate 0.0001
# Train Epoch: 54 [0/77542 (0%)]	log Loss: -10.997073
#
# Train set: Average log loss: -10.9470
#
#
# Test set: Average loss: -10.9599
#
# Current Learning rate 0.0001
# Train Epoch: 55 [0/77542 (0%)]	log Loss: -11.044584
#
# Train set: Average log loss: -10.9642
#
#
# Test set: Average loss: -10.9539
#
# Current Learning rate 0.0001
# Train Epoch: 56 [0/77542 (0%)]	log Loss: -11.038926
#
# Train set: Average log loss: -10.9758
#
#
# Test set: Average loss: -10.9351
#
# Current Learning rate 0.0001
# Train Epoch: 57 [0/77542 (0%)]	log Loss: -11.018136
#
# Train set: Average log loss: -10.9838
#
#
# Test set: Average loss: -10.9373
#
# Current Learning rate 0.0001
# Train Epoch: 58 [0/77542 (0%)]	log Loss: -11.019523
#
# Train set: Average log loss: -10.9992
#
#
# Test set: Average loss: -10.9591
#
# Current Learning rate 0.0001
# Train Epoch: 59 [0/77542 (0%)]	log Loss: -11.042314
#
# Train set: Average log loss: -11.0137
#
#
# Test set: Average loss: -11.0010
#
# Current Learning rate 0.0001
# Train Epoch: 60 [0/77542 (0%)]	log Loss: -11.087646
#
# Train set: Average log loss: -11.0294
#
#
# Test set: Average loss: -11.0188
#
# Current Learning rate 0.0001
# Train Epoch: 61 [0/77542 (0%)]	log Loss: -11.107252
#
# Train set: Average log loss: -11.0363
#
#
# Test set: Average loss: -11.0081
#
# Current Learning rate 0.0001
# Train Epoch: 62 [0/77542 (0%)]	log Loss: -11.094442
#
# Train set: Average log loss: -11.0375
#
#
# Test set: Average loss: -11.0080
#
# Current Learning rate 0.0001
# Train Epoch: 63 [0/77542 (0%)]	log Loss: -11.093610
#
# Train set: Average log loss: -11.0434
#
#
# Test set: Average loss: -11.0149
#
# Current Learning rate 0.0001
# Train Epoch: 64 [0/77542 (0%)]	log Loss: -11.099592
#
# Train set: Average log loss: -11.0501
#
#
# Test set: Average loss: -11.0117
#
# Current Learning rate 0.0001
# Train Epoch: 65 [0/77542 (0%)]	log Loss: -11.093896
#
# Train set: Average log loss: -11.0576
#
#
# Test set: Average loss: -11.0226
#
# Current Learning rate 0.0001
# Train Epoch: 66 [0/77542 (0%)]	log Loss: -11.104452
#
# Train set: Average log loss: -11.0673
#
#
# Test set: Average loss: -11.0322
#
# Current Learning rate 0.0001
# Train Epoch: 67 [0/77542 (0%)]	log Loss: -11.113313
#
# Train set: Average log loss: -11.0733
#
#
# Test set: Average loss: -11.0301
#
# Current Learning rate 0.0001
# Train Epoch: 68 [0/77542 (0%)]	log Loss: -11.108934
#
# Train set: Average log loss: -11.0806
#
#
# Test set: Average loss: -11.0355
#
# Current Learning rate 0.0001
# Train Epoch: 69 [0/77542 (0%)]	log Loss: -11.112971
#
# Train set: Average log loss: -11.0876
#
#
# Test set: Average loss: -11.0296
#
# Current Learning rate 0.0001
# Train Epoch: 70 [0/77542 (0%)]	log Loss: -11.106660
#
# Train set: Average log loss: -11.0973
#
#
# Test set: Average loss: -11.0380
#
# Current Learning rate 0.0001
# Train Epoch: 71 [0/77542 (0%)]	log Loss: -11.113941
#
# Train set: Average log loss: -11.1033
#
#
# Test set: Average loss: -11.0325
#
# Current Learning rate 0.0001
# Train Epoch: 72 [0/77542 (0%)]	log Loss: -11.106666
#
# Train set: Average log loss: -11.1080
#
#
# Test set: Average loss: -11.0267
#
# Current Learning rate 0.0001
# Train Epoch: 73 [0/77542 (0%)]	log Loss: -11.098974
#
# Train set: Average log loss: -11.1105
#
#
# Test set: Average loss: -10.9994
#
# Current Learning rate 0.0001
# Train Epoch: 74 [0/77542 (0%)]	log Loss: -11.067842
#
# Train set: Average log loss: -11.1107
#
#
# Test set: Average loss: -10.9604
#
# Current Learning rate 0.0001
# Train Epoch: 75 [0/77542 (0%)]	log Loss: -11.023735
#
# Train set: Average log loss: -11.1075
#
#
# Test set: Average loss: -10.9133
#
# Current Learning rate 0.0001
# Train Epoch: 76 [0/77542 (0%)]	log Loss: -10.973005
#
# Train set: Average log loss: -11.1170
#
#
# Test set: Average loss: -10.9382
#
# Current Learning rate 0.0001
# Train Epoch: 77 [0/77542 (0%)]	log Loss: -10.998839
#
# Train set: Average log loss: -11.1361
#
#
# Test set: Average loss: -10.9650
#
# Current Learning rate 0.0001
# Train Epoch: 78 [0/77542 (0%)]	log Loss: -11.028127
#
# Train set: Average log loss: -11.1493
#
#
# Test set: Average loss: -10.9777
#
# Current Learning rate 0.0001
# Train Epoch: 79 [0/77542 (0%)]	log Loss: -11.040929
#
# Train set: Average log loss: -11.1563
#
#
# Test set: Average loss: -10.9833
#
# Current Learning rate 0.0001
# Train Epoch: 80 [0/77542 (0%)]	log Loss: -11.043279
#
# Train set: Average log loss: -11.1593
#
#
# Test set: Average loss: -10.9828
#
# Current Learning rate 0.0001
# Train Epoch: 81 [0/77542 (0%)]	log Loss: -11.042621
#
# Train set: Average log loss: -11.1699
#
#
# Test set: Average loss: -10.9963
#
# Current Learning rate 0.0001
# Train Epoch: 82 [0/77542 (0%)]	log Loss: -11.054743
#
# Train set: Average log loss: -11.1761
#
#
# Test set: Average loss: -11.0194
#
# Current Learning rate 0.0001
# Train Epoch: 83 [0/77542 (0%)]	log Loss: -11.077900
#
# Train set: Average log loss: -11.1866
#
#
# Test set: Average loss: -11.0551
#
# Current Learning rate 0.0001
# Train Epoch: 84 [0/77542 (0%)]	log Loss: -11.117110
#
# Train set: Average log loss: -11.1999
#
#
# Test set: Average loss: -11.1030
#
# Current Learning rate 0.0001
# Train Epoch: 85 [0/77542 (0%)]	log Loss: -11.166827
#
# Train set: Average log loss: -11.2183
#
#
# Test set: Average loss: -11.1816
#
# Current Learning rate 0.0001
# Train Epoch: 86 [0/77542 (0%)]	log Loss: -11.250135
#
# Train set: Average log loss: -11.2382
#
#
# Test set: Average loss: -11.2530
#
# Current Learning rate 0.0001
# Train Epoch: 87 [0/77542 (0%)]	log Loss: -11.326608
#
# Train set: Average log loss: -11.2448
#
#
# Test set: Average loss: -11.1797
#
# Current Learning rate 0.0001
# Train Epoch: 88 [0/77542 (0%)]	log Loss: -11.245503
#
# Train set: Average log loss: -11.2352
#
#
# Test set: Average loss: -11.1051
#
# Current Learning rate 0.0001
# Train Epoch: 89 [0/77542 (0%)]	log Loss: -11.164283
#
# Train set: Average log loss: -11.2292
#
#
# Test set: Average loss: -11.0994
#
# Current Learning rate 0.0001
# Train Epoch: 90 [0/77542 (0%)]	log Loss: -11.155470
#
# Train set: Average log loss: -11.2317
#
#
# Test set: Average loss: -11.1252
#
# Current Learning rate 0.0001
# Train Epoch: 91 [0/77542 (0%)]	log Loss: -11.181821
#
# Train set: Average log loss: -11.2431
#
#
# Test set: Average loss: -11.1564
#
# Current Learning rate 0.0001
# Train Epoch: 92 [0/77542 (0%)]	log Loss: -11.214385
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -11.1277
#
# Current Learning rate 0.0001
# Train Epoch: 93 [0/77542 (0%)]	log Loss: -11.182211
#
# Train set: Average log loss: -11.2523
#
#
# Test set: Average loss: -11.1487
#
# Current Learning rate 0.0001
# Train Epoch: 94 [0/77542 (0%)]	log Loss: -11.203485
#
# Train set: Average log loss: -11.2627
#
#
# Test set: Average loss: -11.1549
#
# Current Learning rate 0.0001
# Train Epoch: 95 [0/77542 (0%)]	log Loss: -11.208247
#
# Train set: Average log loss: -11.2659
#
#
# Test set: Average loss: -11.1615
#
# Current Learning rate 0.0001
# Train Epoch: 96 [0/77542 (0%)]	log Loss: -11.215074
#
# Train set: Average log loss: -11.2731
#
#
# Test set: Average loss: -11.1708
#
# Current Learning rate 0.0001
# Train Epoch: 97 [0/77542 (0%)]	log Loss: -11.222598
#
# Train set: Average log loss: -11.2795
#
#
# Test set: Average loss: -11.1773
#
# Current Learning rate 0.0001
# Train Epoch: 98 [0/77542 (0%)]	log Loss: -11.229027
#
# Train set: Average log loss: -11.2879
#
#
# Test set: Average loss: -11.1596
#
# Current Learning rate 0.0001
# Train Epoch: 99 [0/77542 (0%)]	log Loss: -11.209429
#
# Train set: Average log loss: -11.2892
#
#
# Test set: Average loss: -11.1620
#
# Current Learning rate 0.0001
# Train Epoch: 100 [0/77542 (0%)]	log Loss: -11.211206
#
# Train set: Average log loss: -11.2924
#
#
# Test set: Average loss: -11.2037
#
# Current Learning rate 0.0001
# Train Epoch: 101 [0/77542 (0%)]	log Loss: -11.254803
#
# Train set: Average log loss: -11.3045
#
#
# Test set: Average loss: -11.2130
#
# Current Learning rate 0.0001
# Train Epoch: 102 [0/77542 (0%)]	log Loss: -11.264590
#
# Train set: Average log loss: -11.3086
#
#
# Test set: Average loss: -11.2224
#
# Current Learning rate 0.0001
# Train Epoch: 103 [0/77542 (0%)]	log Loss: -11.273973
#
# Train set: Average log loss: -11.3099
#
#
# Test set: Average loss: -11.2484
#
# Current Learning rate 0.0001
# Train Epoch: 104 [0/77542 (0%)]	log Loss: -11.303755
#
# Train set: Average log loss: -11.3151
#
#
# Test set: Average loss: -11.2837
#
# Current Learning rate 0.0001
# Train Epoch: 105 [0/77542 (0%)]	log Loss: -11.340771
#
# Train set: Average log loss: -11.3229
#
#
# Test set: Average loss: -11.3241
#
# Current Learning rate 0.0001
# Train Epoch: 106 [0/77542 (0%)]	log Loss: -11.384288
#
# Train set: Average log loss: -11.3313
#
#
# Test set: Average loss: -11.3488
#
# Current Learning rate 0.0001
# Train Epoch: 107 [0/77542 (0%)]	log Loss: -11.410181
#
# Train set: Average log loss: -11.3389
#
#
# Test set: Average loss: -11.3685
#
# Current Learning rate 0.0001
# Train Epoch: 108 [0/77542 (0%)]	log Loss: -11.429692
#
# Train set: Average log loss: -11.3562
#
#
# Test set: Average loss: -11.3588
#
# Current Learning rate 0.0001
# Train Epoch: 109 [0/77542 (0%)]	log Loss: -11.419118
#
# Train set: Average log loss: -11.3607
#
#
# Test set: Average loss: -11.3361
#
# Current Learning rate 0.0001
# Train Epoch: 110 [0/77542 (0%)]	log Loss: -11.395440
#
# Train set: Average log loss: -11.3641
#
#
# Test set: Average loss: -11.3105
#
# Current Learning rate 0.0001
# Train Epoch: 111 [0/77542 (0%)]	log Loss: -11.367948
#
# Train set: Average log loss: -11.3750
#
#
# Test set: Average loss: -11.3075
#
# Current Learning rate 0.0001
# Train Epoch: 112 [0/77542 (0%)]	log Loss: -11.365147
#
# Train set: Average log loss: -11.3803
#
#
# Test set: Average loss: -11.3019
#
# Current Learning rate 0.0001
# Train Epoch: 113 [0/77542 (0%)]	log Loss: -11.359841
#
# Train set: Average log loss: -11.3925
#
#
# Test set: Average loss: -11.3229
#
# Current Learning rate 0.0001
# Train Epoch: 114 [0/77542 (0%)]	log Loss: -11.386065
#
# Train set: Average log loss: -11.4097
#
#
# Test set: Average loss: -11.3715
#
# Current Learning rate 0.0001
# Train Epoch: 115 [0/77542 (0%)]	log Loss: -11.438278
#
# Train set: Average log loss: -11.4226
#
#
# Test set: Average loss: -11.4643
#
# Current Learning rate 0.0001
# Train Epoch: 116 [0/77542 (0%)]	log Loss: -11.541518
#
# Train set: Average log loss: -11.4316
#
#
# Test set: Average loss: -11.5574
#
# Current Learning rate 0.0001
# Train Epoch: 117 [0/77542 (0%)]	log Loss: -11.643430
#
# Train set: Average log loss: -11.4359
#
#
# Test set: Average loss: -11.6244
#
# Current Learning rate 0.0001
# Train Epoch: 118 [0/77542 (0%)]	log Loss: -11.716929
#
# Train set: Average log loss: -11.4383
#
#
# Test set: Average loss: -11.6787
#
# Current Learning rate 0.0001
# Train Epoch: 119 [0/77542 (0%)]	log Loss: -11.777377
#
# Train set: Average log loss: -11.4415
#
#
# Test set: Average loss: -11.7114
#
# Current Learning rate 0.0001
# Train Epoch: 120 [0/77542 (0%)]	log Loss: -11.810882
#
# Train set: Average log loss: -11.4407
#
#
# Test set: Average loss: -11.7307
#
# Current Learning rate 0.0001
# Train Epoch: 121 [0/77542 (0%)]	log Loss: -11.833206
#
# Train set: Average log loss: -11.4417
#
#
# Test set: Average loss: -11.7354
#
# Current Learning rate 0.0001
# Train Epoch: 122 [0/77542 (0%)]	log Loss: -11.837295
#
# Train set: Average log loss: -11.4416
#
#
# Test set: Average loss: -11.7305
#
# Current Learning rate 0.0001
# Train Epoch: 123 [0/77542 (0%)]	log Loss: -11.829167
#
# Train set: Average log loss: -11.4212
#
#
# Test set: Average loss: -11.6744
#
# Current Learning rate 0.0001
# Train Epoch: 124 [0/77542 (0%)]	log Loss: -11.761961
#
# Train set: Average log loss: -11.3373
#
#
# Test set: Average loss: -11.3074
#
# Current Learning rate 0.0001
# Train Epoch: 125 [0/77542 (0%)]	log Loss: -11.357819
#
# Train set: Average log loss: -11.2930
#
#
# Test set: Average loss: -11.1982
#
# Current Learning rate 0.0001
# Train Epoch: 126 [0/77542 (0%)]	log Loss: -11.239181
#
# Train set: Average log loss: -11.2025
#
#
# Test set: Average loss: -11.4926
#
# Current Learning rate 0.0001
# Train Epoch: 127 [0/77542 (0%)]	log Loss: -11.546929
#
# Train set: Average log loss: -11.1739
#
#
# Test set: Average loss: -10.8899
#
# Current Learning rate 0.0001
# Train Epoch: 128 [0/77542 (0%)]	log Loss: -10.900137
#
# Train set: Average log loss: -11.3566
#
#
# Test set: Average loss: -11.5552
#
# Current Learning rate 0.0001
# Train Epoch: 129 [0/77542 (0%)]	log Loss: -11.631279
#
# Train set: Average log loss: -11.4812
#
#
# Test set: Average loss: -11.5606
#
# Current Learning rate 0.0001
# Train Epoch: 130 [0/77542 (0%)]	log Loss: -11.633239
#
# Train set: Average log loss: -11.4672
#
#
# Test set: Average loss: -11.5365
#
# Current Learning rate 0.0001
# Train Epoch: 131 [0/77542 (0%)]	log Loss: -11.602688
#
# Train set: Average log loss: -11.4647
#
#
# Test set: Average loss: -11.5064
#
# Current Learning rate 0.0001
# Train Epoch: 132 [0/77542 (0%)]	log Loss: -11.567388
#
# Train set: Average log loss: -11.4588
#
#
# Test set: Average loss: -11.4953
#
# Current Learning rate 0.0001
# Train Epoch: 133 [0/77542 (0%)]	log Loss: -11.552597
#
# Train set: Average log loss: -11.4628
#
#
# Test set: Average loss: -11.4994
#
# Current Learning rate 0.0001
# Train Epoch: 134 [0/77542 (0%)]	log Loss: -11.554356
#
# Train set: Average log loss: -11.4724
#
#
# Test set: Average loss: -11.5095
#
# Current Learning rate 0.0001
# Train Epoch: 135 [0/77542 (0%)]	log Loss: -11.563666
#
# Train set: Average log loss: -11.4767
#
#
# Test set: Average loss: -11.5043
#
# Current Learning rate 0.0001
# Train Epoch: 136 [0/77542 (0%)]	log Loss: -11.554939
#
# Train set: Average log loss: -11.4881
#
#
# Test set: Average loss: -11.4990
#
# Current Learning rate 0.0001
# Train Epoch: 137 [0/77542 (0%)]	log Loss: -11.548204
#
# Train set: Average log loss: -11.4839
#
#
# Test set: Average loss: -11.4685
#
# Current Learning rate 0.0001
# Train Epoch: 138 [0/77542 (0%)]	log Loss: -11.514114
#
# Train set: Average log loss: -11.4994
#
#
# Test set: Average loss: -11.4950
#
# Current Learning rate 0.0001
# Train Epoch: 139 [0/77542 (0%)]	log Loss: -11.542449
#
# Train set: Average log loss: -11.5079
#
#
# Test set: Average loss: -11.4853
#
# Current Learning rate 0.0001
# Train Epoch: 140 [0/77542 (0%)]	log Loss: -11.530392
#
# Train set: Average log loss: -11.5159
#
#
# Test set: Average loss: -11.4959
#
# Current Learning rate 0.0001
# Train Epoch: 141 [0/77542 (0%)]	log Loss: -11.539474
#
# Train set: Average log loss: -11.5307
#
#
# Test set: Average loss: -11.5216
#
# Current Learning rate 0.0001
# Train Epoch: 142 [0/77542 (0%)]	log Loss: -11.565421
#
# Train set: Average log loss: -11.5440
#
#
# Test set: Average loss: -11.6003
#
# Current Learning rate 0.0001
# Train Epoch: 143 [0/77542 (0%)]	log Loss: -11.649774
#
# Train set: Average log loss: -11.5791
#
#
# Test set: Average loss: -11.7672
#
# Current Learning rate 0.0001
# Train Epoch: 144 [0/77542 (0%)]	log Loss: -11.832413
#
# Train set: Average log loss: -11.6547
#
#
# Test set: Average loss: -11.9070
#
# Current Learning rate 0.0001
# Train Epoch: 145 [0/77542 (0%)]	log Loss: -11.998049
#
# Train set: Average log loss: -11.7324
#
#
# Test set: Average loss: -11.7799
#
# Current Learning rate 0.0001
# Train Epoch: 146 [0/77542 (0%)]	log Loss: -11.846925
#
# Train set: Average log loss: -11.6933
#
#
# Test set: Average loss: -11.6129
#
# Current Learning rate 0.0001
# Train Epoch: 147 [0/77542 (0%)]	log Loss: -11.671987
#
# Train set: Average log loss: -11.7160
#
#
# Test set: Average loss: -11.8997
#
# Current Learning rate 0.0001
# Train Epoch: 148 [0/77542 (0%)]	log Loss: -12.002884
#
# Train set: Average log loss: -11.6909
#
#
# Test set: Average loss: -11.9015
#
# Current Learning rate 0.0001
# Train Epoch: 149 [0/77542 (0%)]	log Loss: -12.014746
#
# Train set: Average log loss: -11.6115
#
#
# Test set: Average loss: -11.8809
#
# Current Learning rate 0.0001
# Train Epoch: 150 [0/77542 (0%)]	log Loss: -11.994724
#
# Train set: Average log loss: -11.6167
#
#
# Test set: Average loss: -11.9062
#
# Current Learning rate 0.0001
# Train Epoch: 151 [0/77542 (0%)]	log Loss: -12.017522
#
# Train set: Average log loss: -11.6294
#
#
# Test set: Average loss: -11.9103
#
# Current Learning rate 0.0001
# Train Epoch: 152 [0/77542 (0%)]	log Loss: -12.021026
#
# Train set: Average log loss: -11.6288
#
#
# Test set: Average loss: -11.9072
#
# Current Learning rate 0.0001
# Train Epoch: 153 [0/77542 (0%)]	log Loss: -12.018738
#
# Train set: Average log loss: -11.6212
#
#
# Test set: Average loss: -11.8807
#
# Current Learning rate 0.0001
# Train Epoch: 154 [0/77542 (0%)]	log Loss: -11.992035
#
# Train set: Average log loss: -11.6235
#
#
# Test set: Average loss: -11.8708
#
# Current Learning rate 0.0001
# Train Epoch: 155 [0/77542 (0%)]	log Loss: -11.979435
#
# Train set: Average log loss: -11.6166
#
#
# Test set: Average loss: -11.8656
#
# Current Learning rate 0.0001
# Train Epoch: 156 [0/77542 (0%)]	log Loss: -11.976647
#
# Train set: Average log loss: -11.6097
#
#
# Test set: Average loss: -11.9515
#
# Current Learning rate 0.0001
# Train Epoch: 157 [0/77542 (0%)]	log Loss: -12.049073
#
# Train set: Average log loss: -11.4330
#
#
# Test set: Average loss: -11.4916
#
# Current Learning rate 0.0001
# Train Epoch: 158 [0/77542 (0%)]	log Loss: -11.521657
#
# Train set: Average log loss: -11.5245
#
#
# Test set: Average loss: -11.1598
#
# Current Learning rate 0.0001
# Train Epoch: 159 [0/77542 (0%)]	log Loss: -11.169429
#
# Train set: Average log loss: -11.5708
#
#
# Test set: Average loss: -11.3636
#
# Current Learning rate 0.0001
# Train Epoch: 160 [0/77542 (0%)]	log Loss: -11.383547
#
# Train set: Average log loss: -11.5400
#
#
# Test set: Average loss: -11.9302
#
# Current Learning rate 0.0001
# Train Epoch: 161 [0/77542 (0%)]	log Loss: -11.994786
#
# Train set: Average log loss: -11.5371
#
#
# Test set: Average loss: -11.7322
#
# Current Learning rate 0.0001
# Train Epoch: 162 [0/77542 (0%)]	log Loss: -11.804102
#
# Train set: Average log loss: -11.5820
#
#
# Test set: Average loss: -11.6298
#
# Current Learning rate 0.0001
# Train Epoch: 163 [0/77542 (0%)]	log Loss: -11.707113
#
# Train set: Average log loss: -11.6080
#
#
# Test set: Average loss: -11.7223
#
# Current Learning rate 0.0001
# Train Epoch: 164 [0/77542 (0%)]	log Loss: -11.809811
#
# Train set: Average log loss: -11.6441
#
#
# Test set: Average loss: -11.7770
#
# Current Learning rate 0.0001
# Train Epoch: 165 [0/77542 (0%)]	log Loss: -11.872873
#
# Train set: Average log loss: -11.6540
#
#
# Test set: Average loss: -11.7943
#
# Current Learning rate 0.0001
# Train Epoch: 166 [0/77542 (0%)]	log Loss: -11.896002
#
# Train set: Average log loss: -11.6894
#
#
# Test set: Average loss: -11.8311
#
# Current Learning rate 0.0001
# Train Epoch: 167 [0/77542 (0%)]	log Loss: -11.933422
#
# Train set: Average log loss: -11.7345
#
#
# Test set: Average loss: -11.9525
#
# Current Learning rate 0.0001
# Train Epoch: 168 [0/77542 (0%)]	log Loss: -12.062713
#
# Train set: Average log loss: -11.8042
#
#
# Test set: Average loss: -11.9666
#
# Current Learning rate 0.0001
# Train Epoch: 169 [0/77542 (0%)]	log Loss: -12.049140
#
# Train set: Average log loss: -11.9039
#
#
# Test set: Average loss: -11.8855
#
# Current Learning rate 0.0001
# Train Epoch: 170 [0/77542 (0%)]	log Loss: -11.963143
#
# Train set: Average log loss: -11.8656
#
#
# Test set: Average loss: -12.0375
#
# Current Learning rate 0.0001
# Train Epoch: 171 [0/77542 (0%)]	log Loss: -12.156575
#
# Train set: Average log loss: -11.6957
#
#
# Test set: Average loss: -12.0446
#
# Current Learning rate 0.0001
# Train Epoch: 172 [0/77542 (0%)]	log Loss: -12.168045
#
# Train set: Average log loss: -11.7585
#
#
# Test set: Average loss: -12.0520
#
# Current Learning rate 0.0001
# Train Epoch: 173 [0/77542 (0%)]	log Loss: -12.175306
#
# Train set: Average log loss: -11.7069
#
#
# Test set: Average loss: -12.0599
#
# Current Learning rate 0.0001
# Train Epoch: 174 [0/77542 (0%)]	log Loss: -12.180910
#
# Train set: Average log loss: -11.7436
#
#
# Test set: Average loss: -12.0647
#
# Current Learning rate 0.0001
# Train Epoch: 175 [0/77542 (0%)]	log Loss: -12.186147
#
# Train set: Average log loss: -11.7549
#
#
# Test set: Average loss: -12.0589
#
# Current Learning rate 0.0001
# Train Epoch: 176 [0/77542 (0%)]	log Loss: -12.170471
#
# Train set: Average log loss: -11.6206
#
#
# Test set: Average loss: -12.0526
#
# Current Learning rate 0.0001
# Train Epoch: 177 [0/77542 (0%)]	log Loss: -12.166767
#
# Train set: Average log loss: -11.6728
#
#
# Test set: Average loss: -11.3251
#
# Current Learning rate 0.0001
# Train Epoch: 178 [0/77542 (0%)]	log Loss: -11.332078
#
# Train set: Average log loss: -11.5609
#
#
# Test set: Average loss: -11.7382
#
# Current Learning rate 0.0001
# Train Epoch: 179 [0/77542 (0%)]	log Loss: -11.788265
#
# Train set: Average log loss: -11.7931
#
#
# Test set: Average loss: -11.7294
#
# Current Learning rate 0.0001
# Train Epoch: 180 [0/77542 (0%)]	log Loss: -11.778991
#
# Train set: Average log loss: -11.8170
#
#
# Test set: Average loss: -11.5835
#
# Current Learning rate 0.0001
# Train Epoch: 181 [0/77542 (0%)]	log Loss: -11.614594
#
# Train set: Average log loss: -11.8122
#
#
# Test set: Average loss: -11.6666
#
# Current Learning rate 0.0001
# Train Epoch: 182 [0/77542 (0%)]	log Loss: -11.707965
#
# Train set: Average log loss: -11.8249
#
#
# Test set: Average loss: -12.0413
#
# Current Learning rate 0.0001
# Train Epoch: 183 [0/77542 (0%)]	log Loss: -12.144875
#
# Train set: Average log loss: -11.8227
#
#
# Test set: Average loss: -11.9395
#
# Current Learning rate 0.0001
# Train Epoch: 184 [0/77542 (0%)]	log Loss: -12.017363
#
# Train set: Average log loss: -11.5692
#
#
# Test set: Average loss: -11.2382
#
# Current Learning rate 0.0001
# Train Epoch: 185 [0/77542 (0%)]	log Loss: -11.248734
#
# Train set: Average log loss: -11.6567
#
#
# Test set: Average loss: -11.8583
#
# Current Learning rate 0.0001
# Train Epoch: 186 [0/77542 (0%)]	log Loss: -11.921944
#
# Train set: Average log loss: -11.8377
#
#
# Test set: Average loss: -11.7414
#
# Current Learning rate 0.0001
# Train Epoch: 187 [0/77542 (0%)]	log Loss: -11.789131
#
# Train set: Average log loss: -11.8608
#
#
# Test set: Average loss: -11.6240
#
# Current Learning rate 0.0001
# Train Epoch: 188 [0/77542 (0%)]	log Loss: -11.660131
#
# Train set: Average log loss: -11.8708
#
#
# Test set: Average loss: -12.0380
#
# Current Learning rate 0.0001
# Train Epoch: 189 [0/77542 (0%)]	log Loss: -12.136895
#
# Train set: Average log loss: -11.8069
#
#
# Test set: Average loss: -12.0274
#
# Current Learning rate 0.0001
# Train Epoch: 190 [0/77542 (0%)]	log Loss: -12.119369
#
# Train set: Average log loss: -11.6446
#
#
# Test set: Average loss: -11.3715
#
# Current Learning rate 0.0001
# Train Epoch: 191 [0/77542 (0%)]	log Loss: -11.390802
#
# Train set: Average log loss: -11.7529
#
#
# Test set: Average loss: -11.4645
#
# Current Learning rate 0.0001
# Train Epoch: 192 [0/77542 (0%)]	log Loss: -11.487273
#
# Train set: Average log loss: -11.7612
#
#
# Test set: Average loss: -11.7083
#
# Current Learning rate 0.0001
# Train Epoch: 193 [0/77542 (0%)]	log Loss: -11.751737
#
# Train set: Average log loss: -11.8150
#
#
# Test set: Average loss: -11.7056
#
# Current Learning rate 0.0001
# Train Epoch: 194 [0/77542 (0%)]	log Loss: -11.751316
#
# Train set: Average log loss: -11.8877
#
#
# Test set: Average loss: -11.7697
#
# Current Learning rate 0.0001
# Train Epoch: 195 [0/77542 (0%)]	log Loss: -11.826656
#
# Train set: Average log loss: -11.8914
#
#
# Test set: Average loss: -11.9856
#
# Current Learning rate 0.0001
# Train Epoch: 196 [0/77542 (0%)]	log Loss: -12.077215
#
# Train set: Average log loss: -11.7289
#
#
# Test set: Average loss: -11.7641
#
# Current Learning rate 0.0001
# Train Epoch: 197 [0/77542 (0%)]	log Loss: -11.819440
#
# Train set: Average log loss: -11.8399
#
#
# Test set: Average loss: -11.8854
#
# Current Learning rate 0.0001
# Train Epoch: 198 [0/77542 (0%)]	log Loss: -11.959022
#
# Train set: Average log loss: -11.8790
#
#
# Test set: Average loss: -12.0139
#
# Current Learning rate 0.0001
# Train Epoch: 199 [0/77542 (0%)]	log Loss: -12.108903
#
# Train set: Average log loss: -11.7336
#
#
# Test set: Average loss: -11.7482
#
# Current Learning rate 0.0001
# Train Epoch: 200 [0/77542 (0%)]	log Loss: -11.799551
#
# Train set: Average log loss: -11.8082
#
#
# Test set: Average loss: -11.5439
#
# Current Learning rate 0.0001
# Train Epoch: 201 [0/77542 (0%)]	log Loss: -11.581243
#
# Train set: Average log loss: -11.8143
#
#
# Test set: Average loss: -11.4745
#
# Current Learning rate 0.0001
# Train Epoch: 202 [0/77542 (0%)]	log Loss: -11.506765
#
# Train set: Average log loss: -11.8092
#
#
# Test set: Average loss: -11.2544
#
# Current Learning rate 0.0001
# Train Epoch: 203 [0/77542 (0%)]	log Loss: -11.274498
#
# Train set: Average log loss: -11.7159
#
#
# Test set: Average loss: -11.9330
#
# Current Learning rate 0.0001
# Train Epoch: 204 [0/77542 (0%)]	log Loss: -12.007545
#
# Train set: Average log loss: -11.6388
#
#
# Test set: Average loss: -11.8983
#
# Current Learning rate 0.0001
# Train Epoch: 205 [0/77542 (0%)]	log Loss: -11.984405
#
# Train set: Average log loss: -11.7468
#
#
# Test set: Average loss: -11.8364
#
# Current Learning rate 0.0001
# Train Epoch: 206 [0/77542 (0%)]	log Loss: -11.911701
#
# Train set: Average log loss: -11.6128
#
#
# Test set: Average loss: -11.9288
#
# Current Learning rate 0.0001
# Train Epoch: 207 [0/77542 (0%)]	log Loss: -12.031732
#
# Train set: Average log loss: -11.4988
#
#
# Test set: Average loss: -12.0256
#
# Current Learning rate 0.0001
# Train Epoch: 208 [0/77542 (0%)]	log Loss: -12.111702
#
# Train set: Average log loss: -11.5809
#
#
# Test set: Average loss: -11.8742
#
# Current Learning rate 0.0001
# Train Epoch: 209 [0/77542 (0%)]	log Loss: -11.938173
#
# Train set: Average log loss: -11.7779
#
#
# Test set: Average loss: -12.0852
#
# Current Learning rate 0.0001
# Train Epoch: 210 [0/77542 (0%)]	log Loss: -12.183283
#
# Train set: Average log loss: -11.8193
#
#
# Test set: Average loss: -12.0126
#
# Current Learning rate 0.0001
# Train Epoch: 211 [0/77542 (0%)]	log Loss: -12.093634
#
# Train set: Average log loss: -11.7949
#
#
# Test set: Average loss: -11.9638
#
# Current Learning rate 0.0001
# Train Epoch: 212 [0/77542 (0%)]	log Loss: -12.033410
#
# Train set: Average log loss: -11.8004
#
#
# Test set: Average loss: -11.9924
#
# Current Learning rate 0.0001
# Train Epoch: 213 [0/77542 (0%)]	log Loss: -12.065847
#
# Train set: Average log loss: -11.8073
#
#
# Test set: Average loss: -11.9495
#
# Current Learning rate 0.0001
# Train Epoch: 214 [0/77542 (0%)]	log Loss: -12.013042
#
# Train set: Average log loss: -11.8039
#
#
# Test set: Average loss: -11.9195
#
# Current Learning rate 0.0001
# Train Epoch: 215 [0/77542 (0%)]	log Loss: -11.978384
#
# Train set: Average log loss: -11.8154
#
#
# Test set: Average loss: -11.9265
#
# Current Learning rate 0.0001
# Train Epoch: 216 [0/77542 (0%)]	log Loss: -11.985529
#
# Train set: Average log loss: -11.8119
#
#
# Test set: Average loss: -11.8867
#
# Current Learning rate 0.0001
# Train Epoch: 217 [0/77542 (0%)]	log Loss: -11.938879
#
# Train set: Average log loss: -11.8203
#
#
# Test set: Average loss: -11.9009
#
# Current Learning rate 0.0001
# Train Epoch: 218 [0/77542 (0%)]	log Loss: -11.954051
#
# Train set: Average log loss: -11.8279
#
#
# Test set: Average loss: -11.8790
#
# Current Learning rate 0.0001
# Train Epoch: 219 [0/77542 (0%)]	log Loss: -11.927053
#
# Train set: Average log loss: -11.8164
#
#
# Test set: Average loss: -11.8268
#
# Current Learning rate 0.0001
# Train Epoch: 220 [0/77542 (0%)]	log Loss: -11.870115
#
# Train set: Average log loss: -11.8364
#
#
# Test set: Average loss: -11.8702
#
# Current Learning rate 0.0001
# Train Epoch: 221 [0/77542 (0%)]	log Loss: -11.917989
#
# Train set: Average log loss: -11.8381
#
#
# Test set: Average loss: -11.8287
#
# Current Learning rate 0.0001
# Train Epoch: 222 [0/77542 (0%)]	log Loss: -11.870579
#
# Train set: Average log loss: -11.8475
#
#
# Test set: Average loss: -11.8319
#
# Current Learning rate 0.0001
# Train Epoch: 223 [0/77542 (0%)]	log Loss: -11.876194
#
# Train set: Average log loss: -11.8275
#
#
# Test set: Average loss: -11.7880
#
# Current Learning rate 0.0001
# Train Epoch: 224 [0/77542 (0%)]	log Loss: -11.824164
#
# Train set: Average log loss: -11.8462
#
#
# Test set: Average loss: -11.8118
#
# Current Learning rate 0.0001
# Train Epoch: 225 [0/77542 (0%)]	log Loss: -11.851409
#
# Train set: Average log loss: -11.8527
#
#
# Test set: Average loss: -11.8144
#
# Current Learning rate 0.0001
# Train Epoch: 226 [0/77542 (0%)]	log Loss: -11.855386
#
# Train set: Average log loss: -11.8583
#
#
# Test set: Average loss: -11.8099
#
# Current Learning rate 0.0001
# Train Epoch: 227 [0/77542 (0%)]	log Loss: -11.848645
#
# Train set: Average log loss: -11.8543
#
#
# Test set: Average loss: -11.8144
#
# Current Learning rate 0.0001
# Train Epoch: 228 [0/77542 (0%)]	log Loss: -11.853615
#
# Train set: Average log loss: -11.8805
#
#
# Test set: Average loss: -11.8601
#
# Current Learning rate 0.0001
# Train Epoch: 229 [0/77542 (0%)]	log Loss: -11.905321
#
# Train set: Average log loss: -11.8962
#
#
# Test set: Average loss: -11.9670
#
# Current Learning rate 0.0001
# Train Epoch: 230 [0/77542 (0%)]	log Loss: -12.022754
#
# Train set: Average log loss: -11.9429
#
#
# Test set: Average loss: -12.1697
#
# Current Learning rate 0.0001
# Train Epoch: 231 [0/77542 (0%)]	log Loss: -12.259873
#
# Train set: Average log loss: -12.0392
#
#
# Test set: Average loss: -12.2758
#
# Current Learning rate 0.0001
# Train Epoch: 232 [0/77542 (0%)]	log Loss: -12.392443
#
# Train set: Average log loss: -12.1416
#
#
# Test set: Average loss: -12.0147
#
# Current Learning rate 0.0001
# Train Epoch: 233 [0/77542 (0%)]	log Loss: -12.080417
#
# Train set: Average log loss: -12.2267
#
#
# Test set: Average loss: -12.0688
#
# Current Learning rate 0.0001
# Train Epoch: 234 [0/77542 (0%)]	log Loss: -12.145786
#
# Train set: Average log loss: -12.0508
#
#
# Test set: Average loss: -12.2521
#
# Current Learning rate 0.0001
# Train Epoch: 235 [0/77542 (0%)]	log Loss: -12.371039
#
# Train set: Average log loss: -11.8811
#
#
# Test set: Average loss: -12.0434
#
# Current Learning rate 0.0001
# Train Epoch: 236 [0/77542 (0%)]	log Loss: -12.119924
#
# Train set: Average log loss: -12.0106
#
#
# Test set: Average loss: -12.2189
#
# Current Learning rate 0.0001
# Train Epoch: 237 [0/77542 (0%)]	log Loss: -12.331511
#
# Train set: Average log loss: -11.9061
#
#
# Test set: Average loss: -12.0502
#
# Current Learning rate 0.0001
# Train Epoch: 238 [0/77542 (0%)]	log Loss: -12.128115
#
# Train set: Average log loss: -11.9968
#
#
# Test set: Average loss: -12.1476
#
# Current Learning rate 0.0001
# Train Epoch: 239 [0/77542 (0%)]	log Loss: -12.245063
#
# Train set: Average log loss: -11.9247
#
#
# Test set: Average loss: -12.0786
#
# Current Learning rate 0.0001
# Train Epoch: 240 [0/77542 (0%)]	log Loss: -12.162680
#
# Train set: Average log loss: -12.0249
#
#
# Test set: Average loss: -11.9107
#
# Current Learning rate 0.0001
# Train Epoch: 241 [0/77542 (0%)]	log Loss: -11.966476
#
# Train set: Average log loss: -11.7419
#
#
# Test set: Average loss: -11.9845
#
# Current Learning rate 0.0001
# Train Epoch: 242 [0/77542 (0%)]	log Loss: -12.049250
#
# Train set: Average log loss: -11.9315
#
#
# Test set: Average loss: -12.0651
#
# Current Learning rate 0.0001
# Train Epoch: 243 [0/77542 (0%)]	log Loss: -12.140861
#
# Train set: Average log loss: -12.0710
#
#
# Test set: Average loss: -11.9850
#
# Current Learning rate 0.0001
# Train Epoch: 244 [0/77542 (0%)]	log Loss: -12.048476
#
# Train set: Average log loss: -12.0874
#
#
# Test set: Average loss: -12.1642
#
# Current Learning rate 0.0001
# Train Epoch: 245 [0/77542 (0%)]	log Loss: -12.258416
#
# Train set: Average log loss: -11.8731
#
#
# Test set: Average loss: -12.2053
#
# Current Learning rate 0.0001
# Train Epoch: 246 [0/77542 (0%)]	log Loss: -12.314100
#
# Train set: Average log loss: -12.0653
#
#
# Test set: Average loss: -12.2023
#
# Current Learning rate 0.0001
# Train Epoch: 247 [0/77542 (0%)]	log Loss: -12.316840
#
# Train set: Average log loss: -11.9461
#
#
# Test set: Average loss: -11.8055
#
# Current Learning rate 0.0001
# Train Epoch: 248 [0/77542 (0%)]	log Loss: -11.846900
#
# Train set: Average log loss: -12.1140
#
#
# Test set: Average loss: -11.9850
#
# Current Learning rate 0.0001
# Train Epoch: 249 [0/77542 (0%)]	log Loss: -12.057285
#
# Train set: Average log loss: -11.1463
#
#
# Test set: Average loss: -11.5183
#
# Current Learning rate 0.0001
# Train Epoch: 250 [0/77542 (0%)]	log Loss: -11.530741
#
# Train set: Average log loss: -11.7697
#
#
# Test set: Average loss: -12.2491
#
# Current Learning rate 0.0001
# Train Epoch: 251 [0/77542 (0%)]	log Loss: -12.362782
#
# Train set: Average log loss: -11.9478
#
#
# Test set: Average loss: -12.1537
#
# Current Learning rate 0.0001
# Train Epoch: 252 [0/77542 (0%)]	log Loss: -12.244203
#
# Train set: Average log loss: -11.9576
#
#
# Test set: Average loss: -11.9848
#
# Current Learning rate 0.0001
# Train Epoch: 253 [0/77542 (0%)]	log Loss: -12.046950
#
# Train set: Average log loss: -11.9474
#
#
# Test set: Average loss: -11.9007
#
# Current Learning rate 0.0001
# Train Epoch: 254 [0/77542 (0%)]	log Loss: -11.951823
#
# Train set: Average log loss: -11.9514
#
#
# Test set: Average loss: -11.8688
#
# Current Learning rate 0.0001
# Train Epoch: 255 [0/77542 (0%)]	log Loss: -11.914170
#
# Train set: Average log loss: -11.9525
#
#
# Test set: Average loss: -11.8636
#
# Current Learning rate 0.0001
# Train Epoch: 256 [0/77542 (0%)]	log Loss: -11.909732
#
# Train set: Average log loss: -11.9673
#
#
# Test set: Average loss: -11.9182
#
# Current Learning rate 0.0001
# Train Epoch: 257 [0/77542 (0%)]	log Loss: -11.970669
#
# Train set: Average log loss: -11.9839
#
#
# Test set: Average loss: -12.0319
#
# Current Learning rate 0.0001
# Train Epoch: 258 [0/77542 (0%)]	log Loss: -12.100575
#
# Train set: Average log loss: -12.0350
#
#
# Test set: Average loss: -12.2618
#
# Current Learning rate 0.0001
# Train Epoch: 259 [0/77542 (0%)]	log Loss: -12.377267
#
# Train set: Average log loss: -12.1219
#
#
# Test set: Average loss: -12.3519
#
# Current Learning rate 0.0001
# Train Epoch: 260 [0/77542 (0%)]	log Loss: -12.493135
#
# Train set: Average log loss: -12.2477
#
#
# Test set: Average loss: -12.0807
#
# Current Learning rate 0.0001
# Train Epoch: 261 [0/77542 (0%)]	log Loss: -12.162426
#
# Train set: Average log loss: -12.2924
#
#
# Test set: Average loss: -12.1468
#
# Current Learning rate 0.0001
# Train Epoch: 262 [0/77542 (0%)]	log Loss: -12.239274
#
# Train set: Average log loss: -12.2300
#
#
# Test set: Average loss: -12.0575
#
# Current Learning rate 0.0001
# Train Epoch: 263 [0/77542 (0%)]	log Loss: -12.131437
#
# Train set: Average log loss: -11.8568
#
#
# Test set: Average loss: -12.1558
#
# Current Learning rate 0.0001
# Train Epoch: 264 [0/77542 (0%)]	log Loss: -12.254268
#
# Train set: Average log loss: -12.1676
#
#
# Test set: Average loss: -12.3605
#
# Current Learning rate 0.0001
# Train Epoch: 265 [0/77542 (0%)]	log Loss: -12.506451
#
# Train set: Average log loss: -11.6180
#
#
# Test set: Average loss: -11.9618
#
# Current Learning rate 0.0001
# Train Epoch: 266 [0/77542 (0%)]	log Loss: -12.025921
#
# Train set: Average log loss: -12.1760
#
#
# Test set: Average loss: -12.2233
#
# Current Learning rate 0.0001
# Train Epoch: 267 [0/77542 (0%)]	log Loss: -12.338171
#
# Train set: Average log loss: -12.2517
#
#
# Test set: Average loss: -12.3187
#
# Current Learning rate 0.0001
# Train Epoch: 268 [0/77542 (0%)]	log Loss: -12.452275
#
# Train set: Average log loss: -12.2275
#
#
# Test set: Average loss: -12.3120
#
# Current Learning rate 0.0001
# Train Epoch: 269 [0/77542 (0%)]	log Loss: -12.482908
#
# Train set: Average log loss: -11.7710
#
#
# Test set: Average loss: -12.1249
#
# Current Learning rate 0.0001
# Train Epoch: 270 [0/77542 (0%)]	log Loss: -12.208762
#
# Train set: Average log loss: -12.1385
#
#
# Test set: Average loss: -12.2432
#
# Current Learning rate 0.0001
# Train Epoch: 271 [0/77542 (0%)]	log Loss: -12.355625
#
# Train set: Average log loss: -12.1606
#
#
# Test set: Average loss: -12.2883
#
# Current Learning rate 0.0001
# Train Epoch: 272 [0/77542 (0%)]	log Loss: -12.408045
#
# Train set: Average log loss: -11.8750
#
#
# Test set: Average loss: -12.0329
#
# Current Learning rate 0.0001
# Train Epoch: 273 [0/77542 (0%)]	log Loss: -12.111937
#
# Train set: Average log loss: -12.1981
#
#
# Test set: Average loss: -12.4041
#
# Current Learning rate 0.0001
# Train Epoch: 274 [0/77542 (0%)]	log Loss: -12.570487
#
# Train set: Average log loss: -11.6415
#
#
# Test set: Average loss: -11.9008
#
# Current Learning rate 0.0001
# Train Epoch: 275 [0/77542 (0%)]	log Loss: -11.959407
#
# Train set: Average log loss: -12.0659
#
#
# Test set: Average loss: -11.9064
#
# Current Learning rate 0.0001
# Train Epoch: 276 [0/77542 (0%)]	log Loss: -11.976554
#
# Train set: Average log loss: -12.1475
#
#
# Test set: Average loss: -12.1764
#
# Current Learning rate 0.0001
# Train Epoch: 277 [0/77542 (0%)]	log Loss: -12.287475
#
# Train set: Average log loss: -12.2553
#
#
# Test set: Average loss: -12.2036
#
# Current Learning rate 0.0001
# Train Epoch: 278 [0/77542 (0%)]	log Loss: -12.313749
#
# Train set: Average log loss: -12.2543
#
#
# Test set: Average loss: -12.3683
#
# Current Learning rate 0.0001
# Train Epoch: 279 [0/77542 (0%)]	log Loss: -12.544899
#
# Train set: Average log loss: -11.8751
#
#
# Test set: Average loss: -11.9736
#
# Current Learning rate 0.0001
# Train Epoch: 280 [0/77542 (0%)]	log Loss: -12.043889
#
# Train set: Average log loss: -12.1558
#
#
# Test set: Average loss: -12.3168
#
# Current Learning rate 0.0001
# Train Epoch: 281 [0/77542 (0%)]	log Loss: -12.452501
#
# Train set: Average log loss: -11.9753
#
#
# Test set: Average loss: -12.1157
#
# Current Learning rate 0.0001
# Train Epoch: 282 [0/77542 (0%)]	log Loss: -12.208241
#
# Train set: Average log loss: -12.3654
#
#
# Test set: Average loss: -12.4255
#
# Current Learning rate 0.0001
# Train Epoch: 283 [0/77542 (0%)]	log Loss: -12.606169
#
# Train set: Average log loss: -11.2773
#
#
# Test set: Average loss: -11.9490
#
# Current Learning rate 0.0001
# Train Epoch: 284 [0/77542 (0%)]	log Loss: -12.020067
#
# Train set: Average log loss: -11.9635
#
#
# Test set: Average loss: -11.9065
#
# Current Learning rate 0.0001
# Train Epoch: 285 [0/77542 (0%)]	log Loss: -11.970819
#
# Train set: Average log loss: -11.9328
#
#
# Test set: Average loss: -11.7043
#
# Current Learning rate 0.0001
# Train Epoch: 286 [0/77542 (0%)]	log Loss: -11.748970
#
# Train set: Average log loss: -11.8894
#
#
# Test set: Average loss: -11.9889
#
# Current Learning rate 0.0001
# Train Epoch: 287 [0/77542 (0%)]	log Loss: -12.061158
#
# Train set: Average log loss: -11.9525
#
#
# Test set: Average loss: -12.3112
#
# Current Learning rate 0.0001
# Train Epoch: 288 [0/77542 (0%)]	log Loss: -12.436527
#
# Train set: Average log loss: -12.0035
#
#
# Test set: Average loss: -12.3066
#
# Current Learning rate 0.0001
# Train Epoch: 289 [0/77542 (0%)]	log Loss: -12.427815
#
# Train set: Average log loss: -12.0474
#
#
# Test set: Average loss: -12.2212
#
# Current Learning rate 0.0001
# Train Epoch: 290 [0/77542 (0%)]	log Loss: -12.327922
#
# Train set: Average log loss: -12.0536
#
#
# Test set: Average loss: -12.0745
#
# Current Learning rate 0.0001
# Train Epoch: 291 [0/77542 (0%)]	log Loss: -12.159888
#
# Train set: Average log loss: -12.0602
#
#
# Test set: Average loss: -12.0081
#
# Current Learning rate 0.0001
# Train Epoch: 292 [0/77542 (0%)]	log Loss: -12.083596
#
# Train set: Average log loss: -12.0728
#
#
# Test set: Average loss: -12.0327
#
# Current Learning rate 0.0001
# Train Epoch: 293 [0/77542 (0%)]	log Loss: -12.114798
#
# Train set: Average log loss: -12.1105
#
#
# Test set: Average loss: -12.2098
#
# Current Learning rate 0.0001
# Train Epoch: 294 [0/77542 (0%)]	log Loss: -12.322617
#
# Train set: Average log loss: -12.1818
#
#
# Test set: Average loss: -12.4232
#
# Current Learning rate 0.0001
# Train Epoch: 295 [0/77542 (0%)]	log Loss: -12.594331
#
# Train set: Average log loss: -12.3203
#
#
# Test set: Average loss: -12.2689
#
# Current Learning rate 0.0001
# Train Epoch: 296 [0/77542 (0%)]	log Loss: -12.387594
#
# Train set: Average log loss: -12.4224
#
#
# Test set: Average loss: -12.3247
#
# Current Learning rate 0.0001
# Train Epoch: 297 [0/77542 (0%)]	log Loss: -12.459867
#
# Train set: Average log loss: -12.4416
#
#
# Test set: Average loss: -12.0429
#
# Current Learning rate 0.0001
# Train Epoch: 298 [0/77542 (0%)]	log Loss: -12.120552
#
# Train set: Average log loss: -11.6401
#
#
# Test set: Average loss: -12.1612
#
# Current Learning rate 0.0001
# Train Epoch: 299 [0/77542 (0%)]	log Loss: -12.269305
#
# Train set: Average log loss: -12.3373
#
#
# Test set: Average loss: -12.3552
#
# Current Learning rate 0.0001
# Train Epoch: 300 [0/77542 (0%)]	log Loss: -12.501726
#
# Train set: Average log loss: -12.3485
#
#
# Test set: Average loss: -12.4128
#
# Current Learning rate 0.0001
# Train Epoch: 301 [0/77542 (0%)]	log Loss: -12.605511
#
# Train set: Average log loss: -12.2036
#
#
# Test set: Average loss: -12.4540
#
# Current Learning rate 0.0001
# Train Epoch: 302 [0/77542 (0%)]	log Loss: -12.624770
#
# Train set: Average log loss: -11.5308
#
#
# Test set: Average loss: -12.4369
#
# Current Learning rate 0.0001
# Train Epoch: 303 [0/77542 (0%)]	log Loss: -12.598358
#
# Train set: Average log loss: -12.2425
#
#
# Test set: Average loss: -12.3529
#
# Current Learning rate 0.0001
# Train Epoch: 304 [0/77542 (0%)]	log Loss: -12.485695
#
# Train set: Average log loss: -12.4027
#
#
# Test set: Average loss: -12.3785
#
# Current Learning rate 0.0001
# Train Epoch: 305 [0/77542 (0%)]	log Loss: -12.525781
#
# Train set: Average log loss: -12.4056
#
#
# Test set: Average loss: -12.4338
#
# Current Learning rate 0.0001
# Train Epoch: 306 [0/77542 (0%)]	log Loss: -12.628763
#
# Train set: Average log loss: -12.0848
#
#
# Test set: Average loss: -12.2770
#
# Current Learning rate 0.0001
# Train Epoch: 307 [0/77542 (0%)]	log Loss: -12.456544
#
# Train set: Average log loss: -12.2187
#
#
# ...
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7906 [0/77542 (0%)]	log Loss: -14.158578
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7907 [0/77542 (0%)]	log Loss: -14.158583
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7908 [0/77542 (0%)]	log Loss: -14.158589
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7909 [0/77542 (0%)]	log Loss: -14.158589
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7910 [0/77542 (0%)]	log Loss: -14.158580
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7911 [0/77542 (0%)]	log Loss: -14.158584
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7912 [0/77542 (0%)]	log Loss: -14.158588
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7913 [0/77542 (0%)]	log Loss: -14.158587
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7914 [0/77542 (0%)]	log Loss: -14.158579
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7915 [0/77542 (0%)]	log Loss: -14.158586
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7916 [0/77542 (0%)]	log Loss: -14.158595
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7917 [0/77542 (0%)]	log Loss: -14.158590
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7918 [0/77542 (0%)]	log Loss: -14.158590
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7919 [0/77542 (0%)]	log Loss: -14.158587
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7920 [0/77542 (0%)]	log Loss: -14.158591
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7921 [0/77542 (0%)]	log Loss: -14.158585
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7922 [0/77542 (0%)]	log Loss: -14.158588
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7923 [0/77542 (0%)]	log Loss: -14.158591
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7924 [0/77542 (0%)]	log Loss: -14.158592
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7925 [0/77542 (0%)]	log Loss: -14.158588
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7926 [0/77542 (0%)]	log Loss: -14.158586
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7927 [0/77542 (0%)]	log Loss: -14.158591
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7928 [0/77542 (0%)]	log Loss: -14.158595
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7929 [0/77542 (0%)]	log Loss: -14.158593
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7930 [0/77542 (0%)]	log Loss: -14.158601
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7931 [0/77542 (0%)]	log Loss: -14.158592
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7932 [0/77542 (0%)]	log Loss: -14.158596
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7933 [0/77542 (0%)]	log Loss: -14.158592
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7934 [0/77542 (0%)]	log Loss: -14.158591
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7935 [0/77542 (0%)]	log Loss: -14.158588
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7936 [0/77542 (0%)]	log Loss: -14.158595
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7937 [0/77542 (0%)]	log Loss: -14.158594
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7938 [0/77542 (0%)]	log Loss: -14.158594
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7939 [0/77542 (0%)]	log Loss: -14.158596
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7940 [0/77542 (0%)]	log Loss: -14.158602
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7941 [0/77542 (0%)]	log Loss: -14.158600
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7942 [0/77542 (0%)]	log Loss: -14.158594
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7943 [0/77542 (0%)]	log Loss: -14.158594
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7944 [0/77542 (0%)]	log Loss: -14.158598
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7945 [0/77542 (0%)]	log Loss: -14.158590
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7946 [0/77542 (0%)]	log Loss: -14.158595
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7947 [0/77542 (0%)]	log Loss: -14.158605
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7948 [0/77542 (0%)]	log Loss: -14.158601
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7949 [0/77542 (0%)]	log Loss: -14.158607
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7950 [0/77542 (0%)]	log Loss: -14.158598
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7951 [0/77542 (0%)]	log Loss: -14.158594
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7952 [0/77542 (0%)]	log Loss: -14.158600
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7953 [0/77542 (0%)]	log Loss: -14.158604
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7954 [0/77542 (0%)]	log Loss: -14.158594
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7955 [0/77542 (0%)]	log Loss: -14.158603
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7956 [0/77542 (0%)]	log Loss: -14.158598
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7957 [0/77542 (0%)]	log Loss: -14.158601
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7958 [0/77542 (0%)]	log Loss: -14.158598
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7959 [0/77542 (0%)]	log Loss: -14.158606
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7960 [0/77542 (0%)]	log Loss: -14.158605
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7961 [0/77542 (0%)]	log Loss: -14.158605
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7962 [0/77542 (0%)]	log Loss: -14.158600
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7963 [0/77542 (0%)]	log Loss: -14.158608
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7964 [0/77542 (0%)]	log Loss: -14.158603
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7965 [0/77542 (0%)]	log Loss: -14.158599
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7966 [0/77542 (0%)]	log Loss: -14.158600
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7967 [0/77542 (0%)]	log Loss: -14.158610
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7968 [0/77542 (0%)]	log Loss: -14.158606
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7969 [0/77542 (0%)]	log Loss: -14.158612
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7970 [0/77542 (0%)]	log Loss: -14.158604
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7971 [0/77542 (0%)]	log Loss: -14.158611
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7972 [0/77542 (0%)]	log Loss: -14.158615
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7973 [0/77542 (0%)]	log Loss: -14.158609
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7974 [0/77542 (0%)]	log Loss: -14.158607
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7975 [0/77542 (0%)]	log Loss: -14.158605
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7976 [0/77542 (0%)]	log Loss: -14.158611
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7977 [0/77542 (0%)]	log Loss: -14.158605
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7978 [0/77542 (0%)]	log Loss: -14.158611
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7979 [0/77542 (0%)]	log Loss: -14.158609
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7980 [0/77542 (0%)]	log Loss: -14.158616
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7981 [0/77542 (0%)]	log Loss: -14.158607
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7982 [0/77542 (0%)]	log Loss: -14.158612
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7983 [0/77542 (0%)]	log Loss: -14.158610
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7984 [0/77542 (0%)]	log Loss: -14.158613
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7985 [0/77542 (0%)]	log Loss: -14.158625
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7986 [0/77542 (0%)]	log Loss: -14.158616
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7987 [0/77542 (0%)]	log Loss: -14.158615
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7988 [0/77542 (0%)]	log Loss: -14.158619
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7989 [0/77542 (0%)]	log Loss: -14.158617
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7990 [0/77542 (0%)]	log Loss: -14.158611
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7991 [0/77542 (0%)]	log Loss: -14.158620
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7992 [0/77542 (0%)]	log Loss: -14.158617
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7993 [0/77542 (0%)]	log Loss: -14.158618
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7994 [0/77542 (0%)]	log Loss: -14.158624
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7995 [0/77542 (0%)]	log Loss: -14.158626
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7996 [0/77542 (0%)]	log Loss: -14.158624
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7997 [0/77542 (0%)]	log Loss: -14.158625
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7998 [0/77542 (0%)]	log Loss: -14.158627
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7999 [0/77542 (0%)]	log Loss: -14.158620
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1891
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 8000 [0/77542 (0%)]	log Loss: -14.158623
#
# Train set: Average log loss: -14.2109
#
#
# Test set: Average loss: -13.1892
#
# Current Learning rate 3.0517578125e-09

# %%
# Plotting log(MSE) as a function of epochs
plt.figure(figsize=(10,7))
plt.plot( np.log(test_losses), label = "test")
plt.plot( np.log(train_losses), label = "train")

plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Log(LSE)")
plt.title("MSE over Epoch" )
plt.grid()
print("Training WIDE {} VS in the article 8.04e-09".format(train_losses[-1]) )
# Out:
# Training WIDE 6.734295027280883e-07 VS in the article 8.04e-09

# %% [markdown]
# ## d) Prediction
# #### Load the ANN

# %%
# Loading model
device = 'cuda'
loaded_Heston_IV_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_IV_ANN_DE_25_08_03.pt"
loaded_Heston_IV_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_IV_ANN.eval()
# Out:
# Heston_ANN(
#   (fc1): Linear(in_features=8, out_features=200, bias=True)
#   (fc2): Linear(in_features=200, out_features=200, bias=True)
#   (fc3): Linear(in_features=200, out_features=200, bias=True)
#   (fc4): Linear(in_features=200, out_features=200, bias=True)
#   (fc5): Linear(in_features=200, out_features=1, bias=True)
# )

# %% [markdown]
# #### Quick test of the ANN

# %%
x = hs_dataset[0, :-1].unsqueeze(0).to(device)  # input shape (1, 8)
true_iv = hs_dataset[0, -1].item()

with torch.no_grad():
    predicted_iv = model(x).item()
    predicted_iv2 = loaded_Heston_IV_ANN(x)

print(f"True IV:      {true_iv:.6f}")
print(f"Predicted IV: {predicted_iv:.6f}")
# Out:
# True IV:      0.549429
# Predicted IV: 0.550080

# %%
with torch.no_grad():
    predicted_iv1 = model(x)
    predicted_iv2 = loaded_Heston_IV_ANN(x)

print("Are both predictions equal? ", torch.allclose(predicted_iv1, predicted_iv2, atol=1e-6))
print(f"Model(x):              {predicted_iv1.item():.6f}")
print(f"Loaded_Heston_ANN(x):  {predicted_iv2.item():.6f}")
# Out:
# Are both predictions equal?  True
# Model(x):              0.550080
# Loaded_Heston_ANN(x):  0.550080

# %%
theta_base = np.array([-0.5, 1.0, 0.2, 0.3, 0.1])
kappa_vals = np.linspace(0.7, 1.3, 20)

ivs = []
for kappa in kappa_vals:
    theta = theta_base.copy()
    theta[1] = kappa  # vary kappa
    x = np.hstack([[1.0, 0.5, 0.02], theta])  # ATM, T=0.5
    x_tensor = torch.tensor(x, dtype=torch.float32).unsqueeze(0).to(device)
    iv = loaded_Heston_IV_ANN(x_tensor).item()
    ivs.append(iv)

plt.plot(kappa_vals, ivs)
plt.xlabel("κ")
plt.ylabel("Predicted IV")
plt.title("Sensitivity of IV to κ")
plt.grid(True)
plt.show()

# %% [markdown]
# #### This table shows similar trained forward performance as shown in Table (4) from [1]

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_IV_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_IV_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Train scores----------------
# MSE 6.734164e-07
# MAE 6.358952e-04
# MAPE 1.369428e-03
# R2 9.999310e-01
# -----------Test scores----------------
# MSE 1.870787e-06
# MAE 7.894107e-04
# MAPE 1.744080e-03
# R2 9.998105e-01

# %%
plt.scatter(targets, outputs, alpha=0.1)
plt.xlabel("True IV")
plt.ylabel("Predicted IV")
plt.title("Heston-IV-ANN Fit")
plt.grid(True)
plt.show()

# %% [markdown]
# # 2) Backward pass

# %% [markdown]
# ## a) Preperation Market Quotes

# %% [markdown]
# ### Reference Heston parameter

# %%
# Effect of individual parameters
# Section 4.1.1 in [1]
T = 2 
S0 = 100
kappa = 0.1
gamma = 0.1  
v_bar = 0.1
rho = -0.75
v0 = 0.05
r = 0.05

# %% [markdown]
# ### 35 Market quotes

# %%
# ranges are the same as in Table 5 [1] 

moneyness = np.linspace(0.85, 1.15, 5)
maturity = np.linspace(0.5, 2.0, 7)

market_quotes = []
counter = 1
for tau in maturity:
    for m in moneyness:
        # Step 1: get Heston price for call option
        price = call_option_Heston_moy(160, 12, r, tau, kappa,  gamma, vbar, v0, rho, m)
        
        # Step 2: invert to implied volatility
        iv = calcimpliedvol([m, tau, r, price])  # or use IV-ANN
        
        print(f"{counter:2d}. m={m:.2f}, tau={tau:.2f}, r={r:.2f}, price={float(price):.4f}, IV={float(iv):.4f}")
        market_quotes.append((m, tau, r, iv))
        counter += 1
# Out:
#  1. m=0.85, tau=0.50, r=0.05, price=0.0134, IV=0.2131
#  2. m=0.92, tau=0.50, r=0.05, price=0.0372, IV=0.2202
#  3. m=1.00, tau=0.50, r=0.05, price=0.0762, IV=0.2266
#  4. m=1.07, tau=0.50, r=0.05, price=0.1284, IV=0.2323
#  5. m=1.15, tau=0.50, r=0.05, price=0.1900, IV=0.2376
#  6. m=0.85, tau=0.75, r=0.05, price=0.0251, IV=0.2148
#  7. m=0.92, tau=0.75, r=0.05, price=0.0547, IV=0.2217
#  8. m=1.00, tau=0.75, r=0.05, price=0.0970, IV=0.2280
#  9. m=1.07, tau=0.75, r=0.05, price=0.1498, IV=0.2337
# 10. m=1.15, tau=0.75, r=0.05, price=0.2104, IV=0.2388
# 11. m=0.85, tau=1.00, r=0.05, price=0.0372, IV=0.2164
# 12. m=0.92, tau=1.00, r=0.05, price=0.0709, IV=0.2232
# 13. m=1.00, tau=1.00, r=0.05, price=0.1156, IV=0.2294
# 14. m=1.07, tau=1.00, r=0.05, price=0.1691, IV=0.2350
# 15. m=1.15, tau=1.00, r=0.05, price=0.2293, IV=0.2399
# 16. m=0.85, tau=1.25, r=0.05, price=0.0493, IV=0.2182
# 17. m=0.92, tau=1.25, r=0.05, price=0.0861, IV=0.2245
# 18. m=1.00, tau=1.25, r=0.05, price=0.1327, IV=0.2307
# 19. m=1.07, tau=1.25, r=0.05, price=0.1871, IV=0.2364
# 20. m=1.15, tau=1.25, r=0.05, price=0.2471, IV=0.2410
# 21. m=0.85, tau=1.50, r=0.05, price=0.0614, IV=0.2200
# 22. m=0.92, tau=1.50, r=0.05, price=0.1003, IV=0.2253
# 23. m=1.00, tau=1.50, r=0.05, price=0.1488, IV=0.2321
# 24. m=1.07, tau=1.50, r=0.05, price=0.2041, IV=0.2383
# 25. m=1.15, tau=1.50, r=0.05, price=0.2639, IV=0.2420
# 26. m=0.85, tau=1.75, r=0.05, price=0.0732, IV=0.2218
# 27. m=0.92, tau=1.75, r=0.05, price=0.1134, IV=0.2251
# 28. m=1.00, tau=1.75, r=0.05, price=0.1642, IV=0.2336
# 29. m=1.07, tau=1.75, r=0.05, price=0.2208, IV=0.2410
# 30. m=1.15, tau=1.75, r=0.05, price=0.2801, IV=0.2431
# 31. m=0.85, tau=2.00, r=0.05, price=0.0846, IV=0.2230
# 32. m=0.92, tau=2.00, r=0.05, price=0.1251, IV=0.2232
# 33. m=1.00, tau=2.00, r=0.05, price=0.1791, IV=0.2355
# 34. m=1.07, tau=2.00, r=0.05, price=0.2378, IV=0.2456
# 35. m=1.15, tau=2.00, r=0.05, price=0.2958, IV=0.2446

# %% [markdown]
# ### Objective function

# %%
def calibration_objective(theta, inputs, market_iv, iv_ann):
    # theta: [rho, kappa, vbar, gamma, v0]
    # inputs: [moneyness, maturity, r] fixed per quote
    input_tensor = torch.tensor(np.column_stack([
        inputs,  # shape (N, 3)
        np.tile(theta, (inputs.shape[0], 1))
    ]), dtype=torch.float32).to(device)

    with torch.no_grad():
        pred_iv = iv_ann(input_tensor).cpu().numpy().flatten()

    return np.mean((pred_iv - market_iv) ** 2)

# %% [markdown]
# ### Differential Evolution (DE)

# %% [markdown]
# ### 5 parameters

# %%
market_quotes = np.array(market_quotes)

inputs = market_quotes[:, :3]         # [moneyness, maturity, r]
market_iv = market_quotes[:, 3]       # true IVs
iv_ann = loaded_Heston_IV_ANN         # trained and set to eval()

# %%
# Bounds from Section 4.1.1
#theta: [rho, kappa, vbar, gamma, v0]
#bounds = [(-0.85, 0.05), (0.05, 0.45), (0.05, 0.75), (0.05, 0.45), (0.1, 2.0)] # paper order
#bounds = [(-0.85, 0.05), (0.05, 0.75), (0.05, 0.45), (0.1, 2.0), (0.05, 0.45)]
bounds = [
    (-0.85, -0.05), # rho
    (0.1, 2.0), # kappa
    (0.05, 0.45), # vbar
    (0.05, 0.75), # gamma
    (0.05, 0.45) # v0
]

# --- Run DE optimization ---
result_5_01 = differential_evolution(
    func=calibration_objective,
    bounds=bounds,
    args=(inputs, market_iv, iv_ann),
    strategy="best1bin",
    popsize=50,
    tol=1e-5,
    maxiter=1000,
    updating="deferred"
)

# %%
# Bounds from Section 4.1.1
#theta: [rho, kappa, vbar, gamma, v0]
#bounds = [(-0.85, 0.05), (0.05, 0.45), (0.05, 0.75), (0.05, 0.45), (0.1, 2.0)] # paper order
#bounds = [(-0.85, 0.05), (0.05, 0.75), (0.05, 0.45), (0.1, 2.0), (0.05, 0.45)]
bounds = [
    (-0.85, -0.05), # rho
    (0.4, 2.0), # kappa
    (0.05, 0.45), # vbar
    (0.05, 0.75), # gamma
    (0.05, 0.45) # v0
]

# --- Run DE optimization ---
result_5_04 = differential_evolution(
    func=calibration_objective,
    bounds=bounds,
    args=(inputs, market_iv, iv_ann),
    strategy="best1bin",
    popsize=50,
    tol=1e-5,
    maxiter=1000,
    updating="deferred"
)

# %%
print("Calibrated parameters:")

labels = labels = ["rho", "kappa", "v_bar", "gamma", "v0"]
for label, val in zip(labels, result_5_01.x):
    print(f"{label:<3}= {val:.6f}")

print("Final MSE loss:", result_5_01.fun)
# Out:
# Calibrated parameters:
# rho= -0.381342
# kappa= 0.710578
# v_bar= 0.067189
# gamma= 0.296921
# v0 = 0.050000
# Final MSE loss: 4.460103249239742e-06

# %%
print("Calibrated parameters:")

labels = ["rho", "kappa", "v_bar", "gamma", "v0"]
for label, val in zip(labels, result_5_04.x):
    print(f"{label:<3}= {val:.6f}")

print("Final MSE loss:", result_5_04.fun)
# Out:
# Calibrated parameters:
# rho= -0.381341
# kappa= 0.710665
# v_bar= 0.067187
# gamma= 0.296783
# v0 = 0.050000
# Final MSE loss: 4.460102106382835e-06

# %% [markdown]
# ### Differential Evolution (DE)

# %% [markdown]
# ### 3 parameters (kappa = 0.4, v0 = 0.05 fixed)

# %%
def calibration_objective_3(theta, inputs, market_iv, iv_ann):
    # theta = [rho, vbar, gamma]
    fixed_kappa = 0.4
    fixed_v0    = 0.05

    # Broadcast fixed values
    full_theta = np.column_stack([
        np.full(len(inputs), theta[0]),  # rho
        np.full(len(inputs), fixed_kappa),
        np.full(len(inputs), theta[1]),  # vbar
        np.full(len(inputs), theta[2]),  # gamma
        np.full(len(inputs), fixed_v0)
    ])

    # inputs: moneyness, tau, 

    full_input = np.concatenate([inputs, full_theta], axis=1)
    device = next(iv_ann.parameters()).device
    input_tensor = torch.FloatTensor(full_input).to(device)
    #print(full_input)

    with torch.no_grad():
        pred_iv = iv_ann(input_tensor).cpu().numpy().flatten()


    # Only for debug: inspect predicted vs market IVs
    #for i in range(5):  # show first 5 examples
    #    print(f"m={inputs[i,0]:.2f}, tau={inputs[i,1]:.2f} | Market IV = {market_iv[i]:.4f}, Pred IV = {pred_iv[i]:.4f}")

    return np.mean((pred_iv - market_iv)**2)

# %%
# Fix: kappa = 0.1, v0 = 0.05
bounds_3 = [
    (-0.85, -0.05),  # rho
    (0.05, 0.45),    # vbar
    (0.05, 0.75)     # gamma
]

# --- Run DE optimization ---
result_3 = differential_evolution(
    func=calibration_objective_3,
    bounds=bounds_3,
    args=(inputs, market_iv, iv_ann),
    strategy="best1bin",
    popsize=50,
    tol=1e-5,
    maxiter=1000,
    updating="deferred"
)

# %%
print("Calibrated parameters:")

labels = ["rho", "v_bar", "gamma"]
for label, val in zip(labels, result_3.x):
    print(f"{label:<3}= {val:.6f}")

print("Final MSE loss:", result_3.fun)
# Out:
# Calibrated parameters:
# rho= -0.472529
# v_bar= 0.061306
# gamma= 0.161188
# Final MSE loss: 5.173555286701947e-06

# %% [markdown]
# # DOWN FROM HERE EVERYTHING IS ONLY FOR LOOK UP PURPOSES

# %%
import numpy as np
import itertools

# Define Heston parameter bounds
bounds = {
    "rho": (-0.9, 0.0),         # Correlation coefficient
    "kappa": (0.1, 3.0),        # Speed of mean reversion
    "gamma": (0.01, 0.8),       # Volatility of variance
    "nu_0": (0.01, 0.5),        # Initial variance
    "nu_bar": (0.01, 0.5)       # Long-term variance
}

# Number of discrete points to sample within each parameter's range
points_per_param = 5

# Generate equally spaced points for each parameter within its bounds
parameter_points = {param: np.linspace(lower, upper, points_per_param)
                    for param, (lower, upper) in bounds.items()}

# Combine the points to form a grid of all possible parameter combinations
grid = list(itertools.product(
    parameter_points["rho"],
    parameter_points["kappa"],
    parameter_points["gamma"],
    parameter_points["nu_0"],
    parameter_points["nu_bar"]
))

# Convert the grid into a NumPy array for convenience
parameter_grid = np.array(grid)

# Display the grid details
print(f"Search space dimensions: {len(parameter_points)} parameters")
print(f"Total combinations: {parameter_grid.shape[0]}")
print("Example combinations (first 5 rows):")
print(parameter_grid[:5])

# Optional: Save to a file for later use
np.savetxt("heston_search_space.csv", parameter_grid, delimiter=",",
           header="rho,kappa,gamma,nu_0,nu_bar", comments="")

# %%
import torch
import numpy as np
from scipy.optimize import differential_evolution

def calibrate_with_de(loaded_ANN, moneyness, maturities, r, observed_vols, device="cuda"):
    """
    Calibrates Heston parameters using differential evolution and a trained ANN.
    
    Parameters:
    - loaded_ANN: Trained PyTorch ANN (set to .eval())
    - moneyness: 1D array of moneyness values (e.g., shape (5,))
    - maturities: 1D array of maturities (e.g., shape (7,))
    - r: risk-free rate (scalar)
    - observed_vols: flattened vector of observed implied vols (shape (len(moneyness) * len(maturities),))
    - device: "cuda" or "cpu"
    
    Returns:
    - result.x: optimal Heston parameters [rho, kappa, gamma, nu_bar, nu_0]
    - result.fun: final objective value (MSE)
    """

    # Make sure model is in eval mode
    loaded_ANN.eval()

    # Create full input grid for calibration
    def heston_ann(parameters):
        rho, kappa, gamma, nu_bar, nu_0 = parameters
        inputs = []

        for m in moneyness:
            for t in maturities:
                inputs.append([m, t, r, rho, kappa, nu_bar, gamma, nu_0])

        inputs = torch.tensor(inputs, dtype=torch.float32).to(device)

        with torch.no_grad():
            preds = loaded_ANN(inputs).cpu().numpy().flatten()
        return preds

    # Objective function to minimize
    def calibration_objective(parameters):
        predicted_vols = heston_ann(parameters)
        return np.mean((predicted_vols - observed_vols) ** 2)

    # Bounds for DE (adjust to your actual model/training setup)
    bounds = [
        (-0.85, 0.0),     # rho
        (0.1, 3.0),      # kappa
        (0.01, 0.8),     # gamma
        (0.01, 0.5),     # nu_bar
        (0.01, 0.5),     # nu_0
    ]

    # Run differential evolution
    result = differential_evolution(
        calibration_objective,
        bounds,
        strategy="best1bin",
        popsize=50,
        mutation=(0.5, 1.0),
        recombination=0.7,
        tol=0.001,
        disp=True
    )

    return result.x, result.fun

# %%
# Inputs
moneyness = np.linspace(0.85, 1.15, 5)
maturities = np.linspace(0.5, 2.0, 7)
r = 0.03

# Observed vols must be flat vector of shape (35,)
observed_vols = np.linspace(0.2, 0.5, 35)

# Run calibration
opt_params, final_loss = calibrate_with_de(loaded_Heston_ANN, moneyness, maturities, r, observed_vols)

print("Optimal Heston parameters:")
print(f"rho={opt_params[0]:.4f}, kappa={opt_params[1]:.4f}, gamma={opt_params[2]:.4f}, "
      f"nu_bar={opt_params[3]:.4f}, nu_0={opt_params[4]:.4f}")
print(f"Final MSE: {final_loss:.6e}")
# Out:
# differential_evolution step 1: f(x)= 0.00392477
# differential_evolution step 2: f(x)= 0.00392477
# differential_evolution step 3: f(x)= 0.00379698
# differential_evolution step 4: f(x)= 0.00376597
# differential_evolution step 5: f(x)= 0.00376597
# differential_evolution step 6: f(x)= 0.00376597
# differential_evolution step 7: f(x)= 0.0036891
# differential_evolution step 8: f(x)= 0.00364717
# differential_evolution step 9: f(x)= 0.00364717
# differential_evolution step 10: f(x)= 0.00364717
# differential_evolution step 11: f(x)= 0.00364717
# differential_evolution step 12: f(x)= 0.00364717
# differential_evolution step 13: f(x)= 0.00364717
# differential_evolution step 14: f(x)= 0.00364717
# differential_evolution step 15: f(x)= 0.00364717
# differential_evolution step 16: f(x)= 0.00364717
# differential_evolution step 17: f(x)= 0.00364717
# differential_evolution step 18: f(x)= 0.0036225
# differential_evolution step 19: f(x)= 0.0036225
# differential_evolution step 20: f(x)= 0.0036225
# differential_evolution step 21: f(x)= 0.0036225
# differential_evolution step 22: f(x)= 0.0036225
# differential_evolution step 23: f(x)= 0.0036225
# differential_evolution step 24: f(x)= 0.0036225
# differential_evolution step 25: f(x)= 0.00362203
# differential_evolution step 26: f(x)= 0.00362061
# differential_evolution step 27: f(x)= 0.00362061
# differential_evolution step 28: f(x)= 0.00361841
# differential_evolution step 29: f(x)= 0.00361841
# differential_evolution step 30: f(x)= 0.00361841
# differential_evolution step 31: f(x)= 0.00361681
# differential_evolution step 32: f(x)= 0.00361562
# differential_evolution step 33: f(x)= 0.00361163
# differential_evolution step 34: f(x)= 0.00361163
# differential_evolution step 35: f(x)= 0.00361021
# differential_evolution step 36: f(x)= 0.00361001
# differential_evolution step 37: f(x)= 0.00361001
# differential_evolution step 38: f(x)= 0.00361001
# differential_evolution step 39: f(x)= 0.0036084
# differential_evolution step 40: f(x)= 0.0036084
# differential_evolution step 41: f(x)= 0.0036084
# differential_evolution step 42: f(x)= 0.0036084
# differential_evolution step 43: f(x)= 0.0036084
# differential_evolution step 44: f(x)= 0.00360806
# differential_evolution step 45: f(x)= 0.00360787
# differential_evolution step 46: f(x)= 0.00360778
# differential_evolution step 47: f(x)= 0.00360765
# Polishing solution with 'L-BFGS-B'
# Optimal Heston parameters:
# rho=-0.1873, kappa=0.1609, gamma=0.2718, nu_bar=0.4995, nu_0=0.5000
# Final MSE: 3.607652e-03

# %%
import numpy as np

# Observed market implied volatilities (target data)

observed_vols = np.linspace(0.2, 0.5, 35)  # Generates 35 equally spaced values

# Moneyness and time-to-maturity of the observed data
moneyness = np.linspace(0.85, 1.15, 5)  # Moneyness
maturities = np.linspace(0.5, 2.0, 7)   # Time to maturity
r = 0.03
#params = 



# Pre-trained ANN that maps Heston parameters to implied volatilities
def heston_ann(parameters):
    """
    A mock function representing the ANN (pre-trained forward pass).
    In real scenarios, this will return ANN-predicted implied volatilities.
    """
    # Example: Simple mapping for illustration
    rho, kappa, gamma, nu_bar, nu_0 = parameters
    return 0.25 + 0.05 * (moneyness - 1.0) + 0.02 * (maturities - 1.0)

# Objective function for DE calibration
def calibration_objective(parameters):
    """
    Calculates the mean squared error between ANN-predicted
    and observed market volatilities.
    """
    predicted_vols = implied_vol_pipe2
    error = np.mean((predicted_vols - observed_vols) ** 2)
    return error

# %%
bounds = [
    (-0.75, -0.25),   # rho (correlation)
    (0.5, 1.0),    # kappa (mean reversion speed)
    (0.3, 0.5),   # gamma (volatility of variance)
    (0.15, 0.35),   # nu_bar (long-run variance)
    (0.5, 1.0)    # nu_0 (initial variance)
]

# %%
from scipy.optimize import differential_evolution

# Run DE to calibrate the Heston parameters
result = differential_evolution(
    calibration_objective,  # Objective function
    bounds,                 # Parameter bounds
    strategy="best1bin",    # Strategy for mutation
    popsize=50,             # Population size
    mutation=(0.5, 1.0),    # Mutation range
    recombination=0.7,      # Crossover probability
    tol=0.01,               # Convergence tolerance
    disp=True               # Display optimization progress
)

# Display calibrated parameters
print("Calibrated Parameters:", result.x)
print("Objective Function Value:", result.fun)

# %%
# Function to calculate implied volatility using Brent's method
def calc_implied_vol(dataset):
    """
    Computes implied volatilities using the Brent method.
    :param dataset: numpy array containing [S/K, T, r, OptionPrice].
    :return: A single implied volatility value.
    """
    money, T, r, market_price = dataset

    def bs_price(sigma):
        """Black-Scholes option price difference function."""
        d1 = (np.log(money) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
        d2 = d1 - sigma * np.sqrt(T)
        theoretical_price = money * norm.cdf(d1) - np.exp(-r * T) * norm.cdf(d2)
        return theoretical_price - market_price

    # Solve for implied volatility
    try:
        return optimize.brentq(bs_price, 1e-5, 5, maxiter=100)
    except ValueError:
        return np.nan  # Return NaN if Brent fails to converge

# Data generation or loading
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds=l_bounds, u_bounds=u_bounds)
hs_data_loader = DataLoader(hs_dataset, batch_size=4048)

# Step 1: Compute prices using Heston-ANN
predicted_prices = []
with torch.no_grad():
    for data in hs_data_loader:
        inputs = data[:, :-1].to(device)  # Exclude the last column if it's labels
        outputs = loaded_Heston_ANN(inputs)
        predicted_prices.append(outputs.cpu().numpy())
predicted_prices = np.concatenate(predicted_prices)

# Step 2: Prepare the dataset for Brent's method
# Combine predicted prices with necessary inputs for implied volatility calculation
# Assuming hs_dataset.data contains [S/K, T, r, actual_price]:
hs_dataset_data = hs_dataset.data[:, np.array([0, 1, 2])]  # Extract relevant columns
hs_dataset_data = np.hstack((hs_dataset_data, predicted_prices.reshape(-1, 1)))

# Step 3: Calculate implied volatilities
implied_volatilities = np.apply_along_axis(calc_implied_vol, 1, hs_dataset_data)

# Step 4: Evaluate results
# Assuming you have ground-truth implied volatilities for comparison
ground_truth_vol = hs_dataset.data[:, 3]  # Replace with actual column for ground truth
mse = ((ground_truth_vol - implied_volatilities) ** 2).mean()
print(f"MSE: {mse:.6e}")

# %%
# Loading Train / Test Data
hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0]-train_size])
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}
train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs, targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs, targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs, targets)) )
print("R2 {:e}".format(r2_score(outputs, targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs, targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs, targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs, targets)) )
print("R2 {:e}".format(r2_score(outputs, targets)) )

# %%
np.sqrt(1.670718e-07)
print("MSE {:e}".format(np.sqrt(1.670718e-07)) )

# %% [markdown]
# # DOWN FROM HERE EVERYTHING IS ONLY FOR LOOK UP PURPOSES

# %% [markdown]
# # 5) BRENT

# %% [markdown]
# # 6) Pipeline 1: COS + BRENT

# %%
eps = 1e-2 # is used to generate open intervals
# (S/K), (tau), (r), (rho), (kappa), (vbar), (gamma), (v0).
# CASE 1 in table 11
l_bounds = [.75+eps, .4+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps]
u_bounds = [1.25-eps, 1.0-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds = l_bounds, u_bounds=u_bounds)
hs_dataset_data = hs_dataset.data
hs_dataset_data = hs_dataset_data[:,np.array([0,1,2,8])]
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, hs_dataset_data)

# %% [markdown]
# # 7) Pipeline 2: Heston-ANN + IV-ANN

# %%
# Loading model
device = torch.device("cuda")
loaded_Heston_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_ANN.pt"
loaded_Heston_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_ANN.eval()

# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

# Loading model 
device = torch.device("cuda")
loaded_IV_ANN = IV_ANN().to(device)
PATH = "ANN_weights/IV_SCALED_ANN.pt"
loaded_IV_ANN.load_state_dict(torch.load(PATH))
loaded_IV_ANN.eval()


# Plugging in the Heston-ANN prices
hs_dataset2 = hs_dataset.data[:,np.array([0,1,2,8])]
hs_dataset2.data[:,3] = torch.FloatTensor(prices)
loader2 = torch.utils.data.DataLoader(hs_dataset2, 4048)

# Computing IVs
implied_vol = []
indecies_list = []
with torch.no_grad():
  for idx, data in enumerate(loader2):
    data = data.to(device)
    # LOG Transformation
    data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
    data[:,3] = torch.log(data[:,3])
    output = loaded_IV_ANN(data)
    implied_vol.append((output).data.cpu().numpy())
  implied_vol_pipe2 = np.concatenate(implied_vol)
  # indecies_list = np.concatenate(indecies_list).flatten()

# %%
# Eliminating Nan values resulting from prices lower than 1e-7
indecies = np.argwhere(np.isnan(implied_vol_pipe2))
implied_vol_pipe1 = np.delete(implied_vol_pipe1, indecies,0)
implied_vol_pipe2 = np.delete(implied_vol_pipe2, indecies,0)

# %% [markdown]
# # 8) Pipeline 1 VS pipeline 2

# %%
# CASE 1
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
#targets = vol_imp
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )

# %%
# CASE 2
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )

# %% [markdown]
# # 9) Volatility surface (COS + IV-ANN)

# %% [markdown]
# ### Initial volatility surface

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
moyeness = np.linspace(moyeness, 1.24,11)
tau = np.linspace(tau, 1, 6)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(66)).reshape((-1, 1))

# %%
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  bs_IV = (output).data.cpu().numpy()

X = X.flatten()
Y = Y.flatten()
Z = bs_IV

x = np.reshape(X, (-1, 6))
y = np.reshape(Y, (-1, 6))
z = np.reshape(Z, (-1, 6))

# %%
from mpl_toolkits import mplot3d
from matplotlib import cm

# %%
# Plotting the initial volatility surface
plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to matuirity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Smoothing the volatility surface

# %%
from scipy import interpolate

# %%
# Smoothing the volatility surface
xnew, ynew = x.copy(), y.copy()
tck = interpolate.bisplrep(x, y, z, s=1.0)
znew = interpolate.bisplev(xnew[:,0], ynew[0,:], tck)

plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(xnew, ynew, znew,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to maturity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Implied volatility difference

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
n_moneyness = 11
n_tau = 6
moyeness = np.linspace(moyeness, 1.24,n_moneyness)
tau = np.linspace(tau, 1, n_tau)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
rho = np.array(rho*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
kappa = np.array(kappa*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
vbar = np.array(vbar*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
gamma = np.array(gamma*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
v0 = np.array(v0*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(n_tau * n_moneyness)).reshape((-1, 1))

# %%
data_ann = np.concatenate((X, Y, r, rho, kappa, vbar, gamma, v0, cos_prices), axis = 1)
data_ann = torch.FloatTensor(data_ann)
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  implied_vol_pipe2 = (output).data.cpu().numpy()

# %%
X = X.flatten()
Y = Y.flatten()
Z = (implied_vol_pipe1 - implied_vol_pipe2).flatten()

x = np.reshape(X, (-1, min(n_moneyness, n_tau)))
y = np.reshape(Y, (-1, min(n_moneyness, n_tau)))
z = np.reshape(Z, (-1, min(n_moneyness, n_tau)))

plt.figure(figsize=(8,8))
plt.pcolormesh(x, y, z, shading='gouraud')
plt.colorbar()
plt.xlabel("Moneyness")
plt.ylabel("Time to maturity")
plt.show()

# %%
# Re-import necessary libraries and re-define the setup after reset
from scipy.optimize import differential_evolution
import numpy as np

# Define the objective function
def objective_function(x):
    # Example: A simple quadratic function
    return x[0]**2 + x[1]**2 + x[2]**2

# Define the bounds for each variable
bounds = [(-10, 10), (-10, 10), (-10, 10)]  # Variable bounds for a 3D problem

# Run Differential Evolution with the specified settings
result_custom_de = differential_evolution(
    objective_function,  # Objective function
    bounds,             # Variable bounds
    strategy="best1bin",  # Strategy
    popsize=50,          # Population size
    mutation=(0.5, 1.0), # Mutation range
    recombination=0.7,   # Crossover probability
    tol=0.01,            # Convergence tolerance
    disp=False           # Suppress output during the run
)

# Display the result
result_custom_de
