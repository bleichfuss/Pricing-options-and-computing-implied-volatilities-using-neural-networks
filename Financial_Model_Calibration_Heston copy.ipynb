# %% [markdown]
# # Financial Model Calibration using ANNs (CaNN, Calibration Neural Network)
#
# ##### from "A neural network-based framework for financial model calibration" ([1])
#
# ### Phases:
#
# ### 1. Forward pass (training, prediction)
# ### 2. Backward pass (calibration)

# %% [markdown]
# # 1) Forward pass

# %% [markdown]
# ## a) Preperation

# %%
# Basic imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# Updating scipy to use module QMC for Latin hypercube sampling
#!pip install scipy==1.7
from scipy.stats import qmc

# Pytorch imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR, LinearLR, OneCycleLR, LambdaLR

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %%
def bs_price_call(S, K, T, t, r, sigma):
  """
  Black-Scholes call option value price related to PDE (2). Returns option's price.
  S: spot price
  K: strike price
  T: time to maturity
  t: spot time
  r: interest rate
  sigma: volatility of underlying asset
  """

  # Boundary condition of Black-Sholes PDE (2)
  if T == t:
    return np.maximum(0, S - K)  
  # Solution of the PDE (2) on the open interval [t, T)
  else : 
    d1 = ( np.log(S / K) + (r + 0.5 * sigma ** 2) * (T-t) ) / (sigma * np.sqrt(T-t))
    d2 = d1 - sigma*np.sqrt(T-t)
    value = S * norm.cdf(d1) - K * np.exp(-r * (T-t)) * norm.cdf(d2) 
  
  return value

def bs_moneyness_call(moneyness, tau, r, sigma):
  """
  Same function as bs_price_call but in terms of moneyness. Returns V/K and 
  has S/K instead of two seperate paremeters S and K.
  moneyness: S/K
  Tau: time to maturity minus spot time
  r: interest rate
  sigma: volatility of underlying asset
  """

  d1 = ( np.log(moneyness) + (r + 0.5 * sigma ** 2) * (tau) ) / (sigma * np.sqrt(tau))
  d2 = d1 - sigma*np.sqrt(tau)
  value_moneyness = moneyness * norm.cdf(d1) - np.exp(-r * (tau)) * norm.cdf(d2) 
  
  return value_moneyness

# %% [markdown]
# ##### Defining class Heston-IV-ANN

# %%
class Heston_ANN(nn.Module):
  def __init__(self):
    """
    Initilize Heston-IV-ANN netwwork with four hidden layers. 
    Same architecture as the one used in Table (2) [1].
    Weight are initialized using Glorot_uniform also known as Xavier_uniform.
    """
    super(Heston_ANN, self).__init__()
    # 4 layers
    self.fc1 = nn.Linear(8, 200)
    self.fc2 = nn.Linear(200, 200)
    self.fc3 = nn.Linear(200, 200)
    self.fc4 = nn.Linear(200, 200)
    self.fc5 = nn.Linear(200, 1)
    # initilizing the layer's weights
    torch.nn.init.xavier_uniform_(self.fc1.weight)
    torch.nn.init.xavier_uniform_(self.fc2.weight)
    torch.nn.init.xavier_uniform_(self.fc3.weight)
    torch.nn.init.xavier_uniform_(self.fc4.weight)
    torch.nn.init.xavier_uniform_(self.fc5.weight)


  def forward(self, x):
    """
    Foward pass of the network. 
    Relu activations are used and a linear activation is used in the final layer.
    x: input torch tensor (CUDA or CPU)
    """
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = F.relu(self.fc3(x))
    x = F.relu(self.fc4(x))
    x = self.fc5(x)
    return x.flatten()

  def train_model(self, args, device, train_loader, optimizer, epoch):
    """
    Training over train_loader batches for one epoch.
    Returns average training loss.
    args: training parameters.
    device: CUDA or CPU.
    train_loader: train data loader.
    optimizer: gradient descent optmizer.
    epoch: current epoch.
    """
    # train mode
    self.train()
    train_loss = 0
    # loop over data loader
    for batch_idx, data in enumerate(train_loader):
      # extracting the inputs and target
      data, target = data[:,:-1].to(device), data[:,-1].to(device)
      # zeroing the gradients
      optimizer.zero_grad()
      # foward pass
      output = self(data)
      # computing the loss
      loss = F.mse_loss(output, target)
      train_loss += loss.item() * data.shape[0]
      # back propagation
      loss.backward()
      # updating the optimizer step
      optimizer.step()
      # printing batch information
      if batch_idx % args["log_interval"] == 0:
        print('Train Epoch: {} [{}/{} ({:.0f}%)]\tlog Loss: {:.6f}'.format(
            epoch, int(batch_idx / len(train_loader)*len(train_loader.dataset)), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), np.log(loss.item())))
        if args["dry_run"]:
          break
    train_loss /= len(train_loader.dataset)
    print('\nTrain set: Average log loss: {:.4f}\n'.format(np.log(train_loss))) 
    return train_loss


  def test_model(self, device, test_loader):
    """
    Testing over test_loader batches for one epoch. 
    Returns average test loss.
    device: CUDA or CPU.
    test_loader: test data loader.
    """
    # evaluation mode
    self.eval()
    test_loss = 0
    # freezing the gradients
    with torch.no_grad():
      # looping over the test laoder
      for data in test_loader:
        # extracting the inputs and target
        data, target = data[:,:-1].to(device), data[:,-1].to(device)
        # foward pass
        output = self(data)
        #computing the loss
        test_loss += F.mse_loss(output, target, reduction = 'sum').item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}\n'.format(np.log(test_loss))) 
    return test_loss

# %% [markdown]
# ## b) Numerical method for Data generation

# %% [markdown]
# #### COS Method

# %% [markdown]
# #### Vanilla call coefficients

# %% [markdown]
# $\begin{aligned} \chi_{k}(c, d):=& \frac{1}{1+\left(\frac{k \pi}{b-a}\right)^{2}}\left[\cos \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\cos \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right.\\ &\left.+\frac{k \pi}{b-a} \sin \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\frac{k \pi}{b-a} \sin \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right] \end{aligned}$

# %% [markdown]
# $\psi_{k}(c, d):= \begin{cases}{\left[\sin \left(k \pi \frac{d-a}{b-a}\right)-\sin \left(k \pi \frac{c-a}{b-a}\right)\right] \frac{b-a}{k \pi},} & k \neq 0, \\ (d-c), & k=0 .\end{cases}$

# %% [markdown]
# $V_{k}^{\text {call }}=\frac{2}{b-a} K\left(\chi_{k}(0, b)-\psi_{k}(0, b)\right)$

# %%
def call_cosine_coef(a, b, c, d, K, N):
  """
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  K: Strike.
  N: summing lenght.
  Returns V_k coefficient for call option.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*K*(chi_k-psi_k)

# %%
def call_cosine_coef_moy(a, b, c, d, N):
  """
  Moyeness version.
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  N: summing lenght.
  Returns V_k coefficient for call option devided by K.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*(chi_k-psi_k)

# %% [markdown]
# #### Charateristic function for Heston model

# %% [markdown]
# $\begin{aligned} \varphi_{h e s}\left(\omega ; u_{0}\right)=& \exp \left(i \omega \mu \Delta t+\frac{u_{0}}{\eta^{2}}\left(\frac{1-e^{-D \Delta t}}{1-G e^{-D \Delta t}}\right)(\lambda-i \rho \eta \omega-D)\right) \\ & \cdot \exp \left(\frac{\lambda \bar{u}}{\eta^{2}}\left(\Delta t(\lambda-i \rho \eta \omega-D)-2 \log \left(\frac{1-G e^{-D \Delta t}}{1-G}\right)\right)\right) \end{aligned}$

# %% [markdown]
# $D=\sqrt{(\lambda-i \rho \eta \omega)^{2}+\left(\omega^{2}+i \omega\right) \eta^{2}} \quad$ and $\quad G=\frac{\lambda-i \rho \eta \omega-D}{\lambda-i \rho \eta \omega+D} $

# %%
def phi_Heston(a ,b ,N ,r, tau, kappa, gamma, vbar, v0, rho):
  """
  Characteristic function of the log-asset price following the Heston model.
  Section 3.3, equation (33).
  a, b: truncation range parameters.
  N: summing lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns Charateristic function vector.
  """
  #if kappa < 1e-4:
  #  print("kapp < 1e-4")
  #  kappa = 1e-5
  k = np.arange(N).reshape(1,-1)
  u = np.pi*k/(b-a)
  i = complex(0.0,1.0)
  D = np.sqrt((kappa-gamma*rho*i*u)**2+(u**2+i*u)*gamma**2)
  G = (kappa-gamma*rho*i*u-D)/(kappa-gamma*rho*i*u+D)
  C = v0* (1-np.exp(-D*tau)) / (gamma**2*(1-G*np.exp(-D*tau)))*(kappa-gamma*rho*i*u-D)
  A = r*i*u*tau + kappa*vbar/(gamma**2)*(tau*(kappa-gamma*rho*i*u-D) -2*np.log( (1-G*np.exp(-D*tau))/(1-G) )   ) 
  phi = np.exp( A + C )
  return phi

# %% [markdown]
# #### Heston cumulants

# %% [markdown]
# $c_{1}=\mu T+\left(1-e^{-\lambda T}\right) \frac{\bar{u}-u_{0}}{2 \lambda}-\frac{1}{2} \bar{u} T$

# %% [markdown]
# $\begin{aligned} c_{2}=& \frac{1}{8 \lambda^{3}}\left(\eta T \lambda e^{-\lambda T}\left(u_{0}-\bar{u}\right)(8 \lambda \rho-4 \eta)\right.\\ &+\lambda \rho \eta\left(1-e^{-\lambda T}\right)\left(16 \bar{u}-8 u_{0}\right) \\ &+2 \bar{u} \lambda T\left(-4 \lambda \rho \eta+\eta^{2}+4 \lambda^{2}\right) \\ &+\eta^{2}\left(\left(\bar{u}-2 u_{0}\right) e^{-2 \lambda T}+\bar{u}\left(6 e^{-\lambda T}-7\right)+2 u_{0}\right) \\ &\left.+8 \lambda^{2}\left(u_{0}-\bar{u}\right)\left(1-e^{-\lambda T}\right)\right) \end{aligned}$

# %%
def Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho ):
  """
  Computes Heston cumulants as defined in the appendix A for the Heston model.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns cumulants c1 and c2.
  """

  #if kappa == 0:
  #  c1 = r * tau + tau * (vbar - v0) / 2 - 0.5 * vbar * tau
  #else: 
  #   c1 = r * tau + (1 - np.exp(- kappa * tau)) * (vbar - v0) / (2 * kappa) - 0.5 * vbar * tau
  
  c1 = r * tau + (1 - np.exp(- kappa * tau)) * (vbar - v0) / (2 * kappa) - 0.5 * vbar * tau


  #safe_kappa = np.max(kappa, 1e-5)
  safe_kappa = kappa
  c2 = 0.125 / safe_kappa ** 3 * (gamma * tau * np.exp(- safe_kappa * tau) * (v0 - vbar) * (8 * safe_kappa * rho - 4 * gamma) + \
     safe_kappa * rho * gamma * (1 - np.exp(- safe_kappa * tau)) * (16 * vbar - 8 * v0) + \
     2 * vbar * safe_kappa * tau * (- 4 * safe_kappa * rho * gamma + gamma ** 2 + 4 * safe_kappa ** 2) + \
     gamma ** 2 * ((vbar - 2 * v0) * np.exp(-2 * safe_kappa * tau) + vbar * (6 * np.exp(- safe_kappa * tau) - 7) + 2 * v0) + \
     8 * safe_kappa ** 2 * (v0 - vbar) * (1 - np.exp(-safe_kappa * tau)))
  return c1, c2

# %% [markdown]
# #### Truncation range

# %% [markdown]
# $[a, b]:=\left[c_{1}-L \sqrt{c_{2}+\sqrt{c_{4}}}, \quad c_{1}+L \sqrt{c_{2}+\sqrt{c_{4}}}\right]$

# %%
def Truncation_range(c1, c2, c4, L):
  """
  Computes the truncation range given the cumulants c1, c2, c4 and the truncation lenght L.
  c1, c2, c4: Model cumulants.
  L: truncation lenght.
  Returns tuncation interval sup b and inf a.
  """
  a = c1 - L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) )
  b = c1 + L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) ) 
  return a, b

# %% [markdown]
# #### Exponential coefficient

# %% [markdown]
# $e^{i k \pi \frac{\mathbf{x}-a}{b-a}}$

# %%
def exponential_coef(a, b, N, S0, K):
  """
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  S0: asset initial price.
  K: strike.
  Returns the exponential coefficient vector.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(S0/K)-a)/(b-a))

# %%
def exponential_coef_moy(a, b, N, moyeness):
  """
  Moyeness version.
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  moyeness: S/K.
  Returns the exponential coefficient vector devided by K.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(moyeness)-a)/(b-a))

# %% [markdown]
# #### Vanilla call price

# %% [markdown]
# $v\left(\mathbf{x}, t_{0}, u_{0}\right) \approx \mathbf{K} e^{-r \Delta t} \cdot \operatorname{Re}\left\{\sum_{k=0}^{N-1} \varphi_{h e s}\left(\frac{k \pi}{b-a} ; u_{0}\right) U_{k} \cdot e^{i k \pi \frac{\mathbf{x}-a}{b-a}}\right\}$

# %%
def call_option_Heston(N, L, r, tau, kappa, gamma, vbar, v0, rho, K, S0 ):
  """
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  S0: asset initial price.
  K: strike.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef(a, b, c, d, K, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef(a, b, N, S0, K)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, K = K, S0 = S0)
# Out:
# True
# array([[29.79261082]])

# %%
def call_option_Heston_moy(N, L, r, tau, kappa, gamma, vbar, v0, rho, moyeness ):
  """
  Moyeness version.
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  moyeness: S/K.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef_moy(a, b, c, d, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef_moy(a, b, N, moyeness)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston_moy(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = 1)
# Out:
# True
# array([[0.29792611]])

# %% [markdown]
# # Latin Hypercube Sampling

# %% [markdown]
# ### Generating Data

# %% [markdown]
# #### Sampling range for the Heston parameters (Table (3) in [1])

# %%
# here Table (3) of [1] is used, kappa is numerically sensitive to small values
eps = 1e-2 # is used to generate open intervals
def Heston_LHS_data_generator(n = 10**6, l_bounds = [.6+eps, .05+eps, .0+eps, -0.9+eps, 0.4+eps, .01+eps, .01+eps, .05+eps], u_bounds = [1.4-eps, 3.0-eps, .05-eps, 0.0-eps, 3.0-eps, .5-eps, .8-eps, .5-eps]):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,9) containig the inputs samples and the value of the call.
  The inputs are: Moyeness (S/K), time to maturity (tau), Risk free rate (r), Correlation (rho), reversion speed (kappa), Long average variance (vbar), Vol of vol (gamma), Initial variance (v0).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.
  """
  sampler = qmc.LatinHypercube(d = 8) #, seed = 0
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  indecies = np.argwhere(2*sample[:,4]*sample[:,5] <= sample[:,6]**2)
  sample = np.delete(sample, indecies, 0)
  hs_prices = call_option_Heston_moy(N = 160, L= 12, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa = sample[:,4].reshape((-1,1)),\
                                     gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
                                     rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  #hs_prices = call_option_Heston_moy(N = 1500, L= 50, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
  #                                    gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
  #                                    rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))

  hs_dataset = np.concatenate((sample, hs_prices),axis=1)

  print("------ INPUT ------")
  print("S/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,0]), max(hs_dataset[:,0])))
  print("Tau.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,1]), max(hs_dataset[:,1])))
  print("r............ [{:.2f} {:.2f}]".format(min(hs_dataset[:,2]), max(hs_dataset[:,2])))
  print("Corr ........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,3]), max(hs_dataset[:,3])))
  print("Kappa........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,4]), max(hs_dataset[:,4])))
  print("V_bar........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,5]), max(hs_dataset[:,5])))
  print("Gamma........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,6]), max(hs_dataset[:,6])))
  print("V_0 ......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,7]), max(hs_dataset[:,7])))
  print("------ OUTPUT ------")
  print("V/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,-1]), max(hs_dataset[:,-1])))
  # ind_max = np.argmax(hs_dataset[:,-1])
  # print(hs_dataset[ind_max,:])

  return torch.FloatTensor(hs_dataset)

hs_dataset = Heston_LHS_data_generator(10**4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 42
#      37   # ind_max = np.argmax(hs_dataset[:,-1])
#      38   # print(hs_dataset[ind_max,:])
#      40   return torch.FloatTensor(hs_dataset)
# ---> 42 hs_dataset = Heston_LHS_data_generator(10**4)
#
# Cell In[43], line 17, in Heston_LHS_data_generator(n, l_bounds, u_bounds)
#      15 indecies = np.argwhere(2*sample[:,4]*sample[:,5] <= sample[:,6]**2)
#      16 sample = np.delete(sample, indecies, 0)
# ---> 17 hs_prices = call_option_Heston_moy(N = 160, L= 12, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa = sample[:,4].reshape((-1,1)),\
#      18                                    gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
#      19                                    rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
#      20 #hs_prices = call_option_Heston_moy(N = 1500, L= 50, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
#      21 #                                    gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
#      22 #                                    rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
#      24 hs_dataset = np.concatenate((sample, hs_prices),axis=1)
#
# Cell In[14], line 23, in call_option_Heston_moy(N, L, r, tau, kappa, gamma, vbar, v0, rho, moyeness)
#      21 d = b
#      22 V_k = call_cosine_coef_moy(a, b, c, d, N)
# ---> 23 phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
#      24 product_k = V_k * phi_k * exponential_coef_moy(a, b, N, moyeness)
#      25 product_k[:,0] = .5 * product_k[:,0]
#
# Cell In[42], line 16, in phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
#       1 def phi_Heston(a ,b ,N ,r, tau, kappa, gamma, vbar, v0, rho):
#       2   """
#       3   Characteristic function of the log-asset price following the Heston model.
#       4   Section 3.3, equation (33).
#    (...)
#      14   Returns Charateristic function vector.
#      15   """
# ---> 16   if kappa < 1e-4:
#      17     print("kapp < 1e-4")
#      18     kappa = 1e-5
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#eps = 1e-2 # is used to generate open intervals
# (S/K), (tau), (r), (rho), (kappa), (vbar), (gamma), (v0).
# CASE 1 in table 11
#l_bounds = [.75+eps, .4+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps]
#u_bounds = [1.25-eps, 1.-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]
#hs_dataset = Heston_LHS_data_generator(10**5)

# %% [markdown]
# ## c) Training Heston-ANN

# %%
# Training parameters
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 8*10**3,
         "lr": 1e-4,
         "gamma": .5,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}


use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# torch.manual_seed(args["seed"])


# Loading Train / Test Data
hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0] - train_size])

train_loader = torch.utils.data.DataLoader(train_dataset, args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])


# Model training
print(device)
model = Heston_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=args["lr"]) # Adam is found to be the best optimizer in the article
scheduler = StepLR(optimizer, step_size=500, gamma=args["gamma"]) # Deacreses the Learning rate by .5 every 500 epoch

train_losses = []
test_losses = []
for epoch in range(1, args["epochs"] + 1):
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
if args["save_model"] :
  torch.save(model.state_dict(), "Heston_ANN_DE.pt")
# Out:
# ------ INPUT ------
# S/K.......... [0.61 1.39]
# Tau.......... [0.06 2.99]
# r............ [0.01 0.04]
# Corr ........ [-0.89 -0.01]
# Kappa........ [0.41 2.99]
# V_bar........ [0.02 0.49]
# Gamma........ [0.02 0.79]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00 0.76]
# cuda
# Train Epoch: 1 [0/77458 (0%)]	log Loss: -1.707314
#
# Train set: Average log loss: -3.6965
#
#
# Test set: Average loss: -5.2157
#
# Current Learning rate 0.0001
# Train Epoch: 2 [0/77458 (0%)]	log Loss: -5.239835
#
# Train set: Average log loss: -6.3663
#
#
# Test set: Average loss: -7.3919
#
# Current Learning rate 0.0001
# Train Epoch: 3 [0/77458 (0%)]	log Loss: -7.340573
#
# Train set: Average log loss: -7.7726
#
#
# Test set: Average loss: -8.1128
#
# Current Learning rate 0.0001
# Train Epoch: 4 [0/77458 (0%)]	log Loss: -8.087534
#
# Train set: Average log loss: -8.3874
#
#
# Test set: Average loss: -8.6423
#
# Current Learning rate 0.0001
# Train Epoch: 5 [0/77458 (0%)]	log Loss: -8.617549
#
# Train set: Average log loss: -8.8126
#
#
# Test set: Average loss: -8.9440
#
# Current Learning rate 0.0001
# Train Epoch: 6 [0/77458 (0%)]	log Loss: -8.915781
#
# Train set: Average log loss: -9.0381
#
#
# Test set: Average loss: -9.1258
#
# Current Learning rate 0.0001
# Train Epoch: 7 [0/77458 (0%)]	log Loss: -9.106295
#
# Train set: Average log loss: -9.1963
#
#
# Test set: Average loss: -9.2679
#
# Current Learning rate 0.0001
# Train Epoch: 8 [0/77458 (0%)]	log Loss: -9.241549
#
# Train set: Average log loss: -9.3175
#
#
# Test set: Average loss: -9.3711
#
# Current Learning rate 0.0001
# Train Epoch: 9 [0/77458 (0%)]	log Loss: -9.346483
#
# Train set: Average log loss: -9.4161
#
#
# Test set: Average loss: -9.4611
#
# Current Learning rate 0.0001
# Train Epoch: 10 [0/77458 (0%)]	log Loss: -9.442433
#
# Train set: Average log loss: -9.5025
#
#
# Test set: Average loss: -9.5347
#
# Current Learning rate 0.0001
# Train Epoch: 11 [0/77458 (0%)]	log Loss: -9.526120
#
# Train set: Average log loss: -9.5916
#
#
# Test set: Average loss: -9.6154
#
# Current Learning rate 0.0001
# Train Epoch: 12 [0/77458 (0%)]	log Loss: -9.606272
#
# Train set: Average log loss: -9.6788
#
#
# Test set: Average loss: -9.6781
#
# Current Learning rate 0.0001
# Train Epoch: 13 [0/77458 (0%)]	log Loss: -9.667173
#
# Train set: Average log loss: -9.7599
#
#
# Test set: Average loss: -9.7089
#
# Current Learning rate 0.0001
# Train Epoch: 14 [0/77458 (0%)]	log Loss: -9.695066
#
# Train set: Average log loss: -9.8340
#
#
# Test set: Average loss: -9.7262
#
# Current Learning rate 0.0001
# Train Epoch: 15 [0/77458 (0%)]	log Loss: -9.714969
#
# Train set: Average log loss: -9.9134
#
#
# Test set: Average loss: -9.8108
#
# Current Learning rate 0.0001
# Train Epoch: 16 [0/77458 (0%)]	log Loss: -9.798697
#
# Train set: Average log loss: -10.0030
#
#
# Test set: Average loss: -9.9704
#
# Current Learning rate 0.0001
# Train Epoch: 17 [0/77458 (0%)]	log Loss: -9.946907
#
# Train set: Average log loss: -10.0872
#
#
# Test set: Average loss: -10.0753
#
# Current Learning rate 0.0001
# Train Epoch: 18 [0/77458 (0%)]	log Loss: -10.049241
#
# Train set: Average log loss: -10.1743
#
#
# Test set: Average loss: -10.1396
#
# Current Learning rate 0.0001
# Train Epoch: 19 [0/77458 (0%)]	log Loss: -10.114618
#
# Train set: Average log loss: -10.2535
#
#
# Test set: Average loss: -10.2144
#
# Current Learning rate 0.0001
# Train Epoch: 20 [0/77458 (0%)]	log Loss: -10.191637
#
# Train set: Average log loss: -10.3288
#
#
# Test set: Average loss: -10.2585
#
# Current Learning rate 0.0001
# Train Epoch: 21 [0/77458 (0%)]	log Loss: -10.237088
#
# Train set: Average log loss: -10.3931
#
#
# Test set: Average loss: -10.3532
#
# Current Learning rate 0.0001
# Train Epoch: 22 [0/77458 (0%)]	log Loss: -10.326527
#
# Train set: Average log loss: -10.4542
#
#
# Test set: Average loss: -10.4344
#
# Current Learning rate 0.0001
# Train Epoch: 23 [0/77458 (0%)]	log Loss: -10.403591
#
# Train set: Average log loss: -10.5166
#
#
# Test set: Average loss: -10.4854
#
# Current Learning rate 0.0001
# Train Epoch: 24 [0/77458 (0%)]	log Loss: -10.454137
#
# Train set: Average log loss: -10.5677
#
#
# Test set: Average loss: -10.5710
#
# Current Learning rate 0.0001
# Train Epoch: 25 [0/77458 (0%)]	log Loss: -10.529139
#
# Train set: Average log loss: -10.6110
#
#
# Test set: Average loss: -10.6143
#
# Current Learning rate 0.0001
# Train Epoch: 26 [0/77458 (0%)]	log Loss: -10.556260
#
# Train set: Average log loss: -10.6523
#
#
# Test set: Average loss: -10.6272
#
# Current Learning rate 0.0001
# Train Epoch: 27 [0/77458 (0%)]	log Loss: -10.560314
#
# Train set: Average log loss: -10.6876
#
#
# Test set: Average loss: -10.6917
#
# Current Learning rate 0.0001
# Train Epoch: 28 [0/77458 (0%)]	log Loss: -10.621475
#
# Train set: Average log loss: -10.7311
#
#
# Test set: Average loss: -10.7600
#
# Current Learning rate 0.0001
# Train Epoch: 29 [0/77458 (0%)]	log Loss: -10.696056
#
# Train set: Average log loss: -10.7730
#
#
# Test set: Average loss: -10.7449
#
# Current Learning rate 0.0001
# Train Epoch: 30 [0/77458 (0%)]	log Loss: -10.695417
#
# Train set: Average log loss: -10.7987
#
#
# Test set: Average loss: -10.7305
#
# Current Learning rate 0.0001
# Train Epoch: 31 [0/77458 (0%)]	log Loss: -10.688868
#
# Train set: Average log loss: -10.8292
#
#
# Test set: Average loss: -10.7574
#
# Current Learning rate 0.0001
# Train Epoch: 32 [0/77458 (0%)]	log Loss: -10.717935
#
# Train set: Average log loss: -10.8654
#
#
# Test set: Average loss: -10.7823
#
# Current Learning rate 0.0001
# Train Epoch: 33 [0/77458 (0%)]	log Loss: -10.744162
#
# Train set: Average log loss: -10.8968
#
#
# Test set: Average loss: -10.8317
#
# Current Learning rate 0.0001
# Train Epoch: 34 [0/77458 (0%)]	log Loss: -10.790186
#
# Train set: Average log loss: -10.9321
#
#
# Test set: Average loss: -10.9156
#
# Current Learning rate 0.0001
# Train Epoch: 35 [0/77458 (0%)]	log Loss: -10.867280
#
# Train set: Average log loss: -10.9542
#
#
# Test set: Average loss: -10.9578
#
# Current Learning rate 0.0001
# Train Epoch: 36 [0/77458 (0%)]	log Loss: -10.911535
#
# Train set: Average log loss: -10.9670
#
#
# Test set: Average loss: -11.0153
#
# Current Learning rate 0.0001
# Train Epoch: 37 [0/77458 (0%)]	log Loss: -10.961956
#
# Train set: Average log loss: -10.9770
#
#
# Test set: Average loss: -11.0221
#
# Current Learning rate 0.0001
# Train Epoch: 38 [0/77458 (0%)]	log Loss: -10.964820
#
# Train set: Average log loss: -10.9962
#
#
# Test set: Average loss: -11.0331
#
# Current Learning rate 0.0001
# Train Epoch: 39 [0/77458 (0%)]	log Loss: -10.974025
#
# Train set: Average log loss: -11.0145
#
#
# Test set: Average loss: -11.0561
#
# Current Learning rate 0.0001
# Train Epoch: 40 [0/77458 (0%)]	log Loss: -10.998457
#
# Train set: Average log loss: -11.0332
#
#
# Test set: Average loss: -11.0950
#
# Current Learning rate 0.0001
# Train Epoch: 41 [0/77458 (0%)]	log Loss: -11.040185
#
# Train set: Average log loss: -11.0472
#
#
# Test set: Average loss: -11.1352
#
# Current Learning rate 0.0001
# Train Epoch: 42 [0/77458 (0%)]	log Loss: -11.081765
#
# Train set: Average log loss: -11.0607
#
#
# Test set: Average loss: -11.1655
#
# Current Learning rate 0.0001
# Train Epoch: 43 [0/77458 (0%)]	log Loss: -11.115326
#
# Train set: Average log loss: -11.0808
#
#
# Test set: Average loss: -11.1728
#
# Current Learning rate 0.0001
# Train Epoch: 44 [0/77458 (0%)]	log Loss: -11.128724
#
# Train set: Average log loss: -11.0969
#
#
# Test set: Average loss: -11.1530
#
# Current Learning rate 0.0001
# Train Epoch: 45 [0/77458 (0%)]	log Loss: -11.116546
#
# Train set: Average log loss: -11.1116
#
#
# Test set: Average loss: -11.1268
#
# Current Learning rate 0.0001
# Train Epoch: 46 [0/77458 (0%)]	log Loss: -11.096676
#
# Train set: Average log loss: -11.1246
#
#
# Test set: Average loss: -11.1167
#
# Current Learning rate 0.0001
# Train Epoch: 47 [0/77458 (0%)]	log Loss: -11.090179
#
# Train set: Average log loss: -11.1399
#
#
# Test set: Average loss: -11.1268
#
# Current Learning rate 0.0001
# Train Epoch: 48 [0/77458 (0%)]	log Loss: -11.102067
#
# Train set: Average log loss: -11.1506
#
#
# Test set: Average loss: -11.1596
#
# Current Learning rate 0.0001
# Train Epoch: 49 [0/77458 (0%)]	log Loss: -11.134674
#
# Train set: Average log loss: -11.1627
#
#
# Test set: Average loss: -11.2088
#
# Current Learning rate 0.0001
# Train Epoch: 50 [0/77458 (0%)]	log Loss: -11.184188
#
# Train set: Average log loss: -11.1787
#
#
# Test set: Average loss: -11.2782
#
# Current Learning rate 0.0001
# Train Epoch: 51 [0/77458 (0%)]	log Loss: -11.250799
#
# Train set: Average log loss: -11.2001
#
#
# Test set: Average loss: -11.3365
#
# Current Learning rate 0.0001
# Train Epoch: 52 [0/77458 (0%)]	log Loss: -11.305429
#
# Train set: Average log loss: -11.2149
#
#
# Test set: Average loss: -11.3327
#
# Current Learning rate 0.0001
# Train Epoch: 53 [0/77458 (0%)]	log Loss: -11.298803
#
# Train set: Average log loss: -11.2056
#
#
# Test set: Average loss: -11.3263
#
# Current Learning rate 0.0001
# Train Epoch: 54 [0/77458 (0%)]	log Loss: -11.292500
#
# Train set: Average log loss: -11.2083
#
#
# Test set: Average loss: -11.3312
#
# Current Learning rate 0.0001
# Train Epoch: 55 [0/77458 (0%)]	log Loss: -11.299364
#
# Train set: Average log loss: -11.2239
#
#
# Test set: Average loss: -11.3084
#
# Current Learning rate 0.0001
# Train Epoch: 56 [0/77458 (0%)]	log Loss: -11.277348
#
# Train set: Average log loss: -11.2203
#
#
# Test set: Average loss: -11.3273
#
# Current Learning rate 0.0001
# Train Epoch: 57 [0/77458 (0%)]	log Loss: -11.298226
#
# Train set: Average log loss: -11.2456
#
#
# Test set: Average loss: -11.2876
#
# Current Learning rate 0.0001
# Train Epoch: 58 [0/77458 (0%)]	log Loss: -11.260211
#
# Train set: Average log loss: -11.2299
#
#
# Test set: Average loss: -11.3341
#
# Current Learning rate 0.0001
# Train Epoch: 59 [0/77458 (0%)]	log Loss: -11.308561
#
# Train set: Average log loss: -11.2736
#
#
# Test set: Average loss: -11.2555
#
# Current Learning rate 0.0001
# Train Epoch: 60 [0/77458 (0%)]	log Loss: -11.230605
#
# Train set: Average log loss: -11.2423
#
#
# Test set: Average loss: -11.3183
#
# Current Learning rate 0.0001
# Train Epoch: 61 [0/77458 (0%)]	log Loss: -11.292283
#
# Train set: Average log loss: -11.2815
#
#
# Test set: Average loss: -11.2836
#
# Current Learning rate 0.0001
# Train Epoch: 62 [0/77458 (0%)]	log Loss: -11.259625
#
# Train set: Average log loss: -11.2726
#
#
# Test set: Average loss: -11.3047
#
# Current Learning rate 0.0001
# Train Epoch: 63 [0/77458 (0%)]	log Loss: -11.283962
#
# Train set: Average log loss: -11.2886
#
#
# Test set: Average loss: -11.3009
#
# Current Learning rate 0.0001
# Train Epoch: 64 [0/77458 (0%)]	log Loss: -11.282326
#
# Train set: Average log loss: -11.2998
#
#
# Test set: Average loss: -11.2910
#
# Current Learning rate 0.0001
# Train Epoch: 65 [0/77458 (0%)]	log Loss: -11.273739
#
# Train set: Average log loss: -11.3133
#
#
# Test set: Average loss: -11.2913
#
# Current Learning rate 0.0001
# Train Epoch: 66 [0/77458 (0%)]	log Loss: -11.277994
#
# Train set: Average log loss: -11.3300
#
#
# Test set: Average loss: -11.3425
#
# Current Learning rate 0.0001
# Train Epoch: 67 [0/77458 (0%)]	log Loss: -11.328922
#
# Train set: Average log loss: -11.3637
#
#
# Test set: Average loss: -11.5484
#
# Current Learning rate 0.0001
# Train Epoch: 68 [0/77458 (0%)]	log Loss: -11.530299
#
# Train set: Average log loss: -11.2900
#
#
# Test set: Average loss: -11.3801
#
# Current Learning rate 0.0001
# Train Epoch: 69 [0/77458 (0%)]	log Loss: -11.366800
#
# Train set: Average log loss: -11.4298
#
#
# Test set: Average loss: -11.5996
#
# Current Learning rate 0.0001
# Train Epoch: 70 [0/77458 (0%)]	log Loss: -11.580447
#
# Train set: Average log loss: -10.9978
#
#
# Test set: Average loss: -11.6149
#
# Current Learning rate 0.0001
# Train Epoch: 71 [0/77458 (0%)]	log Loss: -11.616455
#
# Train set: Average log loss: -11.5241
#
#
# Test set: Average loss: -11.3052
#
# Current Learning rate 0.0001
# Train Epoch: 72 [0/77458 (0%)]	log Loss: -11.304881
#
# Train set: Average log loss: -11.4834
#
#
# Test set: Average loss: -11.4231
#
# Current Learning rate 0.0001
# Train Epoch: 73 [0/77458 (0%)]	log Loss: -11.422453
#
# Train set: Average log loss: -11.4697
#
#
# Test set: Average loss: -11.5323
#
# Current Learning rate 0.0001
# Train Epoch: 74 [0/77458 (0%)]	log Loss: -11.521957
#
# Train set: Average log loss: -10.9437
#
#
# Test set: Average loss: -11.6064
#
# Current Learning rate 0.0001
# Train Epoch: 75 [0/77458 (0%)]	log Loss: -11.613516
#
# Train set: Average log loss: -11.5237
#
#
# Test set: Average loss: -11.4464
#
# Current Learning rate 0.0001
# Train Epoch: 76 [0/77458 (0%)]	log Loss: -11.457432
#
# Train set: Average log loss: -11.5835
#
#
# Test set: Average loss: -11.2299
#
# Current Learning rate 0.0001
# Train Epoch: 77 [0/77458 (0%)]	log Loss: -11.239825
#
# Train set: Average log loss: -11.5462
#
#
# Test set: Average loss: -11.6136
#
# Current Learning rate 0.0001
# Train Epoch: 78 [0/77458 (0%)]	log Loss: -11.610258
#
# Train set: Average log loss: -11.1020
#
#
# Test set: Average loss: -11.6131
#
# Current Learning rate 0.0001
# Train Epoch: 79 [0/77458 (0%)]	log Loss: -11.636007
#
# Train set: Average log loss: -11.5816
#
#
# Test set: Average loss: -11.2042
#
# Current Learning rate 0.0001
# Train Epoch: 80 [0/77458 (0%)]	log Loss: -11.222756
#
# Train set: Average log loss: -11.5894
#
#
# Test set: Average loss: -11.6706
#
# Current Learning rate 0.0001
# Train Epoch: 81 [0/77458 (0%)]	log Loss: -11.676162
#
# Train set: Average log loss: -11.1478
#
#
# Test set: Average loss: -11.5579
#
# Current Learning rate 0.0001
# Train Epoch: 82 [0/77458 (0%)]	log Loss: -11.590022
#
# Train set: Average log loss: -11.5898
#
#
# Test set: Average loss: -11.1608
#
# Current Learning rate 0.0001
# Train Epoch: 83 [0/77458 (0%)]	log Loss: -11.186945
#
# Train set: Average log loss: -11.6025
#
#
# Test set: Average loss: -11.5342
#
# Current Learning rate 0.0001
# Train Epoch: 84 [0/77458 (0%)]	log Loss: -11.545194
#
# Train set: Average log loss: -11.1822
#
#
# Test set: Average loss: -11.4263
#
# Current Learning rate 0.0001
# Train Epoch: 85 [0/77458 (0%)]	log Loss: -11.464719
#
# Train set: Average log loss: -11.6132
#
#
# Test set: Average loss: -11.1819
#
# Current Learning rate 0.0001
# Train Epoch: 86 [0/77458 (0%)]	log Loss: -11.215187
#
# Train set: Average log loss: -11.6000
#
#
# Test set: Average loss: -11.4721
#
# Current Learning rate 0.0001
# Train Epoch: 87 [0/77458 (0%)]	log Loss: -11.489498
#
# Train set: Average log loss: -11.2846
#
#
# Test set: Average loss: -11.0230
#
# Current Learning rate 0.0001
# Train Epoch: 88 [0/77458 (0%)]	log Loss: -11.058079
#
# Train set: Average log loss: -11.6678
#
#
# Test set: Average loss: -11.8013
#
# Current Learning rate 0.0001
# Train Epoch: 89 [0/77458 (0%)]	log Loss: -11.841645
#
# Train set: Average log loss: -11.3077
#
#
# Test set: Average loss: -10.9915
#
# Current Learning rate 0.0001
# Train Epoch: 90 [0/77458 (0%)]	log Loss: -11.029793
#
# Train set: Average log loss: -11.6747
#
#
# Test set: Average loss: -11.7940
#
# Current Learning rate 0.0001
# Train Epoch: 91 [0/77458 (0%)]	log Loss: -11.844980
#
# Train set: Average log loss: -11.4448
#
#
# Test set: Average loss: -11.3667
#
# Current Learning rate 0.0001
# Train Epoch: 92 [0/77458 (0%)]	log Loss: -11.414361
#
# Train set: Average log loss: -11.5566
#
#
# Test set: Average loss: -11.7805
#
# Current Learning rate 0.0001
# Train Epoch: 93 [0/77458 (0%)]	log Loss: -11.827066
#
# Train set: Average log loss: -11.5020
#
#
# Test set: Average loss: -11.7977
#
# Current Learning rate 0.0001
# Train Epoch: 94 [0/77458 (0%)]	log Loss: -11.856165
#
# Train set: Average log loss: -11.4928
#
#
# Test set: Average loss: -11.4745
#
# Current Learning rate 0.0001
# Train Epoch: 95 [0/77458 (0%)]	log Loss: -11.523948
#
# Train set: Average log loss: -11.5231
#
#
# Test set: Average loss: -11.4476
#
# Current Learning rate 0.0001
# Train Epoch: 96 [0/77458 (0%)]	log Loss: -11.497028
#
# Train set: Average log loss: -11.5405
#
#
# Test set: Average loss: -11.5786
#
# Current Learning rate 0.0001
# Train Epoch: 97 [0/77458 (0%)]	log Loss: -11.632287
#
# Train set: Average log loss: -11.5402
#
#
# Test set: Average loss: -11.5638
#
# Current Learning rate 0.0001
# Train Epoch: 98 [0/77458 (0%)]	log Loss: -11.618352
#
# Train set: Average log loss: -11.5580
#
#
# Test set: Average loss: -11.7754
#
# Current Learning rate 0.0001
# Train Epoch: 99 [0/77458 (0%)]	log Loss: -11.836599
#
# Train set: Average log loss: -11.5281
#
#
# Test set: Average loss: -10.9069
#
# Current Learning rate 0.0001
# Train Epoch: 100 [0/77458 (0%)]	log Loss: -10.946649
#
# Train set: Average log loss: -11.4222
#
#
# Test set: Average loss: -10.6817
#
# Current Learning rate 0.0001
# Train Epoch: 101 [0/77458 (0%)]	log Loss: -10.720111
#
# Train set: Average log loss: -11.3719
#
#
# Test set: Average loss: -11.1337
#
# Current Learning rate 0.0001
# Train Epoch: 102 [0/77458 (0%)]	log Loss: -11.189801
#
# Train set: Average log loss: -11.7011
#
#
# Test set: Average loss: -10.7932
#
# Current Learning rate 0.0001
# Train Epoch: 103 [0/77458 (0%)]	log Loss: -10.837576
#
# Train set: Average log loss: -11.7358
#
#
# Test set: Average loss: -11.3456
#
# Current Learning rate 0.0001
# Train Epoch: 104 [0/77458 (0%)]	log Loss: -11.407657
#
# Train set: Average log loss: -11.5762
#
#
# Test set: Average loss: -11.2270
#
# Current Learning rate 0.0001
# Train Epoch: 105 [0/77458 (0%)]	log Loss: -11.286986
#
# Train set: Average log loss: -11.6555
#
#
# Test set: Average loss: -11.9058
#
# Current Learning rate 0.0001
# Train Epoch: 106 [0/77458 (0%)]	log Loss: -11.984927
#
# Train set: Average log loss: -10.6989
#
#
# Test set: Average loss: -11.8453
#
# Current Learning rate 0.0001
# Train Epoch: 107 [0/77458 (0%)]	log Loss: -11.934690
#
# Train set: Average log loss: -11.7661
#
#
# Test set: Average loss: -11.7225
#
# Current Learning rate 0.0001
# Train Epoch: 108 [0/77458 (0%)]	log Loss: -11.798012
#
# Train set: Average log loss: -11.8362
#
#
# Test set: Average loss: -11.9707
#
# Current Learning rate 0.0001
# Train Epoch: 109 [0/77458 (0%)]	log Loss: -12.045124
#
# Train set: Average log loss: -11.9187
#
#
# Test set: Average loss: -11.5978
#
# Current Learning rate 0.0001
# Train Epoch: 110 [0/77458 (0%)]	log Loss: -11.669465
#
# Train set: Average log loss: -11.8996
#
#
# Test set: Average loss: -11.1379
#
# Current Learning rate 0.0001
# Train Epoch: 111 [0/77458 (0%)]	log Loss: -11.192472
#
# Train set: Average log loss: -11.8941
#
#
# Test set: Average loss: -12.0067
#
# Current Learning rate 0.0001
# Train Epoch: 112 [0/77458 (0%)]	log Loss: -12.075385
#
# Train set: Average log loss: -10.9002
#
#
# Test set: Average loss: -11.6221
#
# Current Learning rate 0.0001
# Train Epoch: 113 [0/77458 (0%)]	log Loss: -11.698380
#
# Train set: Average log loss: -11.9149
#
#
# Test set: Average loss: -12.0195
#
# Current Learning rate 0.0001
# Train Epoch: 114 [0/77458 (0%)]	log Loss: -12.098682
#
# Train set: Average log loss: -11.9462
#
#
# Test set: Average loss: -11.4755
#
# Current Learning rate 0.0001
# Train Epoch: 115 [0/77458 (0%)]	log Loss: -11.547664
#
# Train set: Average log loss: -11.9561
#
#
# Test set: Average loss: -11.2203
#
# Current Learning rate 0.0001
# Train Epoch: 116 [0/77458 (0%)]	log Loss: -11.281014
#
# Train set: Average log loss: -11.7524
#
#
# Test set: Average loss: -12.0382
#
# Current Learning rate 0.0001
# Train Epoch: 117 [0/77458 (0%)]	log Loss: -12.110759
#
# Train set: Average log loss: -11.2119
#
#
# Test set: Average loss: -11.5504
#
# Current Learning rate 0.0001
# Train Epoch: 118 [0/77458 (0%)]	log Loss: -11.638082
#
# Train set: Average log loss: -11.9828
#
#
# Test set: Average loss: -11.5072
#
# Current Learning rate 0.0001
# Train Epoch: 119 [0/77458 (0%)]	log Loss: -11.584456
#
# Train set: Average log loss: -11.9450
#
#
# Test set: Average loss: -11.7618
#
# Current Learning rate 0.0001
# Train Epoch: 120 [0/77458 (0%)]	log Loss: -11.792997
#
# Train set: Average log loss: -11.5756
#
#
# Test set: Average loss: -11.0830
#
# Current Learning rate 0.0001
# Train Epoch: 121 [0/77458 (0%)]	log Loss: -11.147637
#
# Train set: Average log loss: -11.8246
#
#
# Test set: Average loss: -11.8799
#
# Current Learning rate 0.0001
# Train Epoch: 122 [0/77458 (0%)]	log Loss: -11.970173
#
# Train set: Average log loss: -11.2636
#
#
# Test set: Average loss: -11.7178
#
# Current Learning rate 0.0001
# Train Epoch: 123 [0/77458 (0%)]	log Loss: -11.812057
#
# Train set: Average log loss: -12.0420
#
#
# Test set: Average loss: -11.3781
#
# Current Learning rate 0.0001
# Train Epoch: 124 [0/77458 (0%)]	log Loss: -11.457141
#
# Train set: Average log loss: -11.8236
#
#
# Test set: Average loss: -11.9850
#
# Current Learning rate 0.0001
# Train Epoch: 125 [0/77458 (0%)]	log Loss: -12.038370
#
# Train set: Average log loss: -11.3959
#
#
# Test set: Average loss: -11.8421
#
# Current Learning rate 0.0001
# Train Epoch: 126 [0/77458 (0%)]	log Loss: -11.941617
#
# Train set: Average log loss: -11.9607
#
#
# Test set: Average loss: -11.4799
#
# Current Learning rate 0.0001
# Train Epoch: 127 [0/77458 (0%)]	log Loss: -11.563946
#
# Train set: Average log loss: -11.7933
#
#
# Test set: Average loss: -11.8523
#
# Current Learning rate 0.0001
# Train Epoch: 128 [0/77458 (0%)]	log Loss: -11.887165
#
# Train set: Average log loss: -11.6735
#
#
# Test set: Average loss: -11.7839
#
# Current Learning rate 0.0001
# Train Epoch: 129 [0/77458 (0%)]	log Loss: -11.885734
#
# Train set: Average log loss: -11.8405
#
#
# Test set: Average loss: -11.2770
#
# Current Learning rate 0.0001
# Train Epoch: 130 [0/77458 (0%)]	log Loss: -11.275968
#
# Train set: Average log loss: -11.5942
#
#
# Test set: Average loss: -11.4445
#
# Current Learning rate 0.0001
# Train Epoch: 131 [0/77458 (0%)]	log Loss: -11.528824
#
# Train set: Average log loss: -11.7055
#
#
# Test set: Average loss: -11.2208
#
# Current Learning rate 0.0001
# Train Epoch: 132 [0/77458 (0%)]	log Loss: -11.298580
#
# Train set: Average log loss: -11.7438
#
#
# Test set: Average loss: -11.3124
#
# Current Learning rate 0.0001
# Train Epoch: 133 [0/77458 (0%)]	log Loss: -11.396781
#
# Train set: Average log loss: -11.7974
#
#
# Test set: Average loss: -12.0544
#
# Current Learning rate 0.0001
# Train Epoch: 134 [0/77458 (0%)]	log Loss: -12.165463
#
# Train set: Average log loss: -11.5230
#
#
# Test set: Average loss: -11.6910
#
# Current Learning rate 0.0001
# Train Epoch: 135 [0/77458 (0%)]	log Loss: -11.802339
#
# Train set: Average log loss: -12.0362
#
#
# Test set: Average loss: -12.0451
#
# Current Learning rate 0.0001
# Train Epoch: 136 [0/77458 (0%)]	log Loss: -12.098470
#
# Train set: Average log loss: -11.5792
#
#
# Test set: Average loss: -10.7807
#
# Current Learning rate 0.0001
# Train Epoch: 137 [0/77458 (0%)]	log Loss: -10.846549
#
# Train set: Average log loss: -11.7392
#
#
# Test set: Average loss: -10.7582
#
# Current Learning rate 0.0001
# Train Epoch: 138 [0/77458 (0%)]	log Loss: -10.830112
#
# Train set: Average log loss: -11.8831
#
#
# Test set: Average loss: -11.3287
#
# Current Learning rate 0.0001
# Train Epoch: 139 [0/77458 (0%)]	log Loss: -11.425340
#
# Train set: Average log loss: -11.6576
#
#
# Test set: Average loss: -10.9970
#
# Current Learning rate 0.0001
# Train Epoch: 140 [0/77458 (0%)]	log Loss: -11.085294
#
# Train set: Average log loss: -12.0006
#
#
# Test set: Average loss: -12.2019
#
# Current Learning rate 0.0001
# Train Epoch: 141 [0/77458 (0%)]	log Loss: -12.284753
#
# Train set: Average log loss: -11.7641
#
#
# Test set: Average loss: -12.1979
#
# Current Learning rate 0.0001
# Train Epoch: 142 [0/77458 (0%)]	log Loss: -12.306871
#
# Train set: Average log loss: -11.3517
#
#
# Test set: Average loss: -11.6316
#
# Current Learning rate 0.0001
# Train Epoch: 143 [0/77458 (0%)]	log Loss: -11.768153
#
# Train set: Average log loss: -12.1376
#
#
# Test set: Average loss: -12.1328
#
# Current Learning rate 0.0001
# Train Epoch: 144 [0/77458 (0%)]	log Loss: -12.264677
#
# Train set: Average log loss: -11.9958
#
#
# Test set: Average loss: -12.1705
#
# Current Learning rate 0.0001
# Train Epoch: 145 [0/77458 (0%)]	log Loss: -12.233048
#
# Train set: Average log loss: -11.6261
#
#
# Test set: Average loss: -11.1533
#
# Current Learning rate 0.0001
# Train Epoch: 146 [0/77458 (0%)]	log Loss: -11.247226
#
# Train set: Average log loss: -12.0048
#
#
# Test set: Average loss: -11.8127
#
# Current Learning rate 0.0001
# Train Epoch: 147 [0/77458 (0%)]	log Loss: -11.819646
#
# Train set: Average log loss: -11.7211
#
#
# Test set: Average loss: -11.3746
#
# Current Learning rate 0.0001
# Train Epoch: 148 [0/77458 (0%)]	log Loss: -11.474856
#
# Train set: Average log loss: -11.6025
#
#
# Test set: Average loss: -12.2422
#
# Current Learning rate 0.0001
# Train Epoch: 149 [0/77458 (0%)]	log Loss: -12.328230
#
# Train set: Average log loss: -11.7406
#
#
# Test set: Average loss: -12.2471
#
# Current Learning rate 0.0001
# Train Epoch: 150 [0/77458 (0%)]	log Loss: -12.349656
#
# Train set: Average log loss: -12.0059
#
#
# Test set: Average loss: -12.2034
#
# Current Learning rate 0.0001
# Train Epoch: 151 [0/77458 (0%)]	log Loss: -12.335228
#
# Train set: Average log loss: -12.0147
#
#
# Test set: Average loss: -11.4019
#
# Current Learning rate 0.0001
# Train Epoch: 152 [0/77458 (0%)]	log Loss: -11.389672
#
# Train set: Average log loss: -11.5067
#
#
# Test set: Average loss: -12.2356
#
# Current Learning rate 0.0001
# Train Epoch: 153 [0/77458 (0%)]	log Loss: -12.370831
#
# Train set: Average log loss: -12.0317
#
#
# Test set: Average loss: -12.2635
#
# Current Learning rate 0.0001
# Train Epoch: 154 [0/77458 (0%)]	log Loss: -12.391732
#
# Train set: Average log loss: -12.0404
#
#
# Test set: Average loss: -11.6928
#
# Current Learning rate 0.0001
# Train Epoch: 155 [0/77458 (0%)]	log Loss: -11.695095
#
# Train set: Average log loss: -11.7824
#
#
# Test set: Average loss: -11.9076
#
# Current Learning rate 0.0001
# Train Epoch: 156 [0/77458 (0%)]	log Loss: -11.932973
#
# Train set: Average log loss: -11.8530
#
#
# Test set: Average loss: -12.0568
#
# Current Learning rate 0.0001
# Train Epoch: 157 [0/77458 (0%)]	log Loss: -12.188666
#
# Train set: Average log loss: -11.3203
#
#
# Test set: Average loss: -11.3831
#
# Current Learning rate 0.0001
# Train Epoch: 158 [0/77458 (0%)]	log Loss: -11.498070
#
# Train set: Average log loss: -11.7129
#
#
# Test set: Average loss: -11.9042
#
# Current Learning rate 0.0001
# Train Epoch: 159 [0/77458 (0%)]	log Loss: -12.052426
#
# Train set: Average log loss: -11.7077
#
#
# Test set: Average loss: -12.1921
#
# Current Learning rate 0.0001
# Train Epoch: 160 [0/77458 (0%)]	log Loss: -12.260127
#
# Train set: Average log loss: -11.9326
#
#
# Test set: Average loss: -12.3107
#
# Current Learning rate 0.0001
# Train Epoch: 161 [0/77458 (0%)]	log Loss: -12.445755
#
# Train set: Average log loss: -11.8568
#
#
# Test set: Average loss: -12.2006
#
# Current Learning rate 0.0001
# Train Epoch: 162 [0/77458 (0%)]	log Loss: -12.358352
#
# Train set: Average log loss: -11.8774
#
#
# Test set: Average loss: -11.9671
#
# Current Learning rate 0.0001
# Train Epoch: 163 [0/77458 (0%)]	log Loss: -12.122065
#
# Train set: Average log loss: -12.0100
#
#
# Test set: Average loss: -11.7089
#
# Current Learning rate 0.0001
# Train Epoch: 164 [0/77458 (0%)]	log Loss: -11.847768
#
# Train set: Average log loss: -12.2969
#
#
# Test set: Average loss: -12.2191
#
# Current Learning rate 0.0001
# Train Epoch: 165 [0/77458 (0%)]	log Loss: -12.369866
#
# Train set: Average log loss: -12.0231
#
#
# Test set: Average loss: -11.9514
#
# Current Learning rate 0.0001
# Train Epoch: 166 [0/77458 (0%)]	log Loss: -11.968040
#
# Train set: Average log loss: -11.9160
#
#
# Test set: Average loss: -11.2037
#
# Current Learning rate 0.0001
# Train Epoch: 167 [0/77458 (0%)]	log Loss: -11.186886
#
# Train set: Average log loss: -11.5120
#
#
# Test set: Average loss: -11.6829
#
# Current Learning rate 0.0001
# Train Epoch: 168 [0/77458 (0%)]	log Loss: -11.819054
#
# Train set: Average log loss: -12.2582
#
#
# Test set: Average loss: -12.1514
#
# Current Learning rate 0.0001
# Train Epoch: 169 [0/77458 (0%)]	log Loss: -12.303176
#
# Train set: Average log loss: -11.8263
#
#
# Test set: Average loss: -12.2389
#
# Current Learning rate 0.0001
# Train Epoch: 170 [0/77458 (0%)]	log Loss: -12.395750
#
# Train set: Average log loss: -12.1419
#
#
# Test set: Average loss: -11.3167
#
# Current Learning rate 0.0001
# Train Epoch: 171 [0/77458 (0%)]	log Loss: -11.297751
#
# Train set: Average log loss: -11.5397
#
#
# Test set: Average loss: -12.0182
#
# Current Learning rate 0.0001
# Train Epoch: 172 [0/77458 (0%)]	log Loss: -12.176359
#
# Train set: Average log loss: -12.1438
#
#
# Test set: Average loss: -12.3137
#
# Current Learning rate 0.0001
# Train Epoch: 173 [0/77458 (0%)]	log Loss: -12.469943
#
# Train set: Average log loss: -12.1264
#
#
# Test set: Average loss: -11.9444
#
# Current Learning rate 0.0001
# Train Epoch: 174 [0/77458 (0%)]	log Loss: -11.963568
#
# Train set: Average log loss: -11.9007
#
#
# Test set: Average loss: -11.6855
#
# Current Learning rate 0.0001
# Train Epoch: 175 [0/77458 (0%)]	log Loss: -11.689062
#
# Train set: Average log loss: -11.8069
#
#
# Test set: Average loss: -12.2995
#
# Current Learning rate 0.0001
# Train Epoch: 176 [0/77458 (0%)]	log Loss: -12.452979
#
# Train set: Average log loss: -11.5809
#
#
# Test set: Average loss: -11.1730
#
# Current Learning rate 0.0001
# Train Epoch: 177 [0/77458 (0%)]	log Loss: -11.278570
#
# Train set: Average log loss: -12.1931
#
#
# Test set: Average loss: -11.9394
#
# Current Learning rate 0.0001
# Train Epoch: 178 [0/77458 (0%)]	log Loss: -12.095588
#
# Train set: Average log loss: -12.2106
#
#
# Test set: Average loss: -11.8835
#
# Current Learning rate 0.0001
# Train Epoch: 179 [0/77458 (0%)]	log Loss: -11.897924
#
# Train set: Average log loss: -11.8983
#
#
# Test set: Average loss: -11.2435
#
# Current Learning rate 0.0001
# Train Epoch: 180 [0/77458 (0%)]	log Loss: -11.228339
#
# Train set: Average log loss: -11.7106
#
#
# Test set: Average loss: -12.0318
#
# Current Learning rate 0.0001
# Train Epoch: 181 [0/77458 (0%)]	log Loss: -12.191604
#
# Train set: Average log loss: -12.0820
#
#
# Test set: Average loss: -12.1605
#
# Current Learning rate 0.0001
# Train Epoch: 182 [0/77458 (0%)]	log Loss: -12.328696
#
# Train set: Average log loss: -12.0269
#
#
# Test set: Average loss: -12.1453
#
# Current Learning rate 0.0001
# Train Epoch: 183 [0/77458 (0%)]	log Loss: -12.192904
#
# Train set: Average log loss: -11.7991
#
#
# Test set: Average loss: -12.0908
#
# Current Learning rate 0.0001
# Train Epoch: 184 [0/77458 (0%)]	log Loss: -12.255582
#
# Train set: Average log loss: -12.0860
#
#
# Test set: Average loss: -12.3976
#
# Current Learning rate 0.0001
# Train Epoch: 185 [0/77458 (0%)]	log Loss: -12.516803
#
# Train set: Average log loss: -12.0004
#
#
# Test set: Average loss: -12.4087
#
# Current Learning rate 0.0001
# Train Epoch: 186 [0/77458 (0%)]	log Loss: -12.523478
#
# Train set: Average log loss: -11.9457
#
#
# Test set: Average loss: -12.3448
#
# Current Learning rate 0.0001
# Train Epoch: 187 [0/77458 (0%)]	log Loss: -12.509133
#
# Train set: Average log loss: -11.6002
#
#
# Test set: Average loss: -11.2806
#
# Current Learning rate 0.0001
# Train Epoch: 188 [0/77458 (0%)]	log Loss: -11.394565
#
# Train set: Average log loss: -11.9962
#
#
# Test set: Average loss: -11.2920
#
# Current Learning rate 0.0001
# Train Epoch: 189 [0/77458 (0%)]	log Loss: -11.406686
#
# Train set: Average log loss: -12.1365
#
#
# Test set: Average loss: -11.7950
#
# Current Learning rate 0.0001
# Train Epoch: 190 [0/77458 (0%)]	log Loss: -11.950684
#
# Train set: Average log loss: -12.1457
#
#
# Test set: Average loss: -12.4325
#
# Current Learning rate 0.0001
# Train Epoch: 191 [0/77458 (0%)]	log Loss: -12.576218
#
# Train set: Average log loss: -11.7349
#
#
# Test set: Average loss: -11.4475
#
# Current Learning rate 0.0001
# Train Epoch: 192 [0/77458 (0%)]	log Loss: -11.577090
#
# Train set: Average log loss: -12.2040
#
#
# Test set: Average loss: -11.8052
#
# Current Learning rate 0.0001
# Train Epoch: 193 [0/77458 (0%)]	log Loss: -11.960293
#
# Train set: Average log loss: -11.9769
#
#
# Test set: Average loss: -11.1947
#
# Current Learning rate 0.0001
# Train Epoch: 194 [0/77458 (0%)]	log Loss: -11.163177
#
# Train set: Average log loss: -11.9567
#
#
# Test set: Average loss: -11.2680
#
# Current Learning rate 0.0001
# Train Epoch: 195 [0/77458 (0%)]	log Loss: -11.377279
#
# Train set: Average log loss: -11.9325
#
#
# Test set: Average loss: -11.7060
#
# Current Learning rate 0.0001
# Train Epoch: 196 [0/77458 (0%)]	log Loss: -11.855238
#
# Train set: Average log loss: -12.1918
#
#
# Test set: Average loss: -12.4586
#
# Current Learning rate 0.0001
# Train Epoch: 197 [0/77458 (0%)]	log Loss: -12.620781
#
# Train set: Average log loss: -11.3469
#
#
# Test set: Average loss: -11.6479
#
# Current Learning rate 0.0001
# Train Epoch: 198 [0/77458 (0%)]	log Loss: -11.800824
#
# Train set: Average log loss: -11.8241
#
#
# Test set: Average loss: -12.2776
#
# Current Learning rate 0.0001
# Train Epoch: 199 [0/77458 (0%)]	log Loss: -12.336624
#
# Train set: Average log loss: -12.0654
#
#
# Test set: Average loss: -12.4525
#
# Current Learning rate 0.0001
# Train Epoch: 200 [0/77458 (0%)]	log Loss: -12.571574
#
# Train set: Average log loss: -11.9577
#
#
# Test set: Average loss: -12.4427
#
# Current Learning rate 0.0001
# Train Epoch: 201 [0/77458 (0%)]	log Loss: -12.557748
#
# Train set: Average log loss: -11.9930
#
#
# Test set: Average loss: -12.4795
#
# Current Learning rate 0.0001
# Train Epoch: 202 [0/77458 (0%)]	log Loss: -12.617438
#
# Train set: Average log loss: -11.9763
#
#
# Test set: Average loss: -12.4882
#
# Current Learning rate 0.0001
# Train Epoch: 203 [0/77458 (0%)]	log Loss: -12.633625
#
# Train set: Average log loss: -11.9865
#
#
# Test set: Average loss: -12.4987
#
# Current Learning rate 0.0001
# Train Epoch: 204 [0/77458 (0%)]	log Loss: -12.657178
#
# Train set: Average log loss: -11.9905
#
#
# Test set: Average loss: -12.5026
#
# Current Learning rate 0.0001
# Train Epoch: 205 [0/77458 (0%)]	log Loss: -12.673137
#
# Train set: Average log loss: -12.0033
#
#
# Test set: Average loss: -12.4852
#
# Current Learning rate 0.0001
# Train Epoch: 206 [0/77458 (0%)]	log Loss: -12.674030
#
# Train set: Average log loss: -12.0285
#
#
# Test set: Average loss: -12.3623
#
# Current Learning rate 0.0001
# Train Epoch: 207 [0/77458 (0%)]	log Loss: -12.564947
#
# Train set: Average log loss: -12.1527
#
#
# Test set: Average loss: -11.9702
#
# Current Learning rate 0.0001
# Train Epoch: 208 [0/77458 (0%)]	log Loss: -12.145856
#
# Train set: Average log loss: -12.4773
#
#
# Test set: Average loss: -12.4798
#
# Current Learning rate 0.0001
# Train Epoch: 209 [0/77458 (0%)]	log Loss: -12.669789
#
# Train set: Average log loss: -12.0615
#
#
# Test set: Average loss: -12.5069
#
# Current Learning rate 0.0001
# Train Epoch: 210 [0/77458 (0%)]	log Loss: -12.643675
#
# Train set: Average log loss: -12.0969
#
#
# Test set: Average loss: -11.5902
#
# Current Learning rate 0.0001
# Train Epoch: 211 [0/77458 (0%)]	log Loss: -11.583775
#
# Train set: Average log loss: -12.0595
#
#
# Test set: Average loss: -12.4975
#
# Current Learning rate 0.0001
# Train Epoch: 212 [0/77458 (0%)]	log Loss: -12.622884
#
# Train set: Average log loss: -11.7407
#
#
# Test set: Average loss: -12.0214
#
# Current Learning rate 0.0001
# Train Epoch: 213 [0/77458 (0%)]	log Loss: -12.192222
#
# Train set: Average log loss: -12.3165
#
#
# Test set: Average loss: -12.4839
#
# Current Learning rate 0.0001
# Train Epoch: 214 [0/77458 (0%)]	log Loss: -12.676705
#
# Train set: Average log loss: -12.2316
#
#
# Test set: Average loss: -11.6813
#
# Current Learning rate 0.0001
# Train Epoch: 215 [0/77458 (0%)]	log Loss: -11.682121
#
# Train set: Average log loss: -12.0509
#
#
# Test set: Average loss: -12.0527
#
# Current Learning rate 0.0001
# Train Epoch: 216 [0/77458 (0%)]	log Loss: -12.083807
#
# Train set: Average log loss: -11.5844
#
#
# Test set: Average loss: -11.4488
#
# Current Learning rate 0.0001
# Train Epoch: 217 [0/77458 (0%)]	log Loss: -11.568047
#
# Train set: Average log loss: -12.3337
#
#
# Test set: Average loss: -12.1538
#
# Current Learning rate 0.0001
# Train Epoch: 218 [0/77458 (0%)]	log Loss: -12.341454
#
# Train set: Average log loss: -12.3102
#
#
# Test set: Average loss: -12.2721
#
# Current Learning rate 0.0001
# Train Epoch: 219 [0/77458 (0%)]	log Loss: -12.340382
#
# Train set: Average log loss: -11.7958
#
#
# Test set: Average loss: -11.8774
#
# Current Learning rate 0.0001
# Train Epoch: 220 [0/77458 (0%)]	log Loss: -12.038763
#
# Train set: Average log loss: -12.3157
#
#
# Test set: Average loss: -12.3771
#
# Current Learning rate 0.0001
# Train Epoch: 221 [0/77458 (0%)]	log Loss: -12.575670
#
# Train set: Average log loss: -12.1095
#
#
# Test set: Average loss: -12.5213
#
# Current Learning rate 0.0001
# Train Epoch: 222 [0/77458 (0%)]	log Loss: -12.716173
#
# Train set: Average log loss: -12.0611
#
#
# Test set: Average loss: -12.3723
#
# Current Learning rate 0.0001
# Train Epoch: 223 [0/77458 (0%)]	log Loss: -12.570751
#
# Train set: Average log loss: -12.0913
#
#
# Test set: Average loss: -12.5424
#
# Current Learning rate 0.0001
# Train Epoch: 224 [0/77458 (0%)]	log Loss: -12.735531
#
# Train set: Average log loss: -12.0532
#
#
# Test set: Average loss: -12.5184
#
# Current Learning rate 0.0001
# Train Epoch: 225 [0/77458 (0%)]	log Loss: -12.717138
#
# Train set: Average log loss: -12.0321
#
#
# Test set: Average loss: -10.9307
#
# Current Learning rate 0.0001
# Train Epoch: 226 [0/77458 (0%)]	log Loss: -10.910255
#
# Train set: Average log loss: -11.7919
#
#
# Test set: Average loss: -11.2309
#
# Current Learning rate 0.0001
# Train Epoch: 227 [0/77458 (0%)]	log Loss: -11.335777
#
# Train set: Average log loss: -12.0018
#
#
# Test set: Average loss: -11.1849
#
# Current Learning rate 0.0001
# Train Epoch: 228 [0/77458 (0%)]	log Loss: -11.292801
#
# Train set: Average log loss: -12.2043
#
#
# Test set: Average loss: -11.6329
#
# Current Learning rate 0.0001
# Train Epoch: 229 [0/77458 (0%)]	log Loss: -11.777406
#
# Train set: Average log loss: -12.3250
#
#
# Test set: Average loss: -11.8753
#
# Current Learning rate 0.0001
# Train Epoch: 230 [0/77458 (0%)]	log Loss: -12.040329
#
# Train set: Average log loss: -12.2104
#
#
# Test set: Average loss: -12.5105
#
# Current Learning rate 0.0001
# Train Epoch: 231 [0/77458 (0%)]	log Loss: -12.710557
#
# Train set: Average log loss: -11.8079
#
#
# Test set: Average loss: -11.7678
#
# Current Learning rate 0.0001
# Train Epoch: 232 [0/77458 (0%)]	log Loss: -11.922764
#
# Train set: Average log loss: -12.3328
#
#
# Test set: Average loss: -11.7142
#
# Current Learning rate 0.0001
# Train Epoch: 233 [0/77458 (0%)]	log Loss: -11.863746
#
# Train set: Average log loss: -12.1258
#
#
# Test set: Average loss: -11.8923
#
# Current Learning rate 0.0001
# Train Epoch: 234 [0/77458 (0%)]	log Loss: -12.054416
#
# Train set: Average log loss: -12.2776
#
#
# Test set: Average loss: -12.5807
#
# Current Learning rate 0.0001
# Train Epoch: 235 [0/77458 (0%)]	log Loss: -12.771726
#
# Train set: Average log loss: -11.5504
#
#
# Test set: Average loss: -11.1189
#
# Current Learning rate 0.0001
# Train Epoch: 236 [0/77458 (0%)]	log Loss: -11.230096
#
# Train set: Average log loss: -11.8467
#
#
# Test set: Average loss: -12.3615
#
# Current Learning rate 0.0001
# Train Epoch: 237 [0/77458 (0%)]	log Loss: -12.407763
#
# Train set: Average log loss: -11.9807
#
#
# Test set: Average loss: -12.4880
#
# Current Learning rate 0.0001
# Train Epoch: 238 [0/77458 (0%)]	log Loss: -12.572121
#
# Train set: Average log loss: -12.1406
#
#
# Test set: Average loss: -12.4467
#
# Current Learning rate 0.0001
# Train Epoch: 239 [0/77458 (0%)]	log Loss: -12.516989
#
# Train set: Average log loss: -12.0900
#
#
# Test set: Average loss: -12.4597
#
# Current Learning rate 0.0001
# Train Epoch: 240 [0/77458 (0%)]	log Loss: -12.536840
#
# Train set: Average log loss: -12.1028
#
#
# Test set: Average loss: -12.4803
#
# Current Learning rate 0.0001
# Train Epoch: 241 [0/77458 (0%)]	log Loss: -12.564253
#
# Train set: Average log loss: -12.0975
#
#
# Test set: Average loss: -12.5107
#
# Current Learning rate 0.0001
# Train Epoch: 242 [0/77458 (0%)]	log Loss: -12.603852
#
# Train set: Average log loss: -12.1018
#
#
# Test set: Average loss: -12.5363
#
# Current Learning rate 0.0001
# Train Epoch: 243 [0/77458 (0%)]	log Loss: -12.640925
#
# Train set: Average log loss: -12.1163
#
#
# Test set: Average loss: -12.5903
#
# Current Learning rate 0.0001
# Train Epoch: 244 [0/77458 (0%)]	log Loss: -12.718704
#
# Train set: Average log loss: -12.1374
#
#
# Test set: Average loss: -12.6342
#
# Current Learning rate 0.0001
# Train Epoch: 245 [0/77458 (0%)]	log Loss: -12.815776
#
# Train set: Average log loss: -12.2292
#
#
# Test set: Average loss: -12.3339
#
# Current Learning rate 0.0001
# Train Epoch: 246 [0/77458 (0%)]	log Loss: -12.541912
#
# Train set: Average log loss: -12.5274
#
#
# Test set: Average loss: -12.6338
#
# Current Learning rate 0.0001
# Train Epoch: 247 [0/77458 (0%)]	log Loss: -12.827358
#
# Train set: Average log loss: -12.3898
#
#
# Test set: Average loss: -11.3791
#
# Current Learning rate 0.0001
# Train Epoch: 248 [0/77458 (0%)]	log Loss: -11.363739
#
# Train set: Average log loss: -11.9097
#
#
# Test set: Average loss: -12.5573
#
# Current Learning rate 0.0001
# Train Epoch: 249 [0/77458 (0%)]	log Loss: -12.762832
#
# Train set: Average log loss: -12.5048
#
#
# Test set: Average loss: -12.0484
#
# Current Learning rate 0.0001
# Train Epoch: 250 [0/77458 (0%)]	log Loss: -12.069610
#
# Train set: Average log loss: -12.0206
#
#
# Test set: Average loss: -11.8396
#
# Current Learning rate 0.0001
# Train Epoch: 251 [0/77458 (0%)]	log Loss: -11.850278
#
# Train set: Average log loss: -12.0734
#
#
# Test set: Average loss: -12.2661
#
# Current Learning rate 0.0001
# Train Epoch: 252 [0/77458 (0%)]	log Loss: -12.450632
#
# Train set: Average log loss: -12.3350
#
#
# Test set: Average loss: -12.0888
#
# Current Learning rate 0.0001
# Train Epoch: 253 [0/77458 (0%)]	log Loss: -12.116510
#
# Train set: Average log loss: -12.1517
#
#
# Test set: Average loss: -12.5997
#
# Current Learning rate 0.0001
# Train Epoch: 254 [0/77458 (0%)]	log Loss: -12.788092
#
# Train set: Average log loss: -11.6010
#
#
# Test set: Average loss: -12.3707
#
# Current Learning rate 0.0001
# Train Epoch: 255 [0/77458 (0%)]	log Loss: -12.571543
#
# Train set: Average log loss: -12.1323
#
#
# Test set: Average loss: -12.4851
#
# Current Learning rate 0.0001
# Train Epoch: 256 [0/77458 (0%)]	log Loss: -12.690367
#
# Train set: Average log loss: -12.1505
#
#
# Test set: Average loss: -12.5070
#
# Current Learning rate 0.0001
# Train Epoch: 257 [0/77458 (0%)]	log Loss: -12.713110
#
# Train set: Average log loss: -12.1914
#
#
# Test set: Average loss: -12.3557
#
# Current Learning rate 0.0001
# Train Epoch: 258 [0/77458 (0%)]	log Loss: -12.556754
#
# Train set: Average log loss: -12.3935
#
#
# Test set: Average loss: -12.3885
#
# Current Learning rate 0.0001
# Train Epoch: 259 [0/77458 (0%)]	log Loss: -12.590668
#
# Train set: Average log loss: -12.5116
#
#
# Test set: Average loss: -12.5607
#
# Current Learning rate 0.0001
# Train Epoch: 260 [0/77458 (0%)]	log Loss: -12.665189
#
# Train set: Average log loss: -12.0296
#
#
# Test set: Average loss: -12.6828
#
# Current Learning rate 0.0001
# Train Epoch: 261 [0/77458 (0%)]	log Loss: -12.854259
#
# Train set: Average log loss: -12.4738
#
#
# Test set: Average loss: -12.5899
#
# Current Learning rate 0.0001
# Train Epoch: 262 [0/77458 (0%)]	log Loss: -12.693701
#
# Train set: Average log loss: -11.4843
#
#
# Test set: Average loss: -12.5740
#
# Current Learning rate 0.0001
# Train Epoch: 263 [0/77458 (0%)]	log Loss: -12.682914
#
# Train set: Average log loss: -12.2423
#
#
# Test set: Average loss: -12.5837
#
# Current Learning rate 0.0001
# Train Epoch: 264 [0/77458 (0%)]	log Loss: -12.684518
#
# Train set: Average log loss: -12.1752
#
#
# Test set: Average loss: -12.6063
#
# Current Learning rate 0.0001
# Train Epoch: 265 [0/77458 (0%)]	log Loss: -12.716062
#
# Train set: Average log loss: -12.1897
#
#
# Test set: Average loss: -12.6530
#
# Current Learning rate 0.0001
# Train Epoch: 266 [0/77458 (0%)]	log Loss: -12.781686
#
# Train set: Average log loss: -12.2511
#
#
# Test set: Average loss: -12.6604
#
# Current Learning rate 0.0001
# Train Epoch: 267 [0/77458 (0%)]	log Loss: -12.861002
#
# Train set: Average log loss: -12.5061
#
#
# Test set: Average loss: -12.6542
#
# Current Learning rate 0.0001
# Train Epoch: 268 [0/77458 (0%)]	log Loss: -12.854319
#
# Train set: Average log loss: -12.5605
#
#
# Test set: Average loss: -11.2861
#
# Current Learning rate 0.0001
# Train Epoch: 269 [0/77458 (0%)]	log Loss: -11.271112
#
# Train set: Average log loss: -12.0348
#
#
# Test set: Average loss: -12.5536
#
# Current Learning rate 0.0001
# Train Epoch: 270 [0/77458 (0%)]	log Loss: -12.750504
#
# Train set: Average log loss: -12.5015
#
#
# Test set: Average loss: -11.9608
#
# Current Learning rate 0.0001
# Train Epoch: 271 [0/77458 (0%)]	log Loss: -11.974131
#
# Train set: Average log loss: -12.0285
#
#
# Test set: Average loss: -12.6809
#
# Current Learning rate 0.0001
# Train Epoch: 272 [0/77458 (0%)]	log Loss: -12.828786
#
# Train set: Average log loss: -12.1742
#
#
# Test set: Average loss: -12.6261
#
# Current Learning rate 0.0001
# Train Epoch: 273 [0/77458 (0%)]	log Loss: -12.820015
#
# Train set: Average log loss: -12.4350
#
#
# Test set: Average loss: -12.0952
#
# Current Learning rate 0.0001
# Train Epoch: 274 [0/77458 (0%)]	log Loss: -12.118987
#
# Train set: Average log loss: -11.9276
#
#
# Test set: Average loss: -12.7065
#
# Current Learning rate 0.0001
# Train Epoch: 275 [0/77458 (0%)]	log Loss: -12.873733
#
# Train set: Average log loss: -12.4374
#
#
# Test set: Average loss: -11.9425
#
# Current Learning rate 0.0001
# Train Epoch: 276 [0/77458 (0%)]	log Loss: -11.957158
#
# Train set: Average log loss: -12.0183
#
#
# Test set: Average loss: -12.5850
#
# Current Learning rate 0.0001
# Train Epoch: 277 [0/77458 (0%)]	log Loss: -12.776066
#
# Train set: Average log loss: -12.4151
#
#
# Test set: Average loss: -12.3161
#
# Current Learning rate 0.0001
# Train Epoch: 278 [0/77458 (0%)]	log Loss: -12.367802
#
# Train set: Average log loss: -12.0782
#
#
# Test set: Average loss: -12.6029
#
# Current Learning rate 0.0001
# Train Epoch: 279 [0/77458 (0%)]	log Loss: -12.792641
#
# Train set: Average log loss: -12.3403
#
#
# Test set: Average loss: -12.6851
#
# Current Learning rate 0.0001
# Train Epoch: 280 [0/77458 (0%)]	log Loss: -12.818984
#
# Train set: Average log loss: -12.2879
#
#
# Test set: Average loss: -12.2098
#
# Current Learning rate 0.0001
# Train Epoch: 281 [0/77458 (0%)]	log Loss: -12.248607
#
# Train set: Average log loss: -12.1422
#
#
# Test set: Average loss: -10.7861
#
# Current Learning rate 0.0001
# Train Epoch: 282 [0/77458 (0%)]	log Loss: -10.848032
#
# Train set: Average log loss: -11.6071
#
#
# Test set: Average loss: -12.6207
#
# Current Learning rate 0.0001
# Train Epoch: 283 [0/77458 (0%)]	log Loss: -12.717907
#
# Train set: Average log loss: -12.1654
#
#
# Test set: Average loss: -12.7001
#
# Current Learning rate 0.0001
# Train Epoch: 284 [0/77458 (0%)]	log Loss: -12.820937
#
# Train set: Average log loss: -12.2856
#
#
# Test set: Average loss: -12.7088
#
# Current Learning rate 0.0001
# Train Epoch: 285 [0/77458 (0%)]	log Loss: -12.835744
#
# Train set: Average log loss: -12.3326
#
#
# Test set: Average loss: -12.7346
#
# Current Learning rate 0.0001
# Train Epoch: 286 [0/77458 (0%)]	log Loss: -12.928089
#
# Train set: Average log loss: -12.5025
#
#
# Test set: Average loss: -12.4351
#
# Current Learning rate 0.0001
# Train Epoch: 287 [0/77458 (0%)]	log Loss: -12.625527
#
# Train set: Average log loss: -12.6508
#
#
# Test set: Average loss: -12.5789
#
# Current Learning rate 0.0001
# Train Epoch: 288 [0/77458 (0%)]	log Loss: -12.668536
#
# Train set: Average log loss: -11.9819
#
#
# Test set: Average loss: -12.6333
#
# Current Learning rate 0.0001
# Train Epoch: 289 [0/77458 (0%)]	log Loss: -12.829346
#
# Train set: Average log loss: -12.6382
#
#
# Test set: Average loss: -12.5425
#
# Current Learning rate 0.0001
# Train Epoch: 290 [0/77458 (0%)]	log Loss: -12.619347
#
# Train set: Average log loss: -11.9157
#
#
# Test set: Average loss: -12.0449
#
# Current Learning rate 0.0001
# Train Epoch: 291 [0/77458 (0%)]	log Loss: -12.188320
#
# Train set: Average log loss: -12.5168
#
#
# Test set: Average loss: -12.7087
#
# Current Learning rate 0.0001
# Train Epoch: 292 [0/77458 (0%)]	log Loss: -12.837738
#
# Train set: Average log loss: -12.3591
#
#
# Test set: Average loss: -12.5858
#
# Current Learning rate 0.0001
# Train Epoch: 293 [0/77458 (0%)]	log Loss: -12.674392
#
# Train set: Average log loss: -11.9456
#
#
# Test set: Average loss: -12.4592
#
# Current Learning rate 0.0001
# Train Epoch: 294 [0/77458 (0%)]	log Loss: -12.649780
#
# Train set: Average log loss: -12.4464
#
#
# Test set: Average loss: -12.7599
#
# Current Learning rate 0.0001
# Train Epoch: 295 [0/77458 (0%)]	log Loss: -12.937329
#
# Train set: Average log loss: -12.6086
#
#
# Test set: Average loss: -12.1533
#
# Current Learning rate 0.0001
# Train Epoch: 296 [0/77458 (0%)]	log Loss: -12.174975
#
# Train set: Average log loss: -11.9699
#
#
# Test set: Average loss: -12.6155
#
# Current Learning rate 0.0001
# Train Epoch: 297 [0/77458 (0%)]	log Loss: -12.805271
#
# Train set: Average log loss: -12.6156
#
#
# Test set: Average loss: -12.7908
#
# Current Learning rate 0.0001
# Train Epoch: 298 [0/77458 (0%)]	log Loss: -12.948119
#
# Train set: Average log loss: -11.3641
#
#
# Test set: Average loss: -11.7653
#
# Current Learning rate 0.0001
# Train Epoch: 299 [0/77458 (0%)]	log Loss: -11.890803
#
# Train set: Average log loss: -12.4934
#
#
# Test set: Average loss: -12.4375
#
# Current Learning rate 0.0001
# Train Epoch: 300 [0/77458 (0%)]	log Loss: -12.617036
#
# Train set: Average log loss: -12.4328
#
#
# Test set: Average loss: -12.7948
#
# Current Learning rate 0.0001
# Train Epoch: 301 [0/77458 (0%)]	log Loss: -12.961312
#
# Train set: Average log loss: -12.4237
#
#
# Test set: Average loss: -12.4180
#
# Current Learning rate 0.0001
# Train Epoch: 302 [0/77458 (0%)]	log Loss: -12.608977
#
# Train set: Average log loss: -12.5429
#
#
# Test set: Average loss: -12.3733
#
# Current Learning rate 0.0001
# Train Epoch: 303 [0/77458 (0%)]	log Loss: -12.558243
#
# Train set: Average log loss: -12.6693
#
#
# Test set: Average loss: -12.1531
#
# Current Learning rate 0.0001
# Train Epoch: 304 [0/77458 (0%)]	log Loss: -12.172275
#
# Train set: Average log loss: -12.4319
#
#
# Test set: Average loss: -12.4125
#
# Current Learning rate 0.0001
# Train Epoch: 305 [0/77458 (0%)]	log Loss: -12.462602
#
# Train set: Average log loss: -12.0200
#
#
# Test set: Average loss: -12.7815
#
# ...
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7906 [0/77458 (0%)]	log Loss: -14.604445
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7907 [0/77458 (0%)]	log Loss: -14.604444
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7908 [0/77458 (0%)]	log Loss: -14.604452
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7909 [0/77458 (0%)]	log Loss: -14.604450
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7910 [0/77458 (0%)]	log Loss: -14.604445
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7911 [0/77458 (0%)]	log Loss: -14.604453
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7912 [0/77458 (0%)]	log Loss: -14.604445
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7913 [0/77458 (0%)]	log Loss: -14.604447
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7914 [0/77458 (0%)]	log Loss: -14.604451
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7915 [0/77458 (0%)]	log Loss: -14.604447
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7916 [0/77458 (0%)]	log Loss: -14.604443
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7917 [0/77458 (0%)]	log Loss: -14.604441
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7918 [0/77458 (0%)]	log Loss: -14.604450
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7919 [0/77458 (0%)]	log Loss: -14.604444
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7920 [0/77458 (0%)]	log Loss: -14.604443
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7921 [0/77458 (0%)]	log Loss: -14.604450
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7922 [0/77458 (0%)]	log Loss: -14.604443
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7923 [0/77458 (0%)]	log Loss: -14.604450
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7924 [0/77458 (0%)]	log Loss: -14.604446
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7925 [0/77458 (0%)]	log Loss: -14.604445
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7926 [0/77458 (0%)]	log Loss: -14.604453
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7927 [0/77458 (0%)]	log Loss: -14.604454
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7928 [0/77458 (0%)]	log Loss: -14.604448
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7929 [0/77458 (0%)]	log Loss: -14.604447
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7930 [0/77458 (0%)]	log Loss: -14.604442
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7931 [0/77458 (0%)]	log Loss: -14.604448
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7932 [0/77458 (0%)]	log Loss: -14.604443
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7933 [0/77458 (0%)]	log Loss: -14.604447
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7934 [0/77458 (0%)]	log Loss: -14.604441
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7935 [0/77458 (0%)]	log Loss: -14.604443
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7936 [0/77458 (0%)]	log Loss: -14.604448
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7937 [0/77458 (0%)]	log Loss: -14.604446
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7938 [0/77458 (0%)]	log Loss: -14.604446
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7939 [0/77458 (0%)]	log Loss: -14.604442
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7940 [0/77458 (0%)]	log Loss: -14.604437
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7941 [0/77458 (0%)]	log Loss: -14.604436
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7942 [0/77458 (0%)]	log Loss: -14.604437
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7943 [0/77458 (0%)]	log Loss: -14.604442
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7944 [0/77458 (0%)]	log Loss: -14.604441
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7945 [0/77458 (0%)]	log Loss: -14.604442
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7946 [0/77458 (0%)]	log Loss: -14.604438
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7947 [0/77458 (0%)]	log Loss: -14.604448
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7948 [0/77458 (0%)]	log Loss: -14.604445
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7949 [0/77458 (0%)]	log Loss: -14.604443
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7950 [0/77458 (0%)]	log Loss: -14.604444
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7951 [0/77458 (0%)]	log Loss: -14.604438
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7952 [0/77458 (0%)]	log Loss: -14.604440
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7953 [0/77458 (0%)]	log Loss: -14.604440
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7954 [0/77458 (0%)]	log Loss: -14.604447
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7955 [0/77458 (0%)]	log Loss: -14.604439
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7956 [0/77458 (0%)]	log Loss: -14.604443
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7957 [0/77458 (0%)]	log Loss: -14.604438
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7958 [0/77458 (0%)]	log Loss: -14.604438
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7959 [0/77458 (0%)]	log Loss: -14.604452
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7960 [0/77458 (0%)]	log Loss: -14.604442
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7961 [0/77458 (0%)]	log Loss: -14.604449
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7962 [0/77458 (0%)]	log Loss: -14.604444
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7963 [0/77458 (0%)]	log Loss: -14.604443
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7964 [0/77458 (0%)]	log Loss: -14.604440
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7965 [0/77458 (0%)]	log Loss: -14.604441
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7966 [0/77458 (0%)]	log Loss: -14.604440
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7967 [0/77458 (0%)]	log Loss: -14.604441
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7968 [0/77458 (0%)]	log Loss: -14.604437
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7969 [0/77458 (0%)]	log Loss: -14.604438
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7970 [0/77458 (0%)]	log Loss: -14.604443
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7971 [0/77458 (0%)]	log Loss: -14.604435
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7972 [0/77458 (0%)]	log Loss: -14.604444
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7973 [0/77458 (0%)]	log Loss: -14.604431
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7974 [0/77458 (0%)]	log Loss: -14.604441
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7975 [0/77458 (0%)]	log Loss: -14.604440
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7976 [0/77458 (0%)]	log Loss: -14.604441
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7977 [0/77458 (0%)]	log Loss: -14.604437
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7978 [0/77458 (0%)]	log Loss: -14.604438
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7979 [0/77458 (0%)]	log Loss: -14.604435
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7980 [0/77458 (0%)]	log Loss: -14.604436
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7981 [0/77458 (0%)]	log Loss: -14.604432
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7982 [0/77458 (0%)]	log Loss: -14.604434
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7983 [0/77458 (0%)]	log Loss: -14.604430
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7984 [0/77458 (0%)]	log Loss: -14.604426
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7985 [0/77458 (0%)]	log Loss: -14.604436
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7986 [0/77458 (0%)]	log Loss: -14.604435
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7987 [0/77458 (0%)]	log Loss: -14.604437
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7988 [0/77458 (0%)]	log Loss: -14.604439
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7989 [0/77458 (0%)]	log Loss: -14.604439
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7990 [0/77458 (0%)]	log Loss: -14.604439
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7991 [0/77458 (0%)]	log Loss: -14.604445
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7992 [0/77458 (0%)]	log Loss: -14.604443
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7993 [0/77458 (0%)]	log Loss: -14.604441
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7994 [0/77458 (0%)]	log Loss: -14.604442
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7995 [0/77458 (0%)]	log Loss: -14.604437
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7996 [0/77458 (0%)]	log Loss: -14.604446
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7997 [0/77458 (0%)]	log Loss: -14.604442
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7998 [0/77458 (0%)]	log Loss: -14.604442
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7999 [0/77458 (0%)]	log Loss: -14.604441
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 8000 [0/77458 (0%)]	log Loss: -14.604436
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.1400
#
# Current Learning rate 3.0517578125e-09

# %%
# Plotting log(MSE) as a function of epochs
plt.figure(figsize=(10,7))
plt.plot( np.log(test_losses), label = "test")
plt.plot( np.log(train_losses), label = "train")

plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Log(LSE)")
plt.title("MSE over Epoch" )
plt.grid()
print("Training WIDE {} VS in the article 8.04e-09".format(train_losses[-1]) )
# Out:
# Training WIDE 4.4652237940432287e-07 VS in the article 8.04e-09

# %% [markdown]
# ## d) Prediction
# #### Load the ANN

# %%
# Loading model
device = 'cuda'
loaded_Heston_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_ANN_DE.pt"
loaded_Heston_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_ANN.eval()
# Out:
# Heston_ANN(
#   (fc1): Linear(in_features=8, out_features=200, bias=True)
#   (fc2): Linear(in_features=200, out_features=200, bias=True)
#   (fc3): Linear(in_features=200, out_features=200, bias=True)
#   (fc4): Linear(in_features=200, out_features=200, bias=True)
#   (fc5): Linear(in_features=200, out_features=1, bias=True)
# )

# %% [markdown]
# #### This table shows similar trained forward performance as shown in Table (4) from [1]

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Train scores----------------
# MSE 6.440350e-07
# MAE 6.144964e-04
# MAPE 4.099713e-02
# R2 9.999768e-01
# -----------Test scores----------------
# MSE 6.552845e-07
# MAE 6.159798e-04
# MAPE 2.607605e-02
# R2 9.999767e-01

# %% [markdown]
# #### The ANN Solver can now be used for pricing. (e.g. on data, output = loaded_Heston_ANN(data))

# %%
# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

print(prices)
# Out:
# [0.10300332 0.35239398 0.2129313  ... 0.32440856 0.51017773 0.5260942 ]

# %% [markdown]
# ## d) Calculate implied volatilities

# %%
from scipy import optimize

def calcimpliedvol(dataset):
    """
    Computes the implied volatilities using the brent method.
    dataset: numpy array containing moneyness, time to maturity, risk free interest rate and V/K.
    Returns a vector of implied volatilities.
    """
    money = np.array(dataset[0])
    T = np.array(dataset[1])
    r = np.array(dataset[2])
    marketoptionPrice = np.array(dataset[3])
    def bs_price(sigma):
      d1 = ( np.log(money) + (r + 0.5 * sigma ** 2) * (T) ) / (sigma * np.sqrt(T))
      d2 = d1 - sigma*np.sqrt(T)
      value_moyeness = money * norm.cdf(d1) - np.exp(-r * (T)) * norm.cdf(d2) 
      fx = value_moyeness - marketoptionPrice
      return fx
    return optimize.brentq(bs_price,-1,1,maxiter=100)

# %%
# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

# Replace with this
hs_dataset2 = hs_dataset.data[:, np.array([0, 1, 2, 8])]  # Select relevant columns
hs_dataset2[:, 3] = torch.FloatTensor(prices)  # Use Heston-ANN prices as market prices for Brent's method

# Compute implied volatilities using Brent's method
implied_vol = np.apply_along_axis(calcimpliedvol, 1, hs_dataset2)

# Eliminating Nan values
indecies = np.argwhere(np.isnan(implied_vol))
implied_vol = np.delete(implied_vol, indecies, 0)

# %%
print(implied_vol)
# Out:
# [0.52459126 0.51703085 0.44253226 ... 0.34001146 0.57927668 0.60456098]

# %% [markdown]
# ## e) Volatility Surface

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# Define your fixed Heston parameters
rho = -0.05
kappa = 1.5
vbar = 0.1
gamma = 0.3
v0 = 0.1
r = 0.02

# Create a mesh grid of moneyness and maturity
moneyness = np.linspace(0.75, 1.25, 11)
tau = np.linspace(0.1, 1.0, 10)
m_grid, t_grid = np.meshgrid(moneyness, tau)

# Flatten grid and build input tensor
m_flat = m_grid.flatten()
t_flat = t_grid.flatten()
r_flat = np.full_like(m_flat, r)

# Build ANN input: [m, tau, r, rho, kappa, vbar, gamma, v0]
X = np.column_stack([
    m_flat, t_flat, r_flat,
    np.full_like(m_flat, rho),
    np.full_like(m_flat, kappa),
    np.full_like(m_flat, vbar),
    np.full_like(m_flat, gamma),
    np.full_like(m_flat, v0)
])

# Convert to torch tensor
input_tensor = torch.FloatTensor(X).to("cuda" if torch.cuda.is_available() else "cpu")

# Forward pass to get prices
with torch.no_grad():
    prices = loaded_Heston_ANN(input_tensor).cpu().numpy().flatten()

# Prepare for Brent
brent_input = np.column_stack([m_flat, t_flat, r_flat, prices])
iv_surface = np.apply_along_axis(calcimpliedvol, 1, brent_input)
Z = iv_surface.reshape(m_grid.shape)

# Plot the surface
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(m_grid, t_grid, Z, cmap='viridis', edgecolor='none')
ax.set_xlabel("Moneyness (S/K)")
ax.set_ylabel("Maturity (tau)")
ax.set_zlabel("Implied Volatility")
ax.set_title("Implied Volatility Surface (Heston-ANN + Brent)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2) Backward pass

# %% [markdown]
# ### Reference Heston parameter

# %%
# Effect of individual parameters
# Section 4.1.1 in [1]
T = 2 
S0 = 100
kappa = 0.1
gamma = 0.1  # Volatility of variance
nu_bar = 0.1
rho = -0.75
nu_0 = 0.05
r = 0.05
#"rho": (-0.9, 0.0),         # Correlation coefficient
##   "kappa": (0.1, 3.0),        # Speed of mean reversion
#    "gamma": (0.01, 0.8),      
 #   "nu_0": (0.01, 0.5),        # Initial variance
 #   "nu_bar": (0.01, 0.5)       # Long-term variance

# %%
import numpy as np
import torch
from scipy.optimize import brentq
from scipy.stats import norm

# Brent inversion function
def calcimpliedvol(row):
    money, T, r, price = row
    def bs_price(sigma):
        if sigma <= 0:
            return -price
        d1 = (np.log(money) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
        d2 = d1 - sigma * np.sqrt(T)
        bs = money * norm.cdf(d1) - np.exp(-r * T) * norm.cdf(d2)
        return bs - price
    try:
        return brentq(bs_price, 1e-6, 3.0)
    except:
        return np.nan

# Grid: 7 moneyness × 5 maturities = 35
moneyness = np.linspace(0.85, 1.15, 7)
maturity = np.array([0.1, 0.3, 0.6, 1.0, 2.0])
m_grid, t_grid = np.meshgrid(moneyness, maturity)
m_flat = m_grid.flatten()
t_flat = t_grid.flatten()
r_flat = np.full_like(m_flat, 0.01)

# Fixed Heston parameters (Section 4.1.1 reference)
rho, kappa, vbar, gamma, v0 = -0.05, 1.5, 0.1, 0.3, 0.1

# Build input tensor
input_matrix = np.column_stack([
    m_flat, t_flat, r_flat,
    np.full_like(m_flat, rho),
    np.full_like(m_flat, kappa),
    np.full_like(m_flat, vbar),
    np.full_like(m_flat, gamma),
    np.full_like(m_flat, v0)
])
input_tensor = torch.FloatTensor(input_matrix).to(device)

# Predict prices
with torch.no_grad():
    prices = loaded_Heston_ANN(input_tensor).cpu().numpy().flatten()
prices = np.maximum(prices, 1e-5)

# Compute IVs using Brent
brent_input = np.column_stack([m_flat, t_flat, r_flat, prices])
implied_vols = np.apply_along_axis(calcimpliedvol, 1, brent_input)

# Final quotes
market_quotes = np.column_stack([m_flat, t_flat, r_flat, implied_vols])
print("Market Quotes (35):")
for q in market_quotes:
    print(f"m={q[0]:.2f}, tau={q[1]:.2f}, r={q[2]:.2f}, IV={q[3]:.4f}")
# Out:
# Market Quotes (35):
# m=0.80, tau=0.10, r=0.01, IV=0.2172
# m=0.87, tau=0.10, r=0.01, IV=0.1434
# m=0.93, tau=0.10, r=0.01, IV=0.0728
# m=1.00, tau=0.10, r=0.01, IV=nan
# m=1.07, tau=0.10, r=0.01, IV=nan
# m=1.13, tau=0.10, r=0.01, IV=nan
# m=1.20, tau=0.10, r=0.01, IV=nan
# m=0.80, tau=0.30, r=0.01, IV=0.1244
# m=0.87, tau=0.30, r=0.01, IV=0.0817
# m=0.93, tau=0.30, r=0.01, IV=0.0409
# m=1.00, tau=0.30, r=0.01, IV=nan
# m=1.07, tau=0.30, r=0.01, IV=nan
# m=1.13, tau=0.30, r=0.01, IV=nan
# m=1.20, tau=0.30, r=0.01, IV=nan
# m=0.80, tau=0.60, r=0.01, IV=0.0868
# m=0.87, tau=0.60, r=0.01, IV=0.0567
# m=0.93, tau=0.60, r=0.01, IV=0.0277
# m=1.00, tau=0.60, r=0.01, IV=nan
# m=1.07, tau=0.60, r=0.01, IV=nan
# m=1.13, tau=0.60, r=0.01, IV=nan
# m=1.20, tau=0.60, r=0.01, IV=nan
# m=0.80, tau=1.00, r=0.01, IV=0.0661
# m=0.87, tau=1.00, r=0.01, IV=0.0427
# m=0.93, tau=1.00, r=0.01, IV=0.0202
# m=1.00, tau=1.00, r=0.01, IV=nan
# m=1.07, tau=1.00, r=0.01, IV=nan
# m=1.13, tau=1.00, r=0.01, IV=nan
# m=1.20, tau=1.00, r=0.01, IV=nan
# m=0.80, tau=2.00, r=0.01, IV=0.0447
# m=0.87, tau=2.00, r=0.01, IV=0.0281
# m=0.93, tau=2.00, r=0.01, IV=0.0121
# m=1.00, tau=2.00, r=0.01, IV=nan
# m=1.07, tau=2.00, r=0.01, IV=nan
# m=1.13, tau=2.00, r=0.01, IV=nan
# m=1.20, tau=2.00, r=0.01, IV=nan

# %%
# --- Fixed contracts (35 (m, tau, r) triplets) ---
# Example from Table 5 (user must insert actual values)
fixed_contracts = np.array([
    # [moneyness, tau, r]
    [0.8, 0.1, 0.01], [0.9, 0.1, 0.01], ..., [1.2, 1.0, 0.01]  # 35 rows
])

# --- Ground truth Brent IVs ---
# From Pipeline 1: implied_vol_pipe1 (shape: (35,))
target_iv = implied_vol_pipe1  # make sure it's aligned

# --- Loss function ---
def calibration_objective(theta):
    rho, kappa, vbar, gamma, v0 = theta
    input_matrix = np.hstack([
        fixed_contracts,
        np.full((fixed_contracts.shape[0], 1), rho),
        np.full((fixed_contracts.shape[0], 1), kappa),
        np.full((fixed_contracts.shape[0], 1), vbar),
        np.full((fixed_contracts.shape[0], 1), gamma),
        np.full((fixed_contracts.shape[0], 1), v0),
    ])
    input_tensor = torch.FloatTensor(input_matrix).to(device)
    with torch.no_grad():
        prices = loaded_Heston_ANN(input_tensor).cpu().numpy()
    brent_inputs = np.hstack([fixed_contracts, prices.reshape(-1, 1)])
    implied_vols = np.apply_along_axis(calcimpliedvol, 1, brent_inputs)
    return np.mean((implied_vols - target_iv)**2)

# --- Bounds from Section 4.1.1 ---
bounds = [(-0.9, 0.0), (0.1, 3.0), (0.0, 1.0), (0.01, 1.0), (0.01, 1.0)]

# --- Run DE optimization ---
result = differential_evolution(
    calibration_objective,
    bounds,
    strategy="best1bin",
    popsize=15,
    tol=1e-5,
    maxiter=1000,
    polish=True
)

print("Calibrated parameters:", result.x)
print("Final MSE loss:", result.fun)

# %%
# Plugging in the Heston-ANN prices
hs_dataset2 = hs_dataset.data[:,np.array([0,1,2,8])]
hs_dataset2.data[:,3] = torch.FloatTensor(prices)
loader2 = torch.utils.data.DataLoader(hs_dataset2, 4048)

# Computing IVs
implied_vol = []
indecies_list = []
with torch.no_grad():
  for idx, data in enumerate(loader2):
    data = data.to(device)
    # LOG Transformation
    data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
    data[:,3] = torch.log(data[:,3])
    output = loaded_IV_ANN(data)
    implied_vol.append((output).data.cpu().numpy())
  implied_vol_pipe2 = np.concatenate(implied_vol)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[46], line 5
#       3 loaded_IV_ANN = Heston_ANN().to(device)
#       4 PATH = "ANN_weights/IV_SCALED_ANN.pt"
# ----> 5 loaded_IV_ANN.load_state_dict(torch.load(PATH))
#       6 loaded_IV_ANN.eval()
#       9 # Plugging in the Heston-ANN prices
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\torch\nn\modules\module.py:2152, in Module.load_state_dict(self, state_dict, strict, assign)
#    2147         error_msgs.insert(
#    2148             0, 'Missing key(s) in state_dict: {}. '.format(
#    2149                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2151 if len(error_msgs) > 0:
# -> 2152     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2153                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2154 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Heston_ANN:
# 	size mismatch for fc1.weight: copying a param with shape torch.Size([400, 4]) from checkpoint, the shape in current model is torch.Size([200, 8]).
# 	size mismatch for fc1.bias: copying a param with shape torch.Size([400]) from checkpoint, the shape in current model is torch.Size([200]).
# 	size mismatch for fc2.weight: copying a param with shape torch.Size([400, 400]) from checkpoint, the shape in current model is torch.Size([200, 200]).
# 	size mismatch for fc2.bias: copying a param with shape torch.Size([400]) from checkpoint, the shape in current model is torch.Size([200]).
# 	size mismatch for fc3.weight: copying a param with shape torch.Size([400, 400]) from checkpoint, the shape in current model is torch.Size([200, 200]).
# 	size mismatch for fc3.bias: copying a param with shape torch.Size([400]) from checkpoint, the shape in current model is torch.Size([200]).
# 	size mismatch for fc4.weight: copying a param with shape torch.Size([400, 400]) from checkpoint, the shape in current model is torch.Size([200, 200]).
# 	size mismatch for fc4.bias: copying a param with shape torch.Size([400]) from checkpoint, the shape in current model is torch.Size([200]).
# 	size mismatch for fc5.weight: copying a param with shape torch.Size([1, 400]) from checkpoint, the shape in current model is torch.Size([1, 200]).

# %%
import numpy as np
import itertools

# Define Heston parameter bounds
bounds = {
    "rho": (-0.9, 0.0),         # Correlation coefficient
    "kappa": (0.1, 3.0),        # Speed of mean reversion
    "gamma": (0.01, 0.8),       # Volatility of variance
    "nu_0": (0.01, 0.5),        # Initial variance
    "nu_bar": (0.01, 0.5)       # Long-term variance
}

# Number of discrete points to sample within each parameter's range
points_per_param = 5

# Generate equally spaced points for each parameter within its bounds
parameter_points = {param: np.linspace(lower, upper, points_per_param)
                    for param, (lower, upper) in bounds.items()}

# Combine the points to form a grid of all possible parameter combinations
grid = list(itertools.product(
    parameter_points["rho"],
    parameter_points["kappa"],
    parameter_points["gamma"],
    parameter_points["nu_0"],
    parameter_points["nu_bar"]
))

# Convert the grid into a NumPy array for convenience
parameter_grid = np.array(grid)

# Display the grid details
print(f"Search space dimensions: {len(parameter_points)} parameters")
print(f"Total combinations: {parameter_grid.shape[0]}")
print("Example combinations (first 5 rows):")
print(parameter_grid[:5])

# Optional: Save to a file for later use
np.savetxt("heston_search_space.csv", parameter_grid, delimiter=",",
           header="rho,kappa,gamma,nu_0,nu_bar", comments="")

# %%
import torch
import numpy as np
from scipy.optimize import differential_evolution

def calibrate_with_de(loaded_ANN, moneyness, maturities, r, observed_vols, device="cuda"):
    """
    Calibrates Heston parameters using differential evolution and a trained ANN.
    
    Parameters:
    - loaded_ANN: Trained PyTorch ANN (set to .eval())
    - moneyness: 1D array of moneyness values (e.g., shape (5,))
    - maturities: 1D array of maturities (e.g., shape (7,))
    - r: risk-free rate (scalar)
    - observed_vols: flattened vector of observed implied vols (shape (len(moneyness) * len(maturities),))
    - device: "cuda" or "cpu"
    
    Returns:
    - result.x: optimal Heston parameters [rho, kappa, gamma, nu_bar, nu_0]
    - result.fun: final objective value (MSE)
    """

    # Make sure model is in eval mode
    loaded_ANN.eval()

    # Create full input grid for calibration
    def heston_ann(parameters):
        rho, kappa, gamma, nu_bar, nu_0 = parameters
        inputs = []

        for m in moneyness:
            for t in maturities:
                inputs.append([m, t, r, rho, kappa, nu_bar, gamma, nu_0])

        inputs = torch.tensor(inputs, dtype=torch.float32).to(device)

        with torch.no_grad():
            preds = loaded_ANN(inputs).cpu().numpy().flatten()
        return preds

    # Objective function to minimize
    def calibration_objective(parameters):
        predicted_vols = heston_ann(parameters)
        return np.mean((predicted_vols - observed_vols) ** 2)

    # Bounds for DE (adjust to your actual model/training setup)
    bounds = [
        (-0.85, 0.0),     # rho
        (0.1, 3.0),      # kappa
        (0.01, 0.8),     # gamma
        (0.01, 0.5),     # nu_bar
        (0.01, 0.5),     # nu_0
    ]

    # Run differential evolution
    result = differential_evolution(
        calibration_objective,
        bounds,
        strategy="best1bin",
        popsize=50,
        mutation=(0.5, 1.0),
        recombination=0.7,
        tol=0.001,
        disp=True
    )

    return result.x, result.fun

# %%
# Inputs
moneyness = np.linspace(0.85, 1.15, 5)
maturities = np.linspace(0.5, 2.0, 7)
r = 0.03

# Observed vols must be flat vector of shape (35,)
observed_vols = np.linspace(0.2, 0.5, 35)

# Run calibration
opt_params, final_loss = calibrate_with_de(loaded_Heston_ANN, moneyness, maturities, r, observed_vols)

print("Optimal Heston parameters:")
print(f"rho={opt_params[0]:.4f}, kappa={opt_params[1]:.4f}, gamma={opt_params[2]:.4f}, "
      f"nu_bar={opt_params[3]:.4f}, nu_0={opt_params[4]:.4f}")
print(f"Final MSE: {final_loss:.6e}")
# Out:
# differential_evolution step 1: f(x)= 0.00392477
# differential_evolution step 2: f(x)= 0.00392477
# differential_evolution step 3: f(x)= 0.00379698
# differential_evolution step 4: f(x)= 0.00376597
# differential_evolution step 5: f(x)= 0.00376597
# differential_evolution step 6: f(x)= 0.00376597
# differential_evolution step 7: f(x)= 0.0036891
# differential_evolution step 8: f(x)= 0.00364717
# differential_evolution step 9: f(x)= 0.00364717
# differential_evolution step 10: f(x)= 0.00364717
# differential_evolution step 11: f(x)= 0.00364717
# differential_evolution step 12: f(x)= 0.00364717
# differential_evolution step 13: f(x)= 0.00364717
# differential_evolution step 14: f(x)= 0.00364717
# differential_evolution step 15: f(x)= 0.00364717
# differential_evolution step 16: f(x)= 0.00364717
# differential_evolution step 17: f(x)= 0.00364717
# differential_evolution step 18: f(x)= 0.0036225
# differential_evolution step 19: f(x)= 0.0036225
# differential_evolution step 20: f(x)= 0.0036225
# differential_evolution step 21: f(x)= 0.0036225
# differential_evolution step 22: f(x)= 0.0036225
# differential_evolution step 23: f(x)= 0.0036225
# differential_evolution step 24: f(x)= 0.0036225
# differential_evolution step 25: f(x)= 0.00362203
# differential_evolution step 26: f(x)= 0.00362061
# differential_evolution step 27: f(x)= 0.00362061
# differential_evolution step 28: f(x)= 0.00361841
# differential_evolution step 29: f(x)= 0.00361841
# differential_evolution step 30: f(x)= 0.00361841
# differential_evolution step 31: f(x)= 0.00361681
# differential_evolution step 32: f(x)= 0.00361562
# differential_evolution step 33: f(x)= 0.00361163
# differential_evolution step 34: f(x)= 0.00361163
# differential_evolution step 35: f(x)= 0.00361021
# differential_evolution step 36: f(x)= 0.00361001
# differential_evolution step 37: f(x)= 0.00361001
# differential_evolution step 38: f(x)= 0.00361001
# differential_evolution step 39: f(x)= 0.0036084
# differential_evolution step 40: f(x)= 0.0036084
# differential_evolution step 41: f(x)= 0.0036084
# differential_evolution step 42: f(x)= 0.0036084
# differential_evolution step 43: f(x)= 0.0036084
# differential_evolution step 44: f(x)= 0.00360806
# differential_evolution step 45: f(x)= 0.00360787
# differential_evolution step 46: f(x)= 0.00360778
# differential_evolution step 47: f(x)= 0.00360765
# Polishing solution with 'L-BFGS-B'
# Optimal Heston parameters:
# rho=-0.1873, kappa=0.1609, gamma=0.2718, nu_bar=0.4995, nu_0=0.5000
# Final MSE: 3.607652e-03

# %%
import numpy as np

# Observed market implied volatilities (target data)

observed_vols = np.linspace(0.2, 0.5, 35)  # Generates 35 equally spaced values

# Moneyness and time-to-maturity of the observed data
moneyness = np.linspace(0.85, 1.15, 5)  # Moneyness
maturities = np.linspace(0.5, 2.0, 7)   # Time to maturity
r = 0.03
#params = 



# Pre-trained ANN that maps Heston parameters to implied volatilities
def heston_ann(parameters):
    """
    A mock function representing the ANN (pre-trained forward pass).
    In real scenarios, this will return ANN-predicted implied volatilities.
    """
    # Example: Simple mapping for illustration
    rho, kappa, gamma, nu_bar, nu_0 = parameters
    return 0.25 + 0.05 * (moneyness - 1.0) + 0.02 * (maturities - 1.0)

# Objective function for DE calibration
def calibration_objective(parameters):
    """
    Calculates the mean squared error between ANN-predicted
    and observed market volatilities.
    """
    predicted_vols = implied_vol_pipe2
    error = np.mean((predicted_vols - observed_vols) ** 2)
    return error

# %%
bounds = [
    (-0.75, -0.25),   # rho (correlation)
    (0.5, 1.0),    # kappa (mean reversion speed)
    (0.3, 0.5),   # gamma (volatility of variance)
    (0.15, 0.35),   # nu_bar (long-run variance)
    (0.5, 1.0)    # nu_0 (initial variance)
]

# %%
from scipy.optimize import differential_evolution

# Run DE to calibrate the Heston parameters
result = differential_evolution(
    calibration_objective,  # Objective function
    bounds,                 # Parameter bounds
    strategy="best1bin",    # Strategy for mutation
    popsize=50,             # Population size
    mutation=(0.5, 1.0),    # Mutation range
    recombination=0.7,      # Crossover probability
    tol=0.01,               # Convergence tolerance
    disp=True               # Display optimization progress
)

# Display calibrated parameters
print("Calibrated Parameters:", result.x)
print("Objective Function Value:", result.fun)

# %%
# Function to calculate implied volatility using Brent's method
def calc_implied_vol(dataset):
    """
    Computes implied volatilities using the Brent method.
    :param dataset: numpy array containing [S/K, T, r, OptionPrice].
    :return: A single implied volatility value.
    """
    money, T, r, market_price = dataset

    def bs_price(sigma):
        """Black-Scholes option price difference function."""
        d1 = (np.log(money) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
        d2 = d1 - sigma * np.sqrt(T)
        theoretical_price = money * norm.cdf(d1) - np.exp(-r * T) * norm.cdf(d2)
        return theoretical_price - market_price

    # Solve for implied volatility
    try:
        return optimize.brentq(bs_price, 1e-5, 5, maxiter=100)
    except ValueError:
        return np.nan  # Return NaN if Brent fails to converge

# Data generation or loading
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds=l_bounds, u_bounds=u_bounds)
hs_data_loader = DataLoader(hs_dataset, batch_size=4048)

# Step 1: Compute prices using Heston-ANN
predicted_prices = []
with torch.no_grad():
    for data in hs_data_loader:
        inputs = data[:, :-1].to(device)  # Exclude the last column if it's labels
        outputs = loaded_Heston_ANN(inputs)
        predicted_prices.append(outputs.cpu().numpy())
predicted_prices = np.concatenate(predicted_prices)

# Step 2: Prepare the dataset for Brent's method
# Combine predicted prices with necessary inputs for implied volatility calculation
# Assuming hs_dataset.data contains [S/K, T, r, actual_price]:
hs_dataset_data = hs_dataset.data[:, np.array([0, 1, 2])]  # Extract relevant columns
hs_dataset_data = np.hstack((hs_dataset_data, predicted_prices.reshape(-1, 1)))

# Step 3: Calculate implied volatilities
implied_volatilities = np.apply_along_axis(calc_implied_vol, 1, hs_dataset_data)

# Step 4: Evaluate results
# Assuming you have ground-truth implied volatilities for comparison
ground_truth_vol = hs_dataset.data[:, 3]  # Replace with actual column for ground truth
mse = ((ground_truth_vol - implied_volatilities) ** 2).mean()
print(f"MSE: {mse:.6e}")

# %%
# Loading Train / Test Data
hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0]-train_size])
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}
train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs, targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs, targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs, targets)) )
print("R2 {:e}".format(r2_score(outputs, targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs, targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs, targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs, targets)) )
print("R2 {:e}".format(r2_score(outputs, targets)) )

# %%
np.sqrt(1.670718e-07)
print("MSE {:e}".format(np.sqrt(1.670718e-07)) )

# %% [markdown]
# # DOWN FROM HERE EVERYTHING IS ONLY FOR LOOK UP PURPOSES

# %% [markdown]
# # 5) BRENT

# %% [markdown]
# # 6) Pipeline 1: COS + BRENT

# %%
eps = 1e-2 # is used to generate open intervals
# (S/K), (tau), (r), (rho), (kappa), (vbar), (gamma), (v0).
# CASE 1 in table 11
l_bounds = [.75+eps, .4+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps]
u_bounds = [1.25-eps, 1.0-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds = l_bounds, u_bounds=u_bounds)
hs_dataset_data = hs_dataset.data
hs_dataset_data = hs_dataset_data[:,np.array([0,1,2,8])]
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, hs_dataset_data)

# %% [markdown]
# # 7) Pipeline 2: Heston-ANN + IV-ANN

# %%
# Loading model
device = torch.device("cuda")
loaded_Heston_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_ANN.pt"
loaded_Heston_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_ANN.eval()

# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

# Loading model 
device = torch.device("cuda")
loaded_IV_ANN = IV_ANN().to(device)
PATH = "ANN_weights/IV_SCALED_ANN.pt"
loaded_IV_ANN.load_state_dict(torch.load(PATH))
loaded_IV_ANN.eval()


# Plugging in the Heston-ANN prices
hs_dataset2 = hs_dataset.data[:,np.array([0,1,2,8])]
hs_dataset2.data[:,3] = torch.FloatTensor(prices)
loader2 = torch.utils.data.DataLoader(hs_dataset2, 4048)

# Computing IVs
implied_vol = []
indecies_list = []
with torch.no_grad():
  for idx, data in enumerate(loader2):
    data = data.to(device)
    # LOG Transformation
    data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
    data[:,3] = torch.log(data[:,3])
    output = loaded_IV_ANN(data)
    implied_vol.append((output).data.cpu().numpy())
  implied_vol_pipe2 = np.concatenate(implied_vol)
  # indecies_list = np.concatenate(indecies_list).flatten()

# %%
# Eliminating Nan values resulting from prices lower than 1e-7
indecies = np.argwhere(np.isnan(implied_vol_pipe2))
implied_vol_pipe1 = np.delete(implied_vol_pipe1, indecies,0)
implied_vol_pipe2 = np.delete(implied_vol_pipe2, indecies,0)

# %% [markdown]
# # 8) Pipeline 1 VS pipeline 2

# %%
# CASE 1
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
#targets = vol_imp
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )

# %%
# CASE 2
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )

# %% [markdown]
# # 9) Volatility surface (COS + IV-ANN)

# %% [markdown]
# ### Initial volatility surface

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
moyeness = np.linspace(moyeness, 1.24,11)
tau = np.linspace(tau, 1, 6)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(66)).reshape((-1, 1))

# %%
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  bs_IV = (output).data.cpu().numpy()

X = X.flatten()
Y = Y.flatten()
Z = bs_IV

x = np.reshape(X, (-1, 6))
y = np.reshape(Y, (-1, 6))
z = np.reshape(Z, (-1, 6))

# %%
from mpl_toolkits import mplot3d
from matplotlib import cm

# %%
# Plotting the initial volatility surface
plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to matuirity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Smoothing the volatility surface

# %%
from scipy import interpolate

# %%
# Smoothing the volatility surface
xnew, ynew = x.copy(), y.copy()
tck = interpolate.bisplrep(x, y, z, s=1.0)
znew = interpolate.bisplev(xnew[:,0], ynew[0,:], tck)

plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(xnew, ynew, znew,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to maturity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Implied volatility difference

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
n_moneyness = 11
n_tau = 6
moyeness = np.linspace(moyeness, 1.24,n_moneyness)
tau = np.linspace(tau, 1, n_tau)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
rho = np.array(rho*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
kappa = np.array(kappa*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
vbar = np.array(vbar*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
gamma = np.array(gamma*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
v0 = np.array(v0*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(n_tau * n_moneyness)).reshape((-1, 1))

# %%
data_ann = np.concatenate((X, Y, r, rho, kappa, vbar, gamma, v0, cos_prices), axis = 1)
data_ann = torch.FloatTensor(data_ann)
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  implied_vol_pipe2 = (output).data.cpu().numpy()

# %%
X = X.flatten()
Y = Y.flatten()
Z = (implied_vol_pipe1 - implied_vol_pipe2).flatten()

x = np.reshape(X, (-1, min(n_moneyness, n_tau)))
y = np.reshape(Y, (-1, min(n_moneyness, n_tau)))
z = np.reshape(Z, (-1, min(n_moneyness, n_tau)))

plt.figure(figsize=(8,8))
plt.pcolormesh(x, y, z, shading='gouraud')
plt.colorbar()
plt.xlabel("Moneyness")
plt.ylabel("Time to maturity")
plt.show()

# %%
# Re-import necessary libraries and re-define the setup after reset
from scipy.optimize import differential_evolution
import numpy as np

# Define the objective function
def objective_function(x):
    # Example: A simple quadratic function
    return x[0]**2 + x[1]**2 + x[2]**2

# Define the bounds for each variable
bounds = [(-10, 10), (-10, 10), (-10, 10)]  # Variable bounds for a 3D problem

# Run Differential Evolution with the specified settings
result_custom_de = differential_evolution(
    objective_function,  # Objective function
    bounds,             # Variable bounds
    strategy="best1bin",  # Strategy
    popsize=50,          # Population size
    mutation=(0.5, 1.0), # Mutation range
    recombination=0.7,   # Crossover probability
    tol=0.01,            # Convergence tolerance
    disp=False           # Suppress output during the run
)

# Display the result
result_custom_de
