# %% [markdown]
# # Financial Model Calibration using ANNs (CaNN, Calibration Neural Network)
#
# ##### from "A neural network-based framework for financial model calibration" ([1])
#
# ### Phases:
#
# ### 1. Forward pass (training, prediction)
# ### 2. Backward pass (calibration)

# %% [markdown]
# # 1) Forward pass

# %% [markdown]
# ## a) Preperation

# %%
# Basic imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# Updating scipy to use module QMC for Latin hypercube sampling
#!pip install scipy==1.7
from scipy.stats import qmc

# Pytorch imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR, LinearLR, OneCycleLR, LambdaLR

from scipy.optimize import differential_evolution

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %%
def bs_price_call(S, K, T, t, r, sigma):
  """
  Black-Scholes call option value price related to PDE (2). Returns option's price.
  S:     spot price
  K:     strike price
  T:     time to maturity
  t:     spot time
  r:     interest rate
  sigma: volatility of underlying asset
  """

  # Boundary condition of Black-Sholes PDE (2)
  if T == t:
    return np.maximum(0, S - K)  
  # Solution of the PDE (2) on the open interval [t, T)
  else : 
    d1 = ( np.log(S / K) + (r + 0.5 * sigma ** 2) * (T-t) ) / (sigma * np.sqrt(T-t))
    d2 = d1 - sigma*np.sqrt(T-t)
    value = S * norm.cdf(d1) - K * np.exp(-r * (T-t)) * norm.cdf(d2) 
  
  return value

def bs_moneyness_call(moneyness, tau, r, sigma):
  """
  Same function as bs_price_call but in terms of moneyness. Returns V/K and 
  has S/K instead of two seperate paremeters S and K.
  moneyness: S/K
  Tau: time to maturity minus spot time
  r: interest rate
  sigma: volatility of underlying asset
  """

  d1 = ( np.log(moneyness) + (r + 0.5 * sigma ** 2) * (tau) ) / (sigma * np.sqrt(tau))
  d2 = d1 - sigma*np.sqrt(tau)
  value_moneyness = moneyness * norm.cdf(d1) - np.exp(-r * (tau)) * norm.cdf(d2) 
  
  return value_moneyness

# %% [markdown]
# ##### Defining class Heston-IV-ANN

# %%
class Heston_ANN(nn.Module):
  def __init__(self):
    """
    Initilize Heston-IV-ANN netwwork with four hidden layers. 
    Same architecture as the one used in Table (2) [1].
    Weight are initialized using Glorot_uniform also known as Xavier_uniform.
    """
    super(Heston_ANN, self).__init__()
    # 4 layers
    self.fc1 = nn.Linear(8, 200)
    self.fc2 = nn.Linear(200, 200)
    self.fc3 = nn.Linear(200, 200)
    self.fc4 = nn.Linear(200, 200)
    self.fc5 = nn.Linear(200, 1)
    # initilizing the layer's weights
    torch.nn.init.xavier_uniform_(self.fc1.weight) 
    torch.nn.init.xavier_uniform_(self.fc2.weight)
    torch.nn.init.xavier_uniform_(self.fc3.weight)
    torch.nn.init.xavier_uniform_(self.fc4.weight)
    torch.nn.init.xavier_uniform_(self.fc5.weight)


  def forward(self, x):
    """
    Foward pass of the network. 
    Relu activations are used and a linear activation is used in the final layer.
    x: input torch tensor (CUDA or CPU)
    """
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = F.relu(self.fc3(x))
    x = F.relu(self.fc4(x))
    x = self.fc5(x)
    return x.flatten()

  def train_model(self, args, device, train_loader, optimizer, epoch):
    """
    Training over train_loader batches for one epoch.
    Returns average training loss.
    args: training parameters.
    device: CUDA or CPU.
    train_loader: train data loader.
    optimizer: gradient descent optmizer.
    epoch: current epoch.
    """
    # train mode
    self.train()
    train_loss = 0
    # loop over data loader
    for batch_idx, data in enumerate(train_loader):
      # extracting the inputs and target
      data, target = data[:,:-1].to(device), data[:,-1].to(device)
      # zeroing the gradients
      optimizer.zero_grad()
      # foward pass
      output = self(data)
      # computing the loss
      loss = F.mse_loss(output, target)
      train_loss += loss.item() * data.shape[0]
      # back propagation
      loss.backward()
      # updating the optimizer step
      optimizer.step()
      # printing batch information
      if batch_idx % args["log_interval"] == 0:
        print('Train Epoch: {} [{}/{} ({:.0f}%)]\tlog Loss: {:.6f}'.format(
            epoch, int(batch_idx / len(train_loader)*len(train_loader.dataset)), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), np.log(loss.item())))
        if args["dry_run"]:
          break
    train_loss /= len(train_loader.dataset)
    print('\nTrain set: Average log loss: {:.4f}\n'.format(np.log(train_loss))) 
    return train_loss


  def test_model(self, device, test_loader):
    """
    Testing over test_loader batches for one epoch. 
    Returns average test loss.
    device: CUDA or CPU.
    test_loader: test data loader.
    """
    # evaluation mode
    self.eval()
    test_loss = 0
    # freezing the gradients
    with torch.no_grad():
      # looping over the test laoder
      for data in test_loader:
        # extracting the inputs and target
        data, target = data[:,:-1].to(device), data[:,-1].to(device)
        # foward pass
        output = self(data)
        #computing the loss
        test_loss += F.mse_loss(output, target, reduction = 'sum').item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}\n'.format(np.log(test_loss))) 
    return test_loss

# %% [markdown]
# ## b) Numerical method for Data generation

# %% [markdown]
# #### COS Method

# %% [markdown]
# #### Vanilla call coefficients

# %% [markdown]
# $\begin{aligned} \chi_{k}(c, d):=& \frac{1}{1+\left(\frac{k \pi}{b-a}\right)^{2}}\left[\cos \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\cos \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right.\\ &\left.+\frac{k \pi}{b-a} \sin \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\frac{k \pi}{b-a} \sin \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right] \end{aligned}$

# %% [markdown]
# $\psi_{k}(c, d):= \begin{cases}{\left[\sin \left(k \pi \frac{d-a}{b-a}\right)-\sin \left(k \pi \frac{c-a}{b-a}\right)\right] \frac{b-a}{k \pi},} & k \neq 0, \\ (d-c), & k=0 .\end{cases}$

# %% [markdown]
# $V_{k}^{\text {call }}=\frac{2}{b-a} K\left(\chi_{k}(0, b)-\psi_{k}(0, b)\right)$

# %%
def call_cosine_coef(a, b, c, d, K, N):
  """
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  K: Strike.
  N: summing lenght.
  Returns V_k coefficient for call option.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*K*(chi_k-psi_k)

# %%
def call_cosine_coef_moy(a, b, c, d, N):
  """
  Moyeness version.
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  N: summing lenght.
  Returns V_k coefficient for call option devided by K.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*(chi_k-psi_k)

# %% [markdown]
# #### Charateristic function for Heston model

# %% [markdown]
# $\begin{aligned} \varphi_{h e s}\left(\omega ; u_{0}\right)=& \exp \left(i \omega \mu \Delta t+\frac{u_{0}}{\eta^{2}}\left(\frac{1-e^{-D \Delta t}}{1-G e^{-D \Delta t}}\right)(\lambda-i \rho \eta \omega-D)\right) \\ & \cdot \exp \left(\frac{\lambda \bar{u}}{\eta^{2}}\left(\Delta t(\lambda-i \rho \eta \omega-D)-2 \log \left(\frac{1-G e^{-D \Delta t}}{1-G}\right)\right)\right) \end{aligned}$

# %% [markdown]
# $D=\sqrt{(\lambda-i \rho \eta \omega)^{2}+\left(\omega^{2}+i \omega\right) \eta^{2}} \quad$ and $\quad G=\frac{\lambda-i \rho \eta \omega-D}{\lambda-i \rho \eta \omega+D} $

# %%
def phi_Heston(a ,b ,N ,r, tau, kappa, gamma, vbar, v0, rho):
  """
  Characteristic function of the log-asset price following the Heston model.
  Section 3.3, equation (33).
  a, b: truncation range parameters.
  N: summing lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns Charateristic function vector.
  """
  #if kappa < 1e-4:
  #  print("kapp < 1e-4")
  #  kappa = 1e-5
  k = np.arange(N).reshape(1,-1)
  u = np.pi*k/(b-a)
  i = complex(0.0,1.0)
  D = np.sqrt((kappa-gamma*rho*i*u)**2+(u**2+i*u)*gamma**2)
  G = (kappa-gamma*rho*i*u-D)/(kappa-gamma*rho*i*u+D)
  C = v0* (1-np.exp(-D*tau)) / (gamma**2*(1-G*np.exp(-D*tau)))*(kappa-gamma*rho*i*u-D)
  A = r*i*u*tau + kappa*vbar/(gamma**2)*(tau*(kappa-gamma*rho*i*u-D) -2*np.log( (1-G*np.exp(-D*tau))/(1-G) )   ) 
  phi = np.exp( A + C )
  return phi

# %% [markdown]
# #### Heston cumulants

# %% [markdown]
# $c_{1}=\mu T+\left(1-e^{-\lambda T}\right) \frac{\bar{u}-u_{0}}{2 \lambda}-\frac{1}{2} \bar{u} T$

# %% [markdown]
# $\begin{aligned} c_{2}=& \frac{1}{8 \lambda^{3}}\left(\eta T \lambda e^{-\lambda T}\left(u_{0}-\bar{u}\right)(8 \lambda \rho-4 \eta)\right.\\ &+\lambda \rho \eta\left(1-e^{-\lambda T}\right)\left(16 \bar{u}-8 u_{0}\right) \\ &+2 \bar{u} \lambda T\left(-4 \lambda \rho \eta+\eta^{2}+4 \lambda^{2}\right) \\ &+\eta^{2}\left(\left(\bar{u}-2 u_{0}\right) e^{-2 \lambda T}+\bar{u}\left(6 e^{-\lambda T}-7\right)+2 u_{0}\right) \\ &\left.+8 \lambda^{2}\left(u_{0}-\bar{u}\right)\left(1-e^{-\lambda T}\right)\right) \end{aligned}$

# %%
def Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho ):
  """
  Computes Heston cumulants as defined in the appendix A for the Heston model.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns cumulants c1 and c2.
  """

  #if kappa == 0:
  #  c1 = r * tau + tau * (vbar - v0) / 2 - 0.5 * vbar * tau
  #else: 
  #   c1 = r * tau + (1 - np.exp(- kappa * tau)) * (vbar - v0) / (2 * kappa) - 0.5 * vbar * tau
  
  c1 = r * tau + (1 - np.exp(- kappa * tau)) * (vbar - v0) / (2 * kappa) - 0.5 * vbar * tau


  #safe_kappa = np.max(kappa, 1e-5)
  safe_kappa = kappa
  c2 = 0.125 / safe_kappa ** 3 * (gamma * tau * np.exp(- safe_kappa * tau) * (v0 - vbar) * (8 * safe_kappa * rho - 4 * gamma) + \
     safe_kappa * rho * gamma * (1 - np.exp(- safe_kappa * tau)) * (16 * vbar - 8 * v0) + \
     2 * vbar * safe_kappa * tau * (- 4 * safe_kappa * rho * gamma + gamma ** 2 + 4 * safe_kappa ** 2) + \
     gamma ** 2 * ((vbar - 2 * v0) * np.exp(-2 * safe_kappa * tau) + vbar * (6 * np.exp(- safe_kappa * tau) - 7) + 2 * v0) + \
     8 * safe_kappa ** 2 * (v0 - vbar) * (1 - np.exp(-safe_kappa * tau)))
  return c1, c2

# %% [markdown]
# #### Truncation range

# %% [markdown]
# $[a, b]:=\left[c_{1}-L \sqrt{c_{2}+\sqrt{c_{4}}}, \quad c_{1}+L \sqrt{c_{2}+\sqrt{c_{4}}}\right]$

# %%
def Truncation_range(c1, c2, c4, L):
  """
  Computes the truncation range given the cumulants c1, c2, c4 and the truncation lenght L.
  c1, c2, c4: Model cumulants.
  L: truncation lenght.
  Returns tuncation interval sup b and inf a.
  """
  a = c1 - L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) )
  b = c1 + L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) ) 
  return a, b

# %% [markdown]
# #### Exponential coefficient

# %% [markdown]
# $e^{i k \pi \frac{\mathbf{x}-a}{b-a}}$

# %%
def exponential_coef(a, b, N, S0, K):
  """
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  S0: asset initial price.
  K: strike.
  Returns the exponential coefficient vector.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(S0/K)-a)/(b-a))

# %%
def exponential_coef_moy(a, b, N, moyeness):
  """
  Moyeness version.
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  moyeness: S/K.
  Returns the exponential coefficient vector devided by K.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(moyeness)-a)/(b-a))

# %% [markdown]
# #### Vanilla call price

# %% [markdown]
# $v\left(\mathbf{x}, t_{0}, u_{0}\right) \approx \mathbf{K} e^{-r \Delta t} \cdot \operatorname{Re}\left\{\sum_{k=0}^{N-1} \varphi_{h e s}\left(\frac{k \pi}{b-a} ; u_{0}\right) U_{k} \cdot e^{i k \pi \frac{\mathbf{x}-a}{b-a}}\right\}$

# %%
def call_option_Heston(N, L, r, tau, kappa, gamma, vbar, v0, rho, K, S0 ):
  """
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  S0: asset initial price.
  K: strike.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef(a, b, c, d, K, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef(a, b, N, S0, K)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, K = K, S0 = S0)
# Out:
# True
# array([[29.79261082]])

# %%
def call_option_Heston_moy(N, L, r, tau, kappa, gamma, vbar, v0, rho, moyeness ):
  """
  Moyeness version.
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  moyeness: S/K.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef_moy(a, b, c, d, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef_moy(a, b, N, moyeness)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston_moy(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = 1)
# Out:
# True
# array([[0.29792611]])

# %% [markdown]
# # Latin Hypercube Sampling

# %% [markdown]
# ### Generating Data

# %% [markdown]
# #### Sampling range for the Heston parameters (Table (3) in [1])

# %%
# here Table (3) of [1] is used, kappa is numerically sensitive to small values
eps = 1e-2 # is used to generate open intervals
def Heston_LHS_data_generator(n = 10**6, l_bounds = [.6+eps, .05+eps, .0+eps, -0.9+eps, 0.4+eps, .01+eps, .01+eps, .05+eps], u_bounds = [1.4-eps, 3.0-eps, .05-eps, 0.0-eps, 3.0-eps, .5-eps, .8-eps, .5-eps]):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,9) containig the inputs samples and the value of the call.
  The inputs are: Moyeness (S/K), time to maturity (tau), Risk free rate (r), Correlation (rho), reversion speed (kappa), Long average variance (vbar), Vol of vol (gamma), Initial variance (v0).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.
  """
  sampler = qmc.LatinHypercube(d = 8) #, seed = 0
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  indecies = np.argwhere(2*sample[:,4]*sample[:,5] <= sample[:,6]**2)
  sample = np.delete(sample, indecies, 0)
  hs_prices = call_option_Heston_moy(N = 160, L= 12, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa = sample[:,4].reshape((-1,1)),\
                                     gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
                                     rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  #hs_prices = call_option_Heston_moy(N = 1500, L= 50, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
  #                                    gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
  #                                    rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))

  # hs_dataset = np.concatenate((sample, hs_prices),axis=1)

  # print("------ INPUT ------")
  # print("S/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,0]), max(hs_dataset[:,0])))
  # print("Tau.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,1]), max(hs_dataset[:,1])))
  # print("r............ [{:.2f} {:.2f}]".format(min(hs_dataset[:,2]), max(hs_dataset[:,2])))
  # print("Corr ........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,3]), max(hs_dataset[:,3])))
  # print("Kappa........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,4]), max(hs_dataset[:,4])))
  # print("V_bar........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,5]), max(hs_dataset[:,5])))
  # print("Gamma........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,6]), max(hs_dataset[:,6])))
  # print("V_0 ......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,7]), max(hs_dataset[:,7])))
  # print("------ OUTPUT ------")
  # print("V/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,-1]), max(hs_dataset[:,-1])))
  # ind_max = np.argmax(hs_dataset[:,-1])
  # print(hs_dataset[ind_max,:])

  #return torch.FloatTensor(hs_dataset)
  return sample, hs_prices


hs_dataset = Heston_LHS_data_generator(10**4)

# %% [markdown]
# ## c) Training Heston-ANN

# %%
from scipy import optimize

def calcimpliedvol(dataset):
    """
    Computes the implied volatilities using the brent method.
    dataset: numpy array containing moneyness, time to maturity, risk free interest rate and V/K.
    Returns a vector of implied volatilities.
    """
    money = np.array(dataset[0])
    T = np.array(dataset[1])
    r = np.array(dataset[2])
    marketoptionPrice = np.array(dataset[3])
    def bs_price(sigma):
      d1 = ( np.log(money) + (r + 0.5 * sigma ** 2) * (T) ) / (sigma * np.sqrt(T))
      d2 = d1 - sigma*np.sqrt(T)
      value_moyeness = money * norm.cdf(d1) - np.exp(-r * (T)) * norm.cdf(d2) 
      fx = value_moyeness - marketoptionPrice
      return fx
    return optimize.brentq(bs_price, -1, 1, maxiter=100)

# %%
sample, hs_prices = Heston_LHS_data_generator(n = 10**5)
# Convert to NumPy for processing
sample_np = sample
hs_prices_np = hs_prices

# Combine required inputs for Brent
brent_input = np.concatenate([sample_np[:, [0, 1, 2]], hs_prices_np], axis=1)  # shape (n, 4)

# Apply Brent row by row
implied_vols = np.array([
    calcimpliedvol(row) for row in brent_input
])

# Filter out NaNs
valid_idx = ~np.isnan(implied_vols)
sample_np = sample_np[valid_idx]
implied_vols = implied_vols[valid_idx]

# Recombine into final dataset (input + IV target)
final_dataset = np.concatenate([sample_np, implied_vols.reshape(-1, 1)], axis=1)

# Convert to torch Tensor
hs_dataset = torch.FloatTensor(final_dataset)

# %%
# Training parameters
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 8*10**3,
         "lr": 1e-4,
         "gamma": .5,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}


use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# torch.manual_seed(args["seed"])

# Loading Train / Test Data
#hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0] - train_size])

train_loader = torch.utils.data.DataLoader(train_dataset, args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])


# Model training
print(device)
model = Heston_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=args["lr"]) # Adam is found to be the best optimizer in the article
scheduler = StepLR(optimizer, step_size=500, gamma=args["gamma"]) # Deacreses the Learning rate by .5 every 500 epoch

train_losses = []
test_losses = []
for epoch in range(1, args["epochs"] + 1):
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  #print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
if args["save_model"] :
  torch.save(model.state_dict(), "Heston_ANN_DE.pt")
# Out:
# cuda
# Train Epoch: 1 [0/77445 (0%)]	log Loss: -0.642841
#
# Train set: Average log loss: -2.8418
#
#
# Test set: Average loss: -4.8780
#
# Train Epoch: 2 [0/77445 (0%)]	log Loss: -4.909300
#
# Train set: Average log loss: -5.3104
#
#
# Test set: Average loss: -6.1461
#
# Train Epoch: 3 [0/77445 (0%)]	log Loss: -6.135165
#
# Train set: Average log loss: -6.7171
#
#
# Test set: Average loss: -7.2186
#
# Train Epoch: 4 [0/77445 (0%)]	log Loss: -7.191794
#
# Train set: Average log loss: -7.5314
#
#
# Test set: Average loss: -7.8901
#
# Train Epoch: 5 [0/77445 (0%)]	log Loss: -7.911013
#
# Train set: Average log loss: -8.1061
#
#
# Test set: Average loss: -8.3391
#
# Train Epoch: 6 [0/77445 (0%)]	log Loss: -8.380858
#
# Train set: Average log loss: -8.4584
#
#
# Test set: Average loss: -8.6142
#
# Train Epoch: 7 [0/77445 (0%)]	log Loss: -8.658600
#
# Train set: Average log loss: -8.7102
#
#
# Test set: Average loss: -8.8480
#
# Train Epoch: 8 [0/77445 (0%)]	log Loss: -8.881384
#
# Train set: Average log loss: -8.9259
#
#
# Test set: Average loss: -9.0469
#
# Train Epoch: 9 [0/77445 (0%)]	log Loss: -9.067212
#
# Train set: Average log loss: -9.1110
#
#
# Test set: Average loss: -9.2247
#
# Train Epoch: 10 [0/77445 (0%)]	log Loss: -9.245072
#
# Train set: Average log loss: -9.2727
#
#
# Test set: Average loss: -9.3743
#
# Train Epoch: 11 [0/77445 (0%)]	log Loss: -9.392815
#
# Train set: Average log loss: -9.4125
#
#
# Test set: Average loss: -9.4973
#
# Train Epoch: 12 [0/77445 (0%)]	log Loss: -9.515970
#
# Train set: Average log loss: -9.5335
#
#
# Test set: Average loss: -9.6006
#
# Train Epoch: 13 [0/77445 (0%)]	log Loss: -9.620238
#
# Train set: Average log loss: -9.6431
#
#
# Test set: Average loss: -9.6964
#
# Train Epoch: 14 [0/77445 (0%)]	log Loss: -9.711003
#
# Train set: Average log loss: -9.7423
#
#
# Test set: Average loss: -9.7848
#
# Train Epoch: 15 [0/77445 (0%)]	log Loss: -9.787076
#
# Train set: Average log loss: -9.8322
#
#
# Test set: Average loss: -9.8568
#
# Train Epoch: 16 [0/77445 (0%)]	log Loss: -9.855779
#
# Train set: Average log loss: -9.9174
#
#
# Test set: Average loss: -9.9324
#
# Train Epoch: 17 [0/77445 (0%)]	log Loss: -9.930169
#
# Train set: Average log loss: -9.9976
#
#
# Test set: Average loss: -10.0207
#
# Train Epoch: 18 [0/77445 (0%)]	log Loss: -10.015867
#
# Train set: Average log loss: -10.0748
#
#
# Test set: Average loss: -10.0959
#
# Train Epoch: 19 [0/77445 (0%)]	log Loss: -10.090068
#
# Train set: Average log loss: -10.1375
#
#
# Test set: Average loss: -10.1508
#
# Train Epoch: 20 [0/77445 (0%)]	log Loss: -10.149124
#
# Train set: Average log loss: -10.1918
#
#
# Test set: Average loss: -10.2036
#
# Train Epoch: 21 [0/77445 (0%)]	log Loss: -10.206892
#
# Train set: Average log loss: -10.2421
#
#
# Test set: Average loss: -10.2456
#
# Train Epoch: 22 [0/77445 (0%)]	log Loss: -10.254457
#
# Train set: Average log loss: -10.2913
#
#
# Test set: Average loss: -10.2684
#
# Train Epoch: 23 [0/77445 (0%)]	log Loss: -10.279739
#
# Train set: Average log loss: -10.3376
#
#
# Test set: Average loss: -10.2710
#
# Train Epoch: 24 [0/77445 (0%)]	log Loss: -10.282374
#
# Train set: Average log loss: -10.3785
#
#
# Test set: Average loss: -10.2704
#
# Train Epoch: 25 [0/77445 (0%)]	log Loss: -10.278118
#
# Train set: Average log loss: -10.4163
#
#
# Test set: Average loss: -10.2863
#
# Train Epoch: 26 [0/77445 (0%)]	log Loss: -10.292145
#
# Train set: Average log loss: -10.4577
#
#
# Test set: Average loss: -10.3508
#
# Train Epoch: 27 [0/77445 (0%)]	log Loss: -10.356409
#
# Train set: Average log loss: -10.4987
#
#
# Test set: Average loss: -10.4374
#
# Train Epoch: 28 [0/77445 (0%)]	log Loss: -10.442527
#
# Train set: Average log loss: -10.5334
#
#
# Test set: Average loss: -10.5181
#
# Train Epoch: 29 [0/77445 (0%)]	log Loss: -10.522695
#
# Train set: Average log loss: -10.5635
#
#
# Test set: Average loss: -10.5825
#
# Train Epoch: 30 [0/77445 (0%)]	log Loss: -10.587206
#
# Train set: Average log loss: -10.5929
#
#
# Test set: Average loss: -10.6248
#
# Train Epoch: 31 [0/77445 (0%)]	log Loss: -10.629007
#
# Train set: Average log loss: -10.6206
#
#
# Test set: Average loss: -10.6545
#
# Train Epoch: 32 [0/77445 (0%)]	log Loss: -10.660983
#
# Train set: Average log loss: -10.6440
#
#
# Test set: Average loss: -10.6756
#
# Train Epoch: 33 [0/77445 (0%)]	log Loss: -10.683218
#
# Train set: Average log loss: -10.6654
#
#
# Test set: Average loss: -10.6895
#
# Train Epoch: 34 [0/77445 (0%)]	log Loss: -10.698297
#
# Train set: Average log loss: -10.6870
#
#
# Test set: Average loss: -10.7029
#
# Train Epoch: 35 [0/77445 (0%)]	log Loss: -10.713969
#
# Train set: Average log loss: -10.7098
#
#
# Test set: Average loss: -10.7121
#
# Train Epoch: 36 [0/77445 (0%)]	log Loss: -10.723489
#
# Train set: Average log loss: -10.7311
#
#
# Test set: Average loss: -10.7199
#
# Train Epoch: 37 [0/77445 (0%)]	log Loss: -10.732159
#
# Train set: Average log loss: -10.7535
#
#
# Test set: Average loss: -10.7254
#
# Train Epoch: 38 [0/77445 (0%)]	log Loss: -10.739495
#
# Train set: Average log loss: -10.7790
#
#
# Test set: Average loss: -10.7314
#
# Train Epoch: 39 [0/77445 (0%)]	log Loss: -10.747083
#
# Train set: Average log loss: -10.8080
#
#
# Test set: Average loss: -10.7479
#
# Train Epoch: 40 [0/77445 (0%)]	log Loss: -10.766159
#
# Train set: Average log loss: -10.8428
#
#
# Test set: Average loss: -10.7847
#
# Train Epoch: 41 [0/77445 (0%)]	log Loss: -10.803544
#
# Train set: Average log loss: -10.8790
#
#
# Test set: Average loss: -10.8422
#
# Train Epoch: 42 [0/77445 (0%)]	log Loss: -10.859484
#
# Train set: Average log loss: -10.9057
#
#
# Test set: Average loss: -10.9075
#
# Train Epoch: 43 [0/77445 (0%)]	log Loss: -10.920893
#
# Train set: Average log loss: -10.9226
#
#
# Test set: Average loss: -10.9552
#
# Train Epoch: 44 [0/77445 (0%)]	log Loss: -10.962807
#
# Train set: Average log loss: -10.9346
#
#
# Test set: Average loss: -10.9782
#
# Train Epoch: 45 [0/77445 (0%)]	log Loss: -10.985327
#
# Train set: Average log loss: -10.9479
#
#
# Test set: Average loss: -10.9903
#
# Train Epoch: 46 [0/77445 (0%)]	log Loss: -11.002466
#
# Train set: Average log loss: -10.9573
#
#
# Test set: Average loss: -10.9702
#
# Train Epoch: 47 [0/77445 (0%)]	log Loss: -10.988892
#
# Train set: Average log loss: -10.9640
#
#
# Test set: Average loss: -10.9306
#
# Train Epoch: 48 [0/77445 (0%)]	log Loss: -10.958437
#
# Train set: Average log loss: -10.9763
#
#
# Test set: Average loss: -10.8867
#
# Train Epoch: 49 [0/77445 (0%)]	log Loss: -10.919634
#
# Train set: Average log loss: -10.9944
#
#
# Test set: Average loss: -10.8500
#
# Train Epoch: 50 [0/77445 (0%)]	log Loss: -10.888149
#
# Train set: Average log loss: -11.0168
#
#
# Test set: Average loss: -10.8596
#
# Train Epoch: 51 [0/77445 (0%)]	log Loss: -10.901549
#
# Train set: Average log loss: -11.0410
#
#
# Test set: Average loss: -10.9500
#
# Train Epoch: 52 [0/77445 (0%)]	log Loss: -10.988962
#
# Train set: Average log loss: -11.0590
#
#
# Test set: Average loss: -11.0592
#
# Train Epoch: 53 [0/77445 (0%)]	log Loss: -11.093336
#
# Train set: Average log loss: -11.0740
#
#
# Test set: Average loss: -11.1258
#
# Train Epoch: 54 [0/77445 (0%)]	log Loss: -11.152137
#
# Train set: Average log loss: -11.0881
#
#
# Test set: Average loss: -11.1504
#
# Train Epoch: 55 [0/77445 (0%)]	log Loss: -11.170536
#
# Train set: Average log loss: -11.0990
#
#
# Test set: Average loss: -11.1206
#
# Train Epoch: 56 [0/77445 (0%)]	log Loss: -11.132106
#
# Train set: Average log loss: -11.1150
#
#
# Test set: Average loss: -11.0330
#
# Train Epoch: 57 [0/77445 (0%)]	log Loss: -11.036214
#
# Train set: Average log loss: -11.1376
#
#
# Test set: Average loss: -10.9921
#
# Train Epoch: 58 [0/77445 (0%)]	log Loss: -10.994124
#
# Train set: Average log loss: -11.1551
#
#
# Test set: Average loss: -11.0723
#
# Train Epoch: 59 [0/77445 (0%)]	log Loss: -11.076031
#
# Train set: Average log loss: -11.1930
#
#
# Test set: Average loss: -11.2156
#
# Train Epoch: 60 [0/77445 (0%)]	log Loss: -11.230010
#
# Train set: Average log loss: -11.2397
#
#
# Test set: Average loss: -11.2446
#
# Train Epoch: 61 [0/77445 (0%)]	log Loss: -11.266165
#
# Train set: Average log loss: -11.2688
#
#
# Test set: Average loss: -11.2596
#
# Train Epoch: 62 [0/77445 (0%)]	log Loss: -11.282040
#
# Train set: Average log loss: -11.2807
#
#
# Test set: Average loss: -11.2072
#
# Train Epoch: 63 [0/77445 (0%)]	log Loss: -11.220612
#
# Train set: Average log loss: -11.2537
#
#
# Test set: Average loss: -11.2698
#
# Train Epoch: 64 [0/77445 (0%)]	log Loss: -11.287180
#
# Train set: Average log loss: -11.2180
#
#
# Test set: Average loss: -11.2793
#
# Train Epoch: 65 [0/77445 (0%)]	log Loss: -11.295848
#
# Train set: Average log loss: -11.2236
#
#
# Test set: Average loss: -11.2998
#
# Train Epoch: 66 [0/77445 (0%)]	log Loss: -11.316370
#
# Train set: Average log loss: -11.2339
#
#
# Test set: Average loss: -11.3116
#
# Train Epoch: 67 [0/77445 (0%)]	log Loss: -11.326630
#
# Train set: Average log loss: -11.2404
#
#
# Test set: Average loss: -11.3176
#
# Train Epoch: 68 [0/77445 (0%)]	log Loss: -11.331530
#
# Train set: Average log loss: -11.2479
#
#
# Test set: Average loss: -11.3294
#
# Train Epoch: 69 [0/77445 (0%)]	log Loss: -11.345853
#
# Train set: Average log loss: -11.2534
#
#
# Test set: Average loss: -11.3670
#
# Train Epoch: 70 [0/77445 (0%)]	log Loss: -11.386345
#
# Train set: Average log loss: -11.2603
#
#
# Test set: Average loss: -11.3908
#
# Train Epoch: 71 [0/77445 (0%)]	log Loss: -11.414312
#
# Train set: Average log loss: -11.2672
#
#
# Test set: Average loss: -11.4002
#
# Train Epoch: 72 [0/77445 (0%)]	log Loss: -11.428113
#
# Train set: Average log loss: -11.2785
#
#
# Test set: Average loss: -11.4054
#
# Train Epoch: 73 [0/77445 (0%)]	log Loss: -11.435200
#
# Train set: Average log loss: -11.2909
#
#
# Test set: Average loss: -11.4237
#
# Train Epoch: 74 [0/77445 (0%)]	log Loss: -11.452690
#
# Train set: Average log loss: -11.3077
#
#
# Test set: Average loss: -11.4464
#
# Train Epoch: 75 [0/77445 (0%)]	log Loss: -11.470918
#
# Train set: Average log loss: -11.3127
#
#
# Test set: Average loss: -11.4531
#
# Train Epoch: 76 [0/77445 (0%)]	log Loss: -11.474161
#
# Train set: Average log loss: -11.3251
#
#
# Test set: Average loss: -11.4418
#
# Train Epoch: 77 [0/77445 (0%)]	log Loss: -11.460373
#
# Train set: Average log loss: -11.3400
#
#
# Test set: Average loss: -11.4206
#
# Train Epoch: 78 [0/77445 (0%)]	log Loss: -11.437856
#
# Train set: Average log loss: -11.3372
#
#
# Test set: Average loss: -11.4264
#
# Train Epoch: 79 [0/77445 (0%)]	log Loss: -11.443044
#
# Train set: Average log loss: -11.2898
#
#
# Test set: Average loss: -11.4748
#
# Train Epoch: 80 [0/77445 (0%)]	log Loss: -11.495705
#
# Train set: Average log loss: -11.0310
#
#
# Test set: Average loss: -11.2386
#
# Train Epoch: 81 [0/77445 (0%)]	log Loss: -11.246298
#
# Train set: Average log loss: -11.3063
#
#
# Test set: Average loss: -11.4049
#
# Train Epoch: 82 [0/77445 (0%)]	log Loss: -11.444186
#
# Train set: Average log loss: -11.3499
#
#
# Test set: Average loss: -11.4678
#
# Train Epoch: 83 [0/77445 (0%)]	log Loss: -11.507965
#
# Train set: Average log loss: -11.3843
#
#
# Test set: Average loss: -11.5408
#
# Train Epoch: 84 [0/77445 (0%)]	log Loss: -11.568902
#
# Train set: Average log loss: -11.4266
#
#
# Test set: Average loss: -11.3662
#
# Train Epoch: 85 [0/77445 (0%)]	log Loss: -11.381481
#
# Train set: Average log loss: -11.4781
#
#
# Test set: Average loss: -11.5494
#
# Train Epoch: 86 [0/77445 (0%)]	log Loss: -11.581185
#
# Train set: Average log loss: -11.5253
#
#
# Test set: Average loss: -11.4229
#
# Train Epoch: 87 [0/77445 (0%)]	log Loss: -11.439294
#
# Train set: Average log loss: -11.4129
#
#
# Test set: Average loss: -11.5819
#
# Train Epoch: 88 [0/77445 (0%)]	log Loss: -11.612411
#
# Train set: Average log loss: -11.1831
#
#
# Test set: Average loss: -11.4248
#
# Train Epoch: 89 [0/77445 (0%)]	log Loss: -11.452133
#
# Train set: Average log loss: -11.5276
#
#
# Test set: Average loss: -11.6105
#
# Train Epoch: 90 [0/77445 (0%)]	log Loss: -11.644871
#
# Train set: Average log loss: -11.3836
#
#
# Test set: Average loss: -11.5487
#
# Train Epoch: 91 [0/77445 (0%)]	log Loss: -11.574781
#
# Train set: Average log loss: -11.4562
#
#
# Test set: Average loss: -11.4426
#
# Train Epoch: 92 [0/77445 (0%)]	log Loss: -11.468840
#
# Train set: Average log loss: -11.3614
#
#
# Test set: Average loss: -11.5422
#
# Train Epoch: 93 [0/77445 (0%)]	log Loss: -11.590204
#
# Train set: Average log loss: -11.5034
#
#
# Test set: Average loss: -11.5887
#
# Train Epoch: 94 [0/77445 (0%)]	log Loss: -11.651017
#
# Train set: Average log loss: -11.4362
#
#
# Test set: Average loss: -11.6377
#
# Train Epoch: 95 [0/77445 (0%)]	log Loss: -11.702524
#
# Train set: Average log loss: -11.0721
#
#
# Test set: Average loss: -11.2374
#
# Train Epoch: 96 [0/77445 (0%)]	log Loss: -11.261474
#
# Train set: Average log loss: -11.3348
#
#
# Test set: Average loss: -11.1368
#
# Train Epoch: 97 [0/77445 (0%)]	log Loss: -11.200839
#
# Train set: Average log loss: -11.3505
#
#
# Test set: Average loss: -10.9378
#
# Train Epoch: 98 [0/77445 (0%)]	log Loss: -10.996257
#
# Train set: Average log loss: -11.4608
#
#
# Test set: Average loss: -11.0038
#
# Train Epoch: 99 [0/77445 (0%)]	log Loss: -11.066868
#
# Train set: Average log loss: -11.4766
#
#
# Test set: Average loss: -11.1389
#
# Train Epoch: 100 [0/77445 (0%)]	log Loss: -11.209226
#
# Train set: Average log loss: -11.4987
#
#
# Test set: Average loss: -11.5020
#
# Train Epoch: 101 [0/77445 (0%)]	log Loss: -11.581306
#
# Train set: Average log loss: -11.5735
#
#
# Test set: Average loss: -11.6437
#
# Train Epoch: 102 [0/77445 (0%)]	log Loss: -11.694510
#
# Train set: Average log loss: -11.6853
#
#
# Test set: Average loss: -11.7202
#
# Train Epoch: 103 [0/77445 (0%)]	log Loss: -11.796680
#
# Train set: Average log loss: -11.5592
#
#
# Test set: Average loss: -11.5521
#
# Train Epoch: 104 [0/77445 (0%)]	log Loss: -11.582712
#
# Train set: Average log loss: -11.5547
#
#
# Test set: Average loss: -11.1690
#
# Train Epoch: 105 [0/77445 (0%)]	log Loss: -11.196359
#
# Train set: Average log loss: -11.4670
#
#
# Test set: Average loss: -11.6253
#
# Train Epoch: 106 [0/77445 (0%)]	log Loss: -11.659842
#
# Train set: Average log loss: -11.2310
#
#
# Test set: Average loss: -11.3513
#
# Train Epoch: 107 [0/77445 (0%)]	log Loss: -11.386033
#
# Train set: Average log loss: -11.5342
#
#
# Test set: Average loss: -11.2851
#
# Train Epoch: 108 [0/77445 (0%)]	log Loss: -11.319928
#
# Train set: Average log loss: -11.5886
#
#
# Test set: Average loss: -11.5572
#
# Train Epoch: 109 [0/77445 (0%)]	log Loss: -11.610865
#
# Train set: Average log loss: -11.7083
#
#
# Test set: Average loss: -11.7809
#
# Train Epoch: 110 [0/77445 (0%)]	log Loss: -11.860476
#
# Train set: Average log loss: -11.5994
#
#
# Test set: Average loss: -11.7162
#
# Train Epoch: 111 [0/77445 (0%)]	log Loss: -11.796832
#
# Train set: Average log loss: -11.0249
#
#
# Test set: Average loss: -10.9716
#
# Train Epoch: 112 [0/77445 (0%)]	log Loss: -11.039690
#
# Train set: Average log loss: -11.4484
#
#
# Test set: Average loss: -10.8420
#
# Train Epoch: 113 [0/77445 (0%)]	log Loss: -10.906240
#
# Train set: Average log loss: -11.5551
#
#
# Test set: Average loss: -10.9147
#
# Train Epoch: 114 [0/77445 (0%)]	log Loss: -10.983986
#
# Train set: Average log loss: -11.5763
#
#
# Test set: Average loss: -11.0837
#
# Train Epoch: 115 [0/77445 (0%)]	log Loss: -11.160994
#
# Train set: Average log loss: -11.6203
#
#
# Test set: Average loss: -11.6273
#
# Train Epoch: 116 [0/77445 (0%)]	log Loss: -11.722510
#
# Train set: Average log loss: -11.7078
#
#
# Test set: Average loss: -11.7090
#
# Train Epoch: 117 [0/77445 (0%)]	log Loss: -11.766372
#
# Train set: Average log loss: -11.8367
#
#
# Test set: Average loss: -11.8466
#
# Train Epoch: 118 [0/77445 (0%)]	log Loss: -11.927260
#
# Train set: Average log loss: -11.5080
#
#
# Test set: Average loss: -11.8435
#
# Train Epoch: 119 [0/77445 (0%)]	log Loss: -11.931766
#
# Train set: Average log loss: -11.7513
#
#
# Test set: Average loss: -11.8241
#
# Train Epoch: 120 [0/77445 (0%)]	log Loss: -11.919271
#
# Train set: Average log loss: -11.0226
#
#
# Test set: Average loss: -10.7268
#
# Train Epoch: 121 [0/77445 (0%)]	log Loss: -10.787094
#
# Train set: Average log loss: -11.6503
#
#
# Test set: Average loss: -11.0842
#
# Train Epoch: 122 [0/77445 (0%)]	log Loss: -11.164525
#
# Train set: Average log loss: -11.6961
#
#
# Test set: Average loss: -11.6431
#
# Train Epoch: 123 [0/77445 (0%)]	log Loss: -11.743632
#
# Train set: Average log loss: -11.7929
#
#
# Test set: Average loss: -11.8185
#
# Train Epoch: 124 [0/77445 (0%)]	log Loss: -11.891983
#
# Train set: Average log loss: -11.8739
#
#
# Test set: Average loss: -11.8883
#
# Train Epoch: 125 [0/77445 (0%)]	log Loss: -11.981104
#
# Train set: Average log loss: -11.3171
#
#
# Test set: Average loss: -11.8221
#
# Train Epoch: 126 [0/77445 (0%)]	log Loss: -11.890286
#
# Train set: Average log loss: -11.7359
#
#
# Test set: Average loss: -11.8666
#
# Train Epoch: 127 [0/77445 (0%)]	log Loss: -11.946552
#
# Train set: Average log loss: -11.8836
#
#
# Test set: Average loss: -11.8317
#
# Train Epoch: 128 [0/77445 (0%)]	log Loss: -11.934839
#
# Train set: Average log loss: -11.2577
#
#
# Test set: Average loss: -11.8854
#
# Train Epoch: 129 [0/77445 (0%)]	log Loss: -11.981122
#
# Train set: Average log loss: -11.8111
#
#
# Test set: Average loss: -11.7820
#
# Train Epoch: 130 [0/77445 (0%)]	log Loss: -11.843245
#
# Train set: Average log loss: -11.8762
#
#
# Test set: Average loss: -11.5503
#
# Train Epoch: 131 [0/77445 (0%)]	log Loss: -11.658919
#
# Train set: Average log loss: -11.3787
#
#
# Test set: Average loss: -11.7992
#
# Train Epoch: 132 [0/77445 (0%)]	log Loss: -11.859754
#
# Train set: Average log loss: -11.8338
#
#
# Test set: Average loss: -11.9571
#
# Train Epoch: 133 [0/77445 (0%)]	log Loss: -12.056796
#
# Train set: Average log loss: -11.7068
#
#
# Test set: Average loss: -11.8310
#
# Train Epoch: 134 [0/77445 (0%)]	log Loss: -11.942971
#
# Train set: Average log loss: -11.4050
#
#
# Test set: Average loss: -11.9598
#
# Train Epoch: 135 [0/77445 (0%)]	log Loss: -12.040211
#
# Train set: Average log loss: -11.7564
#
#
# Test set: Average loss: -11.9066
#
# Train Epoch: 136 [0/77445 (0%)]	log Loss: -11.991370
#
# Train set: Average log loss: -11.9560
#
#
# Test set: Average loss: -11.8749
#
# Train Epoch: 137 [0/77445 (0%)]	log Loss: -11.991278
#
# Train set: Average log loss: -11.2806
#
#
# Test set: Average loss: -11.9620
#
# Train Epoch: 138 [0/77445 (0%)]	log Loss: -12.055881
#
# Train set: Average log loss: -11.7412
#
#
# Test set: Average loss: -11.9664
#
# Train Epoch: 139 [0/77445 (0%)]	log Loss: -12.053219
#
# Train set: Average log loss: -11.8527
#
#
# Test set: Average loss: -11.9049
#
# Train Epoch: 140 [0/77445 (0%)]	log Loss: -11.986777
#
# Train set: Average log loss: -11.8635
#
#
# Test set: Average loss: -11.9780
#
# Train Epoch: 141 [0/77445 (0%)]	log Loss: -12.077365
#
# Train set: Average log loss: -11.5088
#
#
# Test set: Average loss: -11.9675
#
# Train Epoch: 142 [0/77445 (0%)]	log Loss: -12.047194
#
# Train set: Average log loss: -11.8455
#
#
# Test set: Average loss: -12.0168
#
# Train Epoch: 143 [0/77445 (0%)]	log Loss: -12.126701
#
# Train set: Average log loss: -11.3563
#
#
# Test set: Average loss: -11.9582
#
# Train Epoch: 144 [0/77445 (0%)]	log Loss: -12.070911
#
# Train set: Average log loss: -11.6629
#
#
# Test set: Average loss: -11.2494
#
# Train Epoch: 145 [0/77445 (0%)]	log Loss: -11.340242
#
# Train set: Average log loss: -11.4542
#
#
# Test set: Average loss: -10.4879
#
# Train Epoch: 146 [0/77445 (0%)]	log Loss: -10.562005
#
# Train set: Average log loss: -11.5914
#
#
# Test set: Average loss: -11.3201
#
# Train Epoch: 147 [0/77445 (0%)]	log Loss: -11.434987
#
# Train set: Average log loss: -11.7194
#
#
# Test set: Average loss: -11.2302
#
# Train Epoch: 148 [0/77445 (0%)]	log Loss: -11.339204
#
# Train set: Average log loss: -11.7398
#
#
# Test set: Average loss: -11.0192
#
# Train Epoch: 149 [0/77445 (0%)]	log Loss: -11.118532
#
# Train set: Average log loss: -11.7407
#
#
# Test set: Average loss: -10.9372
#
# Train Epoch: 150 [0/77445 (0%)]	log Loss: -11.034297
#
# Train set: Average log loss: -11.7544
#
#
# Test set: Average loss: -10.9460
#
# Train Epoch: 151 [0/77445 (0%)]	log Loss: -11.044139
#
# Train set: Average log loss: -11.7909
#
#
# Test set: Average loss: -11.1727
#
# Train Epoch: 152 [0/77445 (0%)]	log Loss: -11.281273
#
# Train set: Average log loss: -11.9144
#
#
# Test set: Average loss: -11.9024
#
# Train Epoch: 153 [0/77445 (0%)]	log Loss: -12.045057
#
# Train set: Average log loss: -12.1129
#
#
# Test set: Average loss: -12.0255
#
# Train Epoch: 154 [0/77445 (0%)]	log Loss: -12.173091
#
# Train set: Average log loss: -11.7909
#
#
# Test set: Average loss: -12.0231
#
# Train Epoch: 155 [0/77445 (0%)]	log Loss: -12.176999
#
# Train set: Average log loss: -11.0257
#
#
# Test set: Average loss: -12.0731
#
# Train Epoch: 156 [0/77445 (0%)]	log Loss: -12.187172
#
# Train set: Average log loss: -11.8427
#
#
# Test set: Average loss: -11.6739
#
# Train Epoch: 157 [0/77445 (0%)]	log Loss: -11.816816
#
# Train set: Average log loss: -11.9156
#
#
# Test set: Average loss: -11.3072
#
# Train Epoch: 158 [0/77445 (0%)]	log Loss: -11.426193
#
# Train set: Average log loss: -11.9127
#
#
# Test set: Average loss: -11.2501
#
# Train Epoch: 159 [0/77445 (0%)]	log Loss: -11.362747
#
# Train set: Average log loss: -11.9749
#
#
# Test set: Average loss: -11.9744
#
# Train Epoch: 160 [0/77445 (0%)]	log Loss: -12.125431
#
# Train set: Average log loss: -12.1527
#
#
# Test set: Average loss: -12.0589
#
# Train Epoch: 161 [0/77445 (0%)]	log Loss: -12.216012
#
# Train set: Average log loss: -11.6783
#
#
# Test set: Average loss: -11.9331
#
# Train Epoch: 162 [0/77445 (0%)]	log Loss: -12.088799
#
# Train set: Average log loss: -11.9062
#
#
# Test set: Average loss: -12.0665
#
# Train Epoch: 163 [0/77445 (0%)]	log Loss: -12.220532
#
# Train set: Average log loss: -11.5619
#
#
# Test set: Average loss: -12.1356
#
# Train Epoch: 164 [0/77445 (0%)]	log Loss: -12.274832
#
# Train set: Average log loss: -12.0805
#
#
# Test set: Average loss: -12.1010
#
# Train Epoch: 165 [0/77445 (0%)]	log Loss: -12.261892
#
# Train set: Average log loss: -11.7039
#
#
# Test set: Average loss: -12.0900
#
# Train Epoch: 166 [0/77445 (0%)]	log Loss: -12.252623
#
# Train set: Average log loss: -11.8117
#
#
# Test set: Average loss: -11.6984
#
# Train Epoch: 167 [0/77445 (0%)]	log Loss: -11.845529
#
# Train set: Average log loss: -11.6453
#
#
# Test set: Average loss: -12.1158
#
# Train Epoch: 168 [0/77445 (0%)]	log Loss: -12.212725
#
# Train set: Average log loss: -11.9820
#
#
# Test set: Average loss: -11.8329
#
# Train Epoch: 169 [0/77445 (0%)]	log Loss: -12.000325
#
# Train set: Average log loss: -12.0497
#
#
# Test set: Average loss: -12.1702
#
# Train Epoch: 170 [0/77445 (0%)]	log Loss: -12.317989
#
# Train set: Average log loss: -11.2409
#
#
# Test set: Average loss: -10.8615
#
# Train Epoch: 171 [0/77445 (0%)]	log Loss: -10.961498
#
# Train set: Average log loss: -11.8252
#
#
# Test set: Average loss: -10.8988
#
# Train Epoch: 172 [0/77445 (0%)]	log Loss: -11.003331
#
# Train set: Average log loss: -11.8792
#
#
# Test set: Average loss: -11.1568
#
# Train Epoch: 173 [0/77445 (0%)]	log Loss: -11.274912
#
# Train set: Average log loss: -12.0166
#
#
# Test set: Average loss: -11.9431
#
# Train Epoch: 174 [0/77445 (0%)]	log Loss: -12.112415
#
# Train set: Average log loss: -12.1899
#
#
# Test set: Average loss: -12.0600
#
# Train Epoch: 175 [0/77445 (0%)]	log Loss: -12.243968
#
# Train set: Average log loss: -11.5136
#
#
# Test set: Average loss: -11.8415
#
# Train Epoch: 176 [0/77445 (0%)]	log Loss: -12.014773
#
# Train set: Average log loss: -12.1762
#
#
# Test set: Average loss: -12.1575
#
# Train Epoch: 177 [0/77445 (0%)]	log Loss: -12.336932
#
# Train set: Average log loss: -12.0013
#
#
# Test set: Average loss: -12.0260
#
# Train Epoch: 178 [0/77445 (0%)]	log Loss: -12.208475
#
# Train set: Average log loss: -11.6846
#
#
# Test set: Average loss: -12.1715
#
# Train Epoch: 179 [0/77445 (0%)]	log Loss: -12.352590
#
# Train set: Average log loss: -11.8811
#
#
# Test set: Average loss: -12.0940
#
# Train Epoch: 180 [0/77445 (0%)]	log Loss: -12.289371
#
# Train set: Average log loss: -11.9119
#
#
# Test set: Average loss: -12.0427
#
# Train Epoch: 181 [0/77445 (0%)]	log Loss: -12.224379
#
# Train set: Average log loss: -11.6837
#
#
# Test set: Average loss: -11.3220
#
# Train Epoch: 182 [0/77445 (0%)]	log Loss: -11.468063
#
# Train set: Average log loss: -11.9465
#
#
# Test set: Average loss: -12.0930
#
# Train Epoch: 183 [0/77445 (0%)]	log Loss: -12.191667
#
# Train set: Average log loss: -12.0816
#
#
# Test set: Average loss: -12.1437
#
# Train Epoch: 184 [0/77445 (0%)]	log Loss: -12.336535
#
# Train set: Average log loss: -11.7805
#
#
# Test set: Average loss: -12.1749
#
# Train Epoch: 185 [0/77445 (0%)]	log Loss: -12.295317
#
# Train set: Average log loss: -11.9520
#
#
# Test set: Average loss: -12.2403
#
# Train Epoch: 186 [0/77445 (0%)]	log Loss: -12.407042
#
# Train set: Average log loss: -11.9137
#
#
# Test set: Average loss: -12.0194
#
# Train Epoch: 187 [0/77445 (0%)]	log Loss: -12.202392
#
# Train set: Average log loss: -11.7547
#
#
# Test set: Average loss: -12.2148
#
# Train Epoch: 188 [0/77445 (0%)]	log Loss: -12.346461
#
# Train set: Average log loss: -12.0258
#
#
# Test set: Average loss: -12.0918
#
# Train Epoch: 189 [0/77445 (0%)]	log Loss: -12.202393
#
# Train set: Average log loss: -11.7166
#
#
# Test set: Average loss: -12.1611
#
# Train Epoch: 190 [0/77445 (0%)]	log Loss: -12.294871
#
# Train set: Average log loss: -11.9586
#
#
# Test set: Average loss: -12.0472
#
# Train Epoch: 191 [0/77445 (0%)]	log Loss: -12.241516
#
# Train set: Average log loss: -12.2124
#
#
# Test set: Average loss: -11.9048
#
# Train Epoch: 192 [0/77445 (0%)]	log Loss: -12.076917
#
# Train set: Average log loss: -11.1906
#
#
# Test set: Average loss: -11.5904
#
# Train Epoch: 193 [0/77445 (0%)]	log Loss: -11.748348
#
# Train set: Average log loss: -11.8874
#
#
# Test set: Average loss: -11.6641
#
# Train Epoch: 194 [0/77445 (0%)]	log Loss: -11.828604
#
# Train set: Average log loss: -11.9446
#
#
# Test set: Average loss: -11.3864
#
# Train Epoch: 195 [0/77445 (0%)]	log Loss: -11.527719
#
# Train set: Average log loss: -11.9702
#
#
# Test set: Average loss: -11.1679
#
# Train Epoch: 196 [0/77445 (0%)]	log Loss: -11.291906
#
# Train set: Average log loss: -12.0115
#
#
# Test set: Average loss: -11.3486
#
# Train Epoch: 197 [0/77445 (0%)]	log Loss: -11.483996
#
# Train set: Average log loss: -12.1618
#
#
# Test set: Average loss: -12.2144
#
# Train Epoch: 198 [0/77445 (0%)]	log Loss: -12.409574
#
# Train set: Average log loss: -12.3293
#
#
# Test set: Average loss: -11.8771
#
# Train Epoch: 199 [0/77445 (0%)]	log Loss: -12.067719
#
# Train set: Average log loss: -11.5287
#
#
# Test set: Average loss: -11.5648
#
# Train Epoch: 200 [0/77445 (0%)]	log Loss: -11.715310
#
# Train set: Average log loss: -12.2811
#
#
# Test set: Average loss: -12.2980
#
# Train Epoch: 201 [0/77445 (0%)]	log Loss: -12.492659
#
# Train set: Average log loss: -11.7859
#
#
# Test set: Average loss: -11.8034
#
# Train Epoch: 202 [0/77445 (0%)]	log Loss: -11.997828
#
# Train set: Average log loss: -12.1542
#
#
# Test set: Average loss: -12.3002
#
# Train Epoch: 203 [0/77445 (0%)]	log Loss: -12.469971
#
# Train set: Average log loss: -11.9356
#
#
# Test set: Average loss: -11.8713
#
# Train Epoch: 204 [0/77445 (0%)]	log Loss: -11.929530
#
# Train set: Average log loss: -12.0165
#
#
# Test set: Average loss: -12.0784
#
# Train Epoch: 205 [0/77445 (0%)]	log Loss: -12.185644
#
# Train set: Average log loss: -12.0340
#
#
# Test set: Average loss: -12.2410
#
# Train Epoch: 206 [0/77445 (0%)]	log Loss: -12.388248
#
# Train set: Average log loss: -11.5551
#
#
# Test set: Average loss: -11.3488
#
# Train Epoch: 207 [0/77445 (0%)]	log Loss: -11.482643
#
# Train set: Average log loss: -12.2061
#
#
# Test set: Average loss: -12.3070
#
# Train Epoch: 208 [0/77445 (0%)]	log Loss: -12.512449
#
# Train set: Average log loss: -12.2517
#
#
# Test set: Average loss: -12.3135
#
# Train Epoch: 209 [0/77445 (0%)]	log Loss: -12.481471
#
# Train set: Average log loss: -11.8870
#
#
# Test set: Average loss: -12.2815
#
# Train Epoch: 210 [0/77445 (0%)]	log Loss: -12.506015
#
# Train set: Average log loss: -11.8061
#
#
# Test set: Average loss: -12.3187
#
# Train Epoch: 211 [0/77445 (0%)]	log Loss: -12.496168
#
# Train set: Average log loss: -12.0398
#
#
# Test set: Average loss: -11.9447
#
# Train Epoch: 212 [0/77445 (0%)]	log Loss: -12.132451
#
# Train set: Average log loss: -12.0843
#
#
# Test set: Average loss: -12.3486
#
# Train Epoch: 213 [0/77445 (0%)]	log Loss: -12.511912
#
# Train set: Average log loss: -11.7838
#
#
# Test set: Average loss: -12.3157
#
# Train Epoch: 214 [0/77445 (0%)]	log Loss: -12.471524
#
# Train set: Average log loss: -12.1081
#
#
# Test set: Average loss: -11.8986
#
# Train Epoch: 215 [0/77445 (0%)]	log Loss: -12.087346
#
# Train set: Average log loss: -12.0936
#
#
# Test set: Average loss: -12.3663
#
# Train Epoch: 216 [0/77445 (0%)]	log Loss: -12.545234
#
# Train set: Average log loss: -12.0122
#
#
# Test set: Average loss: -12.3684
#
# Train Epoch: 217 [0/77445 (0%)]	log Loss: -12.552461
#
# Train set: Average log loss: -11.9948
#
#
# Test set: Average loss: -12.1102
#
# Train Epoch: 218 [0/77445 (0%)]	log Loss: -12.209215
#
# Train set: Average log loss: -11.8297
#
#
# Test set: Average loss: -11.4895
#
# Train Epoch: 219 [0/77445 (0%)]	log Loss: -11.636454
#
# Train set: Average log loss: -12.1791
#
#
# Test set: Average loss: -12.3585
#
# Train Epoch: 220 [0/77445 (0%)]	log Loss: -12.529823
#
# Train set: Average log loss: -11.8714
#
#
# Test set: Average loss: -11.4831
#
# Train Epoch: 221 [0/77445 (0%)]	log Loss: -11.632975
#
# Train set: Average log loss: -12.2886
#
#
# Test set: Average loss: -12.3699
#
# Train Epoch: 222 [0/77445 (0%)]	log Loss: -12.577615
#
# Train set: Average log loss: -11.4625
#
#
# Test set: Average loss: -11.0824
#
# Train Epoch: 223 [0/77445 (0%)]	log Loss: -11.198006
#
# Train set: Average log loss: -11.9344
#
#
# Test set: Average loss: -10.9350
#
# Train Epoch: 224 [0/77445 (0%)]	log Loss: -11.048814
#
# Train set: Average log loss: -11.8242
#
#
# Test set: Average loss: -10.9080
#
# Train Epoch: 225 [0/77445 (0%)]	log Loss: -11.026659
#
# Train set: Average log loss: -11.8297
#
#
# Test set: Average loss: -12.2003
#
# Train Epoch: 226 [0/77445 (0%)]	log Loss: -12.425517
#
# Train set: Average log loss: -11.8457
#
#
# Test set: Average loss: -12.1962
#
# Train Epoch: 227 [0/77445 (0%)]	log Loss: -12.421371
#
# Train set: Average log loss: -11.9056
#
#
# Test set: Average loss: -11.9219
#
# Train Epoch: 228 [0/77445 (0%)]	log Loss: -12.119544
#
# Train set: Average log loss: -11.9330
#
#
# Test set: Average loss: -11.7593
#
# Train Epoch: 229 [0/77445 (0%)]	log Loss: -11.940391
#
# Train set: Average log loss: -11.9293
#
#
# Test set: Average loss: -11.6504
#
# Train Epoch: 230 [0/77445 (0%)]	log Loss: -11.820785
#
# Train set: Average log loss: -11.8956
#
#
# Test set: Average loss: -11.5923
#
# Train Epoch: 231 [0/77445 (0%)]	log Loss: -11.756964
#
# Train set: Average log loss: -11.8633
#
#
# Test set: Average loss: -11.9255
#
# Train Epoch: 232 [0/77445 (0%)]	log Loss: -12.118926
#
# Train set: Average log loss: -11.9077
#
#
# Test set: Average loss: -12.3504
#
# Train Epoch: 233 [0/77445 (0%)]	log Loss: -12.559237
#
# Train set: Average log loss: -11.9447
#
#
# Test set: Average loss: -12.3786
#
# Train Epoch: 234 [0/77445 (0%)]	log Loss: -12.585089
#
# Train set: Average log loss: -11.9935
#
#
# Test set: Average loss: -12.3344
#
# Train Epoch: 235 [0/77445 (0%)]	log Loss: -12.548709
#
# Train set: Average log loss: -12.0354
#
#
# Test set: Average loss: -12.1866
#
# Train Epoch: 236 [0/77445 (0%)]	log Loss: -12.399771
#
# Train set: Average log loss: -12.0831
#
#
# Test set: Average loss: -12.0067
#
# Train Epoch: 237 [0/77445 (0%)]	log Loss: -12.207529
#
# Train set: Average log loss: -12.1826
#
#
# Test set: Average loss: -12.0686
#
# Train Epoch: 238 [0/77445 (0%)]	log Loss: -12.280404
#
# Train set: Average log loss: -12.2469
#
#
# Test set: Average loss: -11.5662
#
# Train Epoch: 239 [0/77445 (0%)]	log Loss: -11.730879
#
# Train set: Average log loss: -12.3662
#
#
# Test set: Average loss: -12.2446
#
# Train Epoch: 240 [0/77445 (0%)]	log Loss: -12.475316
#
# Train set: Average log loss: -12.5018
#
#
# Test set: Average loss: -12.3953
#
# Train Epoch: 241 [0/77445 (0%)]	log Loss: -12.627181
#
# Train set: Average log loss: -11.6803
#
#
# Test set: Average loss: -10.6346
#
# Train Epoch: 242 [0/77445 (0%)]	log Loss: -10.625180
#
# Train set: Average log loss: -11.7435
#
#
# Test set: Average loss: -11.7107
#
# Train Epoch: 243 [0/77445 (0%)]	log Loss: -11.886184
#
# Train set: Average log loss: -12.2183
#
#
# Test set: Average loss: -11.4057
#
# Train Epoch: 244 [0/77445 (0%)]	log Loss: -11.552972
#
# Train set: Average log loss: -12.3654
#
#
# Test set: Average loss: -12.2544
#
# Train Epoch: 245 [0/77445 (0%)]	log Loss: -12.488284
#
# Train set: Average log loss: -12.4629
#
#
# Test set: Average loss: -12.3327
#
# Train Epoch: 246 [0/77445 (0%)]	log Loss: -12.481660
#
# Train set: Average log loss: -11.9282
#
#
# Test set: Average loss: -11.8725
#
# Train Epoch: 247 [0/77445 (0%)]	log Loss: -12.077513
#
# Train set: Average log loss: -12.2121
#
#
# Test set: Average loss: -12.4373
#
# Train Epoch: 248 [0/77445 (0%)]	log Loss: -12.613797
#
# Train set: Average log loss: -11.9952
#
#
# Test set: Average loss: -12.3241
#
# Train Epoch: 249 [0/77445 (0%)]	log Loss: -12.541565
#
# Train set: Average log loss: -12.1230
#
#
# Test set: Average loss: -11.9209
#
# Train Epoch: 250 [0/77445 (0%)]	log Loss: -11.978437
#
# Train set: Average log loss: -12.0927
#
#
# Test set: Average loss: -11.8651
#
# Train Epoch: 251 [0/77445 (0%)]	log Loss: -11.929855
#
# Train set: Average log loss: -12.2010
#
#
# Test set: Average loss: -11.7543
#
# Train Epoch: 252 [0/77445 (0%)]	log Loss: -11.819747
#
# Train set: Average log loss: -12.1780
#
#
# Test set: Average loss: -12.0615
#
# Train Epoch: 253 [0/77445 (0%)]	log Loss: -12.162062
#
# Train set: Average log loss: -12.0862
#
#
# Test set: Average loss: -12.4931
#
# Train Epoch: 254 [0/77445 (0%)]	log Loss: -12.700933
#
# Train set: Average log loss: -11.9045
#
#
# Test set: Average loss: -11.3427
#
# Train Epoch: 255 [0/77445 (0%)]	log Loss: -11.471762
#
# Train set: Average log loss: -12.0293
#
#
# Test set: Average loss: -12.0400
#
# Train Epoch: 256 [0/77445 (0%)]	log Loss: -12.245232
#
# Train set: Average log loss: -12.4540
#
#
# Test set: Average loss: -12.5013
#
# Train Epoch: 257 [0/77445 (0%)]	log Loss: -12.704098
#
# Train set: Average log loss: -11.4615
#
#
# Test set: Average loss: -10.8257
#
# Train Epoch: 258 [0/77445 (0%)]	log Loss: -10.923307
#
# Train set: Average log loss: -12.0245
#
#
# Test set: Average loss: -11.4913
#
# Train Epoch: 259 [0/77445 (0%)]	log Loss: -11.647788
#
# Train set: Average log loss: -12.0784
#
#
# Test set: Average loss: -11.7915
#
# Train Epoch: 260 [0/77445 (0%)]	log Loss: -11.975376
#
# Train set: Average log loss: -12.1289
#
#
# Test set: Average loss: -11.6135
#
# Train Epoch: 261 [0/77445 (0%)]	log Loss: -11.781399
#
# Train set: Average log loss: -12.2096
#
#
# Test set: Average loss: -11.4490
#
# Train Epoch: 262 [0/77445 (0%)]	log Loss: -11.599546
#
# Train set: Average log loss: -12.3663
#
#
# Test set: Average loss: -12.0575
#
# Train Epoch: 263 [0/77445 (0%)]	log Loss: -12.266946
#
# Train set: Average log loss: -12.4458
#
#
# Test set: Average loss: -11.8110
#
# Train Epoch: 264 [0/77445 (0%)]	log Loss: -11.994496
#
# Train set: Average log loss: -12.3178
#
#
# Test set: Average loss: -11.0879
#
# Train Epoch: 265 [0/77445 (0%)]	log Loss: -11.220196
#
# Train set: Average log loss: -12.1590
#
#
# Test set: Average loss: -12.1411
#
# Train Epoch: 266 [0/77445 (0%)]	log Loss: -12.223867
#
# Train set: Average log loss: -11.9755
#
#
# Test set: Average loss: -11.7770
#
# Train Epoch: 267 [0/77445 (0%)]	log Loss: -11.952979
#
# Train set: Average log loss: -11.9447
#
#
# Test set: Average loss: -11.1062
#
# Train Epoch: 268 [0/77445 (0%)]	log Loss: -11.136350
#
# Train set: Average log loss: -11.9244
#
#
# Test set: Average loss: -11.6227
#
# Train Epoch: 269 [0/77445 (0%)]	log Loss: -11.779106
#
# Train set: Average log loss: -12.3669
#
#
# Test set: Average loss: -12.1949
#
# Train Epoch: 270 [0/77445 (0%)]	log Loss: -12.417044
#
# Train set: Average log loss: -12.5470
#
#
# Test set: Average loss: -11.8555
#
# Train Epoch: 271 [0/77445 (0%)]	log Loss: -12.036556
#
# Train set: Average log loss: -12.0916
#
#
# Test set: Average loss: -12.4365
#
# Train Epoch: 272 [0/77445 (0%)]	log Loss: -12.671514
#
# Train set: Average log loss: -11.6822
#
#
# Test set: Average loss: -11.6102
#
# Train Epoch: 273 [0/77445 (0%)]	log Loss: -11.767311
#
# Train set: Average log loss: -12.1960
#
#
# Test set: Average loss: -11.5490
#
# Train Epoch: 274 [0/77445 (0%)]	log Loss: -11.705261
#
# Train set: Average log loss: -12.3001
#
#
# Test set: Average loss: -12.2212
#
# Train Epoch: 275 [0/77445 (0%)]	log Loss: -12.450875
#
# Train set: Average log loss: -12.4915
#
#
# Test set: Average loss: -12.1376
#
# Train Epoch: 276 [0/77445 (0%)]	log Loss: -12.353944
#
# Train set: Average log loss: -11.9082
#
#
# Test set: Average loss: -11.8828
#
# Train Epoch: 277 [0/77445 (0%)]	log Loss: -12.064420
#
# Train set: Average log loss: -12.3499
#
#
# Test set: Average loss: -11.6574
#
# Train Epoch: 278 [0/77445 (0%)]	log Loss: -11.831864
#
# Train set: Average log loss: -12.4621
#
#
# Test set: Average loss: -11.8475
#
# Train Epoch: 279 [0/77445 (0%)]	log Loss: -12.036558
#
# Train set: Average log loss: -11.5687
#
#
# Test set: Average loss: -11.1170
#
# Train Epoch: 280 [0/77445 (0%)]	log Loss: -11.246311
#
# Train set: Average log loss: -12.0716
#
#
# Test set: Average loss: -11.1523
#
# Train Epoch: 281 [0/77445 (0%)]	log Loss: -11.288074
#
# Train set: Average log loss: -12.0207
#
#
# Test set: Average loss: -11.4275
#
# Train Epoch: 282 [0/77445 (0%)]	log Loss: -11.590245
#
# Train set: Average log loss: -11.9909
#
#
# Test set: Average loss: -12.4712
#
# Train Epoch: 283 [0/77445 (0%)]	log Loss: -12.678598
#
# Train set: Average log loss: -11.8744
#
#
# Test set: Average loss: -12.4788
#
# Train Epoch: 284 [0/77445 (0%)]	log Loss: -12.712689
#
# Train set: Average log loss: -12.0202
#
#
# Test set: Average loss: -12.4678
#
# Train Epoch: 285 [0/77445 (0%)]	log Loss: -12.699823
#
# Train set: Average log loss: -12.0412
#
#
# Test set: Average loss: -12.5682
#
# Train Epoch: 286 [0/77445 (0%)]	log Loss: -12.757335
#
# Train set: Average log loss: -12.0040
#
#
# Test set: Average loss: -12.4808
#
# Train Epoch: 287 [0/77445 (0%)]	log Loss: -12.618386
#
# Train set: Average log loss: -11.9471
#
#
# Test set: Average loss: -12.4179
#
# Train Epoch: 288 [0/77445 (0%)]	log Loss: -12.535446
#
# Train set: Average log loss: -11.8706
#
#
# Test set: Average loss: -11.9640
#
# Train Epoch: 289 [0/77445 (0%)]	log Loss: -12.009034
#
# Train set: Average log loss: -11.8924
#
#
# Test set: Average loss: -11.5015
#
# Train Epoch: 290 [0/77445 (0%)]	log Loss: -11.526468
#
# Train set: Average log loss: -12.1110
#
#
# Test set: Average loss: -11.6617
#
# Train Epoch: 291 [0/77445 (0%)]	log Loss: -11.700776
#
# Train set: Average log loss: -12.1628
#
#
# Test set: Average loss: -11.8350
#
# Train Epoch: 292 [0/77445 (0%)]	log Loss: -11.886360
#
# Train set: Average log loss: -12.1470
#
#
# Test set: Average loss: -12.0503
#
# Train Epoch: 293 [0/77445 (0%)]	log Loss: -12.123352
#
# Train set: Average log loss: -12.1648
#
#
# Test set: Average loss: -12.2733
#
# Train Epoch: 294 [0/77445 (0%)]	log Loss: -12.378713
#
# Train set: Average log loss: -12.2188
#
#
# Test set: Average loss: -12.4689
#
# Train Epoch: 295 [0/77445 (0%)]	log Loss: -12.616926
#
# Train set: Average log loss: -12.3004
#
#
# Test set: Average loss: -12.5917
#
# Train Epoch: 296 [0/77445 (0%)]	log Loss: -12.787264
#
# Train set: Average log loss: -12.3707
#
#
# Test set: Average loss: -12.5921
#
# Train Epoch: 297 [0/77445 (0%)]	log Loss: -12.816578
#
# Train set: Average log loss: -12.4163
#
#
# Test set: Average loss: -12.1590
#
# Train Epoch: 298 [0/77445 (0%)]	log Loss: -12.358923
#
# Train set: Average log loss: -12.5501
#
#
# Test set: Average loss: -12.4544
#
# Train Epoch: 299 [0/77445 (0%)]	log Loss: -12.688015
#
# Train set: Average log loss: -12.6473
#
#
# Test set: Average loss: -12.4632
#
# Train Epoch: 300 [0/77445 (0%)]	log Loss: -12.699830
#
# Train set: Average log loss: -12.2737
#
#
# Test set: Average loss: -10.9173
#
# Train Epoch: 301 [0/77445 (0%)]	log Loss: -11.037080
#
# Train set: Average log loss: -12.2329
#
#
# Test set: Average loss: -12.0776
#
# Train Epoch: 302 [0/77445 (0%)]	log Loss: -12.157445
#
# Train set: Average log loss: -12.4344
#
#
# Test set: Average loss: -12.5717
#
# Train Epoch: 303 [0/77445 (0%)]	log Loss: -12.805618
#
# Train set: Average log loss: -11.2931
#
#
# Test set: Average loss: -12.4749
#
# Train Epoch: 304 [0/77445 (0%)]	log Loss: -12.708985
#
# Train set: Average log loss: -12.3229
#
#
# Test set: Average loss: -12.5458
#
# Train Epoch: 305 [0/77445 (0%)]	log Loss: -12.776650
#
# Train set: Average log loss: -12.3877
#
#
# Test set: Average loss: -12.4884
#
# Train Epoch: 306 [0/77445 (0%)]	log Loss: -12.720106
#
# Train set: Average log loss: -12.4589
#
#
# Test set: Average loss: -12.0440
#
# Train Epoch: 307 [0/77445 (0%)]	log Loss: -12.237846
#
# Train set: Average log loss: -12.6569
#
#
# Test set: Average loss: -12.6373
#
# Train Epoch: 308 [0/77445 (0%)]	log Loss: -12.874522
#
# Train set: Average log loss: -12.6124
#
#
# Test set: Average loss: -11.2239
#
# Train Epoch: 309 [0/77445 (0%)]	log Loss: -11.252780
#
# Train set: Average log loss: -11.9700
#
#
# Test set: Average loss: -12.4974
#
# Train Epoch: 310 [0/77445 (0%)]	log Loss: -12.746783
#
# Train set: Average log loss: -12.6981
#
#
# Test set: Average loss: -12.6435
#
# Train Epoch: 311 [0/77445 (0%)]	log Loss: -12.880248
#
# Train set: Average log loss: -11.1083
#
#
# Test set: Average loss: -12.5056
#
# Train Epoch: 312 [0/77445 (0%)]	log Loss: -12.640784
#
# Train set: Average log loss: -12.0551
#
#
# Test set: Average loss: -11.5115
#
# Train Epoch: 313 [0/77445 (0%)]	log Loss: -11.542665
#
# Train set: Average log loss: -12.1393
#
#
# Test set: Average loss: -11.6126
#
# Train Epoch: 314 [0/77445 (0%)]	log Loss: -11.652529
#
# Train set: Average log loss: -12.1931
#
#
# Test set: Average loss: -11.7688
#
# Train Epoch: 315 [0/77445 (0%)]	log Loss: -11.819453
#
# Train set: Average log loss: -12.2010
#
#
# Test set: Average loss: -11.9802
#
# Train Epoch: 316 [0/77445 (0%)]	log Loss: -12.047986
#
# Train set: Average log loss: -12.2355
#
#
# Test set: Average loss: -12.2489
#
# Train Epoch: 317 [0/77445 (0%)]	log Loss: -12.349908
#
# Train set: Average log loss: -12.3051
#
#
# Test set: Average loss: -12.4734
#
# Train Epoch: 318 [0/77445 (0%)]	log Loss: -12.619577
#
# Train set: Average log loss: -12.3795
#
#
# Test set: Average loss: -12.6593
#
# Train Epoch: 319 [0/77445 (0%)]	log Loss: -12.878411
#
# Train set: Average log loss: -12.4949
#
#
# Test set: Average loss: -12.6290
#
# Train Epoch: 320 [0/77445 (0%)]	log Loss: -12.867897
#
# Train set: Average log loss: -12.6080
#
#
# Test set: Average loss: -12.3742
#
# Train Epoch: 321 [0/77445 (0%)]	log Loss: -12.601359
#
# Train set: Average log loss: -12.7219
#
#
# Test set: Average loss: -12.6057
#
# Train Epoch: 322 [0/77445 (0%)]	log Loss: -12.860336
#
# Train set: Average log loss: -12.3895
#
#
# Test set: Average loss: -12.5876
#
# Train Epoch: 323 [0/77445 (0%)]	log Loss: -12.828314
#
# Train set: Average log loss: -12.1682
#
#
# Test set: Average loss: -12.2590
#
# Train Epoch: 324 [0/77445 (0%)]	log Loss: -12.358427
#
# Train set: Average log loss: -12.4774
#
#
# Test set: Average loss: -12.2865
#
# Train Epoch: 325 [0/77445 (0%)]	log Loss: -12.399615
#
# Train set: Average log loss: -12.1908
#
#
# Test set: Average loss: -12.3991
#
# Train Epoch: 326 [0/77445 (0%)]	log Loss: -12.543354
#
# Train set: Average log loss: -12.2963
#
#
# Test set: Average loss: -12.3505
#
# Train Epoch: 327 [0/77445 (0%)]	log Loss: -12.477582
#
# Train set: Average log loss: -12.4019
#
#
# Test set: Average loss: -11.6814
#
# Train Epoch: 328 [0/77445 (0%)]	log Loss: -11.833212
#
# Train set: Average log loss: -12.0527
#
#
# Test set: Average loss: -12.2672
#
# Train Epoch: 329 [0/77445 (0%)]	log Loss: -12.476808
#
# Train set: Average log loss: -12.1324
#
#
# Test set: Average loss: -12.6005
#
# Train Epoch: 330 [0/77445 (0%)]	log Loss: -12.865960
#
# Train set: Average log loss: -12.3098
#
#
# Test set: Average loss: -12.6562
#
# Train Epoch: 331 [0/77445 (0%)]	log Loss: -12.918129
#
# Train set: Average log loss: -12.4918
#
#
# Test set: Average loss: -12.4253
#
# Train Epoch: 332 [0/77445 (0%)]	log Loss: -12.678559
#
# Train set: Average log loss: -12.3131
#
#
# Test set: Average loss: -12.6814
#
# Train Epoch: 333 [0/77445 (0%)]	log Loss: -12.926376
#
# Train set: Average log loss: -12.3329
#
#
# Test set: Average loss: -12.5035
#
# Train Epoch: 334 [0/77445 (0%)]	log Loss: -12.651647
#
# Train set: Average log loss: -12.0736
#
#
# Test set: Average loss: -12.0849
#
# Train Epoch: 335 [0/77445 (0%)]	log Loss: -12.296446
#
# Train set: Average log loss: -12.1856
#
#
# Test set: Average loss: -12.4048
#
# Train Epoch: 336 [0/77445 (0%)]	log Loss: -12.531956
#
# Train set: Average log loss: -12.0424
#
#
# Test set: Average loss: -12.1474
#
# Train Epoch: 337 [0/77445 (0%)]	log Loss: -12.358273
#
# Train set: Average log loss: -12.5009
#
#
# Test set: Average loss: -12.6574
#
# Train Epoch: 338 [0/77445 (0%)]	log Loss: -12.924729
#
# Train set: Average log loss: -12.3295
#
#
# Test set: Average loss: -12.7077
#
# Train Epoch: 339 [0/77445 (0%)]	log Loss: -12.960205
#
# Train set: Average log loss: -12.4695
#
#
# Test set: Average loss: -12.7041
#
# Train Epoch: 340 [0/77445 (0%)]	log Loss: -12.974353
#
# Train set: Average log loss: -12.4489
#
#
# Test set: Average loss: -10.9472
#
# Train Epoch: 341 [0/77445 (0%)]	log Loss: -10.977020
#
# Train set: Average log loss: -12.2224
#
#
# Test set: Average loss: -12.1445
#
# Train Epoch: 342 [0/77445 (0%)]	log Loss: -12.361621
#
# Train set: Average log loss: -12.2792
#
#
# Test set: Average loss: -12.5773
#
# Train Epoch: 343 [0/77445 (0%)]	log Loss: -12.733324
#
# Train set: Average log loss: -12.3642
#
#
# Test set: Average loss: -12.5012
#
# Train Epoch: 344 [0/77445 (0%)]	log Loss: -12.671681
#
# Train set: Average log loss: -12.4801
#
#
# Test set: Average loss: -11.2039
#
# Train Epoch: 345 [0/77445 (0%)]	log Loss: -11.333619
#
# Train set: Average log loss: -11.9825
#
#
# Test set: Average loss: -12.6530
#
# Train Epoch: 346 [0/77445 (0%)]	log Loss: -12.854064
#
# Train set: Average log loss: -12.0707
#
#
# Test set: Average loss: -11.7403
#
# Train Epoch: 347 [0/77445 (0%)]	log Loss: -11.905005
#
# Train set: Average log loss: -12.4607
#
#
# Test set: Average loss: -12.0919
#
# Train Epoch: 348 [0/77445 (0%)]	log Loss: -12.295865
#
# Train set: Average log loss: -12.4333
#
#
# Test set: Average loss: -12.6823
#
# Train Epoch: 349 [0/77445 (0%)]	log Loss: -12.953346
#
# Train set: Average log loss: -12.7217
#
#
# Test set: Average loss: -12.6832
#
# Train Epoch: 350 [0/77445 (0%)]	log Loss: -12.959769
#
# Train set: Average log loss: -12.0254
#
#
# Test set: Average loss: -12.6884
#
# Train Epoch: 351 [0/77445 (0%)]	log Loss: -12.964473
#
# Train set: Average log loss: -12.3637
#
#
# Test set: Average loss: -12.6981
#
# Train Epoch: 352 [0/77445 (0%)]	log Loss: -12.977384
#
# Train set: Average log loss: -12.6454
#
#
# Test set: Average loss: -12.5111
#
# Train Epoch: 353 [0/77445 (0%)]	log Loss: -12.777360
#
# Train set: Average log loss: -11.7265
#
#
# Test set: Average loss: -10.9348
#
# Train Epoch: 354 [0/77445 (0%)]	log Loss: -11.046324
#
# Train set: Average log loss: -12.1033
#
#
# Test set: Average loss: -11.8375
#
# Train Epoch: 355 [0/77445 (0%)]	log Loss: -12.029784
#
# Train set: Average log loss: -12.2004
#
#
# Test set: Average loss: -12.6158
#
# Train Epoch: 356 [0/77445 (0%)]	log Loss: -12.827643
#
# Train set: Average log loss: -12.1806
#
#
# Test set: Average loss: -12.5239
#
# Train Epoch: 357 [0/77445 (0%)]	log Loss: -12.656928
#
# Train set: Average log loss: -12.2068
#
#
# Test set: Average loss: -12.6995
#
# Train Epoch: 358 [0/77445 (0%)]	log Loss: -12.898485
#
# Train set: Average log loss: -12.2893
#
#
# Test set: Average loss: -12.7140
#
# Train Epoch: 359 [0/77445 (0%)]	log Loss: -12.922378
#
# Train set: Average log loss: -12.3295
#
#
# Test set: Average loss: -12.7051
#
# Train Epoch: 360 [0/77445 (0%)]	log Loss: -12.912106
#
# Train set: Average log loss: -12.3556
#
#
# Test set: Average loss: -12.6968
#
# Train Epoch: 361 [0/77445 (0%)]	log Loss: -12.924010
#
# Train set: Average log loss: -12.4137
#
#
# Test set: Average loss: -12.3955
#
# Train Epoch: 362 [0/77445 (0%)]	log Loss: -12.637124
#
# Train set: Average log loss: -12.5782
#
#
# Test set: Average loss: -12.1534
#
# Train Epoch: 363 [0/77445 (0%)]	log Loss: -12.366485
#
# Train set: Average log loss: -12.8013
#
#
# Test set: Average loss: -12.7712
#
# Train Epoch: 364 [0/77445 (0%)]	log Loss: -13.023883
#
# Train set: Average log loss: -12.3142
#
#
# Test set: Average loss: -12.4312
#
# Train Epoch: 365 [0/77445 (0%)]	log Loss: -12.682302
#
# Train set: Average log loss: -12.5238
#
#
# Test set: Average loss: -12.6745
#
# Train Epoch: 366 [0/77445 (0%)]	log Loss: -12.846612
#
# Train set: Average log loss: -12.1144
#
#
# Test set: Average loss: -10.4408
#
# Train Epoch: 367 [0/77445 (0%)]	log Loss: -10.463390
#
# Train set: Average log loss: -11.8336
#
#
# Test set: Average loss: -12.4425
#
# Train Epoch: 368 [0/77445 (0%)]	log Loss: -12.676181
#
# Train set: Average log loss: -12.3810
#
#
# Test set: Average loss: -12.3162
#
# Train Epoch: 369 [0/77445 (0%)]	log Loss: -12.544858
#
# Train set: Average log loss: -12.4907
#
#
# Test set: Average loss: -11.9764
#
# Train Epoch: 370 [0/77445 (0%)]	log Loss: -12.168266
#
# Train set: Average log loss: -12.7091
#
#
# Test set: Average loss: -12.4032
#
# Train Epoch: 371 [0/77445 (0%)]	log Loss: -12.641470
#
# Train set: Average log loss: -12.8153
#
#
# Test set: Average loss: -12.4221
#
# Train Epoch: 372 [0/77445 (0%)]	log Loss: -12.671580
#
# Train set: Average log loss: -11.6925
#
#
# Test set: Average loss: -12.5461
#
# Train Epoch: 373 [0/77445 (0%)]	log Loss: -12.705014
#
# Train set: Average log loss: -12.2968
#
#
# Test set: Average loss: -12.6537
#
# Train Epoch: 374 [0/77445 (0%)]	log Loss: -12.820400
#
# Train set: Average log loss: -12.3581
#
#
# Test set: Average loss: -12.7097
#
# Train Epoch: 375 [0/77445 (0%)]	log Loss: -12.933117
#
# Train set: Average log loss: -12.4694
#
#
# Test set: Average loss: -12.4820
#
# Train Epoch: 376 [0/77445 (0%)]	log Loss: -12.728638
#
# Train set: Average log loss: -12.7087
#
#
# Test set: Average loss: -12.5283
#
# ...
#
# Train Epoch: 7877 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7878 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7879 [0/77445 (0%)]	log Loss: -14.266542
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7880 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7881 [0/77445 (0%)]	log Loss: -14.266529
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7882 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7883 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7884 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7885 [0/77445 (0%)]	log Loss: -14.266535
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7886 [0/77445 (0%)]	log Loss: -14.266530
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7887 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7888 [0/77445 (0%)]	log Loss: -14.266526
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7889 [0/77445 (0%)]	log Loss: -14.266523
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7890 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7891 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7892 [0/77445 (0%)]	log Loss: -14.266539
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7893 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7894 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7895 [0/77445 (0%)]	log Loss: -14.266522
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7896 [0/77445 (0%)]	log Loss: -14.266527
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7897 [0/77445 (0%)]	log Loss: -14.266525
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7898 [0/77445 (0%)]	log Loss: -14.266534
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7899 [0/77445 (0%)]	log Loss: -14.266528
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7900 [0/77445 (0%)]	log Loss: -14.266530
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7901 [0/77445 (0%)]	log Loss: -14.266525
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7902 [0/77445 (0%)]	log Loss: -14.266534
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7903 [0/77445 (0%)]	log Loss: -14.266535
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7904 [0/77445 (0%)]	log Loss: -14.266534
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7905 [0/77445 (0%)]	log Loss: -14.266525
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7906 [0/77445 (0%)]	log Loss: -14.266535
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7907 [0/77445 (0%)]	log Loss: -14.266536
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7908 [0/77445 (0%)]	log Loss: -14.266524
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7909 [0/77445 (0%)]	log Loss: -14.266533
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7910 [0/77445 (0%)]	log Loss: -14.266533
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7911 [0/77445 (0%)]	log Loss: -14.266533
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7912 [0/77445 (0%)]	log Loss: -14.266530
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7913 [0/77445 (0%)]	log Loss: -14.266526
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7914 [0/77445 (0%)]	log Loss: -14.266524
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7915 [0/77445 (0%)]	log Loss: -14.266525
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7916 [0/77445 (0%)]	log Loss: -14.266523
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7917 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7918 [0/77445 (0%)]	log Loss: -14.266529
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7919 [0/77445 (0%)]	log Loss: -14.266527
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7920 [0/77445 (0%)]	log Loss: -14.266529
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7921 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7922 [0/77445 (0%)]	log Loss: -14.266537
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7923 [0/77445 (0%)]	log Loss: -14.266533
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7924 [0/77445 (0%)]	log Loss: -14.266526
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7925 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7926 [0/77445 (0%)]	log Loss: -14.266539
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7927 [0/77445 (0%)]	log Loss: -14.266529
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7928 [0/77445 (0%)]	log Loss: -14.266540
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7929 [0/77445 (0%)]	log Loss: -14.266527
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7930 [0/77445 (0%)]	log Loss: -14.266533
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7931 [0/77445 (0%)]	log Loss: -14.266529
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7932 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7933 [0/77445 (0%)]	log Loss: -14.266526
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7934 [0/77445 (0%)]	log Loss: -14.266527
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7935 [0/77445 (0%)]	log Loss: -14.266528
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7936 [0/77445 (0%)]	log Loss: -14.266528
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7937 [0/77445 (0%)]	log Loss: -14.266533
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7938 [0/77445 (0%)]	log Loss: -14.266527
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7939 [0/77445 (0%)]	log Loss: -14.266524
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7940 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7941 [0/77445 (0%)]	log Loss: -14.266527
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7942 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7943 [0/77445 (0%)]	log Loss: -14.266533
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7944 [0/77445 (0%)]	log Loss: -14.266534
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7945 [0/77445 (0%)]	log Loss: -14.266521
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7946 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7947 [0/77445 (0%)]	log Loss: -14.266525
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7948 [0/77445 (0%)]	log Loss: -14.266530
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7949 [0/77445 (0%)]	log Loss: -14.266526
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7950 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7951 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7952 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7953 [0/77445 (0%)]	log Loss: -14.266522
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7954 [0/77445 (0%)]	log Loss: -14.266527
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7955 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7956 [0/77445 (0%)]	log Loss: -14.266525
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7957 [0/77445 (0%)]	log Loss: -14.266517
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7958 [0/77445 (0%)]	log Loss: -14.266517
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7959 [0/77445 (0%)]	log Loss: -14.266529
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7960 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7961 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7962 [0/77445 (0%)]	log Loss: -14.266528
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7963 [0/77445 (0%)]	log Loss: -14.266531
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7964 [0/77445 (0%)]	log Loss: -14.266523
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7965 [0/77445 (0%)]	log Loss: -14.266526
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7966 [0/77445 (0%)]	log Loss: -14.266529
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7967 [0/77445 (0%)]	log Loss: -14.266521
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7968 [0/77445 (0%)]	log Loss: -14.266524
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7969 [0/77445 (0%)]	log Loss: -14.266521
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7970 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7971 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7972 [0/77445 (0%)]	log Loss: -14.266534
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7973 [0/77445 (0%)]	log Loss: -14.266524
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7974 [0/77445 (0%)]	log Loss: -14.266525
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7975 [0/77445 (0%)]	log Loss: -14.266529
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7976 [0/77445 (0%)]	log Loss: -14.266527
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7977 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7978 [0/77445 (0%)]	log Loss: -14.266527
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7979 [0/77445 (0%)]	log Loss: -14.266528
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7980 [0/77445 (0%)]	log Loss: -14.266521
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7981 [0/77445 (0%)]	log Loss: -14.266519
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7982 [0/77445 (0%)]	log Loss: -14.266522
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7983 [0/77445 (0%)]	log Loss: -14.266526
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7984 [0/77445 (0%)]	log Loss: -14.266532
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7985 [0/77445 (0%)]	log Loss: -14.266523
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7986 [0/77445 (0%)]	log Loss: -14.266522
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7987 [0/77445 (0%)]	log Loss: -14.266530
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7988 [0/77445 (0%)]	log Loss: -14.266529
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7989 [0/77445 (0%)]	log Loss: -14.266529
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7990 [0/77445 (0%)]	log Loss: -14.266521
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7991 [0/77445 (0%)]	log Loss: -14.266527
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7992 [0/77445 (0%)]	log Loss: -14.266528
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7993 [0/77445 (0%)]	log Loss: -14.266523
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7994 [0/77445 (0%)]	log Loss: -14.266527
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7995 [0/77445 (0%)]	log Loss: -14.266519
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7996 [0/77445 (0%)]	log Loss: -14.266526
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7997 [0/77445 (0%)]	log Loss: -14.266524
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7998 [0/77445 (0%)]	log Loss: -14.266525
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 7999 [0/77445 (0%)]	log Loss: -14.266523
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783
#
# Train Epoch: 8000 [0/77445 (0%)]	log Loss: -14.266522
#
# Train set: Average log loss: -14.3392
#
#
# Test set: Average loss: -13.6783

# %%
# Plotting log(MSE) as a function of epochs
plt.figure(figsize=(10,7))
plt.plot( np.log(test_losses), label = "test")
plt.plot( np.log(train_losses), label = "train")

plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Log(LSE)")
plt.title("MSE over Epoch" )
plt.grid()
print("Training WIDE {} VS in the article 8.04e-09".format(train_losses[-1]) )
# Out:
# Training WIDE 5.923232430764109e-07 VS in the article 8.04e-09

# %% [markdown]
# ## d) Prediction
# #### Load the ANN

# %%
# Loading model
device = 'cuda'
loaded_Heston_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_ANN_DE.pt"
loaded_Heston_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_ANN.eval()
# Out:
# Heston_ANN(
#   (fc1): Linear(in_features=8, out_features=200, bias=True)
#   (fc2): Linear(in_features=200, out_features=200, bias=True)
#   (fc3): Linear(in_features=200, out_features=200, bias=True)
#   (fc4): Linear(in_features=200, out_features=200, bias=True)
#   (fc5): Linear(in_features=200, out_features=1, bias=True)
# )

# %% [markdown]
# #### This table shows similar trained forward performance as shown in Table (4) from [1]

# %%
x = hs_dataset[0, :-1].unsqueeze(0).to(device)  # input shape (1, 8)
true_iv = hs_dataset[0, -1].item()

# %%
with torch.no_grad():
    predicted_iv = model(x).item()
    predicted_iv2 = loaded_Heston_ANN(x)

# %%
print(f"True IV:      {true_iv:.4f}")
print(f"Predicted IV: {predicted_iv:.4f}")
print(f"Predicted IV 2: {predicted_iv2:.4f}")
# Out:
# True IV:      0.3355
# Predicted IV: 0.3356
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 print(f"True IV:      {true_iv:.4f}")
#       2 print(f"Predicted IV: {predicted_iv:.4f}")
# ----> 3 print(f"Predicted IV 2: {predicted_iv2:.4f}")
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\torch\_tensor.py:934, in Tensor.__format__(self, format_spec)
#     932 if self.dim() == 0 and not self.is_meta and type(self) is Tensor:
#     933     return self.item().__format__(format_spec)
# --> 934 return object.__format__(self, format_spec)
#
# TypeError: unsupported format string passed to Tensor.__format__

# %%
with torch.no_grad():
    predicted_iv1 = model(x)
    predicted_iv2 = loaded_Heston_ANN(x)

print("Are both predictions equal? ", torch.allclose(predicted_iv1, predicted_iv2, atol=1e-6))
print(f"Model(x):              {predicted_iv1.item():.6f}")
print(f"Loaded_Heston_ANN(x):  {predicted_iv2.item():.6f}")
# Out:
# Are both predictions equal?  False
# Model(x):              0.335588
# Loaded_Heston_ANN(x):  0.395709

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Train scores----------------
# MSE 6.410718e-07
# MAE 6.151346e-04
# MAPE 2.882762e-02
# R2 9.999770e-01
# -----------Test scores----------------
# MSE 6.685028e-07
# MAE 6.187673e-04
# MAPE 2.215859e-02
# R2 9.999760e-01

# %% [markdown]
# #### The ANN Solver can now be used for pricing. (e.g. on data, output = loaded_Heston_ANN(data))

# %%
# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

print(prices)
# Out:
# [0.04151211 0.4886806  0.01257699 ... 0.08910975 0.12090141 0.01049523]

# %% [markdown]
# ## d) Calculate implied volatilities

# %%
from scipy import optimize

def calcimpliedvol(dataset):
    """
    Computes the implied volatilities using the brent method.
    dataset: numpy array containing moneyness, time to maturity, risk free interest rate and V/K.
    Returns a vector of implied volatilities.
    """
    money = np.array(dataset[0])
    T = np.array(dataset[1])
    r = np.array(dataset[2])
    marketoptionPrice = np.array(dataset[3])
    def bs_price(sigma):
      d1 = ( np.log(money) + (r + 0.5 * sigma ** 2) * (T) ) / (sigma * np.sqrt(T))
      d2 = d1 - sigma*np.sqrt(T)
      value_moyeness = money * norm.cdf(d1) - np.exp(-r * (T)) * norm.cdf(d2) 
      fx = value_moyeness - marketoptionPrice
      return fx
    return optimize.brentq(bs_price, -1, 1, maxiter=100)

# %%
# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

# Replace with this
hs_dataset2 = hs_dataset.data[:, np.array([0, 1, 2, 8])]  # Select relevant columns
hs_dataset2[:, 3] = torch.FloatTensor(prices)  # Use Heston-ANN prices as market prices for Brent's method

# Compute implied volatilities using Brent's method
implied_vol = np.apply_along_axis(calcimpliedvol, 1, hs_dataset2)

# Eliminating Nan values
indecies = np.argwhere(np.isnan(implied_vol))
implied_vol = np.delete(implied_vol, indecies, 0)

# %%
print(implied_vol)
# Out:
# [0.52459126 0.51703085 0.44253226 ... 0.34001146 0.57927668 0.60456098]

# %% [markdown]
# ## e) Volatility Surface

# %%
# Create a mesh grid of moneyness and maturity
moneyness = np.linspace(0.75, 1.25, 11)
tau = np.linspace(0.1, 1.0, 10)
m_grid, t_grid = np.meshgrid(moneyness, tau)

# Flatten grid and build input tensor
m_flat = m_grid.flatten()
t_flat = t_grid.flatten()
r_flat = np.full_like(m_flat, r)

# Build ANN input: [m, tau, r, rho, kappa, vbar, gamma, v0]
X = np.column_stack([
    m_flat, t_flat, r_flat,
    np.full_like(m_flat, rho),
    np.full_like(m_flat, kappa),
    np.full_like(m_flat, vbar),
    np.full_like(m_flat, gamma),
    np.full_like(m_flat, v0)
])

# Convert to torch tensor
input_tensor = torch.FloatTensor(X).to("cuda" if torch.cuda.is_available() else "cpu")

# Forward pass to get prices
with torch.no_grad():
    prices = loaded_Heston_ANN(input_tensor).cpu().numpy().flatten()

# Prepare for Brent
brent_input = np.column_stack([m_flat, t_flat, r_flat, prices])
iv_surface = np.apply_along_axis(calcimpliedvol, 1, brent_input)
Z = iv_surface.reshape(m_grid.shape)

# Plot the surface
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(m_grid, t_grid, Z, cmap='viridis', edgecolor='none')
ax.set_xlabel("Moneyness (S/K)")
ax.set_ylabel("Maturity (tau)")
ax.set_zlabel("Implied Volatility")
ax.set_title("Implied Volatility Surface (Heston-ANN + Brent)")
plt.tight_layout()
plt.show()

# %%
class IV_ANN(Heston_ANN):
    # The authors of the paper seem to use
    # the same architecture both for BS-ANN and the IV-ANN
    # thus the class inherets from BS_ANN
  pass

# %%
# here Table (3) of [1] is used, kappa is numerically sensitive to small values
eps = 1e-2 # is used to generate open intervals
def Heston_LHS_data_generator(n = 10**6, l_bounds = [.6+eps, .05+eps, .0+eps, -0.9+eps, 0.4+eps, .01+eps, .01+eps, .05+eps], u_bounds = [1.4-eps, 3.0-eps, .05-eps, 0.0-eps, 3.0-eps, .5-eps, .8-eps, .5-eps]):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,9) containig the inputs samples and the value of the call.
  The inputs are: Moyeness (S/K), time to maturity (tau), Risk free rate (r), Correlation (rho), reversion speed (kappa), Long average variance (vbar), Vol of vol (gamma), Initial variance (v0).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.
  """
  sampler = qmc.LatinHypercube(d = 8) #, seed = 0
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  indecies = np.argwhere(2*sample[:,4]*sample[:,5] <= sample[:,6]**2)
  sample = np.delete(sample, indecies, 0)
  hs_prices = call_option_Heston_moy(N = 160, L= 12, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa = sample[:,4].reshape((-1,1)),\
                                     gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
                                     rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  #hs_prices = call_option_Heston_moy(N = 1500, L= 50, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
  #                                    gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
  #                                    rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))

  hs_dataset = np.concatenate((sample, hs_prices),axis=1)

  print("------ INPUT ------")
  print("S/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,0]), max(hs_dataset[:,0])))
  print("Tau.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,1]), max(hs_dataset[:,1])))
  print("r............ [{:.2f} {:.2f}]".format(min(hs_dataset[:,2]), max(hs_dataset[:,2])))
  print("Corr ........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,3]), max(hs_dataset[:,3])))
  print("Kappa........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,4]), max(hs_dataset[:,4])))
  print("V_bar........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,5]), max(hs_dataset[:,5])))
  print("Gamma........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,6]), max(hs_dataset[:,6])))
  print("V_0 ......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,7]), max(hs_dataset[:,7])))
  print("------ OUTPUT ------")
  print("V/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,-1]), max(hs_dataset[:,-1])))
  # ind_max = np.argmax(hs_dataset[:,-1])
  # print(hs_dataset[ind_max,:])

  return torch.FloatTensor(hs_dataset)

hs_dataset = Heston_LHS_data_generator(10**4)
# Out:
# ------ INPUT ------
# S/K.......... [0.61 1.39]
# Tau.......... [0.06 2.99]
# r............ [0.01 0.04]
# Corr ........ [-0.89 -0.01]
# Kappa........ [0.41 2.99]
# V_bar........ [0.02 0.49]
# Gamma........ [0.02 0.79]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00 0.77]

# %%
def IV_LHS_data_generator(n = 10**6, l_bounds = [.6, .05, .0, .01], u_bounds = [1.4, 3.0, .05, 0.6], log_scale = True):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,5) containig the inputs samples and the volatility as the target.
  Performs a log transormation of V/K.
  The inputs are: Moneyness (S/K), time to maturity (tau), Risk free rate (r), Volatility (sigma).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.
  log_scale: performs log transformation if True.

  """
  sampler = qmc.LatinHypercube(d = 4)
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  bs_prices = bs_moneyness_call(sample[:,0], sample[:,1], sample[:,2], sample[:,3]).reshape((-1, 1))
  bs_dataset = np.concatenate((sample[:,:-1], bs_prices, sample[:,3].reshape((n, 1))), axis = 1)

  # log transformation as in section 4.3
  if log_scale : 
    print("log(V/K) before transformation: [{:.2f}, {:.2f}]".format(min(bs_dataset[:,3]), max(bs_dataset[:,3])))
    # Calculate intrinsic value
    bs_dataset[:,3] = bs_dataset[:,3] - np.maximum(bs_dataset[:,0] - np.exp(-bs_dataset[:,2] * bs_dataset[:,1]), 0)
    # Discard samples where time value is too small or negative
    indecies = np.argwhere(bs_dataset[:,3] < 1e-7)
    bs_dataset = np.delete(bs_dataset, indecies, 0)
    # Log transformation
    bs_dataset[:,3] = np.log(bs_dataset[:,3])
    print("log(V/K) after transformation: [{:.2f}, {:.2f}]".format(min(bs_dataset[:,3]), max(bs_dataset[:,3])))
  print("------ INPUT ------")
  print("S/K.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,0]), max(bs_dataset[:,0])))
  print("Tau.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,1]), max(bs_dataset[:,1])))
  print("r............ [{:.2f} {:.2f}]".format(min(bs_dataset[:,2]), max(bs_dataset[:,2])))
  if log_scale : 
    print("log(V/K)..... [{:.2f} {:.2f}]".format(min(bs_dataset[:,3]), max(bs_dataset[:,3])))
  else : 
    print("V/K.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,3]), max(bs_dataset[:,3])))
  print("------ OUTPUT ------")
  print("Sigma........ [{:.2f} {:.2f}]".format(min(bs_dataset[:,4]), max(bs_dataset[:,4])))
  return torch.FloatTensor(bs_dataset)

bs_dataset = IV_LHS_data_generator(log_scale = True)
# Out:
# log(V/K) before transformation: [0.00, 0.75]
# log(V/K) after transformation: [-16.12, -0.95]
# ------ INPUT ------
# S/K.......... [0.60 1.40]
# Tau.......... [0.05 3.00]
# r............ [0.00 0.05]
# log(V/K)..... [-16.12 -0.95]
# ------ OUTPUT ------
# Sigma........ [0.01 0.60]

# %%
# Training parameters
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}

use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# torch.manual_seed(args["seed"])

# Loading Train / Test Data
bs_dataset = IV_LHS_data_generator(n = 10**5, log_scale = True)
train_size, test_size = int(bs_dataset.shape[0]*0.9), int(bs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(bs_dataset, [train_size, bs_dataset.shape[0]-train_size])

train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])

# Model training
print(device)
model = IV_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=args["lr"]) # Adam is found to be the best optimizer in the article
scheduler = StepLR(optimizer, step_size=10**3, gamma=args["gamma"]) # Deacreses the Learning rate by .1 every 1000 epoch

train_losses = []
test_losses = []
for epoch in range(1, args["epochs"] + 1):
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
if args["save_model"] :
  torch.save(model.state_dict(), "IV_SCALED_ANN.pt")
# Out:
# log(V/K) before transformation: [0.00, 0.74]
# log(V/K) after transformation: [-16.12, -0.95]
# ------ INPUT ------
# S/K.......... [0.60 1.40]
# Tau.......... [0.05 3.00]
# r............ [0.00 0.05]
# log(V/K)..... [-16.12 -0.95]
# ------ OUTPUT ------
# Sigma........ [0.01 0.60]
# cuda
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[72], line 35
#      33 test_losses = []
#      34 for epoch in range(1, args["epochs"] + 1):
# ---> 35   train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
#      36   test_loss = model.test_model(device, test_loader)
#      37   print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
#
# Cell In[3], line 56, in Heston_ANN.train_model(self, args, device, train_loader, optimizer, epoch)
#      54 optimizer.zero_grad()
#      55 # foward pass
# ---> 56 output = self(data)
#      57 # computing the loss
#      58 loss = F.mse_loss(output, target)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[3], line 29, in Heston_ANN.forward(self, x)
#      23 def forward(self, x):
#      24   """
#      25   Foward pass of the network.
#      26   Relu activations are used and a linear activation is used in the final layer.
#      27   x: input torch tensor (CUDA or CPU)
#      28   """
# ---> 29   x = F.relu(self.fc1(x))
#      30   x = F.relu(self.fc2(x))
#      31   x = F.relu(self.fc3(x))
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1024x4 and 8x200)

# %% [markdown]
# # 2) Backward pass

# %% [markdown]
# ### Reference Heston parameter

# %%
# Effect of individual parameters
# Section 4.1.1 in [1]
T = 2 
S0 = 100
kappa = 0.1
gamma = 0.1  # Volatility of variance
nu_bar = 0.1
rho = -0.75
nu_0 = 0.05
r = 0.05

# %%
# Grid: 7 moneyness × 5 maturities = 35
moneyness = np.linspace(0.85, 1.15, 5)
maturity = np.linspace(0.5, 2.0, 7)
m_grid, t_grid = np.meshgrid(moneyness, maturity)
m_flat = m_grid.flatten()
t_flat = t_grid.flatten()
r_flat = np.full_like(m_flat, 0.03)

# Build input tensor
input_matrix = np.column_stack([
    m_flat, t_flat, r_flat,
    np.full_like(m_flat, rho),
    np.full_like(m_flat, kappa),
    np.full_like(m_flat, vbar),
    np.full_like(m_flat, gamma),
    np.full_like(m_flat, nu_0)
])
input_tensor = torch.FloatTensor(input_matrix).to(device)

# Predict prices
with torch.no_grad():
    prices = loaded_Heston_ANN(input_tensor).cpu().numpy().flatten()
#prices = np.maximum(prices, 1e-5)
#print(prices)
prices = np.maximum(prices, m_flat - np.exp(-r_flat * t_flat) + 1e-4)
#print(prices)

# Compute IVs using Brent
brent_input = np.column_stack([m_flat, t_flat, r_flat, prices])
implied_vols = np.apply_along_axis(calcimpliedvol, 1, brent_input)

# Final quotes
market_quotes = np.column_stack([m_flat, t_flat, r_flat, implied_vols])
print("Market Quotes (35):")
for q in market_quotes:
    print(f"m={q[0]:.2f}, tau={q[1]:.2f}, r={q[2]:.2f}, IV={q[3]:.4f}")
# Out:
# Market Quotes (35):
# m=0.85, tau=0.50, r=0.03, IV=0.2542
# m=0.92, tau=0.50, r=0.03, IV=0.2554
# m=1.00, tau=0.50, r=0.03, IV=0.2660
# m=1.07, tau=0.50, r=0.03, IV=0.2728
# m=1.15, tau=0.50, r=0.03, IV=0.2797
# m=0.85, tau=0.75, r=0.03, IV=0.2409
# m=0.92, tau=0.75, r=0.03, IV=0.2548
# m=1.00, tau=0.75, r=0.03, IV=0.2662
# m=1.07, tau=0.75, r=0.03, IV=0.2698
# m=1.15, tau=0.75, r=0.03, IV=0.2845
# m=0.85, tau=1.00, r=0.03, IV=0.2380
# m=0.92, tau=1.00, r=0.03, IV=0.2562
# m=1.00, tau=1.00, r=0.03, IV=0.2615
# m=1.07, tau=1.00, r=0.03, IV=0.2645
# m=1.15, tau=1.00, r=0.03, IV=0.2708
# m=0.85, tau=1.25, r=0.03, IV=0.2371
# m=0.92, tau=1.25, r=0.03, IV=0.2464
# m=1.00, tau=1.25, r=0.03, IV=0.2503
# m=1.07, tau=1.25, r=0.03, IV=0.2550
# m=1.15, tau=1.25, r=0.03, IV=0.2606
# m=0.85, tau=1.50, r=0.03, IV=0.2407
# m=0.92, tau=1.50, r=0.03, IV=0.2447
# m=1.00, tau=1.50, r=0.03, IV=0.2465
# m=1.07, tau=1.50, r=0.03, IV=0.2474
# m=1.15, tau=1.50, r=0.03, IV=0.2488
# m=0.85, tau=1.75, r=0.03, IV=0.2399
# m=0.92, tau=1.75, r=0.03, IV=0.2416
# m=1.00, tau=1.75, r=0.03, IV=0.2439
# m=1.07, tau=1.75, r=0.03, IV=0.2458
# m=1.15, tau=1.75, r=0.03, IV=0.2451
# m=0.85, tau=2.00, r=0.03, IV=0.2389
# m=0.92, tau=2.00, r=0.03, IV=0.2400
# m=1.00, tau=2.00, r=0.03, IV=0.2450
# m=1.07, tau=2.00, r=0.03, IV=0.2466
# m=1.15, tau=2.00, r=0.03, IV=0.2443

# %%
def calibration_objective(theta, inputs, market_iv, iv_ann):
    # theta: [rho, kappa, vbar, gamma, v0]
    # inputs: [moneyness, maturity, r] fixed per quote
    input_tensor = torch.tensor(np.column_stack([
        inputs,  # shape (N, 3)
        np.tile(theta, (inputs.shape[0], 1))
    ]), dtype=torch.float32).to(device)

    with torch.no_grad():
        pred_iv = iv_ann(input_tensor).cpu().numpy().flatten()

    return np.mean((pred_iv - market_iv) ** 2)

# %%
target_iv = implied_vols

# Use the contract terms (moneyness, maturity, r) from market quotes
fixed_contracts = market_quotes[:, :3]  # shape (35, 3)

# --- Loss function ---
def calibration_objective(theta):
    rho, kappa, vbar, gamma, v0 = theta

    

    # Build full input matrix (35 rows, 8 features)
    input_matrix = np.hstack([
        fixed_contracts,
        np.full((fixed_contracts.shape[0], 1), rho),
        np.full((fixed_contracts.shape[0], 1), kappa),
        np.full((fixed_contracts.shape[0], 1), vbar),
        np.full((fixed_contracts.shape[0], 1), gamma),
        np.full((fixed_contracts.shape[0], 1), v0),
    ])
    input_tensor = torch.FloatTensor(input_matrix).to(device)

    # Predict prices with Heston-ANN
    with torch.no_grad():
        prices = loaded_Heston_ANN(input_tensor).cpu().numpy().flatten()

    # Ensure prices > intrinsic value for Brent to work
    intrinsic = fixed_contracts[:, 0] - np.exp(-fixed_contracts[:, 1] * fixed_contracts[:, 2])
    prices = np.maximum(prices, intrinsic + 1e-4)
    print("Input params:", theta)
    #print("Prices shape:", prices.shape)
    #print("Input prices:", prices)
    #print("Target IV shape:", target_iv.shape)
    assert prices is not None, "Heston-ANN returned None!"

    # Compute Brent IVs
    brent_inputs = np.column_stack([fixed_contracts, prices])
    predicted_iv = np.apply_along_axis(calcimpliedvol, 1, brent_inputs)

    # Check for NaNs
    if np.any(np.isnan(predicted_iv)):
        return 1e3  # penalize invalid parameter sets

    # Compute MSE loss
    return np.mean((predicted_iv - target_iv)**2)

# %%
# --- Bounds from Section 4.1.1 ---
bounds = [(-0.85, 0.05), (0.05, 0.45), (0.05, 0.75), (0.05, 0.45), (0.1, 2.0)]

# --- Run DE optimization ---
result = differential_evolution(
    calibration_objective,
    bounds,
    strategy="best1bin",
    popsize=15,
    tol=1e-5,
    maxiter=1000,
    #polish=True,
    workers=1,
    updating="deferred"
)

print("Calibrated parameters:", result.x)
print("Final MSE loss:", result.fun)
# Out:
# Input params: [-0.09532251  0.24635111  0.74193226  0.32532349  1.76879556]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:1122, in DifferentialEvolutionSolver._calculate_population_energies(self, population)
#    1121 try:
# -> 1122     calc_energies = list(
#    1123         self._mapwrapper(self.func, parameters_pop[0:S])
#    1124     )
#    1125     calc_energies = np.squeeze(calc_energies)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\_lib\_util.py:372, in _FunctionWrapper.__call__(self, x)
#     371 def __call__(self, x):
# --> 372     return self.f(x, *self.args)
#
# Cell In[58], line 38, in calibration_objective(theta)
#      37 brent_inputs = np.column_stack([fixed_contracts, prices])
# ---> 38 predicted_iv = np.apply_along_axis(calcimpliedvol, 1, brent_inputs)
#      40 # Check for NaNs
#
# File <__array_function__ internals>:200, in apply_along_axis(*args, **kwargs)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\numpy\lib\shape_base.py:379, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     376     raise ValueError(
#     377         'Cannot apply_along_axis when any iteration dimensions are 0'
#     378     ) from None
# --> 379 res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     381 # build a buffer for storing evaluations of func1d.
#     382 # remove the requested axis, and add the new ones on the end.
#     383 # laid out so that each write is contiguous.
#     384 # for a tuple index inds, buff[inds] = func1d(inarr_view[inds])
#
# Cell In[27], line 19, in calcimpliedvol(dataset)
#      18   return fx
# ---> 19 return optimize.brentq(bs_price,-1,1,maxiter=100)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_zeros_py.py:784, in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     783     raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 784 r = _zeros._brentq(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     785 return results_c(full_output, r)
#
# ValueError: f(a) and f(b) must have different signs
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[62], line 5
#       2 bounds = [(-0.85, 0.05), (0.05, 0.45), (0.05, 0.75), (0.05, 0.45), (0.1, 2.0)]
#       4 # --- Run DE optimization ---
# ----> 5 result = differential_evolution(
#       6     calibration_objective,
#       7     bounds,
#       8     strategy="best1bin",
#       9     popsize=15,
#      10     tol=1e-5,
#      11     maxiter=1000,
#      12     #polish=True,
#      13     workers=1,
#      14     updating="deferred"
#      15 )
#      17 print("Calibrated parameters:", result.x)
#      18 print("Final MSE loss:", result.fun)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:397, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     380 # using a context manager means that any created Pool objects are
#     381 # cleared up.
#     382 with DifferentialEvolutionSolver(func, bounds, args=args,
#     383                                  strategy=strategy,
#     384                                  maxiter=maxiter,
#    (...)
#     395                                  integrality=integrality,
#     396                                  vectorized=vectorized) as solver:
# --> 397     ret = solver.solve()
#     399 return ret
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:989, in DifferentialEvolutionSolver.solve(self)
#     984     self.feasible, self.constraint_violation = (
#     985         self._calculate_population_feasibilities(self.population))
#     987     # only work out population energies for feasible solutions
#     988     self.population_energies[self.feasible] = (
# --> 989         self._calculate_population_energies(
#     990             self.population[self.feasible]))
#     992     self._promote_lowest_energy()
#     994 # do the optimization.
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:1129, in DifferentialEvolutionSolver._calculate_population_energies(self, population)
#    1125     calc_energies = np.squeeze(calc_energies)
#    1126 except (TypeError, ValueError) as e:
#    1127     # wrong number of arguments for _mapwrapper
#    1128     # or wrong length returned from the mapper
# -> 1129     raise RuntimeError(
#    1130         "The map-like callable must be of the form f(func, iterable), "
#    1131         "returning a sequence of numbers the same length as 'iterable'"
#    1132     ) from e
#    1134 if calc_energies.size != S:
#    1135     if self.vectorized:
#
# RuntimeError: The map-like callable must be of the form f(func, iterable), returning a sequence of numbers the same length as 'iterable'

# %%
# EXAMPLE DE

import numpy as np
from scipy.optimize import differential_evolution

# Synthetic model: true IV is a known function of moneyness and maturity
def true_iv(m, t, rho, gamma):
    return 0.2 + 0.1 * (m - 1)**2 + 0.05 * t + 0.02 * abs(rho) + 0.01 * gamma

# Generate synthetic market quotes
moneyness = np.linspace(0.85, 1.15, 5)
maturity = np.linspace(0.5, 2.0, 7)
m_grid, t_grid = np.meshgrid(moneyness, maturity)
m_flat = m_grid.flatten()
t_flat = t_grid.flatten()

true_params = (-0.75, 0.2)
target_iv = true_iv(m_flat, t_flat, *true_params)

# Objective to minimize
def calibration_objective(params):
    rho, gamma = params
    predicted_iv = true_iv(m_flat, t_flat, rho, gamma)
    return np.mean((predicted_iv - target_iv)**2)

# Run DE
bounds = [(-0.85, 0.05), (0.05, 0.45)]
result = differential_evolution(calibration_objective, bounds)

print("Calibrated parameters:", result.x)
print("True parameters:", true_params)
print("Final loss:", result.fun)
# Out:
# Calibrated parameters: [-0.82250742  0.05498515]
# True parameters: (-0.75, 0.2)
# Final loss: 0.0

# %%
import numpy as np

# Observed market implied volatilities (target data)

observed_vols = np.linspace(0.2, 0.5, 35)  # Generates 35 equally spaced values

# Moneyness and time-to-maturity of the observed data
moneyness = np.linspace(0.85, 1.15, 5)  # Moneyness
maturities = np.linspace(0.5, 2.0, 7)   # Time to maturity
r = 0.03
#params = 



# Pre-trained ANN that maps Heston parameters to implied volatilities
def heston_ann(parameters):
    """
    A mock function representing the ANN (pre-trained forward pass).
    In real scenarios, this will return ANN-predicted implied volatilities.
    """
    # Example: Simple mapping for illustration
    rho, kappa, gamma, nu_bar, nu_0 = parameters
    return 0.25 + 0.05 * (moneyness - 1.0) + 0.02 * (maturities - 1.0)

# Objective function for DE calibration
def calibration_objective(parameters):
    """
    Calculates the mean squared error between ANN-predicted
    and observed market volatilities.
    """
    predicted_vols = implied_vols
    error = np.mean((predicted_vols - observed_vols) ** 2)
    return error

# %% [markdown]
# # DOWN FROM HERE EVERYTHING IS ONLY FOR LOOK UP PURPOSES

# %%
import numpy as np
import itertools

# Define Heston parameter bounds
bounds = {
    "rho": (-0.9, 0.0),         # Correlation coefficient
    "kappa": (0.1, 3.0),        # Speed of mean reversion
    "gamma": (0.01, 0.8),       # Volatility of variance
    "nu_0": (0.01, 0.5),        # Initial variance
    "nu_bar": (0.01, 0.5)       # Long-term variance
}

# Number of discrete points to sample within each parameter's range
points_per_param = 5

# Generate equally spaced points for each parameter within its bounds
parameter_points = {param: np.linspace(lower, upper, points_per_param)
                    for param, (lower, upper) in bounds.items()}

# Combine the points to form a grid of all possible parameter combinations
grid = list(itertools.product(
    parameter_points["rho"],
    parameter_points["kappa"],
    parameter_points["gamma"],
    parameter_points["nu_0"],
    parameter_points["nu_bar"]
))

# Convert the grid into a NumPy array for convenience
parameter_grid = np.array(grid)

# Display the grid details
print(f"Search space dimensions: {len(parameter_points)} parameters")
print(f"Total combinations: {parameter_grid.shape[0]}")
print("Example combinations (first 5 rows):")
print(parameter_grid[:5])

# Optional: Save to a file for later use
np.savetxt("heston_search_space.csv", parameter_grid, delimiter=",",
           header="rho,kappa,gamma,nu_0,nu_bar", comments="")

# %%
import torch
import numpy as np
from scipy.optimize import differential_evolution

def calibrate_with_de(loaded_ANN, moneyness, maturities, r, observed_vols, device="cuda"):
    """
    Calibrates Heston parameters using differential evolution and a trained ANN.
    
    Parameters:
    - loaded_ANN: Trained PyTorch ANN (set to .eval())
    - moneyness: 1D array of moneyness values (e.g., shape (5,))
    - maturities: 1D array of maturities (e.g., shape (7,))
    - r: risk-free rate (scalar)
    - observed_vols: flattened vector of observed implied vols (shape (len(moneyness) * len(maturities),))
    - device: "cuda" or "cpu"
    
    Returns:
    - result.x: optimal Heston parameters [rho, kappa, gamma, nu_bar, nu_0]
    - result.fun: final objective value (MSE)
    """

    # Make sure model is in eval mode
    loaded_ANN.eval()

    # Create full input grid for calibration
    def heston_ann(parameters):
        rho, kappa, gamma, nu_bar, nu_0 = parameters
        inputs = []

        for m in moneyness:
            for t in maturities:
                inputs.append([m, t, r, rho, kappa, nu_bar, gamma, nu_0])

        inputs = torch.tensor(inputs, dtype=torch.float32).to(device)

        with torch.no_grad():
            preds = loaded_ANN(inputs).cpu().numpy().flatten()
        return preds

    # Objective function to minimize
    def calibration_objective(parameters):
        predicted_vols = heston_ann(parameters)
        return np.mean((predicted_vols - observed_vols) ** 2)

    # Bounds for DE (adjust to your actual model/training setup)
    bounds = [
        (-0.85, 0.0),     # rho
        (0.1, 3.0),      # kappa
        (0.01, 0.8),     # gamma
        (0.01, 0.5),     # nu_bar
        (0.01, 0.5),     # nu_0
    ]

    # Run differential evolution
    result = differential_evolution(
        calibration_objective,
        bounds,
        strategy="best1bin",
        popsize=50,
        mutation=(0.5, 1.0),
        recombination=0.7,
        tol=0.001,
        disp=True
    )

    return result.x, result.fun

# %%
# Inputs
moneyness = np.linspace(0.85, 1.15, 5)
maturities = np.linspace(0.5, 2.0, 7)
r = 0.03

# Observed vols must be flat vector of shape (35,)
observed_vols = np.linspace(0.2, 0.5, 35)

# Run calibration
opt_params, final_loss = calibrate_with_de(loaded_Heston_ANN, moneyness, maturities, r, observed_vols)

print("Optimal Heston parameters:")
print(f"rho={opt_params[0]:.4f}, kappa={opt_params[1]:.4f}, gamma={opt_params[2]:.4f}, "
      f"nu_bar={opt_params[3]:.4f}, nu_0={opt_params[4]:.4f}")
print(f"Final MSE: {final_loss:.6e}")
# Out:
# differential_evolution step 1: f(x)= 0.00392477
# differential_evolution step 2: f(x)= 0.00392477
# differential_evolution step 3: f(x)= 0.00379698
# differential_evolution step 4: f(x)= 0.00376597
# differential_evolution step 5: f(x)= 0.00376597
# differential_evolution step 6: f(x)= 0.00376597
# differential_evolution step 7: f(x)= 0.0036891
# differential_evolution step 8: f(x)= 0.00364717
# differential_evolution step 9: f(x)= 0.00364717
# differential_evolution step 10: f(x)= 0.00364717
# differential_evolution step 11: f(x)= 0.00364717
# differential_evolution step 12: f(x)= 0.00364717
# differential_evolution step 13: f(x)= 0.00364717
# differential_evolution step 14: f(x)= 0.00364717
# differential_evolution step 15: f(x)= 0.00364717
# differential_evolution step 16: f(x)= 0.00364717
# differential_evolution step 17: f(x)= 0.00364717
# differential_evolution step 18: f(x)= 0.0036225
# differential_evolution step 19: f(x)= 0.0036225
# differential_evolution step 20: f(x)= 0.0036225
# differential_evolution step 21: f(x)= 0.0036225
# differential_evolution step 22: f(x)= 0.0036225
# differential_evolution step 23: f(x)= 0.0036225
# differential_evolution step 24: f(x)= 0.0036225
# differential_evolution step 25: f(x)= 0.00362203
# differential_evolution step 26: f(x)= 0.00362061
# differential_evolution step 27: f(x)= 0.00362061
# differential_evolution step 28: f(x)= 0.00361841
# differential_evolution step 29: f(x)= 0.00361841
# differential_evolution step 30: f(x)= 0.00361841
# differential_evolution step 31: f(x)= 0.00361681
# differential_evolution step 32: f(x)= 0.00361562
# differential_evolution step 33: f(x)= 0.00361163
# differential_evolution step 34: f(x)= 0.00361163
# differential_evolution step 35: f(x)= 0.00361021
# differential_evolution step 36: f(x)= 0.00361001
# differential_evolution step 37: f(x)= 0.00361001
# differential_evolution step 38: f(x)= 0.00361001
# differential_evolution step 39: f(x)= 0.0036084
# differential_evolution step 40: f(x)= 0.0036084
# differential_evolution step 41: f(x)= 0.0036084
# differential_evolution step 42: f(x)= 0.0036084
# differential_evolution step 43: f(x)= 0.0036084
# differential_evolution step 44: f(x)= 0.00360806
# differential_evolution step 45: f(x)= 0.00360787
# differential_evolution step 46: f(x)= 0.00360778
# differential_evolution step 47: f(x)= 0.00360765
# Polishing solution with 'L-BFGS-B'
# Optimal Heston parameters:
# rho=-0.1873, kappa=0.1609, gamma=0.2718, nu_bar=0.4995, nu_0=0.5000
# Final MSE: 3.607652e-03

# %%
import numpy as np

# Observed market implied volatilities (target data)

observed_vols = np.linspace(0.2, 0.5, 35)  # Generates 35 equally spaced values

# Moneyness and time-to-maturity of the observed data
moneyness = np.linspace(0.85, 1.15, 5)  # Moneyness
maturities = np.linspace(0.5, 2.0, 7)   # Time to maturity
r = 0.03
#params = 



# Pre-trained ANN that maps Heston parameters to implied volatilities
def heston_ann(parameters):
    """
    A mock function representing the ANN (pre-trained forward pass).
    In real scenarios, this will return ANN-predicted implied volatilities.
    """
    # Example: Simple mapping for illustration
    rho, kappa, gamma, nu_bar, nu_0 = parameters
    return 0.25 + 0.05 * (moneyness - 1.0) + 0.02 * (maturities - 1.0)

# Objective function for DE calibration
def calibration_objective(parameters):
    """
    Calculates the mean squared error between ANN-predicted
    and observed market volatilities.
    """
    predicted_vols = implied_vol_pipe2
    error = np.mean((predicted_vols - observed_vols) ** 2)
    return error

# %%
bounds = [
    (-0.75, -0.25),   # rho (correlation)
    (0.5, 1.0),    # kappa (mean reversion speed)
    (0.3, 0.5),   # gamma (volatility of variance)
    (0.15, 0.35),   # nu_bar (long-run variance)
    (0.5, 1.0)    # nu_0 (initial variance)
]

# %%
from scipy.optimize import differential_evolution

# Run DE to calibrate the Heston parameters
result = differential_evolution(
    calibration_objective,  # Objective function
    bounds,                 # Parameter bounds
    strategy="best1bin",    # Strategy for mutation
    popsize=50,             # Population size
    mutation=(0.5, 1.0),    # Mutation range
    recombination=0.7,      # Crossover probability
    tol=0.01,               # Convergence tolerance
    disp=True               # Display optimization progress
)

# Display calibrated parameters
print("Calibrated Parameters:", result.x)
print("Objective Function Value:", result.fun)

# %%
# Function to calculate implied volatility using Brent's method
def calc_implied_vol(dataset):
    """
    Computes implied volatilities using the Brent method.
    :param dataset: numpy array containing [S/K, T, r, OptionPrice].
    :return: A single implied volatility value.
    """
    money, T, r, market_price = dataset

    def bs_price(sigma):
        """Black-Scholes option price difference function."""
        d1 = (np.log(money) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
        d2 = d1 - sigma * np.sqrt(T)
        theoretical_price = money * norm.cdf(d1) - np.exp(-r * T) * norm.cdf(d2)
        return theoretical_price - market_price

    # Solve for implied volatility
    try:
        return optimize.brentq(bs_price, 1e-5, 5, maxiter=100)
    except ValueError:
        return np.nan  # Return NaN if Brent fails to converge

# Data generation or loading
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds=l_bounds, u_bounds=u_bounds)
hs_data_loader = DataLoader(hs_dataset, batch_size=4048)

# Step 1: Compute prices using Heston-ANN
predicted_prices = []
with torch.no_grad():
    for data in hs_data_loader:
        inputs = data[:, :-1].to(device)  # Exclude the last column if it's labels
        outputs = loaded_Heston_ANN(inputs)
        predicted_prices.append(outputs.cpu().numpy())
predicted_prices = np.concatenate(predicted_prices)

# Step 2: Prepare the dataset for Brent's method
# Combine predicted prices with necessary inputs for implied volatility calculation
# Assuming hs_dataset.data contains [S/K, T, r, actual_price]:
hs_dataset_data = hs_dataset.data[:, np.array([0, 1, 2])]  # Extract relevant columns
hs_dataset_data = np.hstack((hs_dataset_data, predicted_prices.reshape(-1, 1)))

# Step 3: Calculate implied volatilities
implied_volatilities = np.apply_along_axis(calc_implied_vol, 1, hs_dataset_data)

# Step 4: Evaluate results
# Assuming you have ground-truth implied volatilities for comparison
ground_truth_vol = hs_dataset.data[:, 3]  # Replace with actual column for ground truth
mse = ((ground_truth_vol - implied_volatilities) ** 2).mean()
print(f"MSE: {mse:.6e}")

# %%
# Loading Train / Test Data
hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0]-train_size])
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}
train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs, targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs, targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs, targets)) )
print("R2 {:e}".format(r2_score(outputs, targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs, targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs, targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs, targets)) )
print("R2 {:e}".format(r2_score(outputs, targets)) )

# %%
np.sqrt(1.670718e-07)
print("MSE {:e}".format(np.sqrt(1.670718e-07)) )

# %% [markdown]
# # DOWN FROM HERE EVERYTHING IS ONLY FOR LOOK UP PURPOSES

# %% [markdown]
# # 5) BRENT

# %% [markdown]
# # 6) Pipeline 1: COS + BRENT

# %%
eps = 1e-2 # is used to generate open intervals
# (S/K), (tau), (r), (rho), (kappa), (vbar), (gamma), (v0).
# CASE 1 in table 11
l_bounds = [.75+eps, .4+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps]
u_bounds = [1.25-eps, 1.0-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds = l_bounds, u_bounds=u_bounds)
hs_dataset_data = hs_dataset.data
hs_dataset_data = hs_dataset_data[:,np.array([0,1,2,8])]
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, hs_dataset_data)

# %% [markdown]
# # 7) Pipeline 2: Heston-ANN + IV-ANN

# %%
# Loading model
device = torch.device("cuda")
loaded_Heston_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_ANN.pt"
loaded_Heston_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_ANN.eval()

# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

# Loading model 
device = torch.device("cuda")
loaded_IV_ANN = IV_ANN().to(device)
PATH = "ANN_weights/IV_SCALED_ANN.pt"
loaded_IV_ANN.load_state_dict(torch.load(PATH))
loaded_IV_ANN.eval()


# Plugging in the Heston-ANN prices
hs_dataset2 = hs_dataset.data[:,np.array([0,1,2,8])]
hs_dataset2.data[:,3] = torch.FloatTensor(prices)
loader2 = torch.utils.data.DataLoader(hs_dataset2, 4048)

# Computing IVs
implied_vol = []
indecies_list = []
with torch.no_grad():
  for idx, data in enumerate(loader2):
    data = data.to(device)
    # LOG Transformation
    data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
    data[:,3] = torch.log(data[:,3])
    output = loaded_IV_ANN(data)
    implied_vol.append((output).data.cpu().numpy())
  implied_vol_pipe2 = np.concatenate(implied_vol)
  # indecies_list = np.concatenate(indecies_list).flatten()

# %%
# Eliminating Nan values resulting from prices lower than 1e-7
indecies = np.argwhere(np.isnan(implied_vol_pipe2))
implied_vol_pipe1 = np.delete(implied_vol_pipe1, indecies,0)
implied_vol_pipe2 = np.delete(implied_vol_pipe2, indecies,0)

# %% [markdown]
# # 8) Pipeline 1 VS pipeline 2

# %%
# CASE 1
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
#targets = vol_imp
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )

# %%
# CASE 2
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )

# %% [markdown]
# # 9) Volatility surface (COS + IV-ANN)

# %% [markdown]
# ### Initial volatility surface

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
moyeness = np.linspace(moyeness, 1.24,11)
tau = np.linspace(tau, 1, 6)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(66)).reshape((-1, 1))

# %%
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  bs_IV = (output).data.cpu().numpy()

X = X.flatten()
Y = Y.flatten()
Z = bs_IV

x = np.reshape(X, (-1, 6))
y = np.reshape(Y, (-1, 6))
z = np.reshape(Z, (-1, 6))

# %%
from mpl_toolkits import mplot3d
from matplotlib import cm

# %%
# Plotting the initial volatility surface
plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to matuirity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Smoothing the volatility surface

# %%
from scipy import interpolate

# %%
# Smoothing the volatility surface
xnew, ynew = x.copy(), y.copy()
tck = interpolate.bisplrep(x, y, z, s=1.0)
znew = interpolate.bisplev(xnew[:,0], ynew[0,:], tck)

plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(xnew, ynew, znew,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to maturity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Implied volatility difference

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
n_moneyness = 11
n_tau = 6
moyeness = np.linspace(moyeness, 1.24,n_moneyness)
tau = np.linspace(tau, 1, n_tau)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
rho = np.array(rho*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
kappa = np.array(kappa*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
vbar = np.array(vbar*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
gamma = np.array(gamma*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
v0 = np.array(v0*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(n_tau * n_moneyness)).reshape((-1, 1))

# %%
data_ann = np.concatenate((X, Y, r, rho, kappa, vbar, gamma, v0, cos_prices), axis = 1)
data_ann = torch.FloatTensor(data_ann)
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  implied_vol_pipe2 = (output).data.cpu().numpy()

# %%
X = X.flatten()
Y = Y.flatten()
Z = (implied_vol_pipe1 - implied_vol_pipe2).flatten()

x = np.reshape(X, (-1, min(n_moneyness, n_tau)))
y = np.reshape(Y, (-1, min(n_moneyness, n_tau)))
z = np.reshape(Z, (-1, min(n_moneyness, n_tau)))

plt.figure(figsize=(8,8))
plt.pcolormesh(x, y, z, shading='gouraud')
plt.colorbar()
plt.xlabel("Moneyness")
plt.ylabel("Time to maturity")
plt.show()

# %%
# Re-import necessary libraries and re-define the setup after reset
from scipy.optimize import differential_evolution
import numpy as np

# Define the objective function
def objective_function(x):
    # Example: A simple quadratic function
    return x[0]**2 + x[1]**2 + x[2]**2

# Define the bounds for each variable
bounds = [(-10, 10), (-10, 10), (-10, 10)]  # Variable bounds for a 3D problem

# Run Differential Evolution with the specified settings
result_custom_de = differential_evolution(
    objective_function,  # Objective function
    bounds,             # Variable bounds
    strategy="best1bin",  # Strategy
    popsize=50,          # Population size
    mutation=(0.5, 1.0), # Mutation range
    recombination=0.7,   # Crossover probability
    tol=0.01,            # Convergence tolerance
    disp=False           # Suppress output during the run
)

# Display the result
result_custom_de
