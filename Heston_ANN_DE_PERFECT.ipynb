# %% [markdown]
# # Pricing vanilla call options and computing implied volatilities using neural networks

# %%
# Basic imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# Updating scipy to use module QMC for Latin hypercube sampling
#!pip install scipy==1.7
from scipy.stats import qmc

# Pytorch imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR, LinearLR, OneCycleLR, LambdaLR

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %%
def bs_price_call(S, K, T, t, r, sigma):
  """
  Black-Scholes call option value price related to PDE (2). Returns option's price.
  S: spot price
  K: strike price
  T: time to maturity
  t: spot time
  r: interest rate
  sigma: volatility of underlying asset
  """

  # Boundary condition of Black-Sholes PDE (2)
  if T == t:
    return np.maximum(0, S - K)  
  # Solution of the PDE (2) on the open interval [t, T)
  else : 
    d1 = ( np.log(S / K) + (r + 0.5 * sigma ** 2) * (T-t) ) / (sigma * np.sqrt(T-t))
    d2 = d1 - sigma*np.sqrt(T-t)
    value = S * norm.cdf(d1) - K * np.exp(-r * (T-t)) * norm.cdf(d2) 
  
  return value

def bs_moneyness_call(moneyness, tau, r, sigma):
  """
  Same function as bs_price_call but in terms of moneyness. Returns V/K and 
  has S/K instead of two seperate paremeters S and K.
  moneyness: S/K
  Tau: time to maturity minus spot time
  r: interest rate
  sigma: volatility of underlying asset
  """

  d1 = ( np.log(moneyness) + (r + 0.5 * sigma ** 2) * (tau) ) / (sigma * np.sqrt(tau))
  d2 = d1 - sigma*np.sqrt(tau)
  value_moneyness = moneyness * norm.cdf(d1) - np.exp(-r * (tau)) * norm.cdf(d2) 
  
  return value_moneyness

# %% [markdown]
# ### Data generation

# %% [markdown]
# ### Defining class BS-ANN

# %%
class BS_ANN(nn.Module):
  def __init__(self):
    """
    Initilize BS-ANN netwwork with four hidden layers. 
    Same architecture as the one used in table 2.
    Weight are initialized using Glorot_uniform also known as Xavier_uniform.
    """
    super(BS_ANN, self).__init__()
    # 4 layers
    self.fc1 = nn.Linear(4, 400)
    self.fc2 = nn.Linear(400, 400)
    self.fc3 = nn.Linear(400, 400)
    self.fc4 = nn.Linear(400, 400)
    self.fc5 = nn.Linear(400, 1)
    # initilizing the layer's weights
    torch.nn.init.xavier_uniform_(self.fc1.weight)
    torch.nn.init.xavier_uniform_(self.fc2.weight)
    torch.nn.init.xavier_uniform_(self.fc3.weight)
    torch.nn.init.xavier_uniform_(self.fc4.weight)
    torch.nn.init.xavier_uniform_(self.fc5.weight)


  def forward(self, x):
    """
    Foward pass of the network. 
    Relu activations are used and a linear activation is used in the final layer.
    x: input torch tensor (CUDA or CPU)
    """
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = F.relu(self.fc3(x))
    x = F.relu(self.fc4(x))
    x = self.fc5(x)
    return x.flatten()

  def train_model(self, args, device, train_loader, optimizer, epoch):
    """
    Training over train_loader batches for one epoch.
    Returns average training loss.
    args: training parameters.
    device: CUDA or CPU.
    train_loader: train data loader.
    optimizer: gradient descent optmizer.
    epoch: current epoch.
    """
    # train mode
    self.train()
    train_loss = 0
    # loop over data loader
    for batch_idx, data in enumerate(train_loader):
      # extracting the inputs and target
      data, target = data[:,:-1].to(device), data[:,-1].to(device)
      # zeroing the gradients
      optimizer.zero_grad()
      # foward pass
      output = self(data)
      # computing the loss
      loss = F.mse_loss(output, target)
      train_loss += loss.item() * data.shape[0]
      # back propagation
      loss.backward()
      # updating the optimizer step
      optimizer.step()
      # printing batch information
      if batch_idx % args["log_interval"] == 0:
        print('Train Epoch: {} [{}/{} ({:.0f}%)]\tlog Loss: {:.6f}'.format(
            epoch, int(batch_idx / len(train_loader)*len(train_loader.dataset)), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), np.log(loss.item())))
        if args["dry_run"]:
          break
    train_loss /= len(train_loader.dataset)
    print('\nTrain set: Average log loss: {:.4f}\n'.format(np.log(train_loss))) 
    return train_loss


  def test_model(self, device, test_loader):
    """
    Testing over test_loader batches for one epoch. 
    Returns average test loss.
    device: CUDA or CPU.
    test_loader: test data loader.
    """
    # evaluation mode
    self.eval()
    test_loss = 0
    # freezing the gradients
    with torch.no_grad():
      # looping over the test laoder
      for data in test_loader:
        # extracting the inputs and target
        data, target = data[:,:-1].to(device), data[:,-1].to(device)
        # foward pass
        output = self(data)
        #computing the loss
        test_loss += F.mse_loss(output, target, reduction = 'sum').item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}\n'.format(np.log(test_loss))) 
    return test_loss

# %% [markdown]
# # 3) COS Method

# %% [markdown]
# #### Vanilla call coefficients

# %% [markdown]
# $\begin{aligned} \chi_{k}(c, d):=& \frac{1}{1+\left(\frac{k \pi}{b-a}\right)^{2}}\left[\cos \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\cos \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right.\\ &\left.+\frac{k \pi}{b-a} \sin \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\frac{k \pi}{b-a} \sin \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right] \end{aligned}$

# %% [markdown]
# $\psi_{k}(c, d):= \begin{cases}{\left[\sin \left(k \pi \frac{d-a}{b-a}\right)-\sin \left(k \pi \frac{c-a}{b-a}\right)\right] \frac{b-a}{k \pi},} & k \neq 0, \\ (d-c), & k=0 .\end{cases}$

# %% [markdown]
# $V_{k}^{\text {call }}=\frac{2}{b-a} K\left(\chi_{k}(0, b)-\psi_{k}(0, b)\right)$

# %%
def call_cosine_coef(a, b, c, d, K, N):
  """
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  K: Strike.
  N: summing lenght.
  Returns V_k coefficient for call option.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*K*(chi_k-psi_k)

# %%
def call_cosine_coef_moy(a, b, c, d, N):
  """
  Moyeness version.
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  N: summing lenght.
  Returns V_k coefficient for call option devided by K.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*(chi_k-psi_k)

# %% [markdown]
# #### Charateristic function for Heston model

# %% [markdown]
# $\begin{aligned} \varphi_{h e s}\left(\omega ; u_{0}\right)=& \exp \left(i \omega \mu \Delta t+\frac{u_{0}}{\eta^{2}}\left(\frac{1-e^{-D \Delta t}}{1-G e^{-D \Delta t}}\right)(\lambda-i \rho \eta \omega-D)\right) \\ & \cdot \exp \left(\frac{\lambda \bar{u}}{\eta^{2}}\left(\Delta t(\lambda-i \rho \eta \omega-D)-2 \log \left(\frac{1-G e^{-D \Delta t}}{1-G}\right)\right)\right) \end{aligned}$

# %% [markdown]
# $D=\sqrt{(\lambda-i \rho \eta \omega)^{2}+\left(\omega^{2}+i \omega\right) \eta^{2}} \quad$ and $\quad G=\frac{\lambda-i \rho \eta \omega-D}{\lambda-i \rho \eta \omega+D} $

# %%
def phi_Heston(a ,b ,N ,r, tau, kappa, gamma, vbar, v0, rho):
  """
  Characteristic function of the log-asset price following the Heston model.
  Section 3.3, equation (33).
  a, b: truncation range parameters.
  N: summing lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns Charateristic function vector.
  """
  k = np.arange(N).reshape(1,-1)
  u = np.pi*k/(b-a)
  i = complex(0.0,1.0)
  D = np.sqrt((kappa-gamma*rho*i*u)**2+(u**2+i*u)*gamma**2)
  G = (kappa-gamma*rho*i*u-D)/(kappa-gamma*rho*i*u+D)
  C = v0* (1-np.exp(-D*tau)) / (gamma**2*(1-G*np.exp(-D*tau)))*(kappa-gamma*rho*i*u-D)
  A = r*i*u*tau + kappa*vbar/(gamma**2)*(tau*(kappa-gamma*rho*i*u-D) -2*np.log( (1-G*np.exp(-D*tau))/(1-G) )   ) 
  phi = np.exp( A + C )
  return phi

# %% [markdown]
# #### Heston cumulants

# %% [markdown]
# $c_{1}=\mu T+\left(1-e^{-\lambda T}\right) \frac{\bar{u}-u_{0}}{2 \lambda}-\frac{1}{2} \bar{u} T$

# %% [markdown]
# $\begin{aligned} c_{2}=& \frac{1}{8 \lambda^{3}}\left(\eta T \lambda e^{-\lambda T}\left(u_{0}-\bar{u}\right)(8 \lambda \rho-4 \eta)\right.\\ &+\lambda \rho \eta\left(1-e^{-\lambda T}\right)\left(16 \bar{u}-8 u_{0}\right) \\ &+2 \bar{u} \lambda T\left(-4 \lambda \rho \eta+\eta^{2}+4 \lambda^{2}\right) \\ &+\eta^{2}\left(\left(\bar{u}-2 u_{0}\right) e^{-2 \lambda T}+\bar{u}\left(6 e^{-\lambda T}-7\right)+2 u_{0}\right) \\ &\left.+8 \lambda^{2}\left(u_{0}-\bar{u}\right)\left(1-e^{-\lambda T}\right)\right) \end{aligned}$

# %%
def Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho ):
  """
  Computes Heston cumulants as defined in the appendix A for the Heston model.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns cumulants c1 and c2.
  """
  c1 = r * tau + (1 - np.exp(- kappa * tau)) * (vbar - v0) / (2 * kappa) - 0.5 * vbar * tau
  
  c2 = 0.125 / kappa ** 3 * (gamma * tau * np.exp(- kappa * tau) * (v0 - vbar) * (8 * kappa * rho - 4 * gamma) + \
     kappa * rho * gamma * (1 - np.exp(- kappa * tau)) * (16 * vbar - 8 * v0) + \
     2 * vbar * kappa * tau * (- 4 * kappa * rho * gamma + gamma ** 2 + 4 * kappa ** 2) + \
     gamma ** 2 * ((vbar - 2 * v0) * np.exp(-2 * kappa * tau) + vbar * (6 * np.exp(- kappa * tau) - 7) + 2 * v0) + \
     8 * kappa ** 2 * (v0 - vbar) * (1 - np.exp(-kappa * tau)))
  return c1, c2

# %% [markdown]
# #### Truncation range

# %% [markdown]
# $[a, b]:=\left[c_{1}-L \sqrt{c_{2}+\sqrt{c_{4}}}, \quad c_{1}+L \sqrt{c_{2}+\sqrt{c_{4}}}\right]$

# %%
def Truncation_range(c1, c2, c4, L):
  """
  Computes the truncation range given the cumulants c1, c2, c4 and the truncation lenght L.
  c1, c2, c4: Model cumulants.
  L: truncation lenght.
  Returns tuncation interval sup b and inf a.
  """
  a = c1 - L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) )
  b = c1 + L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) ) 
  return a, b

# %% [markdown]
# #### Exponential coefficient

# %% [markdown]
# $e^{i k \pi \frac{\mathbf{x}-a}{b-a}}$

# %%
def exponential_coef(a, b, N, S0, K):
  """
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  S0: asset initial price.
  K: strike.
  Returns the exponential coefficient vector.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(S0/K)-a)/(b-a))

# %%
def exponential_coef_moy(a, b, N, moyeness):
  """
  Moyeness version.
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  moyeness: S/K.
  Returns the exponential coefficient vector devided by K.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(moyeness)-a)/(b-a))

# %% [markdown]
# #### Vanilla call price

# %% [markdown]
# $v\left(\mathbf{x}, t_{0}, u_{0}\right) \approx \mathbf{K} e^{-r \Delta t} \cdot \operatorname{Re}\left\{\sum_{k=0}^{N-1} \varphi_{h e s}\left(\frac{k \pi}{b-a} ; u_{0}\right) U_{k} \cdot e^{i k \pi \frac{\mathbf{x}-a}{b-a}}\right\}$

# %%
def call_option_Heston(N, L, r, tau, kappa, gamma, vbar, v0, rho, K, S0 ):
  """
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  S0: asset initial price.
  K: strike.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef(a, b, c, d, K, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef(a, b, N, S0, K)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, K = K, S0 = S0)
# Out:
# True
# array([[29.79261082]])

# %%
def call_option_Heston_moy(N, L, r, tau, kappa, gamma, vbar, v0, rho, moyeness ):
  """
  Moyeness version.
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  moyeness: S/K.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef_moy(a, b, c, d, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef_moy(a, b, N, moyeness)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston_moy(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = 1)
# Out:
# True
# array([[0.29792611]])

# %% [markdown]
# # 4) Heston pricing network: Heston-ANN

# %% [markdown]
# ### Generating Data

# %%
# Table 3 of Liu et al.
# moneyness m =
eps = 1e-2 # is used to generate open intervals
def Heston_LHS_data_generator(n = 10**6, l_bounds = [.6+eps, .05+eps, .0+eps, -0.9+eps, 0.4+eps, .01+eps, .01+eps, .05+eps], u_bounds = [1.4-eps, 3.0-eps, .05-eps, 0.0-eps, 3.0-eps, .5-eps, .8-eps, .5-eps]):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,9) containig the inputs samples and the value of the call.
  The inputs are: Moyeness (S/K), time to maturity (tau), Risk free rate (r), Correlation (rho), reversion speed (kappa), Long average variance (vbar), Vol of vol (gamma), Initial variance (v0).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.
  """
  sampler = qmc.LatinHypercube(d = 8) #, seed = 0
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  indecies = np.argwhere(2*sample[:,4]*sample[:,5] <= sample[:,6]**2)
  sample = np.delete(sample, indecies, 0)
  hs_prices = call_option_Heston_moy(N = 160, L= 12, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa = sample[:,4].reshape((-1,1)),\
                                     gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
                                     rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  # hs_prices = call_option_Heston_moy(N = 1500, L= 50, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
  #                                    gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
  #                                    rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))

  hs_dataset = np.concatenate((sample, hs_prices),axis=1)

  print("------ INPUT ------")
  print("S/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,0]), max(hs_dataset[:,0])))
  print("Tau.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,1]), max(hs_dataset[:,1])))
  print("r............ [{:.2f} {:.2f}]".format(min(hs_dataset[:,2]), max(hs_dataset[:,2])))
  print("Corr ........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,3]), max(hs_dataset[:,3])))
  print("Kappa........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,4]), max(hs_dataset[:,4])))
  print("V_bar........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,5]), max(hs_dataset[:,5])))
  print("Gamma........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,6]), max(hs_dataset[:,6])))
  print("V_0 ......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,7]), max(hs_dataset[:,7])))
  print("------ OUTPUT ------")
  print("V/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,-1]), max(hs_dataset[:,-1])))
  # ind_max = np.argmax(hs_dataset[:,-1])
  # print(hs_dataset[ind_max,:])

  return torch.FloatTensor(hs_dataset)

hs_dataset = Heston_LHS_data_generator(10**4)
# Out:
# ------ INPUT ------
# S/K.......... [0.61 1.39]
# Tau.......... [0.06 2.99]
# r............ [0.01 0.04]
# Corr ........ [-0.89 -0.01]
# Kappa........ [0.41 2.99]
# V_bar........ [0.02 0.49]
# Gamma........ [0.02 0.79]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00 0.75]

# %% [markdown]
# ### Defining class Heston-ANN

# %%
class Heston_ANN(BS_ANN):
  def __init__(self):
    """
    Initilize BS-Heston_ANN netwwork. Same architecture as the one used in tge article.
    Weight are initialized using Glorot_uniform also known as Xavier_uniform.
    Takes inputs of size 8.
    """
    super(Heston_ANN, self).__init__()
    self.fc1 = nn.Linear(8, 200)
    self.fc2 = nn.Linear(200, 200)
    self.fc3 = nn.Linear(200, 200)
    self.fc4 = nn.Linear(200, 200)
    self.fc5 = nn.Linear(200, 1)

    torch.nn.init.xavier_uniform_(self.fc1.weight)
    torch.nn.init.xavier_uniform_(self.fc2.weight)
    torch.nn.init.xavier_uniform_(self.fc3.weight)
    torch.nn.init.xavier_uniform_(self.fc4.weight)
    torch.nn.init.xavier_uniform_(self.fc5.weight)

# %% [markdown]
# ### Training Heston-ANN

# %%
# Training parameters
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 8*10**3,
         "lr": 1e-4,
         "gamma": .5,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}



use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# torch.manual_seed(args["seed"])


# Loading Train / Test Data
hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0] - train_size])

train_loader = torch.utils.data.DataLoader(train_dataset, args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])


# Model training
print(device)
model = Heston_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=args["lr"]) # Adam is found to be the best optimizer in the article
scheduler = StepLR(optimizer, step_size=500, gamma=args["gamma"]) # Deacreses the Learning rate by .5 every 500 epoch

train_losses = []
test_losses = []
for epoch in range(1, args["epochs"] + 1):
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
if args["save_model"] :
  torch.save(model.state_dict(), "Heston_ANN_DE.pt")
# Out:
# ------ INPUT ------
# S/K.......... [0.61 1.39]
# Tau.......... [0.06 2.99]
# r............ [0.01 0.04]
# Corr ........ [-0.89 -0.01]
# Kappa........ [0.41 2.99]
# V_bar........ [0.02 0.49]
# Gamma........ [0.02 0.79]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00 0.77]
# cuda
# Train Epoch: 1 [0/77415 (0%)]	log Loss: -2.282897
#
# Train set: Average log loss: -3.8500
#
#
# Test set: Average loss: -5.1445
#
# Current Learning rate 0.0001
# Train Epoch: 2 [0/77415 (0%)]	log Loss: -5.131303
#
# Train set: Average log loss: -6.3284
#
#
# Test set: Average loss: -7.2767
#
# Current Learning rate 0.0001
# Train Epoch: 3 [0/77415 (0%)]	log Loss: -7.369640
#
# Train set: Average log loss: -7.5833
#
#
# Test set: Average loss: -7.8675
#
# Current Learning rate 0.0001
# Train Epoch: 4 [0/77415 (0%)]	log Loss: -8.011238
#
# Train set: Average log loss: -8.1601
#
#
# Test set: Average loss: -8.3904
#
# Current Learning rate 0.0001
# Train Epoch: 5 [0/77415 (0%)]	log Loss: -8.577625
#
# Train set: Average log loss: -8.5981
#
#
# Test set: Average loss: -8.7425
#
# Current Learning rate 0.0001
# Train Epoch: 6 [0/77415 (0%)]	log Loss: -8.960699
#
# Train set: Average log loss: -8.9055
#
#
# Test set: Average loss: -9.0032
#
# Current Learning rate 0.0001
# Train Epoch: 7 [0/77415 (0%)]	log Loss: -9.216740
#
# Train set: Average log loss: -9.1453
#
#
# Test set: Average loss: -9.2280
#
# Current Learning rate 0.0001
# Train Epoch: 8 [0/77415 (0%)]	log Loss: -9.411918
#
# Train set: Average log loss: -9.3375
#
#
# Test set: Average loss: -9.4059
#
# Current Learning rate 0.0001
# Train Epoch: 9 [0/77415 (0%)]	log Loss: -9.568335
#
# Train set: Average log loss: -9.4828
#
#
# Test set: Average loss: -9.5420
#
# Current Learning rate 0.0001
# Train Epoch: 10 [0/77415 (0%)]	log Loss: -9.696539
#
# Train set: Average log loss: -9.6035
#
#
# Test set: Average loss: -9.6558
#
# Current Learning rate 0.0001
# Train Epoch: 11 [0/77415 (0%)]	log Loss: -9.799935
#
# Train set: Average log loss: -9.7012
#
#
# Test set: Average loss: -9.7433
#
# Current Learning rate 0.0001
# Train Epoch: 12 [0/77415 (0%)]	log Loss: -9.877745
#
# Train set: Average log loss: -9.7850
#
#
# Test set: Average loss: -9.7825
#
# Current Learning rate 0.0001
# Train Epoch: 13 [0/77415 (0%)]	log Loss: -9.900389
#
# Train set: Average log loss: -9.8638
#
#
# Test set: Average loss: -9.8093
#
# Current Learning rate 0.0001
# Train Epoch: 14 [0/77415 (0%)]	log Loss: -9.917043
#
# Train set: Average log loss: -9.9384
#
#
# Test set: Average loss: -9.8785
#
# Current Learning rate 0.0001
# Train Epoch: 15 [0/77415 (0%)]	log Loss: -9.983600
#
# Train set: Average log loss: -10.0045
#
#
# Test set: Average loss: -9.9684
#
# Current Learning rate 0.0001
# Train Epoch: 16 [0/77415 (0%)]	log Loss: -10.075753
#
# Train set: Average log loss: -10.0610
#
#
# Test set: Average loss: -10.0635
#
# Current Learning rate 0.0001
# Train Epoch: 17 [0/77415 (0%)]	log Loss: -10.174940
#
# Train set: Average log loss: -10.1204
#
#
# Test set: Average loss: -10.1627
#
# Current Learning rate 0.0001
# Train Epoch: 18 [0/77415 (0%)]	log Loss: -10.284119
#
# Train set: Average log loss: -10.1843
#
#
# Test set: Average loss: -10.2463
#
# Current Learning rate 0.0001
# Train Epoch: 19 [0/77415 (0%)]	log Loss: -10.377832
#
# Train set: Average log loss: -10.2544
#
#
# Test set: Average loss: -10.2938
#
# Current Learning rate 0.0001
# Train Epoch: 20 [0/77415 (0%)]	log Loss: -10.425122
#
# Train set: Average log loss: -10.3139
#
#
# Test set: Average loss: -10.3306
#
# Current Learning rate 0.0001
# Train Epoch: 21 [0/77415 (0%)]	log Loss: -10.460906
#
# Train set: Average log loss: -10.3569
#
#
# Test set: Average loss: -10.3494
#
# Current Learning rate 0.0001
# Train Epoch: 22 [0/77415 (0%)]	log Loss: -10.474370
#
# Train set: Average log loss: -10.4038
#
#
# Test set: Average loss: -10.4326
#
# Current Learning rate 0.0001
# Train Epoch: 23 [0/77415 (0%)]	log Loss: -10.568249
#
# Train set: Average log loss: -10.4585
#
#
# Test set: Average loss: -10.5020
#
# Current Learning rate 0.0001
# Train Epoch: 24 [0/77415 (0%)]	log Loss: -10.656849
#
# Train set: Average log loss: -10.5088
#
#
# Test set: Average loss: -10.5180
#
# Current Learning rate 0.0001
# Train Epoch: 25 [0/77415 (0%)]	log Loss: -10.676810
#
# Train set: Average log loss: -10.5557
#
#
# Test set: Average loss: -10.5357
#
# Current Learning rate 0.0001
# Train Epoch: 26 [0/77415 (0%)]	log Loss: -10.689633
#
# Train set: Average log loss: -10.5741
#
#
# Test set: Average loss: -10.5091
#
# Current Learning rate 0.0001
# Train Epoch: 27 [0/77415 (0%)]	log Loss: -10.653348
#
# Train set: Average log loss: -10.5875
#
#
# Test set: Average loss: -10.5175
#
# Current Learning rate 0.0001
# Train Epoch: 28 [0/77415 (0%)]	log Loss: -10.654052
#
# Train set: Average log loss: -10.6274
#
#
# Test set: Average loss: -10.6244
#
# Current Learning rate 0.0001
# Train Epoch: 29 [0/77415 (0%)]	log Loss: -10.762089
#
# Train set: Average log loss: -10.6704
#
#
# Test set: Average loss: -10.7059
#
# Current Learning rate 0.0001
# Train Epoch: 30 [0/77415 (0%)]	log Loss: -10.840513
#
# Train set: Average log loss: -10.7082
#
#
# Test set: Average loss: -10.7225
#
# Current Learning rate 0.0001
# Train Epoch: 31 [0/77415 (0%)]	log Loss: -10.854839
#
# Train set: Average log loss: -10.7446
#
#
# Test set: Average loss: -10.7225
#
# Current Learning rate 0.0001
# Train Epoch: 32 [0/77415 (0%)]	log Loss: -10.847405
#
# Train set: Average log loss: -10.7599
#
#
# Test set: Average loss: -10.7451
#
# Current Learning rate 0.0001
# Train Epoch: 33 [0/77415 (0%)]	log Loss: -10.862922
#
# Train set: Average log loss: -10.7739
#
#
# Test set: Average loss: -10.7476
#
# Current Learning rate 0.0001
# Train Epoch: 34 [0/77415 (0%)]	log Loss: -10.857573
#
# Train set: Average log loss: -10.7914
#
#
# Test set: Average loss: -10.7768
#
# Current Learning rate 0.0001
# Train Epoch: 35 [0/77415 (0%)]	log Loss: -10.878035
#
# Train set: Average log loss: -10.8089
#
#
# Test set: Average loss: -10.8439
#
# Current Learning rate 0.0001
# Train Epoch: 36 [0/77415 (0%)]	log Loss: -10.941203
#
# Train set: Average log loss: -10.8260
#
#
# Test set: Average loss: -10.9027
#
# Current Learning rate 0.0001
# Train Epoch: 37 [0/77415 (0%)]	log Loss: -10.994876
#
# Train set: Average log loss: -10.8393
#
#
# Test set: Average loss: -10.9420
#
# Current Learning rate 0.0001
# Train Epoch: 38 [0/77415 (0%)]	log Loss: -11.029242
#
# Train set: Average log loss: -10.8582
#
#
# Test set: Average loss: -10.9744
#
# Current Learning rate 0.0001
# Train Epoch: 39 [0/77415 (0%)]	log Loss: -11.056642
#
# Train set: Average log loss: -10.8767
#
#
# Test set: Average loss: -11.0045
#
# Current Learning rate 0.0001
# Train Epoch: 40 [0/77415 (0%)]	log Loss: -11.084459
#
# Train set: Average log loss: -10.8919
#
#
# Test set: Average loss: -11.0330
#
# Current Learning rate 0.0001
# Train Epoch: 41 [0/77415 (0%)]	log Loss: -11.110094
#
# Train set: Average log loss: -10.9101
#
#
# Test set: Average loss: -11.0595
#
# Current Learning rate 0.0001
# Train Epoch: 42 [0/77415 (0%)]	log Loss: -11.134840
#
# Train set: Average log loss: -10.9259
#
#
# Test set: Average loss: -11.0861
#
# Current Learning rate 0.0001
# Train Epoch: 43 [0/77415 (0%)]	log Loss: -11.159348
#
# Train set: Average log loss: -10.9418
#
#
# Test set: Average loss: -11.1101
#
# Current Learning rate 0.0001
# Train Epoch: 44 [0/77415 (0%)]	log Loss: -11.179942
#
# Train set: Average log loss: -10.9590
#
#
# Test set: Average loss: -11.1328
#
# Current Learning rate 0.0001
# Train Epoch: 45 [0/77415 (0%)]	log Loss: -11.199833
#
# Train set: Average log loss: -10.9763
#
#
# Test set: Average loss: -11.1534
#
# Current Learning rate 0.0001
# Train Epoch: 46 [0/77415 (0%)]	log Loss: -11.216505
#
# Train set: Average log loss: -10.9902
#
#
# Test set: Average loss: -11.1745
#
# Current Learning rate 0.0001
# Train Epoch: 47 [0/77415 (0%)]	log Loss: -11.236533
#
# Train set: Average log loss: -11.0085
#
#
# Test set: Average loss: -11.1896
#
# Current Learning rate 0.0001
# Train Epoch: 48 [0/77415 (0%)]	log Loss: -11.253198
#
# Train set: Average log loss: -11.0242
#
#
# Test set: Average loss: -11.1993
#
# Current Learning rate 0.0001
# Train Epoch: 49 [0/77415 (0%)]	log Loss: -11.264567
#
# Train set: Average log loss: -11.0416
#
#
# Test set: Average loss: -11.1986
#
# Current Learning rate 0.0001
# Train Epoch: 50 [0/77415 (0%)]	log Loss: -11.266108
#
# Train set: Average log loss: -11.0596
#
#
# Test set: Average loss: -11.1893
#
# Current Learning rate 0.0001
# Train Epoch: 51 [0/77415 (0%)]	log Loss: -11.254418
#
# Train set: Average log loss: -11.0879
#
#
# Test set: Average loss: -11.1482
#
# Current Learning rate 0.0001
# Train Epoch: 52 [0/77415 (0%)]	log Loss: -11.210775
#
# Train set: Average log loss: -11.1317
#
#
# Test set: Average loss: -11.1060
#
# Current Learning rate 0.0001
# Train Epoch: 53 [0/77415 (0%)]	log Loss: -11.163302
#
# Train set: Average log loss: -11.1700
#
#
# Test set: Average loss: -11.0968
#
# Current Learning rate 0.0001
# Train Epoch: 54 [0/77415 (0%)]	log Loss: -11.150672
#
# Train set: Average log loss: -11.1676
#
#
# Test set: Average loss: -11.0138
#
# Current Learning rate 0.0001
# Train Epoch: 55 [0/77415 (0%)]	log Loss: -11.060453
#
# Train set: Average log loss: -11.1504
#
#
# Test set: Average loss: -11.0308
#
# Current Learning rate 0.0001
# Train Epoch: 56 [0/77415 (0%)]	log Loss: -11.075695
#
# Train set: Average log loss: -11.1476
#
#
# Test set: Average loss: -11.0310
#
# Current Learning rate 0.0001
# Train Epoch: 57 [0/77415 (0%)]	log Loss: -11.074029
#
# Train set: Average log loss: -11.1516
#
#
# Test set: Average loss: -11.0107
#
# Current Learning rate 0.0001
# Train Epoch: 58 [0/77415 (0%)]	log Loss: -11.050293
#
# Train set: Average log loss: -11.1604
#
#
# Test set: Average loss: -10.9891
#
# Current Learning rate 0.0001
# Train Epoch: 59 [0/77415 (0%)]	log Loss: -11.025337
#
# Train set: Average log loss: -11.1809
#
#
# Test set: Average loss: -11.0016
#
# Current Learning rate 0.0001
# Train Epoch: 60 [0/77415 (0%)]	log Loss: -11.037207
#
# Train set: Average log loss: -11.2028
#
#
# Test set: Average loss: -11.0559
#
# Current Learning rate 0.0001
# Train Epoch: 61 [0/77415 (0%)]	log Loss: -11.092747
#
# Train set: Average log loss: -11.2257
#
#
# Test set: Average loss: -11.1658
#
# Current Learning rate 0.0001
# Train Epoch: 62 [0/77415 (0%)]	log Loss: -11.203937
#
# Train set: Average log loss: -11.2527
#
#
# Test set: Average loss: -11.3641
#
# Current Learning rate 0.0001
# Train Epoch: 63 [0/77415 (0%)]	log Loss: -11.408858
#
# Train set: Average log loss: -11.2790
#
#
# Test set: Average loss: -11.4918
#
# Current Learning rate 0.0001
# Train Epoch: 64 [0/77415 (0%)]	log Loss: -11.539248
#
# Train set: Average log loss: -11.3001
#
#
# Test set: Average loss: -11.5019
#
# Current Learning rate 0.0001
# Train Epoch: 65 [0/77415 (0%)]	log Loss: -11.547152
#
# Train set: Average log loss: -11.2656
#
#
# Test set: Average loss: -11.4987
#
# Current Learning rate 0.0001
# Train Epoch: 66 [0/77415 (0%)]	log Loss: -11.543001
#
# Train set: Average log loss: -11.2879
#
#
# Test set: Average loss: -11.5382
#
# Current Learning rate 0.0001
# Train Epoch: 67 [0/77415 (0%)]	log Loss: -11.584445
#
# Train set: Average log loss: -11.2881
#
#
# Test set: Average loss: -11.5392
#
# Current Learning rate 0.0001
# Train Epoch: 68 [0/77415 (0%)]	log Loss: -11.584514
#
# Train set: Average log loss: -11.3034
#
#
# Test set: Average loss: -11.5613
#
# Current Learning rate 0.0001
# Train Epoch: 69 [0/77415 (0%)]	log Loss: -11.608077
#
# Train set: Average log loss: -11.3054
#
#
# Test set: Average loss: -11.5750
#
# Current Learning rate 0.0001
# Train Epoch: 70 [0/77415 (0%)]	log Loss: -11.624634
#
# Train set: Average log loss: -11.3317
#
#
# Test set: Average loss: -11.5910
#
# Current Learning rate 0.0001
# Train Epoch: 71 [0/77415 (0%)]	log Loss: -11.641446
#
# Train set: Average log loss: -11.3414
#
#
# Test set: Average loss: -11.5976
#
# Current Learning rate 0.0001
# Train Epoch: 72 [0/77415 (0%)]	log Loss: -11.648978
#
# Train set: Average log loss: -11.3338
#
#
# Test set: Average loss: -11.5968
#
# Current Learning rate 0.0001
# Train Epoch: 73 [0/77415 (0%)]	log Loss: -11.647836
#
# Train set: Average log loss: -11.3393
#
#
# Test set: Average loss: -11.6144
#
# Current Learning rate 0.0001
# Train Epoch: 74 [0/77415 (0%)]	log Loss: -11.668791
#
# Train set: Average log loss: -11.3774
#
#
# Test set: Average loss: -11.6347
#
# Current Learning rate 0.0001
# Train Epoch: 75 [0/77415 (0%)]	log Loss: -11.691543
#
# Train set: Average log loss: -11.4083
#
#
# Test set: Average loss: -11.6589
#
# Current Learning rate 0.0001
# Train Epoch: 76 [0/77415 (0%)]	log Loss: -11.717266
#
# Train set: Average log loss: -11.4372
#
#
# Test set: Average loss: -11.2591
#
# Current Learning rate 0.0001
# Train Epoch: 77 [0/77415 (0%)]	log Loss: -11.298581
#
# Train set: Average log loss: -11.3831
#
#
# Test set: Average loss: -11.1977
#
# Current Learning rate 0.0001
# Train Epoch: 78 [0/77415 (0%)]	log Loss: -11.238272
#
# Train set: Average log loss: -11.3559
#
#
# Test set: Average loss: -11.5777
#
# Current Learning rate 0.0001
# Train Epoch: 79 [0/77415 (0%)]	log Loss: -11.637401
#
# Train set: Average log loss: -11.3734
#
#
# Test set: Average loss: -11.3788
#
# Current Learning rate 0.0001
# Train Epoch: 80 [0/77415 (0%)]	log Loss: -11.412216
#
# Train set: Average log loss: -11.3398
#
#
# Test set: Average loss: -11.6995
#
# Current Learning rate 0.0001
# Train Epoch: 81 [0/77415 (0%)]	log Loss: -11.758174
#
# Train set: Average log loss: -11.3836
#
#
# Test set: Average loss: -11.6638
#
# Current Learning rate 0.0001
# Train Epoch: 82 [0/77415 (0%)]	log Loss: -11.724640
#
# Train set: Average log loss: -11.3444
#
#
# Test set: Average loss: -11.6976
#
# Current Learning rate 0.0001
# Train Epoch: 83 [0/77415 (0%)]	log Loss: -11.756515
#
# Train set: Average log loss: -11.1374
#
#
# Test set: Average loss: -10.9002
#
# Current Learning rate 0.0001
# Train Epoch: 84 [0/77415 (0%)]	log Loss: -10.915811
#
# Train set: Average log loss: -11.4257
#
#
# Test set: Average loss: -11.6766
#
# Current Learning rate 0.0001
# Train Epoch: 85 [0/77415 (0%)]	log Loss: -11.744994
#
# Train set: Average log loss: -11.4838
#
#
# Test set: Average loss: -11.4767
#
# Current Learning rate 0.0001
# Train Epoch: 86 [0/77415 (0%)]	log Loss: -11.528646
#
# Train set: Average log loss: -11.4845
#
#
# Test set: Average loss: -11.2754
#
# Current Learning rate 0.0001
# Train Epoch: 87 [0/77415 (0%)]	log Loss: -11.315015
#
# Train set: Average log loss: -11.4910
#
#
# Test set: Average loss: -11.2020
#
# Current Learning rate 0.0001
# Train Epoch: 88 [0/77415 (0%)]	log Loss: -11.237564
#
# Train set: Average log loss: -11.4964
#
#
# Test set: Average loss: -11.1657
#
# Current Learning rate 0.0001
# Train Epoch: 89 [0/77415 (0%)]	log Loss: -11.198294
#
# Train set: Average log loss: -11.5020
#
#
# Test set: Average loss: -11.1730
#
# Current Learning rate 0.0001
# Train Epoch: 90 [0/77415 (0%)]	log Loss: -11.205346
#
# Train set: Average log loss: -11.5050
#
#
# Test set: Average loss: -11.1870
#
# Current Learning rate 0.0001
# Train Epoch: 91 [0/77415 (0%)]	log Loss: -11.220252
#
# Train set: Average log loss: -11.5052
#
#
# Test set: Average loss: -11.1828
#
# Current Learning rate 0.0001
# Train Epoch: 92 [0/77415 (0%)]	log Loss: -11.217503
#
# Train set: Average log loss: -11.5124
#
#
# Test set: Average loss: -11.1847
#
# Current Learning rate 0.0001
# Train Epoch: 93 [0/77415 (0%)]	log Loss: -11.220190
#
# Train set: Average log loss: -11.5185
#
#
# Test set: Average loss: -11.1963
#
# Current Learning rate 0.0001
# Train Epoch: 94 [0/77415 (0%)]	log Loss: -11.233789
#
# Train set: Average log loss: -11.5286
#
#
# Test set: Average loss: -11.2108
#
# Current Learning rate 0.0001
# Train Epoch: 95 [0/77415 (0%)]	log Loss: -11.250114
#
# Train set: Average log loss: -11.5344
#
#
# Test set: Average loss: -11.2283
#
# Current Learning rate 0.0001
# Train Epoch: 96 [0/77415 (0%)]	log Loss: -11.268495
#
# Train set: Average log loss: -11.5433
#
#
# Test set: Average loss: -11.2413
#
# Current Learning rate 0.0001
# Train Epoch: 97 [0/77415 (0%)]	log Loss: -11.282411
#
# Train set: Average log loss: -11.5531
#
#
# Test set: Average loss: -11.2723
#
# Current Learning rate 0.0001
# Train Epoch: 98 [0/77415 (0%)]	log Loss: -11.314943
#
# Train set: Average log loss: -11.5706
#
#
# Test set: Average loss: -11.3626
#
# Current Learning rate 0.0001
# Train Epoch: 99 [0/77415 (0%)]	log Loss: -11.408111
#
# Train set: Average log loss: -11.6270
#
#
# Test set: Average loss: -11.7106
#
# Current Learning rate 0.0001
# Train Epoch: 100 [0/77415 (0%)]	log Loss: -11.772112
#
# Train set: Average log loss: -11.8376
#
#
# Test set: Average loss: -11.9297
#
# Current Learning rate 0.0001
# Train Epoch: 101 [0/77415 (0%)]	log Loss: -11.999171
#
# Train set: Average log loss: -11.5776
#
#
# Test set: Average loss: -10.6418
#
# Current Learning rate 0.0001
# Train Epoch: 102 [0/77415 (0%)]	log Loss: -10.656668
#
# Train set: Average log loss: -11.5944
#
#
# Test set: Average loss: -11.5005
#
# Current Learning rate 0.0001
# Train Epoch: 103 [0/77415 (0%)]	log Loss: -11.528967
#
# Train set: Average log loss: -11.6290
#
#
# Test set: Average loss: -11.8003
#
# Current Learning rate 0.0001
# Train Epoch: 104 [0/77415 (0%)]	log Loss: -11.859733
#
# Train set: Average log loss: -11.5003
#
#
# Test set: Average loss: -11.2735
#
# Current Learning rate 0.0001
# Train Epoch: 105 [0/77415 (0%)]	log Loss: -11.308140
#
# Train set: Average log loss: -11.6832
#
#
# Test set: Average loss: -11.8663
#
# Current Learning rate 0.0001
# Train Epoch: 106 [0/77415 (0%)]	log Loss: -11.920117
#
# Train set: Average log loss: -11.5685
#
#
# Test set: Average loss: -11.5825
#
# Current Learning rate 0.0001
# Train Epoch: 107 [0/77415 (0%)]	log Loss: -11.622336
#
# Train set: Average log loss: -11.6679
#
#
# Test set: Average loss: -11.6144
#
# Current Learning rate 0.0001
# Train Epoch: 108 [0/77415 (0%)]	log Loss: -11.663452
#
# Train set: Average log loss: -11.8159
#
#
# Test set: Average loss: -11.1634
#
# Current Learning rate 0.0001
# Train Epoch: 109 [0/77415 (0%)]	log Loss: -11.193664
#
# Train set: Average log loss: -11.1137
#
#
# Test set: Average loss: -11.0439
#
# Current Learning rate 0.0001
# Train Epoch: 110 [0/77415 (0%)]	log Loss: -11.082416
#
# Train set: Average log loss: -11.5076
#
#
# Test set: Average loss: -11.9166
#
# Current Learning rate 0.0001
# Train Epoch: 111 [0/77415 (0%)]	log Loss: -11.993365
#
# Train set: Average log loss: -11.5756
#
#
# Test set: Average loss: -11.8457
#
# Current Learning rate 0.0001
# Train Epoch: 112 [0/77415 (0%)]	log Loss: -11.909540
#
# Train set: Average log loss: -11.6091
#
#
# Test set: Average loss: -11.9061
#
# Current Learning rate 0.0001
# Train Epoch: 113 [0/77415 (0%)]	log Loss: -11.973175
#
# Train set: Average log loss: -11.6269
#
#
# Test set: Average loss: -11.9425
#
# Current Learning rate 0.0001
# Train Epoch: 114 [0/77415 (0%)]	log Loss: -12.012821
#
# Train set: Average log loss: -11.6500
#
#
# Test set: Average loss: -11.9667
#
# Current Learning rate 0.0001
# Train Epoch: 115 [0/77415 (0%)]	log Loss: -12.039117
#
# Train set: Average log loss: -11.6841
#
#
# Test set: Average loss: -12.0185
#
# Current Learning rate 0.0001
# Train Epoch: 116 [0/77415 (0%)]	log Loss: -12.097833
#
# Train set: Average log loss: -11.7256
#
#
# Test set: Average loss: -12.0127
#
# Current Learning rate 0.0001
# Train Epoch: 117 [0/77415 (0%)]	log Loss: -12.096391
#
# Train set: Average log loss: -11.7621
#
#
# Test set: Average loss: -11.7338
#
# Current Learning rate 0.0001
# Train Epoch: 118 [0/77415 (0%)]	log Loss: -11.797459
#
# Train set: Average log loss: -11.7512
#
#
# Test set: Average loss: -11.5558
#
# Current Learning rate 0.0001
# Train Epoch: 119 [0/77415 (0%)]	log Loss: -11.608930
#
# Train set: Average log loss: -11.7399
#
#
# Test set: Average loss: -11.6324
#
# Current Learning rate 0.0001
# Train Epoch: 120 [0/77415 (0%)]	log Loss: -11.687343
#
# Train set: Average log loss: -11.8410
#
#
# Test set: Average loss: -12.0465
#
# Current Learning rate 0.0001
# Train Epoch: 121 [0/77415 (0%)]	log Loss: -12.114717
#
# Train set: Average log loss: -12.0002
#
#
# Test set: Average loss: -12.0913
#
# Current Learning rate 0.0001
# Train Epoch: 122 [0/77415 (0%)]	log Loss: -12.149769
#
# Train set: Average log loss: -11.8149
#
#
# Test set: Average loss: -12.0370
#
# Current Learning rate 0.0001
# Train Epoch: 123 [0/77415 (0%)]	log Loss: -12.102623
#
# Train set: Average log loss: -11.1982
#
#
# Test set: Average loss: -12.0228
#
# Current Learning rate 0.0001
# Train Epoch: 124 [0/77415 (0%)]	log Loss: -12.104126
#
# Train set: Average log loss: -11.7324
#
#
# Test set: Average loss: -11.9320
#
# Current Learning rate 0.0001
# Train Epoch: 125 [0/77415 (0%)]	log Loss: -12.010685
#
# Train set: Average log loss: -11.7747
#
#
# Test set: Average loss: -11.7518
#
# Current Learning rate 0.0001
# Train Epoch: 126 [0/77415 (0%)]	log Loss: -11.821087
#
# Train set: Average log loss: -11.7829
#
#
# Test set: Average loss: -11.6329
#
# Current Learning rate 0.0001
# Train Epoch: 127 [0/77415 (0%)]	log Loss: -11.694990
#
# Train set: Average log loss: -11.8206
#
#
# Test set: Average loss: -11.8380
#
# Current Learning rate 0.0001
# Train Epoch: 128 [0/77415 (0%)]	log Loss: -11.905691
#
# Train set: Average log loss: -12.0025
#
#
# Test set: Average loss: -11.6688
#
# Current Learning rate 0.0001
# Train Epoch: 129 [0/77415 (0%)]	log Loss: -11.730869
#
# Train set: Average log loss: -11.8663
#
#
# Test set: Average loss: -12.0546
#
# Current Learning rate 0.0001
# Train Epoch: 130 [0/77415 (0%)]	log Loss: -12.086537
#
# Train set: Average log loss: -11.7102
#
#
# Test set: Average loss: -12.0240
#
# Current Learning rate 0.0001
# Train Epoch: 131 [0/77415 (0%)]	log Loss: -12.096211
#
# Train set: Average log loss: -11.7748
#
#
# Test set: Average loss: -11.8204
#
# Current Learning rate 0.0001
# Train Epoch: 132 [0/77415 (0%)]	log Loss: -11.883448
#
# Train set: Average log loss: -11.6453
#
#
# Test set: Average loss: -11.3784
#
# Current Learning rate 0.0001
# Train Epoch: 133 [0/77415 (0%)]	log Loss: -11.380858
#
# Train set: Average log loss: -11.7867
#
#
# Test set: Average loss: -11.3495
#
# Current Learning rate 0.0001
# Train Epoch: 134 [0/77415 (0%)]	log Loss: -11.398188
#
# Train set: Average log loss: -11.7637
#
#
# Test set: Average loss: -11.9818
#
# Current Learning rate 0.0001
# Train Epoch: 135 [0/77415 (0%)]	log Loss: -12.059785
#
# Train set: Average log loss: -12.0015
#
#
# Test set: Average loss: -12.2046
#
# Current Learning rate 0.0001
# Train Epoch: 136 [0/77415 (0%)]	log Loss: -12.266886
#
# Train set: Average log loss: -11.1887
#
#
# Test set: Average loss: -12.1533
#
# Current Learning rate 0.0001
# Train Epoch: 137 [0/77415 (0%)]	log Loss: -12.244229
#
# Train set: Average log loss: -11.3873
#
#
# Test set: Average loss: -12.0295
#
# Current Learning rate 0.0001
# Train Epoch: 138 [0/77415 (0%)]	log Loss: -12.083349
#
# Train set: Average log loss: -11.5159
#
#
# Test set: Average loss: -11.4322
#
# Current Learning rate 0.0001
# Train Epoch: 139 [0/77415 (0%)]	log Loss: -11.447968
#
# Train set: Average log loss: -11.8370
#
#
# Test set: Average loss: -11.5981
#
# Current Learning rate 0.0001
# Train Epoch: 140 [0/77415 (0%)]	log Loss: -11.619228
#
# Train set: Average log loss: -11.7462
#
#
# Test set: Average loss: -11.5930
#
# Current Learning rate 0.0001
# Train Epoch: 141 [0/77415 (0%)]	log Loss: -11.615713
#
# Train set: Average log loss: -11.7499
#
#
# Test set: Average loss: -11.6132
#
# Current Learning rate 0.0001
# Train Epoch: 142 [0/77415 (0%)]	log Loss: -11.638558
#
# Train set: Average log loss: -11.7586
#
#
# Test set: Average loss: -11.6391
#
# Current Learning rate 0.0001
# Train Epoch: 143 [0/77415 (0%)]	log Loss: -11.666088
#
# Train set: Average log loss: -11.7601
#
#
# Test set: Average loss: -11.6560
#
# Current Learning rate 0.0001
# Train Epoch: 144 [0/77415 (0%)]	log Loss: -11.685260
#
# Train set: Average log loss: -11.7645
#
#
# Test set: Average loss: -11.6784
#
# Current Learning rate 0.0001
# Train Epoch: 145 [0/77415 (0%)]	log Loss: -11.709580
#
# Train set: Average log loss: -11.7689
#
#
# Test set: Average loss: -11.6984
#
# Current Learning rate 0.0001
# Train Epoch: 146 [0/77415 (0%)]	log Loss: -11.731679
#
# Train set: Average log loss: -11.7754
#
#
# Test set: Average loss: -11.7265
#
# Current Learning rate 0.0001
# Train Epoch: 147 [0/77415 (0%)]	log Loss: -11.761074
#
# Train set: Average log loss: -11.7806
#
#
# Test set: Average loss: -11.7531
#
# Current Learning rate 0.0001
# Train Epoch: 148 [0/77415 (0%)]	log Loss: -11.789979
#
# Train set: Average log loss: -11.7835
#
#
# Test set: Average loss: -11.7736
#
# Current Learning rate 0.0001
# Train Epoch: 149 [0/77415 (0%)]	log Loss: -11.811672
#
# Train set: Average log loss: -11.7890
#
#
# Test set: Average loss: -11.7922
#
# Current Learning rate 0.0001
# Train Epoch: 150 [0/77415 (0%)]	log Loss: -11.830889
#
# Train set: Average log loss: -11.7950
#
#
# Test set: Average loss: -11.8166
#
# Current Learning rate 0.0001
# Train Epoch: 151 [0/77415 (0%)]	log Loss: -11.857160
#
# Train set: Average log loss: -11.8028
#
#
# Test set: Average loss: -11.8481
#
# Current Learning rate 0.0001
# Train Epoch: 152 [0/77415 (0%)]	log Loss: -11.890801
#
# Train set: Average log loss: -11.8147
#
#
# Test set: Average loss: -11.8990
#
# Current Learning rate 0.0001
# Train Epoch: 153 [0/77415 (0%)]	log Loss: -11.943358
#
# Train set: Average log loss: -11.8285
#
#
# Test set: Average loss: -11.9822
#
# Current Learning rate 0.0001
# Train Epoch: 154 [0/77415 (0%)]	log Loss: -12.031620
#
# Train set: Average log loss: -11.8668
#
#
# Test set: Average loss: -12.1041
#
# Current Learning rate 0.0001
# Train Epoch: 155 [0/77415 (0%)]	log Loss: -12.159711
#
# Train set: Average log loss: -11.9484
#
#
# Test set: Average loss: -12.1824
#
# Current Learning rate 0.0001
# Train Epoch: 156 [0/77415 (0%)]	log Loss: -12.241712
#
# Train set: Average log loss: -12.0695
#
#
# Test set: Average loss: -12.1475
#
# Current Learning rate 0.0001
# Train Epoch: 157 [0/77415 (0%)]	log Loss: -12.210201
#
# Train set: Average log loss: -12.1662
#
#
# Test set: Average loss: -12.1115
#
# Current Learning rate 0.0001
# Train Epoch: 158 [0/77415 (0%)]	log Loss: -12.175004
#
# Train set: Average log loss: -12.1453
#
#
# Test set: Average loss: -12.2506
#
# Current Learning rate 0.0001
# Train Epoch: 159 [0/77415 (0%)]	log Loss: -12.315665
#
# Train set: Average log loss: -12.2155
#
#
# Test set: Average loss: -10.9964
#
# Current Learning rate 0.0001
# Train Epoch: 160 [0/77415 (0%)]	log Loss: -11.018504
#
# Train set: Average log loss: -11.8824
#
#
# Test set: Average loss: -12.3512
#
# Current Learning rate 0.0001
# Train Epoch: 161 [0/77415 (0%)]	log Loss: -12.416885
#
# Train set: Average log loss: -11.7673
#
#
# Test set: Average loss: -11.2287
#
# Current Learning rate 0.0001
# Train Epoch: 162 [0/77415 (0%)]	log Loss: -11.259912
#
# Train set: Average log loss: -11.6402
#
#
# Test set: Average loss: -12.2259
#
# Current Learning rate 0.0001
# Train Epoch: 163 [0/77415 (0%)]	log Loss: -12.295995
#
# Train set: Average log loss: -11.9880
#
#
# Test set: Average loss: -12.1918
#
# Current Learning rate 0.0001
# Train Epoch: 164 [0/77415 (0%)]	log Loss: -12.253422
#
# Train set: Average log loss: -12.1188
#
#
# Test set: Average loss: -12.1089
#
# Current Learning rate 0.0001
# Train Epoch: 165 [0/77415 (0%)]	log Loss: -12.169910
#
# Train set: Average log loss: -12.1406
#
#
# Test set: Average loss: -10.6911
#
# Current Learning rate 0.0001
# Train Epoch: 166 [0/77415 (0%)]	log Loss: -10.710902
#
# Train set: Average log loss: -11.9542
#
#
# Test set: Average loss: -11.7517
#
# Current Learning rate 0.0001
# Train Epoch: 167 [0/77415 (0%)]	log Loss: -11.756334
#
# Train set: Average log loss: -11.6242
#
#
# Test set: Average loss: -12.3750
#
# Current Learning rate 0.0001
# Train Epoch: 168 [0/77415 (0%)]	log Loss: -12.441025
#
# Train set: Average log loss: -12.1248
#
#
# Test set: Average loss: -12.0973
#
# Current Learning rate 0.0001
# Train Epoch: 169 [0/77415 (0%)]	log Loss: -12.156186
#
# Train set: Average log loss: -12.3261
#
#
# Test set: Average loss: -11.3604
#
# Current Learning rate 0.0001
# Train Epoch: 170 [0/77415 (0%)]	log Loss: -11.396736
#
# Train set: Average log loss: -11.4415
#
#
# Test set: Average loss: -12.0407
#
# Current Learning rate 0.0001
# Train Epoch: 171 [0/77415 (0%)]	log Loss: -12.109829
#
# Train set: Average log loss: -11.9856
#
#
# Test set: Average loss: -12.0276
#
# Current Learning rate 0.0001
# Train Epoch: 172 [0/77415 (0%)]	log Loss: -12.094881
#
# Train set: Average log loss: -11.9981
#
#
# Test set: Average loss: -12.1371
#
# Current Learning rate 0.0001
# Train Epoch: 173 [0/77415 (0%)]	log Loss: -12.204956
#
# Train set: Average log loss: -12.1497
#
#
# Test set: Average loss: -12.1904
#
# Current Learning rate 0.0001
# Train Epoch: 174 [0/77415 (0%)]	log Loss: -12.259802
#
# Train set: Average log loss: -12.1463
#
#
# Test set: Average loss: -10.4677
#
# Current Learning rate 0.0001
# Train Epoch: 175 [0/77415 (0%)]	log Loss: -10.487275
#
# Train set: Average log loss: -11.8789
#
#
# Test set: Average loss: -11.9352
#
# Current Learning rate 0.0001
# Train Epoch: 176 [0/77415 (0%)]	log Loss: -11.998996
#
# Train set: Average log loss: -12.0899
#
#
# Test set: Average loss: -11.9158
#
# Current Learning rate 0.0001
# Train Epoch: 177 [0/77415 (0%)]	log Loss: -11.983234
#
# Train set: Average log loss: -11.8484
#
#
# Test set: Average loss: -10.1198
#
# Current Learning rate 0.0001
# Train Epoch: 178 [0/77415 (0%)]	log Loss: -10.135899
#
# Train set: Average log loss: -11.6161
#
#
# Test set: Average loss: -12.2815
#
# Current Learning rate 0.0001
# Train Epoch: 179 [0/77415 (0%)]	log Loss: -12.336874
#
# Train set: Average log loss: -11.9169
#
#
# Test set: Average loss: -12.2168
#
# Current Learning rate 0.0001
# Train Epoch: 180 [0/77415 (0%)]	log Loss: -12.264397
#
# Train set: Average log loss: -11.9952
#
#
# Test set: Average loss: -12.3824
#
# Current Learning rate 0.0001
# Train Epoch: 181 [0/77415 (0%)]	log Loss: -12.451979
#
# Train set: Average log loss: -12.0732
#
#
# Test set: Average loss: -12.4284
#
# Current Learning rate 0.0001
# Train Epoch: 182 [0/77415 (0%)]	log Loss: -12.519540
#
# Train set: Average log loss: -12.1281
#
#
# Test set: Average loss: -12.4368
#
# Current Learning rate 0.0001
# Train Epoch: 183 [0/77415 (0%)]	log Loss: -12.518836
#
# Train set: Average log loss: -12.2447
#
#
# Test set: Average loss: -11.6929
#
# Current Learning rate 0.0001
# Train Epoch: 184 [0/77415 (0%)]	log Loss: -11.750947
#
# Train set: Average log loss: -12.2306
#
#
# Test set: Average loss: -12.0562
#
# Current Learning rate 0.0001
# Train Epoch: 185 [0/77415 (0%)]	log Loss: -12.137519
#
# Train set: Average log loss: -11.7756
#
#
# Test set: Average loss: -12.3145
#
# Current Learning rate 0.0001
# Train Epoch: 186 [0/77415 (0%)]	log Loss: -12.397522
#
# Train set: Average log loss: -12.3326
#
#
# Test set: Average loss: -11.8478
#
# Current Learning rate 0.0001
# Train Epoch: 187 [0/77415 (0%)]	log Loss: -11.911558
#
# Train set: Average log loss: -11.5961
#
#
# Test set: Average loss: -12.4008
#
# Current Learning rate 0.0001
# Train Epoch: 188 [0/77415 (0%)]	log Loss: -12.473818
#
# Train set: Average log loss: -11.9173
#
#
# Test set: Average loss: -12.3999
#
# Current Learning rate 0.0001
# Train Epoch: 189 [0/77415 (0%)]	log Loss: -12.478839
#
# Train set: Average log loss: -11.9650
#
#
# Test set: Average loss: -12.4000
#
# Current Learning rate 0.0001
# Train Epoch: 190 [0/77415 (0%)]	log Loss: -12.494531
#
# Train set: Average log loss: -11.9555
#
#
# Test set: Average loss: -12.4704
#
# Current Learning rate 0.0001
# Train Epoch: 191 [0/77415 (0%)]	log Loss: -12.563868
#
# Train set: Average log loss: -11.9392
#
#
# Test set: Average loss: -12.1457
#
# Current Learning rate 0.0001
# Train Epoch: 192 [0/77415 (0%)]	log Loss: -12.191160
#
# Train set: Average log loss: -11.9333
#
#
# Test set: Average loss: -11.8522
#
# Current Learning rate 0.0001
# Train Epoch: 193 [0/77415 (0%)]	log Loss: -11.877807
#
# Train set: Average log loss: -11.9474
#
#
# Test set: Average loss: -11.6153
#
# Current Learning rate 0.0001
# Train Epoch: 194 [0/77415 (0%)]	log Loss: -11.633379
#
# Train set: Average log loss: -11.9662
#
#
# Test set: Average loss: -11.4820
#
# Current Learning rate 0.0001
# Train Epoch: 195 [0/77415 (0%)]	log Loss: -11.499592
#
# Train set: Average log loss: -11.9932
#
#
# Test set: Average loss: -11.4692
#
# Current Learning rate 0.0001
# Train Epoch: 196 [0/77415 (0%)]	log Loss: -11.488020
#
# Train set: Average log loss: -12.0356
#
#
# Test set: Average loss: -11.6024
#
# Current Learning rate 0.0001
# Train Epoch: 197 [0/77415 (0%)]	log Loss: -11.629411
#
# Train set: Average log loss: -12.1157
#
#
# Test set: Average loss: -12.0723
#
# Current Learning rate 0.0001
# Train Epoch: 198 [0/77415 (0%)]	log Loss: -12.122032
#
# Train set: Average log loss: -12.2654
#
#
# Test set: Average loss: -12.5312
#
# Current Learning rate 0.0001
# Train Epoch: 199 [0/77415 (0%)]	log Loss: -12.620358
#
# Train set: Average log loss: -12.4302
#
#
# Test set: Average loss: -12.2126
#
# Current Learning rate 0.0001
# Train Epoch: 200 [0/77415 (0%)]	log Loss: -12.283657
#
# Train set: Average log loss: -11.8851
#
#
# Test set: Average loss: -12.1414
#
# Current Learning rate 0.0001
# Train Epoch: 201 [0/77415 (0%)]	log Loss: -12.206859
#
# Train set: Average log loss: -12.3055
#
#
# Test set: Average loss: -12.3056
#
# Current Learning rate 0.0001
# Train Epoch: 202 [0/77415 (0%)]	log Loss: -12.381534
#
# Train set: Average log loss: -11.9413
#
#
# Test set: Average loss: -11.2798
#
# Current Learning rate 0.0001
# Train Epoch: 203 [0/77415 (0%)]	log Loss: -11.313575
#
# Train set: Average log loss: -12.0331
#
#
# Test set: Average loss: -11.7937
#
# Current Learning rate 0.0001
# Train Epoch: 204 [0/77415 (0%)]	log Loss: -11.842572
#
# Train set: Average log loss: -12.1671
#
#
# Test set: Average loss: -11.5927
#
# Current Learning rate 0.0001
# Train Epoch: 205 [0/77415 (0%)]	log Loss: -11.639261
#
# Train set: Average log loss: -11.9739
#
#
# Test set: Average loss: -11.2620
#
# Current Learning rate 0.0001
# Train Epoch: 206 [0/77415 (0%)]	log Loss: -11.300004
#
# Train set: Average log loss: -12.1398
#
#
# Test set: Average loss: -12.3680
#
# Current Learning rate 0.0001
# Train Epoch: 207 [0/77415 (0%)]	log Loss: -12.448770
#
# Train set: Average log loss: -12.2551
#
#
# Test set: Average loss: -11.9570
#
# Current Learning rate 0.0001
# Train Epoch: 208 [0/77415 (0%)]	log Loss: -12.019599
#
# Train set: Average log loss: -11.9252
#
#
# Test set: Average loss: -12.5456
#
# Current Learning rate 0.0001
# Train Epoch: 209 [0/77415 (0%)]	log Loss: -12.629215
#
# Train set: Average log loss: -12.1686
#
#
# Test set: Average loss: -12.5780
#
# Current Learning rate 0.0001
# Train Epoch: 210 [0/77415 (0%)]	log Loss: -12.652100
#
# Train set: Average log loss: -11.9719
#
#
# Test set: Average loss: -10.7261
#
# Current Learning rate 0.0001
# Train Epoch: 211 [0/77415 (0%)]	log Loss: -10.747310
#
# Train set: Average log loss: -11.9953
#
#
# Test set: Average loss: -11.9608
#
# Current Learning rate 0.0001
# Train Epoch: 212 [0/77415 (0%)]	log Loss: -11.964341
#
# Train set: Average log loss: -11.9162
#
#
# Test set: Average loss: -12.3940
#
# Current Learning rate 0.0001
# Train Epoch: 213 [0/77415 (0%)]	log Loss: -12.438329
#
# Train set: Average log loss: -12.0817
#
#
# Test set: Average loss: -12.4179
#
# Current Learning rate 0.0001
# Train Epoch: 214 [0/77415 (0%)]	log Loss: -12.479470
#
# Train set: Average log loss: -12.1072
#
#
# Test set: Average loss: -12.4393
#
# Current Learning rate 0.0001
# Train Epoch: 215 [0/77415 (0%)]	log Loss: -12.504602
#
# Train set: Average log loss: -12.1863
#
#
# Test set: Average loss: -12.5245
#
# Current Learning rate 0.0001
# Train Epoch: 216 [0/77415 (0%)]	log Loss: -12.595277
#
# Train set: Average log loss: -12.3419
#
#
# Test set: Average loss: -12.5719
#
# Current Learning rate 0.0001
# Train Epoch: 217 [0/77415 (0%)]	log Loss: -12.657016
#
# Train set: Average log loss: -12.1782
#
#
# Test set: Average loss: -12.4928
#
# Current Learning rate 0.0001
# Train Epoch: 218 [0/77415 (0%)]	log Loss: -12.577240
#
# Train set: Average log loss: -11.7992
#
#
# Test set: Average loss: -12.5616
#
# Current Learning rate 0.0001
# Train Epoch: 219 [0/77415 (0%)]	log Loss: -12.648803
#
# Train set: Average log loss: -12.2797
#
#
# Test set: Average loss: -12.6124
#
# Current Learning rate 0.0001
# Train Epoch: 220 [0/77415 (0%)]	log Loss: -12.693178
#
# Train set: Average log loss: -12.3988
#
#
# Test set: Average loss: -12.5074
#
# Current Learning rate 0.0001
# Train Epoch: 221 [0/77415 (0%)]	log Loss: -12.556880
#
# Train set: Average log loss: -12.2236
#
#
# Test set: Average loss: -11.5518
#
# Current Learning rate 0.0001
# Train Epoch: 222 [0/77415 (0%)]	log Loss: -11.551130
#
# Train set: Average log loss: -12.0413
#
#
# Test set: Average loss: -12.2697
#
# Current Learning rate 0.0001
# Train Epoch: 223 [0/77415 (0%)]	log Loss: -12.340041
#
# Train set: Average log loss: -12.0693
#
#
# Test set: Average loss: -12.1250
#
# Current Learning rate 0.0001
# Train Epoch: 224 [0/77415 (0%)]	log Loss: -12.190245
#
# Train set: Average log loss: -12.1277
#
#
# Test set: Average loss: -12.3807
#
# Current Learning rate 0.0001
# Train Epoch: 225 [0/77415 (0%)]	log Loss: -12.436627
#
# Train set: Average log loss: -11.8420
#
#
# Test set: Average loss: -12.4269
#
# Current Learning rate 0.0001
# Train Epoch: 226 [0/77415 (0%)]	log Loss: -12.509615
#
# Train set: Average log loss: -12.0607
#
#
# Test set: Average loss: -12.3658
#
# Current Learning rate 0.0001
# Train Epoch: 227 [0/77415 (0%)]	log Loss: -12.418278
#
# Train set: Average log loss: -12.0567
#
#
# Test set: Average loss: -12.1682
#
# Current Learning rate 0.0001
# Train Epoch: 228 [0/77415 (0%)]	log Loss: -12.212941
#
# Train set: Average log loss: -12.0124
#
#
# Test set: Average loss: -11.4240
#
# Current Learning rate 0.0001
# Train Epoch: 229 [0/77415 (0%)]	log Loss: -11.437596
#
# Train set: Average log loss: -11.9555
#
#
# Test set: Average loss: -11.1149
#
# Current Learning rate 0.0001
# Train Epoch: 230 [0/77415 (0%)]	log Loss: -11.125579
#
# Train set: Average log loss: -11.8636
#
#
# Test set: Average loss: -11.8755
#
# Current Learning rate 0.0001
# Train Epoch: 231 [0/77415 (0%)]	log Loss: -11.904932
#
# Train set: Average log loss: -11.5810
#
#
# Test set: Average loss: -11.5996
#
# Current Learning rate 0.0001
# Train Epoch: 232 [0/77415 (0%)]	log Loss: -11.625421
#
# Train set: Average log loss: -12.0440
#
#
# Test set: Average loss: -11.6955
#
# Current Learning rate 0.0001
# Train Epoch: 233 [0/77415 (0%)]	log Loss: -11.714936
#
# Train set: Average log loss: -12.1389
#
#
# Test set: Average loss: -11.7037
#
# Current Learning rate 0.0001
# Train Epoch: 234 [0/77415 (0%)]	log Loss: -11.725544
#
# Train set: Average log loss: -12.1083
#
#
# Test set: Average loss: -11.7290
#
# Current Learning rate 0.0001
# Train Epoch: 235 [0/77415 (0%)]	log Loss: -11.752737
#
# Train set: Average log loss: -12.0963
#
#
# Test set: Average loss: -11.7767
#
# Current Learning rate 0.0001
# Train Epoch: 236 [0/77415 (0%)]	log Loss: -11.804199
#
# Train set: Average log loss: -12.1012
#
#
# Test set: Average loss: -11.8427
#
# Current Learning rate 0.0001
# Train Epoch: 237 [0/77415 (0%)]	log Loss: -11.872806
#
# Train set: Average log loss: -12.1062
#
#
# Test set: Average loss: -11.9334
#
# Current Learning rate 0.0001
# Train Epoch: 238 [0/77415 (0%)]	log Loss: -11.966830
#
# Train set: Average log loss: -12.1179
#
#
# Test set: Average loss: -12.0316
#
# Current Learning rate 0.0001
# Train Epoch: 239 [0/77415 (0%)]	log Loss: -12.068992
#
# Train set: Average log loss: -12.1331
#
#
# Test set: Average loss: -12.1705
#
# Current Learning rate 0.0001
# Train Epoch: 240 [0/77415 (0%)]	log Loss: -12.213021
#
# Train set: Average log loss: -12.1711
#
#
# Test set: Average loss: -12.3303
#
# Current Learning rate 0.0001
# Train Epoch: 241 [0/77415 (0%)]	log Loss: -12.378149
#
# Train set: Average log loss: -12.2497
#
#
# Test set: Average loss: -12.3313
#
# Current Learning rate 0.0001
# Train Epoch: 242 [0/77415 (0%)]	log Loss: -12.378116
#
# Train set: Average log loss: -12.3572
#
#
# Test set: Average loss: -11.8697
#
# Current Learning rate 0.0001
# Train Epoch: 243 [0/77415 (0%)]	log Loss: -11.899140
#
# Train set: Average log loss: -12.4379
#
#
# Test set: Average loss: -12.0851
#
# Current Learning rate 0.0001
# Train Epoch: 244 [0/77415 (0%)]	log Loss: -12.128422
#
# Train set: Average log loss: -12.5059
#
#
# Test set: Average loss: -12.7161
#
# Current Learning rate 0.0001
# Train Epoch: 245 [0/77415 (0%)]	log Loss: -12.793288
#
# Train set: Average log loss: -12.4674
#
#
# Test set: Average loss: -12.4395
#
# Current Learning rate 0.0001
# Train Epoch: 246 [0/77415 (0%)]	log Loss: -12.506986
#
# Train set: Average log loss: -11.9398
#
#
# Test set: Average loss: -10.4862
#
# Current Learning rate 0.0001
# Train Epoch: 247 [0/77415 (0%)]	log Loss: -10.493136
#
# Train set: Average log loss: -12.0846
#
#
# Test set: Average loss: -12.6832
#
# Current Learning rate 0.0001
# Train Epoch: 248 [0/77415 (0%)]	log Loss: -12.751710
#
# Train set: Average log loss: -12.4669
#
#
# Test set: Average loss: -12.1218
#
# Current Learning rate 0.0001
# Train Epoch: 249 [0/77415 (0%)]	log Loss: -12.154948
#
# Train set: Average log loss: -12.2876
#
#
# Test set: Average loss: -12.6515
#
# Current Learning rate 0.0001
# Train Epoch: 250 [0/77415 (0%)]	log Loss: -12.731314
#
# Train set: Average log loss: -12.1905
#
#
# Test set: Average loss: -9.9628
#
# Current Learning rate 0.0001
# Train Epoch: 251 [0/77415 (0%)]	log Loss: -9.963193
#
# Train set: Average log loss: -11.8667
#
#
# Test set: Average loss: -12.0739
#
# Current Learning rate 0.0001
# Train Epoch: 252 [0/77415 (0%)]	log Loss: -12.105401
#
# Train set: Average log loss: -12.3661
#
#
# Test set: Average loss: -12.6176
#
# Current Learning rate 0.0001
# Train Epoch: 253 [0/77415 (0%)]	log Loss: -12.681717
#
# Train set: Average log loss: -12.5230
#
#
# Test set: Average loss: -12.6632
#
# Current Learning rate 0.0001
# Train Epoch: 254 [0/77415 (0%)]	log Loss: -12.737982
#
# Train set: Average log loss: -12.4738
#
#
# Test set: Average loss: -10.3504
#
# Current Learning rate 0.0001
# Train Epoch: 255 [0/77415 (0%)]	log Loss: -10.346561
#
# Train set: Average log loss: -11.5026
#
#
# Test set: Average loss: -11.6256
#
# Current Learning rate 0.0001
# Train Epoch: 256 [0/77415 (0%)]	log Loss: -11.646651
#
# Train set: Average log loss: -12.2481
#
#
# Test set: Average loss: -11.6178
#
# Current Learning rate 0.0001
# Train Epoch: 257 [0/77415 (0%)]	log Loss: -11.646008
#
# Train set: Average log loss: -12.3535
#
#
# Test set: Average loss: -11.9572
#
# Current Learning rate 0.0001
# Train Epoch: 258 [0/77415 (0%)]	log Loss: -11.997090
#
# Train set: Average log loss: -12.4561
#
#
# Test set: Average loss: -12.7284
#
# Current Learning rate 0.0001
# Train Epoch: 259 [0/77415 (0%)]	log Loss: -12.800956
#
# Train set: Average log loss: -12.5939
#
#
# Test set: Average loss: -12.7533
#
# Current Learning rate 0.0001
# Train Epoch: 260 [0/77415 (0%)]	log Loss: -12.835498
#
# Train set: Average log loss: -11.9172
#
#
# Test set: Average loss: -12.0546
#
# Current Learning rate 0.0001
# Train Epoch: 261 [0/77415 (0%)]	log Loss: -12.086667
#
# Train set: Average log loss: -12.3476
#
#
# Test set: Average loss: -12.6551
#
# Current Learning rate 0.0001
# Train Epoch: 262 [0/77415 (0%)]	log Loss: -12.709609
#
# Train set: Average log loss: -12.7268
#
#
# Test set: Average loss: -12.7380
#
# Current Learning rate 0.0001
# Train Epoch: 263 [0/77415 (0%)]	log Loss: -12.803340
#
# Train set: Average log loss: -11.6361
#
#
# Test set: Average loss: -11.7870
#
# Current Learning rate 0.0001
# Train Epoch: 264 [0/77415 (0%)]	log Loss: -11.818912
#
# Train set: Average log loss: -12.3534
#
#
# Test set: Average loss: -12.2456
#
# Current Learning rate 0.0001
# Train Epoch: 265 [0/77415 (0%)]	log Loss: -12.294641
#
# Train set: Average log loss: -12.4372
#
#
# Test set: Average loss: -12.6304
#
# Current Learning rate 0.0001
# Train Epoch: 266 [0/77415 (0%)]	log Loss: -12.692269
#
# Train set: Average log loss: -12.5854
#
#
# Test set: Average loss: -12.5342
#
# Current Learning rate 0.0001
# Train Epoch: 267 [0/77415 (0%)]	log Loss: -12.591969
#
# Train set: Average log loss: -11.8447
#
#
# Test set: Average loss: -11.9380
#
# Current Learning rate 0.0001
# Train Epoch: 268 [0/77415 (0%)]	log Loss: -11.963886
#
# Train set: Average log loss: -12.3075
#
#
# Test set: Average loss: -12.5574
#
# Current Learning rate 0.0001
# Train Epoch: 269 [0/77415 (0%)]	log Loss: -12.612675
#
# Train set: Average log loss: -12.4045
#
#
# Test set: Average loss: -12.4704
#
# Current Learning rate 0.0001
# Train Epoch: 270 [0/77415 (0%)]	log Loss: -12.503560
#
# Train set: Average log loss: -12.4615
#
#
# Test set: Average loss: -12.6176
#
# Current Learning rate 0.0001
# Train Epoch: 271 [0/77415 (0%)]	log Loss: -12.669009
#
# Train set: Average log loss: -12.3852
#
#
# Test set: Average loss: -12.6366
#
# Current Learning rate 0.0001
# Train Epoch: 272 [0/77415 (0%)]	log Loss: -12.701326
#
# Train set: Average log loss: -11.9265
#
#
# Test set: Average loss: -12.1157
#
# Current Learning rate 0.0001
# Train Epoch: 273 [0/77415 (0%)]	log Loss: -12.142796
#
# Train set: Average log loss: -12.3246
#
#
# Test set: Average loss: -11.9731
#
# Current Learning rate 0.0001
# Train Epoch: 274 [0/77415 (0%)]	log Loss: -11.992610
#
# Train set: Average log loss: -12.1830
#
#
# Test set: Average loss: -11.6742
#
# Current Learning rate 0.0001
# Train Epoch: 275 [0/77415 (0%)]	log Loss: -11.689296
#
# Train set: Average log loss: -12.3808
#
#
# Test set: Average loss: -12.6718
#
# Current Learning rate 0.0001
# Train Epoch: 276 [0/77415 (0%)]	log Loss: -12.715911
#
# Train set: Average log loss: -12.5755
#
#
# Test set: Average loss: -11.3887
#
# Current Learning rate 0.0001
# Train Epoch: 277 [0/77415 (0%)]	log Loss: -11.403255
#
# Train set: Average log loss: -12.0231
#
#
# Test set: Average loss: -12.2319
#
# Current Learning rate 0.0001
# Train Epoch: 278 [0/77415 (0%)]	log Loss: -12.260092
#
# Train set: Average log loss: -12.4469
#
#
# Test set: Average loss: -12.3049
#
# Current Learning rate 0.0001
# Train Epoch: 279 [0/77415 (0%)]	log Loss: -12.344277
#
# Train set: Average log loss: -12.4405
#
#
# Test set: Average loss: -12.7879
#
# Current Learning rate 0.0001
# Train Epoch: 280 [0/77415 (0%)]	log Loss: -12.848127
#
# Train set: Average log loss: -11.2662
#
#
# Test set: Average loss: -12.4352
#
# Current Learning rate 0.0001
# Train Epoch: 281 [0/77415 (0%)]	log Loss: -12.457443
#
# Train set: Average log loss: -12.1475
#
#
# Test set: Average loss: -11.9387
#
# Current Learning rate 0.0001
# Train Epoch: 282 [0/77415 (0%)]	log Loss: -11.957301
#
# Train set: Average log loss: -12.1476
#
#
# Test set: Average loss: -11.7625
#
# Current Learning rate 0.0001
# Train Epoch: 283 [0/77415 (0%)]	log Loss: -11.780195
#
# Train set: Average log loss: -12.1920
#
#
# Test set: Average loss: -11.7552
#
# Current Learning rate 0.0001
# Train Epoch: 284 [0/77415 (0%)]	log Loss: -11.774680
#
# Train set: Average log loss: -12.2207
#
#
# Test set: Average loss: -11.8174
#
# Current Learning rate 0.0001
# Train Epoch: 285 [0/77415 (0%)]	log Loss: -11.839778
#
# Train set: Average log loss: -12.2449
#
#
# Test set: Average loss: -11.9653
#
# Current Learning rate 0.0001
# Train Epoch: 286 [0/77415 (0%)]	log Loss: -11.993011
#
# Train set: Average log loss: -12.2872
#
#
# Test set: Average loss: -12.2389
#
# Current Learning rate 0.0001
# Train Epoch: 287 [0/77415 (0%)]	log Loss: -12.275753
#
# Train set: Average log loss: -12.3764
#
#
# Test set: Average loss: -12.4402
#
# Current Learning rate 0.0001
# Train Epoch: 288 [0/77415 (0%)]	log Loss: -12.485421
#
# Train set: Average log loss: -12.4968
#
#
# Test set: Average loss: -11.9226
#
# Current Learning rate 0.0001
# Train Epoch: 289 [0/77415 (0%)]	log Loss: -11.952807
#
# Train set: Average log loss: -12.5348
#
#
# Test set: Average loss: -11.8943
#
# Current Learning rate 0.0001
# Train Epoch: 290 [0/77415 (0%)]	log Loss: -11.927501
#
# Train set: Average log loss: -12.6620
#
#
# Test set: Average loss: -12.7661
#
# Current Learning rate 0.0001
# Train Epoch: 291 [0/77415 (0%)]	log Loss: -12.834255
#
# Train set: Average log loss: -12.5926
#
#
# Test set: Average loss: -12.6111
#
# Current Learning rate 0.0001
# Train Epoch: 292 [0/77415 (0%)]	log Loss: -12.678540
#
# Train set: Average log loss: -12.3165
#
#
# Test set: Average loss: -12.8226
#
# Current Learning rate 0.0001
# Train Epoch: 293 [0/77415 (0%)]	log Loss: -12.899560
#
# Train set: Average log loss: -12.4202
#
#
# Test set: Average loss: -12.8148
#
# Current Learning rate 0.0001
# Train Epoch: 294 [0/77415 (0%)]	log Loss: -12.880936
#
# Train set: Average log loss: -12.0474
#
#
# Test set: Average loss: -10.9400
#
# Current Learning rate 0.0001
# Train Epoch: 295 [0/77415 (0%)]	log Loss: -10.949100
#
# Train set: Average log loss: -12.2559
#
#
# Test set: Average loss: -12.6510
#
# Current Learning rate 0.0001
# Train Epoch: 296 [0/77415 (0%)]	log Loss: -12.700026
#
# Train set: Average log loss: -12.6452
#
#
# Test set: Average loss: -12.0838
#
# Current Learning rate 0.0001
# Train Epoch: 297 [0/77415 (0%)]	log Loss: -12.116744
#
# Train set: Average log loss: -12.2708
#
#
# Test set: Average loss: -12.1193
#
# Current Learning rate 0.0001
# Train Epoch: 298 [0/77415 (0%)]	log Loss: -12.167325
#
# Train set: Average log loss: -12.1846
#
#
# Test set: Average loss: -12.8520
#
# Current Learning rate 0.0001
# Train Epoch: 299 [0/77415 (0%)]	log Loss: -12.909124
#
# Train set: Average log loss: -12.1397
#
#
# Test set: Average loss: -12.7947
#
# Current Learning rate 0.0001
# Train Epoch: 300 [0/77415 (0%)]	log Loss: -12.861222
#
# Train set: Average log loss: -12.3406
#
#
# Test set: Average loss: -12.5624
#
# Current Learning rate 0.0001
# Train Epoch: 301 [0/77415 (0%)]	log Loss: -12.617965
#
# Train set: Average log loss: -12.3417
#
#
# Test set: Average loss: -12.6115
#
# Current Learning rate 0.0001
# Train Epoch: 302 [0/77415 (0%)]	log Loss: -12.656002
#
# Train set: Average log loss: -12.6229
#
#
# Test set: Average loss: -12.8904
#
# Current Learning rate 0.0001
# Train Epoch: 303 [0/77415 (0%)]	log Loss: -12.957548
#
# Train set: Average log loss: -12.4131
#
#
# Test set: Average loss: -11.9429
#
# Current Learning rate 0.0001
# Train Epoch: 304 [0/77415 (0%)]	log Loss: -11.962833
#
# Train set: Average log loss: -11.9673
#
#
# Test set: Average loss: -11.8990
#
# Current Learning rate 0.0001
# Train Epoch: 305 [0/77415 (0%)]	log Loss: -11.926747
#
# Train set: Average log loss: -12.1407
#
#
# Test set: Average loss: -12.6874
#
# ...
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7906 [0/77415 (0%)]	log Loss: -14.553934
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7907 [0/77415 (0%)]	log Loss: -14.553935
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7908 [0/77415 (0%)]	log Loss: -14.553937
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7909 [0/77415 (0%)]	log Loss: -14.553937
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7910 [0/77415 (0%)]	log Loss: -14.553934
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7911 [0/77415 (0%)]	log Loss: -14.553929
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7912 [0/77415 (0%)]	log Loss: -14.553928
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7913 [0/77415 (0%)]	log Loss: -14.553929
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7914 [0/77415 (0%)]	log Loss: -14.553933
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7915 [0/77415 (0%)]	log Loss: -14.553932
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7916 [0/77415 (0%)]	log Loss: -14.553936
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7917 [0/77415 (0%)]	log Loss: -14.553922
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7918 [0/77415 (0%)]	log Loss: -14.553929
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7919 [0/77415 (0%)]	log Loss: -14.553922
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7920 [0/77415 (0%)]	log Loss: -14.553922
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7921 [0/77415 (0%)]	log Loss: -14.553928
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7922 [0/77415 (0%)]	log Loss: -14.553923
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7923 [0/77415 (0%)]	log Loss: -14.553925
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7924 [0/77415 (0%)]	log Loss: -14.553922
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7925 [0/77415 (0%)]	log Loss: -14.553926
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7926 [0/77415 (0%)]	log Loss: -14.553926
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7927 [0/77415 (0%)]	log Loss: -14.553930
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7928 [0/77415 (0%)]	log Loss: -14.553913
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7929 [0/77415 (0%)]	log Loss: -14.553920
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7930 [0/77415 (0%)]	log Loss: -14.553924
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7931 [0/77415 (0%)]	log Loss: -14.553917
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7932 [0/77415 (0%)]	log Loss: -14.553921
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7933 [0/77415 (0%)]	log Loss: -14.553924
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7934 [0/77415 (0%)]	log Loss: -14.553918
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7935 [0/77415 (0%)]	log Loss: -14.553921
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7936 [0/77415 (0%)]	log Loss: -14.553922
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7937 [0/77415 (0%)]	log Loss: -14.553916
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7938 [0/77415 (0%)]	log Loss: -14.553918
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7939 [0/77415 (0%)]	log Loss: -14.553909
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7940 [0/77415 (0%)]	log Loss: -14.553913
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7941 [0/77415 (0%)]	log Loss: -14.553917
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7942 [0/77415 (0%)]	log Loss: -14.553912
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7943 [0/77415 (0%)]	log Loss: -14.553912
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7944 [0/77415 (0%)]	log Loss: -14.553918
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7945 [0/77415 (0%)]	log Loss: -14.553912
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7946 [0/77415 (0%)]	log Loss: -14.553910
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7947 [0/77415 (0%)]	log Loss: -14.553903
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7948 [0/77415 (0%)]	log Loss: -14.553912
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7949 [0/77415 (0%)]	log Loss: -14.553904
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7950 [0/77415 (0%)]	log Loss: -14.553904
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7951 [0/77415 (0%)]	log Loss: -14.553909
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7952 [0/77415 (0%)]	log Loss: -14.553905
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7953 [0/77415 (0%)]	log Loss: -14.553908
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7954 [0/77415 (0%)]	log Loss: -14.553908
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7955 [0/77415 (0%)]	log Loss: -14.553899
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7956 [0/77415 (0%)]	log Loss: -14.553908
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7957 [0/77415 (0%)]	log Loss: -14.553905
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7958 [0/77415 (0%)]	log Loss: -14.553902
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7959 [0/77415 (0%)]	log Loss: -14.553899
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7960 [0/77415 (0%)]	log Loss: -14.553902
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7961 [0/77415 (0%)]	log Loss: -14.553902
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7962 [0/77415 (0%)]	log Loss: -14.553900
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7963 [0/77415 (0%)]	log Loss: -14.553906
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7964 [0/77415 (0%)]	log Loss: -14.553897
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7965 [0/77415 (0%)]	log Loss: -14.553897
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7966 [0/77415 (0%)]	log Loss: -14.553899
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7967 [0/77415 (0%)]	log Loss: -14.553895
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7968 [0/77415 (0%)]	log Loss: -14.553889
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7969 [0/77415 (0%)]	log Loss: -14.553889
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7970 [0/77415 (0%)]	log Loss: -14.553894
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7971 [0/77415 (0%)]	log Loss: -14.553898
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7972 [0/77415 (0%)]	log Loss: -14.553895
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7973 [0/77415 (0%)]	log Loss: -14.553893
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7974 [0/77415 (0%)]	log Loss: -14.553890
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7975 [0/77415 (0%)]	log Loss: -14.553886
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7976 [0/77415 (0%)]	log Loss: -14.553890
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7977 [0/77415 (0%)]	log Loss: -14.553887
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7978 [0/77415 (0%)]	log Loss: -14.553886
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7979 [0/77415 (0%)]	log Loss: -14.553885
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7980 [0/77415 (0%)]	log Loss: -14.553888
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7981 [0/77415 (0%)]	log Loss: -14.553890
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7982 [0/77415 (0%)]	log Loss: -14.553884
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7983 [0/77415 (0%)]	log Loss: -14.553891
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7984 [0/77415 (0%)]	log Loss: -14.553897
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7985 [0/77415 (0%)]	log Loss: -14.553889
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7986 [0/77415 (0%)]	log Loss: -14.553891
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7987 [0/77415 (0%)]	log Loss: -14.553882
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7988 [0/77415 (0%)]	log Loss: -14.553886
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7989 [0/77415 (0%)]	log Loss: -14.553882
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7990 [0/77415 (0%)]	log Loss: -14.553888
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7991 [0/77415 (0%)]	log Loss: -14.553886
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7992 [0/77415 (0%)]	log Loss: -14.553880
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7993 [0/77415 (0%)]	log Loss: -14.553885
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7994 [0/77415 (0%)]	log Loss: -14.553877
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7995 [0/77415 (0%)]	log Loss: -14.553886
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7996 [0/77415 (0%)]	log Loss: -14.553877
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7997 [0/77415 (0%)]	log Loss: -14.553876
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7998 [0/77415 (0%)]	log Loss: -14.553870
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7999 [0/77415 (0%)]	log Loss: -14.553873
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 8000 [0/77415 (0%)]	log Loss: -14.553874
#
# Train set: Average log loss: -14.6364
#
#
# Test set: Average loss: -14.1811
#
# Current Learning rate 3.0517578125e-09

# %%
# Plotting log(MSE) as a function of epochs
plt.figure(figsize=(10,7))
plt.plot( np.log(test_losses), label = "test")
plt.plot( np.log(train_losses), label = "train")

plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Log(LSE)")
plt.title("MSE over Epoch" )
plt.grid()
print("Training WIDE {} VS in the article 8.04e-09".format(train_losses[-1]) )
# Out:
# Training WIDE 4.400335376912711e-07 VS in the article 8.04e-09

# %%
# Loading model
device = 'cuda'
loaded_Heston_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_ANN_DE.pt"
loaded_Heston_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_ANN.eval()
# Out:
# Heston_ANN(
#   (fc1): Linear(in_features=8, out_features=200, bias=True)
#   (fc2): Linear(in_features=200, out_features=200, bias=True)
#   (fc3): Linear(in_features=200, out_features=200, bias=True)
#   (fc4): Linear(in_features=200, out_features=200, bias=True)
#   (fc5): Linear(in_features=200, out_features=1, bias=True)
# )

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Train scores----------------
# MSE 6.499973e-07
# MAE 6.143526e-04
# MAPE 2.703216e-02
# R2 9.999767e-01
# -----------Test scores----------------
# MSE 6.161127e-07
# MAE 6.043821e-04
# MAPE 2.023176e-02
# R2 9.999779e-01

# %%
# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

print(prices)
# Out:
# [0.04168085 0.3014155  0.03980945 ... 0.13001926 0.15836792 0.0952353 ]

# %%
from scipy import optimize

def calcimpliedvol(dataset):
    """
    Computes the implied volatilities using the brent method.
    dataset: numpy array containing moneyness, time to maturity, risk free interest rate and V/K.
    Returns a vector of implied volatilities.
    """
    money = np.array(dataset[0])
    T = np.array(dataset[1])
    r = np.array(dataset[2])
    marketoptionPrice = np.array(dataset[3])
    def bs_price(sigma):
      d1 = ( np.log(money) + (r + 0.5 * sigma ** 2) * (T) ) / (sigma * np.sqrt(T))
      d2 = d1 - sigma*np.sqrt(T)
      value_moyeness = money * norm.cdf(d1) - np.exp(-r * (T)) * norm.cdf(d2) 
      fx = value_moyeness - marketoptionPrice
      return fx
    return optimize.brentq(bs_price,-1,1,maxiter=100)

# %%
eps = 1e-2 # is used to generate open intervals
# (S/K), (tau), (r), (rho), (kappa), (vbar), (gamma), (v0).
# CASE 1 in table 11
#l_bounds = [.75+eps, .4+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps]
#u_bounds = [1.25-eps, 1.-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]
hs_dataset = Heston_LHS_data_generator(10**5)
# Out:
# ------ INPUT ------
# S/K.......... [0.61 1.39]
# Tau.......... [0.06 2.99]
# r............ [0.01 0.04]
# Corr ........ [-0.89 -0.01]
# Kappa........ [0.41 2.99]
# V_bar........ [0.02 0.49]
# Gamma........ [0.02 0.79]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00 0.75]

# %%
# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

# Replace with this
hs_dataset2 = hs_dataset.data[:, np.array([0, 1, 2, 8])]  # Select relevant columns
hs_dataset2[:, 3] = torch.FloatTensor(prices)  # Use Heston-ANN prices as market prices for Brent's method

# Compute implied volatilities using Brent's method
implied_vol = np.apply_along_axis(calcimpliedvol, 1, hs_dataset2)

# Eliminating Nan values
indecies = np.argwhere(np.isnan(implied_vol))
implied_vol = np.delete(implied_vol, indecies, 0)

# %%
print(implied_vol)
# Out:
# [0.55469233 0.57968031 0.43657305 ... 0.49875483 0.5565194  0.50508962]

# %%
#Individiual parameters
# 4.1.1 in the paper
T = 2 
S0 = 100
kappa = 0.1
gamma = 0.1  # Volatility of variance
nu_bar = 0.1
rho = -0.75
nu_0 = 0.05
r = 0.05
#"rho": (-0.9, 0.0),         # Correlation coefficient
##   "kappa": (0.1, 3.0),        # Speed of mean reversion
#    "gamma": (0.01, 0.8),      
 #   "nu_0": (0.01, 0.5),        # Initial variance
 #   "nu_bar": (0.01, 0.5)       # Long-term variance

# %%
# Loading model 
device = torch.device("cuda")
loaded_IV_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/IV_SCALED_ANN.pt"
loaded_IV_ANN.load_state_dict(torch.load(PATH))
loaded_IV_ANN.eval()


# Plugging in the Heston-ANN prices
hs_dataset2 = hs_dataset.data[:,np.array([0,1,2,8])]
hs_dataset2.data[:,3] = torch.FloatTensor(prices)
loader2 = torch.utils.data.DataLoader(hs_dataset2, 4048)

# Computing IVs
implied_vol = []
indecies_list = []
with torch.no_grad():
  for idx, data in enumerate(loader2):
    data = data.to(device)
    # LOG Transformation
    data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
    data[:,3] = torch.log(data[:,3])
    output = loaded_IV_ANN(data)
    implied_vol.append((output).data.cpu().numpy())
  implied_vol_pipe2 = np.concatenate(implied_vol)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 5
#       3 loaded_IV_ANN = Heston_ANN().to(device)
#       4 PATH = "ANN_weights/IV_SCALED_ANN.pt"
# ----> 5 loaded_IV_ANN.load_state_dict(torch.load(PATH))
#       6 loaded_IV_ANN.eval()
#       9 # Plugging in the Heston-ANN prices
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\torch\nn\modules\module.py:2152, in Module.load_state_dict(self, state_dict, strict, assign)
#    2147         error_msgs.insert(
#    2148             0, 'Missing key(s) in state_dict: {}. '.format(
#    2149                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2151 if len(error_msgs) > 0:
# -> 2152     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2153                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2154 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Heston_ANN:
# 	size mismatch for fc1.weight: copying a param with shape torch.Size([400, 4]) from checkpoint, the shape in current model is torch.Size([200, 8]).
# 	size mismatch for fc1.bias: copying a param with shape torch.Size([400]) from checkpoint, the shape in current model is torch.Size([200]).
# 	size mismatch for fc2.weight: copying a param with shape torch.Size([400, 400]) from checkpoint, the shape in current model is torch.Size([200, 200]).
# 	size mismatch for fc2.bias: copying a param with shape torch.Size([400]) from checkpoint, the shape in current model is torch.Size([200]).
# 	size mismatch for fc3.weight: copying a param with shape torch.Size([400, 400]) from checkpoint, the shape in current model is torch.Size([200, 200]).
# 	size mismatch for fc3.bias: copying a param with shape torch.Size([400]) from checkpoint, the shape in current model is torch.Size([200]).
# 	size mismatch for fc4.weight: copying a param with shape torch.Size([400, 400]) from checkpoint, the shape in current model is torch.Size([200, 200]).
# 	size mismatch for fc4.bias: copying a param with shape torch.Size([400]) from checkpoint, the shape in current model is torch.Size([200]).
# 	size mismatch for fc5.weight: copying a param with shape torch.Size([1, 400]) from checkpoint, the shape in current model is torch.Size([1, 200]).

# %%
import numpy as np
import itertools

# Define Heston parameter bounds
bounds = {
    "rho": (-0.9, 0.0),         # Correlation coefficient
    "kappa": (0.1, 3.0),        # Speed of mean reversion
    "gamma": (0.01, 0.8),       # Volatility of variance
    "nu_0": (0.01, 0.5),        # Initial variance
    "nu_bar": (0.01, 0.5)       # Long-term variance
}

# Number of discrete points to sample within each parameter's range
points_per_param = 5

# Generate equally spaced points for each parameter within its bounds
parameter_points = {param: np.linspace(lower, upper, points_per_param)
                    for param, (lower, upper) in bounds.items()}

# Combine the points to form a grid of all possible parameter combinations
grid = list(itertools.product(
    parameter_points["rho"],
    parameter_points["kappa"],
    parameter_points["gamma"],
    parameter_points["nu_0"],
    parameter_points["nu_bar"]
))

# Convert the grid into a NumPy array for convenience
parameter_grid = np.array(grid)

# Display the grid details
print(f"Search space dimensions: {len(parameter_points)} parameters")
print(f"Total combinations: {parameter_grid.shape[0]}")
print("Example combinations (first 5 rows):")
print(parameter_grid[:5])

# Optional: Save to a file for later use
np.savetxt("heston_search_space.csv", parameter_grid, delimiter=",",
           header="rho,kappa,gamma,nu_0,nu_bar", comments="")
# Out:
# Search space dimensions: 5 parameters
# Total combinations: 3125
# Example combinations (first 5 rows):
# [[-0.9     0.1     0.01    0.01    0.01  ]
#  [-0.9     0.1     0.01    0.01    0.1325]
#  [-0.9     0.1     0.01    0.01    0.255 ]
#  [-0.9     0.1     0.01    0.01    0.3775]
#  [-0.9     0.1     0.01    0.01    0.5   ]]

# %%
import numpy as np

# Observed market implied volatilities (target data)

observed_vols = np.linspace(0.2, 0.5, 35)  # Generates 35 equally spaced values

# Moneyness and time-to-maturity of the observed data
moneyness = np.linspace(0.85, 1.15, 5)  # Moneyness
maturities = np.linspace(0.5, 2.0, 7)   # Time to maturity
r = 0.03
#params = 



# Pre-trained ANN that maps Heston parameters to implied volatilities
def heston_ann(parameters):
    """
    A mock function representing the ANN (pre-trained forward pass).
    In real scenarios, this will return ANN-predicted implied volatilities.
    """
    # Example: Simple mapping for illustration
    rho, kappa, gamma, nu_bar, nu_0 = parameters
    return 0.25 + 0.05 * (moneyness - 1.0) + 0.02 * (maturities - 1.0)

# Objective function for DE calibration
def calibration_objective(parameters):
    """
    Calculates the mean squared error between ANN-predicted
    and observed market volatilities.
    """
    predicted_vols = implied_vol_pipe2
    error = np.mean((predicted_vols - observed_vols) ** 2)
    return error

# %%
bounds = [
    (-0.75, -0.25),   # rho (correlation)
    (0.5, 1.0),    # kappa (mean reversion speed)
    (0.3, 0.5),   # gamma (volatility of variance)
    (0.15, 0.35),   # nu_bar (long-run variance)
    (0.5, 1.0)    # nu_0 (initial variance)
]

# %%
from scipy.optimize import differential_evolution

# Run DE to calibrate the Heston parameters
result = differential_evolution(
    calibration_objective,  # Objective function
    bounds,                 # Parameter bounds
    strategy="best1bin",    # Strategy for mutation
    popsize=50,             # Population size
    mutation=(0.5, 1.0),    # Mutation range
    recombination=0.7,      # Crossover probability
    tol=0.01,               # Convergence tolerance
    disp=True               # Display optimization progress
)

# Display calibrated parameters
print("Calibrated Parameters:", result.x)
print("Objective Function Value:", result.fun)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 from scipy.optimize import differential_evolution
#       3 # Run DE to calibrate the Heston parameters
# ----> 4 result = differential_evolution(
#       5     calibration_objective,  # Objective function
#       6     bounds,                 # Parameter bounds
#       7     strategy="best1bin",    # Strategy for mutation
#       8     popsize=50,             # Population size
#       9     mutation=(0.5, 1.0),    # Mutation range
#      10     recombination=0.7,      # Crossover probability
#      11     tol=0.01,               # Convergence tolerance
#      12     disp=True               # Display optimization progress
#      13 )
#      15 # Display calibrated parameters
#      16 print("Calibrated Parameters:", result.x)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:397, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     380 # using a context manager means that any created Pool objects are
#     381 # cleared up.
#     382 with DifferentialEvolutionSolver(func, bounds, args=args,
#     383                                  strategy=strategy,
#     384                                  maxiter=maxiter,
#    (...)
#     395                                  integrality=integrality,
#     396                                  vectorized=vectorized) as solver:
# --> 397     ret = solver.solve()
#     399 return ret
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:989, in DifferentialEvolutionSolver.solve(self)
#     984     self.feasible, self.constraint_violation = (
#     985         self._calculate_population_feasibilities(self.population))
#     987     # only work out population energies for feasible solutions
#     988     self.population_energies[self.feasible] = (
# --> 989         self._calculate_population_energies(
#     990             self.population[self.feasible]))
#     992     self._promote_lowest_energy()
#     994 # do the optimization.
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:1122, in DifferentialEvolutionSolver._calculate_population_energies(self, population)
#    1120 parameters_pop = self._scale_parameters(population)
#    1121 try:
# -> 1122     calc_energies = list(
#    1123         self._mapwrapper(self.func, parameters_pop[0:S])
#    1124     )
#    1125     calc_energies = np.squeeze(calc_energies)
#    1126 except (TypeError, ValueError) as e:
#    1127     # wrong number of arguments for _mapwrapper
#    1128     # or wrong length returned from the mapper
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\_lib\_util.py:372, in _FunctionWrapper.__call__(self, x)
#     371 def __call__(self, x):
# --> 372     return self.f(x, *self.args)
#
# Cell In[26], line 31, in calibration_objective(parameters)
#      26 def calibration_objective(parameters):
#      27     """
#      28     Calculates the mean squared error between ANN-predicted
#      29     and observed market volatilities.
#      30     """
# ---> 31     predicted_vols = implied_vol_pipe2
#      32     error = np.mean((predicted_vols - observed_vols) ** 2)
#      33     return error
#
# NameError: name 'implied_vol_pipe2' is not defined

# %%
# Function to calculate implied volatility using Brent's method
def calc_implied_vol(dataset):
    """
    Computes implied volatilities using the Brent method.
    :param dataset: numpy array containing [S/K, T, r, OptionPrice].
    :return: A single implied volatility value.
    """
    money, T, r, market_price = dataset

    def bs_price(sigma):
        """Black-Scholes option price difference function."""
        d1 = (np.log(money) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
        d2 = d1 - sigma * np.sqrt(T)
        theoretical_price = money * norm.cdf(d1) - np.exp(-r * T) * norm.cdf(d2)
        return theoretical_price - market_price

    # Solve for implied volatility
    try:
        return optimize.brentq(bs_price, 1e-5, 5, maxiter=100)
    except ValueError:
        return np.nan  # Return NaN if Brent fails to converge

# Data generation or loading
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds=l_bounds, u_bounds=u_bounds)
hs_data_loader = DataLoader(hs_dataset, batch_size=4048)

# Step 1: Compute prices using Heston-ANN
predicted_prices = []
with torch.no_grad():
    for data in hs_data_loader:
        inputs = data[:, :-1].to(device)  # Exclude the last column if it's labels
        outputs = loaded_Heston_ANN(inputs)
        predicted_prices.append(outputs.cpu().numpy())
predicted_prices = np.concatenate(predicted_prices)

# Step 2: Prepare the dataset for Brent's method
# Combine predicted prices with necessary inputs for implied volatility calculation
# Assuming hs_dataset.data contains [S/K, T, r, actual_price]:
hs_dataset_data = hs_dataset.data[:, np.array([0, 1, 2])]  # Extract relevant columns
hs_dataset_data = np.hstack((hs_dataset_data, predicted_prices.reshape(-1, 1)))

# Step 3: Calculate implied volatilities
implied_volatilities = np.apply_along_axis(calc_implied_vol, 1, hs_dataset_data)

# Step 4: Evaluate results
# Assuming you have ground-truth implied volatilities for comparison
ground_truth_vol = hs_dataset.data[:, 3]  # Replace with actual column for ground truth
mse = ((ground_truth_vol - implied_volatilities) ** 2).mean()
print(f"MSE: {mse:.6e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 24
#      21         return np.nan  # Return NaN if Brent fails to converge
#      23 # Data generation or loading
# ---> 24 hs_dataset = Heston_LHS_data_generator(10**5, l_bounds=l_bounds, u_bounds=u_bounds)
#      25 hs_data_loader = DataLoader(hs_dataset, batch_size=4048)
#      27 # Step 1: Compute prices using Heston-ANN
#
# NameError: name 'l_bounds' is not defined

# %%
# Loading Train / Test Data
hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0]-train_size])
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}
train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])
# Out:
# (93178, 8)
# True
# ------ INPUT ------
# S/K.......... [0.61 1.39]
# Tau.......... [0.11 1.39]
# r............ [0.01 0.09]
# Corr ........ [-0.94 -0.01]
# Kappa........ [0.41 1.99]
# V_bar........ [0.01 0.49]
# Gamma........ [0.01 0.49]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [-0.00 0.63]

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs, targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs, targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs, targets)) )
print("R2 {:e}".format(r2_score(outputs, targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs, targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs, targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs, targets)) )
print("R2 {:e}".format(r2_score(outputs, targets)) )
# Out:
# -----------Train scores----------------
# MSE 1.610120e-07
# MAE 3.071456e-04
# MAPE 3.364305e-02
# R2 9.999927e-01
# -----------Test scores----------------
# MSE 1.593581e-07
# MAE 3.047288e-04
# MAPE 1.600726e-02
# R2 9.999928e-01

# %%
np.sqrt(1.670718e-07)
print("MSE {:e}".format(np.sqrt(1.670718e-07)) )
# Out:
# MSE 4.087442e-04

# %% [markdown]
# # 5) BRENT

# %% [markdown]
# # 6) Pipeline 1: COS + BRENT

# %%
eps = 1e-2 # is used to generate open intervals
# (S/K), (tau), (r), (rho), (kappa), (vbar), (gamma), (v0).
# CASE 1 in table 11
l_bounds = [.75+eps, .4+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps]
u_bounds = [1.25-eps, 1.0-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds = l_bounds, u_bounds=u_bounds)
hs_dataset_data = hs_dataset.data
hs_dataset_data = hs_dataset_data[:,np.array([0,1,2,8])]
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, hs_dataset_data)
# Out:
# (93320, 8)
# True
# ------ INPUT ------
# S/K.......... [0.76 1.24]
# Tau.......... [0.41 0.99]
# r............ [0.01 0.09]
# Corr ........ [-0.94 -0.01]
# Kappa........ [0.41 1.99]
# V_bar........ [0.01 0.49]
# Gamma........ [0.01 0.49]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00 0.47]

# %% [markdown]
# # 7) Pipeline 2: Heston-ANN + IV-ANN

# %%
# Loading model
device = torch.device("cuda")
loaded_Heston_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_ANN.pt"
loaded_Heston_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_ANN.eval()

# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

# Loading model 
device = torch.device("cuda")
loaded_IV_ANN = IV_ANN().to(device)
PATH = "ANN_weights/IV_SCALED_ANN.pt"
loaded_IV_ANN.load_state_dict(torch.load(PATH))
loaded_IV_ANN.eval()


# Plugging in the Heston-ANN prices
hs_dataset2 = hs_dataset.data[:,np.array([0,1,2,8])]
hs_dataset2.data[:,3] = torch.FloatTensor(prices)
loader2 = torch.utils.data.DataLoader(hs_dataset2, 4048)

# Computing IVs
implied_vol = []
indecies_list = []
with torch.no_grad():
  for idx, data in enumerate(loader2):
    data = data.to(device)
    # LOG Transformation
    data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
    data[:,3] = torch.log(data[:,3])
    output = loaded_IV_ANN(data)
    implied_vol.append((output).data.cpu().numpy())
  implied_vol_pipe2 = np.concatenate(implied_vol)
  # indecies_list = np.concatenate(indecies_list).flatten()

# %%
# Eliminating Nan values resulting from prices lower than 1e-7
indecies = np.argwhere(np.isnan(implied_vol_pipe2))
implied_vol_pipe1 = np.delete(implied_vol_pipe1, indecies,0)
implied_vol_pipe2 = np.delete(implied_vol_pipe2, indecies,0)

# %% [markdown]
# # 8) Pipeline 1 VS pipeline 2

# %%
# CASE 1
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
#targets = vol_imp
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Vol scores----------------
# MSE 2.064996e-06
# RMSE 1.437010e-03
# MAE 1.112770e-03
# MAPE 2.353723e-03
# R2 9.997818e-01

# %%
# CASE 2
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Vol scores----------------
# MSE 2.064996e-06
# RMSE 1.437010e-03
# MAE 1.112770e-03
# MAPE 2.353723e-03
# R2 9.997818e-01

# %% [markdown]
# # 9) Volatility surface (COS + IV-ANN)

# %% [markdown]
# ### Initial volatility surface

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
moyeness = np.linspace(moyeness, 1.24,11)
tau = np.linspace(tau, 1, 6)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(66)).reshape((-1, 1))

# %%
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  bs_IV = (output).data.cpu().numpy()

X = X.flatten()
Y = Y.flatten()
Z = bs_IV

x = np.reshape(X, (-1, 6))
y = np.reshape(Y, (-1, 6))
z = np.reshape(Z, (-1, 6))

# %%
from mpl_toolkits import mplot3d
from matplotlib import cm

# %%
# Plotting the initial volatility surface
plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to matuirity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Smoothing the volatility surface

# %%
from scipy import interpolate

# %%
# Smoothing the volatility surface
xnew, ynew = x.copy(), y.copy()
tck = interpolate.bisplrep(x, y, z, s=1.0)
znew = interpolate.bisplev(xnew[:,0], ynew[0,:], tck)

plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(xnew, ynew, znew,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to maturity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Implied volatility difference

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
n_moneyness = 11
n_tau = 6
moyeness = np.linspace(moyeness, 1.24,n_moneyness)
tau = np.linspace(tau, 1, n_tau)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
rho = np.array(rho*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
kappa = np.array(kappa*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
vbar = np.array(vbar*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
gamma = np.array(gamma*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
v0 = np.array(v0*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(n_tau * n_moneyness)).reshape((-1, 1))

# %%
data_ann = np.concatenate((X, Y, r, rho, kappa, vbar, gamma, v0, cos_prices), axis = 1)
data_ann = torch.FloatTensor(data_ann)
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  implied_vol_pipe2 = (output).data.cpu().numpy()

# %%
X = X.flatten()
Y = Y.flatten()
Z = (implied_vol_pipe1 - implied_vol_pipe2).flatten()

x = np.reshape(X, (-1, min(n_moneyness, n_tau)))
y = np.reshape(Y, (-1, min(n_moneyness, n_tau)))
z = np.reshape(Z, (-1, min(n_moneyness, n_tau)))

plt.figure(figsize=(8,8))
plt.pcolormesh(x, y, z, shading='gouraud')
plt.colorbar()
plt.xlabel("Moneyness")
plt.ylabel("Time to maturity")
plt.show()

# %%
# Re-import necessary libraries and re-define the setup after reset
from scipy.optimize import differential_evolution
import numpy as np

# Define the objective function
def objective_function(x):
    # Example: A simple quadratic function
    return x[0]**2 + x[1]**2 + x[2]**2

# Define the bounds for each variable
bounds = [(-10, 10), (-10, 10), (-10, 10)]  # Variable bounds for a 3D problem

# Run Differential Evolution with the specified settings
result_custom_de = differential_evolution(
    objective_function,  # Objective function
    bounds,             # Variable bounds
    strategy="best1bin",  # Strategy
    popsize=50,          # Population size
    mutation=(0.5, 1.0), # Mutation range
    recombination=0.7,   # Crossover probability
    tol=0.01,            # Convergence tolerance
    disp=False           # Suppress output during the run
)

# Display the result
result_custom_de
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 0.0
#        x: [ 0.000e+00  0.000e+00  0.000e+00]
#      nit: 130
#     nfev: 19654
