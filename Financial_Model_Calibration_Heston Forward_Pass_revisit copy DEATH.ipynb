# %% [markdown]
# # Financial Model Calibration using ANNs (CaNN, Calibration Neural Network)
#
# ##### from "A neural network-based framework for financial model calibration", Liu et al. ([1])
# ##### and "Pricing options and computing implied volatilities using neural networks", Liu et al. ([2])

# %% [markdown]
# # -------------------------------------------------------

# %% [markdown]
# ## The framework consists of 3 Phases, i.e.:
#
# ### 1. Training (Forward pass)
# ### 2. Prediction (Forward pass)
# ### 3. Calibration (Backward pass)

# %% [markdown]
# # -------------------------------------------------------

# %% [markdown]
# Table of contents
#
# ### 1) Forward pass
# ###### a) Preperation
# ###### b) Data generation
# ###### c) Training Heston-IV-ANN
# ###### d) Prediction
# ###### e) Volatility Surface (In doing)
#
# ### 2) Backward pass
# ###### a) Preperation Market Quotes
# ###### b) Differential Evolution (DE)

# %% [markdown]
# # -------------------------------------------------------

# %% [markdown]
# # 1) Forward pass

# %% [markdown]
# ## a) Preperation

# %%
# Basic imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# Updating scipy to use module QMC for Latin hypercube sampling
#!pip install scipy==1.7
from scipy.stats import qmc

# Pytorch imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR, LinearLR, OneCycleLR, LambdaLR

from scipy.optimize import differential_evolution

# %%
# run on GPU
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### Black-Scholes

# %%
def bs_price_call(S, K, T, t, r, sigma):
  """
  Black-Scholes call option value price related to PDE (2). Returns option's price.
  S:     spot price
  K:     strike price
  T:     time to maturity
  t:     spot time
  r:     interest rate
  sigma: volatility of underlying asset
  """

  # Boundary condition of Black-Sholes PDE (2)
  if T == t:
    return np.maximum(0, S - K)  
  # Solution of the PDE (2) on the open interval [t, T)
  else : 
    d1 = ( np.log(S / K) + (r + 0.5 * sigma ** 2) * (T-t) ) / (sigma * np.sqrt(T-t))
    d2 = d1 - sigma*np.sqrt(T-t)
    value = S * norm.cdf(d1) - K * np.exp(-r * (T-t)) * norm.cdf(d2) 
  
  return value

def bs_moneyness_call(moneyness, tau, r, sigma):
  """
  Same function as bs_price_call but in terms of moneyness. Returns V/K and 
  has S/K instead of two seperate paremeters S and K.
  moneyness: S/K
  Tau: time to maturity minus spot time
  r: interest rate
  sigma: volatility of underlying asset
  """

  d1 = ( np.log(moneyness) + (r + 0.5 * sigma ** 2) * (tau) ) / (sigma * np.sqrt(tau))
  d2 = d1 - sigma*np.sqrt(tau)
  value_moneyness = moneyness * norm.cdf(d1) - np.exp(-r * (tau)) * norm.cdf(d2) 
  
  return value_moneyness

# %% [markdown]
# ##### Defining class Heston-IV-ANN

# %%
class Heston_ANN(nn.Module):
  def __init__(self):
    """
    Initilize Heston-IV-ANN netwwork with four hidden layers. 
    Same architecture as the one used in Table (2) [2].
    Weight are initialized using Glorot_uniform also known as Xavier_uniform.
    """
    super(Heston_ANN, self).__init__()
    # 4 layers
    self.fc1 = nn.Linear(8, 200)
    self.fc2 = nn.Linear(200, 200)
    self.fc3 = nn.Linear(200, 200)
    self.fc4 = nn.Linear(200, 200)
    self.fc5 = nn.Linear(200, 1)
    # initilizing the layer's weights
    torch.nn.init.xavier_uniform_(self.fc1.weight) 
    torch.nn.init.xavier_uniform_(self.fc2.weight)
    torch.nn.init.xavier_uniform_(self.fc3.weight)
    torch.nn.init.xavier_uniform_(self.fc4.weight)
    torch.nn.init.xavier_uniform_(self.fc5.weight)


  def forward(self, x):
    """
    Foward pass of the network. 
    Relu activations are used and a linear activation is used in the final layer.
    x: input torch tensor (CUDA or CPU)
    """
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = F.relu(self.fc3(x))
    x = F.relu(self.fc4(x))
    x = self.fc5(x)
    return x.flatten()

  def train_model(self, args, device, train_loader, optimizer, epoch):
    """
    Training over train_loader batches for one epoch.
    Returns average training loss.
    args: training parameters.
    device: CUDA or CPU.
    train_loader: train data loader.
    optimizer: gradient descent optmizer.
    epoch: current epoch.
    """
    # train mode
    self.train()
    train_loss = 0
    # loop over data loader
    for batch_idx, data in enumerate(train_loader):
      # extracting the inputs and target
      data, target = data[:,:-1].to(device), data[:,-1].to(device)
      # zeroing the gradients
      optimizer.zero_grad()
      # foward pass
      output = self(data)
      # computing the loss
      loss = F.mse_loss(output, target)
      train_loss += loss.item() * data.shape[0]
      # back propagation
      loss.backward()
      # updating the optimizer step
      optimizer.step()
      # printing batch information
      if batch_idx % args["log_interval"] == 0:
        print('Train Epoch: {} [{}/{} ({:.0f}%)]\tlog Loss: {:.6f}'.format(
            epoch, int(batch_idx / len(train_loader)*len(train_loader.dataset)), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), np.log(loss.item())))
        if args["dry_run"]:
          break
    train_loss /= len(train_loader.dataset)
    print('\nTrain set: Average log loss: {:.4f}\n'.format(np.log(train_loss))) 
    return train_loss


  def test_model(self, device, test_loader):
    """
    Testing over test_loader batches for one epoch. 
    Returns average test loss.
    device: CUDA or CPU.
    test_loader: test data loader.
    """
    # evaluation mode
    self.eval()
    test_loss = 0
    # freezing the gradients
    with torch.no_grad():
      # looping over the test laoder
      for data in test_loader:
        # extracting the inputs and target
        data, target = data[:,:-1].to(device), data[:,-1].to(device)
        # foward pass
        output = self(data)
        #computing the loss
        test_loss += F.mse_loss(output, target, reduction = 'sum').item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}\n'.format(np.log(test_loss))) 
    return test_loss

# %% [markdown]
# ## b) Data generation

# %% [markdown]
# ### Numerical method here: Heston and COS

# %% [markdown]
# #### COS Method

# %% [markdown]
# #### Vanilla call coefficients

# %% [markdown]
# $\begin{aligned} \chi_{k}(c, d):=& \frac{1}{1+\left(\frac{k \pi}{b-a}\right)^{2}}\left[\cos \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\cos \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right.\\ &\left.+\frac{k \pi}{b-a} \sin \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\frac{k \pi}{b-a} \sin \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right] \end{aligned}$

# %% [markdown]
# $\psi_{k}(c, d):= \begin{cases}{\left[\sin \left(k \pi \frac{d-a}{b-a}\right)-\sin \left(k \pi \frac{c-a}{b-a}\right)\right] \frac{b-a}{k \pi},} & k \neq 0, \\ (d-c), & k=0 .\end{cases}$

# %% [markdown]
# $V_{k}^{\text {call }}=\frac{2}{b-a} K\left(\chi_{k}(0, b)-\psi_{k}(0, b)\right)$

# %%
def call_cosine_coef(a, b, c, d, K, N):
  """
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  K: Strike.
  N: summing lenght.
  Returns V_k coefficient for call option.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*K*(chi_k-psi_k)

# %%
def call_cosine_coef_moy(a, b, c, d, N):
  """
  Moyeness version.
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  N: summing lenght.
  Returns V_k coefficient for call option devided by K.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*(chi_k-psi_k)

# %% [markdown]
# #### Charateristic function for Heston model

# %% [markdown]
# $\begin{aligned} \varphi_{h e s}\left(\omega ; u_{0}\right)=& \exp \left(i \omega \mu \Delta t+\frac{u_{0}}{\eta^{2}}\left(\frac{1-e^{-D \Delta t}}{1-G e^{-D \Delta t}}\right)(\lambda-i \rho \eta \omega-D)\right) \\ & \cdot \exp \left(\frac{\lambda \bar{u}}{\eta^{2}}\left(\Delta t(\lambda-i \rho \eta \omega-D)-2 \log \left(\frac{1-G e^{-D \Delta t}}{1-G}\right)\right)\right) \end{aligned}$

# %% [markdown]
# $D=\sqrt{(\lambda-i \rho \eta \omega)^{2}+\left(\omega^{2}+i \omega\right) \eta^{2}} \quad$ and $\quad G=\frac{\lambda-i \rho \eta \omega-D}{\lambda-i \rho \eta \omega+D} $

# %%
def phi_Heston(a ,b ,N ,r, tau, kappa, gamma, vbar, v0, rho):
  """
  Characteristic function of the log-asset price following the Heston model.
  Section 3.3, equation (33).
  a, b: truncation range parameters.
  N: summing lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns Charateristic function vector.
  """
  #if kappa < 1e-4:
  #  print("kapp < 1e-4")
  #  kappa = 1e-5
  k = np.arange(N).reshape(1,-1)
  u = np.pi*k/(b-a)
  i = complex(0.0,1.0)
  D = np.sqrt((kappa-gamma*rho*i*u)**2+(u**2+i*u)*gamma**2)
  G = (kappa-gamma*rho*i*u-D)/(kappa-gamma*rho*i*u+D)
  C = v0* (1-np.exp(-D*tau)) / (gamma**2*(1-G*np.exp(-D*tau)))*(kappa-gamma*rho*i*u-D)
  A = r*i*u*tau + kappa*vbar/(gamma**2)*(tau*(kappa-gamma*rho*i*u-D) -2*np.log( (1-G*np.exp(-D*tau))/(1-G) )   ) 
  phi = np.exp( A + C )
  return phi

# %% [markdown]
# #### Heston cumulants

# %% [markdown]
# $c_{1}=\mu T+\left(1-e^{-\lambda T}\right) \frac{\bar{u}-u_{0}}{2 \lambda}-\frac{1}{2} \bar{u} T$

# %% [markdown]
# $\begin{aligned} c_{2}=& \frac{1}{8 \lambda^{3}}\left(\eta T \lambda e^{-\lambda T}\left(u_{0}-\bar{u}\right)(8 \lambda \rho-4 \eta)\right.\\ &+\lambda \rho \eta\left(1-e^{-\lambda T}\right)\left(16 \bar{u}-8 u_{0}\right) \\ &+2 \bar{u} \lambda T\left(-4 \lambda \rho \eta+\eta^{2}+4 \lambda^{2}\right) \\ &+\eta^{2}\left(\left(\bar{u}-2 u_{0}\right) e^{-2 \lambda T}+\bar{u}\left(6 e^{-\lambda T}-7\right)+2 u_{0}\right) \\ &\left.+8 \lambda^{2}\left(u_{0}-\bar{u}\right)\left(1-e^{-\lambda T}\right)\right) \end{aligned}$

# %%
def Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho ):
  """
  Computes Heston cumulants as defined in the appendix A for the Heston model.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns cumulants c1 and c2.
  """

  #if kappa == 0:
  #  c1 = r * tau + tau * (vbar - v0) / 2 - 0.5 * vbar * tau
  #else: 
  #   c1 = r * tau + (1 - np.exp(- kappa * tau)) * (vbar - v0) / (2 * kappa) - 0.5 * vbar * tau
  
  c1 = r * tau + (1 - np.exp(- kappa * tau)) * (vbar - v0) / (2 * kappa) - 0.5 * vbar * tau


  #safe_kappa = np.max(kappa, 1e-5)
  safe_kappa = kappa
  c2 = 0.125 / safe_kappa ** 3 * (gamma * tau * np.exp(- safe_kappa * tau) * (v0 - vbar) * (8 * safe_kappa * rho - 4 * gamma) + \
     safe_kappa * rho * gamma * (1 - np.exp(- safe_kappa * tau)) * (16 * vbar - 8 * v0) + \
     2 * vbar * safe_kappa * tau * (- 4 * safe_kappa * rho * gamma + gamma ** 2 + 4 * safe_kappa ** 2) + \
     gamma ** 2 * ((vbar - 2 * v0) * np.exp(-2 * safe_kappa * tau) + vbar * (6 * np.exp(- safe_kappa * tau) - 7) + 2 * v0) + \
     8 * safe_kappa ** 2 * (v0 - vbar) * (1 - np.exp(-safe_kappa * tau)))
  return c1, c2

# %% [markdown]
# #### Truncation range

# %% [markdown]
# $[a, b]:=\left[c_{1}-L \sqrt{c_{2}+\sqrt{c_{4}}}, \quad c_{1}+L \sqrt{c_{2}+\sqrt{c_{4}}}\right]$

# %%
def Truncation_range(c1, c2, c4, L):
  """
  Computes the truncation range given the cumulants c1, c2, c4 and the truncation lenght L.
  c1, c2, c4: Model cumulants.
  L: truncation lenght.
  Returns tuncation interval sup b and inf a.
  """
  a = c1 - L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) )
  b = c1 + L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) ) 
  return a, b

# %% [markdown]
# #### Exponential coefficient

# %% [markdown]
# $e^{i k \pi \frac{\mathbf{x}-a}{b-a}}$

# %%
def exponential_coef(a, b, N, S0, K):
  """
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  S0: asset initial price.
  K: strike.
  Returns the exponential coefficient vector.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(S0/K)-a)/(b-a))

# %%
def exponential_coef_moy(a, b, N, moyeness):
  """
  Moyeness version.
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  moyeness: S/K.
  Returns the exponential coefficient vector devided by K.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(moyeness)-a)/(b-a))

# %% [markdown]
# #### Vanilla call price

# %% [markdown]
# $v\left(\mathbf{x}, t_{0}, u_{0}\right) \approx \mathbf{K} e^{-r \Delta t} \cdot \operatorname{Re}\left\{\sum_{k=0}^{N-1} \varphi_{h e s}\left(\frac{k \pi}{b-a} ; u_{0}\right) U_{k} \cdot e^{i k \pi \frac{\mathbf{x}-a}{b-a}}\right\}$

# %%
def call_option_Heston(N, L, r, tau, kappa, gamma, vbar, v0, rho, K, S0 ):
  """
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  S0: asset initial price.
  K: strike.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef(a, b, c, d, K, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef(a, b, N, S0, K)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, K = K, S0 = S0)
# Out:
# True
# array([[29.79261082]])

# %%
def call_option_Heston_moy(N, L, r, tau, kappa, gamma, vbar, v0, rho, moyeness ):
  """
  Moyeness version.
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  moyeness: S/K.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef_moy(a, b, c, d, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef_moy(a, b, N, moyeness)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston_moy(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = 1)
# Out:
# True
# array([[0.29792611]])

# %% [markdown]
# # Latin Hypercube Sampling

# %% [markdown]
# ### Generating Data

# %% [markdown]
# #### Sampling range for the Heston parameters (Table (3) in [1])

# %%
# here Table (3) of [1] is used, kappa is numerically sensitive to small values
eps = 1e-2 # is used to generate open intervals
def Heston_LHS_data_generator(n = 10**6, l_bounds = [.6+eps, .05+eps, .0+eps, -0.9+eps, 0.4+eps, .01+eps, .01+eps, .05+eps], u_bounds = [1.4-eps, 3.0-eps, .05-eps, 0.0-eps, 3.0-eps, .5-eps, .8-eps, .5-eps]):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,9) containig the inputs samples and the value of the call.
  The inputs are: Moyeness (S/K), time to maturity (tau), Risk free rate (r), Correlation (rho), reversion speed (kappa), Long average variance (vbar), Vol of vol (gamma), Initial variance (v0).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.
  """
  sampler = qmc.LatinHypercube(d = 8) #, seed = 0
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  indecies = np.argwhere(2*sample[:,4]*sample[:,5] <= sample[:,6]**2)
  sample = np.delete(sample, indecies, 0)
  hs_prices = call_option_Heston_moy(N = 500, L= 12, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa = sample[:,4].reshape((-1,1)),\
                                     gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
                                     rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  #hs_prices = call_option_Heston_moy(N = 1500, L= 50, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
  #                                    gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
  #                                    rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))

  # hs_dataset = np.concatenate((sample, hs_prices),axis=1)

  print("------ INPUT ------")
  print("S/K.......... [{:.2f}, {:.2f}]".format(sample[:,0].min(), sample[:,0].max()))
  print("Tau.......... [{:.2f}, {:.2f}]".format(sample[:,1].min(), sample[:,1].max()))
  print("r............ [{:.2f}, {:.2f}]".format(sample[:,2].min(), sample[:,2].max()))
  print("Corr ........ [{:.2f}, {:.2f}]".format(sample[:,3].min(), sample[:,3].max()))
  print("Kappa........ [{:.2f}, {:.2f}]".format(sample[:,4].min(), sample[:,4].max()))
  print("V_bar........ [{:.2f}, {:.2f}]".format(sample[:,5].min(), sample[:,5].max()))
  print("Gamma........ [{:.2f}, {:.2f}]".format(sample[:,6].min(), sample[:,6].max()))
  print("V_0 ......... [{:.2f}, {:.2f}]".format(sample[:,7].min(), sample[:,7].max()))
  print("------ OUTPUT ------")
  print("V/K.......... [{:.2f}, {:.2f}]".format(hs_prices.min(), hs_prices.max()))

  return sample, hs_prices


testset = Heston_LHS_data_generator(10**4)
# Out:
# ------ INPUT ------
# S/K.......... [0.61, 1.39]
# Tau.......... [0.06, 2.99]
# r............ [0.01, 0.04]
# Corr ........ [-0.89, -0.01]
# Kappa........ [0.41, 2.99]
# V_bar........ [0.02, 0.49]
# Gamma........ [0.02, 0.79]
# V_0 ......... [0.06, 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00, 0.76]

# %% [markdown]
# ## c) Training Heston-IV-ANN

# %% [markdown]
# ### Use Brent to inverse price to implied volatility (IV)

# %%
eps = 1e-2 # is used to generate open intervals
def Heston_LHS_data_generator_OLD(n = 10**6, l_bounds = [.6+eps, .1+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps], u_bounds = [1.4-eps, 1.4-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,9) containig the inputs samples and the value of the call.
  The inputs are: Moyeness (S/K), time to maturity (tau), Risk free rate (r), Correlation (rho), reversion speed (kappa), Long average variance (vbar), Vol of vol (gamma), Initial variance (v0).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.
  """
  sampler = qmc.LatinHypercube(d=8) #, seed = 0
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  indecies = np.argwhere(2*sample[:,4]*sample[:,5]<= sample[:,6]**2)
  sample = np.delete(sample, indecies,0)
  # print(sample.shape)
  # print(2*kappa*vbar>gamma**2)
  hs_prices = call_option_Heston_moy(N = 160, L= 12, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
                                     gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
                                     rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  # hs_prices = call_option_Heston_moy(N = 1500, L= 50, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
  #                                    gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
  #                                    rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  
  hs_dataset = np.concatenate((sample, hs_prices),axis=1)

  print("------ INPUT ------")
  print("S/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,0]),max(hs_dataset[:,0])))
  print("Tau.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,1]),max(hs_dataset[:,1])))
  print("r............ [{:.2f} {:.2f}]".format(min(hs_dataset[:,2]),max(hs_dataset[:,2])))
  print("Corr ........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,3]),max(hs_dataset[:,3])))
  print("Kappa........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,4]),max(hs_dataset[:,4])))
  print("V_bar........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,5]),max(hs_dataset[:,5])))
  print("Gamma........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,6]),max(hs_dataset[:,6])))
  print("V_0 ......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,7]),max(hs_dataset[:,7])))
  print("------ OUTPUT ------")
  print("V/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,-1]),max(hs_dataset[:,-1])))
  # ind_max = np.argmax(hs_dataset[:,-1])
  # print(hs_dataset[ind_max,:])

  return torch.FloatTensor(hs_dataset)

# %%
from scipy import optimize

def calcimpliedvol_OLD(dataset):
    """
    Computes the implied volatilities using the brent method.
    dataset: numpy array containing moneyness, time to maturity, risk free interest rate and V/K.
    Returns a vector of implied volatilities.
    """
    money = np.array(dataset[0])
    T = np.array(dataset[1])
    r = np.array(dataset[2])
    marketoptionPrice = np.array(dataset[3])
    def bs_price(sigma):
      d1 = ( np.log(money) + (r + 0.5 * sigma ** 2) * (T) ) / (sigma * np.sqrt(T))
      d2 = d1 - sigma*np.sqrt(T)
      value_moyeness = money * norm.cdf(d1) - np.exp(-r * (T)) * norm.cdf(d2) 
      fx = value_moyeness - marketoptionPrice
      return fx
    return optimize.brentq(bs_price,-1,1,maxiter=100)

# %%
eps = 1e-2 # is used to generate open intervals
# (S/K), (tau), (r), (rho), (kappa), (vbar), (gamma), (v0).
# CASE 1 in table 11
l_bounds = [.75+eps, .4+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps]
u_bounds = [1.25-eps, 1.-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]
hs_dataset_OLD = Heston_LHS_data_generator_OLD(10**5, l_bounds = l_bounds, u_bounds=u_bounds)
hs_dataset_OLD_data = hs_dataset_OLD.data
hs_dataset_OLD_data = hs_dataset_OLD_data[:,np.array([0,1,2,8])]
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol_OLD, 1, hs_dataset_OLD_data)
# Out:
# ------ INPUT ------
# S/K.......... [0.76 1.24]
# Tau.......... [0.41 0.99]
# r............ [0.01 0.09]
# Corr ........ [-0.94 -0.01]
# Kappa........ [0.41 1.99]
# V_bar........ [0.01 0.49]
# Gamma........ [0.01 0.49]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00 0.46]

# %%
# Print first data point and corresponding implied vol
print("Inputs size:", hs_dataset_OLD_data.shape)
print("Inputs (m, T, r, V/K):", hs_dataset_OLD_data[9330])
print("Implied vol:", implied_vol_pipe1[9330])
# Out:
# Inputs size: torch.Size([93253, 4])
# Inputs (m, T, r, V/K): tensor([1.1673, 0.5640, 0.0654, 0.2382])
# Implied vol: 0.3368300130730295

# %%
from scipy.stats import norm
from scipy.optimize import brentq
import numpy as np

def bs_price(sigma, m, T, r):
    if sigma <= 0:
        return 0.0
    d1 = (np.log(1 / m) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    return np.exp(-r * T) * (norm.cdf(d1) - m * norm.cdf(d2))

def calcimpliedvol(x):  # x = [moneyness, T, r, price]
    m, T, r, price = x
    global counter
    # Avoid division by 0 or invalid prices
    if price <= 1e-8 or m <= 0 or T <= 0:
        return np.nan

    try:
        #counter += 1
        # Quick feasibility check before Brent
        low = bs_price(1e-4, m, T, r)
        high = bs_price(5.0, m, T, r)

        f_low = bs_price(1e-4, m, T, r) - price
        f_high = bs_price(5.0, m, T, r) - price
        #print(f"Brent signs: f(low)={f_low:.4e}, f(high)={f_high:.4e}")
        #print(f"low ={low:.4e}, high={high:.4e}")
        if not (low < price < high):
            return np.nan

        # Brent root finding
        implied_vol = brentq(
            lambda sigma: bs_price(sigma, m, T, r) - price,
            a=1e-4,
            b=10.0,
            maxiter=1000,
            xtol=1e-8
        )
        return implied_vol

    except Exception as e:
        counter = 1
        print(f"⚠️ Brent failed: {e}")
        print(f"Inputs: m={m:.4f}, T={T:.4f}, r={r:.4f}, price={price:.4f}")
        print(f"BS@low= {bs_price(1e-4, m, T, r):.4f}, BS@high= {bs_price(5.0, m, T, r):.4f}")
        return np.nan

# %% [markdown]
# ### Add IV to final data

# %%
sample, hs_prices = Heston_LHS_data_generator(n = 10**5)
# Convert to NumPy for processing
sample_np = sample
hs_prices_np = hs_prices

# Combine required inputs for Brent
brent_input = np.concatenate([sample_np[:, [0, 1, 2]], hs_prices_np], axis=1)  # shape (n, 4)

print("brent_input shape:", brent_input.shape)

# Apply Brent row by row
implied_vols = np.array([
    calcimpliedvol(row) for row in brent_input
])

# Filter out NaNs
valid_idx = ~np.isnan(implied_vols)
sample_np = sample_np[valid_idx]
implied_vols = implied_vols[valid_idx]

# Recombine into final dataset (input + IV target)
final_dataset = np.concatenate([sample_np, implied_vols.reshape(-1, 1)], axis=1)

# Convert to torch Tensor
hs_dataset = torch.FloatTensor(final_dataset)
# Out:
# ------ INPUT ------
# S/K.......... [0.61, 1.39]
# Tau.......... [0.06, 2.99]
# r............ [0.01, 0.04]
# Corr ........ [-0.89, -0.01]
# Kappa........ [0.41, 2.99]
# V_bar........ [0.02, 0.49]
# Gamma........ [0.02, 0.79]
# V_0 ......... [0.06, 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00, 0.76]
# brent_input shape: (86029, 4)

# %%
print("First sample:\n", hs_dataset[0])
print("sample_np shape:", sample_np.shape)
print("implied_vols shape:", implied_vols.shape)
# Out:
# First sample:
#  tensor([ 1.0413,  1.0797,  0.0185, -0.1741,  2.8999,  0.1048,  0.4201,  0.1990,
#          0.4942])
# sample_np shape: (60132, 8)
# implied_vols shape: (60132,)

# %%
for i in range(25):
    print(f"Row {i}: m={brent_input[i,0]:.2f}, T={brent_input[i,1]:.2f}, r={brent_input[i,2]:.2f}, price={brent_input[i,3]:.4f} → IV={implied_vols[i]:.4f}")
# Out:
# Row 0: m=0.80, T=2.89, r=0.02, price=0.1137 → IV=0.4942
# Row 1: m=1.04, T=1.08, r=0.02, price=0.1830 → IV=0.8032
# Row 2: m=1.23, T=2.75, r=0.01, price=0.4284 → IV=1.2440
# Row 3: m=0.75, T=0.98, r=0.02, price=0.1078 → IV=1.0307
# Row 4: m=1.26, T=1.80, r=0.02, price=0.5243 → IV=0.9554
# Row 5: m=1.23, T=1.05, r=0.03, price=0.3309 → IV=0.8993
# Row 6: m=1.10, T=0.44, r=0.03, price=0.2084 → IV=0.9440
# Row 7: m=0.79, T=1.87, r=0.02, price=0.0688 → IV=0.2350
# Row 8: m=1.16, T=1.16, r=0.03, price=0.3164 → IV=0.9442
# Row 9: m=1.12, T=0.46, r=0.02, price=0.2065 → IV=0.0866
# Row 10: m=0.62, T=0.56, r=0.03, price=0.0035 → IV=0.4297
# Row 11: m=0.86, T=2.26, r=0.03, price=0.1936 → IV=0.6318
# Row 12: m=0.75, T=1.11, r=0.01, price=0.0207 → IV=0.6857
# Row 13: m=0.87, T=0.24, r=0.03, price=0.0396 → IV=0.5907
# Row 14: m=0.63, T=2.29, r=0.02, price=0.0663 → IV=0.3365
# Row 15: m=1.16, T=2.41, r=0.03, price=0.4670 → IV=1.2796
# Row 16: m=0.73, T=0.84, r=0.03, price=0.0523 → IV=0.5474
# Row 17: m=0.81, T=2.52, r=0.01, price=0.1914 → IV=1.0699
# Row 18: m=0.67, T=0.37, r=0.04, price=0.0039 → IV=0.6208
# Row 19: m=0.96, T=2.42, r=0.03, price=0.2566 → IV=0.8079
# Row 20: m=0.98, T=1.61, r=0.04, price=0.2966 → IV=0.5815
# Row 21: m=1.08, T=1.27, r=0.01, price=0.2692 → IV=1.3410
# Row 22: m=1.00, T=1.11, r=0.03, price=0.2375 → IV=1.5164
# Row 23: m=0.79, T=0.18, r=0.01, price=0.0181 → IV=1.0836
# Row 24: m=0.93, T=0.48, r=0.03, price=0.1275 → IV=1.0449

# %%
# Inputs
m = 1.01
T = 2.86
r = 0.02
sigma = 0.5736

# Compute d1, d2
d1 = (np.log(m) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
d2 = d1 - sigma * np.sqrt(T)

# BS price in moneyness form
bs_price = m * norm.cdf(d1) - np.exp(-r * T) * norm.cdf(d2)

print("BS Price:", bs_price)
# Out:
# BS Price: 0.39745370187324625

# %%
plt.figure(figsize=(8, 4))
plt.hist(implied_vols, bins=100, edgecolor='black')
plt.title("Distribution of Implied Volatilities (Brent)")
plt.xlabel("Implied Volatility")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Training of the ANN

# %%
# Training parameters
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 8*10**3,
         "lr": 1e-4,
         "gamma": .5,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}


use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# torch.manual_seed(args["seed"])

# Loading Train / Test Data
#hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0] - train_size])

train_loader = torch.utils.data.DataLoader(train_dataset, args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])


# Model training
print(device)
model = Heston_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=args["lr"]) # Adam is found to be the best optimizer in the article
scheduler = StepLR(optimizer, step_size=500, gamma=args["gamma"]) # Deacreses the Learning rate by .5 every 500 epoch

train_losses = []
test_losses = []
for epoch in range(1, args["epochs"] + 1):
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
if args["save_model"] :
  torch.save(model.state_dict(), "ANN_weights/Heston_IV_ANN_DE_DEATH.pt")
# Out:
# cuda
# Train Epoch: 1 [0/54118 (0%)]	log Loss: 0.016690
#
# Train set: Average log loss: -1.0209
#
#
# Test set: Average loss: -1.5084
#
# Current Learning rate 0.0001
# Train Epoch: 2 [0/54118 (0%)]	log Loss: -1.386092
#
# Train set: Average log loss: -1.6402
#
#
# Test set: Average loss: -1.8624
#
# Current Learning rate 0.0001
# Train Epoch: 3 [0/54118 (0%)]	log Loss: -1.743948
#
# Train set: Average log loss: -2.1059
#
#
# Test set: Average loss: -2.6212
#
# Current Learning rate 0.0001
# Train Epoch: 4 [0/54118 (0%)]	log Loss: -2.451223
#
# Train set: Average log loss: -3.0727
#
#
# Test set: Average loss: -3.5786
#
# Current Learning rate 0.0001
# Train Epoch: 5 [0/54118 (0%)]	log Loss: -3.331504
#
# Train set: Average log loss: -3.7838
#
#
# Test set: Average loss: -4.0824
#
# Current Learning rate 0.0001
# Train Epoch: 6 [0/54118 (0%)]	log Loss: -3.843187
#
# Train set: Average log loss: -4.2385
#
#
# Test set: Average loss: -4.4537
#
# Current Learning rate 0.0001
# Train Epoch: 7 [0/54118 (0%)]	log Loss: -4.239012
#
# Train set: Average log loss: -4.5630
#
#
# Test set: Average loss: -4.7041
#
# Current Learning rate 0.0001
# Train Epoch: 8 [0/54118 (0%)]	log Loss: -4.511135
#
# Train set: Average log loss: -4.8054
#
#
# Test set: Average loss: -4.9031
#
# Current Learning rate 0.0001
# Train Epoch: 9 [0/54118 (0%)]	log Loss: -4.739455
#
# Train set: Average log loss: -4.9971
#
#
# Test set: Average loss: -5.0622
#
# Current Learning rate 0.0001
# Train Epoch: 10 [0/54118 (0%)]	log Loss: -4.928378
#
# Train set: Average log loss: -5.1553
#
#
# Test set: Average loss: -5.2032
#
# Current Learning rate 0.0001
# Train Epoch: 11 [0/54118 (0%)]	log Loss: -5.094006
#
# Train set: Average log loss: -5.2916
#
#
# Test set: Average loss: -5.3340
#
# Current Learning rate 0.0001
# Train Epoch: 12 [0/54118 (0%)]	log Loss: -5.246513
#
# Train set: Average log loss: -5.4130
#
#
# Test set: Average loss: -5.4650
#
# Current Learning rate 0.0001
# Train Epoch: 13 [0/54118 (0%)]	log Loss: -5.387030
#
# Train set: Average log loss: -5.5268
#
#
# Test set: Average loss: -5.5963
#
# Current Learning rate 0.0001
# Train Epoch: 14 [0/54118 (0%)]	log Loss: -5.526569
#
# Train set: Average log loss: -5.6380
#
#
# Test set: Average loss: -5.7186
#
# Current Learning rate 0.0001
# Train Epoch: 15 [0/54118 (0%)]	log Loss: -5.653884
#
# Train set: Average log loss: -5.7466
#
#
# Test set: Average loss: -5.8207
#
# Current Learning rate 0.0001
# Train Epoch: 16 [0/54118 (0%)]	log Loss: -5.753152
#
# Train set: Average log loss: -5.8461
#
#
# Test set: Average loss: -5.9126
#
# Current Learning rate 0.0001
# Train Epoch: 17 [0/54118 (0%)]	log Loss: -5.834789
#
# Train set: Average log loss: -5.9396
#
#
# Test set: Average loss: -5.9964
#
# Current Learning rate 0.0001
# Train Epoch: 18 [0/54118 (0%)]	log Loss: -5.908416
#
# Train set: Average log loss: -6.0269
#
#
# Test set: Average loss: -6.0764
#
# Current Learning rate 0.0001
# Train Epoch: 19 [0/54118 (0%)]	log Loss: -5.980423
#
# Train set: Average log loss: -6.1087
#
#
# Test set: Average loss: -6.1377
#
# Current Learning rate 0.0001
# Train Epoch: 20 [0/54118 (0%)]	log Loss: -6.037045
#
# Train set: Average log loss: -6.1869
#
#
# Test set: Average loss: -6.2045
#
# Current Learning rate 0.0001
# Train Epoch: 21 [0/54118 (0%)]	log Loss: -6.100609
#
# Train set: Average log loss: -6.2627
#
#
# Test set: Average loss: -6.2861
#
# Current Learning rate 0.0001
# Train Epoch: 22 [0/54118 (0%)]	log Loss: -6.179377
#
# Train set: Average log loss: -6.3324
#
#
# Test set: Average loss: -6.3542
#
# Current Learning rate 0.0001
# Train Epoch: 23 [0/54118 (0%)]	log Loss: -6.245116
#
# Train set: Average log loss: -6.3950
#
#
# Test set: Average loss: -6.4029
#
# Current Learning rate 0.0001
# Train Epoch: 24 [0/54118 (0%)]	log Loss: -6.294813
#
# Train set: Average log loss: -6.4516
#
#
# Test set: Average loss: -6.4283
#
# Current Learning rate 0.0001
# Train Epoch: 25 [0/54118 (0%)]	log Loss: -6.319189
#
# Train set: Average log loss: -6.5014
#
#
# Test set: Average loss: -6.4451
#
# Current Learning rate 0.0001
# Train Epoch: 26 [0/54118 (0%)]	log Loss: -6.336446
#
# Train set: Average log loss: -6.5460
#
#
# Test set: Average loss: -6.4646
#
# Current Learning rate 0.0001
# Train Epoch: 27 [0/54118 (0%)]	log Loss: -6.356752
#
# Train set: Average log loss: -6.5892
#
#
# Test set: Average loss: -6.4899
#
# Current Learning rate 0.0001
# Train Epoch: 28 [0/54118 (0%)]	log Loss: -6.381842
#
# Train set: Average log loss: -6.6309
#
#
# Test set: Average loss: -6.5197
#
# Current Learning rate 0.0001
# Train Epoch: 29 [0/54118 (0%)]	log Loss: -6.409465
#
# Train set: Average log loss: -6.6708
#
#
# Test set: Average loss: -6.5473
#
# Current Learning rate 0.0001
# Train Epoch: 30 [0/54118 (0%)]	log Loss: -6.434999
#
# Train set: Average log loss: -6.7088
#
#
# Test set: Average loss: -6.5747
#
# Current Learning rate 0.0001
# Train Epoch: 31 [0/54118 (0%)]	log Loss: -6.460491
#
# Train set: Average log loss: -6.7446
#
#
# Test set: Average loss: -6.6013
#
# Current Learning rate 0.0001
# Train Epoch: 32 [0/54118 (0%)]	log Loss: -6.486548
#
# Train set: Average log loss: -6.7800
#
#
# Test set: Average loss: -6.6285
#
# Current Learning rate 0.0001
# Train Epoch: 33 [0/54118 (0%)]	log Loss: -6.514445
#
# Train set: Average log loss: -6.8143
#
#
# Test set: Average loss: -6.6512
#
# Current Learning rate 0.0001
# Train Epoch: 34 [0/54118 (0%)]	log Loss: -6.537908
#
# Train set: Average log loss: -6.8470
#
#
# Test set: Average loss: -6.6739
#
# Current Learning rate 0.0001
# Train Epoch: 35 [0/54118 (0%)]	log Loss: -6.561925
#
# Train set: Average log loss: -6.8786
#
#
# Test set: Average loss: -6.6915
#
# Current Learning rate 0.0001
# Train Epoch: 36 [0/54118 (0%)]	log Loss: -6.582881
#
# Train set: Average log loss: -6.9094
#
#
# Test set: Average loss: -6.7096
#
# Current Learning rate 0.0001
# Train Epoch: 37 [0/54118 (0%)]	log Loss: -6.605548
#
# Train set: Average log loss: -6.9402
#
#
# Test set: Average loss: -6.7301
#
# Current Learning rate 0.0001
# Train Epoch: 38 [0/54118 (0%)]	log Loss: -6.629809
#
# Train set: Average log loss: -6.9702
#
#
# Test set: Average loss: -6.7508
#
# Current Learning rate 0.0001
# Train Epoch: 39 [0/54118 (0%)]	log Loss: -6.653501
#
# Train set: Average log loss: -6.9993
#
#
# Test set: Average loss: -6.7718
#
# Current Learning rate 0.0001
# Train Epoch: 40 [0/54118 (0%)]	log Loss: -6.677870
#
# Train set: Average log loss: -7.0288
#
#
# Test set: Average loss: -6.7986
#
# Current Learning rate 0.0001
# Train Epoch: 41 [0/54118 (0%)]	log Loss: -6.707200
#
# Train set: Average log loss: -7.0582
#
#
# Test set: Average loss: -6.8317
#
# Current Learning rate 0.0001
# Train Epoch: 42 [0/54118 (0%)]	log Loss: -6.741592
#
# Train set: Average log loss: -7.0894
#
#
# Test set: Average loss: -6.8755
#
# Current Learning rate 0.0001
# Train Epoch: 43 [0/54118 (0%)]	log Loss: -6.784572
#
# Train set: Average log loss: -7.1219
#
#
# Test set: Average loss: -6.9329
#
# Current Learning rate 0.0001
# Train Epoch: 44 [0/54118 (0%)]	log Loss: -6.841684
#
# Train set: Average log loss: -7.1573
#
#
# Test set: Average loss: -7.0080
#
# Current Learning rate 0.0001
# Train Epoch: 45 [0/54118 (0%)]	log Loss: -6.915426
#
# Train set: Average log loss: -7.1948
#
#
# Test set: Average loss: -7.0853
#
# Current Learning rate 0.0001
# Train Epoch: 46 [0/54118 (0%)]	log Loss: -6.991868
#
# Train set: Average log loss: -7.2295
#
#
# Test set: Average loss: -7.1513
#
# Current Learning rate 0.0001
# Train Epoch: 47 [0/54118 (0%)]	log Loss: -7.057392
#
# Train set: Average log loss: -7.2573
#
#
# Test set: Average loss: -7.2134
#
# Current Learning rate 0.0001
# Train Epoch: 48 [0/54118 (0%)]	log Loss: -7.119820
#
# Train set: Average log loss: -7.2831
#
#
# Test set: Average loss: -7.2602
#
# Current Learning rate 0.0001
# Train Epoch: 49 [0/54118 (0%)]	log Loss: -7.167930
#
# Train set: Average log loss: -7.3118
#
#
# Test set: Average loss: -7.2802
#
# Current Learning rate 0.0001
# Train Epoch: 50 [0/54118 (0%)]	log Loss: -7.187987
#
# Train set: Average log loss: -7.3401
#
#
# Test set: Average loss: -7.2855
#
# Current Learning rate 0.0001
# Train Epoch: 51 [0/54118 (0%)]	log Loss: -7.190629
#
# Train set: Average log loss: -7.3649
#
#
# Test set: Average loss: -7.2726
#
# Current Learning rate 0.0001
# Train Epoch: 52 [0/54118 (0%)]	log Loss: -7.176382
#
# Train set: Average log loss: -7.3878
#
#
# Test set: Average loss: -7.2738
#
# Current Learning rate 0.0001
# Train Epoch: 53 [0/54118 (0%)]	log Loss: -7.179522
#
# Train set: Average log loss: -7.4119
#
#
# Test set: Average loss: -7.2966
#
# Current Learning rate 0.0001
# Train Epoch: 54 [0/54118 (0%)]	log Loss: -7.205273
#
# Train set: Average log loss: -7.4381
#
#
# Test set: Average loss: -7.2981
#
# Current Learning rate 0.0001
# Train Epoch: 55 [0/54118 (0%)]	log Loss: -7.207965
#
# Train set: Average log loss: -7.4605
#
#
# Test set: Average loss: -7.3226
#
# Current Learning rate 0.0001
# Train Epoch: 56 [0/54118 (0%)]	log Loss: -7.235804
#
# Train set: Average log loss: -7.4823
#
#
# Test set: Average loss: -7.3651
#
# Current Learning rate 0.0001
# Train Epoch: 57 [0/54118 (0%)]	log Loss: -7.279475
#
# Train set: Average log loss: -7.5044
#
#
# Test set: Average loss: -7.3871
#
# Current Learning rate 0.0001
# Train Epoch: 58 [0/54118 (0%)]	log Loss: -7.307608
#
# Train set: Average log loss: -7.5242
#
#
# Test set: Average loss: -7.4479
#
# Current Learning rate 0.0001
# Train Epoch: 59 [0/54118 (0%)]	log Loss: -7.371961
#
# Train set: Average log loss: -7.5450
#
#
# Test set: Average loss: -7.5052
#
# Current Learning rate 0.0001
# Train Epoch: 60 [0/54118 (0%)]	log Loss: -7.437802
#
# Train set: Average log loss: -7.5630
#
#
# Test set: Average loss: -7.5410
#
# Current Learning rate 0.0001
# Train Epoch: 61 [0/54118 (0%)]	log Loss: -7.480859
#
# Train set: Average log loss: -7.5778
#
#
# Test set: Average loss: -7.5676
#
# Current Learning rate 0.0001
# Train Epoch: 62 [0/54118 (0%)]	log Loss: -7.514479
#
# Train set: Average log loss: -7.5925
#
#
# Test set: Average loss: -7.5891
#
# Current Learning rate 0.0001
# Train Epoch: 63 [0/54118 (0%)]	log Loss: -7.538433
#
# Train set: Average log loss: -7.6101
#
#
# Test set: Average loss: -7.6082
#
# Current Learning rate 0.0001
# Train Epoch: 64 [0/54118 (0%)]	log Loss: -7.565799
#
# Train set: Average log loss: -7.6294
#
#
# Test set: Average loss: -7.6228
#
# Current Learning rate 0.0001
# Train Epoch: 65 [0/54118 (0%)]	log Loss: -7.584843
#
# Train set: Average log loss: -7.6470
#
#
# Test set: Average loss: -7.6372
#
# Current Learning rate 0.0001
# Train Epoch: 66 [0/54118 (0%)]	log Loss: -7.602548
#
# Train set: Average log loss: -7.6612
#
#
# Test set: Average loss: -7.6516
#
# Current Learning rate 0.0001
# Train Epoch: 67 [0/54118 (0%)]	log Loss: -7.620487
#
# Train set: Average log loss: -7.6767
#
#
# Test set: Average loss: -7.6675
#
# Current Learning rate 0.0001
# Train Epoch: 68 [0/54118 (0%)]	log Loss: -7.639335
#
# Train set: Average log loss: -7.6931
#
#
# Test set: Average loss: -7.6810
#
# Current Learning rate 0.0001
# Train Epoch: 69 [0/54118 (0%)]	log Loss: -7.656206
#
# Train set: Average log loss: -7.7113
#
#
# Test set: Average loss: -7.6975
#
# Current Learning rate 0.0001
# Train Epoch: 70 [0/54118 (0%)]	log Loss: -7.676365
#
# Train set: Average log loss: -7.7282
#
#
# Test set: Average loss: -7.7152
#
# Current Learning rate 0.0001
# Train Epoch: 71 [0/54118 (0%)]	log Loss: -7.697532
#
# Train set: Average log loss: -7.7452
#
#
# Test set: Average loss: -7.7339
#
# Current Learning rate 0.0001
# Train Epoch: 72 [0/54118 (0%)]	log Loss: -7.718286
#
# Train set: Average log loss: -7.7617
#
#
# Test set: Average loss: -7.7503
#
# Current Learning rate 0.0001
# Train Epoch: 73 [0/54118 (0%)]	log Loss: -7.736902
#
# Train set: Average log loss: -7.7792
#
#
# Test set: Average loss: -7.7680
#
# Current Learning rate 0.0001
# Train Epoch: 74 [0/54118 (0%)]	log Loss: -7.758264
#
# Train set: Average log loss: -7.7960
#
#
# Test set: Average loss: -7.7895
#
# Current Learning rate 0.0001
# Train Epoch: 75 [0/54118 (0%)]	log Loss: -7.780974
#
# Train set: Average log loss: -7.8104
#
#
# Test set: Average loss: -7.8090
#
# Current Learning rate 0.0001
# Train Epoch: 76 [0/54118 (0%)]	log Loss: -7.802531
#
# Train set: Average log loss: -7.8245
#
#
# Test set: Average loss: -7.8314
#
# Current Learning rate 0.0001
# Train Epoch: 77 [0/54118 (0%)]	log Loss: -7.827684
#
# Train set: Average log loss: -7.8433
#
#
# Test set: Average loss: -7.8511
#
# Current Learning rate 0.0001
# Train Epoch: 78 [0/54118 (0%)]	log Loss: -7.850459
#
# Train set: Average log loss: -7.8580
#
#
# Test set: Average loss: -7.8731
#
# Current Learning rate 0.0001
# Train Epoch: 79 [0/54118 (0%)]	log Loss: -7.874034
#
# Train set: Average log loss: -7.8753
#
#
# Test set: Average loss: -7.8945
#
# Current Learning rate 0.0001
# Train Epoch: 80 [0/54118 (0%)]	log Loss: -7.897010
#
# Train set: Average log loss: -7.8896
#
#
# Test set: Average loss: -7.9164
#
# Current Learning rate 0.0001
# Train Epoch: 81 [0/54118 (0%)]	log Loss: -7.921220
#
# Train set: Average log loss: -7.9049
#
#
# Test set: Average loss: -7.9345
#
# Current Learning rate 0.0001
# Train Epoch: 82 [0/54118 (0%)]	log Loss: -7.941471
#
# Train set: Average log loss: -7.9196
#
#
# Test set: Average loss: -7.9533
#
# Current Learning rate 0.0001
# Train Epoch: 83 [0/54118 (0%)]	log Loss: -7.962220
#
# Train set: Average log loss: -7.9356
#
#
# Test set: Average loss: -7.9690
#
# Current Learning rate 0.0001
# Train Epoch: 84 [0/54118 (0%)]	log Loss: -7.981694
#
# Train set: Average log loss: -7.9530
#
#
# Test set: Average loss: -7.9833
#
# Current Learning rate 0.0001
# Train Epoch: 85 [0/54118 (0%)]	log Loss: -7.998777
#
# Train set: Average log loss: -7.9723
#
#
# Test set: Average loss: -7.9938
#
# Current Learning rate 0.0001
# Train Epoch: 86 [0/54118 (0%)]	log Loss: -8.010616
#
# Train set: Average log loss: -7.9911
#
#
# Test set: Average loss: -8.0017
#
# Current Learning rate 0.0001
# Train Epoch: 87 [0/54118 (0%)]	log Loss: -8.018888
#
# Train set: Average log loss: -8.0082
#
#
# Test set: Average loss: -8.0060
#
# Current Learning rate 0.0001
# Train Epoch: 88 [0/54118 (0%)]	log Loss: -8.025613
#
# Train set: Average log loss: -8.0223
#
#
# Test set: Average loss: -8.0116
#
# Current Learning rate 0.0001
# Train Epoch: 89 [0/54118 (0%)]	log Loss: -8.031510
#
# Train set: Average log loss: -8.0337
#
#
# Test set: Average loss: -8.0093
#
# Current Learning rate 0.0001
# Train Epoch: 90 [0/54118 (0%)]	log Loss: -8.031372
#
# Train set: Average log loss: -8.0471
#
#
# Test set: Average loss: -8.0112
#
# Current Learning rate 0.0001
# Train Epoch: 91 [0/54118 (0%)]	log Loss: -8.031915
#
# Train set: Average log loss: -8.0617
#
#
# Test set: Average loss: -8.0202
#
# Current Learning rate 0.0001
# Train Epoch: 92 [0/54118 (0%)]	log Loss: -8.043358
#
# Train set: Average log loss: -8.0791
#
#
# Test set: Average loss: -8.0426
#
# Current Learning rate 0.0001
# Train Epoch: 93 [0/54118 (0%)]	log Loss: -8.065731
#
# Train set: Average log loss: -8.0982
#
#
# Test set: Average loss: -8.0734
#
# Current Learning rate 0.0001
# Train Epoch: 94 [0/54118 (0%)]	log Loss: -8.098510
#
# Train set: Average log loss: -8.1142
#
#
# Test set: Average loss: -8.0999
#
# Current Learning rate 0.0001
# Train Epoch: 95 [0/54118 (0%)]	log Loss: -8.124382
#
# Train set: Average log loss: -8.1259
#
#
# Test set: Average loss: -8.1244
#
# Current Learning rate 0.0001
# Train Epoch: 96 [0/54118 (0%)]	log Loss: -8.149399
#
# Train set: Average log loss: -8.1308
#
#
# Test set: Average loss: -8.1402
#
# Current Learning rate 0.0001
# Train Epoch: 97 [0/54118 (0%)]	log Loss: -8.166821
#
# Train set: Average log loss: -8.1390
#
#
# Test set: Average loss: -8.1518
#
# Current Learning rate 0.0001
# Train Epoch: 98 [0/54118 (0%)]	log Loss: -8.179879
#
# Train set: Average log loss: -8.1492
#
#
# Test set: Average loss: -8.1641
#
# Current Learning rate 0.0001
# Train Epoch: 99 [0/54118 (0%)]	log Loss: -8.193013
#
# Train set: Average log loss: -8.1605
#
#
# Test set: Average loss: -8.1765
#
# Current Learning rate 0.0001
# Train Epoch: 100 [0/54118 (0%)]	log Loss: -8.208239
#
# Train set: Average log loss: -8.1706
#
#
# Test set: Average loss: -8.1881
#
# Current Learning rate 0.0001
# Train Epoch: 101 [0/54118 (0%)]	log Loss: -8.219755
#
# Train set: Average log loss: -8.1846
#
#
# Test set: Average loss: -8.1995
#
# Current Learning rate 0.0001
# Train Epoch: 102 [0/54118 (0%)]	log Loss: -8.231532
#
# Train set: Average log loss: -8.1952
#
#
# Test set: Average loss: -8.2096
#
# Current Learning rate 0.0001
# Train Epoch: 103 [0/54118 (0%)]	log Loss: -8.244475
#
# Train set: Average log loss: -8.2118
#
#
# Test set: Average loss: -8.2194
#
# Current Learning rate 0.0001
# Train Epoch: 104 [0/54118 (0%)]	log Loss: -8.255622
#
# Train set: Average log loss: -8.2261
#
#
# Test set: Average loss: -8.2293
#
# Current Learning rate 0.0001
# Train Epoch: 105 [0/54118 (0%)]	log Loss: -8.265998
#
# Train set: Average log loss: -8.2349
#
#
# Test set: Average loss: -8.2379
#
# Current Learning rate 0.0001
# Train Epoch: 106 [0/54118 (0%)]	log Loss: -8.274986
#
# Train set: Average log loss: -8.2447
#
#
# Test set: Average loss: -8.2475
#
# Current Learning rate 0.0001
# Train Epoch: 107 [0/54118 (0%)]	log Loss: -8.285236
#
# Train set: Average log loss: -8.2587
#
#
# Test set: Average loss: -8.2580
#
# Current Learning rate 0.0001
# Train Epoch: 108 [0/54118 (0%)]	log Loss: -8.297979
#
# Train set: Average log loss: -8.2651
#
#
# Test set: Average loss: -8.2661
#
# Current Learning rate 0.0001
# Train Epoch: 109 [0/54118 (0%)]	log Loss: -8.304736
#
# Train set: Average log loss: -8.2796
#
#
# Test set: Average loss: -8.2741
#
# Current Learning rate 0.0001
# Train Epoch: 110 [0/54118 (0%)]	log Loss: -8.315120
#
# Train set: Average log loss: -8.2852
#
#
# Test set: Average loss: -8.2827
#
# Current Learning rate 0.0001
# Train Epoch: 111 [0/54118 (0%)]	log Loss: -8.323996
#
# Train set: Average log loss: -8.2976
#
#
# Test set: Average loss: -8.2885
#
# Current Learning rate 0.0001
# Train Epoch: 112 [0/54118 (0%)]	log Loss: -8.329547
#
# Train set: Average log loss: -8.3130
#
#
# Test set: Average loss: -8.2962
#
# Current Learning rate 0.0001
# Train Epoch: 113 [0/54118 (0%)]	log Loss: -8.338027
#
# Train set: Average log loss: -8.3215
#
#
# Test set: Average loss: -8.3051
#
# Current Learning rate 0.0001
# Train Epoch: 114 [0/54118 (0%)]	log Loss: -8.348715
#
# Train set: Average log loss: -8.3352
#
#
# Test set: Average loss: -8.3153
#
# Current Learning rate 0.0001
# Train Epoch: 115 [0/54118 (0%)]	log Loss: -8.360857
#
# Train set: Average log loss: -8.3461
#
#
# Test set: Average loss: -8.3240
#
# Current Learning rate 0.0001
# Train Epoch: 116 [0/54118 (0%)]	log Loss: -8.370878
#
# Train set: Average log loss: -8.3596
#
#
# Test set: Average loss: -8.3374
#
# Current Learning rate 0.0001
# Train Epoch: 117 [0/54118 (0%)]	log Loss: -8.389543
#
# Train set: Average log loss: -8.3716
#
#
# Test set: Average loss: -8.3443
#
# Current Learning rate 0.0001
# Train Epoch: 118 [0/54118 (0%)]	log Loss: -8.396207
#
# Train set: Average log loss: -8.3819
#
#
# Test set: Average loss: -8.3556
#
# Current Learning rate 0.0001
# Train Epoch: 119 [0/54118 (0%)]	log Loss: -8.408512
#
# Train set: Average log loss: -8.3870
#
#
# Test set: Average loss: -8.3659
#
# Current Learning rate 0.0001
# Train Epoch: 120 [0/54118 (0%)]	log Loss: -8.420684
#
# Train set: Average log loss: -8.3979
#
#
# Test set: Average loss: -8.3766
#
# Current Learning rate 0.0001
# Train Epoch: 121 [0/54118 (0%)]	log Loss: -8.434182
#
# Train set: Average log loss: -8.4027
#
#
# Test set: Average loss: -8.3850
#
# Current Learning rate 0.0001
# Train Epoch: 122 [0/54118 (0%)]	log Loss: -8.444128
#
# Train set: Average log loss: -8.4094
#
#
# Test set: Average loss: -8.3919
#
# Current Learning rate 0.0001
# Train Epoch: 123 [0/54118 (0%)]	log Loss: -8.454549
#
# Train set: Average log loss: -8.4126
#
#
# Test set: Average loss: -8.4020
#
# Current Learning rate 0.0001
# Train Epoch: 124 [0/54118 (0%)]	log Loss: -8.465837
#
# Train set: Average log loss: -8.4075
#
#
# Test set: Average loss: -8.4128
#
# Current Learning rate 0.0001
# Train Epoch: 125 [0/54118 (0%)]	log Loss: -8.476184
#
# Train set: Average log loss: -8.4210
#
#
# Test set: Average loss: -8.4107
#
# Current Learning rate 0.0001
# Train Epoch: 126 [0/54118 (0%)]	log Loss: -8.479949
#
# Train set: Average log loss: -8.4263
#
#
# Test set: Average loss: -8.3754
#
# Current Learning rate 0.0001
# Train Epoch: 127 [0/54118 (0%)]	log Loss: -8.445567
#
# Train set: Average log loss: -8.4372
#
#
# Test set: Average loss: -8.2875
#
# Current Learning rate 0.0001
# Train Epoch: 128 [0/54118 (0%)]	log Loss: -8.354617
#
# Train set: Average log loss: -8.4539
#
#
# Test set: Average loss: -8.2550
#
# Current Learning rate 0.0001
# Train Epoch: 129 [0/54118 (0%)]	log Loss: -8.320545
#
# Train set: Average log loss: -8.4712
#
#
# Test set: Average loss: -8.2643
#
# Current Learning rate 0.0001
# Train Epoch: 130 [0/54118 (0%)]	log Loss: -8.332118
#
# Train set: Average log loss: -8.4879
#
#
# Test set: Average loss: -8.2922
#
# Current Learning rate 0.0001
# Train Epoch: 131 [0/54118 (0%)]	log Loss: -8.362131
#
# Train set: Average log loss: -8.5013
#
#
# Test set: Average loss: -8.3245
#
# Current Learning rate 0.0001
# Train Epoch: 132 [0/54118 (0%)]	log Loss: -8.398536
#
# Train set: Average log loss: -8.5121
#
#
# Test set: Average loss: -8.3563
#
# Current Learning rate 0.0001
# Train Epoch: 133 [0/54118 (0%)]	log Loss: -8.434303
#
# Train set: Average log loss: -8.5213
#
#
# Test set: Average loss: -8.3923
#
# Current Learning rate 0.0001
# Train Epoch: 134 [0/54118 (0%)]	log Loss: -8.476492
#
# Train set: Average log loss: -8.5294
#
#
# Test set: Average loss: -8.4181
#
# Current Learning rate 0.0001
# Train Epoch: 135 [0/54118 (0%)]	log Loss: -8.505066
#
# Train set: Average log loss: -8.5351
#
#
# Test set: Average loss: -8.4416
#
# Current Learning rate 0.0001
# Train Epoch: 136 [0/54118 (0%)]	log Loss: -8.533756
#
# Train set: Average log loss: -8.5428
#
#
# Test set: Average loss: -8.4586
#
# Current Learning rate 0.0001
# Train Epoch: 137 [0/54118 (0%)]	log Loss: -8.550784
#
# Train set: Average log loss: -8.5515
#
#
# Test set: Average loss: -8.4714
#
# Current Learning rate 0.0001
# Train Epoch: 138 [0/54118 (0%)]	log Loss: -8.565794
#
# Train set: Average log loss: -8.5582
#
#
# Test set: Average loss: -8.4876
#
# Current Learning rate 0.0001
# Train Epoch: 139 [0/54118 (0%)]	log Loss: -8.587100
#
# Train set: Average log loss: -8.5687
#
#
# Test set: Average loss: -8.4994
#
# Current Learning rate 0.0001
# Train Epoch: 140 [0/54118 (0%)]	log Loss: -8.603074
#
# Train set: Average log loss: -8.5736
#
#
# Test set: Average loss: -8.5099
#
# Current Learning rate 0.0001
# Train Epoch: 141 [0/54118 (0%)]	log Loss: -8.616278
#
# Train set: Average log loss: -8.5799
#
#
# Test set: Average loss: -8.5253
#
# Current Learning rate 0.0001
# Train Epoch: 142 [0/54118 (0%)]	log Loss: -8.633007
#
# Train set: Average log loss: -8.5860
#
#
# Test set: Average loss: -8.5330
#
# Current Learning rate 0.0001
# Train Epoch: 143 [0/54118 (0%)]	log Loss: -8.642932
#
# Train set: Average log loss: -8.5949
#
#
# Test set: Average loss: -8.5405
#
# Current Learning rate 0.0001
# Train Epoch: 144 [0/54118 (0%)]	log Loss: -8.654430
#
# Train set: Average log loss: -8.6032
#
#
# Test set: Average loss: -8.5480
#
# Current Learning rate 0.0001
# Train Epoch: 145 [0/54118 (0%)]	log Loss: -8.661515
#
# Train set: Average log loss: -8.6079
#
#
# Test set: Average loss: -8.5496
#
# Current Learning rate 0.0001
# Train Epoch: 146 [0/54118 (0%)]	log Loss: -8.665974
#
# Train set: Average log loss: -8.6123
#
#
# Test set: Average loss: -8.5481
#
# Current Learning rate 0.0001
# Train Epoch: 147 [0/54118 (0%)]	log Loss: -8.663860
#
# Train set: Average log loss: -8.6196
#
#
# Test set: Average loss: -8.5370
#
# Current Learning rate 0.0001
# Train Epoch: 148 [0/54118 (0%)]	log Loss: -8.655264
#
# Train set: Average log loss: -8.6231
#
#
# Test set: Average loss: -8.5171
#
# Current Learning rate 0.0001
# Train Epoch: 149 [0/54118 (0%)]	log Loss: -8.630779
#
# Train set: Average log loss: -8.6250
#
#
# Test set: Average loss: -8.4822
#
# Current Learning rate 0.0001
# Train Epoch: 150 [0/54118 (0%)]	log Loss: -8.590126
#
# Train set: Average log loss: -8.6328
#
#
# Test set: Average loss: -8.4428
#
# Current Learning rate 0.0001
# Train Epoch: 151 [0/54118 (0%)]	log Loss: -8.541566
#
# Train set: Average log loss: -8.6315
#
#
# Test set: Average loss: -8.4350
#
# Current Learning rate 0.0001
# Train Epoch: 152 [0/54118 (0%)]	log Loss: -8.533700
#
# Train set: Average log loss: -8.6416
#
#
# Test set: Average loss: -8.4312
#
# Current Learning rate 0.0001
# Train Epoch: 153 [0/54118 (0%)]	log Loss: -8.528177
#
# Train set: Average log loss: -8.6416
#
#
# Test set: Average loss: -8.4326
#
# Current Learning rate 0.0001
# Train Epoch: 154 [0/54118 (0%)]	log Loss: -8.532264
#
# Train set: Average log loss: -8.6442
#
#
# Test set: Average loss: -8.4134
#
# Current Learning rate 0.0001
# Train Epoch: 155 [0/54118 (0%)]	log Loss: -8.511034
#
# Train set: Average log loss: -8.6166
#
#
# Test set: Average loss: -8.2990
#
# Current Learning rate 0.0001
# Train Epoch: 156 [0/54118 (0%)]	log Loss: -8.374834
#
# Train set: Average log loss: -8.5259
#
#
# Test set: Average loss: -7.9277
#
# Current Learning rate 0.0001
# Train Epoch: 157 [0/54118 (0%)]	log Loss: -7.951553
#
# Train set: Average log loss: -8.5618
#
#
# Test set: Average loss: -8.1641
#
# Current Learning rate 0.0001
# Train Epoch: 158 [0/54118 (0%)]	log Loss: -8.190463
#
# Train set: Average log loss: -8.6522
#
#
# Test set: Average loss: -8.3315
#
# Current Learning rate 0.0001
# Train Epoch: 159 [0/54118 (0%)]	log Loss: -8.390025
#
# Train set: Average log loss: -8.6716
#
#
# Test set: Average loss: -8.4084
#
# Current Learning rate 0.0001
# Train Epoch: 160 [0/54118 (0%)]	log Loss: -8.475129
#
# Train set: Average log loss: -8.6691
#
#
# Test set: Average loss: -8.4917
#
# Current Learning rate 0.0001
# Train Epoch: 161 [0/54118 (0%)]	log Loss: -8.572251
#
# Train set: Average log loss: -8.6693
#
#
# Test set: Average loss: -8.6197
#
# Current Learning rate 0.0001
# Train Epoch: 162 [0/54118 (0%)]	log Loss: -8.717131
#
# Train set: Average log loss: -8.6484
#
#
# Test set: Average loss: -8.7277
#
# Current Learning rate 0.0001
# Train Epoch: 163 [0/54118 (0%)]	log Loss: -8.857801
#
# Train set: Average log loss: -8.6364
#
#
# Test set: Average loss: -8.6455
#
# Current Learning rate 0.0001
# Train Epoch: 164 [0/54118 (0%)]	log Loss: -8.777586
#
# Train set: Average log loss: -8.6673
#
#
# Test set: Average loss: -8.6002
#
# Current Learning rate 0.0001
# Train Epoch: 165 [0/54118 (0%)]	log Loss: -8.733715
#
# Train set: Average log loss: -8.7280
#
#
# Test set: Average loss: -8.6470
#
# Current Learning rate 0.0001
# Train Epoch: 166 [0/54118 (0%)]	log Loss: -8.787108
#
# Train set: Average log loss: -8.7362
#
#
# Test set: Average loss: -8.6799
#
# Current Learning rate 0.0001
# Train Epoch: 167 [0/54118 (0%)]	log Loss: -8.819642
#
# Train set: Average log loss: -8.7409
#
#
# Test set: Average loss: -8.7086
#
# Current Learning rate 0.0001
# Train Epoch: 168 [0/54118 (0%)]	log Loss: -8.852606
#
# Train set: Average log loss: -8.7447
#
#
# Test set: Average loss: -8.7175
#
# Current Learning rate 0.0001
# Train Epoch: 169 [0/54118 (0%)]	log Loss: -8.870309
#
# Train set: Average log loss: -8.7438
#
#
# Test set: Average loss: -8.7356
#
# Current Learning rate 0.0001
# Train Epoch: 170 [0/54118 (0%)]	log Loss: -8.888506
#
# Train set: Average log loss: -8.7513
#
#
# Test set: Average loss: -8.7482
#
# Current Learning rate 0.0001
# Train Epoch: 171 [0/54118 (0%)]	log Loss: -8.903537
#
# Train set: Average log loss: -8.7569
#
#
# Test set: Average loss: -8.7687
#
# Current Learning rate 0.0001
# Train Epoch: 172 [0/54118 (0%)]	log Loss: -8.923659
#
# Train set: Average log loss: -8.7634
#
#
# Test set: Average loss: -8.7830
#
# Current Learning rate 0.0001
# Train Epoch: 173 [0/54118 (0%)]	log Loss: -8.936576
#
# Train set: Average log loss: -8.7725
#
#
# Test set: Average loss: -8.8003
#
# Current Learning rate 0.0001
# Train Epoch: 174 [0/54118 (0%)]	log Loss: -8.956347
#
# Train set: Average log loss: -8.7808
#
#
# Test set: Average loss: -8.8184
#
# Current Learning rate 0.0001
# Train Epoch: 175 [0/54118 (0%)]	log Loss: -8.968540
#
# Train set: Average log loss: -8.7858
#
#
# Test set: Average loss: -8.8324
#
# Current Learning rate 0.0001
# Train Epoch: 176 [0/54118 (0%)]	log Loss: -8.981815
#
# Train set: Average log loss: -8.7948
#
#
# Test set: Average loss: -8.8444
#
# Current Learning rate 0.0001
# Train Epoch: 177 [0/54118 (0%)]	log Loss: -8.990174
#
# Train set: Average log loss: -8.8029
#
#
# Test set: Average loss: -8.8510
#
# Current Learning rate 0.0001
# Train Epoch: 178 [0/54118 (0%)]	log Loss: -8.993224
#
# Train set: Average log loss: -8.8202
#
#
# Test set: Average loss: -8.8455
#
# Current Learning rate 0.0001
# Train Epoch: 179 [0/54118 (0%)]	log Loss: -8.982493
#
# Train set: Average log loss: -8.8410
#
#
# Test set: Average loss: -8.8077
#
# Current Learning rate 0.0001
# Train Epoch: 180 [0/54118 (0%)]	log Loss: -8.926429
#
# Train set: Average log loss: -8.8737
#
#
# Test set: Average loss: -8.7330
#
# Current Learning rate 0.0001
# Train Epoch: 181 [0/54118 (0%)]	log Loss: -8.836072
#
# Train set: Average log loss: -8.8945
#
#
# Test set: Average loss: -8.6363
#
# Current Learning rate 0.0001
# Train Epoch: 182 [0/54118 (0%)]	log Loss: -8.727628
#
# Train set: Average log loss: -8.8918
#
#
# Test set: Average loss: -8.5918
#
# Current Learning rate 0.0001
# Train Epoch: 183 [0/54118 (0%)]	log Loss: -8.691499
#
# Train set: Average log loss: -8.8789
#
#
# Test set: Average loss: -8.6034
#
# Current Learning rate 0.0001
# Train Epoch: 184 [0/54118 (0%)]	log Loss: -8.712266
#
# Train set: Average log loss: -8.8768
#
#
# Test set: Average loss: -8.6533
#
# Current Learning rate 0.0001
# Train Epoch: 185 [0/54118 (0%)]	log Loss: -8.775461
#
# Train set: Average log loss: -8.8913
#
#
# Test set: Average loss: -8.7279
#
# Current Learning rate 0.0001
# Train Epoch: 186 [0/54118 (0%)]	log Loss: -8.875081
#
# Train set: Average log loss: -8.9189
#
#
# Test set: Average loss: -8.8089
#
# Current Learning rate 0.0001
# Train Epoch: 187 [0/54118 (0%)]	log Loss: -8.975984
#
# Train set: Average log loss: -8.9475
#
#
# Test set: Average loss: -8.8807
#
# Current Learning rate 0.0001
# Train Epoch: 188 [0/54118 (0%)]	log Loss: -9.076091
#
# Train set: Average log loss: -8.9581
#
#
# Test set: Average loss: -8.8876
#
# Current Learning rate 0.0001
# Train Epoch: 189 [0/54118 (0%)]	log Loss: -9.091797
#
# Train set: Average log loss: -8.9971
#
#
# Test set: Average loss: -8.8729
#
# Current Learning rate 0.0001
# Train Epoch: 190 [0/54118 (0%)]	log Loss: -9.070080
#
# Train set: Average log loss: -9.0241
#
#
# Test set: Average loss: -8.9065
#
# Current Learning rate 0.0001
# Train Epoch: 191 [0/54118 (0%)]	log Loss: -9.111039
#
# Train set: Average log loss: -8.9740
#
#
# Test set: Average loss: -8.9385
#
# Current Learning rate 0.0001
# Train Epoch: 192 [0/54118 (0%)]	log Loss: -9.134869
#
# Train set: Average log loss: -8.8974
#
#
# Test set: Average loss: -8.9460
#
# Current Learning rate 0.0001
# Train Epoch: 193 [0/54118 (0%)]	log Loss: -9.120853
#
# Train set: Average log loss: -8.9106
#
#
# Test set: Average loss: -8.9601
#
# Current Learning rate 0.0001
# Train Epoch: 194 [0/54118 (0%)]	log Loss: -9.134493
#
# Train set: Average log loss: -8.9206
#
#
# Test set: Average loss: -8.9585
#
# Current Learning rate 0.0001
# Train Epoch: 195 [0/54118 (0%)]	log Loss: -9.141790
#
# Train set: Average log loss: -8.9017
#
#
# Test set: Average loss: -8.9745
#
# Current Learning rate 0.0001
# Train Epoch: 196 [0/54118 (0%)]	log Loss: -9.153840
#
# Train set: Average log loss: -8.9242
#
#
# Test set: Average loss: -8.9792
#
# Current Learning rate 0.0001
# Train Epoch: 197 [0/54118 (0%)]	log Loss: -9.164941
#
# Train set: Average log loss: -8.9243
#
#
# Test set: Average loss: -8.9861
#
# Current Learning rate 0.0001
# Train Epoch: 198 [0/54118 (0%)]	log Loss: -9.176190
#
# Train set: Average log loss: -8.9453
#
#
# Test set: Average loss: -8.9898
#
# Current Learning rate 0.0001
# Train Epoch: 199 [0/54118 (0%)]	log Loss: -9.179192
#
# Train set: Average log loss: -8.9472
#
#
# Test set: Average loss: -8.9857
#
# Current Learning rate 0.0001
# Train Epoch: 200 [0/54118 (0%)]	log Loss: -9.160498
#
# Train set: Average log loss: -8.8792
#
#
# Test set: Average loss: -8.9532
#
# Current Learning rate 0.0001
# Train Epoch: 201 [0/54118 (0%)]	log Loss: -9.136066
#
# Train set: Average log loss: -8.9743
#
#
# Test set: Average loss: -8.9890
#
# Current Learning rate 0.0001
# Train Epoch: 202 [0/54118 (0%)]	log Loss: -9.172910
#
# Train set: Average log loss: -8.8641
#
#
# Test set: Average loss: -8.9332
#
# Current Learning rate 0.0001
# Train Epoch: 203 [0/54118 (0%)]	log Loss: -9.109914
#
# Train set: Average log loss: -8.8874
#
#
# Test set: Average loss: -9.0035
#
# Current Learning rate 0.0001
# Train Epoch: 204 [0/54118 (0%)]	log Loss: -9.208246
#
# Train set: Average log loss: -8.9158
#
#
# Test set: Average loss: -8.8666
#
# Current Learning rate 0.0001
# Train Epoch: 205 [0/54118 (0%)]	log Loss: -9.060405
#
# Train set: Average log loss: -8.9539
#
#
# Test set: Average loss: -8.9285
#
# Current Learning rate 0.0001
# Train Epoch: 206 [0/54118 (0%)]	log Loss: -9.127306
#
# Train set: Average log loss: -8.9947
#
#
# Test set: Average loss: -8.9912
#
# Current Learning rate 0.0001
# Train Epoch: 207 [0/54118 (0%)]	log Loss: -9.197167
#
# Train set: Average log loss: -8.9321
#
#
# Test set: Average loss: -8.9592
#
# Current Learning rate 0.0001
# Train Epoch: 208 [0/54118 (0%)]	log Loss: -9.148472
#
# Train set: Average log loss: -8.9552
#
#
# Test set: Average loss: -8.9784
#
# Current Learning rate 0.0001
# Train Epoch: 209 [0/54118 (0%)]	log Loss: -9.174193
#
# Train set: Average log loss: -8.9285
#
#
# Test set: Average loss: -8.9580
#
# Current Learning rate 0.0001
# Train Epoch: 210 [0/54118 (0%)]	log Loss: -9.147430
#
# Train set: Average log loss: -8.9080
#
#
# Test set: Average loss: -8.9763
#
# Current Learning rate 0.0001
# Train Epoch: 211 [0/54118 (0%)]	log Loss: -9.178446
#
# Train set: Average log loss: -8.8488
#
#
# Test set: Average loss: -8.5301
#
# Current Learning rate 0.0001
# Train Epoch: 212 [0/54118 (0%)]	log Loss: -8.649204
#
# Train set: Average log loss: -8.8501
#
#
# Test set: Average loss: -8.6252
#
# Current Learning rate 0.0001
# Train Epoch: 213 [0/54118 (0%)]	log Loss: -8.746240
#
# Train set: Average log loss: -8.9865
#
#
# Test set: Average loss: -8.5695
#
# Current Learning rate 0.0001
# Train Epoch: 214 [0/54118 (0%)]	log Loss: -8.689305
#
# Train set: Average log loss: -8.9415
#
#
# Test set: Average loss: -8.5173
#
# Current Learning rate 0.0001
# Train Epoch: 215 [0/54118 (0%)]	log Loss: -8.631458
#
# Train set: Average log loss: -8.9164
#
#
# Test set: Average loss: -8.4702
#
# Current Learning rate 0.0001
# Train Epoch: 216 [0/54118 (0%)]	log Loss: -8.579404
#
# Train set: Average log loss: -8.9261
#
#
# Test set: Average loss: -8.4470
#
# Current Learning rate 0.0001
# Train Epoch: 217 [0/54118 (0%)]	log Loss: -8.556456
#
# Train set: Average log loss: -8.9318
#
#
# Test set: Average loss: -8.3963
#
# Current Learning rate 0.0001
# Train Epoch: 218 [0/54118 (0%)]	log Loss: -8.503776
#
# Train set: Average log loss: -8.9377
#
#
# Test set: Average loss: -8.4447
#
# Current Learning rate 0.0001
# Train Epoch: 219 [0/54118 (0%)]	log Loss: -8.569643
#
# Train set: Average log loss: -8.9655
#
#
# Test set: Average loss: -8.4196
#
# Current Learning rate 0.0001
# Train Epoch: 220 [0/54118 (0%)]	log Loss: -8.543638
#
# Train set: Average log loss: -8.9607
#
#
# Test set: Average loss: -8.4607
#
# Current Learning rate 0.0001
# Train Epoch: 221 [0/54118 (0%)]	log Loss: -8.598762
#
# Train set: Average log loss: -8.9821
#
#
# Test set: Average loss: -8.4698
#
# Current Learning rate 0.0001
# Train Epoch: 222 [0/54118 (0%)]	log Loss: -8.608233
#
# Train set: Average log loss: -8.9884
#
#
# Test set: Average loss: -8.4549
#
# Current Learning rate 0.0001
# Train Epoch: 223 [0/54118 (0%)]	log Loss: -8.595553
#
# Train set: Average log loss: -8.9841
#
#
# Test set: Average loss: -8.4634
#
# Current Learning rate 0.0001
# Train Epoch: 224 [0/54118 (0%)]	log Loss: -8.607477
#
# Train set: Average log loss: -8.9955
#
#
# Test set: Average loss: -8.4626
#
# Current Learning rate 0.0001
# Train Epoch: 225 [0/54118 (0%)]	log Loss: -8.607573
#
# Train set: Average log loss: -9.0009
#
#
# Test set: Average loss: -8.4841
#
# Current Learning rate 0.0001
# Train Epoch: 226 [0/54118 (0%)]	log Loss: -8.634662
#
# Train set: Average log loss: -9.0020
#
#
# Test set: Average loss: -8.4726
#
# Current Learning rate 0.0001
# Train Epoch: 227 [0/54118 (0%)]	log Loss: -8.622084
#
# Train set: Average log loss: -9.0084
#
#
# Test set: Average loss: -8.4806
#
# Current Learning rate 0.0001
# Train Epoch: 228 [0/54118 (0%)]	log Loss: -8.634161
#
# Train set: Average log loss: -9.0117
#
#
# Test set: Average loss: -8.4896
#
# Current Learning rate 0.0001
# Train Epoch: 229 [0/54118 (0%)]	log Loss: -8.648267
#
# Train set: Average log loss: -9.0184
#
#
# Test set: Average loss: -8.5000
#
# Current Learning rate 0.0001
# Train Epoch: 230 [0/54118 (0%)]	log Loss: -8.662265
#
# Train set: Average log loss: -9.0344
#
#
# Test set: Average loss: -8.5200
#
# Current Learning rate 0.0001
# Train Epoch: 231 [0/54118 (0%)]	log Loss: -8.684905
#
# Train set: Average log loss: -9.0326
#
#
# Test set: Average loss: -8.5399
#
# Current Learning rate 0.0001
# Train Epoch: 232 [0/54118 (0%)]	log Loss: -8.708662
#
# Train set: Average log loss: -9.0333
#
#
# Test set: Average loss: -8.5611
#
# Current Learning rate 0.0001
# Train Epoch: 233 [0/54118 (0%)]	log Loss: -8.737792
#
# Train set: Average log loss: -9.0392
#
#
# Test set: Average loss: -8.5771
#
# Current Learning rate 0.0001
# Train Epoch: 234 [0/54118 (0%)]	log Loss: -8.755988
#
# Train set: Average log loss: -9.0565
#
#
# Test set: Average loss: -8.6344
#
# Current Learning rate 0.0001
# Train Epoch: 235 [0/54118 (0%)]	log Loss: -8.825454
#
# Train set: Average log loss: -9.0606
#
#
# Test set: Average loss: -8.6719
#
# Current Learning rate 0.0001
# Train Epoch: 236 [0/54118 (0%)]	log Loss: -8.866913
#
# Train set: Average log loss: -9.0579
#
#
# Test set: Average loss: -8.6849
#
# Current Learning rate 0.0001
# Train Epoch: 237 [0/54118 (0%)]	log Loss: -8.880561
#
# Train set: Average log loss: -9.0558
#
#
# Test set: Average loss: -8.6786
#
# Current Learning rate 0.0001
# Train Epoch: 238 [0/54118 (0%)]	log Loss: -8.871260
#
# Train set: Average log loss: -9.0931
#
#
# Test set: Average loss: -8.8049
#
# Current Learning rate 0.0001
# Train Epoch: 239 [0/54118 (0%)]	log Loss: -9.027018
#
# Train set: Average log loss: -8.9683
#
#
# Test set: Average loss: -8.5035
#
# Current Learning rate 0.0001
# Train Epoch: 240 [0/54118 (0%)]	log Loss: -8.656416
#
# Train set: Average log loss: -9.1079
#
#
# Test set: Average loss: -8.7634
#
# Current Learning rate 0.0001
# Train Epoch: 241 [0/54118 (0%)]	log Loss: -8.980889
#
# Train set: Average log loss: -9.0662
#
#
# Test set: Average loss: -8.6992
#
# Current Learning rate 0.0001
# Train Epoch: 242 [0/54118 (0%)]	log Loss: -8.895187
#
# Train set: Average log loss: -9.1534
#
#
# Test set: Average loss: -8.9380
#
# Current Learning rate 0.0001
# Train Epoch: 243 [0/54118 (0%)]	log Loss: -9.191974
#
# Train set: Average log loss: -8.7748
#
#
# Test set: Average loss: -8.1350
#
# Current Learning rate 0.0001
# Train Epoch: 244 [0/54118 (0%)]	log Loss: -8.219286
#
# Train set: Average log loss: -9.0881
#
#
# Test set: Average loss: -8.7715
#
# Current Learning rate 0.0001
# Train Epoch: 245 [0/54118 (0%)]	log Loss: -8.994726
#
# Train set: Average log loss: -9.1897
#
#
# Test set: Average loss: -8.7522
#
# Current Learning rate 0.0001
# Train Epoch: 246 [0/54118 (0%)]	log Loss: -8.974921
#
# Train set: Average log loss: -9.2083
#
#
# Test set: Average loss: -8.8744
#
# Current Learning rate 0.0001
# Train Epoch: 247 [0/54118 (0%)]	log Loss: -9.118380
#
# Train set: Average log loss: -9.0924
#
#
# Test set: Average loss: -8.8047
#
# Current Learning rate 0.0001
# Train Epoch: 248 [0/54118 (0%)]	log Loss: -9.020678
#
# Train set: Average log loss: -9.1634
#
#
# Test set: Average loss: -9.0047
#
# Current Learning rate 0.0001
# Train Epoch: 249 [0/54118 (0%)]	log Loss: -9.267827
#
# Train set: Average log loss: -8.7464
#
#
# Test set: Average loss: -8.2353
#
# Current Learning rate 0.0001
# Train Epoch: 250 [0/54118 (0%)]	log Loss: -8.326495
#
# Train set: Average log loss: -9.0500
#
#
# Test set: Average loss: -8.8935
#
# Current Learning rate 0.0001
# Train Epoch: 251 [0/54118 (0%)]	log Loss: -9.149037
#
# Train set: Average log loss: -9.0539
#
#
# Test set: Average loss: -8.8637
#
# Current Learning rate 0.0001
# Train Epoch: 252 [0/54118 (0%)]	log Loss: -9.118648
#
# Train set: Average log loss: -9.0130
#
#
# Test set: Average loss: -8.9638
#
# Current Learning rate 0.0001
# Train Epoch: 253 [0/54118 (0%)]	log Loss: -9.243127
#
# Train set: Average log loss: -8.9146
#
#
# Test set: Average loss: -8.7442
#
# Current Learning rate 0.0001
# Train Epoch: 254 [0/54118 (0%)]	log Loss: -8.907451
#
# Train set: Average log loss: -8.5990
#
#
# Test set: Average loss: -8.2956
#
# Current Learning rate 0.0001
# Train Epoch: 255 [0/54118 (0%)]	log Loss: -8.337960
#
# Train set: Average log loss: -8.9174
#
#
# Test set: Average loss: -8.8279
#
# Current Learning rate 0.0001
# Train Epoch: 256 [0/54118 (0%)]	log Loss: -8.930302
#
# Train set: Average log loss: -8.8819
#
#
# Test set: Average loss: -9.1006
#
# Current Learning rate 0.0001
# Train Epoch: 257 [0/54118 (0%)]	log Loss: -9.291490
#
# Train set: Average log loss: -8.8564
#
#
# Test set: Average loss: -8.9470
#
# Current Learning rate 0.0001
# Train Epoch: 258 [0/54118 (0%)]	log Loss: -9.114379
#
# Train set: Average log loss: -9.0096
#
#
# Test set: Average loss: -9.0675
#
# Current Learning rate 0.0001
# Train Epoch: 259 [0/54118 (0%)]	log Loss: -9.260165
#
# Train set: Average log loss: -9.0624
#
#
# Test set: Average loss: -9.0680
#
# Current Learning rate 0.0001
# Train Epoch: 260 [0/54118 (0%)]	log Loss: -9.249217
#
# Train set: Average log loss: -9.0539
#
#
# Test set: Average loss: -9.0643
#
# Current Learning rate 0.0001
# Train Epoch: 261 [0/54118 (0%)]	log Loss: -9.240710
#
# Train set: Average log loss: -9.0511
#
#
# Test set: Average loss: -9.0611
#
# Current Learning rate 0.0001
# Train Epoch: 262 [0/54118 (0%)]	log Loss: -9.237147
#
# Train set: Average log loss: -9.0490
#
#
# Test set: Average loss: -9.0683
#
# Current Learning rate 0.0001
# Train Epoch: 263 [0/54118 (0%)]	log Loss: -9.239773
#
# Train set: Average log loss: -9.0557
#
#
# Test set: Average loss: -9.0709
#
# Current Learning rate 0.0001
# Train Epoch: 264 [0/54118 (0%)]	log Loss: -9.242513
#
# Train set: Average log loss: -9.0543
#
#
# Test set: Average loss: -9.0723
#
# Current Learning rate 0.0001
# Train Epoch: 265 [0/54118 (0%)]	log Loss: -9.242069
#
# Train set: Average log loss: -9.0604
#
#
# Test set: Average loss: -9.0759
#
# Current Learning rate 0.0001
# Train Epoch: 266 [0/54118 (0%)]	log Loss: -9.248930
#
# Train set: Average log loss: -9.0614
#
#
# Test set: Average loss: -9.0847
#
# Current Learning rate 0.0001
# Train Epoch: 267 [0/54118 (0%)]	log Loss: -9.256613
#
# Train set: Average log loss: -9.0665
#
#
# Test set: Average loss: -9.0829
#
# Current Learning rate 0.0001
# Train Epoch: 268 [0/54118 (0%)]	log Loss: -9.254094
#
# Train set: Average log loss: -9.0694
#
#
# Test set: Average loss: -9.0881
#
# Current Learning rate 0.0001
# Train Epoch: 269 [0/54118 (0%)]	log Loss: -9.257299
#
# Train set: Average log loss: -9.0698
#
#
# Test set: Average loss: -9.0819
#
# Current Learning rate 0.0001
# Train Epoch: 270 [0/54118 (0%)]	log Loss: -9.254294
#
# Train set: Average log loss: -9.0702
#
#
# Test set: Average loss: -9.0863
#
# Current Learning rate 0.0001
# Train Epoch: 271 [0/54118 (0%)]	log Loss: -9.255083
#
# Train set: Average log loss: -9.0755
#
#
# Test set: Average loss: -9.0872
#
# Current Learning rate 0.0001
# Train Epoch: 272 [0/54118 (0%)]	log Loss: -9.253672
#
# Train set: Average log loss: -9.0801
#
#
# Test set: Average loss: -9.0945
#
# Current Learning rate 0.0001
# Train Epoch: 273 [0/54118 (0%)]	log Loss: -9.259217
#
# Train set: Average log loss: -9.0830
#
#
# Test set: Average loss: -9.0956
#
# Current Learning rate 0.0001
# Train Epoch: 274 [0/54118 (0%)]	log Loss: -9.259815
#
# Train set: Average log loss: -9.0845
#
#
# Test set: Average loss: -9.1021
#
# Current Learning rate 0.0001
# Train Epoch: 275 [0/54118 (0%)]	log Loss: -9.266197
#
# Train set: Average log loss: -9.0843
#
#
# Test set: Average loss: -9.1000
#
# Current Learning rate 0.0001
# Train Epoch: 276 [0/54118 (0%)]	log Loss: -9.264075
#
# Train set: Average log loss: -9.0862
#
#
# Test set: Average loss: -9.0997
#
# Current Learning rate 0.0001
# Train Epoch: 277 [0/54118 (0%)]	log Loss: -9.262990
#
# Train set: Average log loss: -9.0876
#
#
# Test set: Average loss: -9.0973
#
# Current Learning rate 0.0001
# Train Epoch: 278 [0/54118 (0%)]	log Loss: -9.262130
#
# Train set: Average log loss: -9.0913
#
#
# Test set: Average loss: -9.1017
#
# Current Learning rate 0.0001
# Train Epoch: 279 [0/54118 (0%)]	log Loss: -9.262411
#
# Train set: Average log loss: -9.0968
#
#
# Test set: Average loss: -9.1099
#
# Current Learning rate 0.0001
# Train Epoch: 280 [0/54118 (0%)]	log Loss: -9.270367
#
# Train set: Average log loss: -9.0980
#
#
# Test set: Average loss: -9.1065
#
# Current Learning rate 0.0001
# Train Epoch: 281 [0/54118 (0%)]	log Loss: -9.264009
#
# Train set: Average log loss: -9.1037
#
#
# Test set: Average loss: -9.1120
#
# Current Learning rate 0.0001
# Train Epoch: 282 [0/54118 (0%)]	log Loss: -9.273742
#
# Train set: Average log loss: -9.1053
#
#
# Test set: Average loss: -9.1172
#
# Current Learning rate 0.0001
# Train Epoch: 283 [0/54118 (0%)]	log Loss: -9.271980
#
# Train set: Average log loss: -9.1084
#
#
# Test set: Average loss: -9.1097
#
# Current Learning rate 0.0001
# Train Epoch: 284 [0/54118 (0%)]	log Loss: -9.266513
#
# Train set: Average log loss: -9.1083
#
#
# Test set: Average loss: -9.1184
#
# Current Learning rate 0.0001
# Train Epoch: 285 [0/54118 (0%)]	log Loss: -9.274844
#
# Train set: Average log loss: -9.1072
#
#
# Test set: Average loss: -9.1129
#
# Current Learning rate 0.0001
# Train Epoch: 286 [0/54118 (0%)]	log Loss: -9.263444
#
# Train set: Average log loss: -9.1117
#
#
# Test set: Average loss: -9.1212
#
# Current Learning rate 0.0001
# Train Epoch: 287 [0/54118 (0%)]	log Loss: -9.269580
#
# Train set: Average log loss: -9.1170
#
#
# Test set: Average loss: -9.1236
#
# Current Learning rate 0.0001
# Train Epoch: 288 [0/54118 (0%)]	log Loss: -9.273978
#
# Train set: Average log loss: -9.1222
#
#
# Test set: Average loss: -9.1446
#
# Current Learning rate 0.0001
# Train Epoch: 289 [0/54118 (0%)]	log Loss: -9.283532
#
# Train set: Average log loss: -9.1330
#
#
# Test set: Average loss: -9.1431
#
# Current Learning rate 0.0001
# Train Epoch: 290 [0/54118 (0%)]	log Loss: -9.298271
#
# Train set: Average log loss: -9.1308
#
#
# Test set: Average loss: -9.1656
#
# Current Learning rate 0.0001
# Train Epoch: 291 [0/54118 (0%)]	log Loss: -9.303723
#
# Train set: Average log loss: -9.1430
#
#
# Test set: Average loss: -9.1767
#
# Current Learning rate 0.0001
# Train Epoch: 292 [0/54118 (0%)]	log Loss: -9.330310
#
# Train set: Average log loss: -9.1442
#
#
# Test set: Average loss: -9.1936
#
# Current Learning rate 0.0001
# Train Epoch: 293 [0/54118 (0%)]	log Loss: -9.339788
#
# Train set: Average log loss: -9.1493
#
#
# Test set: Average loss: -9.2085
#
# Current Learning rate 0.0001
# Train Epoch: 294 [0/54118 (0%)]	log Loss: -9.353569
#
# Train set: Average log loss: -9.1615
#
#
# Test set: Average loss: -9.2388
#
# Current Learning rate 0.0001
# Train Epoch: 295 [0/54118 (0%)]	log Loss: -9.371803
#
# Train set: Average log loss: -9.1729
#
#
# Test set: Average loss: -9.2591
#
# Current Learning rate 0.0001
# Train Epoch: 296 [0/54118 (0%)]	log Loss: -9.396218
#
# Train set: Average log loss: -9.1959
#
#
# Test set: Average loss: -9.2724
#
# Current Learning rate 0.0001
# Train Epoch: 297 [0/54118 (0%)]	log Loss: -9.395255
#
# Train set: Average log loss: -9.2321
#
#
# Test set: Average loss: -9.2448
#
# Current Learning rate 0.0001
# Train Epoch: 298 [0/54118 (0%)]	log Loss: -9.350839
#
# Train set: Average log loss: -9.2820
#
#
# Test set: Average loss: -9.1532
#
# Current Learning rate 0.0001
# Train Epoch: 299 [0/54118 (0%)]	log Loss: -9.245668
#
# Train set: Average log loss: -9.2913
#
#
# Test set: Average loss: -9.1096
#
# Current Learning rate 0.0001
# Train Epoch: 300 [0/54118 (0%)]	log Loss: -9.209269
#
# Train set: Average log loss: -9.2728
#
#
# Test set: Average loss: -9.1489
#
# Current Learning rate 0.0001
# Train Epoch: 301 [0/54118 (0%)]	log Loss: -9.278501
#
# Train set: Average log loss: -9.2716
#
#
# Test set: Average loss: -9.2191
#
# Current Learning rate 0.0001
# Train Epoch: 302 [0/54118 (0%)]	log Loss: -9.375587
#
# Train set: Average log loss: -9.3065
#
#
# Test set: Average loss: -9.2729
#
# Current Learning rate 0.0001
# Train Epoch: 303 [0/54118 (0%)]	log Loss: -9.464058
#
# Train set: Average log loss: -9.3339
#
#
# Test set: Average loss: -9.3087
#
# Current Learning rate 0.0001
# Train Epoch: 304 [0/54118 (0%)]	log Loss: -9.527160
#
# Train set: Average log loss: -9.3423
#
#
# Test set: Average loss: -9.2545
#
# Current Learning rate 0.0001
# Train Epoch: 305 [0/54118 (0%)]	log Loss: -9.489000
#
# Train set: Average log loss: -9.4268
#
#
# Test set: Average loss: -9.1697
#
# Current Learning rate 0.0001
# Train Epoch: 306 [0/54118 (0%)]	log Loss: -9.382321
#
# Train set: Average log loss: -9.4123
#
#
# Test set: Average loss: -9.2460
#
# Current Learning rate 0.0001
# Train Epoch: 307 [0/54118 (0%)]	log Loss: -9.450897
#
# Train set: Average log loss: -9.3784
#
#
# Test set: Average loss: -9.3188
#
# Current Learning rate 0.0001
# Train Epoch: 308 [0/54118 (0%)]	log Loss: -9.507763
#
# Train set: Average log loss: -9.1613
#
#
# Test set: Average loss: -9.2361
#
# Current Learning rate 0.0001
# Train Epoch: 309 [0/54118 (0%)]	log Loss: -9.371276
#
# Train set: Average log loss: -9.3587
#
#
# Test set: Average loss: -9.2323
#
# Current Learning rate 0.0001
# Train Epoch: 310 [0/54118 (0%)]	log Loss: -9.408507
#
# Train set: Average log loss: -9.1061
#
#
# Test set: Average loss: -9.1652
#
# Current Learning rate 0.0001
# Train Epoch: 311 [0/54118 (0%)]	log Loss: -9.302393
#
# Train set: Average log loss: -9.3369
#
#
# Test set: Average loss: -9.3130
#
# Current Learning rate 0.0001
# Train Epoch: 312 [0/54118 (0%)]	log Loss: -9.541527
#
# Train set: Average log loss: -9.3040
#
#
# Test set: Average loss: -9.3117
#
# Current Learning rate 0.0001
# Train Epoch: 313 [0/54118 (0%)]	log Loss: -9.560045
#
# ...
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7906 [0/54118 (0%)]	log Loss: -11.292524
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7907 [0/54118 (0%)]	log Loss: -11.292529
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7908 [0/54118 (0%)]	log Loss: -11.292528
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7909 [0/54118 (0%)]	log Loss: -11.292528
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7910 [0/54118 (0%)]	log Loss: -11.292527
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7911 [0/54118 (0%)]	log Loss: -11.292528
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7912 [0/54118 (0%)]	log Loss: -11.292527
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7913 [0/54118 (0%)]	log Loss: -11.292525
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7914 [0/54118 (0%)]	log Loss: -11.292526
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7915 [0/54118 (0%)]	log Loss: -11.292523
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7916 [0/54118 (0%)]	log Loss: -11.292519
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7917 [0/54118 (0%)]	log Loss: -11.292520
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7918 [0/54118 (0%)]	log Loss: -11.292523
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7919 [0/54118 (0%)]	log Loss: -11.292525
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7920 [0/54118 (0%)]	log Loss: -11.292525
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7921 [0/54118 (0%)]	log Loss: -11.292525
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7922 [0/54118 (0%)]	log Loss: -11.292520
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7923 [0/54118 (0%)]	log Loss: -11.292526
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7924 [0/54118 (0%)]	log Loss: -11.292528
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7925 [0/54118 (0%)]	log Loss: -11.292526
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7926 [0/54118 (0%)]	log Loss: -11.292523
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7927 [0/54118 (0%)]	log Loss: -11.292522
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7928 [0/54118 (0%)]	log Loss: -11.292527
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7929 [0/54118 (0%)]	log Loss: -11.292530
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7930 [0/54118 (0%)]	log Loss: -11.292528
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7931 [0/54118 (0%)]	log Loss: -11.292525
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7932 [0/54118 (0%)]	log Loss: -11.292523
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7933 [0/54118 (0%)]	log Loss: -11.292524
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7934 [0/54118 (0%)]	log Loss: -11.292527
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7935 [0/54118 (0%)]	log Loss: -11.292522
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7936 [0/54118 (0%)]	log Loss: -11.292521
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7937 [0/54118 (0%)]	log Loss: -11.292523
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7938 [0/54118 (0%)]	log Loss: -11.292522
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7939 [0/54118 (0%)]	log Loss: -11.292523
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7940 [0/54118 (0%)]	log Loss: -11.292521
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7941 [0/54118 (0%)]	log Loss: -11.292523
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7942 [0/54118 (0%)]	log Loss: -11.292516
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7943 [0/54118 (0%)]	log Loss: -11.292520
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7944 [0/54118 (0%)]	log Loss: -11.292519
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7945 [0/54118 (0%)]	log Loss: -11.292522
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7946 [0/54118 (0%)]	log Loss: -11.292524
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7947 [0/54118 (0%)]	log Loss: -11.292529
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7948 [0/54118 (0%)]	log Loss: -11.292521
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7949 [0/54118 (0%)]	log Loss: -11.292525
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7950 [0/54118 (0%)]	log Loss: -11.292518
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7951 [0/54118 (0%)]	log Loss: -11.292522
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7952 [0/54118 (0%)]	log Loss: -11.292527
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7953 [0/54118 (0%)]	log Loss: -11.292527
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7954 [0/54118 (0%)]	log Loss: -11.292524
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7955 [0/54118 (0%)]	log Loss: -11.292528
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7956 [0/54118 (0%)]	log Loss: -11.292519
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7957 [0/54118 (0%)]	log Loss: -11.292516
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7958 [0/54118 (0%)]	log Loss: -11.292526
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7959 [0/54118 (0%)]	log Loss: -11.292527
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7960 [0/54118 (0%)]	log Loss: -11.292528
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7961 [0/54118 (0%)]	log Loss: -11.292532
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7962 [0/54118 (0%)]	log Loss: -11.292530
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7963 [0/54118 (0%)]	log Loss: -11.292530
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7964 [0/54118 (0%)]	log Loss: -11.292527
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7965 [0/54118 (0%)]	log Loss: -11.292529
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7966 [0/54118 (0%)]	log Loss: -11.292523
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7967 [0/54118 (0%)]	log Loss: -11.292525
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7968 [0/54118 (0%)]	log Loss: -11.292522
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7969 [0/54118 (0%)]	log Loss: -11.292524
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7970 [0/54118 (0%)]	log Loss: -11.292524
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7971 [0/54118 (0%)]	log Loss: -11.292521
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7972 [0/54118 (0%)]	log Loss: -11.292523
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7973 [0/54118 (0%)]	log Loss: -11.292522
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7974 [0/54118 (0%)]	log Loss: -11.292522
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7975 [0/54118 (0%)]	log Loss: -11.292522
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7976 [0/54118 (0%)]	log Loss: -11.292527
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7977 [0/54118 (0%)]	log Loss: -11.292528
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7978 [0/54118 (0%)]	log Loss: -11.292528
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7979 [0/54118 (0%)]	log Loss: -11.292526
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7980 [0/54118 (0%)]	log Loss: -11.292526
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7981 [0/54118 (0%)]	log Loss: -11.292527
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7982 [0/54118 (0%)]	log Loss: -11.292521
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7983 [0/54118 (0%)]	log Loss: -11.292520
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7984 [0/54118 (0%)]	log Loss: -11.292524
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7985 [0/54118 (0%)]	log Loss: -11.292523
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7986 [0/54118 (0%)]	log Loss: -11.292523
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7987 [0/54118 (0%)]	log Loss: -11.292531
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7988 [0/54118 (0%)]	log Loss: -11.292530
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7989 [0/54118 (0%)]	log Loss: -11.292532
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7990 [0/54118 (0%)]	log Loss: -11.292528
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7991 [0/54118 (0%)]	log Loss: -11.292525
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7992 [0/54118 (0%)]	log Loss: -11.292523
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7993 [0/54118 (0%)]	log Loss: -11.292522
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7994 [0/54118 (0%)]	log Loss: -11.292526
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7995 [0/54118 (0%)]	log Loss: -11.292531
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7996 [0/54118 (0%)]	log Loss: -11.292530
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7997 [0/54118 (0%)]	log Loss: -11.292529
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7998 [0/54118 (0%)]	log Loss: -11.292528
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7999 [0/54118 (0%)]	log Loss: -11.292529
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 8000 [0/54118 (0%)]	log Loss: -11.292529
#
# Train set: Average log loss: -11.2507
#
#
# Test set: Average loss: -10.6719
#
# Current Learning rate 3.0517578125e-09

# %%
# Plotting log(MSE) as a function of epochs
plt.figure(figsize=(10,7))
plt.plot( np.log(test_losses), label = "test")
plt.plot( np.log(train_losses), label = "train")

plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Log(LSE)")
plt.title("MSE over Epoch" )
plt.grid()
print("Training WIDE {} VS in the article 8.04e-09".format(train_losses[-1]) )
# Out:
# Training WIDE 1.2997643284790099e-05 VS in the article 8.04e-09

# %% [markdown]
# ## d) Prediction
# #### Load the ANN

# %%
# Loading model
device = 'cuda'
loaded_Heston_IV_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_IV_ANN_DE.pt"
loaded_Heston_IV_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_IV_ANN.eval()
# Out:
# Heston_ANN(
#   (fc1): Linear(in_features=8, out_features=200, bias=True)
#   (fc2): Linear(in_features=200, out_features=200, bias=True)
#   (fc3): Linear(in_features=200, out_features=200, bias=True)
#   (fc4): Linear(in_features=200, out_features=200, bias=True)
#   (fc5): Linear(in_features=200, out_features=1, bias=True)
# )

# %%
x = hs_dataset[0, :-1].unsqueeze(0).to(device)  # input shape (1, 8)
true_iv = hs_dataset[0, -1].item()

# %%
with torch.no_grad():
    predicted_iv = model(x).item()
    predicted_iv2 = loaded_Heston_IV_ANN(x)

# %%
print(f"True IV:      {true_iv:.4f}")
print(f"Predicted IV: {predicted_iv:.4f}")
# Out:
# True IV:      0.4942
# Predicted IV: 0.4971

# %%
with torch.no_grad():
    predicted_iv1 = model(x)
    predicted_iv2 = loaded_Heston_IV_ANN(x)

print("Are both predictions equal? ", torch.allclose(predicted_iv1, predicted_iv2, atol=1e-6))
print(f"Model(x):              {predicted_iv1.item():.6f}")
print(f"Loaded_Heston_ANN(x):  {predicted_iv2.item():.6f}")
# Out:
# Are both predictions equal?  True
# Model(x):              0.497133
# Loaded_Heston_ANN(x):  0.497133

# %% [markdown]
# #### This table shows similar trained forward performance as shown in Table (4) from [1]

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_IV_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_IV_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Train scores----------------
# MSE 1.299727e-05
# MAE 2.734592e-03
# MAPE 5.137553e-03
# R2 9.999535e-01
# -----------Test scores----------------
# MSE 2.318725e-05
# MAE 3.194792e-03
# MAPE 6.121043e-03
# R2 9.999149e-01

# %%
plt.scatter(targets, outputs, alpha=0.1)
plt.xlabel("True IV")
plt.ylabel("Predicted IV")
plt.title("Heston-IV-ANN Fit")
plt.grid(True)
plt.show()

# %% [markdown]
# # 2) Backward pass

# %% [markdown]
# ## a) Preperation Market Quotes

# %% [markdown]
# ### Reference Heston parameter

# %%
# Effect of individual parameters
# Section 4.1.1 in [1]
T = 2 
S0 = 100
kappa = 0.1
gamma = 0.1  # Volatility of variance
nu_bar = 0.1
rho = -0.75
nu_0 = 0.05
r = 0.05

# %%
# Grid setup: 7 maturities × 5 moneynesses = 35
moneyness = np.linspace(0.85, 1.15, 5)
maturity = np.linspace(0.5, 2.0, 7)
m_grid, t_grid = np.meshgrid(moneyness, maturity)
m_flat = m_grid.flatten()
t_flat = t_grid.flatten()
r_flat = np.full_like(m_flat, r)

# Step 1: COS Heston → option prices (V/K)
prices = call_option_Heston_moy(
    N=300,
    L=12,
    r=r_flat.reshape(-1, 1),
    tau=t_flat.reshape(-1, 1),
    kappa=np.full_like(m_flat, kappa).reshape(-1, 1),
    gamma=np.full_like(m_flat, gamma).reshape(-1, 1),
    vbar=np.full_like(m_flat, vbar).reshape(-1, 1),
    v0=np.full_like(m_flat, nu_0).reshape(-1, 1),
    rho=np.full_like(m_flat, rho).reshape(-1, 1),
    moyeness=m_flat.reshape(-1, 1)
).flatten()

#prices = np.maximum(prices, 1e-5)

# Step 2: Brent inversion → implied vols
brent_input = np.column_stack([m_flat, t_flat, r_flat, prices])
implied_vols = np.array([calcimpliedvol(row) for row in brent_input])
invalid = np.isnan(implied_vols)
print(f"Invalid IVs: {np.sum(invalid)} / {len(implied_vols)}")


# Step 3: Final market quote table
market_quotes = np.column_stack([m_flat, t_flat, r_flat, implied_vols])

# Print for verification
print("Market Quotes (35):")
for q in market_quotes:
    print(f"m={q[0]:.2f}, tau={q[1]:.2f}, r={q[2]:.2f}, IV={q[3]:.4f}")

#print("calcimpliedvol calls:", counter)
# Out:
# Invalid IVs: 10 / 35
# Market Quotes (35):
# m=0.85, tau=0.50, r=0.05, IV=nan
# m=0.92, tau=0.50, r=0.05, IV=nan
# m=1.00, tau=0.50, r=0.05, IV=0.2795
# m=1.07, tau=0.50, r=0.05, IV=0.5739
# m=1.15, tau=0.50, r=0.05, IV=0.8837
# m=0.85, tau=0.75, r=0.05, IV=nan
# m=0.92, tau=0.75, r=0.05, IV=nan
# m=1.00, tau=0.75, r=0.05, IV=0.2954
# m=1.07, tau=0.75, r=0.05, IV=0.5387
# m=1.15, tau=0.75, r=0.05, IV=0.7908
# m=0.85, tau=1.00, r=0.05, IV=nan
# m=0.92, tau=1.00, r=0.05, IV=nan
# m=1.00, tau=1.00, r=0.05, IV=0.3097
# m=1.07, tau=1.00, r=0.05, IV=0.5235
# m=1.15, tau=1.00, r=0.05, IV=0.7431
# m=0.85, tau=1.25, r=0.05, IV=nan
# m=0.92, tau=1.25, r=0.05, IV=0.1146
# m=1.00, tau=1.25, r=0.05, IV=0.3232
# m=1.07, tau=1.25, r=0.05, IV=0.5173
# m=1.15, tau=1.25, r=0.05, IV=0.7157
# m=0.85, tau=1.50, r=0.05, IV=nan
# m=0.92, tau=1.50, r=0.05, IV=0.1475
# m=1.00, tau=1.50, r=0.05, IV=0.3360
# m=1.07, tau=1.50, r=0.05, IV=0.5160
# m=1.15, tau=1.50, r=0.05, IV=0.6994
# m=0.85, tau=1.75, r=0.05, IV=nan
# m=0.92, tau=1.75, r=0.05, IV=0.1733
# m=1.00, tau=1.75, r=0.05, IV=0.3484
# m=1.07, tau=1.75, r=0.05, IV=0.5177
# m=1.15, tau=1.75, r=0.05, IV=0.6900
# m=0.85, tau=2.00, r=0.05, IV=nan
# m=0.92, tau=2.00, r=0.05, IV=0.1953
# m=1.00, tau=2.00, r=0.05, IV=0.3604
# m=1.07, tau=2.00, r=0.05, IV=0.5214
# m=1.15, tau=2.00, r=0.05, IV=0.6852

# %%
print("Total IVs:    ", len(implied_vols))
print("Failures (NaN):", np.sum(np.isnan(implied_vols)))
print("Successes:    ", np.sum(~np.isnan(implied_vols)))
# Out:
# Total IVs:     35
# Failures (NaN): 10
# Successes:     25

# %%
import matplotlib.pyplot as plt

plt.hist(prices, bins=15, edgecolor='black')
plt.title("Histogram of Market Prices (V/K)")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
for i, p in enumerate(prices):
    if p < 0.1:
        print(f"#{i:2d}: m={m_flat[i]:.2f}, tau={t_flat[i]:.2f}, price={p:.4f}")

# %% [markdown]
# ### 1 single Market quote

# %%
price = call_option_Heston_moy(
    N=1000, L=20,
    r=0.05,
    tau=np.array([[1.0]]),
    kappa=np.array([[0.1]]),
    gamma=np.array([[0.1]]),
    vbar=np.array([[0.1]]),
    v0=np.array([[0.05]]),
    rho=np.array([[-0.75]]),
    moyeness=np.array([[1.0]])
).item()

iv = calcimpliedvol([1.0, 1.0, 0.05, price])

input_tensor = torch.FloatTensor([[1.0, 1.0, 0.05, -0.75, 0.1, 0.1, 0.1, 0.05]]).to(device)
with torch.no_grad():
    iv_test = loaded_Heston_IV_ANN(input_tensor).item()

print(price)
print(iv)
print(iv_test)
# Out:
# 0.11556168412475808
# 0.30971752102183253
# 0.34737056493759155

# %% [markdown]
# ### Calibrate 3 parameters (kappa, v_0 fixed)

# %%
# Effect of individual parameters
# Section 4.1.1 in [1]
T = 2 
S0 = 100
kappa = 0.1
gamma = 0.1  # Volatility of variance
nu_bar = 0.1
rho = -0.75
nu_0 = 0.05
r = 0.05

# %% [markdown]
# ### Market quotes (Table (5))

# %%
# Grid setup: 7 maturities × 5 moneynesses = 35
moneyness = np.linspace(0.85, 1.15, 5)
maturity = np.linspace(0.5, 2.0, 7)
m_grid, t_grid = np.meshgrid(moneyness, maturity)
m_flat = m_grid.flatten()
t_flat = t_grid.flatten()
r_flat = np.full_like(m_flat, r)

# Step 1: COS Heston → option prices (V/K)
prices = call_option_Heston_moy(
    N=300,
    L=12,
    r=r_flat.reshape(-1, 1),
    tau=t_flat.reshape(-1, 1),
    kappa=np.full_like(m_flat, kappa).reshape(-1, 1),
    gamma=np.full_like(m_flat, gamma).reshape(-1, 1),
    vbar=np.full_like(m_flat, vbar).reshape(-1, 1),
    v0=np.full_like(m_flat, v0).reshape(-1, 1),
    rho=np.full_like(m_flat, rho).reshape(-1, 1),
    moyeness=m_flat.reshape(-1, 1)
).flatten()

#print(min(prices), max(prices), np.any(prices <= 0))

print(f"Price: {prices[0]:.5f}")
# Step 2: Brent inversion → implied vols
brent_input = np.column_stack([m_flat, t_flat, r_flat, prices])
implied_vols = np.array([calcimpliedvol(row) for row in brent_input])

# Step 3: Final market quote table
market_quotes = np.column_stack([m_flat, t_flat, r_flat, implied_vols])

print("Market Quotes (35):")
for q in market_quotes:
    print(f"m={q[0]:.2f}, tau={q[1]:.2f}, r={q[2]:.2f}, IV={q[3]:.4f}")
# Out:
# Price: 0.12074
# Market Quotes (35):
# m=0.85, tau=0.50, r=0.05, IV=nan
# m=0.92, tau=0.50, r=0.05, IV=0.4577
# m=1.00, tau=0.50, r=0.05, IV=0.7544
# m=1.07, tau=0.50, r=0.05, IV=1.0358
# m=1.15, tau=0.50, r=0.05, IV=1.3167
# m=0.85, tau=0.75, r=0.05, IV=0.2113
# m=0.92, tau=0.75, r=0.05, IV=0.5204
# m=1.00, tau=0.75, r=0.05, IV=0.7669
# m=1.07, tau=0.75, r=0.05, IV=1.0038
# m=1.15, tau=0.75, r=0.05, IV=1.2406
# m=0.85, tau=1.00, r=0.05, IV=0.3113
# m=0.92, tau=1.00, r=0.05, IV=0.5602
# m=1.00, tau=1.00, r=0.05, IV=0.7785
# m=1.07, tau=1.00, r=0.05, IV=0.9903
# m=1.15, tau=1.00, r=0.05, IV=1.2028
# m=0.85, tau=1.25, r=0.05, IV=0.3698
# m=0.92, tau=1.25, r=0.05, IV=0.5896
# m=1.00, tau=1.25, r=0.05, IV=0.7896
# m=1.07, tau=1.25, r=0.05, IV=0.9854
# m=1.15, tau=1.25, r=0.05, IV=1.1830
# m=0.85, tau=1.50, r=0.05, IV=0.4120
# m=0.92, tau=1.50, r=0.05, IV=0.6136
# m=1.00, tau=1.50, r=0.05, IV=0.8009
# m=1.07, tau=1.50, r=0.05, IV=0.9857
# m=1.15, tau=1.50, r=0.05, IV=1.1737
# m=0.85, tau=1.75, r=0.05, IV=0.4458
# m=0.92, tau=1.75, r=0.05, IV=0.6345
# m=1.00, tau=1.75, r=0.05, IV=0.8127
# m=1.07, tau=1.75, r=0.05, IV=0.9902
# m=1.15, tau=1.75, r=0.05, IV=1.1716
# m=0.85, tau=2.00, r=0.05, IV=0.4755
# m=0.92, tau=2.00, r=0.05, IV=0.6561
# m=1.00, tau=2.00, r=0.05, IV=0.8267
# m=1.07, tau=2.00, r=0.05, IV=1.0031
# m=1.15, tau=2.00, r=0.05, IV=1.1762

# %%
implied_vol_NAN = np.array([calcimpliedvol(brent_input[0])])
print(implied_vol_NAN)
implied_vol_NAN = np.array([calcimpliedvol(brent_input[1])])
print(implied_vol_NAN)
# Out:
# Quote: m=0.85, T=0.50, r=0.05, price=0.1207
# f(1e-4)=0.1463, f(5.0)=0.9060
# [nan]
# Quote: m=0.92, T=0.50, r=0.05, price=0.1604
# f(1e-4)=0.0731, f(5.0)=0.9030
# [0.45774695]

# %%
m, T, r, price = brent_input[0]

print("COS Heston price for quote 0:", price)


def bs_obj(sigma):
    print("f(1e-4):", bs_price(sigma, m, T, r) - price)
    print("f(5.0):",   bs_price(sigma, m, T, r) - price)
    return bs_price(sigma, m, T, r) - price

iv_fixed = brentq(bs_obj, 1e-4, 5.0)
print("Recovered IV:", iv_fixed)
# Out:
# COS Heston price for quote 0: 0.12074269836632713
# f(1e-4): 0.02555378843792279
# f(5.0): 0.02555378843792279
# f(1e-4): 0.7852849986197311
# f(5.0): 0.7852849986197311
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 11
#       8     print("f(5.0):",   bs_price(sigma, m, T, r) - price)
#       9     return bs_price(sigma, m, T, r) - price
# ---> 11 iv_fixed = brentq(bs_obj, 1e-4, 5.0)
#      12 print("Recovered IV:", iv_fixed)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_zeros_py.py:784, in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     782 if rtol < _rtol:
#     783     raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 784 r = _zeros._brentq(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     785 return results_c(full_output, r)
#
# ValueError: f(a) and f(b) must have different signs

# %%
for row in market_quotes:
    m, T, r, iv = row
    price_check = bs_price(iv, m, T, r)
    print(f"Repriced: {price_check:.4f}")
# Out:
# Repriced: nan
# Repriced: 0.1604
# Repriced: 0.2049
# Repriced: 0.2538
# Repriced: 0.3065
# Repriced: 0.1603
# Repriced: 0.2033
# Repriced: 0.2502
# Repriced: 0.3006
# Repriced: 0.3541
# Repriced: 0.1934
# Repriced: 0.2388
# Repriced: 0.2876
# Repriced: 0.3393
# Repriced: 0.3937
# Repriced: 0.2220
# Repriced: 0.2694
# Repriced: 0.3197
# Repriced: 0.3726
# Repriced: 0.4279
# Repriced: 0.2474
# Repriced: 0.2964
# Repriced: 0.3481
# Repriced: 0.4020
# Repriced: 0.4582
# Repriced: 0.2705
# Repriced: 0.3209
# Repriced: 0.3737
# Repriced: 0.4288
# Repriced: 0.4856
# Repriced: 0.2922
# Repriced: 0.3444
# Repriced: 0.3979
# Repriced: 0.4555
# Repriced: 0.5111

# %%
for i, row in enumerate(market_quotes):
    m, T, r, iv = row
    original_price = prices[i]  # <-- This is the price fed into Brent
    if np.isnan(iv):
        print(f"{i}: Brent failed")
        continue
    re_bs_price = bs_price(iv, m, T, r)
    print(f"{i}: Heston={original_price:.4f}, BS(IV)={re_bs_price:.4f}, Δ={abs(original_price - re_bs_price):.4e}")
# Out:
# 0: Brent failed
# 1: Heston=0.1604, BS(IV)=0.1604, Δ=5.8287e-16
# 2: Heston=0.2049, BS(IV)=0.2049, Δ=2.8579e-11
# 3: Heston=0.2538, BS(IV)=0.2538, Δ=3.9399e-10
# 4: Heston=0.3065, BS(IV)=0.3065, Δ=2.2204e-16
# 5: Heston=0.1603, BS(IV)=0.1603, Δ=9.9809e-14
# 6: Heston=0.2033, BS(IV)=0.2033, Δ=8.6891e-11
# 7: Heston=0.2502, BS(IV)=0.2502, Δ=5.8287e-15
# 8: Heston=0.3006, BS(IV)=0.3006, Δ=1.1102e-16
# 9: Heston=0.3541, BS(IV)=0.3541, Δ=1.2601e-14
# 10: Heston=0.1934, BS(IV)=0.1934, Δ=3.0512e-12
# 11: Heston=0.2388, BS(IV)=0.2388, Δ=6.4976e-14
# 12: Heston=0.2876, BS(IV)=0.2876, Δ=1.7417e-12
# 13: Heston=0.3393, BS(IV)=0.3393, Δ=1.2556e-11
# 14: Heston=0.3937, BS(IV)=0.3937, Δ=8.1246e-10
# 15: Heston=0.2220, BS(IV)=0.2220, Δ=1.5942e-10
# 16: Heston=0.2694, BS(IV)=0.2694, Δ=3.8858e-16
# 17: Heston=0.3197, BS(IV)=0.3197, Δ=1.6187e-10
# 18: Heston=0.3726, BS(IV)=0.3726, Δ=0.0000e+00
# 19: Heston=0.4279, BS(IV)=0.4279, Δ=9.8754e-14
# 20: Heston=0.2474, BS(IV)=0.2474, Δ=1.0952e-13
# 21: Heston=0.2964, BS(IV)=0.2964, Δ=1.6986e-14
# 22: Heston=0.3481, BS(IV)=0.3481, Δ=5.5511e-17
# 23: Heston=0.4020, BS(IV)=0.4020, Δ=7.4596e-11
# 24: Heston=0.4582, BS(IV)=0.4582, Δ=2.7247e-10
# 25: Heston=0.2705, BS(IV)=0.2705, Δ=9.2903e-10
# 26: Heston=0.3209, BS(IV)=0.3209, Δ=6.3283e-15
# 27: Heston=0.3737, BS(IV)=0.3737, Δ=5.8509e-14
# 28: Heston=0.4288, BS(IV)=0.4288, Δ=7.8786e-10
# 29: Heston=0.4856, BS(IV)=0.4856, Δ=1.7099e-10
# 30: Heston=0.2922, BS(IV)=0.2922, Δ=5.7226e-10
# 31: Heston=0.3444, BS(IV)=0.3444, Δ=1.1887e-10
# 32: Heston=0.3979, BS(IV)=0.3979, Δ=2.4356e-11
# 33: Heston=0.4555, BS(IV)=0.4555, Δ=5.8125e-12
# 34: Heston=0.5111, BS(IV)=0.5111, Δ=1.5167e-12

# %%
from scipy.optimize import brentq
from scipy.stats import norm
import numpy as np

# Inputs
m = 0.85
T = 0.5
r = 0.05
price = 0.12074269836632713

# Black-Scholes function (moneyness version)
def bs_price(sigma):
    d1 = (np.log(m) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    val = m * norm.cdf(d1) - np.exp(-r * T) * norm.cdf(d2)
    return val - price

# Check bracket
print("f(1e-4) =", bs_price(1e-4))
print("f(5.0)   =", bs_price(5.0))
# Out:
# f(1e-4) = -0.12074269836632713
# f(5.0)   = 0.659095407985856

# %%
iv = brentq(bs_price, 1e-4, 5.0)
print("IV =", iv)
# Out:
# IV = 0.6929583354556618

# %% [markdown]
# ### Objective function

# %%
def calibration_objective(theta, inputs, market_iv, iv_ann):
    # theta: [rho, kappa, vbar, gamma, v0]
    # inputs: [moneyness, maturity, r] fixed per quote
    input_tensor = torch.tensor(np.column_stack([
        inputs,  # shape (N, 3)
        np.tile(theta, (inputs.shape[0], 1))
    ]), dtype=torch.float32).to(device)

    with torch.no_grad():
        pred_iv = iv_ann(input_tensor).cpu().numpy().flatten()

    return np.mean((pred_iv - market_iv) ** 2)

# %%
inputs = market_quotes[:, :3]         # [moneyness, maturity, r]
market_iv = market_quotes[:, 3]       # true IVs
iv_ann = loaded_Heston_IV_ANN         # trained and set to eval()

# %% [markdown]
# ### Differential Evolution (DE)

# %%
# Effect of individual parameters
# Section 4.1.1 in [1]
T = 2 
S0 = 100
kappa = 0.1
gamma = 0.1  # Volatility of variance
nu_bar = 0.1
rho = -0.75
nu_0 = 0.05
r = 0.05

# %%
# Bounds from Section 4.1.1
bounds = [(-0.85, 0.05), (0.05, 0.45), (0.05, 0.75), (0.05, 0.45), (0.1, 2.0)]

# --- Run DE optimization ---
result = differential_evolution(
    func=calibration_objective,
    bounds=bounds,
    args=(inputs, market_iv, iv_ann),
    strategy="best1bin",
    popsize=50,
    tol=1e-5,
    maxiter=1000,
    updating="deferred"
)

print("Calibrated parameters: (rho, nu_bar, gamma, nu_0, kappa)")
print("Calibrated parameters:", result.x)
print("Final MSE loss:", result.fun)
# Out:
# Calibrated parameters: (rho, nu_bar, gamma, nu_0, kappa)
# Calibrated parameters: [-0.15014579  0.06063102  0.40687907  0.31647636  0.48144413]
# Final MSE loss: nan

# %%
target_iv = implied_vols

# Use the contract terms (moneyness, maturity, r) from market quotes
fixed_contracts = market_quotes[:, :3]  # shape (35, 3)

# --- Loss function ---
def calibration_objective(theta):
    rho, kappa, vbar, gamma, v0 = theta

    

    # Build full input matrix (35 rows, 8 features)
    input_matrix = np.hstack([
        fixed_contracts,
        np.full((fixed_contracts.shape[0], 1), rho),
        np.full((fixed_contracts.shape[0], 1), kappa),
        np.full((fixed_contracts.shape[0], 1), vbar),
        np.full((fixed_contracts.shape[0], 1), gamma),
        np.full((fixed_contracts.shape[0], 1), v0),
    ])
    input_tensor = torch.FloatTensor(input_matrix).to(device)

    # Predict prices with Heston-ANN
    with torch.no_grad():
        prices = loaded_Heston_ANN(input_tensor).cpu().numpy().flatten()

    # Ensure prices > intrinsic value for Brent to work
    intrinsic = fixed_contracts[:, 0] - np.exp(-fixed_contracts[:, 1] * fixed_contracts[:, 2])
    prices = np.maximum(prices, intrinsic + 1e-4)
    print("Input params:", theta)
    #print("Prices shape:", prices.shape)
    #print("Input prices:", prices)
    #print("Target IV shape:", target_iv.shape)
    assert prices is not None, "Heston-ANN returned None!"

    # Compute Brent IVs
    brent_inputs = np.column_stack([fixed_contracts, prices])
    predicted_iv = np.apply_along_axis(calcimpliedvol, 1, brent_inputs)

    # Check for NaNs
    if np.any(np.isnan(predicted_iv)):
        return 1e3  # penalize invalid parameter sets

    # Compute MSE loss
    return np.mean((predicted_iv - target_iv)**2)

# %%
# --- Bounds from Section 4.1.1 ---
bounds = [(-0.85, 0.05), (0.05, 0.45), (0.05, 0.75), (0.05, 0.45), (0.1, 2.0)]

# --- Run DE optimization ---
result = differential_evolution(
    calibration_objective,
    bounds,
    strategy="best1bin",
    popsize=15,
    tol=1e-5,
    maxiter=1000,
    #polish=True,
    workers=1,
    updating="deferred"
)

print("Calibrated parameters:", result.x)
print("Final MSE loss:", result.fun)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:1122, in DifferentialEvolutionSolver._calculate_population_energies(self, population)
#    1121 try:
# -> 1122     calc_energies = list(
#    1123         self._mapwrapper(self.func, parameters_pop[0:S])
#    1124     )
#    1125     calc_energies = np.squeeze(calc_energies)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\_lib\_util.py:372, in _FunctionWrapper.__call__(self, x)
#     371 def __call__(self, x):
# --> 372     return self.f(x, *self.args)
#
# TypeError: calibration_objective() missing 3 required positional arguments: 'inputs', 'market_iv', and 'iv_ann'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[55], line 5
#       2 bounds = [(-0.85, 0.05), (0.05, 0.45), (0.05, 0.75), (0.05, 0.45), (0.1, 2.0)]
#       4 # --- Run DE optimization ---
# ----> 5 result = differential_evolution(
#       6     calibration_objective,
#       7     bounds,
#       8     strategy="best1bin",
#       9     popsize=15,
#      10     tol=1e-5,
#      11     maxiter=1000,
#      12     #polish=True,
#      13     workers=1,
#      14     updating="deferred"
#      15 )
#      17 print("Calibrated parameters:", result.x)
#      18 print("Final MSE loss:", result.fun)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:397, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     380 # using a context manager means that any created Pool objects are
#     381 # cleared up.
#     382 with DifferentialEvolutionSolver(func, bounds, args=args,
#     383                                  strategy=strategy,
#     384                                  maxiter=maxiter,
#    (...)
#     395                                  integrality=integrality,
#     396                                  vectorized=vectorized) as solver:
# --> 397     ret = solver.solve()
#     399 return ret
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:989, in DifferentialEvolutionSolver.solve(self)
#     984     self.feasible, self.constraint_violation = (
#     985         self._calculate_population_feasibilities(self.population))
#     987     # only work out population energies for feasible solutions
#     988     self.population_energies[self.feasible] = (
# --> 989         self._calculate_population_energies(
#     990             self.population[self.feasible]))
#     992     self._promote_lowest_energy()
#     994 # do the optimization.
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:1129, in DifferentialEvolutionSolver._calculate_population_energies(self, population)
#    1125     calc_energies = np.squeeze(calc_energies)
#    1126 except (TypeError, ValueError) as e:
#    1127     # wrong number of arguments for _mapwrapper
#    1128     # or wrong length returned from the mapper
# -> 1129     raise RuntimeError(
#    1130         "The map-like callable must be of the form f(func, iterable), "
#    1131         "returning a sequence of numbers the same length as 'iterable'"
#    1132     ) from e
#    1134 if calc_energies.size != S:
#    1135     if self.vectorized:
#
# RuntimeError: The map-like callable must be of the form f(func, iterable), returning a sequence of numbers the same length as 'iterable'

# %%
# EXAMPLE DE

import numpy as np
from scipy.optimize import differential_evolution

# Synthetic model: true IV is a known function of moneyness and maturity
def true_iv(m, t, rho, gamma):
    return 0.2 + 0.1 * (m - 1)**2 + 0.05 * t + 0.02 * abs(rho) + 0.01 * gamma

# Generate synthetic market quotes
moneyness = np.linspace(0.85, 1.15, 5)
maturity = np.linspace(0.5, 2.0, 7)
m_grid, t_grid = np.meshgrid(moneyness, maturity)
m_flat = m_grid.flatten()
t_flat = t_grid.flatten()

true_params = (-0.75, 0.2)
target_iv = true_iv(m_flat, t_flat, *true_params)

# Objective to minimize
def calibration_objective(params):
    rho, gamma = params
    predicted_iv = true_iv(m_flat, t_flat, rho, gamma)
    return np.mean((predicted_iv - target_iv)**2)

# Run DE
bounds = [(-0.85, 0.05), (0.05, 0.45)]
result = differential_evolution(calibration_objective, bounds)

print("Calibrated parameters:", result.x)
print("True parameters:", true_params)
print("Final loss:", result.fun)
# Out:
# Calibrated parameters: [-0.82250742  0.05498515]
# True parameters: (-0.75, 0.2)
# Final loss: 0.0

# %%
import numpy as np

# Observed market implied volatilities (target data)

observed_vols = np.linspace(0.2, 0.5, 35)  # Generates 35 equally spaced values

# Moneyness and time-to-maturity of the observed data
moneyness = np.linspace(0.85, 1.15, 5)  # Moneyness
maturities = np.linspace(0.5, 2.0, 7)   # Time to maturity
r = 0.03
#params = 



# Pre-trained ANN that maps Heston parameters to implied volatilities
def heston_ann(parameters):
    """
    A mock function representing the ANN (pre-trained forward pass).
    In real scenarios, this will return ANN-predicted implied volatilities.
    """
    # Example: Simple mapping for illustration
    rho, kappa, gamma, nu_bar, nu_0 = parameters
    return 0.25 + 0.05 * (moneyness - 1.0) + 0.02 * (maturities - 1.0)

# Objective function for DE calibration
def calibration_objective(parameters):
    """
    Calculates the mean squared error between ANN-predicted
    and observed market volatilities.
    """
    predicted_vols = implied_vols
    error = np.mean((predicted_vols - observed_vols) ** 2)
    return error

# %% [markdown]
# # DOWN FROM HERE EVERYTHING IS ONLY FOR LOOK UP PURPOSES

# %%
import numpy as np
import itertools

# Define Heston parameter bounds
bounds = {
    "rho": (-0.9, 0.0),         # Correlation coefficient
    "kappa": (0.1, 3.0),        # Speed of mean reversion
    "gamma": (0.01, 0.8),       # Volatility of variance
    "nu_0": (0.01, 0.5),        # Initial variance
    "nu_bar": (0.01, 0.5)       # Long-term variance
}

# Number of discrete points to sample within each parameter's range
points_per_param = 5

# Generate equally spaced points for each parameter within its bounds
parameter_points = {param: np.linspace(lower, upper, points_per_param)
                    for param, (lower, upper) in bounds.items()}

# Combine the points to form a grid of all possible parameter combinations
grid = list(itertools.product(
    parameter_points["rho"],
    parameter_points["kappa"],
    parameter_points["gamma"],
    parameter_points["nu_0"],
    parameter_points["nu_bar"]
))

# Convert the grid into a NumPy array for convenience
parameter_grid = np.array(grid)

# Display the grid details
print(f"Search space dimensions: {len(parameter_points)} parameters")
print(f"Total combinations: {parameter_grid.shape[0]}")
print("Example combinations (first 5 rows):")
print(parameter_grid[:5])

# Optional: Save to a file for later use
np.savetxt("heston_search_space.csv", parameter_grid, delimiter=",",
           header="rho,kappa,gamma,nu_0,nu_bar", comments="")

# %%
import torch
import numpy as np
from scipy.optimize import differential_evolution

def calibrate_with_de(loaded_ANN, moneyness, maturities, r, observed_vols, device="cuda"):
    """
    Calibrates Heston parameters using differential evolution and a trained ANN.
    
    Parameters:
    - loaded_ANN: Trained PyTorch ANN (set to .eval())
    - moneyness: 1D array of moneyness values (e.g., shape (5,))
    - maturities: 1D array of maturities (e.g., shape (7,))
    - r: risk-free rate (scalar)
    - observed_vols: flattened vector of observed implied vols (shape (len(moneyness) * len(maturities),))
    - device: "cuda" or "cpu"
    
    Returns:
    - result.x: optimal Heston parameters [rho, kappa, gamma, nu_bar, nu_0]
    - result.fun: final objective value (MSE)
    """

    # Make sure model is in eval mode
    loaded_ANN.eval()

    # Create full input grid for calibration
    def heston_ann(parameters):
        rho, kappa, gamma, nu_bar, nu_0 = parameters
        inputs = []

        for m in moneyness:
            for t in maturities:
                inputs.append([m, t, r, rho, kappa, nu_bar, gamma, nu_0])

        inputs = torch.tensor(inputs, dtype=torch.float32).to(device)

        with torch.no_grad():
            preds = loaded_ANN(inputs).cpu().numpy().flatten()
        return preds

    # Objective function to minimize
    def calibration_objective(parameters):
        predicted_vols = heston_ann(parameters)
        return np.mean((predicted_vols - observed_vols) ** 2)

    # Bounds for DE (adjust to your actual model/training setup)
    bounds = [
        (-0.85, 0.0),     # rho
        (0.1, 3.0),      # kappa
        (0.01, 0.8),     # gamma
        (0.01, 0.5),     # nu_bar
        (0.01, 0.5),     # nu_0
    ]

    # Run differential evolution
    result = differential_evolution(
        calibration_objective,
        bounds,
        strategy="best1bin",
        popsize=50,
        mutation=(0.5, 1.0),
        recombination=0.7,
        tol=0.001,
        disp=True
    )

    return result.x, result.fun

# %%
# Inputs
moneyness = np.linspace(0.85, 1.15, 5)
maturities = np.linspace(0.5, 2.0, 7)
r = 0.03

# Observed vols must be flat vector of shape (35,)
observed_vols = np.linspace(0.2, 0.5, 35)

# Run calibration
opt_params, final_loss = calibrate_with_de(loaded_Heston_ANN, moneyness, maturities, r, observed_vols)

print("Optimal Heston parameters:")
print(f"rho={opt_params[0]:.4f}, kappa={opt_params[1]:.4f}, gamma={opt_params[2]:.4f}, "
      f"nu_bar={opt_params[3]:.4f}, nu_0={opt_params[4]:.4f}")
print(f"Final MSE: {final_loss:.6e}")
# Out:
# differential_evolution step 1: f(x)= 0.00392477
# differential_evolution step 2: f(x)= 0.00392477
# differential_evolution step 3: f(x)= 0.00379698
# differential_evolution step 4: f(x)= 0.00376597
# differential_evolution step 5: f(x)= 0.00376597
# differential_evolution step 6: f(x)= 0.00376597
# differential_evolution step 7: f(x)= 0.0036891
# differential_evolution step 8: f(x)= 0.00364717
# differential_evolution step 9: f(x)= 0.00364717
# differential_evolution step 10: f(x)= 0.00364717
# differential_evolution step 11: f(x)= 0.00364717
# differential_evolution step 12: f(x)= 0.00364717
# differential_evolution step 13: f(x)= 0.00364717
# differential_evolution step 14: f(x)= 0.00364717
# differential_evolution step 15: f(x)= 0.00364717
# differential_evolution step 16: f(x)= 0.00364717
# differential_evolution step 17: f(x)= 0.00364717
# differential_evolution step 18: f(x)= 0.0036225
# differential_evolution step 19: f(x)= 0.0036225
# differential_evolution step 20: f(x)= 0.0036225
# differential_evolution step 21: f(x)= 0.0036225
# differential_evolution step 22: f(x)= 0.0036225
# differential_evolution step 23: f(x)= 0.0036225
# differential_evolution step 24: f(x)= 0.0036225
# differential_evolution step 25: f(x)= 0.00362203
# differential_evolution step 26: f(x)= 0.00362061
# differential_evolution step 27: f(x)= 0.00362061
# differential_evolution step 28: f(x)= 0.00361841
# differential_evolution step 29: f(x)= 0.00361841
# differential_evolution step 30: f(x)= 0.00361841
# differential_evolution step 31: f(x)= 0.00361681
# differential_evolution step 32: f(x)= 0.00361562
# differential_evolution step 33: f(x)= 0.00361163
# differential_evolution step 34: f(x)= 0.00361163
# differential_evolution step 35: f(x)= 0.00361021
# differential_evolution step 36: f(x)= 0.00361001
# differential_evolution step 37: f(x)= 0.00361001
# differential_evolution step 38: f(x)= 0.00361001
# differential_evolution step 39: f(x)= 0.0036084
# differential_evolution step 40: f(x)= 0.0036084
# differential_evolution step 41: f(x)= 0.0036084
# differential_evolution step 42: f(x)= 0.0036084
# differential_evolution step 43: f(x)= 0.0036084
# differential_evolution step 44: f(x)= 0.00360806
# differential_evolution step 45: f(x)= 0.00360787
# differential_evolution step 46: f(x)= 0.00360778
# differential_evolution step 47: f(x)= 0.00360765
# Polishing solution with 'L-BFGS-B'
# Optimal Heston parameters:
# rho=-0.1873, kappa=0.1609, gamma=0.2718, nu_bar=0.4995, nu_0=0.5000
# Final MSE: 3.607652e-03

# %%
import numpy as np

# Observed market implied volatilities (target data)

observed_vols = np.linspace(0.2, 0.5, 35)  # Generates 35 equally spaced values

# Moneyness and time-to-maturity of the observed data
moneyness = np.linspace(0.85, 1.15, 5)  # Moneyness
maturities = np.linspace(0.5, 2.0, 7)   # Time to maturity
r = 0.03
#params = 



# Pre-trained ANN that maps Heston parameters to implied volatilities
def heston_ann(parameters):
    """
    A mock function representing the ANN (pre-trained forward pass).
    In real scenarios, this will return ANN-predicted implied volatilities.
    """
    # Example: Simple mapping for illustration
    rho, kappa, gamma, nu_bar, nu_0 = parameters
    return 0.25 + 0.05 * (moneyness - 1.0) + 0.02 * (maturities - 1.0)

# Objective function for DE calibration
def calibration_objective(parameters):
    """
    Calculates the mean squared error between ANN-predicted
    and observed market volatilities.
    """
    predicted_vols = implied_vol_pipe2
    error = np.mean((predicted_vols - observed_vols) ** 2)
    return error

# %%
bounds = [
    (-0.75, -0.25),   # rho (correlation)
    (0.5, 1.0),    # kappa (mean reversion speed)
    (0.3, 0.5),   # gamma (volatility of variance)
    (0.15, 0.35),   # nu_bar (long-run variance)
    (0.5, 1.0)    # nu_0 (initial variance)
]

# %%
from scipy.optimize import differential_evolution

# Run DE to calibrate the Heston parameters
result = differential_evolution(
    calibration_objective,  # Objective function
    bounds,                 # Parameter bounds
    strategy="best1bin",    # Strategy for mutation
    popsize=50,             # Population size
    mutation=(0.5, 1.0),    # Mutation range
    recombination=0.7,      # Crossover probability
    tol=0.01,               # Convergence tolerance
    disp=True               # Display optimization progress
)

# Display calibrated parameters
print("Calibrated Parameters:", result.x)
print("Objective Function Value:", result.fun)

# %%
# Function to calculate implied volatility using Brent's method
def calc_implied_vol(dataset):
    """
    Computes implied volatilities using the Brent method.
    :param dataset: numpy array containing [S/K, T, r, OptionPrice].
    :return: A single implied volatility value.
    """
    money, T, r, market_price = dataset

    def bs_price(sigma):
        """Black-Scholes option price difference function."""
        d1 = (np.log(money) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
        d2 = d1 - sigma * np.sqrt(T)
        theoretical_price = money * norm.cdf(d1) - np.exp(-r * T) * norm.cdf(d2)
        return theoretical_price - market_price

    # Solve for implied volatility
    try:
        return optimize.brentq(bs_price, 1e-5, 5, maxiter=100)
    except ValueError:
        return np.nan  # Return NaN if Brent fails to converge

# Data generation or loading
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds=l_bounds, u_bounds=u_bounds)
hs_data_loader = DataLoader(hs_dataset, batch_size=4048)

# Step 1: Compute prices using Heston-ANN
predicted_prices = []
with torch.no_grad():
    for data in hs_data_loader:
        inputs = data[:, :-1].to(device)  # Exclude the last column if it's labels
        outputs = loaded_Heston_ANN(inputs)
        predicted_prices.append(outputs.cpu().numpy())
predicted_prices = np.concatenate(predicted_prices)

# Step 2: Prepare the dataset for Brent's method
# Combine predicted prices with necessary inputs for implied volatility calculation
# Assuming hs_dataset.data contains [S/K, T, r, actual_price]:
hs_dataset_data = hs_dataset.data[:, np.array([0, 1, 2])]  # Extract relevant columns
hs_dataset_data = np.hstack((hs_dataset_data, predicted_prices.reshape(-1, 1)))

# Step 3: Calculate implied volatilities
implied_volatilities = np.apply_along_axis(calc_implied_vol, 1, hs_dataset_data)

# Step 4: Evaluate results
# Assuming you have ground-truth implied volatilities for comparison
ground_truth_vol = hs_dataset.data[:, 3]  # Replace with actual column for ground truth
mse = ((ground_truth_vol - implied_volatilities) ** 2).mean()
print(f"MSE: {mse:.6e}")

# %%
# Loading Train / Test Data
hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0]-train_size])
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}
train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs, targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs, targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs, targets)) )
print("R2 {:e}".format(r2_score(outputs, targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs, targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs, targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs, targets)) )
print("R2 {:e}".format(r2_score(outputs, targets)) )

# %%
np.sqrt(1.670718e-07)
print("MSE {:e}".format(np.sqrt(1.670718e-07)) )

# %% [markdown]
# # DOWN FROM HERE EVERYTHING IS ONLY FOR LOOK UP PURPOSES

# %% [markdown]
# # 5) BRENT

# %% [markdown]
# # 6) Pipeline 1: COS + BRENT

# %%
eps = 1e-2 # is used to generate open intervals
# (S/K), (tau), (r), (rho), (kappa), (vbar), (gamma), (v0).
# CASE 1 in table 11
l_bounds = [.75+eps, .4+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps]
u_bounds = [1.25-eps, 1.0-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds = l_bounds, u_bounds=u_bounds)
hs_dataset_data = hs_dataset.data
hs_dataset_data = hs_dataset_data[:,np.array([0,1,2,8])]
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, hs_dataset_data)

# %% [markdown]
# # 7) Pipeline 2: Heston-ANN + IV-ANN

# %%
# Loading model
device = torch.device("cuda")
loaded_Heston_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_ANN.pt"
loaded_Heston_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_ANN.eval()

# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

# Loading model 
device = torch.device("cuda")
loaded_IV_ANN = IV_ANN().to(device)
PATH = "ANN_weights/IV_SCALED_ANN.pt"
loaded_IV_ANN.load_state_dict(torch.load(PATH))
loaded_IV_ANN.eval()


# Plugging in the Heston-ANN prices
hs_dataset2 = hs_dataset.data[:,np.array([0,1,2,8])]
hs_dataset2.data[:,3] = torch.FloatTensor(prices)
loader2 = torch.utils.data.DataLoader(hs_dataset2, 4048)

# Computing IVs
implied_vol = []
indecies_list = []
with torch.no_grad():
  for idx, data in enumerate(loader2):
    data = data.to(device)
    # LOG Transformation
    data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
    data[:,3] = torch.log(data[:,3])
    output = loaded_IV_ANN(data)
    implied_vol.append((output).data.cpu().numpy())
  implied_vol_pipe2 = np.concatenate(implied_vol)
  # indecies_list = np.concatenate(indecies_list).flatten()

# %%
# Eliminating Nan values resulting from prices lower than 1e-7
indecies = np.argwhere(np.isnan(implied_vol_pipe2))
implied_vol_pipe1 = np.delete(implied_vol_pipe1, indecies,0)
implied_vol_pipe2 = np.delete(implied_vol_pipe2, indecies,0)

# %% [markdown]
# # 8) Pipeline 1 VS pipeline 2

# %%
# CASE 1
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
#targets = vol_imp
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )

# %%
# CASE 2
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )

# %% [markdown]
# # 9) Volatility surface (COS + IV-ANN)

# %% [markdown]
# ### Initial volatility surface

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
moyeness = np.linspace(moyeness, 1.24,11)
tau = np.linspace(tau, 1, 6)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(66)).reshape((-1, 1))

# %%
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  bs_IV = (output).data.cpu().numpy()

X = X.flatten()
Y = Y.flatten()
Z = bs_IV

x = np.reshape(X, (-1, 6))
y = np.reshape(Y, (-1, 6))
z = np.reshape(Z, (-1, 6))

# %%
from mpl_toolkits import mplot3d
from matplotlib import cm

# %%
# Plotting the initial volatility surface
plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to matuirity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Smoothing the volatility surface

# %%
from scipy import interpolate

# %%
# Smoothing the volatility surface
xnew, ynew = x.copy(), y.copy()
tck = interpolate.bisplrep(x, y, z, s=1.0)
znew = interpolate.bisplev(xnew[:,0], ynew[0,:], tck)

plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(xnew, ynew, znew,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to maturity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Implied volatility difference

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
n_moneyness = 11
n_tau = 6
moyeness = np.linspace(moyeness, 1.24,n_moneyness)
tau = np.linspace(tau, 1, n_tau)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
rho = np.array(rho*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
kappa = np.array(kappa*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
vbar = np.array(vbar*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
gamma = np.array(gamma*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
v0 = np.array(v0*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(n_tau * n_moneyness)).reshape((-1, 1))

# %%
data_ann = np.concatenate((X, Y, r, rho, kappa, vbar, gamma, v0, cos_prices), axis = 1)
data_ann = torch.FloatTensor(data_ann)
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  implied_vol_pipe2 = (output).data.cpu().numpy()

# %%
X = X.flatten()
Y = Y.flatten()
Z = (implied_vol_pipe1 - implied_vol_pipe2).flatten()

x = np.reshape(X, (-1, min(n_moneyness, n_tau)))
y = np.reshape(Y, (-1, min(n_moneyness, n_tau)))
z = np.reshape(Z, (-1, min(n_moneyness, n_tau)))

plt.figure(figsize=(8,8))
plt.pcolormesh(x, y, z, shading='gouraud')
plt.colorbar()
plt.xlabel("Moneyness")
plt.ylabel("Time to maturity")
plt.show()

# %%
# Re-import necessary libraries and re-define the setup after reset
from scipy.optimize import differential_evolution
import numpy as np

# Define the objective function
def objective_function(x):
    # Example: A simple quadratic function
    return x[0]**2 + x[1]**2 + x[2]**2

# Define the bounds for each variable
bounds = [(-10, 10), (-10, 10), (-10, 10)]  # Variable bounds for a 3D problem

# Run Differential Evolution with the specified settings
result_custom_de = differential_evolution(
    objective_function,  # Objective function
    bounds,             # Variable bounds
    strategy="best1bin",  # Strategy
    popsize=50,          # Population size
    mutation=(0.5, 1.0), # Mutation range
    recombination=0.7,   # Crossover probability
    tol=0.01,            # Convergence tolerance
    disp=False           # Suppress output during the run
)

# Display the result
result_custom_de
