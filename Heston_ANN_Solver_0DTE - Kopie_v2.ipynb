# %% [markdown]
# # Pricing 0DTE put options and computing implied volatilities using neural networks

# %%
import numpy as np

def sinc_disc_ft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, N, CP, opt_type):
    """
    Compute CoN, AoN, and Plain Vanilla put/call prices using the FT-version of the SINC formula.
    
    Parameters:
        S (float): Current spot price
        t (float): Time to maturity
        K (array): Strike prices
        IR (float): Interest rate
        DY (float): Dividend yield
        model (str): Model type ('Heston', 'Rough Heston', etc.)
        params (list): Model parameters
        xi (array): Forward variance curve
        j (int): Number of variance steps
        Xc (float): Truncation boundary
        Xm (float): Shift in truncation
        N (int): Number of Fourier points
        CP (int): Call (+1) or put (-1)
        opt_type (int): Type of option (e.g., 1 for call, -1 for put, etc.)
        
    Returns:
        numpy.ndarray: Option prices based on the specified type
    """
    # Ensure K is a row vector
    K = np.array(K).flatten()

    # Truncation range
    Xl = -Xc + Xm
    Xh = Xc + Xm

    # Length of truncation range
    wid = Xh - Xl  # 2 * Xc

    # Fourier modes for CoN put
    n = np.arange(1, N//2 + 1, 2)  # Odd indices
    wn = n / wid

    # Log-strike with Xm shift
    k = np.log(K / S) - (IR - DY) * t - Xm

    # Compute sin and cos in the formula
    sn = np.sin(2 * np.pi * np.outer(k, wn))
    cs = np.cos(2 * np.pi * np.outer(k, wn))

    # CF at points wn for CoN put
    f1 = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun(model, params, xi, j, 2 * np.pi * wn, t)
    # CF at points wn - 1i/(2*pi) for AoN put
    f2 = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun(model, params, xi, j, 2 * np.pi * wn - 1j, t)

    # Compute sums in eq. (8) and (9) for CoN and AoN put
    ad1 = np.sum((sn * np.real(f1) - cs * np.imag(f1)) / n, axis=1)
    ad2 = np.sum((sn * np.real(f2) - cs * np.imag(f2)) / n, axis=1)

    # CoN and AoN put prices
    conP = K * np.exp(-IR * t) * (0.5 + (2 / np.pi) * ad1)
    aonP = S * np.exp(-DY * t) * (0.5 + (2 / np.pi) * ad2)

    # Put price as linear combination of digital options
    put = conP - aonP  # eq. (1)

    # Call price from put-call parity
    call = put + S * np.exp(-DY * t) - K * np.exp(-IR * t)

    # Digital call options
    conC = K * np.exp(-IR * t) - conP
    aonC = S * np.exp(-DY * t) - aonP

    # Output based on option type
    if CP * opt_type == 1:
        return call
    elif CP * opt_type == -1:
        return put
    elif CP * opt_type == 2:
        return conC
    elif CP * opt_type == -2:
        return conP
    elif CP * opt_type == 3:
        return aonC
    elif CP * opt_type == -3:
        return aonP

# %%
import numpy as np

def charfun(model, params, xi, n, u, t):
    """
    Computes the characteristic function for a given model.

    Parameters:
        model (str): The model type ('Heston' or 'rough Heston').
        params (list): Model parameters.
                      - Heston: [lambda, v_bar, eta, v0, rho]
                      - Rough Heston: [H, nu, rho]
        xi (array): Forward variance curve (for Rough Heston).
        n (int): Number of variance steps (for Rough Heston).
        u (array): Fourier transform variable.
        t (float): Time to maturity.
        
    Returns:
        numpy.ndarray: Characteristic function values.
    """
    if model == 'Heston':
        lambda_, v_bar, eta, v0, rho = params
        
        beta = lambda_ - rho * eta * 1j * u
        alpha = -0.5 * u**2 - 0.5 * 1j * u
        zeta = 0.5 * eta**2

        d = np.sqrt(beta**2 - 4 * alpha * zeta)

        rm = (beta - d) / eta**2
        rp = (beta + d) / eta**2

        g = rm / rp

        C = rm * t - (2 / eta**2) * np.log((1 - g * np.exp(-d * t)) / (1 - g))
        D = rm * (1 - np.exp(-d * t)) / (1 - g * np.exp(-d * t))

        phi = np.exp(v_bar * lambda_ * C + v0 * D)
        return phi

    elif model == 'rough Heston':
        H, nu, rho = params

        alpha = H + 0.5
        ti = np.arange(n) / n * t
        y = nu * ti**alpha

        # Coefficients for Padé approximants
        rm, rp, p1, p2, p3, q1, q2, q3 = dh_pade33_coeff(alpha, rho, u)

        charFun = np.zeros(len(u), dtype=complex)
        for j in range(len(u)):
            dah = dh_pade33(y, rm[j], rp[j], p1[j], p2[j], p3[j], q1[j], q2[j], q3[j])
            charFun[j] = np.exp(np.dot(np.flip(xi), dah) * t / n)

        return charFun

    else:
        raise ValueError(f"Model '{model}' is not supported. Use 'Heston' or 'rough Heston'.")

# %%
def dh_pade33_coeff(alpha, rho, u):
    """
    Computes the coefficients for the Padé(3,3) approximant.

    Parameters:
        alpha (float): Fractional exponent (H + 0.5).
        rho (float): Correlation coefficient.
        u (array): Fourier transform variable.
        
    Returns:
        tuple: Coefficients (rm, rp, p1, p2, p3, q1, q2, q3).
    """
    rm = -alpha + rho * 1j * u
    rp = alpha + rho * 1j * u

    p1 = rm**2
    p2 = rm * rp
    p3 = rp**2

    q1 = 1 + rp**2
    q2 = 2 * rm * rp
    q3 = 1 + rm**2

    return rm, rp, p1, p2, p3, q1, q2, q3

def dh_pade33(y, rm, rp, p1, p2, p3, q1, q2, q3):
    """
    Computes the Padé(3,3) approximation.

    Parameters:
        y (array): Time steps for the fractional Riccati equation.
        rm, rp, p1, p2, p3, q1, q2, q3 (float): Padé coefficients.
        
    Returns:
        numpy.ndarray: Approximated values.
    """
    numerator = p1 * y**3 + p2 * y**2 + p3 * y
    denominator = q1 * y**3 + q2 * y**2 + q3 * y + 1
    return numerator / denominator

# %%
import numpy as np
from scipy.interpolate import interp1d

def sinc_fast_ft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, pow, CP):
    """
    Computes plain vanilla put/call prices using the FFT-version of the SINC formula.

    Parameters:
        S (float): Current spot price.
        t (float): Time to maturity.
        K (array): Strike prices.
        IR (float): Interest rate.
        DY (float): Dividend yield.
        model (str): Model type ('Heston' or 'rough Heston').
        params (list): Model parameters.
        xi (array): Forward variance curve.
        j (int): Number of variance steps.
        Xc (float): Truncation boundary.
        Xm (float): Shift in truncation.
        pow (int): Power of 2 for FFT grid size (N = 2^pow).
        CP (int): Call (+1) or Put (-1).

    Returns:
        numpy.ndarray: Option prices for the given strikes.
    """
    # Ensure K is a flat array
    K = np.array(K).flatten()

    # Number of Fourier modes for European prices
    N = 2**pow

    # Truncation range
    Xl = -Xc + Xm
    Xh = Xc + Xm

    # Length of truncation range
    wid = Xh - Xl  # 2 * Xc

    # Sampled Fourier modes for CoN put
    n = np.arange(1, N//2 + 1, 2)  # Odd indices
    wn = n / wid

    # Weights for positive odd frequencies
    Il = 2 / n

    # Characteristic function at points wn for CoN put
    f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun(model, params, xi, j, 2 * np.pi * wn, t)
    # and wn - 1i/(2*pi) for AoN put (exponential shift included)
    f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun(model, params, xi, j, 2 * np.pi * wn - 1j, t)

    # Set even frequencies to zero
    q1l = np.zeros(N//2, dtype=complex)
    q1l[1::2] = f1l * Il
    q2l = np.zeros(N//2, dtype=complex)
    q2l[1::2] = f2l * Il

    # Weights for negative odd frequencies
    Iu = -np.flip(Il)

    # Characteristic function at points -wn for CoN put
    f1u = np.flip(np.conj(f1l))
    # and -[wn - 1i/(2*pi)] for AoN put (exponential shift included)
    f2u = np.flip(np.conj(f2l))

    # Set even frequencies to zero
    q1u = np.zeros(N//2, dtype=complex)
    q1u[0::2] = f1u * Iu
    q2u = np.zeros(N//2, dtype=complex)
    q2u[0::2] = f2u * Iu

    # Rearrange positive and negative frequencies for FFT
    q1 = 1j / (2 * np.pi) * np.concatenate([q1l, [0], q1u[:-1]])
    q2 = 1j / (2 * np.pi) * np.concatenate([q2l, [0], q2u[:-1]])

    # Apply FFT
    d1 = np.fft.fft(q1) + 0.5
    d2 = np.fft.fft(q2) + 0.5

    # Extract positive and negative parts
    d11, d12 = d1[:N//2], d1[N//2:]
    d21, d22 = d2[:N//2], d2[N//2:]

    dd1 = np.concatenate([d12, d11])
    dd2 = np.concatenate([d22, d21])

    # Define a strike grid
    m = np.arange(-N//2, N//2)
    # Compute strike buckets (shift Xm included)
    km = m * wid / N + (IR - DY) * t + Xm
    Km = S * np.exp(km)

    # Price CoN and AoN put over the buckets
    conP = np.exp(-IR * t) * np.real(Km * dd1)
    aonP = np.exp(-DY * t) * np.real(S * dd2)

    # Interpolate on the desired strikes
    conP_interp = interp1d(Km, conP, kind='linear', fill_value="extrapolate")
    aonP_interp = interp1d(Km, aonP, kind='linear', fill_value="extrapolate")

    conP = conP_interp(K)
    aonP = aonP_interp(K)

    # Put price as a linear combination of digital options
    put = conP - aonP  # Eq. (1)

    # Call price from put-call parity
    call = put + S * np.exp(-DY * t) - K * np.exp(-IR * t)

    if CP == 1:
        return call
    elif CP == -1:
        return put

# %%
import numpy as np
from scipy.stats import norm

def bs_implied_vol_put(S, K, T, r, P):
    """
    Computes the implied volatility of European put options using bisection.

    Parameters:
        S (float): Spot price
        K (array): Strike prices
        T (float): Time to maturity
        r (float): Risk-free interest rate
        P (array): Market put prices

    Returns:
        numpy.ndarray: Implied volatilities for the given strikes
    """
    n = len(K)
    
    # Low and high bounds for volatility
    sigmaL = 1e-10 * np.ones(n)
    PL = bs_formula_put(S, K, T, r, sigmaL)

    sigmaH = 10 * np.ones(n)
    PH = bs_formula_put(S, K, T, r, sigmaH)
    
    # Iteratively refine sigma bounds
    while np.mean(sigmaH - sigmaL) > 1e-10:
        sigma = (sigmaL + sigmaH) / 2
        PM = bs_formula_put(S, K, T, r, sigma)
        
        # Adjust bounds
        mask = PM < P
        PL = np.where(mask, PM, PL)
        sigmaL = np.where(mask, sigma, sigmaL)

        mask = PM >= P
        PH = np.where(mask, PM, PH)
        sigmaH = np.where(mask, sigma, sigmaH)
    
    return sigma


def bs_formula_put(S, K, T, r, sigma):
    """
    Computes the Black-Scholes price for European put options.

    Parameters:
        S (float): Spot price
        K (array): Strike prices
        T (float): Time to maturity
        r (float): Risk-free interest rate
        sigma (array): Volatilities

    Returns:
        numpy.ndarray: Black-Scholes put prices
    """
    x = np.log(S / K) + r * T
    sig = sigma * np.sqrt(T)
    d1 = x / sig + sig / 2
    d2 = d1 - sig
    pv = np.exp(-r * T)
    
    put = pv * K * norm.cdf(-d2) - S * norm.cdf(-d1)
    return put

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from scipy.fft import fft, ifft

# Load the CSV file using the csv module with a semicolon delimiter
data = []
with open('spx_surf20130814.csv', 'r', encoding='utf-8-sig') as file:  # Use 'utf-8-sig' to handle BOM
    reader = csv.DictReader(file, delimiter=';')
    for row in reader:
        data.append(row)

# Extract actual column names and strip whitespace/BOM from keys
columns = list(data[0].keys())
structured_data = {col.lstrip('\ufeff').strip(): np.array([float(row[col]) for row in data]) for col in columns}

# Extract unique maturities
expiries = np.unique(structured_data['t'])  # Adjust column name based on output

# Heston model parameters (example values, adjust as needed)
lambda_ = 1.5768
v_bar = 0.0398
eta = 0.5751
v0 = 0.0157
rho = -0.5711
params = [lambda_, v_bar, eta, v0, rho]

# Market and model settings
IR = 0  # Risk-free rate
DY = 0  # Dividend yield
Xc = 4  # Truncation range (example)
Xm = 0  # No shift
pow = 14  # Grid size 2^pow
CP = -1  # Put (-1)

# Define the SINC Fast Fourier Transform (FFT) function
def sinc_fast_ft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, pow, CP):
    # Fourier grid settings
    N = 2 ** pow  # Number of points in the FFT grid
    k = np.log(K / S)  # Log-moneyness
    L = np.max(k) - np.min(k)  # Total range of log-moneyness
    dx = L / N  # Grid spacing
    x = np.linspace(np.min(k) - dx / 2, np.max(k) + dx / 2, N)  # Grid points
    
    # Calculate the characteristic function (CF) for the Heston model
    cf = np.zeros(N, dtype=complex)
    for i in range(N):
        # Heston characteristic function (placeholder)
        cf[i] = np.exp(-1j * x[i] * np.log(S))  # This is a placeholder; replace with real CF calculation
    
    # Fourier transform of the option price
    option_price = np.real(ifft(cf)) * np.exp(-x * Xc)  # Apply inverse FFT
    
    # Return the option price
    return option_price

# Define the Black-Scholes implied volatility calculation for put options
def bs_implied_vol_put(S, K, t, r, price):
    # Placeholder for implied volatility calculation based on Black-Scholes
    # This function should be replaced by an actual implementation
    return np.full_like(price, 0.2)  # Assume 20% volatility for simplicity

# Prepare output arrays
errors = []

# Iterate through the maturities and calculate prices
for expiry in expiries:
    subset_indices = structured_data['t'] == expiry
    fwd = structured_data['fwd'][subset_indices][0]  # Forward price
    t = expiry  # Maturity
    K = structured_data['K'][subset_indices]  # Strike prices
    impVol_bench = structured_data['impVol'][subset_indices]  # Benchmark implied volatilities

    # Run SINC FFT pricing
    prices = sinc_fast_ft(S=fwd, t=t, K=K, IR=IR, DY=DY, model='Heston', params=params,
                          xi=None, j=0, Xc=Xc, Xm=Xm, pow=pow, CP=CP)
    
    # Compute implied volatilities from prices (requires a BSImpliedVolPut function)
    impVol_model = bs_implied_vol_put(fwd, K, t, IR, prices)

    # Compute error
    error = np.mean(np.abs(impVol_model - impVol_bench))
    errors.append(error)

    print(f"Maturity: {t}, Mean Absolute Error: {error}")

# Plot errors
plt.figure(figsize=(10, 6))
plt.plot(expiries, errors, marker='o', label='Mean Absolute Error')
plt.xlabel('Expiry')
plt.ylabel('Error')
plt.title('Mean Absolute Error vs Expiry (Heston FFT)')
plt.legend()
plt.grid(True)
plt.show()

# Plot the option prices (SINC FFT method)
plt.figure(figsize=(10, 6))
for expiry in expiries:
    subset_indices = structured_data['t'] == expiry
    fwd = structured_data['fwd'][subset_indices][0]  # Forward price
    t = expiry  # Maturity
    K = structured_data['K'][subset_indices]  # Strike prices
    prices = sinc_fast_ft(S=fwd, t=t, K=K, IR=IR, DY=DY, model='Heston', params=params,
                          xi=None, j=0, Xc=Xc, Xm=Xm, pow=pow, CP=CP)
    plt.plot(K, prices, label=f"Expiry {t}")

plt.xlabel('Strike Price')
plt.ylabel('Option Price')
plt.title('Option Prices (SINC FFT Method)')
plt.legend()
plt.grid(True)
plt.show()

# Plot the volatility smile (implied volatility as a function of strike)
plt.figure(figsize=(10, 6))
for expiry in expiries:
    subset_indices = structured_data['t'] == expiry
    fwd = structured_data['fwd'][subset_indices][0]  # Forward price
    t = expiry  # Maturity
    K = structured_data['K'][subset_indices]  # Strike prices
    impVol_bench = structured_data['impVol'][subset_indices]  # Benchmark implied volatilities
    plt.plot(K, impVol_bench, label=f"Expiry {t}")

plt.xlabel('Strike Price')
plt.ylabel('Implied Volatility')
plt.title('Implied Volatility Smile')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 82
#      79 impVol_model = bs_implied_vol_put(fwd, K, t, IR, prices)
#      81 # Compute error
# ---> 82 error = np.mean(np.abs(impVol_model - impVol_bench))
#      83 errors.append(error)
#      85 print(f"Maturity: {t}, Mean Absolute Error: {error}")
#
# ValueError: operands could not be broadcast together with shapes (16384,) (34,)

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# Function to compute prices using FFT-SINC (simplified placeholder implementation)
def sinc_fast_ft(S, t, K, IR, DY, model, params, Xc, Xm, pow, CP):
    """
    Compute option prices using FFT-SINC method.
    S : float : Forward price
    t : float : Maturity
    K : ndarray : Strike prices
    IR : float : Risk-free rate
    DY : float : Dividend yield
    model : str : Name of the model ('Heston' in this case)
    params : list : Model-specific parameters
    Xc : float : Truncation range
    Xm : float : Shift (not used here, assumed 0)
    pow : int : Power for grid size (2^pow)
    CP : int : Call/Put flag (-1 for put, +1 for call)
    """
    # Generate grid in Fourier space
    N = 2 ** pow
    delta_k = 2 * Xc / N
    u = np.arange(0, N) * delta_k - Xc  # Symmetric grid centered at 0

    # Model-specific characteristic function
    if model.lower() == 'heston':
        lambda_, v_bar, eta, v0, rho = params
        xi = u + 1j * 0.5  # Add a small imaginary component for stability
        cf = np.exp(-1j * xi * Xm)  # Placeholder for characteristic function
    else:
        raise ValueError("Unsupported model")

    # Compute FFT of the characteristic function
    fft_prices = np.fft.fft(cf * np.exp(-1j * u * Xm) * delta_k)
    fft_prices = np.real(np.fft.fftshift(fft_prices))

    # Interpolate prices to match strikes
    strikes = np.exp(u)
    prices = np.interp(K, strikes, fft_prices)

    # Adjust for put/call
    if CP == -1:  # Put
        prices = np.maximum(K - S, 0) + np.exp(-IR * t) * prices
    elif CP == 1:  # Call
        prices = np.maximum(S - K, 0) + np.exp(-IR * t) * prices
    return prices

# Function to compute implied volatility (placeholder)
def bs_implied_vol_put(fwd, K, t, IR, prices):
    """
    Compute implied volatility using Black-Scholes formula.
    Placeholder function: Returns a dummy smile.
    """
    return 0.2 + 0.1 * (K / fwd - 1)

# Load the CSV file
data = []
with open('spx_surf20130814.csv', 'r', encoding='utf-8-sig') as file:
    reader = csv.DictReader(file, delimiter=';')
    for row in reader:
        data.append(row)

# Process structured data
columns = list(data[0].keys())
structured_data = {col.lstrip('\ufeff').strip(): np.array([float(row[col]) for row in data]) for col in columns}

# Extract unique maturities
expiries = np.unique(structured_data['t'])

# Model parameters
lambda_ = 1.5768
v_bar = 0.0398
eta = 0.5751
v0 = 0.0157
rho = -0.5711
params = [lambda_, v_bar, eta, v0, rho]
IR = 0  # Risk-free rate
DY = 0  # Dividend yield
Xc = 4  # Truncation range
Xm = 0  # Shift
pow = 14  # Grid size 2^pow
CP = -1  # Put

# Prepare output arrays
all_prices = []
all_vols = []

# Main loop over expiries
for expiry in expiries:
    subset_indices = structured_data['t'] == expiry
    fwd = structured_data['fwd'][subset_indices][0]  # Forward price
    t = expiry  # Maturity
    K = structured_data['K'][subset_indices]  # Strike prices
    impVol_bench = structured_data['impVol'][subset_indices]  # Benchmark implied volatilities

    # Run SINC FFT pricing
    prices = sinc_fast_ft(S=fwd, t=t, K=K, IR=IR, DY=DY, model='Heston', params=params,
                          Xc=Xc, Xm=Xm, pow=pow, CP=CP)
    
    # Compute implied volatilities from prices
    impVol_model = bs_implied_vol_put(fwd, K, t, IR, prices)

    # Store results
    all_prices.append((K, prices))
    all_vols.append((K, impVol_model))

# Plot option prices
plt.figure(figsize=(10, 6))
for K, prices in all_prices:
    plt.plot(K, prices, label=f"Prices (Expiry={t:.2f})")
plt.xlabel("Strike Price")
plt.ylabel("Option Price")
plt.title("Option Prices (FFT-SINC)")
plt.legend()
plt.grid()
plt.show()

# Plot implied volatility smile
plt.figure(figsize=(10, 6))
for K, vols in all_vols:
    plt.plot(K, vols, label=f"Smile (Expiry={t:.2f})")
plt.xlabel("Strike Price")
plt.ylabel("Implied Volatility")
plt.title("Implied Volatility Smile (FFT-SINC)")
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from scipy.fft import fft, ifft

# Load the CSV file using the csv module with a semicolon delimiter
data = []
with open('spx_surf20130814.csv', 'r', encoding='utf-8-sig') as file:
    reader = csv.DictReader(file, delimiter=';')
    for row in reader:
        data.append(row)

# Extract actual column names and strip whitespace/BOM from keys
columns = list(data[0].keys())
structured_data = {col.lstrip('\ufeff').strip(): np.array([float(row[col]) for row in data]) for col in columns}

# Extract unique maturities
expiries = np.unique(structured_data['t'])  # Adjust column name based on output

# Heston model parameters (example values, adjust as needed)
lambda_ = 1.5768
v_bar = 0.0398
eta = 0.5751
v0 = 0.0157
rho = -0.5711
params = [lambda_, v_bar, eta, v0, rho]

# Market and model settings
IR = 0  # Risk-free rate
DY = 0  # Dividend yield
Xc = 4  # Truncation range (example)
Xm = 0  # No shift
pow = 14  # Grid size 2^pow
CP = -1  # Put (-1)

# Define the SINC Fast Fourier Transform (FFT) function
def sinc_fast_ft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, pow, CP):
    # Fourier grid settings
    N = 2 ** pow  # Number of points in the FFT grid
    k = np.log(K / S)  # Log-moneyness
    L = np.max(k) - np.min(k)  # Total range of log-moneyness
    dx = L / N  # Grid spacing
    x = np.linspace(np.min(k) - dx / 2, np.max(k) + dx / 2, N)  # Grid points
    
    # Calculate the characteristic function (CF) for the Heston model
    cf = np.zeros(N, dtype=complex)
    for i in range(N):
        # Heston characteristic function (placeholder)
        cf[i] = np.exp(-1j * x[i] * np.log(S))  # Placeholder; replace with real CF calculation
    
    # Fourier transform of the option price
    option_price = np.real(ifft(cf)) * np.exp(-x * Xc)  # Apply inverse FFT
    
    # Return the option price and grid points
    return option_price, x

# Prepare output arrays
errors = []

# Plot Xn for the first expiry
expiry = expiries[0]
subset_indices = structured_data['t'] == expiry
fwd = structured_data['fwd'][subset_indices][0]  # Forward price
t = expiry  # Maturity
K = structured_data['K'][subset_indices]  # Strike prices

# Run SINC FFT pricing and extract Xn
prices, Xn = sinc_fast_ft(S=fwd, t=t, K=K, IR=IR, DY=DY, model='Heston', params=params,
                          xi=None, j=0, Xc=Xc, Xm=Xm, pow=pow, CP=CP)

# Plot Xn (Fourier grid points for log-moneyness)
plt.figure(figsize=(10, 6))
plt.plot(Xn, label="Fourier Grid Points (Xn)")
plt.xlabel('Index')
plt.ylabel('Xn (Log-Moneyness Grid Points)')
plt.title('Fourier Grid Points (Xn) for Log-Moneyness')
plt.legend()
plt.grid(True)
plt.show()

# Plot the option prices for this expiry
plt.figure(figsize=(10, 6))
plt.plot(K, prices, label=f"Option Prices for Expiry {t}")
plt.xlabel('Strike Price')
plt.ylabel('Option Price')
plt.title('Option Prices (SINC FFT Method)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 83
#      81 # Plot the option prices for this expiry
#      82 plt.figure(figsize=(10, 6))
# ---> 83 plt.plot(K, prices, label=f"Option Prices for Expiry {t}")
#      84 plt.xlabel('Strike Price')
#      85 plt.ylabel('Option Price')
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (34,) and (16384,)

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from scipy.fft import fft, ifft
from scipy.interpolate import interp1d

# Load the CSV file using the csv module with a semicolon delimiter
data = []
with open('spx_surf20130814.csv', 'r', encoding='utf-8-sig') as file:
    reader = csv.DictReader(file, delimiter=';')
    for row in reader:
        data.append(row)

# Extract actual column names and strip whitespace/BOM from keys
columns = list(data[0].keys())
structured_data = {col.lstrip('\ufeff').strip(): np.array([float(row[col]) for row in data]) for col in columns}

# Extract unique maturities
expiries = np.unique(structured_data['t'])  # Adjust column name based on output

# Heston model parameters (example values, adjust as needed)
lambda_ = 1.5768
v_bar = 0.0398
eta = 0.5751
v0 = 0.0157
rho = -0.5711
params = [lambda_, v_bar, eta, v0, rho]

# Market and model settings
IR = 0  # Risk-free rate
DY = 0  # Dividend yield
Xc = 4  # Truncation range (example)
Xm = 0  # No shift
pow = 14  # Grid size 2^pow
CP = -1  # Put (-1)

# Define the SINC Fast Fourier Transform (FFT) function
def sinc_fast_ft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, pow, CP):
    # Fourier grid settings
    N = 2 ** pow  # Number of points in the FFT grid
    dk = 2 * np.pi / (N * (Xc - Xm))  # Fourier step
    k_grid = np.linspace(-N / 2, N / 2 - 1, N) * dk  # Fourier grid points
    
    # Log-moneyness range
    x = np.linspace(-Xc, Xc, N)
    
    # Placeholder for characteristic function (real implementation needed)
    cf = np.exp(-1j * x * np.log(S))  # Dummy CF; replace with actual Heston CF
    
    # Apply FFT to compute prices
    fft_prices = np.real(ifft(cf)) * np.exp(-x * Xc)  # Apply inverse FFT
    
    # Return the computed prices and the Fourier grid
    return fft_prices, x

# Choose the first expiry for the demonstration
expiry = expiries[0]
subset_indices = structured_data['t'] == expiry
fwd = structured_data['fwd'][subset_indices][0]  # Forward price
t = expiry  # Maturity
K = structured_data['K'][subset_indices]  # Strike prices

# Run SINC FFT pricing and extract grid points
prices, Xn = sinc_fast_ft(S=fwd, t=t, K=K, IR=IR, DY=DY, model='Heston', params=params,
                          xi=None, j=0, Xc=Xc, Xm=Xm, pow=pow, CP=CP)

# Interpolate prices to match strike prices
interpolator = interp1d(Xn, prices, kind='cubic', fill_value="extrapolate")
prices_interpolated = interpolator(np.log(K / fwd))  # Match the log-moneyness of strikes

# Plot Fourier grid points (Xn)
plt.figure(figsize=(10, 6))
plt.plot(Xn, label="Fourier Grid Points (Xn)")
plt.xlabel('Index')
plt.ylabel('Xn (Log-Moneyness Grid Points)')
plt.title('Fourier Grid Points (Xn) for Log-Moneyness')
plt.legend()
plt.grid(True)
plt.show()

# Plot interpolated option prices for this expiry
plt.figure(figsize=(10, 6))
plt.plot(K, prices_interpolated, label=f"Option Prices for Expiry {t}")
plt.xlabel('Strike Price')
plt.ylabel('Option Price')
plt.title('Option Prices (SINC FFT Method)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from scipy.fft import fft, ifft
from scipy.stats import norm
from scipy.interpolate import interp1d

# Load the CSV file using the csv module with a semicolon delimiter
data = []
with open('spx_surf20130814.csv', 'r', encoding='utf-8-sig') as file:
    reader = csv.DictReader(file, delimiter=';')
    for row in reader:
        data.append(row)

# Extract actual column names and strip whitespace/BOM from keys
columns = list(data[0].keys())
structured_data = {col.lstrip('\ufeff').strip(): np.array([float(row[col]) for row in data]) for col in columns}

# Extract unique maturities
expiries = np.unique(structured_data['t'])  # Adjust column name based on output

# Black-Scholes pricing function for puts
def black_scholes_put(S, K, T, r, sigma):
    """
    Black-Scholes formula for European put options
    S: Spot price
    K: Strike price
    T: Time to maturity
    r: Risk-free rate
    sigma: Volatility
    """
    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    put_price = K * np.exp(-r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)
    return put_price

# SINC Fast Fourier Transform (FFT) function
def sinc_fast_ft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, pow, CP):
    # Fourier grid settings
    N = 2 ** pow  # Number of points in the FFT grid
    dk = 2 * np.pi / (N * (Xc - Xm))  # Fourier step
    k_grid = np.linspace(-N / 2, N / 2 - 1, N) * dk  # Fourier grid points
    
    # Log-moneyness range
    x = np.linspace(-Xc, Xc, N)
    
    # Placeholder for characteristic function (real implementation needed)
    cf = np.exp(-1j * x * np.log(S))  # Dummy CF; replace with actual Heston CF
    
    # Apply FFT to compute prices
    fft_prices = np.real(ifft(cf)) * np.exp(-x * Xc)  # Apply inverse FFT
    
    # Return the computed prices and the Fourier grid
    return fft_prices, x

# Choose the first expiry for demonstration
expiry = expiries[0]
subset_indices = structured_data['t'] == expiry
fwd = structured_data['fwd'][subset_indices][0]  # Forward price
t = expiry  # Maturity
K = structured_data['K'][subset_indices]  # Strike prices
impVol = structured_data['impVol'][subset_indices]  # Implied volatilities

# Run SINC FFT pricing and extract grid points
prices, Xn = sinc_fast_ft(S=fwd, t=t, K=K, IR=0, DY=0, model='Heston', params=None,
                          xi=None, j=0, Xc=4, Xm=0, pow=14, CP=-1)

# Interpolate SINC FFT prices to strike prices
interpolator = interp1d(Xn, prices, kind='cubic', fill_value="extrapolate")
prices_interpolated = interpolator(np.log(K / fwd))  # Match the log-moneyness of strikes

# Calculate Black-Scholes prices using implied volatilities
bs_prices = black_scholes_put(S=fwd, K=K, T=t, r=0, sigma=impVol)

# Plot comparison of SINC FFT and Black-Scholes prices
plt.figure(figsize=(10, 6))
plt.plot(K, prices_interpolated, label="SINC FFT Prices", marker='o')
plt.plot(K, bs_prices, label="Black-Scholes Prices", linestyle='--')
plt.xlabel('Strike Price')
plt.ylabel('Option Price')
plt.title('Comparison of SINC FFT and Black-Scholes Prices')
plt.legend()
plt.grid(True)
plt.show()

# Plot percentage difference between SINC FFT and Black-Scholes prices
percentage_diff = 100 * (prices_interpolated - bs_prices) / bs_prices
plt.figure(figsize=(10, 6))
plt.plot(K, percentage_diff, label="Percentage Difference (%)", marker='x')
plt.xlabel('Strike Price')
plt.ylabel('Percentage Difference')
plt.title('Percentage Difference Between SINC FFT and Black-Scholes Prices')
plt.axhline(0, color='black', linestyle='--', linewidth=0.8)
plt.legend()
plt.grid(True)
plt.show()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# Load the CSV file using the csv module with a semicolon delimiter
data = []
with open('spx_surf20130814.csv', 'r', encoding='utf-8-sig') as file:  # Use 'utf-8-sig' to handle BOM
    reader = csv.DictReader(file, delimiter=';')
    for row in reader:
        data.append(row)

# Extract actual column names and strip whitespace/BOM from keys
columns = list(data[0].keys())
structured_data = {col.lstrip('\ufeff').strip(): np.array([float(row[col]) for row in data]) for col in columns}

# Extract unique maturities
expiries = np.unique(structured_data['t'])  # Adjust column name based on output

# Heston model parameters (example values, adjust as needed)
lambda_ = 1.5768
v_bar = 0.0398
eta = 0.5751
v0 = 0.0157
rho = -0.5711
params = [lambda_, v_bar, eta, v0, rho]

# Market and model settings
IR = 0  # Risk-free rate
DY = 0  # Dividend yield
Xc = 4  # Truncation range (example)
Xm = 0  # No shift
pow = 14  # Grid size 2^pow
CP = -1  # Put (-1)

# Prepare output arrays
errors = []

for expiry in expiries:
    subset_indices = structured_data['t'] == expiry
    fwd = structured_data['fwd'][subset_indices][0]  # Forward price
    t = expiry  # Maturity
    K = structured_data['K'][subset_indices]  # Strike prices
    impVol_bench = structured_data['impVol'][subset_indices]  # Benchmark implied volatilities

    # Run SINC FFT pricing
    prices = sinc_fast_ft(S=fwd, t=t, K=K, IR=IR, DY=DY, model='Heston', params=params,
                          xi=None, j=0, Xc=Xc, Xm=Xm, pow=pow, CP=CP)
    
    # Compute implied volatilities from prices (requires a BSImpliedVolPut function)
    impVol_model = bs_implied_vol_put(fwd, K, t, IR, prices)

    # Compute error
    error = np.mean(np.abs(impVol_model - impVol_bench))
    errors.append(error)

    print(f"Maturity: {t}, Mean Absolute Error: {error}")

# Plot errors
plt.figure(figsize=(10, 6))
plt.plot(expiries, errors, marker='o', label='Mean Absolute Error')
plt.xlabel('Expiry')
plt.ylabel('Error')
plt.title('Mean Absolute Error vs Expiry (Heston FFT)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Maturity: 0.008213552, Mean Absolute Error: 0.07085388212864585
# Maturity: 0.024640657, Mean Absolute Error: 0.07128734046406209
# Maturity: 0.043805613, Mean Absolute Error: 0.06127866913567592
# Maturity: 0.062970568, Mean Absolute Error: 0.054630234100175507
# Maturity: 0.082135524, Mean Absolute Error: 0.049950515355278315
# Maturity: 0.10403833, Mean Absolute Error: 0.05279829418909628
# Maturity: 0.128678987, Mean Absolute Error: 0.04674318297352246
# Maturity: 0.180698152, Mean Absolute Error: 0.04347929700356524
# Maturity: 0.257357974, Mean Absolute Error: 0.03551389200912555
# Maturity: 0.353182752, Mean Absolute Error: 0.029672677631802275
# Maturity: 0.380561259, Mean Absolute Error: 0.02840919721721339
# Maturity: 0.429842574, Mean Absolute Error: 0.028257542282296596
# Maturity: 0.602327173, Mean Absolute Error: 0.022387079300308546
# Maturity: 0.62696783, Mean Absolute Error: 0.02046479523750308
# Maturity: 0.851471595, Mean Absolute Error: 0.018158143043268824
# Maturity: 0.876112252, Mean Absolute Error: 0.015833579224937437
# Maturity: 1.349760438, Mean Absolute Error: 0.0138891493371375
# Maturity: 1.42642026, Mean Absolute Error: 0.011962806766084712
# Maturity: 2.346338125, Mean Absolute Error: 0.022706324645017713

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# Load the CSV file using the csv module with a semicolon delimiter
data = []
with open('spx_surf20130814.csv', 'r') as file:
    reader = csv.DictReader(file, delimiter=';')
    for row in reader:
        data.append(row)

# Extract actual column names and strip whitespace from keys
columns = list(data[0].keys())
structured_data = {col.strip(): np.array([float(row[col]) for row in data]) for col in columns}

# Extract unique maturities
expiries = np.unique(structured_data['t'])  # Adjust column name based on output

# Heston model parameters (example values, adjust as needed)
lambda_ = 1.5768
v_bar = 0.0398
eta = 0.5751
v0 = 0.0157
rho = -0.5711
params = [lambda_, v_bar, eta, v0, rho]

# Market and model settings
IR = 0  # Risk-free rate
DY = 0  # Dividend yield
Xc = 4  # Truncation range (example)
Xm = 0  # No shift
pow = 14  # Grid size 2^pow
CP = -1  # Put (-1)

# Prepare output arrays
errors = []

print(columns)
print(structured_data.keys())

for expiry in expiries:
    subset_indices = structured_data['t'] == expiry
    fwd = structured_data['fwd'][subset_indices][0]  # Forward price
    t = expiry  # Maturity
    K = structured_data['K'][subset_indices]  # Strike prices
    impVol_bench = structured_data['impVol'][subset_indices]  # Benchmark implied volatilities

    # Run SINC FFT pricing
    prices = sinc_fast_ft(S=fwd, t=t, K=K, IR=IR, DY=DY, model='Heston', params=params,
                          xi=None, j=0, Xc=Xc, Xm=Xm, pow=pow, CP=CP)
    
    # Compute implied volatilities from prices (requires a BSImpliedVolPut function)
    impVol_model = bs_implied_vol_put(fwd, K, t, IR, prices)

    # Compute error
    error = np.mean(np.abs(impVol_model - impVol_bench))
    errors.append(error)

    print(f"Maturity: {t}, Mean Absolute Error: {error}")

# Plot errors
plt.figure(figsize=(10, 6))
plt.plot(expiries, errors, marker='o', label='Mean Absolute Error')
plt.xlabel('Expiry')
plt.ylabel('Error')
plt.title('Mean Absolute Error vs Expiry (Heston FFT)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ['\ufefffwd', 't ', 'K', 'put', 'impVol']
# dict_keys(['\ufefffwd', 't', 'K', 'put', 'impVol'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 43
#      41 for expiry in expiries:
#      42     subset_indices = structured_data['t'] == expiry
# ---> 43     fwd = structured_data['fwd'][subset_indices][0]  # Forward price
#      44     t = expiry  # Maturity
#      45     K = structured_data['K'][subset_indices]  # Strike prices
#
# KeyError: 'fwd'

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# Load the CSV file using the csv module with a semicolon delimiter
data = []
with open('spx_surf20130814.csv', 'r') as file:
    reader = csv.DictReader(file, delimiter=';')
    for row in reader:
        data.append(row)

# Convert data to a structured numpy array
columns = list(data[0].keys())
structured_data = {col: np.array([float(row[col]) for row in data]) for col in columns}

# Extract unique maturities
expiries = np.unique(structured_data['t '])  # Note the space after 't'

# Heston model parameters (example values, adjust as needed)
lambda_ = 1.5768
v_bar = 0.0398
eta = 0.5751
v0 = 0.0157
rho = -0.5711
params = [lambda_, v_bar, eta, v0, rho]

# Market and model settings
IR = 0  # Risk-free rate
DY = 0  # Dividend yield
Xc = 4  # Truncation range (example)
Xm = 0  # No shift
pow = 14  # Grid size 2^pow
CP = -1  # Put (-1)

# Prepare output arrays
errors = []

for expiry in expiries:
    subset_indices = structured_data['t '] == expiry
    fwd = structured_data['fwd'][subset_indices][0]  # Forward price
    t = expiry  # Maturity
    K = structured_data['K'][subset_indices]  # Strike prices
    impVol_bench = structured_data['impVol'][subset_indices]  # Benchmark implied volatilities

    # Run SINC FFT pricing
    prices = sinc_fast_ft(S=fwd, t=t, K=K, IR=IR, DY=DY, model='Heston', params=params,
                          xi=None, j=0, Xc=Xc, Xm=Xm, pow=pow, CP=CP)
    
    # Compute implied volatilities from prices (requires a BSImpliedVolPut function)
    impVol_model = bs_implied_vol_put(fwd, K, t, IR, prices)

    # Compute error
    error = np.mean(np.abs(impVol_model - impVol_bench))
    errors.append(error)

    print(f"Maturity: {t}, Mean Absolute Error: {error}")

# Plot errors
plt.figure(figsize=(10, 6))
plt.plot(expiries, errors, marker='o', label='Mean Absolute Error')
plt.xlabel('Expiry')
plt.ylabel('Error')
plt.title('Mean Absolute Error vs Expiry (Heston FFT)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 40
#      38 for expiry in expiries:
#      39     subset_indices = structured_data['t '] == expiry
# ---> 40     fwd = structured_data['fwd'][subset_indices][0]  # Forward price
#      41     t = expiry  # Maturity
#      42     K = structured_data['K'][subset_indices]  # Strike prices
#
# KeyError: 'fwd'

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# Load the CSV file using the csv module with a semicolon delimiter
data = []
with open('spx_surf20130814.csv', 'r') as file:
    reader = csv.DictReader(file, delimiter=';')
    for row in reader:
        data.append(row)

# Convert data to a structured numpy array
columns = list(data[0].keys())
structured_data = {col: np.array([float(row[col]) for row in data]) for col in columns}

# Extract unique maturities
expiries = np.unique(structured_data['t'])

# Heston model parameters (example values, adjust as needed)
lambda_ = 1.5768
v_bar = 0.0398
eta = 0.5751
v0 = 0.0157
rho = -0.5711
params = [lambda_, v_bar, eta, v0, rho]

# Market and model settings
IR = 0  # Risk-free rate
DY = 0  # Dividend yield
Xc = 4  # Truncation range (example)
Xm = 0  # No shift
pow = 14  # Grid size 2^pow
CP = -1  # Put (-1)

# Prepare output arrays
errors = []

for expiry in expiries:
    subset_indices = structured_data['t'] == expiry
    fwd = structured_data['fwd'][subset_indices][0]  # Forward price
    t = expiry  # Maturity
    K = structured_data['K'][subset_indices]  # Strike prices
    impVol_bench = structured_data['impVol'][subset_indices]  # Benchmark implied volatilities

    # Run SINC FFT pricing
    prices = sinc_fast_ft(S=fwd, t=t, K=K, IR=IR, DY=DY, model='Heston', params=params,
                          xi=None, j=0, Xc=Xc, Xm=Xm, pow=pow, CP=CP)
    
    # Compute implied volatilities from prices (requires a BSImpliedVolPut function)
    impVol_model = bs_implied_vol_put(fwd, K, t, IR, prices)

    # Compute error
    error = np.mean(np.abs(impVol_model - impVol_bench))
    errors.append(error)

    print(f"Maturity: {t}, Mean Absolute Error: {error}")

# Plot errors
plt.figure(figsize=(10, 6))
plt.plot(expiries, errors, marker='o', label='Mean Absolute Error')
plt.xlabel('Expiry')
plt.ylabel('Error')
plt.title('Mean Absolute Error vs Expiry (Heston FFT)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 17
#      14 structured_data = {col: np.array([float(row[col]) for row in data]) for col in columns}
#      16 # Extract unique maturities
# ---> 17 expiries = np.unique(structured_data['t'])
#      19 # Heston model parameters (example values, adjust as needed)
#      20 lambda_ = 1.5768
#
# KeyError: 't'

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# Load the CSV file using csv module
data = []
with open('spx_surf20130814.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)

# Convert data to a structured numpy array
columns = list(data[0].keys())
structured_data = {col: np.array([float(row[col]) for row in data]) for col in columns}

# Extract unique maturities
expiries = np.unique(structured_data['t'])

# Heston model parameters (example values, adjust as needed)
lambda_ = 1.5768
v_bar = 0.0398
eta = 0.5751
v0 = 0.0157
rho = -0.5711
params = [lambda_, v_bar, eta, v0, rho]

# Market and model settings
IR = 0  # Risk-free rate
DY = 0  # Dividend yield
Xc = 4  # Truncation range (example)
Xm = 0  # No shift
pow = 14  # Grid size 2^pow
CP = -1  # Put (-1)

# Prepare output arrays
errors = []

for expiry in expiries:
    subset_indices = structured_data['t'] == expiry
    fwd = structured_data['fwd'][subset_indices][0]  # Forward price
    t = expiry  # Maturity
    K = structured_data['K'][subset_indices]  # Strike prices
    impVol_bench = structured_data['impVol'][subset_indices]  # Benchmark implied volatilities

    # Run SINC FFT pricing
    prices = sinc_fast_ft(S=fwd, t=t, K=K, IR=IR, DY=DY, model='Heston', params=params,
                          xi=None, j=0, Xc=Xc, Xm=Xm, pow=pow, CP=CP)
    
    # Compute implied volatilities from prices (requires a BSImpliedVolPut function)
    impVol_model = bs_implied_vol_put(fwd, K, t, IR, prices)

    # Compute error
    error = np.mean(np.abs(impVol_model - impVol_bench))
    errors.append(error)

    print(f"Maturity: {t}, Mean Absolute Error: {error}")

# Plot errors
plt.figure(figsize=(10, 6))
plt.plot(expiries, errors, marker='o', label='Mean Absolute Error')
plt.xlabel('Expiry')
plt.ylabel('Error')
plt.title('Mean Absolute Error vs Expiry (Heston FFT)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 14
#      12 # Convert data to a structured numpy array
#      13 columns = list(data[0].keys())
# ---> 14 structured_data = {col: np.array([float(row[col]) for row in data]) for col in columns}
#      16 # Extract unique maturities
#      17 expiries = np.unique(structured_data['t'])
#
# Cell In[31], line 14, in <dictcomp>(.0)
#      12 # Convert data to a structured numpy array
#      13 columns = list(data[0].keys())
# ---> 14 structured_data = {col: np.array([float(row[col]) for row in data]) for col in columns}
#      16 # Extract unique maturities
#      17 expiries = np.unique(structured_data['t'])
#
# Cell In[31], line 14, in <listcomp>(.0)
#      12 # Convert data to a structured numpy array
#      13 columns = list(data[0].keys())
# ---> 14 structured_data = {col: np.array([float(row[col]) for row in data]) for col in columns}
#      16 # Extract unique maturities
#      17 expiries = np.unique(structured_data['t'])
#
# ValueError: could not convert string to float: '1685.489836;0.008213552;1570;0.05428407;0.29551991'

# %%
def heston_cf(params, u, t, S0, v0, r, q):
    """
    Heston model characteristic function.
    """
    lam, v_bar, eta, v0, rho = params
    beta = lam - rho * eta * 1j * u
    alpha = -0.5 * (u**2 + 1j * u)
    zeta = 0.5 * eta**2

    d = np.sqrt(beta**2 - 4 * alpha * zeta)
    g = (beta - d) / (beta + d)

    C = (beta - d) * t / (2 * zeta) - (1 / zeta) * np.log((1 - g * np.exp(-d * t)) / (1 - g))
    D = (beta - d) / zeta * (1 - np.exp(-d * t)) / (1 - g * np.exp(-d * t))

    return np.exp(C * v_bar + D * v0 + 1j * u * np.log(S0) + 1j * u * (r - q) * t)

# %%
def sinc_fft_heston(S, K, t, r, q, params, Xc, Xm, pow, CP):
    """
    SINC-FFT pricing for the Heston model.
    """
    N = 2 ** pow
    Xl = -Xc + Xm
    Xh = Xc + Xm
    wid = Xh - Xl

    n = np.arange(1, N // 2, 2)
    wn = n / wid
    Il = 2 / n

    f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * heston_cf(params, 2 * np.pi * wn, t, S, params[3], r, q)
    f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * heston_cf(params, 2 * np.pi * wn - 1j, t, S, params[3], r, q)

    q1l = np.zeros(N // 2, dtype=np.complex128)
    q1l[1::2] = f1l * Il
    q2l = np.zeros(N // 2, dtype=np.complex128)
    q2l[1::2] = f2l * Il

    Iu = -np.flip(Il)
    f1u = np.flip(np.conj(f1l))
    f2u = np.flip(np.conj(f2l))

    q1u = np.zeros(N // 2, dtype=np.complex128)
    q1u[0::2] = f1u * Iu
    q2u = np.zeros(N // 2, dtype=np.complex128)
    q2u[0::2] = f2u * Iu

    q1 = 1j / (2 * np.pi) * np.concatenate((q1l, [0], q1u[:-1]))
    q2 = 1j / (2 * np.pi) * np.concatenate((q2l, [0], q2u[:-1]))

    d1 = np.fft.fft(q1) + 0.5
    d2 = np.fft.fft(q2) + 0.5

    m = np.arange(-N // 2, N // 2)
    km = m * wid / N + (r - q) * t + Xm
    Km = S * np.exp(km)

    conP = np.exp(-r * t) * np.real(Km * np.roll(d1, N // 2))
    aonP = np.exp(-q * t) * np.real(S * np.roll(d2, N // 2))

    put = np.interp(K, Km, conP - aonP)
    call = put + S * np.exp(-q * t) - K * np.exp(-r * t)

    return call if CP == 1 else put

# %%
def cos_heston(S, K, t, r, q, params, Xc, Xm, N, CP):
    """
    COS pricing for the Heston model.
    """
    K1 = np.exp(-(r - q) * t) * K
    x = np.log(S / K1)
    a, b = -Xc + Xm, Xc + Xm
    k = np.arange(N)
    u = k * np.pi / (b - a)

    phi = heston_cf(params, u, t, S, params[3], r, q)
    phi[0] = 1
    eto = np.exp(1j * np.pi * np.outer(x, k) / (b - a))

    psi = np.zeros(N)
    psi[0] = b - a
    psi[1:] = (np.sin(k[1:] * np.pi * (b - a) / (b - a)) - np.sin(k[1:] * np.pi * (a - a) / (b - a))) / (k[1:] * np.pi)
    Vk = 2 / (b - a) * np.outer(K1, psi)

    conP = np.exp(-r * t) * np.real(np.sum(eto * (phi * Vk), axis=1))
    aonP = np.exp(-q * t) * np.real(np.sum(eto * (phi * Vk), axis=1))

    put = conP - aonP
    call = put + S * np.exp(-q * t) - K * np.exp(-r * t)

    return call if CP == 1 else put

# %%
def sinc_fft_heston_debug(S, K, t, r, q, params, Xc, Xm, pow, CP):
    """
    Debugging SINC-FFT pricing for the Heston model.
    """
    N = 2 ** pow
    Xl = -Xc + Xm
    Xh = Xc + Xm
    wid = Xh - Xl

    n = np.arange(1, N // 2, 2)
    wn = n / wid
    Il = 2 / n

    # Calculate characteristic function values
    f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * heston_cf(params, 2 * np.pi * wn, t, S, params[3], r, q)
    f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * heston_cf(params, 2 * np.pi * wn - 1j, t, S, params[3], r, q)

    # DEBUG: Print characteristic function outputs
    print("f1l (sample):", f1l[:10])
    print("f2l (sample):", f2l[:10])

    q1l = np.zeros(N // 2, dtype=np.complex128)
    q1l[1::2] = f1l * Il
    q2l = np.zeros(N // 2, dtype=np.complex128)
    q2l[1::2] = f2l * Il

    Iu = -np.flip(Il)
    f1u = np.flip(np.conj(f1l))
    f2u = np.flip(np.conj(f2l))

    q1u = np.zeros(N // 2, dtype=np.complex128)
    q1u[0::2] = f1u * Iu
    q2u = np.zeros(N // 2, dtype=np.complex128)
    q2u[0::2] = f2u * Iu

    q1 = 1j / (2 * np.pi) * np.concatenate((q1l, [0], q1u[:-1]))
    q2 = 1j / (2 * np.pi) * np.concatenate((q2l, [0], q2u[:-1]))

    # DEBUG: Check Fourier weights
    print("q1 (sample):", q1[:10])
    print("q2 (sample):", q2[:10])

    d1 = np.fft.fft(q1) + 0.5
    d2 = np.fft.fft(q2) + 0.5

    m = np.arange(-N // 2, N // 2)
    km = m * wid / N + (r - q) * t + Xm
    Km = S * np.exp(km)

    # DEBUG: Check truncation grid
    print("Km (sample):", Km[:10])

    conP = np.exp(-r * t) * np.real(Km * np.roll(d1, N // 2))
    aonP = np.exp(-q * t) * np.real(S * np.roll(d2, N // 2))

    # DEBUG: Check final Fourier outputs
    print("conP (sample):", conP[:10])
    print("aonP (sample):", aonP[:10])

    put = np.interp(K, Km, conP - aonP)
    call = put + S * np.exp(-q * t) - K * np.exp(-r * t)

    return call if CP == 1 else put

# %%
def sinc_fft_heston_fixed(S, K, t, r, q, params, Xc, Xm, pow, CP):
    """
    Fixed SINC-FFT pricing for the Heston model with numerical stability adjustments.
    """
    N = 2 ** pow
    Xl = -Xc + Xm
    Xh = Xc + Xm
    wid = Xh - Xl

    n = np.arange(1, N // 2, 2)
    wn = n / wid
    Il = 2 / n  # Weighting term

    # Characteristic function evaluations
    f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * heston_cf(params, 2 * np.pi * wn, t, S, params[3], r, q)
    f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * heston_cf(params, 2 * np.pi * wn - 1j, t, S, params[3], r, q)

    # Rescale characteristic function to stabilize growth
    f2l = f2l / np.max(np.abs(f2l))  # Normalize f2l to avoid instability

    q1l = np.zeros(N // 2, dtype=np.complex128)
    q1l[1::2] = f1l * Il
    q2l = np.zeros(N // 2, dtype=np.complex128)
    q2l[1::2] = f2l * Il

    Iu = -np.flip(Il)
    f1u = np.flip(np.conj(f1l))
    f2u = np.flip(np.conj(f2l))

    q1u = np.zeros(N // 2, dtype=np.complex128)
    q1u[0::2] = f1u * Iu
    q2u = np.zeros(N // 2, dtype=np.complex128)
    q2u[0::2] = f2u * Iu

    q1 = 1j / (2 * np.pi) * np.concatenate((q1l, [0], q1u[:-1]))
    q2 = 1j / (2 * np.pi) * np.concatenate((q2l, [0], q2u[:-1]))

    d1 = np.fft.fft(q1) + 0.5
    d2 = np.fft.fft(q2) + 0.5

    m = np.arange(-N // 2, N // 2)
    km = m * wid / N + (r - q) * t + Xm
    Km = S * np.exp(km)

    # Compute option prices
    conP = np.exp(-r * t) * np.real(Km * np.roll(d1, N // 2))
    aonP = np.exp(-q * t) * np.real(S * np.roll(d2, N // 2))

    # Stabilize final price
    aonP = aonP - np.min(aonP)  # Shift to avoid excessive growth

    put = np.interp(K, Km, conP - aonP)
    call = put + S * np.exp(-q * t) - K * np.exp(-r * t)

    return call if CP == 1 else put

# %%
# Compute prices with the fixed SINC-FFT method
prices_sinc_fixed = sinc_fft_heston_fixed(S, K, T, r, q, params, Xc, Xm, pow, CP)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(K, prices_sinc_fixed, label='SINC-FFT (Fixed)', linestyle='--')
plt.xlabel('Strike Price (K)')
plt.ylabel('Option Price')
plt.title('Heston Model: Fixed SINC-FFT Method')
plt.legend()
plt.grid()
plt.show()

# %%
# Test parameters
S = 100  # Spot price
T = 0.1  # Short maturity
K = np.linspace(80, 120, 50)  # Strike prices
r, q = 0.03, 0.02  # Interest rate and dividend yield
params = [1.5768, 0.0398, 0.5751, 0.0157, -0.5711]  # Heston parameters
Xc = 2.0499  # Truncation range for T=0.1
Xm = 0
pow = 12  # SINC resolution
CP = -1  # Put option

# Compute SINC-FFT prices with debugging
prices_sinc_debug = sinc_fft_heston_debug(S, K, T, r, q, params, Xc, Xm, pow, CP)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(K, prices_sinc_debug, label='SINC-FFT (Debug)', linestyle='--')
plt.xlabel('Strike Price (K)')
plt.ylabel('Option Price')
plt.title('Heston Model: SINC-FFT Debugging')
plt.legend()
plt.grid()
plt.show()
# Out:
# f1l (sample): [ 0.71265382+0.69625904j -0.66142974+0.70624433j -0.67626446-0.61470048j
#   0.56274126-0.62568201j  0.56008353+0.51072558j -0.46167254+0.48601559j
#  -0.40954792-0.41668927j  0.37566083-0.33545055j  0.26696843+0.33794893j
#  -0.30287241+0.20597444j]
# f2l (sample): [ 71.0205966 +70.04158134j -67.28365073+69.87382347j
#  -66.56167937-63.28698249j  58.62211859-61.36208436j
#   54.7805841 +53.75409141j -48.98059596+47.41330948j
#  -39.82328745-44.44246739j  40.17374414-32.46426288j
#   25.65440568+36.15669105j -32.36192124+19.58438702j]
# q1 (sample): [ 0.        +0.j         -0.22162614+0.22684476j  0.        +0.j
#  -0.07493485-0.07017987j  0.        +0.j          0.03913305-0.04305233j
#   0.        +0.j          0.02845154+0.02558944j  0.        +0.j
#  -0.01806322+0.0198089j ]
# q2 (sample): [  0.         +0.j         -22.29492779+22.60655802j
#    0.         +0.j          -7.41384293 -7.13901707j
#    0.         +0.j           4.02897444 -4.23744812j
#    0.         +0.j           2.7903083  +2.66571427j
#    0.         +0.j          -1.90116208 +1.93746683j]
# Km (sample): [12.88765899 12.90056506 12.91348406 12.926416   12.93936088 12.95231873
#  12.96528956 12.97827337 12.99127019 13.00428002]
# conP (sample): [12.84904642 12.86191359 12.87479364 12.88768657 12.90059241 12.91351117
#  12.92644285 12.93938748 12.95234506 12.96531561]
# aonP (sample): [5044.89918119 5044.8990702  5044.89895563 5044.89883738 5044.89871532
#  5044.89858933 5044.89845929 5044.89832507 5044.89818654 5044.89804355]

# %%
S = 100  # Spot price
r, q = 0.03, 0.02  # Interest rate and dividend yield
params = [1.5768, 0.0398, 0.5751, 0.0157, -0.5711]  # Heston parameters
K = np.linspace(80, 120, 50)  # Strike prices
T = 0.1  # Short maturity
Xc = 2.0499  # Truncation range for T=0.1
Xm = 0
pow = 12  # SINC resolution
N = 2 ** 12  # COS resolution
CP = -1  # Put option

# %%
prices_sinc = sinc_fft_heston(S, K, T, r, q, params, Xc, Xm, pow, CP)
prices_cos = cos_heston(S, K, T, r, q, params, Xc, Xm, N, CP)

plt.figure(figsize=(10, 6))
plt.plot(K, prices_sinc, label='SINC-FFT', linestyle='--')
#plt.plot(K, prices_cos, label='COS Method', linestyle='-')
plt.xlabel('Strike Price (K)')
plt.ylabel('Option Price')
plt.title('Heston Model: SINC-FFT vs COS Method')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def heston_cf(params, u, t, S0, v0, r, q):
    lam, v_bar, eta, v0, rho = params
    beta = lam - rho * eta * 1j * u
    alpha = -0.5 * (u**2 + 1j * u)
    zeta = 0.5 * eta**2

    d = np.sqrt(beta**2 - 4 * alpha * zeta)
    g = (beta - d) / (beta + d)

    C = (beta - d) * t / (2 * zeta) - (1 / zeta) * np.log((1 - g * np.exp(-d * t)) / (1 - g))
    D = (beta - d) / zeta * (1 - np.exp(-d * t)) / (1 - g * np.exp(-d * t))

    return np.exp(C * v_bar + D * v0 + 1j * u * np.log(S0) + 1j * u * (r - q) * t)

def sinc_fft_heston(S, K, t, r, q, params, Xc, Xm, pow, CP):
    """
    SINC-FFT pricing for Heston model (fixed ComplexWarning).
    """
    N = 2 ** pow
    Xl = -Xc + Xm
    Xh = Xc + Xm
    wid = Xh - Xl

    n = np.arange(1, N // 2, 2)
    wn = n / wid
    Il = 2 / n

    # Calculate the characteristic function and extract real parts explicitly
    f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * heston_cf(params, 2 * np.pi * wn, t, S, params[3], r, q)
    f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * heston_cf(params, 2 * np.pi * wn - 1j, t, S, params[3], r, q)

    # Ensure real values are used for q1l and q2l
    q1l = np.zeros(N // 2, dtype=np.complex128)
    q1l[1::2] = np.real(f1l * Il)
    q2l = np.zeros(N // 2, dtype=np.complex128)
    q2l[1::2] = np.real(f2l * Il)

    Iu = -np.flip(Il)
    f1u = np.flip(np.conj(f1l))
    f2u = np.flip(np.conj(f2l))

    q1u = np.zeros(N // 2, dtype=np.complex128)
    q1u[0::2] = np.real(f1u * Iu)
    q2u = np.zeros(N // 2, dtype=np.complex128)
    q2u[0::2] = np.real(f2u * Iu)

    q1 = 1j / (2 * np.pi) * np.concatenate((q1l, [0], q1u[:-1]))
    q2 = 1j / (2 * np.pi) * np.concatenate((q2l, [0], q2u[:-1]))

    d1 = np.fft.fft(q1) + 0.5
    d2 = np.fft.fft(q2) + 0.5

    m = np.arange(-N // 2, N // 2)
    km = m * wid / N + (r - q) * t + Xm
    Km = S * np.exp(km)

    # Explicitly extract the real parts for conP and aonP
    conP = np.exp(-r * t) * np.real(Km * np.roll(d1, N // 2))
    aonP = np.exp(-q * t) * np.real(S * np.roll(d2, N // 2))

    put = np.interp(K, Km, conP - aonP)
    call = put + S * np.exp(-q * t) - K * np.exp(-r * t)

    return call if CP == 1 else put


def cos_heston(S, K, t, r, q, params, Xc, Xm, N, CP):
    K1 = np.exp(-(r - q) * t) * K
    x = np.log(S / K1)
    a, b = -Xc + Xm, Xc + Xm
    k = np.arange(N)
    u = k * np.pi / (b - a)

    phi = heston_cf(params, u, t, S, params[3], r, q)
    phi[0] = 1
    m = len(K)
    eto = np.exp(1j * np.pi * np.outer(x, k) / (b - a))

    psi = np.zeros(N)
    psi[0] = b - a
    psi[1:] = (np.sin(k[1:] * np.pi * (b - a) / (b - a)) - np.sin(k[1:] * np.pi * (a - a) / (b - a))) / (k[1:] * np.pi)
    Vk = 2 / (b - a) * np.outer(K1, psi)

    conP = np.exp(-r * t) * np.real(np.sum(eto * (phi * Vk), axis=1))
    aonP = np.exp(-q * t) * np.real(np.sum(eto * (phi * Vk), axis=1))

    put = conP - aonP
    call = put + S * np.exp(-q * t) - K * np.exp(-r * t)

    return call if CP == 1 else put

# Example parameters
S = 100  # Spot price
t = 1.0  # Time to maturity
K = np.linspace(80, 120, 50)  # Strike prices
r, q = 0.03, 0.02  # Interest rate and dividend yield
params = [2.0, 0.04, 0.3, 0.04, -0.7]  # [lambda, v_bar, eta, v0, rho]
Xc = 15
Xm = 0
pow = 14
N = 2 ** 14
CP = 1  # Call price

# Calculate prices using both methods
prices_sinc = sinc_fft_heston(S, K, t, r, q, params, Xc, Xm, pow, CP)
prices_cos = cos_heston(S, K, t, r, q, params, Xc, Xm, N, CP)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(K, prices_sinc, label='SINC-FFT', linestyle='--')
plt.plot(K, prices_cos, label='COS Method', linestyle='-')
plt.xlabel('Strike Price (K)')
plt.ylabel('Option Price')
plt.title('Heston Model: SINC-FFT vs COS Method')
plt.legend()
plt.grid()
plt.show()

# %%
# Diagnostic: Compare characteristic function for SINC-FFT and COS
u_values = np.linspace(-100, 100, 100)  # Sample Fourier transform points
cf_sinc = heston_cf(params, u_values, t, S, params[3], r, q)
cf_cos = heston_cf(params, u_values, t, S, params[3], r, q)

plt.figure(figsize=(10, 6))
plt.plot(u_values, cf_sinc.real, label="SINC-FFT: Real Part")
plt.plot(u_values, cf_cos.real, linestyle='--', label="COS: Real Part")
plt.plot(u_values, cf_sinc.imag, label="SINC-FFT: Imaginary Part")
plt.plot(u_values, cf_cos.imag, linestyle='--', label="COS: Imaginary Part")
plt.xlabel("u (Fourier Variable)")
plt.ylabel("Characteristic Function")
plt.title("Comparison of Heston Characteristic Function")
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np

# %%
def sinc_fft_heston(S, K, t, r, q, params, v0, Xc, Xm, pow, CP):
    """
    SINC-FFT pricing for Heston model.
    """
    N = 2 ** pow
    Xl = -Xc + Xm
    Xh = Xc + Xm
    wid = Xh - Xl

    n = np.arange(1, N // 2, 2)
    wn = n / wid
    Il = 2 / n

    f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * heston_cf(params, 2 * np.pi * wn, t, S, v0, r, q)
    f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * heston_cf(params, 2 * np.pi * wn - 1j, t, S, v0, r, q)

    q1l = np.zeros(N // 2)
    q1l[1::2] = f1l * Il
    q2l = np.zeros(N // 2)
    q2l[1::2] = f2l * Il

    Iu = -np.flip(Il)
    f1u = np.flip(np.conj(f1l))
    f2u = np.flip(np.conj(f2l))

    q1u = np.zeros(N // 2)
    q1u[0::2] = f1u * Iu
    q2u = np.zeros(N // 2)
    q2u[0::2] = f2u * Iu

    q1 = 1j / (2 * np.pi) * np.concatenate((q1l, [0], q1u[:-1]))
    q2 = 1j / (2 * np.pi) * np.concatenate((q2l, [0], q2u[:-1]))

    d1 = np.fft.fft(q1) + 0.5
    d2 = np.fft.fft(q2) + 0.5

    m = np.arange(-N // 2, N // 2)
    km = m * wid / N + (r - q) * t + Xm
    Km = S * np.exp(km)

    conP = np.exp(-r * t) * np.real(Km * np.roll(d1, N // 2))
    aonP = np.exp(-q * t) * np.real(S * np.roll(d2, N // 2))

    put = np.interp(K, Km, conP - aonP)
    call = put + S * np.exp(-q * t) - K * np.exp(-r * t)

    return call if CP == 1 else put


def cos_heston(S, K, t, r, q, params, v0, Xc, Xm, N, CP):
    """
    COS pricing for Heston model.
    """
    K1 = np.exp(-(r - q) * t) * K
    x = np.log(S / K1)
    a, b = -Xc + Xm, Xc + Xm
    k = np.arange(N)
    u = k * np.pi / (b - a)

    phi = heston_cf(params, u, t, S, v0, r, q)
    phi[0] = 1
    eto = np.exp(1j * np.pi * k * (x[:, None] - a) / (b - a))

    psi = np.where(
        k == 0, b - a,
        (np.sin(k * np.pi * (b - a) / (b - a)) - np.sin(k * np.pi * (a - a) / (b - a))) / (k * np.pi)
    )
    Vk = 2 / (b - a) * K1[:, None] * psi

    conP = np.exp(-r * t) * np.real(eto @ (phi * Vk.T).T)
    aonP = np.exp(-q * t) * np.real(eto @ (phi * Vk.T).T)

    put = conP - aonP
    call = put + S * np.exp(-q * t) - K * np.exp(-r * t)

    return call if CP == 1 else put

# %%
# Example parameters
S = 100  # Spot price
t = 0.5  # Time to maturity
K = np.linspace(80, 120, 50)  # Strike prices
r, q = 0.01, 0.02  # Interest rate and dividend yield
params = [2.0, 0.04, 0.3, -0.7]  # [kappa, theta, sigma, rho]
v0 = 0.04  # Initial variance
Xc = 5
Xm = 0
pow = 10
N = 2 ** 10
CP = 1  # Call price

# Calculate prices using both methods
prices_sinc = sinc_fft_heston(S, K, t, r, q, params, v0, Xc, Xm, pow, CP)
prices_cos = cos_heston(S, K, t, r, q, params, v0, Xc, Xm, N, CP)

# Plot
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(K, prices_sinc, label='SINC-FFT', linestyle='--')
plt.plot(K, prices_cos, label='COS Method', linestyle='-')
plt.xlabel('Strike Price (K)')
plt.ylabel('Option Price')
plt.title('Heston Model: SINC-FFT vs COS Method')
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 15
#      12 CP = 1  # Call price
#      14 # Calculate prices using both methods
# ---> 15 prices_sinc = sinc_fft_heston(S, K, t, r, q, params, v0, Xc, Xm, pow, CP)
#      16 prices_cos = cos_heston(S, K, t, r, q, params, v0, Xc, Xm, N, CP)
#      18 # Plot
#
# Cell In[4], line 14, in sinc_fft_heston(S, K, t, r, q, params, v0, Xc, Xm, pow, CP)
#      11 wn = n / wid
#      12 Il = 2 / n
# ---> 14 f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * heston_cf(params, 2 * np.pi * wn, t, S, v0, r, q)
#      15 f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * heston_cf(params, 2 * np.pi * wn - 1j, t, S, v0, r, q)
#      17 q1l = np.zeros(N // 2)
#
# NameError: name 'heston_cf' is not defined

# %%
def sinc_fastft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, pow, CP):
    N = 2 ** pow
    Xl = -Xc + Xm
    Xh = Xc + Xm
    wid = Xh - Xl
    n = np.arange(1, N // 2, 2)
    wn = n / wid
    Il = 2 / n

    def charfun(model, params, xi, j, u, t):
        # Placeholder for characteristic function. Replace with actual implementation.
        return np.exp(-0.5 * u ** 2 * t)  # Gaussian process as example

    f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun(model, params, xi, j, 2 * np.pi * wn, t)
    f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun(model, params, xi, j, 2 * np.pi * wn - 1j, t)

    q1l = np.zeros(N // 2)
    q1l[1::2] = f1l * Il
    q2l = np.zeros(N // 2)
    q2l[1::2] = f2l * Il

    Iu = -np.flip(Il)
    f1u = np.flip(np.conj(f1l))
    f2u = np.flip(np.conj(f2l))

    q1u = np.zeros(N // 2)
    q1u[0::2] = f1u * Iu
    q2u = np.zeros(N // 2)
    q2u[0::2] = f2u * Iu

    q1 = 1j / (2 * np.pi) * np.concatenate((q1l, [0], q1u[:-1]))
    q2 = 1j / (2 * np.pi) * np.concatenate((q2l, [0], q2u[:-1]))

    d1 = np.fft.fft(q1) + 0.5
    d2 = np.fft.fft(q2) + 0.5

    m = np.arange(-N // 2, N // 2)
    km = m * wid / N + (IR - DY) * t + Xm
    Km = S * np.exp(km)

    conP = np.exp(-IR * t) * np.real(Km * np.roll(d1, N // 2))
    aonP = np.exp(-DY * t) * np.real(S * np.roll(d2, N // 2))

    put = np.interp(K, Km, conP - aonP)
    call = put + S * np.exp(-DY * t) - K * np.exp(-IR * t)

    return call if CP == 1 else put

# %%
def cosm_discft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, N, CP, type=1):
    K1 = np.exp(-(IR - DY) * t) * K
    x = np.log(S / K1)
    a = -Xc + Xm
    b = Xc + Xm
    k = np.arange(N)
    u = k * np.pi / (b - a)

    def charfun(model, params, xi, j, u, t):
        # Placeholder for characteristic function. Replace with actual implementation.
        return np.exp(-0.5 * u ** 2 * t)  # Gaussian process as example

    phi = charfun(model, params, xi, j, u, t)
    phi[0] = 1
    eto = np.exp(1j * np.pi * k * (x[:, None] - a) / (b - a))

    wgt = np.ones(N)
    wgt[0] = 0.5

    psi = (np.sin(k * np.pi * (b - a) / (b - a)) - np.sin(k * np.pi * (a - a) / (b - a))) / (k * np.pi)
    psi[0] = b - a
    Vk = 2 / (b - a) * K1[:, None] * psi

    conP = np.exp(-IR * t) * np.real(eto @ (phi * Vk.T).T)
    aonP = np.exp(-DY * t) * np.real(eto @ (phi * Vk.T).T)

    put = conP - aonP
    call = put + S * np.exp(-DY * t) - K * np.exp(-IR * t)

    return call if CP * type == 1 else put

# %%
# Example parameters
S = 100  # Spot price
t = 0.5  # Time to maturity
K = np.linspace(80, 120, 50)  # Strike prices
IR, DY = 0.01, 0.02  # Interest rate and dividend yield
model = 'Heston'
params = [0.05, 0.4, -0.65]  # H, nu, rho
xi = np.array([0.0256])  # Variance curve
j = 100
Xc = 5
Xm = 0
pow = 10
CP = 1  # Call price

# Calculate prices using both methods
prices_sinc = sinc_fastft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, pow, CP)
prices_cosm = cosm_discft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, 2**10, CP)

# Plot
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(K, prices_sinc, label='SINC-FFT', linestyle='--')
plt.plot(K, prices_cosm, label='COS Method', linestyle='-')
plt.xlabel('Strike Price (K)')
plt.ylabel('Option Price')
plt.title('Option Prices: SINC-FFT vs COS Method')
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\Dominik\AppData\Local\Temp\ipykernel_16536\1280278544.py:20: ComplexWarning: Casting complex values to real discards the imaginary part
#   q1l[1::2] = f1l * Il
# C:\Users\Dominik\AppData\Local\Temp\ipykernel_16536\1280278544.py:22: ComplexWarning: Casting complex values to real discards the imaginary part
#   q2l[1::2] = f2l * Il
# C:\Users\Dominik\AppData\Local\Temp\ipykernel_16536\1280278544.py:29: ComplexWarning: Casting complex values to real discards the imaginary part
#   q1u[0::2] = f1u * Iu
# C:\Users\Dominik\AppData\Local\Temp\ipykernel_16536\1280278544.py:31: ComplexWarning: Casting complex values to real discards the imaginary part
#   q2u[0::2] = f2u * Iu
# C:\Users\Dominik\AppData\Local\Temp\ipykernel_16536\2545338288.py:20: RuntimeWarning: invalid value encountered in divide
#   psi = (np.sin(k * np.pi * (b - a) / (b - a)) - np.sin(k * np.pi * (a - a) / (b - a))) / (k * np.pi)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 17
#      15 # Calculate prices using both methods
#      16 prices_sinc = sinc_fastft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, pow, CP)
# ---> 17 prices_cosm = cosm_discft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, 2**10, CP)
#      19 # Plot
#      20 import matplotlib.pyplot as plt
#
# Cell In[2], line 24, in cosm_discft(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, N, CP, type)
#      21 psi[0] = b - a
#      22 Vk = 2 / (b - a) * K1[:, None] * psi
# ---> 24 conP = np.exp(-IR * t) * np.real(eto @ (phi * Vk.T).T)
#      25 aonP = np.exp(-DY * t) * np.real(eto @ (phi * Vk.T).T)
#      27 put = conP - aonP
#
# ValueError: operands could not be broadcast together with shapes (1024,) (1024,50)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Heston model characteristic function
def charfun_heston(params, u, t):
    lambda_, v_bar, eta, v0, rho = params
    
    beta = lambda_ - rho * eta * 1j * u
    alpha = -0.5 * u**2 - 0.5 * 1j * u
    zeta = 0.5 * eta**2
    
    d = np.sqrt(beta**2 - 4 * alpha * zeta)
    
    rm = (beta - d) / eta**2
    rp = (beta + d) / eta**2
    
    g = rm / rp
    
    C = rm * t - 2 / eta**2 * np.log((1 - g * np.exp(-d * t)) / (1 - g))
    D = rm * (1 - np.exp(-d * t)) / (1 - g * np.exp(-d * t))
    
    phi = np.exp(v_bar * lambda_ * C + v0 * D)
    
    return phi

# %%
# SINC operation function for Heston model pricing
def sinc_fast_ft(S, t, K, IR, DY, params, Xc, Xm, pow, CP):
    K = np.array(K) if isinstance(K, (list, np.ndarray)) else np.array([K])
    N = 2 ** pow
    
    Xl = -Xc + Xm
    Xh = Xc + Xm
    wid = Xh - Xl
    
    n = np.arange(1, N // 2, 2)
    wn = n / wid
    Il = 2 / n
    
    f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun_heston(params, 2 * np.pi * wn, t)
    f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun_heston(params, 2 * np.pi * wn - 1j, t)
    
    #q1l = np.zeros(N // 2)
    q1l = np.zeros(N // 2, dtype=complex)
    q1l[1::2] = np.real(f1l * Il)
    q2l = np.zeros(N // 2, dtype=complex)
    q2l[1::2] = np.real(f2l * Il)
    
    Iu = -np.flip(Il)
    f1u = np.flip(np.conj(f1l))
    f2u = np.flip(np.conj(f2l))
    
    q1u = np.zeros(N // 2, dtype=complex)
    q1u[::2] = np.real(f1u * Iu)
    q2u = np.zeros(N // 2, dtype=complex)
    q2u[::2] = np.real(f2u * Iu)
    
    q1 = 1j / (2 * np.pi) * np.concatenate([q1l, [0], q1u[:-1]])
    q2 = 1j / (2 * np.pi) * np.concatenate([q2l, [0], q2u[:-1]])
    
    d1 = np.fft.fft(q1) + 0.5
    d2 = np.fft.fft(q2) + 0.5
    
    d11 = d1[:N // 2]
    d12 = d1[N // 2:]
    d21 = d2[:N // 2]
    d22 = d2[N // 2:]
    
    dd1 = np.concatenate([d12, d11])
    dd2 = np.concatenate([d22, d21])
    
    m = np.arange(-N // 2, N // 2)
    km = m * wid / N + (IR - DY) * t + Xm
    Km = S * np.exp(km)
    
    conP = np.exp(-IR * t) * np.real(Km * dd1)
    aonP = np.exp(-DY * t) * np.real(S * dd2)
    
    conP = np.interp(K, Km, conP)
    aonP = np.interp(K, Km, aonP)
    
    put = conP - aonP
    call = put + S * np.exp(-DY * t) - K * np.exp(-IR * t)
    
    return call if CP == 1 else put

# %%
# Main function for SINC FFT Heston model pricing
def main():
    CP = 1  # for Call options
    S = 1
    t = 1.00
    K = S * np.arange(0.60, 1.41, 0.10)  # Strike prices
    IR = 0.05  # Interest rate
    DY = 0.02  # Dividend yield
    params = [1.5768, 0.0398, 0.5751, 0.0175, -0.5711]  # Heston parameters
    
    if t == 0.01:
        Xc = 1.3863
    elif t == 0.10:
        Xc = 2.0499
    elif t == 1.00:
        Xc = 12.1802
    elif t == 10:
        Xc = 32.8824
    Xm = 0
    
    pow = 18  # FFT precision for sinc method
    heston_prices = sinc_fast_ft(S, t, K, IR, DY, params, Xc, Xm, pow, CP)
    
    # Plot Heston model prices
    plt.plot(K, heston_prices, label="Heston Model (SINC FFT)", marker='o')
    plt.xlabel("Strike Price (K)")
    plt.ylabel("Option Price")
    plt.title("Option Prices Using Heston Model (SINC FFT)")
    plt.legend()
    plt.show()
    
    # Print results for review
    print("Strike Prices:", K)
    print("Heston Model Prices:", heston_prices)

# Run the main function
main()
# Out:
# Strike Prices: [0.6 0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4]
# Heston Model Prices: [ 0.41016264  0.31545475  0.21860474  0.1127435   0.01730197 -0.02177361
#  -0.02893055 -0.02630609 -0.02209005]

# %%
def charfun_edgeworth(params, u, t):
    # Extract only the first 8 parameters required for Edgeworth model
    sigma_t, beta_tilde, rho_t, alpha_tilde, eta_t, lambda_t, mu_j, sigma_j = params[:8]
    
    # Compute skewness and kurtosis adjustments for the characteristic function
    skewness_term = (1j * u)**3 * beta_tilde * rho_t / (2 * sigma_t) * np.sqrt(t)
    kurtosis_term = (1j * u)**2 * ((alpha_tilde / (2 * sigma_t)) + (beta_tilde**2 / (4 * sigma_t**2))) * t
    jumps_term = lambda_t * (np.exp(1j * u * mu_j - 0.5 * u**2 * sigma_j**2) - 1) * t

    # Apply clipping to the terms before combining them
    max_val = 100  # Arbitrary cutoff to avoid overflow; adjust based on observations

    skewness_term = np.clip(skewness_term, -max_val, max_val)
    kurtosis_term = np.clip(kurtosis_term, -max_val, max_val)
    jumps_term = np.clip(jumps_term, -max_val, max_val)

    ## Compute the final characteristic function with clipped values
    #phi_edgeworth = np.exp(-0.5 * u**2 * sigma_t**2 * t + skewness_term + kurtosis_term + jumps_term)
    # Combine the terms in log-space
    log_phi_edgeworth = -0.5 * u**2 * sigma_t**2 * t + skewness_term + kurtosis_term + jumps_term

    # Clip the log terms to avoid overflow
    log_phi_edgeworth = np.clip(log_phi_edgeworth, -max_val, max_val)

    # Final exponentiation
    phi_edgeworth = np.exp(log_phi_edgeworth)


    # Print intermediate values for debugging
    print("u:", u)
    print("\nskewness_term:", skewness_term)
    print("\nkurtosis_term:", kurtosis_term)
    print("\njumps_term:", jumps_term)

    # Combine terms into the final characteristic function with exp
    phi_edgeworth = np.exp(-0.5 * u**2 * sigma_t**2 * t + skewness_term + kurtosis_term + jumps_term)
    print("\nphi_edgeworth:", phi_edgeworth)

    return phi_edgeworth

# %%
# SINC operation function for Edgeworth model pricing
def sinc_fast_ft_edgeworth(S, t, K, IR, DY, params, Xc, Xm, pow, CP, model="heston"):
    K = np.array(K) if isinstance(K, (list, np.ndarray)) else np.array([K])
    N = 2 ** pow
    Xl = -Xc + Xm
    Xh = Xc + Xm
    wid = Xh - Xl
    n = np.arange(1, N // 2, 2)
    wn = n / wid
    Il = 2 / n
    
    # Choose characteristic function based on model selection
    if model == "heston":
        f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun_heston(params, 2 * np.pi * wn, t)
        f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun_heston(params, 2 * np.pi * wn - 1j, t)
    elif model == "edgeworth":
        f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun_edgeworth(params, 2 * np.pi * wn, t)
        f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun_edgeworth(params, 2 * np.pi * wn - 1j, t)

    #q1l = np.zeros(N // 2)
    q1l = np.zeros(N // 2, dtype=complex)
    q1l[1::2] = np.real(f1l * Il)
    q2l = np.zeros(N // 2, dtype=complex)
    q2l[1::2] = np.real(f2l * Il)
    
    Iu = -np.flip(Il)
    f1u = np.flip(np.conj(f1l))
    f2u = np.flip(np.conj(f2l))
    
    q1u = np.zeros(N // 2, dtype=complex)
    q1u[::2] = np.real(f1u * Iu)
    q2u = np.zeros(N // 2, dtype=complex)
    q2u[::2] = np.real(f2u * Iu)
    
    q1 = 1j / (2 * np.pi) * np.concatenate([q1l, [0], q1u[:-1]])
    q2 = 1j / (2 * np.pi) * np.concatenate([q2l, [0], q2u[:-1]])
    
    d1 = np.fft.fft(q1) + 0.5
    d2 = np.fft.fft(q2) + 0.5
    
    d11 = d1[:N // 2]
    d12 = d1[N // 2:]
    d21 = d2[:N // 2]
    d22 = d2[N // 2:]
    
    dd1 = np.concatenate([d12, d11])
    dd2 = np.concatenate([d22, d21])
    
    m = np.arange(-N // 2, N // 2)
    km = m * wid / N + (IR - DY) * t + Xm
    Km = S * np.exp(km)
    
    conP = np.exp(-IR * t) * np.real(Km * dd1)
    aonP = np.exp(-DY * t) * np.real(S * dd2)
    
    conP = np.interp(K, Km, conP)
    aonP = np.interp(K, Km, aonP)
    
    put = conP - aonP
    call = put + S * np.exp(-DY * t) - K * np.exp(-IR * t)
    
    return call if CP == 1 else put

# %%
def main():
    # Option type (Call = 1, Put = -1)
    CP = 1  # for Call options
    S = 1  # Spot price
    t = 1.00  # Time to maturity
    K = S * np.arange(0.60, 1.41, 0.10)  # Strike prices
    IR = 0.05  # Interest rate
    DY = 0.02  # Dividend yield
    
    # Heston model parameters
    heston_params = [1.5768, 0.0398, 0.5751, 0.0175, -0.5711]  # (lambda_, v_bar, eta, v0, rho)

    # Edgeworth model parameters
    # sigma_t, beta_tilde, rho_t, alpha_tilde, eta_t, lambda_t, mu_j, sigma_j
    edgeworth_params = [0.2, 0.3, -0.5, 0.05, 0.3, 0.1, 0.02, 0.15]
    
    # Parameters for Fourier inversion using SINC method
    if t == 0.01:
        Xc = 1.3863
    elif t == 0.10:
        Xc = 2.0499
    elif t == 1.00:
        Xc = 12.1802
    elif t == 10:
        Xc = 32.8824
    Xm = 0
    pow = 18  # FFT precision for sinc method

    # Compute prices using Heston model
    heston_prices = sinc_fast_ft(S, t, K, IR, DY, heston_params, Xc, Xm, pow, CP)
    
    # Compute prices using Edgeworth-like expansion model
    edgeworth_prices = sinc_fast_ft_edgeworth(S, t, K, IR, DY, edgeworth_params, Xc, Xm, pow, CP, model="edgeworth")

    # Plot results for comparison
    plt.plot(K, heston_prices, label="Heston Model (SINC FFT)", marker='o')
    plt.plot(K, edgeworth_prices, label="Edgeworth-Like Expansion (SINC FFT)", marker='x')
    plt.xlabel("Strike Price (K)")
    plt.ylabel("Option Price")
    plt.title("Comparison of Heston and Edgeworth-Like Expansion Models")
    plt.legend()
    plt.show()
    
    # Print results for review
    print("Strike Prices:", K)
    print("Heston Model Prices:", heston_prices)
    print("Edgeworth Model Prices:", edgeworth_prices)

# Run the main function
main()
# Out:
# u: [2.57926196e-01 7.73778588e-01 1.28963098e+00 ... 3.38056127e+04
#  3.38061286e+04 3.38066444e+04]
#
# skewness_term: [0.+6.43454181e-03j 0.+1.73732629e-01j 0.+8.04317726e-01j ...
#  0.+1.44876419e+13j 0.+1.44883052e+13j 0.+1.44889684e+13j]
#
# kurtosis_term: [-4.57365718e-02+0.j -4.11629146e-01+0.j -1.14341430e+00+0.j ...
#  -1.00000000e+02+0.j -1.00000000e+02+0.j -1.00000000e+02+0.j]
#
# jumps_term: [-7.61431837e-05+0.00051546j -6.83205577e-04+0.00153711j
#  -1.88629083e-03+0.00253117j ... -1.00000000e-01-0.j
#  -1.00000000e-01-0.j         -1.00000000e-01-0.j        ]
#
# phi_edgeworth: [ 0.95392771+0.00662991j  0.64421288+0.1140816j   0.21287402+0.22220829j
#  ...  0.        +0.j         -0.        -0.j
#  -0.        +0.j        ]
# u: [2.57926196e-01-1.j 7.73778588e-01-1.j 1.28963098e+00-1.j ...
#  3.38056127e+04-1.j 3.38061286e+04-1.j 3.38066444e+04-1.j]
#
# skewness_term: [ -0.30015834-0.28373243j   0.29857497-0.69676828j
#    1.49604157-0.64651713j ... 100.        +0.j
#  100.        +0.j         100.        +0.j        ]
#
# kurtosis_term: [   0.64176343+0.35464852j    0.27587085+1.06394556j
#    -0.4559143 +1.7732426j  ... -100.        +0.j
#  -100.        +0.j         -100.        +0.j        ]
#
# jumps_term: [ 0.00309096+0.00113011j  0.00242631+0.00336956j  0.00110979+0.00554731j
#  ... -0.1       -0.j         -0.1       -0.j
#  -0.1       -0.j        ]
#
# phi_edgeworth: [1.43328618+0.11831778j 1.65207783+0.70140632j 1.05485657+2.58872973j ...
#  0.        +0.j         0.        +0.j         0.        +0.j        ]
# Strike Prices: [0.6 0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4]
# Heston Model Prices: [ 0.41016264  0.31545475  0.21860474  0.1127435   0.01730197 -0.02177361
#  -0.02893055 -0.02630609 -0.02209005]
# Edgeworth Model Prices: [-4.04357976e+13 -2.48337372e+13  2.96105217e+13  4.38541029e+13
#   1.29362593e+13 -2.67185749e+13 -4.52427970e+13 -3.58793770e+13
#  -8.84029571e+12]

# %%
def main():
    CP = 1  # for Call options
    S = 1
    t = 1.00
    K = S * np.arange(0.60, 1.41, 0.10)  # Strike prices
    IR = 0.05  # Interest rate
    DY = 0.02  # Dividend yield
    params = [1.5768, 0.0398, 0.5751, 0.0175, -0.5711]  # Heston parameters
    
    if t == 0.01:
        Xc = 1.3863
    elif t == 0.10:
        Xc = 2.0499
    elif t == 1.00:
        Xc = 12.1802
    elif t == 10:
        Xc = 32.8824
    Xm = 0
    
    pow = 18  # FFT precision for sinc method
    heston_prices = sinc_fast_ft(S, t, K, IR, DY, params, Xc, Xm, pow, CP)
    
    # Compare Heston and Edgeworth prices
    heston_prices = sinc_fast_ft_edgeworth(S, t, K, IR, DY, params, Xc, Xm, pow, CP, model="heston")
    edgeworth_prices = sinc_fast_ft_edgeworth(S, t, K, IR, DY, params, Xc, Xm, pow, CP, model="edgeworth")

    # Plot results for comparison
    plt.plot(K, heston_prices, label="Heston Model (SINC FFT)", marker='o')
    plt.plot(K, edgeworth_prices, label="Edgeworth-Like Expansion (SINC FFT)", marker='x')
    plt.xlabel("Strike Price (K)")
    plt.ylabel("Option Price")
    plt.title("Comparison of Heston and Edgeworth-Like Expansion Models")
    plt.legend()
    plt.show()
    
    # Print results for review
    print("Strike Prices:", K)
    print("Heston Model Prices:", heston_prices)

# Run the main function
main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 41
#      38     print("Heston Model Prices:", heston_prices)
#      40 # Run the main function
# ---> 41 main()
#
# Cell In[47], line 25, in main()
#      23 # Compare Heston and Edgeworth prices
#      24 heston_prices = sinc_fast_ft_edgeworth(S, t, K, IR, DY, params, Xc, Xm, pow, CP, model="heston")
# ---> 25 edgeworth_prices = sinc_fast_ft_edgeworth(S, t, K, IR, DY, params, Xc, Xm, pow, CP, model="edgeworth")
#      27 # Plot results for comparison
#      28 plt.plot(K, heston_prices, label="Heston Model (SINC FFT)", marker='o')
#
# Cell In[45], line 17, in sinc_fast_ft_edgeworth(S, t, K, IR, DY, params, Xc, Xm, pow, CP, model)
#      15     f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun_heston(params, 2 * np.pi * wn - 1j, t)
#      16 elif model == "edgeworth":
# ---> 17     f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun_edgeworth(params, 2 * np.pi * wn, t)
#      18     f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun_edgeworth(params, 2 * np.pi * wn - 1j, t)
#      20 #q1l = np.zeros(N // 2)
#
# Cell In[43], line 3, in charfun_edgeworth(params, u, t)
#       1 def charfun_edgeworth(params, u, t):
#       2     # Extract only the first 8 parameters required for Edgeworth model
# ----> 3     sigma_t, beta_tilde, rho_t, alpha_tilde, eta_t, lambda_t, mu_j, sigma_j = params[:8]
#       5     # Compute skewness and kurtosis adjustments for the characteristic function
#       6     skewness_term = (1j * u)**3 * beta_tilde * rho_t / (2 * sigma_t) * np.sqrt(t)
#
# ValueError: not enough values to unpack (expected 8, got 5)

# %%
def calculate_compensator(mu_j, sigma_j, sigma_t, tau):
    """
    Calculates the compensator term mu_bar_j for the jump component of the characteristic function.
    
    Parameters:
    - mu_j: Mean jump size (log scale)
    - sigma_j: Volatility of jumps
    - sigma_t: Current volatility of the asset
    - tau: Small time to maturity

    Returns:
    - mu_bar_j: The compensator for the mean jump size.
    """
    mu_bar_j = np.exp(mu_j / (sigma_t * np.sqrt(tau)) + (sigma_j**2 / (2 * sigma_t**2 * tau))) - 1
    return mu_bar_j

def discrete_component(u, tau, sigma_t, lambda_t, mu_j, sigma_j, mu_bar_j):
    """
    Calculates the discrete (jump) component of the characteristic function for the model.
    """
    jump_mean_term = 1j * u * mu_j / (sigma_t * np.sqrt(tau))
    jump_variance_term = - u**2 * sigma_j**2 / (2 * sigma_t**2 * tau)
    C_logXd = np.exp(tau * lambda_t * (np.exp(jump_mean_term + jump_variance_term) - 1 - 1j * u * mu_bar_j))
    return C_logXd

def continuous_component(u, tau, sigma_t, mu_tilde, rho_t, alpha_q, beta_tilde, delta_tilde, eta_t):
    """
    Calculates the continuous (diffusive) component of the characteristic function for the model.
    """
    drift_term = 1j * u * (mu_tilde * tau) / (sigma_t * np.sqrt(tau))
    gaussian_term = -0.5 * u**2
    third_moment_adjustment = -1j * u**3 * (beta_tilde * rho_t) / (2 * sigma_t) * np.sqrt(tau)
    second_moment_adjustment = - u**2 * ((alpha_q + delta_tilde) / (2 * sigma_t) + beta_tilde**2 / (4 * sigma_t**2)) * tau
    fourth_moment_adjustment = (1 / 24) * (beta_tilde**2 / sigma_t**2) * u**2 * (4 * u**2 - rho_t**2 * u**2 * (3 * u**2 - 8)) * tau
    sixth_moment_adjustment = (eta_t / (6 * sigma_t)) * u**4 * tau
    adjustments = 1 + third_moment_adjustment + second_moment_adjustment + fourth_moment_adjustment + sixth_moment_adjustment
    C_logXc = np.exp(drift_term + gaussian_term) * adjustments
    return C_logXc

def charfun(u, tau, sigma_t, lambda_t, mu_j, sigma_j, mu_tilde, rho_t, alpha_q, beta_tilde, delta_tilde, eta_t):
    """
    Combines the discrete and continuous components to produce the full characteristic function for the model.
    
    Parameters:
    - u: Fourier variable
    - tau: Small time to maturity
    - sigma_t, lambda_t, mu_j, sigma_j: Jump component parameters
    - mu_tilde, rho_t, alpha_q, beta_tilde, delta_tilde, eta_t: Continuous component parameters

    Returns:
    - The complete characteristic function for the model.
    """
    # Calculate compensator for the discrete component
    mu_bar_j = calculate_compensator(mu_j, sigma_j, sigma_t, tau)
    
    # Calculate discrete and continuous components
    C_logXd = discrete_component(u, tau, sigma_t, lambda_t, mu_j, sigma_j, mu_bar_j)
    C_logXc = continuous_component(u, tau, sigma_t, mu_tilde, rho_t, alpha_q, beta_tilde, delta_tilde, eta_t)
    
    # Full characteristic function as product of continuous and discrete components
    phi = C_logXc * C_logXd
    return phi

# %%
# SINC operation function for Heston model pricing
def sinc_fast_ft(S, t, K, IR, DY, params, Xc, Xm, pow, CP):
    K = np.array(K) if isinstance(K, (list, np.ndarray)) else np.array([K])
    N = 2 ** pow
    
    Xl = -Xc + Xm
    Xh = Xc + Xm
    wid = Xh - Xl
    
    n = np.arange(1, N // 2, 2)
    wn = n / wid
    Il = 2 / n
    
    f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun_heston(params, 2 * np.pi * wn, t)
    f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun_heston(params, 2 * np.pi * wn - 1j, t)
    
    #q1l = np.zeros(N // 2)
    q1l = np.zeros(N // 2, dtype=complex)
    q1l[1::2] = np.real(f1l * Il)
    q2l = np.zeros(N // 2, dtype=complex)
    q2l[1::2] = np.real(f2l * Il)
    
    Iu = -np.flip(Il)
    f1u = np.flip(np.conj(f1l))
    f2u = np.flip(np.conj(f2l))
    
    q1u = np.zeros(N // 2, dtype=complex)
    q1u[::2] = np.real(f1u * Iu)
    q2u = np.zeros(N // 2, dtype=complex)
    q2u[::2] = np.real(f2u * Iu)
    
    q1 = 1j / (2 * np.pi) * np.concatenate([q1l, [0], q1u[:-1]])
    q2 = 1j / (2 * np.pi) * np.concatenate([q2l, [0], q2u[:-1]])
    
    d1 = np.fft.fft(q1) + 0.5
    d2 = np.fft.fft(q2) + 0.5
    
    d11 = d1[:N // 2]
    d12 = d1[N // 2:]
    d21 = d2[:N // 2]
    d22 = d2[N // 2:]
    
    dd1 = np.concatenate([d12, d11])
    dd2 = np.concatenate([d22, d21])
    
    m = np.arange(-N // 2, N // 2)
    km = m * wid / N + (IR - DY) * t + Xm
    Km = S * np.exp(km)
    
    conP = np.exp(-IR * t) * np.real(Km * dd1)
    aonP = np.exp(-DY * t) * np.real(S * dd2)
    
    conP = np.interp(K, Km, conP)
    aonP = np.interp(K, Km, aonP)
    
    put = conP - aonP
    call = put + S * np.exp(-DY * t) - K * np.exp(-IR * t)
    
    return call if CP == 1 else put

# %%
import numpy as np
from scipy.fft import fft
from scipy.interpolate import interp1d

def SINC_fastFT(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, pow, CP):
    """
    SINC method for FFT pricing of European plain vanilla call/put options.
    
    Parameters:
    - S: Spot price of the underlying asset
    - t: Time to maturity
    - K: Array of strike prices
    - IR: Interest rate
    - DY: Dividend yield
    - model: Model for characteristic function
    - params: Model parameters for the characteristic function
    - xi, j: Other specific parameters for characteristic function if needed
    - Xc, Xm: Truncation center and offset for the Fourier range
    - pow: Power of 2 for FFT size (N = 2^pow)
    - CP: Option type (1 for call, -1 for put)

    Returns:
    - Array of option prices (call or put depending on CP)
    """
    # Ensure K is a row vector
    if K.ndim == 1:
        K = K.reshape(1, -1)
    
    # Number of Fourier modes for FFT
    N = 2**pow
    
    # Construct truncation range and Fourier modes
    Xl = -Xc + Xm
    Xh = Xc + Xm
    wid = Xh - Xl
    n = np.arange(1, N//2, 2)
    wn = n / wid
    
    # Weights for positive and negative frequencies
    Il = 2 / n
    Iu = -Il[::-1]

    # Evaluate CF at sampled Fourier modes for CoN and AoN options
    f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun(model, params, xi, j, 2 * np.pi * wn, t)
    f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun(model, params, xi, j, 2 * np.pi * wn - 1j, t)

    # Set even frequencies to zero
    q1l = np.zeros(N // 2, dtype=complex)
    q1l[1::2] = f1l * Il
    q2l = np.zeros(N // 2, dtype=complex)
    q2l[1::2] = f2l * Il
    
    # Negative frequency components
    f1u = np.conj(f1l[::-1])
    f2u = np.conj(f2l[::-1])
    q1u = np.zeros(N // 2, dtype=complex)
    q1u[::2] = f1u * Iu
    q2u = np.zeros(N // 2, dtype=complex)
    q2u[::2] = f2u * Iu
    
    # Rearrange for FFT algorithm
    q1 = 1j / (2 * np.pi) * np.concatenate([q1l, [0], q1u[:-1]])
    q2 = 1j / (2 * np.pi) * np.concatenate([q2l, [0], q2u[:-1]])
    
    # Perform FFT for CoN and AoN
    d1 = fft(q1) + 0.5
    d2 = fft(q2) + 0.5
    
    # Extract digital option components
    d11, d12 = d1[:N//2], d1[N//2:]
    d21, d22 = d2[:N//2], d2[N//2:]
    dd1 = np.concatenate([d12, d11])
    dd2 = np.concatenate([d22, d21])
    
    # Define strike grid and compute buckets
    m = np.arange(-N//2, N//2)
    km = m * wid / N + (IR - DY) * t + Xm
    Km = S * np.exp(km)
    
    # Calculate CoN and AoN put prices over the buckets
    conP = np.exp(-IR * t) * np.real(Km * dd1)
    aonP = np.exp(-DY * t) * np.real(S * dd2)
    
    # Interpolate on the desired strikes
    conP_interp = interp1d(Km, conP, kind='linear', fill_value="extrapolate")
    aonP_interp = interp1d(Km, aonP, kind='linear', fill_value="extrapolate")
    conP = conP_interp(K)
    aonP = aonP_interp(K)
    
    # Put price as a linear combination of digital options
    put = conP - aonP  # Based on put pricing formula
    
    # Call price from put-call parity
    call = put + S * np.exp(-DY * t) - K * np.exp(-IR * t)
    
    # Output call or put price based on CP flag
    return call if CP == 1 else put

# %%
import numpy as np

# Assume all the helper functions from above (charfun, SINC_fastFT, calculate_compensator, etc.) are already defined

# 1. Set parameters for the test
S = 100          # Spot price of the underlying asset
K = np.array([90, 100, 110])  # Array of strike prices for testing
t = 0.001        # Time to maturity, very close to 0 for 0DTE options
IR = 0.01        # Risk-free interest rate
DY = 0.0         # Dividend yield
Xc = 10          # Truncation center
Xm = 5           # Offset
pow = 12         # Power for FFT size, so N = 2^pow
CP = 1           # 1 for call, -1 for put

# 2. Set model parameters for our characteristic function model
# Example parameters based on the continuous and discrete components
sigma_t = 0.2         # Current volatility
lambda_t = 0.1        # Jump intensity
mu_j = -0.05          # Mean jump size
sigma_j = 0.1         # Jump size volatility
mu_tilde = IR - 0.5 * sigma_t**2  # Adjusted drift term
rho_t = -0.5          # Correlation between price and variance
alpha_q = 0.05        # Risk-neutral drift adjustment for volatility
beta_tilde = 0.2      # Term for volatility skew adjustment
delta_tilde = 0.02    # Additional variance adjustment
eta_t = 0.1           # Higher moment adjustment

# Bundle parameters for easy passing
params = (sigma_t, lambda_t, mu_j, sigma_j, mu_tilde, rho_t, alpha_q, beta_tilde, delta_tilde, eta_t)

# Define a wrapper function for charfun that fits the SINC_fastFT input structure
def test_charfun(model, params, xi, j, u, t):
    # Unpack all parameters needed by charfun
    sigma_t, lambda_t, mu_j, sigma_j, mu_tilde, rho_t, alpha_q, beta_tilde, delta_tilde, eta_t = params
    
    # Call the charfun with all required parameters
    return charfun(u, t, sigma_t, lambda_t, mu_j, sigma_j, mu_tilde, rho_t, alpha_q, beta_tilde, delta_tilde, eta_t)

# 3. Use `test_charfun` in place of `charfun` in the SINC_fastFT function call
call_prices = SINC_fastFT(S, t, K, IR, DY, 'custom', params, None, None, Xc, Xm, pow, CP=1)
put_prices = SINC_fastFT(S, t, K, IR, DY, 'custom', params, None, None, Xc, Xm, pow, CP=-1)

# 4. Display results
print("Strike Prices:", K)
print("Call Prices for 0DTE Options:", call_prices)
print("Put Prices for 0DTE Options:", put_prices)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 41
#      38     return charfun(u, t, sigma_t, lambda_t, mu_j, sigma_j, mu_tilde, rho_t, alpha_q, beta_tilde, delta_tilde, eta_t)
#      40 # 3. Use `test_charfun` in place of `charfun` in the SINC_fastFT function call
# ---> 41 call_prices = SINC_fastFT(S, t, K, IR, DY, 'custom', params, None, None, Xc, Xm, pow, CP=1)
#      42 put_prices = SINC_fastFT(S, t, K, IR, DY, 'custom', params, None, None, Xc, Xm, pow, CP=-1)
#      44 # 4. Display results
#
# Cell In[3], line 44, in SINC_fastFT(S, t, K, IR, DY, model, params, xi, j, Xc, Xm, pow, CP)
#      41 Iu = -Il[::-1]
#      43 # Evaluate CF at sampled Fourier modes for CoN and AoN options
# ---> 44 f1l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun(model, params, xi, j, 2 * np.pi * wn, t)
#      45 f2l = np.exp(-1j * 2 * np.pi * wn * Xm) * charfun(model, params, xi, j, 2 * np.pi * wn - 1j, t)
#      47 # Set even frequencies to zero
#
# TypeError: charfun() missing 6 required positional arguments: 'mu_tilde', 'rho_t', 'alpha_q', 'beta_tilde', 'delta_tilde', and 'eta_t'

# %%
import numpy as np

def discrete_component(u, tau, sigma_t, lambda_t, mu_j, sigma_j, mu_bar_j):
    """
    Calculates the discrete (jump) component of the characteristic function for 0DTE options.

    Parameters:
    - u: Fourier variable
    - tau: Small time to maturity
    - sigma_t: Current volatility of the asset
    - lambda_t: Jump intensity (expected number of jumps per unit time)
    - mu_j: Mean jump size (log scale)
    - sigma_j: Volatility of jumps
    - mu_bar_j: Adjusted mean jump size (log scale)

    Returns:
    - The discrete component of the characteristic function value for the log-price of the asset.
    """
    
    # Calculate the exponent terms
    jump_mean_term = 1j * u * mu_j / (sigma_t * np.sqrt(tau))
    jump_variance_term = - u**2 * sigma_j**2 / (2 * sigma_t**2 * tau)
    
    # Combine terms to compute the discrete component
    C_logXd = np.exp(tau * lambda_t * (np.exp(jump_mean_term + jump_variance_term) - 1 - 1j * u * mu_bar_j))
    
    return C_logXd

# %%
def calculate_compensator(mu_j, sigma_j, sigma_t, tau):
    """
    Calculates the compensator term mu_bar_j for the jump component of the characteristic function.
    
    Parameters:
    - mu_j: Mean jump size (log scale)
    - sigma_j: Volatility of jumps
    - sigma_t: Current volatility of the asset
    - tau: Small time to maturity

    Returns:
    - mu_bar_j: The compensator for the mean jump size.
    """
    
    # Calculate the compensator mu_bar_j
    mu_bar_j = np.exp(mu_j / (sigma_t * np.sqrt(tau)) + (sigma_j**2 / (2 * sigma_t**2 * tau))) - 1
    
    return mu_bar_j

# %%
import numpy as np

def continuous_component(u, tau, sigma_t, mu_tilde, rho_t, alpha_q, beta_tilde, delta_tilde, eta_t):
    """
    Calculates the continuous (diffusive) component of the characteristic function for 0DTE options.

    Parameters:
    - u: Fourier variable
    - tau: Small time to maturity
    - sigma_t: Current volatility of the asset
    - mu_tilde: Adjusted drift term in the continuous component
    - rho_t: Correlation between asset price and variance
    - alpha_q: Risk-neutral drift adjustment for volatility process
    - beta_tilde: Term for volatility skew adjustment
    - delta_tilde: Additional variance adjustment
    - eta_t: Higher moment adjustment factor for variance

    Returns:
    - The continuous component of the characteristic function value for the log-price of the asset.
    """
    
    # Drift term and Gaussian base component
    drift_term = 1j * u * (mu_tilde * tau) / (sigma_t * np.sqrt(tau))
    gaussian_term = -0.5 * u**2

    # Third moment adjustment (skewness adjustment)
    third_moment_adjustment = -1j * u**3 * (beta_tilde * rho_t) / (2 * sigma_t) * np.sqrt(tau)

    # Second, fourth, and sixth moment adjustments (kurtosis and higher-order adjustments)
    second_moment_adjustment = - u**2 * ((alpha_q + delta_tilde) / (2 * sigma_t) + beta_tilde**2 / (4 * sigma_t**2)) * tau
    fourth_moment_adjustment = (1 / 24) * (beta_tilde**2 / sigma_t**2) * u**2 * (4 * u**2 - rho_t**2 * u**2 * (3 * u**2 - 8)) * tau
    sixth_moment_adjustment = (eta_t / (6 * sigma_t)) * u**4 * tau

    # Combine adjustments
    adjustments = 1 + third_moment_adjustment + second_moment_adjustment + fourth_moment_adjustment + sixth_moment_adjustment

    # Final continuous component
    C_logXc = np.exp(drift_term + gaussian_term) * adjustments
    
    return C_logXc

# %%
import numpy as np

# Parameters calculated outside the characteristic function
def calculate_characteristic_params(sigma_t, tau, lambda_t, mu_j, sigma_j, mu_tilde, rho_t, 
                                    alpha_q, beta_tilde, delta_tilde, eta_t, mu_bar_j):
    """
    Calculates pre-computed terms for the characteristic function to be used in Fourier pricing.
    """
    # Drift term
    drift_term_1 = 1j * mu_tilde * tau / (sigma_t * np.sqrt(tau)) 
    drift_term_2 = - 0.5

    # Jump component
    jump_mean = np.exp(1j * mu_j / (sigma_t * np.sqrt(tau))) - 1
    jump_variance = - (sigma_j**2) / (2 * sigma_t**2 * tau)
    jump_component = lambda_t * tau * (np.exp(jump_mean + jump_variance) - 1 - 1j * mu_bar_j)

    # Continuous component: skew and kurtosis adjustments
    skew_adjustment = -1j * (beta_tilde * rho_t) / (2 * sigma_t) * np.sqrt(tau)

    # Splitting second_fourth_sixth_adjustments into separate terms for clarity
    second_moment_adjustment = - (alpha_q + delta_tilde) / (2 * sigma_t) * tau
    fourth_moment_adjustment = - (beta_tilde**2 / (4 * sigma_t**2)) * tau
    kurtosis_adjustment = (1 / 24) * (beta_tilde**2 / sigma_t**2) * (4 - rho_t**2 * (3 - 8)) * tau
    sixth_moment_adjustment = eta_t / (6 * sigma_t) * tau

    return drift_term_1, drift_term_2, jump_component, skew_adjustment, second_moment_adjustment, fourth_moment_adjustment, kurtosis_adjustment, sixth_moment_adjustment

# Characteristic function
def characteristic_function(u, drift_term_1, drift_term_2, jump_component, skew_adjustment, 
                            second_moment_adjustment, fourth_moment_adjustment, 
                            kurtosis_adjustment, sixth_moment_adjustment):
    """
    Complete characteristic function for 0DTE options using precomputed parameters.
    """
    
    # Jump Component
    C_logXd = np.exp(jump_component)
    
    # Continuous Component with Adjustments
    C_logXc = np.exp(drift_term_1 * u + drift_term_2 * u**2) * (1 + u**3 * skew_adjustment 
                    + u**2 * (second_moment_adjustment + fourth_moment_adjustment + kurtosis_adjustment + sixth_moment_adjustment))
    
    # Complete Characteristic Function (Product of Continuous and Discrete Components)
    characteristic_function_value = C_logXc * C_logXd
    return characteristic_function_value

# %%
import numpy as np

def characteristic_function(u, tau, sigma_t, lambda_t, mu_j, sigma_j, mu_bar_j, 
                           mu_tilde, rho_t, alpha_q, beta_tilde, delta_tilde, eta_t):
    """
    Complete characteristic function for 0DTE options with baseline specification.
    
    Parameters:
    - u: Fourier variable
    - tau: Small time to maturity
    - sigma_t: Current volatility of the asset
    - lambda_t: Jump intensity (expected number of jumps per unit time)
    - mu_j: Mean jump size (log scale)
    - sigma_j: Volatility of jumps
    - mu_bar_j: Adjusted mean jump size (log scale)
    - mu_tilde: Adjusted drift term in continuous component
    - rho_t: Correlation between asset price and variance
    - alpha_q: Risk-neutral drift adjustment
    - beta_tilde: Term for volatility skew adjustment
    - delta_tilde: Additional variance adjustment
    - eta_t: Higher moment adjustment factor for variance

    Returns:
    - The complete characteristic function value for log-price of the asset.
    """

    # Discrete Component for Jumps
    jump_mean = np.exp(1j * u * (mu_j / (sigma_t * np.sqrt(tau)))) - 1
    jump_variance = - u**2 * (sigma_j**2 / (2 * sigma_t**2 * tau))
    C_logXd = np.exp(tau * lambda_t * (np.exp(jump_mean + jump_variance) - 1 - 1j * u * mu_bar_j))

    # Continuous Component with Higher-Order Moment Adjustments
    skew_adjustment = -1j * u**3 * (beta_tilde * rho_t) / (2 * sigma_t) * np.sqrt(tau)
    second_fourth_sixth_adjustments = (
        - u**2 * ((alpha_q + delta_tilde) / (2 * sigma_t) + beta_tilde**2 / (4 * sigma_t**2)) * tau
        + (1 / 24) * (beta_tilde**2 / sigma_t**2) * u**2 * (4 * u**2 - rho_t**2 * u**2 * (3 * u**2 - 8)) * tau
        + (eta_t / (6 * sigma_t)) * u**4 * tau
    )

    # Complete Continuous Component
    drift_term = 1j * u * (mu_tilde * tau) / (sigma_t * np.sqrt(tau)) - 0.5 * u**2
    C_logXc = np.exp(drift_term) * (1 + skew_adjustment + second_fourth_sixth_adjustments)

    # Final Characteristic Function (Product of Continuous and Discrete Components)
    characteristic_function_value = C_logXc * C_logXd
    return characteristic_function_value

# %%
import numpy as np

def characteristic_function(u, tau, sigma_t, lambda_t, mu_j, sigma_j, mu_bar_j, 
                           mu_tilde, rho_t, alpha_q, beta_tilde, delta_tilde, eta_t):
    """
    Complete characteristic function for 0DTE options with baseline specification.
    
    Parameters:
    - u: Fourier variable
    - tau: Small time to maturity
    - sigma_t: Current volatility of the asset
    - lambda_t: Jump intensity (expected number of jumps per unit time)
    - mu_j: Mean jump size (log scale)
    - sigma_j: Volatility of jumps
    - mu_bar_j: Adjusted mean jump size (log scale)
    - mu_tilde: Adjusted drift term in continuous component
    - rho_t: Correlation between asset price and variance
    - alpha_q: Risk-neutral drift adjustment
    - beta_tilde: Term for volatility skew adjustment
    - delta_tilde: Additional variance adjustment
    - eta_t: Higher moment adjustment factor for variance

    Returns:
    - The complete characteristic function value for log-price of the asset.
    """

    # Discrete Component for Jumps
    jump_mean = np.exp(1j * u * (mu_j / (sigma_t * np.sqrt(tau))))
    jump_variance = - u**2 * (sigma_j**2 / (2 * sigma_t**2 * tau))

    # Compensator term for risk-neutral measure (from the paper)
    mu_bar_j = np.exp(mu_j / (sigma_t * np.sqrt(tau)) + sigma_j**2 / (2 * sigma_t**2 * tau)) - 1

    # Full discrete component characteristic function
    C_logXd = np.exp(tau * lambda_t * (jump_mean + jump_variance - 1 - 1j * u * mu_bar_j))

    # Continuous Component with Higher-Order Moment Adjustments
    skew_adjustment = -1j * u**3 * (beta_tilde * rho_t) / (2 * sigma_t) * np.sqrt(tau)
    second_fourth_sixth_adjustments = (
        - u**2 * ((alpha_q + delta_tilde) / (2 * sigma_t) + beta_tilde**2 / (4 * sigma_t**2)) * tau
        + (1 / 24) * (beta_tilde**2 / sigma_t**2) * u**2 * (4 * u**2 - rho_t**2 * u**2 * (3 * u**2 - 8)) * tau
        + (eta_t / (6 * sigma_t)) * u**4 * tau
    )

    # Complete Continuous Component
    drift_term = 1j * u * (mu_tilde * tau) / (sigma_t * np.sqrt(tau)) - 0.5 * u**2
    C_logXc = np.exp(drift_term) * (1 + skew_adjustment + second_fourth_sixth_adjustments)

    # Final Characteristic Function (Product of Continuous and Discrete Components)
    characteristic_function_value = C_logXc * C_logXd
    return characteristic_function_value

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from scipy.stats import norm
from scipy.integrate import quad
import matplotlib.pyplot as plt
from scipy.stats import qmc

# %%
class ODTE_ANN(nn.Module):
    def __init__(self):
        super(ODTE_ANN, self).__init__()
        # Neural network layers
        self.fc1 = nn.Linear(4, 400)
        self.fc2 = nn.Linear(400, 400)
        self.fc3 = nn.Linear(400, 400)
        self.fc4 = nn.Linear(400, 1)
        
        # Xavier initialization
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.xavier_uniform_(self.fc2.weight)
        nn.init.xavier_uniform_(self.fc3.weight)
        nn.init.xavier_uniform_(self.fc4.weight)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        return self.fc4(x)
    
    def train_model(self, args, device, train_loader, optimizer, epoch):
        self.train()
        train_loss = 0
        for batch_idx, data in enumerate(train_loader):
            inputs, targets = data[:,:-1].to(device), data[:,-1].to(device)
            optimizer.zero_grad()
            output = self(inputs)
            loss = F.mse_loss(output, targets)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        return train_loss

    def test_model(self, device, test_loader):
        self.eval()
        test_loss = 0
        with torch.no_grad():
            for data in test_loader:
                inputs, targets = data[:,:-1].to(device), data[:,-1].to(device)
                output = self(inputs)
                test_loss += F.mse_loss(output, targets)
        return test_loss

# %%
def bs_moneyness_call(moneyness, tau, r, sigma):
    d1 = (np.log(moneyness) + (r + 0.5 * sigma ** 2) * tau) / (sigma * np.sqrt(tau))
    d2 = d1 - sigma * np.sqrt(tau)
    value_moneyness = moneyness * norm.cdf(d1) - np.exp(-r * tau) * norm.cdf(d2)
    return value_moneyness

def bs_LHS_data_generator(n=10**4, l_bounds=[.4, .2, .02, .01], u_bounds=[1.6, 1.1, .1, 1]):
    sampler = qmc.LatinHypercube(d=4)
    sample = sampler.random(n)
    sample = qmc.scale(sample, l_bounds, u_bounds)
    bs_prices = bs_moneyness_call(sample[:, 0], sample[:, 1], sample[:, 2], sample[:, 3]).reshape((-1, 1))
    bs_dataset = np.concatenate((sample, bs_prices), axis=1)
    return torch.FloatTensor(bs_dataset)

# %%
# Out:
# cuda

# %%
# Parameters
S_t = 100
K = 105
r = 0.05
sigma = 0.2
tau = 0.02

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)

# Baseline Pricing
price_baseline = sinc_pricing(K, S_t, r, sigma, tau)
print(f"Baseline Price: {price_baseline}")

# Second Specification Pricing (with volatility jumps)
lambda_sigma = 0.1
rho_J = 0.3
s_sigma = 0.05
price_second = sinc_pricing(K, S_t, r, sigma, tau, lambda_sigma, rho_J, s_sigma, is_second=True)
print(f"Second Spec Price: {price_second}")

# Initialize the Neural Network Model
model = ODTE_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Load and split dataset
bs_dataset = bs_LHS_data_generator(n=10**4)
train_size = int(0.9 * bs_dataset.shape[0])
test_size = bs_dataset.shape[0] - train_size
train_dataset, test_dataset = torch.utils.data.random_split(bs_dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1024)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1024)

# Train the model
for epoch in range(1, 201):
    train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
    test_loss = model.test_model(device, test_loader)
    print(f'Epoch {epoch}: Train Loss: {train_loss}, Test Loss: {test_loss}')
# Out:
# cuda
# Baseline Price: nan
# Second Spec Price: nan
# C:\Users\Dominik\AppData\Local\Temp\ipykernel_9164\1882450711.py:14: RuntimeWarning: divide by zero encountered in divide
#   integrand = np.exp(-1j * k_values * np.log(K)) * cf_values / (1j * k_values)
# C:\Users\Dominik\AppData\Local\Temp\ipykernel_9164\1882450711.py:14: RuntimeWarning: invalid value encountered in divide
#   integrand = np.exp(-1j * k_values * np.log(K)) * cf_values / (1j * k_values)
# C:\Users\Dominik\AppData\Local\Temp\ipykernel_9164\1882450711.py:17: RuntimeWarning: invalid value encountered in scalar multiply
#   price = (h / (2 * np.pi)) * np.sum(integrand)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[40], line 24
#      21 print(f"Second Spec Price: {price_second}")
#      23 # Initialize the Neural Network Model
# ---> 24 model = ODTE_ANN().to(device)
#      25 optimizer = optim.Adam(model.parameters(), lr=0.001)
#      27 # Load and split dataset
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\torch\nn\modules\module.py:1160, in Module.to(self, *args, **kwargs)
#    1156         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1157                     non_blocking, memory_format=convert_to_format)
#    1158     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1160 return self._apply(convert)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\torch\nn\modules\module.py:810, in Module._apply(self, fn, recurse)
#     808 if recurse:
#     809     for module in self.children():
# --> 810         module._apply(fn)
#     812 def compute_should_use_set_data(tensor, tensor_applied):
#     813     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     814         # If the new tensor has compatible tensor type as the existing tensor,
#     815         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     820         # global flag to let the user control whether they want the future
#     821         # behavior of overwriting the existing tensor or not.
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\torch\nn\modules\module.py:833, in Module._apply(self, fn, recurse)
#     829 # Tensors stored in modules are graph leaves, and we don't want to
#     830 # track autograd history of `param_applied`, so we have to use
#     831 # `with torch.no_grad():`
#     832 with torch.no_grad():
# --> 833     param_applied = fn(param)
#     834 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     835 if should_use_set_data:
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\torch\nn\modules\module.py:1158, in Module.to.<locals>.convert(t)
#    1155 if convert_to_format is not None and t.dim() in (4, 5):
#    1156     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1157                 non_blocking, memory_format=convert_to_format)
# -> 1158 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# RuntimeError: CUDA error: unknown error
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
import numpy as np
from scipy.integrate import quad
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
from scipy.stats import norm
from scipy import integrate
import matplotlib.pyplot as plt
from scipy.stats import qmc
from torch.optim.lr_scheduler import StepLR, LinearLR, OneCycleLR, LambdaLR

def characteristic_function(u, tau, S0, r, sigma, lambda_jump, mu_jump, sigma_jump, 
                            rho, vol_of_vol, lambda_vol_jump, sigma_vol_jump):
    """
    Complete characteristic function for 0DTE option pricing with jumps in both price and volatility.
    u: Fourier variable
    tau: time to maturity (0DTE means tau is very small)
    S0: initial stock price
    r: risk-free rate
    sigma: initial volatility
    lambda_jump: intensity of price jumps
    mu_jump: mean of price jumps
    sigma_jump: volatility of price jumps
    rho: correlation between price and volatility
    vol_of_vol: volatility of volatility (vol-vol)
    lambda_vol_jump: intensity of volatility jumps
    sigma_vol_jump: volatility of volatility jumps
    """
    # Adjusted drift to account for jumps in price
    drift_adj = r - 0.5 * sigma**2 - lambda_jump * (np.exp(mu_jump + 0.5 * sigma_jump**2) - 1)

    # Continuous part of the characteristic function
    continuous_part = np.exp(1j * u * (np.log(S0) + drift_adj * tau) - 0.5 * u**2 * sigma**2 * tau)
    
    # Jump component for prices
    price_jump_part = np.exp(tau * lambda_jump * (np.exp(1j * u * mu_jump - 0.5 * u**2 * sigma_jump**2) - 1))
    
    # Jump component for volatility
    vol_jump_part = np.exp(tau * lambda_vol_jump * (np.exp(-0.5 * u**2 * sigma_vol_jump**2) - 1))

    # Skewness and kurtosis from leverage and volatility of volatility
    skew_kurt_part = np.exp(1j * u * rho * vol_of_vol * np.sqrt(tau) - 0.5 * (u**2 * vol_of_vol**2 * tau))
    
    # Complete characteristic function combining all components
    total_char_func = continuous_part * price_jump_part * vol_jump_part * skew_kurt_part
    
    return total_char_func

# %%
def zeroDTE_option_price(S0, K, tau, r, sigma, lambda_jump, mu_jump, sigma_jump, 
                      rho, vol_of_vol, lambda_vol_jump, sigma_vol_jump):
    """
    Compute the 0DTE option price using Fourier inversion.
    S0: initial stock price
    K: strike price
    tau: time to maturity (very small for 0DTE)
    r: risk-free rate
    sigma: volatility
    Other parameters correspond to jumps and volatility jumps.
    """
    # Strike price in terms of log-moneyness
    log_moneyness = np.log(S0 / K)

    # Integrand function for Fourier inversion
    def integrand(u):
        cf = characteristic_function(u - 1j, tau, S0, r, sigma, lambda_jump, mu_jump, sigma_jump, 
                                     rho, vol_of_vol, lambda_vol_jump, sigma_vol_jump)
        return np.real(np.exp(-1j * u * log_moneyness) * cf / (1j * u))

    # Integration bounds
    integral = quad(integrand, 0, np.inf, limit=200)[0]
    
    # Final price using Fourier inversion formula
    price = S0 * np.exp(-r * tau) * (0.5 + integral / np.pi)
    return price

# %%
def generate_0DTE_data(n=10**6, l_bounds=[0.8, 0.001, 0.01, 0.01], u_bounds=[1.2, 0.01, 0.03, 0.5]):
    """
    Generate samples of 0DTE option prices using Latin hypercube sampling.
    Returns a torch tensor of dimension (n, 5) containing the inputs and option prices.
    n: number of samples
    l_bounds: lower bounds for the inputs
    u_bounds: upper bounds for the inputs
    """
    sampler = qmc.LatinHypercube(d=4)
    sample = sampler.random(n)
    sample = qmc.scale(sample, l_bounds, u_bounds)

    S0, K, tau, sigma = sample[:, 0], sample[:, 0] * np.random.uniform(0.9, 1.1, size=n), sample[:, 1], sample[:, 3]
    
    # Jumps and volatility of volatility parameters (randomly sampled)
    lambda_jump = np.random.uniform(0.01, 0.5, n)
    mu_jump = np.random.uniform(-0.1, 0.1, n)
    sigma_jump = np.random.uniform(0.1, 0.3, n)
    rho = np.random.uniform(-0.5, 0, n)
    vol_of_vol = np.random.uniform(0.1, 0.4, n)
    lambda_vol_jump = np.random.uniform(0.01, 0.2, n)
    sigma_vol_jump = np.random.uniform(0.05, 0.15, n)
    
    prices = np.array([zeroDTE_option_price(S0[i], K[i], tau[i], 0.01, sigma[i], 
                                         lambda_jump[i], mu_jump[i], sigma_jump[i], 
                                         rho[i], vol_of_vol[i], lambda_vol_jump[i], sigma_vol_jump[i])
                       for i in range(n)])
    
    bs_dataset = np.column_stack((S0/K, tau, 0.01, sigma, prices / K))
    return torch.FloatTensor(bs_dataset)

# %%
# Black-Scholes ANN Model (baseline)
class BS_ANN(nn.Module):
    def __init__(self):
        """
        Initializes a 5-layer neural network model for option pricing.
        Input: [S/K, time to maturity, risk-free rate, volatility]
        Output: [Option price]
        """
        super(BS_ANN, self).__init__()
        self.fc1 = nn.Linear(4, 400)
        self.fc2 = nn.Linear(400, 400)
        self.fc3 = nn.Linear(400, 400)
        self.fc4 = nn.Linear(400, 400)
        self.fc5 = nn.Linear(400, 1)
        
        # Xavier uniform initialization
        torch.nn.init.xavier_uniform_(self.fc1.weight)
        torch.nn.init.xavier_uniform_(self.fc2.weight)
        torch.nn.init.xavier_uniform_(self.fc3.weight)
        torch.nn.init.xavier_uniform_(self.fc4.weight)
        torch.nn.init.xavier_uniform_(self.fc5.weight)

    def forward(self, x):
        """
        Forward pass through the neural network.
        ReLU activation is used for hidden layers and linear for output.
        """
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        return self.fc5(x).flatten()

# Training function for the ANN
def train_model(model, args, device, train_loader, optimizer, epoch):
    """
    Training loop for one epoch.
    model: the neural network to train.
    args: training parameters.
    device: CUDA or CPU.
    train_loader: training data loader.
    optimizer: optimization algorithm.
    epoch: current epoch number.
    """
    model.train()
    train_loss = 0

    for batch_idx, data in enumerate(train_loader):
        data, target = data[:, :-1].to(device), data[:, -1].to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.mse_loss(output, target)
        train_loss += loss.item() * data.shape[0]
        loss.backward()
        optimizer.step()

        if batch_idx % args["log_interval"] == 0:
            print(f'Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} '
                  f'({100. * batch_idx / len(train_loader):.0f}%)] Loss: {loss.item():.6f}')

    train_loss /= len(train_loader.dataset)
    print(f'\nTrain set: Average loss: {train_loss:.4f}')
    return train_loss

# Testing function for the ANN
def test_model(model, device, test_loader):
    """
    Test the model on test_loader dataset.
    device: CUDA or CPU.
    test_loader: testing data loader.
    """
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for data in test_loader:
            data, target = data[:, :-1].to(device), data[:, -1].to(device)
            output = model(data)
            test_loss += F.mse_loss(output, target, reduction='sum').item()

    test_loss /= len(test_loader.dataset)
    print(f'\nTest set: Average loss: {test_loss:.4f}')
    return test_loss

# %%
# Use your existing BS_ANN architecture

# Hyperparameters and device configuration
args = {
    "batch_size": 1024,
    "test_batch_size": 1024,
    "epochs": 200,
    "lr": 1e-3,  # Initial learning rate
    "gamma": 0.9,  # Learning rate decay factor
    "no_cuda": False,
    "log_interval": 10,
    "save_model": False
}

# Set up the device (GPU/CPU)
use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# Data generation
bs_dataset = generate_0DTE_data(n=10**4)

# Splitting and loading data
train_size, test_size = int(bs_dataset.shape[0] * 0.9), int(bs_dataset.shape[0] * 0.1)
train_dataset, test_dataset = torch.utils.data.random_split(bs_dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=args["test_batch_size"])

# Model training
model = BS_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=args["lr"])
scheduler = LambdaLR(optimizer, lr_lambda=lambda epoch: 10**(-9 + epoch * 10 / (args["epochs"] - 1)))

train_losses = []
test_losses = []
lrs = []

# Training loop
for epoch in range(1, args["epochs"] + 1):
    print(f"Current Learning Rate: {scheduler.get_last_lr()[0]}")
    lrs.append(scheduler.get_last_lr()[0])
    train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
    test_loss = model.test_model(device, test_loader)
    scheduler.step()
    train_losses.append(train_loss)
    test_losses.append(test_loss)

# Optionally save the model
if args["save_model"]:
    torch.save(model.state_dict(), "0DTE_ANN_model.pt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 19
#      17 device = torch.device("cuda" if use_cuda else "cpu")
#      18 # Data generation
# ---> 19 bs_dataset = generate_0DTE_data(n=10**4)
#      21 # Splitting and loading data
#      22 train_size, test_size = int(bs_dataset.shape[0] * 0.9), int(bs_dataset.shape[0] * 0.1)
#
# Cell In[21], line 29, in generate_0DTE_data(n, l_bounds, u_bounds)
#      22 sigma_vol_jump = np.random.uniform(0.05, 0.15, n)
#      24 prices = np.array([zeroDTE_option_price(S0[i], K[i], tau[i], 0.01, sigma[i],
#      25                                      lambda_jump[i], mu_jump[i], sigma_jump[i],
#      26                                      rho[i], vol_of_vol[i], lambda_vol_jump[i], sigma_vol_jump[i])
#      27                    for i in range(n)])
# ---> 29 bs_dataset = np.column_stack((S0/K, tau, 0.01, sigma, prices / K))
#      30 return torch.FloatTensor(bs_dataset)
#
# File <__array_function__ internals>:200, in column_stack(*args, **kwargs)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\numpy\lib\shape_base.py:656, in column_stack(tup)
#     654         arr = array(arr, copy=False, subok=True, ndmin=2).T
#     655     arrays.append(arr)
# --> 656 return _nx.concatenate(arrays, 1)
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 10000 and the array at index 2 has size 1

# %%
# Required imports


# Define the Black-Scholes price function (baseline)
def bs_moneyness_call(moneyness, tau, r, sigma):
    """
    Black-Scholes price for European call option in terms of moneyness.

    Parameters:
    moneyness: S/K, ratio of spot price to strike price
    tau: Time to maturity
    r: Risk-free interest rate
    sigma: Volatility of underlying asset

    Returns:
    The price of a call option.
    """
    d1 = (np.log(moneyness) + (r + 0.5 * sigma ** 2) * tau) / (sigma * np.sqrt(tau))
    d2 = d1 - sigma * np.sqrt(tau)
    value_moneyness = moneyness * norm.cdf(d1) - np.exp(-r * tau) * norm.cdf(d2)

    return value_moneyness

# Data generation function using Latin Hypercube Sampling
def bs_LHS_data_generator(n=10**6, l_bounds=[.4, .2, .02, .01], u_bounds=[1.6, 1.1, .1, 1]):
    """
    Generates samples of call prices using Latin hypercube sampling.

    Parameters:
    n: number of samples.
    l_bounds: lower bounds for the inputs.
    u_bounds: upper bounds for the inputs.

    Returns:
    A torch float tensor of shape (n, 5) containing input samples and corresponding option prices.
    """
    sampler = qmc.LatinHypercube(d=4)
    sample = sampler.random(n)
    sample = qmc.scale(sample, l_bounds, u_bounds)
    bs_prices = bs_moneyness_call(sample[:, 0], sample[:, 1], sample[:, 2], sample[:, 3]).reshape((-1, 1))
    bs_dataset = np.concatenate((sample, bs_prices), axis=1)

    print("------ INPUT ------")
    print(f"S/K.......... [{min(bs_dataset[:,0]):.2f} {max(bs_dataset[:,0]):.2f}]")
    print(f"Tau.......... [{min(bs_dataset[:,1]):.2f} {max(bs_dataset[:,1]):.2f}]")
    print(f"r............ [{min(bs_dataset[:,2]):.2f} {max(bs_dataset[:,2]):.2f}]")
    print(f"Sigma........ [{min(bs_dataset[:,3]):.2f} {max(bs_dataset[:,3]):.2f}]")
    print("------ OUTPUT ------")
    print(f"V/K.......... [{min(bs_dataset[:,4]):.2f} {max(bs_dataset[:,4]):.2f}]")

    return torch.FloatTensor(bs_dataset)

# Black-Scholes ANN Model (baseline)
class BS_ANN(nn.Module):
    def __init__(self):
        """
        Initializes a 5-layer neural network model for option pricing.
        Input: [S/K, time to maturity, risk-free rate, volatility]
        Output: [Option price]
        """
        super(BS_ANN, self).__init__()
        self.fc1 = nn.Linear(4, 400)
        self.fc2 = nn.Linear(400, 400)
        self.fc3 = nn.Linear(400, 400)
        self.fc4 = nn.Linear(400, 400)
        self.fc5 = nn.Linear(400, 1)
        
        # Xavier uniform initialization
        torch.nn.init.xavier_uniform_(self.fc1.weight)
        torch.nn.init.xavier_uniform_(self.fc2.weight)
        torch.nn.init.xavier_uniform_(self.fc3.weight)
        torch.nn.init.xavier_uniform_(self.fc4.weight)
        torch.nn.init.xavier_uniform_(self.fc5.weight)

    def forward(self, x):
        """
        Forward pass through the neural network.
        ReLU activation is used for hidden layers and linear for output.
        """
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        return self.fc5(x).flatten()

# Training function for the ANN
def train_model(model, args, device, train_loader, optimizer, epoch):
    """
    Training loop for one epoch.
    model: the neural network to train.
    args: training parameters.
    device: CUDA or CPU.
    train_loader: training data loader.
    optimizer: optimization algorithm.
    epoch: current epoch number.
    """
    model.train()
    train_loss = 0

    for batch_idx, data in enumerate(train_loader):
        data, target = data[:, :-1].to(device), data[:, -1].to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.mse_loss(output, target)
        train_loss += loss.item() * data.shape[0]
        loss.backward()
        optimizer.step()

        if batch_idx % args["log_interval"] == 0:
            print(f'Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} '
                  f'({100. * batch_idx / len(train_loader):.0f}%)] Loss: {loss.item():.6f}')

    train_loss /= len(train_loader.dataset)
    print(f'\nTrain set: Average loss: {train_loss:.4f}')
    return train_loss

# Testing function for the ANN
def test_model(model, device, test_loader):
    """
    Test the model on test_loader dataset.
    device: CUDA or CPU.
    test_loader: testing data loader.
    """
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for data in test_loader:
            data, target = data[:, :-1].to(device), data[:, -1].to(device)
            output = model(data)
            test_loss += F.mse_loss(output, target, reduction='sum').item()

    test_loss /= len(test_loader.dataset)
    print(f'\nTest set: Average loss: {test_loss:.4f}')
    return test_loss

# Characteristic function (used for SINC method)
def characteristic_function_baseline(u, tau, r, sigma):
    """
    Characteristic function for the Black-Scholes model.
    
    Parameters:
    u: Fourier variable
    tau: Time to maturity
    r: Risk-free rate
    sigma: Volatility
    
    Returns:
    The characteristic function value.
    """
    return np.exp((1j * u * (r - 0.5 * sigma ** 2) * tau) - 0.5 * u**2 * sigma**2 * tau)

# SINC method for option pricing
def sinc_method_option_price(K, tau, r, sigma):
    """
    Uses the SINC method for Fourier inversion to price options.
    
    Parameters:
    K: Strike price
    tau: Time to maturity
    r: Risk-free rate
    sigma: Volatility
    
    Returns:
    Option price via SINC method.
    """
    def characteristic_function(u):
        return characteristic_function_baseline(u, tau, r, sigma)

    # Fourier inversion via SINC method
    cf_values = characteristic_function(K)
    sinc_kernel = np.sinc(K)
    integrand_values = np.real(np.dot(cf_values, sinc_kernel))  # Real part for pricing
    return integrand_values

# Hyperparameters and device configuration
args = {
    "batch_size": 1024,
    "test_batch_size": 1024,
    "epochs": 200,
    "lr": 1e-3,  # Initial learning rate
    "gamma": 0.9,  # Learning rate decay factor
    "no_cuda": False,
    "log_interval": 10,
    "save_model": False
}

# Set up the device (GPU/CPU)
use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# Load dataset
bs_dataset = bs_LHS_data_generator(n=10**4)
train_size = int(0.9 * bs_dataset.shape[0])
test_size = bs_dataset.shape[0] - train_size
train_dataset, test_dataset = torch.utils.data.random_split(bs_dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=args["batch_size"])
test_loader = DataLoader(test_dataset, batch_size=args["test_batch_size"])

# Initialize model and optimizer
model = BS_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=args["lr"])

# Learning rate scheduler to decay the learning rate
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=args["gamma"])

# Lists to store losses and learning rates
train_losses = []
test_losses = []
lrs = []

# Training loop over epochs
for epoch in range(1, args["epochs"] + 1):
    # Print and store the current learning rate
    print(f"Epoch {epoch}: Current Learning rate {scheduler.get_last_lr()[0]}")
    lrs.append(scheduler.get_last_lr()[0])
    
    # Train the model
    train_loss = train_model(model, args, device, train_loader, optimizer, epoch)
    test_loss = test_model(model, device, test_loader)
    
    # Step the learning rate scheduler
    scheduler.step()
    
    # Store losses
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    
    # Optionally save model at intervals
    if args["save_model"] and epoch % 100 == 0:
        torch.save(model.state_dict(), f"BS_ANN_Epoch_{epoch}.pt")
# Out:
# ------ INPUT ------
# S/K.......... [0.40 1.60]
# Tau.......... [0.20 1.10]
# r............ [0.02 0.10]
# Sigma........ [0.01 1.00]
# ------ OUTPUT ------
# V/K.......... [0.00 0.88]
# Epoch 1: Current Learning rate 0.001
# Train Epoch: 1 [0/9000 (0%)] Loss: 0.052128
#
# Train set: Average loss: 0.0961
#
# Test set: Average loss: 0.0418
# Epoch 2: Current Learning rate 0.001
# Train Epoch: 2 [0/9000 (0%)] Loss: 0.043486
#
# Train set: Average loss: 0.0314
#
# Test set: Average loss: 0.0159
# Epoch 3: Current Learning rate 0.001
# Train Epoch: 3 [0/9000 (0%)] Loss: 0.015642
#
# Train set: Average loss: 0.0077
#
# Test set: Average loss: 0.0036
# Epoch 4: Current Learning rate 0.001
# Train Epoch: 4 [0/9000 (0%)] Loss: 0.003783
#
# Train set: Average loss: 0.0028
#
# Test set: Average loss: 0.0019
# Epoch 5: Current Learning rate 0.001
# Train Epoch: 5 [0/9000 (0%)] Loss: 0.002067
#
# Train set: Average loss: 0.0015
#
# Test set: Average loss: 0.0010
# Epoch 6: Current Learning rate 0.001
# Train Epoch: 6 [0/9000 (0%)] Loss: 0.001082
#
# Train set: Average loss: 0.0009
#
# Test set: Average loss: 0.0008
# Epoch 7: Current Learning rate 0.001
# Train Epoch: 7 [0/9000 (0%)] Loss: 0.000780
#
# Train set: Average loss: 0.0006
#
# Test set: Average loss: 0.0005
# Epoch 8: Current Learning rate 0.001
# Train Epoch: 8 [0/9000 (0%)] Loss: 0.000529
#
# Train set: Average loss: 0.0004
#
# Test set: Average loss: 0.0003
# Epoch 9: Current Learning rate 0.001
# Train Epoch: 9 [0/9000 (0%)] Loss: 0.000369
#
# Train set: Average loss: 0.0003
#
# Test set: Average loss: 0.0002
# Epoch 10: Current Learning rate 0.001
# Train Epoch: 10 [0/9000 (0%)] Loss: 0.000272
#
# Train set: Average loss: 0.0002
#
# Test set: Average loss: 0.0002
# Epoch 11: Current Learning rate 0.0009000000000000001
# Train Epoch: 11 [0/9000 (0%)] Loss: 0.000218
#
# Train set: Average loss: 0.0002
#
# Test set: Average loss: 0.0002
# Epoch 12: Current Learning rate 0.0009000000000000001
# Train Epoch: 12 [0/9000 (0%)] Loss: 0.000177
#
# Train set: Average loss: 0.0002
#
# Test set: Average loss: 0.0001
# Epoch 13: Current Learning rate 0.0009000000000000001
# Train Epoch: 13 [0/9000 (0%)] Loss: 0.000145
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0001
# Epoch 14: Current Learning rate 0.0009000000000000001
# Train Epoch: 14 [0/9000 (0%)] Loss: 0.000119
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0001
# Epoch 15: Current Learning rate 0.0009000000000000001
# Train Epoch: 15 [0/9000 (0%)] Loss: 0.000098
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0001
# Epoch 16: Current Learning rate 0.0009000000000000001
# Train Epoch: 16 [0/9000 (0%)] Loss: 0.000089
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0001
# Epoch 17: Current Learning rate 0.0009000000000000001
# Train Epoch: 17 [0/9000 (0%)] Loss: 0.000082
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0001
# Epoch 18: Current Learning rate 0.0009000000000000001
# Train Epoch: 18 [0/9000 (0%)] Loss: 0.000074
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0001
# Epoch 19: Current Learning rate 0.0009000000000000001
# Train Epoch: 19 [0/9000 (0%)] Loss: 0.000092
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0002
# Epoch 20: Current Learning rate 0.0009000000000000001
# Train Epoch: 20 [0/9000 (0%)] Loss: 0.000145
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0001
# Epoch 21: Current Learning rate 0.0008100000000000001
# Train Epoch: 21 [0/9000 (0%)] Loss: 0.000134
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0001
# Epoch 22: Current Learning rate 0.0008100000000000001
# Train Epoch: 22 [0/9000 (0%)] Loss: 0.000109
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0001
# Epoch 23: Current Learning rate 0.0008100000000000001
# Train Epoch: 23 [0/9000 (0%)] Loss: 0.000062
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0000
# Epoch 24: Current Learning rate 0.0008100000000000001
# Train Epoch: 24 [0/9000 (0%)] Loss: 0.000053
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0001
# Epoch 25: Current Learning rate 0.0008100000000000001
# Train Epoch: 25 [0/9000 (0%)] Loss: 0.000062
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0000
# Epoch 26: Current Learning rate 0.0008100000000000001
# Train Epoch: 26 [0/9000 (0%)] Loss: 0.000056
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0000
# Epoch 27: Current Learning rate 0.0008100000000000001
# Train Epoch: 27 [0/9000 (0%)] Loss: 0.000045
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0001
# Epoch 28: Current Learning rate 0.0008100000000000001
# Train Epoch: 28 [0/9000 (0%)] Loss: 0.000133
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0001
# Epoch 29: Current Learning rate 0.0008100000000000001
# Train Epoch: 29 [0/9000 (0%)] Loss: 0.000050
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 30: Current Learning rate 0.0008100000000000001
# Train Epoch: 30 [0/9000 (0%)] Loss: 0.000039
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0003
# Epoch 31: Current Learning rate 0.000729
# Train Epoch: 31 [0/9000 (0%)] Loss: 0.000276
#
# Train set: Average loss: 0.0002
#
# Test set: Average loss: 0.0001
# Epoch 32: Current Learning rate 0.000729
# Train Epoch: 32 [0/9000 (0%)] Loss: 0.000089
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0000
# Epoch 33: Current Learning rate 0.000729
# Train Epoch: 33 [0/9000 (0%)] Loss: 0.000039
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0000
# Epoch 34: Current Learning rate 0.000729
# Train Epoch: 34 [0/9000 (0%)] Loss: 0.000041
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 35: Current Learning rate 0.000729
# Train Epoch: 35 [0/9000 (0%)] Loss: 0.000052
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 36: Current Learning rate 0.000729
# Train Epoch: 36 [0/9000 (0%)] Loss: 0.000033
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 37: Current Learning rate 0.000729
# Train Epoch: 37 [0/9000 (0%)] Loss: 0.000032
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 38: Current Learning rate 0.000729
# Train Epoch: 38 [0/9000 (0%)] Loss: 0.000030
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 39: Current Learning rate 0.000729
# Train Epoch: 39 [0/9000 (0%)] Loss: 0.000030
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0001
# Epoch 40: Current Learning rate 0.000729
# Train Epoch: 40 [0/9000 (0%)] Loss: 0.000048
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 41: Current Learning rate 0.0006561000000000001
# Train Epoch: 41 [0/9000 (0%)] Loss: 0.000040
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 42: Current Learning rate 0.0006561000000000001
# Train Epoch: 42 [0/9000 (0%)] Loss: 0.000029
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 43: Current Learning rate 0.0006561000000000001
# Train Epoch: 43 [0/9000 (0%)] Loss: 0.000030
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 44: Current Learning rate 0.0006561000000000001
# Train Epoch: 44 [0/9000 (0%)] Loss: 0.000025
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 45: Current Learning rate 0.0006561000000000001
# Train Epoch: 45 [0/9000 (0%)] Loss: 0.000025
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 46: Current Learning rate 0.0006561000000000001
# Train Epoch: 46 [0/9000 (0%)] Loss: 0.000025
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 47: Current Learning rate 0.0006561000000000001
# Train Epoch: 47 [0/9000 (0%)] Loss: 0.000030
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 48: Current Learning rate 0.0006561000000000001
# Train Epoch: 48 [0/9000 (0%)] Loss: 0.000031
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 49: Current Learning rate 0.0006561000000000001
# Train Epoch: 49 [0/9000 (0%)] Loss: 0.000033
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0004
# Epoch 50: Current Learning rate 0.0006561000000000001
# Train Epoch: 50 [0/9000 (0%)] Loss: 0.000417
#
# Train set: Average loss: 0.0003
#
# Test set: Average loss: 0.0002
# Epoch 51: Current Learning rate 0.00059049
# Train Epoch: 51 [0/9000 (0%)] Loss: 0.000213
#
# Train set: Average loss: 0.0001
#
# Test set: Average loss: 0.0000
# Epoch 52: Current Learning rate 0.00059049
# Train Epoch: 52 [0/9000 (0%)] Loss: 0.000026
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 53: Current Learning rate 0.00059049
# Train Epoch: 53 [0/9000 (0%)] Loss: 0.000042
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 54: Current Learning rate 0.00059049
# Train Epoch: 54 [0/9000 (0%)] Loss: 0.000025
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 55: Current Learning rate 0.00059049
# Train Epoch: 55 [0/9000 (0%)] Loss: 0.000020
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 56: Current Learning rate 0.00059049
# Train Epoch: 56 [0/9000 (0%)] Loss: 0.000021
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 57: Current Learning rate 0.00059049
# Train Epoch: 57 [0/9000 (0%)] Loss: 0.000020
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 58: Current Learning rate 0.00059049
# Train Epoch: 58 [0/9000 (0%)] Loss: 0.000020
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 59: Current Learning rate 0.00059049
# Train Epoch: 59 [0/9000 (0%)] Loss: 0.000019
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 60: Current Learning rate 0.00059049
# Train Epoch: 60 [0/9000 (0%)] Loss: 0.000018
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 61: Current Learning rate 0.000531441
# Train Epoch: 61 [0/9000 (0%)] Loss: 0.000018
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 62: Current Learning rate 0.000531441
# Train Epoch: 62 [0/9000 (0%)] Loss: 0.000018
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 63: Current Learning rate 0.000531441
# Train Epoch: 63 [0/9000 (0%)] Loss: 0.000017
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 64: Current Learning rate 0.000531441
# Train Epoch: 64 [0/9000 (0%)] Loss: 0.000017
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 65: Current Learning rate 0.000531441
# Train Epoch: 65 [0/9000 (0%)] Loss: 0.000017
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 66: Current Learning rate 0.000531441
# Train Epoch: 66 [0/9000 (0%)] Loss: 0.000017
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 67: Current Learning rate 0.000531441
# Train Epoch: 67 [0/9000 (0%)] Loss: 0.000017
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 68: Current Learning rate 0.000531441
# Train Epoch: 68 [0/9000 (0%)] Loss: 0.000016
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 69: Current Learning rate 0.000531441
# Train Epoch: 69 [0/9000 (0%)] Loss: 0.000016
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 70: Current Learning rate 0.000531441
# Train Epoch: 70 [0/9000 (0%)] Loss: 0.000016
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 71: Current Learning rate 0.0004782969
# Train Epoch: 71 [0/9000 (0%)] Loss: 0.000016
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 72: Current Learning rate 0.0004782969
# Train Epoch: 72 [0/9000 (0%)] Loss: 0.000016
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 73: Current Learning rate 0.0004782969
# Train Epoch: 73 [0/9000 (0%)] Loss: 0.000015
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 74: Current Learning rate 0.0004782969
# Train Epoch: 74 [0/9000 (0%)] Loss: 0.000015
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 75: Current Learning rate 0.0004782969
# Train Epoch: 75 [0/9000 (0%)] Loss: 0.000015
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 76: Current Learning rate 0.0004782969
# Train Epoch: 76 [0/9000 (0%)] Loss: 0.000015
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 77: Current Learning rate 0.0004782969
# Train Epoch: 77 [0/9000 (0%)] Loss: 0.000015
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 78: Current Learning rate 0.0004782969
# Train Epoch: 78 [0/9000 (0%)] Loss: 0.000015
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 79: Current Learning rate 0.0004782969
# Train Epoch: 79 [0/9000 (0%)] Loss: 0.000014
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 80: Current Learning rate 0.0004782969
# Train Epoch: 80 [0/9000 (0%)] Loss: 0.000014
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 81: Current Learning rate 0.00043046721
# Train Epoch: 81 [0/9000 (0%)] Loss: 0.000014
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 82: Current Learning rate 0.00043046721
# Train Epoch: 82 [0/9000 (0%)] Loss: 0.000014
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 83: Current Learning rate 0.00043046721
# Train Epoch: 83 [0/9000 (0%)] Loss: 0.000014
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 84: Current Learning rate 0.00043046721
# Train Epoch: 84 [0/9000 (0%)] Loss: 0.000014
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 85: Current Learning rate 0.00043046721
# Train Epoch: 85 [0/9000 (0%)] Loss: 0.000014
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 86: Current Learning rate 0.00043046721
# Train Epoch: 86 [0/9000 (0%)] Loss: 0.000013
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 87: Current Learning rate 0.00043046721
# Train Epoch: 87 [0/9000 (0%)] Loss: 0.000013
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 88: Current Learning rate 0.00043046721
# Train Epoch: 88 [0/9000 (0%)] Loss: 0.000013
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 89: Current Learning rate 0.00043046721
# Train Epoch: 89 [0/9000 (0%)] Loss: 0.000013
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 90: Current Learning rate 0.00043046721
# Train Epoch: 90 [0/9000 (0%)] Loss: 0.000013
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 91: Current Learning rate 0.000387420489
# Train Epoch: 91 [0/9000 (0%)] Loss: 0.000013
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 92: Current Learning rate 0.000387420489
# Train Epoch: 92 [0/9000 (0%)] Loss: 0.000013
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 93: Current Learning rate 0.000387420489
# Train Epoch: 93 [0/9000 (0%)] Loss: 0.000013
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 94: Current Learning rate 0.000387420489
# Train Epoch: 94 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 95: Current Learning rate 0.000387420489
# Train Epoch: 95 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 96: Current Learning rate 0.000387420489
# Train Epoch: 96 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 97: Current Learning rate 0.000387420489
# Train Epoch: 97 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 98: Current Learning rate 0.000387420489
# Train Epoch: 98 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 99: Current Learning rate 0.000387420489
# Train Epoch: 99 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 100: Current Learning rate 0.000387420489
# Train Epoch: 100 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 101: Current Learning rate 0.0003486784401
# Train Epoch: 101 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 102: Current Learning rate 0.0003486784401
# Train Epoch: 102 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 103: Current Learning rate 0.0003486784401
# Train Epoch: 103 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 104: Current Learning rate 0.0003486784401
# Train Epoch: 104 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 105: Current Learning rate 0.0003486784401
# Train Epoch: 105 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 106: Current Learning rate 0.0003486784401
# Train Epoch: 106 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 107: Current Learning rate 0.0003486784401
# Train Epoch: 107 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 108: Current Learning rate 0.0003486784401
# Train Epoch: 108 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 109: Current Learning rate 0.0003486784401
# Train Epoch: 109 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 110: Current Learning rate 0.0003486784401
# Train Epoch: 110 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 111: Current Learning rate 0.00031381059609000004
# Train Epoch: 111 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 112: Current Learning rate 0.00031381059609000004
# Train Epoch: 112 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 113: Current Learning rate 0.00031381059609000004
# Train Epoch: 113 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 114: Current Learning rate 0.00031381059609000004
# Train Epoch: 114 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 115: Current Learning rate 0.00031381059609000004
# Train Epoch: 115 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 116: Current Learning rate 0.00031381059609000004
# Train Epoch: 116 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 117: Current Learning rate 0.00031381059609000004
# Train Epoch: 117 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 118: Current Learning rate 0.00031381059609000004
# Train Epoch: 118 [0/9000 (0%)] Loss: 0.000010
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 119: Current Learning rate 0.00031381059609000004
# Train Epoch: 119 [0/9000 (0%)] Loss: 0.000010
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 120: Current Learning rate 0.00031381059609000004
# Train Epoch: 120 [0/9000 (0%)] Loss: 0.000010
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 121: Current Learning rate 0.00028242953648100003
# Train Epoch: 121 [0/9000 (0%)] Loss: 0.000010
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 122: Current Learning rate 0.00028242953648100003
# Train Epoch: 122 [0/9000 (0%)] Loss: 0.000010
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 123: Current Learning rate 0.00028242953648100003
# Train Epoch: 123 [0/9000 (0%)] Loss: 0.000010
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 124: Current Learning rate 0.00028242953648100003
# Train Epoch: 124 [0/9000 (0%)] Loss: 0.000010
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 125: Current Learning rate 0.00028242953648100003
# Train Epoch: 125 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 126: Current Learning rate 0.00028242953648100003
# Train Epoch: 126 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 127: Current Learning rate 0.00028242953648100003
# Train Epoch: 127 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 128: Current Learning rate 0.00028242953648100003
# Train Epoch: 128 [0/9000 (0%)] Loss: 0.000012
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 129: Current Learning rate 0.00028242953648100003
# Train Epoch: 129 [0/9000 (0%)] Loss: 0.000011
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 130: Current Learning rate 0.00028242953648100003
# Train Epoch: 130 [0/9000 (0%)] Loss: 0.000010
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 131: Current Learning rate 0.00025418658283290005
# Train Epoch: 131 [0/9000 (0%)] Loss: 0.000010
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 132: Current Learning rate 0.00025418658283290005
# Train Epoch: 132 [0/9000 (0%)] Loss: 0.000009
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 133: Current Learning rate 0.00025418658283290005
# Train Epoch: 133 [0/9000 (0%)] Loss: 0.000009
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 134: Current Learning rate 0.00025418658283290005
# Train Epoch: 134 [0/9000 (0%)] Loss: 0.000009
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 135: Current Learning rate 0.00025418658283290005
# Train Epoch: 135 [0/9000 (0%)] Loss: 0.000009
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 136: Current Learning rate 0.00025418658283290005
# Train Epoch: 136 [0/9000 (0%)] Loss: 0.000009
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 137: Current Learning rate 0.00025418658283290005
# Train Epoch: 137 [0/9000 (0%)] Loss: 0.000009
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 138: Current Learning rate 0.00025418658283290005
# Train Epoch: 138 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 139: Current Learning rate 0.00025418658283290005
# Train Epoch: 139 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 140: Current Learning rate 0.00025418658283290005
# Train Epoch: 140 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 141: Current Learning rate 0.00022876792454961005
# Train Epoch: 141 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 142: Current Learning rate 0.00022876792454961005
# Train Epoch: 142 [0/9000 (0%)] Loss: 0.000009
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 143: Current Learning rate 0.00022876792454961005
# Train Epoch: 143 [0/9000 (0%)] Loss: 0.000010
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 144: Current Learning rate 0.00022876792454961005
# Train Epoch: 144 [0/9000 (0%)] Loss: 0.000009
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 145: Current Learning rate 0.00022876792454961005
# Train Epoch: 145 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 146: Current Learning rate 0.00022876792454961005
# Train Epoch: 146 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 147: Current Learning rate 0.00022876792454961005
# Train Epoch: 147 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 148: Current Learning rate 0.00022876792454961005
# Train Epoch: 148 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 149: Current Learning rate 0.00022876792454961005
# Train Epoch: 149 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 150: Current Learning rate 0.00022876792454961005
# Train Epoch: 150 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 151: Current Learning rate 0.00020589113209464906
# Train Epoch: 151 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 152: Current Learning rate 0.00020589113209464906
# Train Epoch: 152 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 153: Current Learning rate 0.00020589113209464906
# Train Epoch: 153 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 154: Current Learning rate 0.00020589113209464906
# Train Epoch: 154 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 155: Current Learning rate 0.00020589113209464906
# Train Epoch: 155 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 156: Current Learning rate 0.00020589113209464906
# Train Epoch: 156 [0/9000 (0%)] Loss: 0.000008
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 157: Current Learning rate 0.00020589113209464906
# Train Epoch: 157 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 158: Current Learning rate 0.00020589113209464906
# Train Epoch: 158 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 159: Current Learning rate 0.00020589113209464906
# Train Epoch: 159 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 160: Current Learning rate 0.00020589113209464906
# Train Epoch: 160 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 161: Current Learning rate 0.00018530201888518417
# Train Epoch: 161 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 162: Current Learning rate 0.00018530201888518417
# Train Epoch: 162 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 163: Current Learning rate 0.00018530201888518417
# Train Epoch: 163 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 164: Current Learning rate 0.00018530201888518417
# Train Epoch: 164 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 165: Current Learning rate 0.00018530201888518417
# Train Epoch: 165 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 166: Current Learning rate 0.00018530201888518417
# Train Epoch: 166 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 167: Current Learning rate 0.00018530201888518417
# Train Epoch: 167 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 168: Current Learning rate 0.00018530201888518417
# Train Epoch: 168 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 169: Current Learning rate 0.00018530201888518417
# Train Epoch: 169 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 170: Current Learning rate 0.00018530201888518417
# Train Epoch: 170 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 171: Current Learning rate 0.00016677181699666576
# Train Epoch: 171 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 172: Current Learning rate 0.00016677181699666576
# Train Epoch: 172 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 173: Current Learning rate 0.00016677181699666576
# Train Epoch: 173 [0/9000 (0%)] Loss: 0.000007
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 174: Current Learning rate 0.00016677181699666576
# Train Epoch: 174 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 175: Current Learning rate 0.00016677181699666576
# Train Epoch: 175 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 176: Current Learning rate 0.00016677181699666576
# Train Epoch: 176 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 177: Current Learning rate 0.00016677181699666576
# Train Epoch: 177 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 178: Current Learning rate 0.00016677181699666576
# Train Epoch: 178 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 179: Current Learning rate 0.00016677181699666576
# Train Epoch: 179 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 180: Current Learning rate 0.00016677181699666576
# Train Epoch: 180 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 181: Current Learning rate 0.0001500946352969992
# Train Epoch: 181 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 182: Current Learning rate 0.0001500946352969992
# Train Epoch: 182 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 183: Current Learning rate 0.0001500946352969992
# Train Epoch: 183 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 184: Current Learning rate 0.0001500946352969992
# Train Epoch: 184 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 185: Current Learning rate 0.0001500946352969992
# Train Epoch: 185 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 186: Current Learning rate 0.0001500946352969992
# Train Epoch: 186 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 187: Current Learning rate 0.0001500946352969992
# Train Epoch: 187 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 188: Current Learning rate 0.0001500946352969992
# Train Epoch: 188 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 189: Current Learning rate 0.0001500946352969992
# Train Epoch: 189 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 190: Current Learning rate 0.0001500946352969992
# Train Epoch: 190 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 191: Current Learning rate 0.0001350851717672993
# Train Epoch: 191 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 192: Current Learning rate 0.0001350851717672993
# Train Epoch: 192 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 193: Current Learning rate 0.0001350851717672993
# Train Epoch: 193 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 194: Current Learning rate 0.0001350851717672993
# Train Epoch: 194 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 195: Current Learning rate 0.0001350851717672993
# Train Epoch: 195 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 196: Current Learning rate 0.0001350851717672993
# Train Epoch: 196 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 197: Current Learning rate 0.0001350851717672993
# Train Epoch: 197 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 198: Current Learning rate 0.0001350851717672993
# Train Epoch: 198 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 199: Current Learning rate 0.0001350851717672993
# Train Epoch: 199 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000
# Epoch 200: Current Learning rate 0.0001350851717672993
# Train Epoch: 200 [0/9000 (0%)] Loss: 0.000006
#
# Train set: Average loss: 0.0000
#
# Test set: Average loss: 0.0000

# %%
train_losses = []
test_losses = []
lrs = []
# Training loop over epochs
for epoch in range(1, args["epochs"] + 1):
  print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  lrs.append(scheduler.get_last_lr())
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
  if args["save_model"] & (epoch % 10**3) ==0:
    torch.save(model.state_dict(), "BS_ANN"+str(epoch)+".pt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 # Training loop over epochs
#       5 for epoch in range(1, args["epochs"] + 1):
# ----> 6   print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
#       7   lrs.append(scheduler.get_last_lr())
#       8   train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
#
# NameError: name 'scheduler' is not defined

# %%
type(args["epochs"])
# Out:
# int

# %%
# Plotting log(MSE) against the learning rate (log scale)
#plt.plot(np.log10(lrs), np.log(train_losses), label="Training Loss")
plt.plot(np.linspace(0, args["epochs"]), np.log(train_losses), label="Training Loss")
plt.xlabel("Learning Rate (log scale)")
plt.ylabel("log(MSE)")
plt.title("Training Loss vs. Learning Rate")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Plotting log(MSE) against the learning rate (log scale)
#       2 #plt.plot(np.log10(lrs), np.log(train_losses), label="Training Loss")
# ----> 3 plt.plot(np.linspace(0, args["epochs"]), np.log(train_losses), label="Training Loss")
#       4 plt.xlabel("Learning Rate (log scale)")
#       5 plt.ylabel("log(MSE)")
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (50,) and (200,)

# %% [markdown]
# **EXECUTER CETTE CELLULE PUIS REDEMARRER L'ENVIRNEMENT ET REEXECUTER**

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import LambdaLR
from scipy.integrate import quad
from numpy.fft import fftshift
from scipy.stats import norm
from scipy import stats
from scipy.stats import qmc


### 1. Characteristic Function for the Baseline Model
def characteristic_function_baseline(u, params, tau, S0, r):
    """
    Compute the characteristic function for the baseline specification 
    of the model, handling price jumps and volatility jumps.
    
    params: dict containing the model parameters (vol, jumps, etc.)
    tau: Time to maturity.
    S0: Spot price of the underlying asset.
    r: Risk-free rate.
    """
    vol, mu_j, sigma_j = params['vol'], params['mu_j'], params['sigma_j']

    # Characteristic function terms - Price and volatility jumps.
    drift = (r - 0.5 * vol ** 2) * tau
    price_jump_component = np.exp(1j * u * drift - 0.5 * u**2 * vol ** 2 * tau)

    # Handling jumps
    jump_mean = mu_j * tau
    jump_var = sigma_j ** 2 * tau

    # Jump component for small tenors
    jump_characteristic = np.exp(1j * u * jump_mean - 0.5 * u**2 * jump_var)

    return price_jump_component * jump_characteristic


### 2. SINC Fourier Pricing Method
def sinc_pricing(moneyness, tau, r, cf, strikes, params):
    """
    Pricing of options using the Fourier method with the SINC method.

    moneyness: array of moneyness (S/K)
    tau: Time to maturity
    r: Risk-free rate
    cf: Characteristic function
    strikes: Strike prices of the options
    params: Additional model parameters for volatility, jumps, etc.
    """
    N = 256  # Fourier grid points
    L = 10   # Scaling parameter for SINC method

    # Range of k_m values for Fourier integration
    k_m = np.linspace(-L, L, N)

    # Initialize price array
    option_prices = np.zeros(len(strikes))

    # Iterate over strikes
    for i, K in enumerate(strikes):
        integrand_values = []

        # Compute characteristic function at all k_m values at once (vectorized)
        cf_values = np.array([cf(k - 1j, params, tau, moneyness, r) for k in k_m])

        # Expand dimensions to match broadcasting shape of K and k_m
        cf_values = np.expand_dims(cf_values, axis=1)  # shape: (N, 1) if needed
        K = np.expand_dims(K, axis=0)  # shape: (1, ) to broadcast

        # Iterate over each k_m value
        for k_idx, k in enumerate(k_m):
            cf_value = cf_values[k_idx]

            # Compute integrand for each k_m value and corresponding K
            integrand = np.exp(-1j * k * np.log(K)) * cf_value / (1j * k)

            # Collect real part of the integrand for integration
            integrand_values.append(integrand.real)

        # Convert to numpy array for proper summation
        integrand_values = np.array(integrand_values)

        # Fix dimensions if needed for summation
        integrand_values = integrand_values.reshape(-1)

        # Use np.trapz for integration
        sinc_sum = np.trapz(integrand_values, k_m)

        # Store the option price (discounted by the risk-free rate)
        option_prices[i] = np.exp(-r * tau) * sinc_sum

    return option_prices




### 3. Data Generator for ANN using LHS and SINC Method
def bs_LHS_data_generator(n = 10**6, l_bounds = [.4, .2, .02, .01], u_bounds = [1.6, 1.1, .1, 1]):
    """
    Generates samples of call prices using Latin hypercube sampling for the ANN.
    Returns a torch float tensor of dimension (n,5) containing the inputs samples and the value of the call.
    """
    sampler = qmc.LatinHypercube(d = 4)
    sample = sampler.random(n)
    sample = qmc.scale(sample, l_bounds, u_bounds)

    # Generate prices with the new baseline model
    strikes = sample[:, 0]
    taus = sample[:, 1]
    bs_prices = sinc_pricing(strikes, taus, sample[:, 2], characteristic_function_baseline, strikes, {'vol': 0.2, 'mu_j': -0.05, 'sigma_j': 0.1}).reshape((-1, 1))
    
    bs_dataset = np.concatenate((sample, bs_prices), axis=1)

    print("------ INPUT ------")
    print("S/K.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,0]),max(bs_dataset[:,0])))
    print("Tau.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,1]),max(bs_dataset[:,1])))
    print("r............ [{:.2f} {:.2f}]".format(min(bs_dataset[:,2]),max(bs_dataset[:,2])))
    print("Sigma........ [{:.2f} {:.2f}]".format(min(bs_dataset[:,3]),max(bs_dataset[:,3])))
    print("------ OUTPUT ------")
    print("V/K.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,4]),max(bs_dataset[:,4])))

    return torch.FloatTensor(bs_dataset)


### 4. BS-ANN Architecture
class BS_ANN(nn.Module):
    def __init__(self):
        """
        Initialize BS-ANN network with four hidden layers. 
        Weight are initialized using Glorot_uniform also known as Xavier_uniform.
        """
        super(BS_ANN, self).__init__()
        # 4 layers
        self.fc1 = nn.Linear(4, 400)
        self.fc2 = nn.Linear(400, 400)
        self.fc3 = nn.Linear(400, 400)
        self.fc4 = nn.Linear(400, 400)
        self.fc5 = nn.Linear(400, 1)
        # Initialize the layer's weights
        torch.nn.init.xavier_uniform_(self.fc1.weight)
        torch.nn.init.xavier_uniform_(self.fc2.weight)
        torch.nn.init.xavier_uniform_(self.fc3.weight)
        torch.nn.init.xavier_uniform_(self.fc4.weight)
        torch.nn.init.xavier_uniform_(self.fc5.weight)

    def forward(self, x):
        """
        Forward pass of the network. 
        Relu activations are used and a linear activation in the final layer.
        """
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.fc5(x)
        return x.flatten()

    def train_model(self, args, device, train_loader, optimizer, epoch):
        """
        Training over train_loader batches for one epoch.
        Returns average training loss.
        """
        self.train()
        train_loss = 0
        for batch_idx, data in enumerate(train_loader):
            data, target = data[:, :-1].to(device), data[:, -1].to(device)
            optimizer.zero_grad()
            output = self(data)
            loss = F.mse_loss(output, target)
            train_loss += loss.item() * data.shape[0]
            loss.backward()
            optimizer.step()
            if batch_idx % args["log_interval"] == 0:
                print(f'Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item():.6f}')
        train_loss /= len(train_loader.dataset)
        return train_loss

    def test_model(self, device, test_loader):
        """
        Testing over test_loader batches for one epoch. 
        Returns average test loss.
        """
        self.eval()
        test_loss = 0
        with torch.no_grad():
            for data in test_loader:
                data, target = data[:, :-1].to(device), data[:, -1].to(device)
                output = self(data)
                test_loss += F.mse_loss(output, target, reduction='sum').item()

        test_loss /= len(test_loader.dataset)
        print(f'\nTest set: Average loss: {test_loss:.4f}')
        return test_loss


### 5. Training the Model
def train_bs_ann():
    # Setting training parameters
    args = {
        "batch_size": 1024,
        "test_batch_size": 1024,
        "epochs": 200,
        "lr": 1,
        "gamma": 1,
        "no_cuda": False,
        "log_interval": 100,
        "dry_run": False,
        "save_model": False
    }

    use_cuda = not args["no_cuda"] and torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    # Generate the dataset using LHS sampling and the baseline model
    bs_dataset = bs_LHS_data_generator(n=10**4)
    train_size, test_size = int(bs_dataset.shape[0] * 0.9), int(bs_dataset.shape[0] * 0.1)
    train_dataset, test_dataset = torch.utils.data.random_split(bs_dataset, [train_size, test_size])

    train_loader = torch.utils.data.DataLoader(train_dataset, args["batch_size"])
    test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])

    # Model training
    model = BS_ANN().to(device)
    optimizer = optim.Adam(model.parameters(), lr=args["lr"])
    scheduler = LambdaLR(optimizer, lr_lambda=lambda epoch: 10**(-9 + epoch*10/(args["epochs"] - 1)))

    train_losses = []
    test_losses = []
    lrs = []
    # Training loop over epochs
    for epoch in range(1, args["epochs"] + 1):
        print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
        lrs.append(scheduler.get_last_lr())
        train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
        test_loss = model.test_model(device, test_loader)
        scheduler.step()
        train_losses.append(train_loss)
        test_losses.append(test_loss)
        if args["save_model"] & (epoch % 10**3) ==0:
            torch.save(model.state_dict(), "BS_ANN"+str(epoch)+".pt")

# %%
train_bs_ann()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\numpy\lib\function_base.py:4878, in trapz(y, x, dx, axis)
#    4877 try:
# -> 4878     ret = (d * (y[tuple(slice1)] + y[tuple(slice2)]) / 2.0).sum(axis)
#    4879 except ValueError:
#    4880     # Operations didn't work, cast to ndarray
#
# ValueError: operands could not be broadcast together with shapes (255,) (2559999,)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 train_bs_ann()
#
# Cell In[45], line 218, in train_bs_ann()
#     215 device = torch.device("cuda" if use_cuda else "cpu")
#     217 # Generate the dataset using LHS sampling and the baseline model
# --> 218 bs_dataset = bs_LHS_data_generator(n=10**4)
#     219 train_size, test_size = int(bs_dataset.shape[0] * 0.9), int(bs_dataset.shape[0] * 0.1)
#     220 train_dataset, test_dataset = torch.utils.data.random_split(bs_dataset, [train_size, test_size])
#
# Cell In[45], line 113, in bs_LHS_data_generator(n, l_bounds, u_bounds)
#     111 strikes = sample[:, 0]
#     112 taus = sample[:, 1]
# --> 113 bs_prices = sinc_pricing(strikes, taus, sample[:, 2], characteristic_function_baseline, strikes, {'vol': 0.2, 'mu_j': -0.05, 'sigma_j': 0.1}).reshape((-1, 1))
#     115 bs_dataset = np.concatenate((sample, bs_prices), axis=1)
#     117 print("------ INPUT ------")
#
# Cell In[45], line 90, in sinc_pricing(moneyness, tau, r, cf, strikes, params)
#      87 integrand_values = integrand_values.reshape(-1)
#      89 # Use np.trapz for integration
# ---> 90 sinc_sum = np.trapz(integrand_values, k_m)
#      92 # Store the option price (discounted by the risk-free rate)
#      93 option_prices[i] = np.exp(-r * tau) * sinc_sum
#
# File <__array_function__ internals>:200, in trapz(*args, **kwargs)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\numpy\lib\function_base.py:4883, in trapz(y, x, dx, axis)
#    4881     d = np.asarray(d)
#    4882     y = np.asarray(y)
# -> 4883     ret = add.reduce(d * (y[tuple(slice1)]+y[tuple(slice2)])/2.0, axis)
#    4884 return ret
#
# ValueError: operands could not be broadcast together with shapes (255,) (2559999,)

# %%
import numpy as np
import torch
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import LambdaLR
from scipy.integrate import quad
from numpy.fft import fftshift
from scipy.stats import norm

# %%
# Basic imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# Updating scipy to use module QMC for Latin hypercube sampling
#!pip install scipy==1.7
from scipy.stats import qmc

# Pytorch imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR, LinearLR, OneCycleLR, LambdaLR

# %%
def characteristic_function_baseline(u, params, tau, S0, r):
    """
    Compute the characteristic function for the baseline specification 
    of the model, handling price jumps and volatility jumps.
    
    params: dict containing the model parameters, like vol, jumps, etc.
    tau: Time to maturity.
    S0: Spot price of the underlying asset.
    r: Risk-free rate.
    """
    vol, mu_j, sigma_j = params['vol'], params['mu_j'], params['sigma_j']

    # Characteristic function terms - Price and volatility jumps.
    drift = (r - 0.5 * vol ** 2) * tau
    price_jump_component = np.exp(1j * u * drift - 0.5 * u**2 * vol ** 2 * tau)

    # Handling jumps
    jump_mean = mu_j * tau
    jump_var = sigma_j ** 2 * tau

    # Jump component for small tenors
    jump_characteristic = np.exp(1j * u * jump_mean - 0.5 * u**2 * jump_var)

    return price_jump_component * jump_characteristic

# %%
import numpy as np

def sinc_pricing(moneyness, tau, r, cf, strikes, params):
    """
    Pricing of options using the Fourier method with the SINC method.

    moneyness: array of moneyness (S/K)
    tau: Time to maturity
    r: Risk-free rate
    cf: Characteristic function
    strikes: Strike prices of the options
    params: Additional model parameters for volatility, jumps, etc.
    """
    N = 256  # Number of Fourier grid points
    L = 10   # Scaling parameter for SINC method

    # Range of k_m values for Fourier integration
    k_m = np.linspace(-L, L, N)

    # Initialize price array
    option_prices = np.zeros(len(strikes))

    # Iterate over strikes
    for i, K in enumerate(strikes):
        integrand_values = []

        # Compute characteristic function at all k_m values at once (vectorized)
        cf_values = np.array([cf(k - 1j, params, tau, moneyness, r) for k in k_m])

        # Adjust cf_values shape to (N, 1000000) by removing the second dimension
        cf_values = cf_values.reshape(N, -1)  # Shape: (256, 1000000)

        # Print out the shapes of the arrays
        print(f"Shape of cf_values: {cf_values.shape}")

        # Ensure K is expanded correctly
        K_array = np.full(cf_values.shape[0], K)  # shape: (256,)

        # Print shape of K
        print(f"Shape of K: {K_array.shape}")

        # Iterate over each k_m value
        for k_idx, k in enumerate(k_m):
            cf_value = cf_values[k_idx]

            # Compute integrand for each k_m value and corresponding K
            integrand = np.exp(-1j * k * np.log(K_array)) * cf_value / (1j * k)

            # Collect real part of the integrand for integration
            integrand_values.append(integrand.real)

        # Convert to numpy array for proper summation
        integrand_values = np.array(integrand_values)

        # Print the shape of integrand_values
        print(f"Shape of integrand_values: {integrand_values.shape}")

        # Use np.trapz for integration
        sinc_sum = np.trapz(integrand_values, k_m)

        # Store the option price (discounted by the risk-free rate)
        option_prices[i] = np.exp(-r * tau) * sinc_sum

    return option_prices

# %%
strikes = np.array([0.5, 0.6, 0.7])  # Example strikes
moneyness = 0.6  # Example moneyness
tau = 0.1  # Example time to maturity
r = 0.05  # Example risk-free rate
params = {}  # Your parameters for the characteristic function

option_prices = sinc_pricing(moneyness, tau, r, cf, strikes, params)
print(f"Calculated Option Prices: {option_prices}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 7
#       4 r = 0.05  # Example risk-free rate
#       5 params = {}  # Your parameters for the characteristic function
# ----> 7 option_prices = sinc_pricing(moneyness, tau, r, cf, strikes, params)
#       8 print(f"Calculated Option Prices: {option_prices}")
#
# NameError: name 'cf' is not defined

# %%
def bs_LHS_data_generator(n = 10**6, l_bounds = [.4, .2, .02, .01], u_bounds = [1.6, 1.1, .1, 1]):
    """
    Generates samples of call prices using Latin hypercube sampling for the ANN.
    Returns a torch float tensor of dimension (n,5) containig the inputs samples and the value of the call.
    """
    sampler = qmc.LatinHypercube(d = 4)
    sample = sampler.random(n)
    sample = qmc.scale(sample, l_bounds, u_bounds)

    # Generate prices with the new baseline model
    strikes = sample[:, 0]
    taus = sample[:, 1]
    bs_prices = sinc_pricing(strikes, taus, sample[:, 2], characteristic_function_baseline, strikes, {'vol': 0.2, 'mu_j': -0.05, 'sigma_j': 0.1}).reshape((-1, 1))
    
    bs_dataset = np.concatenate((sample, bs_prices), axis=1)

    print("------ INPUT ------")
    print("S/K.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,0]),max(bs_dataset[:,0])))
    print("Tau.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,1]),max(bs_dataset[:,1])))
    print("r............ [{:.2f} {:.2f}]".format(min(bs_dataset[:,2]),max(bs_dataset[:,2])))
    print("Sigma........ [{:.2f} {:.2f}]".format(min(bs_dataset[:,3]),max(bs_dataset[:,3])))
    print("------ OUTPUT ------")
    print("V/K.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,4]),max(bs_dataset[:,4])))

    return torch.FloatTensor(bs_dataset)

bs_dataset = bs_LHS_data_generator()
# Out:
# Shape of cf_values: (256, 1000000)
# Shape of K: (256,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 27
#      23     print("V/K.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,4]),max(bs_dataset[:,4])))
#      25     return torch.FloatTensor(bs_dataset)
# ---> 27 bs_dataset = bs_LHS_data_generator()
#
# Cell In[59], line 13, in bs_LHS_data_generator(n, l_bounds, u_bounds)
#      11 strikes = sample[:, 0]
#      12 taus = sample[:, 1]
# ---> 13 bs_prices = sinc_pricing(strikes, taus, sample[:, 2], characteristic_function_baseline, strikes, {'vol': 0.2, 'mu_j': -0.05, 'sigma_j': 0.1}).reshape((-1, 1))
#      15 bs_dataset = np.concatenate((sample, bs_prices), axis=1)
#      17 print("------ INPUT ------")
#
# Cell In[57], line 47, in sinc_pricing(moneyness, tau, r, cf, strikes, params)
#      44 cf_value = cf_values[k_idx]
#      46 # Compute integrand for each k_m value and corresponding K
# ---> 47 integrand = np.exp(-1j * k * np.log(K_array)) * cf_value / (1j * k)
#      49 # Collect real part of the integrand for integration
#      50 integrand_values.append(integrand.real)
#
# ValueError: operands could not be broadcast together with shapes (256,) (1000000,)

# %%
class BS_ANN(nn.Module):
    def __init__(self):
        """
        Initialize BS-ANN network with four hidden layers. 
        Weight are initialized using Glorot_uniform also known as Xavier_uniform.
        """
        super(BS_ANN, self).__init__()
        # 4 layers
        self.fc1 = nn.Linear(4, 400)
        self.fc2 = nn.Linear(400, 400)
        self.fc3 = nn.Linear(400, 400)
        self.fc4 = nn.Linear(400, 400)
        self.fc5 = nn.Linear(400, 1)
        # Initialize the layer's weights
        torch.nn.init.xavier_uniform_(self.fc1.weight)
        torch.nn.init.xavier_uniform_(self.fc2.weight)
        torch.nn.init.xavier_uniform_(self.fc3.weight)
        torch.nn.init.xavier_uniform_(self.fc4.weight)
        torch.nn.init.xavier_uniform_(self.fc5.weight)

    def forward(self, x):
        """
        Forward pass of the network. 
        Relu activations are used and a linear activation in the final layer.
        """
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.fc5(x)
        return x.flatten()

    def train_model(self, args, device, train_loader, optimizer, epoch):
        """
        Training over train_loader batches for one epoch.
        Returns average training loss.
        """
        self.train()
        train_loss = 0
        for batch_idx, data in enumerate(train_loader):
            data, target = data[:, :-1].to(device), data[:, -1].to(device)
            optimizer.zero_grad()
            output = self(data)
            loss = F.mse_loss(output, target)
            train_loss += loss.item() * data.shape[0]
            loss.backward()
            optimizer.step()
            if batch_idx % args["log_interval"] == 0:
                print(f'Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item():.6f}')
        train_loss /= len(train_loader.dataset)
        return train_loss

    def test_model(self, device, test_loader):
        """
        Testing over test_loader batches for one epoch. 
        Returns average test loss.
        """
        self.eval()
        test_loss = 0
        with torch.no_grad():
            for data in test_loader:
                data, target = data[:, :-1].to(device), data[:, -1].to(device)
                output = self(data)
                test_loss += F.mse_loss(output, target, reduction='sum').item()

        test_loss /= len(test_loader.dataset)
        print(f'\nTest set: Average loss: {test_loss:.4f}')
        return test_loss

# %%
def train_bs_ann():
    # Setting training parameters
    args = {
        "batch_size": 1024,
        "test_batch_size": 1024,
        "epochs": 200,
        "lr": 1,
        "gamma": 1,
        "no_cuda": False,
        "log_interval": 100,
        "dry_run": False,
        "save_model": False
    }

    use_cuda = not args["no_cuda"] and torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    # Generate the dataset using LHS sampling and the baseline model
    bs_dataset = bs_LHS_data_generator(n=10**4)
    train_size, test_size = int(bs_dataset.shape[0] * 0.9), int(bs_dataset.shape[0] * 0.1)
    train_dataset, test_dataset = torch.utils.data.random_split(bs_dataset, [train_size, test_size])

    train_loader = torch.utils.data.DataLoader(train_dataset, args["batch_size"])
    test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])

    # Model training
    model = BS_ANN().to(device)
    optimizer = optim.Adam(model.parameters(), lr=args["lr"])
    scheduler = LambdaLR(optimizer, lr_lambda=lambda epoch: 10**(-9 + epoch*10/(args["epochs"] - 1)))

    train_losses, test_losses

# %%
train_bs_ann()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\numpy\lib\function_base.py:4878, in trapz(y, x, dx, axis)
#    4877 try:
# -> 4878     ret = (d * (y[tuple(slice1)] + y[tuple(slice2)]) / 2.0).sum(axis)
#    4879 except ValueError:
#    4880     # Operations didn't work, cast to ndarray
#
# ValueError: operands could not be broadcast together with shapes (255,) (2559999,)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 train_bs_ann()
#
# Cell In[41], line 206, in train_bs_ann()
#     203 device = torch.device("cuda" if use_cuda else "cpu")
#     205 # Generate the dataset using LHS sampling and the baseline model
# --> 206 bs_dataset = bs_LHS_data_generator(n=10**4)
#     207 train_size, test_size = int(bs_dataset.shape[0] * 0.9), int(bs_dataset.shape[0] * 0.1)
#     208 train_dataset, test_dataset = torch.utils.data.random_split(bs_dataset, [train_size, test_size])
#
# Cell In[41], line 101, in bs_LHS_data_generator(n, l_bounds, u_bounds)
#      99 strikes = sample[:, 0]
#     100 taus = sample[:, 1]
# --> 101 bs_prices = sinc_pricing(strikes, taus, sample[:, 2], characteristic_function_baseline, strikes, {'vol': 0.2, 'mu_j': -0.05, 'sigma_j': 0.1}).reshape((-1, 1))
#     103 bs_dataset = np.concatenate((sample, bs_prices), axis=1)
#     105 print("------ INPUT ------")
#
# Cell In[43], line 49, in sinc_pricing(moneyness, tau, r, cf, strikes, params)
#      46 integrand_values = integrand_values.reshape(-1)
#      48 # Use np.trapz for integration
# ---> 49 sinc_sum = np.trapz(integrand_values, k_m)
#      51 # Store the option price (discounted by the risk-free rate)
#      52 option_prices[i] = np.exp(-r * tau) * sinc_sum
#
# File <__array_function__ internals>:200, in trapz(*args, **kwargs)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\numpy\lib\function_base.py:4883, in trapz(y, x, dx, axis)
#    4881     d = np.asarray(d)
#    4882     y = np.asarray(y)
# -> 4883     ret = add.reduce(d * (y[tuple(slice1)]+y[tuple(slice2)])/2.0, axis)
#    4884 return ret
#
# ValueError: operands could not be broadcast together with shapes (255,) (2559999,)

# %%
# Plotting the log MSE as a funtion of the learning rate
plt.plot(np.log10(lrs), np.log(train_losses), label = "train")
plt.xlabel("Learning rate (log scale)")
plt.ylabel("log(MSE)")
plt.title("Average training loss over learning rate" )
plt.grid()
plt.legend()

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # 1) Black Scholes pricing network: BS-ANN

# %% [markdown]
# ### Closed-form formula

# %%
def bs_price_call(S, K, T, t, r, sigma):
  """
  Black-Scholes call option value price related to PDE (2). Returns option's price.
  S: spot price
  K: strike price
  T: time to maturity
  t: spot time
  r: interest rate
  sigma: volatility of underlying asset
  """

  # Boundary condition of Black-Sholes PDE (2)
  if T == t:
    return np.maximum(0, S - K)  
  # Solution of the PDE (2) on the open interval [t, T)
  else : 
    d1 = ( np.log(S / K) + (r + 0.5 * sigma ** 2) * (T-t) ) / (sigma * np.sqrt(T-t))
    d2 = d1 - sigma*np.sqrt(T-t)
    value = S * norm.cdf(d1) - K * np.exp(-r * (T-t)) * norm.cdf(d2) 
  
  return value

def bs_moneyness_call(moneyness, tau, r, sigma):
  """
  Same function as bs_price_call but in terms of moneyness. Returns V/K and 
  has S/K instead of two seperate paremeters S and K.
  moneyness: S/K
  Tau: time to maturity minus spot time
  r: interest rate
  sigma: volatility of underlying asset
  """

  d1 = ( np.log(moneyness) + (r + 0.5 * sigma ** 2) * (tau) ) / (sigma * np.sqrt(tau))
  d2 = d1 - sigma*np.sqrt(tau)
  value_moneyness = moneyness * norm.cdf(d1) - np.exp(-r * (tau)) * norm.cdf(d2) 
  
  return value_moneyness

# %%
# Checking the call prices with respect to strikes
r, T, t, sigma, K, S = .02, 1, 1, .2, 100, np.arange(200)
plt.plot(S, bs_price_call(S, K, T, t, r, sigma))
plt.xlabel("Strike")
plt.ylabel("Price")
plt.title("Call option price" )
plt.grid()

# %% [markdown]
# ### Data generation

# %%
def bs_LHS_data_generator(n = 10**6, l_bounds = [.4, .2, .02, .01], u_bounds = [1.6, 1.1, .1, 1]):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,5) containig the inputs samples and the value of the call.
  The inputs are: Moneyness (S/K), time to maturity (tau), Risk free rate (r), Volatility (sigma).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.

  """
  sampler = qmc.LatinHypercube(d = 4)
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  bs_prices = bs_moneyness_call(sample[:, 0], sample[:, 1], sample[:, 2], sample[:, 3]).reshape((-1, 1))
  bs_dataset = np.concatenate((sample, bs_prices),axis=1)

  print("------ INPUT ------")
  print("S/K.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,0]),max(bs_dataset[:,0])))
  print("Tau.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,1]),max(bs_dataset[:,1])))
  print("r............ [{:.2f} {:.2f}]".format(min(bs_dataset[:,2]),max(bs_dataset[:,2])))
  print("Sigma........ [{:.2f} {:.2f}]".format(min(bs_dataset[:,3]),max(bs_dataset[:,3])))
  print("------ OUTPUT ------")
  print("V/K.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,4]),max(bs_dataset[:,4])))


  return torch.FloatTensor(bs_dataset)

# Testing the function
bs_dataset = bs_LHS_data_generator()
# Out:
# ------ INPUT ------
# S/K.......... [0.40 1.60]
# Tau.......... [0.20 1.10]
# r............ [0.02 0.10]
# Sigma........ [0.01 1.00]
# ------ OUTPUT ------
# V/K.......... [0.00 0.90]

# %%
# Checking the LHS distribution of the input
plt.figure(figsize=(10,7))
h = plt.hist(bs_dataset[:,0], bins= 10)
plt.xlabel("values")
plt.ylabel("sample")
plt.title("Stock price histogram (S/K)" )
plt.grid()

# %%
# Checking the output distribution (V/K).
plt.figure(figsize=(10,7))
h = plt.hist(bs_dataset[:,-1],bins=100)
plt.xlabel("values")
plt.ylabel("sample")
plt.title("Call price histogram (V/K)" )
plt.grid()

# %% [markdown]
# **Remark:** The majority of option prices are below 0.01

# %% [markdown]
# ### Defining class BS-ANN

# %% [markdown]
# ### Search of optimal Learning rate interval

# %% [markdown]
# **Remark:** it seems like the best interval is from $10^{-4}$ to $10^{-6}$

# %%
# ADDED CODE BOX
# Plotting the Log(MSE) with respect to the epoch
plt.figure(figsize=(10,7))
plt.plot( np.log(test_losses), label = "test")
plt.plot( np.log(train_losses), label = "train")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Log(MSE)")
plt.title("MSE over Epoch" )
plt.grid()
print("Training WIDE {} VS in the article 8.04e-09".format(train_losses[-1]) )
# Out:
# Training WIDE 1.2428339981502956 VS in the article 8.04e-09

# %% [markdown]
# ### Training BS-ANN with DecayLR from $10^{-4}$ to $10^{-6}$ Wide dataset

# %%
# Training parameters
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}



use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# torch.manual_seed(args["seed"])


# Loading Train / Test Data
bs_dataset = bs_LHS_data_generator(n = 10**5)
train_size, test_size = int(bs_dataset.shape[0]*0.9), int(bs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(bs_dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])



print(device)
model = BS_ANN().to(device)
# Adam is found to be the best optimizer in the article
optimizer = optim.Adam(model.parameters(), lr = args["lr"]) 
# Deacreses the Learning rate by .1 every 1000 epoch
scheduler = StepLR(optimizer, step_size=10**3, gamma=args["gamma"]) 

train_losses = []
test_losses = []
# Training loop
for epoch in range(1, args["epochs"] + 1):
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
if args["save_model"] :
  torch.save(model.state_dict(), "BS_ANN.pt")
# Out:
# ------ INPUT ------
# S/K.......... [0.40 1.60]
# Tau.......... [0.20 1.10]
# r............ [0.02 0.10]
# Sigma........ [0.01 1.00]
# ------ OUTPUT ------
# V/K.......... [0.00 0.89]
# cuda
# Train Epoch: 1 [0/90000 (0%)]	log Loss: -1.878099
#
# Train set: Average log loss: -3.9773
#
#
# Test set: Average loss: -6.4762
#
# Current Learning rate 0.0001
# Train Epoch: 2 [0/90000 (0%)]	log Loss: -6.488426
#
# Train set: Average log loss: -7.1410
#
#
# Test set: Average loss: -7.7887
#
# Current Learning rate 0.0001
# Train Epoch: 3 [0/90000 (0%)]	log Loss: -7.836579
#
# Train set: Average log loss: -8.2131
#
#
# Test set: Average loss: -8.6201
#
# Current Learning rate 0.0001
# Train Epoch: 4 [0/90000 (0%)]	log Loss: -8.637086
#
# Train set: Average log loss: -8.9441
#
#
# Test set: Average loss: -9.3021
#
# Current Learning rate 0.0001
# Train Epoch: 5 [0/90000 (0%)]	log Loss: -9.280575
#
# Train set: Average log loss: -9.6135
#
#
# Test set: Average loss: -9.9635
#
# Current Learning rate 0.0001
# Train Epoch: 6 [0/90000 (0%)]	log Loss: -9.906272
#
# Train set: Average log loss: -10.2041
#
#
# Test set: Average loss: -10.4679
#
# Current Learning rate 0.0001
# Train Epoch: 7 [0/90000 (0%)]	log Loss: -10.371916
#
# Train set: Average log loss: -10.5876
#
#
# Test set: Average loss: -10.4406
#
# Current Learning rate 0.0001
# Train Epoch: 8 [0/90000 (0%)]	log Loss: -10.365269
#
# Train set: Average log loss: -10.8622
#
#
# Test set: Average loss: -10.8798
#
# Current Learning rate 0.0001
# Train Epoch: 9 [0/90000 (0%)]	log Loss: -10.805529
#
# Train set: Average log loss: -11.0174
#
#
# Test set: Average loss: -10.6634
#
# Current Learning rate 0.0001
# Train Epoch: 10 [0/90000 (0%)]	log Loss: -10.636711
#
# Train set: Average log loss: -11.1080
#
#
# Test set: Average loss: -11.0931
#
# Current Learning rate 0.0001
# Train Epoch: 11 [0/90000 (0%)]	log Loss: -11.072061
#
# Train set: Average log loss: -11.2521
#
#
# Test set: Average loss: -11.3651
#
# Current Learning rate 0.0001
# Train Epoch: 12 [0/90000 (0%)]	log Loss: -11.338180
#
# Train set: Average log loss: -11.3517
#
#
# Test set: Average loss: -11.0426
#
# Current Learning rate 0.0001
# Train Epoch: 13 [0/90000 (0%)]	log Loss: -11.014697
#
# Train set: Average log loss: -11.3447
#
#
# Test set: Average loss: -10.9924
#
# Current Learning rate 0.0001
# Train Epoch: 14 [0/90000 (0%)]	log Loss: -10.967562
#
# Train set: Average log loss: -11.2534
#
#
# Test set: Average loss: -11.0551
#
# Current Learning rate 0.0001
# Train Epoch: 15 [0/90000 (0%)]	log Loss: -11.031053
#
# Train set: Average log loss: -11.2746
#
#
# Test set: Average loss: -10.9738
#
# Current Learning rate 0.0001
# Train Epoch: 16 [0/90000 (0%)]	log Loss: -10.945640
#
# Train set: Average log loss: -11.2777
#
#
# Test set: Average loss: -11.0004
#
# Current Learning rate 0.0001
# Train Epoch: 17 [0/90000 (0%)]	log Loss: -10.968322
#
# Train set: Average log loss: -11.3009
#
#
# Test set: Average loss: -11.1431
#
# Current Learning rate 0.0001
# Train Epoch: 18 [0/90000 (0%)]	log Loss: -11.106325
#
# Train set: Average log loss: -11.3963
#
#
# Test set: Average loss: -11.9202
#
# Current Learning rate 0.0001
# Train Epoch: 19 [0/90000 (0%)]	log Loss: -11.905712
#
# Train set: Average log loss: -11.7366
#
#
# Test set: Average loss: -11.9413
#
# Current Learning rate 0.0001
# Train Epoch: 20 [0/90000 (0%)]	log Loss: -11.965182
#
# Train set: Average log loss: -11.3460
#
#
# Test set: Average loss: -11.5044
#
# Current Learning rate 0.0001
# Train Epoch: 21 [0/90000 (0%)]	log Loss: -11.556187
#
# Train set: Average log loss: -11.4995
#
#
# Test set: Average loss: -12.1225
#
# Current Learning rate 0.0001
# Train Epoch: 22 [0/90000 (0%)]	log Loss: -12.123065
#
# Train set: Average log loss: -11.1920
#
#
# Test set: Average loss: -11.0108
#
# Current Learning rate 0.0001
# Train Epoch: 23 [0/90000 (0%)]	log Loss: -11.061471
#
# Train set: Average log loss: -11.6022
#
#
# Test set: Average loss: -12.0158
#
# Current Learning rate 0.0001
# Train Epoch: 24 [0/90000 (0%)]	log Loss: -11.969999
#
# Train set: Average log loss: -11.4231
#
#
# Test set: Average loss: -12.2265
#
# Current Learning rate 0.0001
# Train Epoch: 25 [0/90000 (0%)]	log Loss: -12.186694
#
# Train set: Average log loss: -11.3578
#
#
# Test set: Average loss: -12.1778
#
# Current Learning rate 0.0001
# Train Epoch: 26 [0/90000 (0%)]	log Loss: -12.131352
#
# Train set: Average log loss: -11.4004
#
#
# Test set: Average loss: -12.3725
#
# Current Learning rate 0.0001
# Train Epoch: 27 [0/90000 (0%)]	log Loss: -12.333219
#
# Train set: Average log loss: -11.2360
#
#
# Test set: Average loss: -12.2857
#
# Current Learning rate 0.0001
# Train Epoch: 28 [0/90000 (0%)]	log Loss: -12.251335
#
# Train set: Average log loss: -11.3495
#
#
# Test set: Average loss: -12.2395
#
# Current Learning rate 0.0001
# Train Epoch: 29 [0/90000 (0%)]	log Loss: -12.293870
#
# Train set: Average log loss: -11.4017
#
#
# Test set: Average loss: -12.4644
#
# Current Learning rate 0.0001
# Train Epoch: 30 [0/90000 (0%)]	log Loss: -12.454069
#
# Train set: Average log loss: -11.3952
#
#
# Test set: Average loss: -12.4508
#
# Current Learning rate 0.0001
# Train Epoch: 31 [0/90000 (0%)]	log Loss: -12.424450
#
# Train set: Average log loss: -11.4062
#
#
# Test set: Average loss: -12.2765
#
# Current Learning rate 0.0001
# Train Epoch: 32 [0/90000 (0%)]	log Loss: -12.225239
#
# Train set: Average log loss: -11.4064
#
#
# Test set: Average loss: -12.0773
#
# Current Learning rate 0.0001
# Train Epoch: 33 [0/90000 (0%)]	log Loss: -12.019121
#
# Train set: Average log loss: -11.4145
#
#
# Test set: Average loss: -12.0057
#
# Current Learning rate 0.0001
# Train Epoch: 34 [0/90000 (0%)]	log Loss: -11.947924
#
# Train set: Average log loss: -11.4330
#
#
# Test set: Average loss: -11.9970
#
# Current Learning rate 0.0001
# Train Epoch: 35 [0/90000 (0%)]	log Loss: -11.937764
#
# Train set: Average log loss: -11.5043
#
#
# Test set: Average loss: -12.2015
#
# Current Learning rate 0.0001
# Train Epoch: 36 [0/90000 (0%)]	log Loss: -12.134615
#
# Train set: Average log loss: -11.4728
#
#
# Test set: Average loss: -12.7534
#
# Current Learning rate 0.0001
# Train Epoch: 37 [0/90000 (0%)]	log Loss: -12.735650
#
# Train set: Average log loss: -11.5102
#
#
# Test set: Average loss: -12.7848
#
# Current Learning rate 0.0001
# Train Epoch: 38 [0/90000 (0%)]	log Loss: -12.712609
#
# Train set: Average log loss: -11.2624
#
#
# Test set: Average loss: -12.8329
#
# Current Learning rate 0.0001
# Train Epoch: 39 [0/90000 (0%)]	log Loss: -12.762667
#
# Train set: Average log loss: -11.2981
#
#
# Test set: Average loss: -11.6702
#
# Current Learning rate 0.0001
# Train Epoch: 40 [0/90000 (0%)]	log Loss: -11.722721
#
# Train set: Average log loss: -11.5196
#
#
# Test set: Average loss: -11.9031
#
# Current Learning rate 0.0001
# Train Epoch: 41 [0/90000 (0%)]	log Loss: -11.844704
#
# Train set: Average log loss: -11.5817
#
#
# Test set: Average loss: -12.0288
#
# Current Learning rate 0.0001
# Train Epoch: 42 [0/90000 (0%)]	log Loss: -11.955753
#
# Train set: Average log loss: -11.5215
#
#
# Test set: Average loss: -12.7990
#
# Current Learning rate 0.0001
# Train Epoch: 43 [0/90000 (0%)]	log Loss: -12.704961
#
# Train set: Average log loss: -11.4813
#
#
# Test set: Average loss: -10.3285
#
# Current Learning rate 0.0001
# Train Epoch: 44 [0/90000 (0%)]	log Loss: -10.295156
#
# Train set: Average log loss: -11.4431
#
#
# Test set: Average loss: -13.0949
#
# Current Learning rate 0.0001
# Train Epoch: 45 [0/90000 (0%)]	log Loss: -13.022048
#
# Train set: Average log loss: -11.5311
#
#
# Test set: Average loss: -12.5808
#
# Current Learning rate 0.0001
# Train Epoch: 46 [0/90000 (0%)]	log Loss: -12.483102
#
# Train set: Average log loss: -11.0757
#
#
# Test set: Average loss: -12.9433
#
# Current Learning rate 0.0001
# Train Epoch: 47 [0/90000 (0%)]	log Loss: -12.950900
#
# Train set: Average log loss: -11.7333
#
#
# Test set: Average loss: -10.8271
#
# Current Learning rate 0.0001
# Train Epoch: 48 [0/90000 (0%)]	log Loss: -10.790263
#
# Train set: Average log loss: -11.7236
#
#
# Test set: Average loss: -12.7067
#
# Current Learning rate 0.0001
# Train Epoch: 49 [0/90000 (0%)]	log Loss: -12.606068
#
# Train set: Average log loss: -11.0279
#
#
# Test set: Average loss: -12.8722
#
# Current Learning rate 0.0001
# Train Epoch: 50 [0/90000 (0%)]	log Loss: -12.894391
#
# Train set: Average log loss: -12.0327
#
#
# Test set: Average loss: -11.2413
#
# Current Learning rate 0.0001
# Train Epoch: 51 [0/90000 (0%)]	log Loss: -11.194971
#
# Train set: Average log loss: -11.5272
#
#
# Test set: Average loss: -13.2658
#
# Current Learning rate 0.0001
# Train Epoch: 52 [0/90000 (0%)]	log Loss: -13.176558
#
# Train set: Average log loss: -11.8518
#
#
# Test set: Average loss: -11.7060
#
# Current Learning rate 0.0001
# Train Epoch: 53 [0/90000 (0%)]	log Loss: -11.639366
#
# Train set: Average log loss: -11.2054
#
#
# Test set: Average loss: -12.8300
#
# Current Learning rate 0.0001
# Train Epoch: 54 [0/90000 (0%)]	log Loss: -12.728342
#
# Train set: Average log loss: -11.5662
#
#
# Test set: Average loss: -10.8865
#
# Current Learning rate 0.0001
# Train Epoch: 55 [0/90000 (0%)]	log Loss: -10.853095
#
# Train set: Average log loss: -11.6764
#
#
# Test set: Average loss: -13.3755
#
# Current Learning rate 0.0001
# Train Epoch: 56 [0/90000 (0%)]	log Loss: -13.324087
#
# Train set: Average log loss: -10.9476
#
#
# Test set: Average loss: -13.3151
#
# Current Learning rate 0.0001
# Train Epoch: 57 [0/90000 (0%)]	log Loss: -13.278008
#
# Train set: Average log loss: -12.9456
#
#
# Test set: Average loss: -12.8101
#
# Current Learning rate 0.0001
# Train Epoch: 58 [0/90000 (0%)]	log Loss: -12.720711
#
# Train set: Average log loss: -11.1567
#
#
# Test set: Average loss: -13.0122
#
# Current Learning rate 0.0001
# Train Epoch: 59 [0/90000 (0%)]	log Loss: -13.039548
#
# Train set: Average log loss: -11.8890
#
#
# Test set: Average loss: -11.0112
#
# Current Learning rate 0.0001
# Train Epoch: 60 [0/90000 (0%)]	log Loss: -10.982290
#
# Train set: Average log loss: -11.6903
#
#
# Test set: Average loss: -13.4471
#
# Current Learning rate 0.0001
# Train Epoch: 61 [0/90000 (0%)]	log Loss: -13.404401
#
# Train set: Average log loss: -11.3410
#
#
# Test set: Average loss: -13.4582
#
# Current Learning rate 0.0001
# Train Epoch: 62 [0/90000 (0%)]	log Loss: -13.442599
#
# Train set: Average log loss: -12.0915
#
#
# Test set: Average loss: -11.8947
#
# Current Learning rate 0.0001
# Train Epoch: 63 [0/90000 (0%)]	log Loss: -11.841577
#
# Train set: Average log loss: -10.8712
#
#
# Test set: Average loss: -12.8680
#
# Current Learning rate 0.0001
# Train Epoch: 64 [0/90000 (0%)]	log Loss: -12.773162
#
# Train set: Average log loss: -13.0859
#
#
# Test set: Average loss: -13.3011
#
# Current Learning rate 0.0001
# Train Epoch: 65 [0/90000 (0%)]	log Loss: -13.218580
#
# Train set: Average log loss: -12.0174
#
#
# Test set: Average loss: -11.8878
#
# Current Learning rate 0.0001
# Train Epoch: 66 [0/90000 (0%)]	log Loss: -11.835790
#
# Train set: Average log loss: -11.0988
#
#
# Test set: Average loss: -13.5490
#
# Current Learning rate 0.0001
# Train Epoch: 67 [0/90000 (0%)]	log Loss: -13.537179
#
# Train set: Average log loss: -11.8548
#
#
# Test set: Average loss: -11.0734
#
# Current Learning rate 0.0001
# Train Epoch: 68 [0/90000 (0%)]	log Loss: -11.051070
#
# Train set: Average log loss: -11.7702
#
#
# Test set: Average loss: -13.5868
#
# Current Learning rate 0.0001
# Train Epoch: 69 [0/90000 (0%)]	log Loss: -13.557952
#
# Train set: Average log loss: -11.4273
#
#
# Test set: Average loss: -13.5704
#
# Current Learning rate 0.0001
# Train Epoch: 70 [0/90000 (0%)]	log Loss: -13.561430
#
# Train set: Average log loss: -12.2304
#
#
# Test set: Average loss: -11.9102
#
# Current Learning rate 0.0001
# Train Epoch: 71 [0/90000 (0%)]	log Loss: -11.865948
#
# Train set: Average log loss: -11.3635
#
#
# Test set: Average loss: -13.0977
#
# Current Learning rate 0.0001
# Train Epoch: 72 [0/90000 (0%)]	log Loss: -13.019289
#
# Train set: Average log loss: -11.8787
#
#
# Test set: Average loss: -13.6555
#
# Current Learning rate 0.0001
# Train Epoch: 73 [0/90000 (0%)]	log Loss: -13.636224
#
# Train set: Average log loss: -10.9686
#
#
# Test set: Average loss: -13.3370
#
# Current Learning rate 0.0001
# Train Epoch: 74 [0/90000 (0%)]	log Loss: -13.261959
#
# Train set: Average log loss: -13.3433
#
#
# Test set: Average loss: -13.3832
#
# Current Learning rate 0.0001
# Train Epoch: 75 [0/90000 (0%)]	log Loss: -13.313631
#
# Train set: Average log loss: -11.3376
#
#
# Test set: Average loss: -13.6704
#
# Current Learning rate 0.0001
# Train Epoch: 76 [0/90000 (0%)]	log Loss: -13.651168
#
# Train set: Average log loss: -12.0253
#
#
# Test set: Average loss: -11.2947
#
# Current Learning rate 0.0001
# Train Epoch: 77 [0/90000 (0%)]	log Loss: -11.275265
#
# Train set: Average log loss: -11.7818
#
#
# Test set: Average loss: -10.8450
#
# Current Learning rate 0.0001
# Train Epoch: 78 [0/90000 (0%)]	log Loss: -10.829640
#
# Train set: Average log loss: -11.7189
#
#
# Test set: Average loss: -10.9808
#
# Current Learning rate 0.0001
# Train Epoch: 79 [0/90000 (0%)]	log Loss: -10.965164
#
# Train set: Average log loss: -11.5687
#
#
# Test set: Average loss: -11.6934
#
# Current Learning rate 0.0001
# Train Epoch: 80 [0/90000 (0%)]	log Loss: -11.676850
#
# Train set: Average log loss: -11.9716
#
#
# Test set: Average loss: -12.3000
#
# Current Learning rate 0.0001
# Train Epoch: 81 [0/90000 (0%)]	log Loss: -12.265308
#
# Train set: Average log loss: -11.1918
#
#
# Test set: Average loss: -13.5564
#
# Current Learning rate 0.0001
# Train Epoch: 82 [0/90000 (0%)]	log Loss: -13.568563
#
# Train set: Average log loss: -12.7378
#
#
# Test set: Average loss: -11.7272
#
# Current Learning rate 0.0001
# Train Epoch: 83 [0/90000 (0%)]	log Loss: -11.701922
#
# Train set: Average log loss: -11.0532
#
#
# Test set: Average loss: -13.6144
#
# Current Learning rate 0.0001
# Train Epoch: 84 [0/90000 (0%)]	log Loss: -13.577913
#
# Train set: Average log loss: -13.4260
#
#
# Test set: Average loss: -13.7988
#
# Current Learning rate 0.0001
# Train Epoch: 85 [0/90000 (0%)]	log Loss: -13.770389
#
# Train set: Average log loss: -11.1291
#
#
# Test set: Average loss: -13.1501
#
# Current Learning rate 0.0001
# Train Epoch: 86 [0/90000 (0%)]	log Loss: -13.099937
#
# Train set: Average log loss: -13.4551
#
#
# Test set: Average loss: -13.6848
#
# Current Learning rate 0.0001
# Train Epoch: 87 [0/90000 (0%)]	log Loss: -13.649186
#
# Train set: Average log loss: -11.0380
#
#
# Test set: Average loss: -13.3519
#
# Current Learning rate 0.0001
# Train Epoch: 88 [0/90000 (0%)]	log Loss: -13.306411
#
# Train set: Average log loss: -13.5472
#
#
# Test set: Average loss: -13.1225
#
# Current Learning rate 0.0001
# Train Epoch: 89 [0/90000 (0%)]	log Loss: -13.093123
#
# Train set: Average log loss: -11.8285
#
#
# Test set: Average loss: -13.2576
#
# Current Learning rate 0.0001
# Train Epoch: 90 [0/90000 (0%)]	log Loss: -13.231823
#
# Train set: Average log loss: -11.8162
#
#
# Test set: Average loss: -12.2077
#
# Current Learning rate 0.0001
# Train Epoch: 91 [0/90000 (0%)]	log Loss: -12.194828
#
# Train set: Average log loss: -11.4377
#
#
# Test set: Average loss: -13.5822
#
# Current Learning rate 0.0001
# Train Epoch: 92 [0/90000 (0%)]	log Loss: -13.597471
#
# Train set: Average log loss: -12.1283
#
#
# Test set: Average loss: -11.4748
#
# Current Learning rate 0.0001
# Train Epoch: 93 [0/90000 (0%)]	log Loss: -11.471725
#
# Train set: Average log loss: -12.1413
#
#
# Test set: Average loss: -11.9840
#
# Current Learning rate 0.0001
# Train Epoch: 94 [0/90000 (0%)]	log Loss: -11.970336
#
# Train set: Average log loss: -10.9258
#
#
# Test set: Average loss: -12.7579
#
# Current Learning rate 0.0001
# Train Epoch: 95 [0/90000 (0%)]	log Loss: -12.739743
#
# Train set: Average log loss: -13.4149
#
#
# Test set: Average loss: -13.8143
#
# Current Learning rate 0.0001
# Train Epoch: 96 [0/90000 (0%)]	log Loss: -13.813079
#
# Train set: Average log loss: -12.3453
#
#
# Test set: Average loss: -12.7403
#
# Current Learning rate 0.0001
# Train Epoch: 97 [0/90000 (0%)]	log Loss: -12.725092
#
# Train set: Average log loss: -10.9914
#
#
# Test set: Average loss: -13.7022
#
# Current Learning rate 0.0001
# Train Epoch: 98 [0/90000 (0%)]	log Loss: -13.663333
#
# Train set: Average log loss: -13.6024
#
#
# Test set: Average loss: -13.7293
#
# Current Learning rate 0.0001
# Train Epoch: 99 [0/90000 (0%)]	log Loss: -13.722394
#
# Train set: Average log loss: -12.0889
#
#
# Test set: Average loss: -11.0471
#
# Current Learning rate 0.0001
# Train Epoch: 100 [0/90000 (0%)]	log Loss: -11.061484
#
# Train set: Average log loss: -11.9401
#
#
# Test set: Average loss: -12.6342
#
# Current Learning rate 0.0001
# Train Epoch: 101 [0/90000 (0%)]	log Loss: -12.622542
#
# Train set: Average log loss: -10.9778
#
#
# Test set: Average loss: -13.8174
#
# Current Learning rate 0.0001
# Train Epoch: 102 [0/90000 (0%)]	log Loss: -13.789027
#
# Train set: Average log loss: -13.6694
#
#
# Test set: Average loss: -14.0305
#
# Current Learning rate 0.0001
# Train Epoch: 103 [0/90000 (0%)]	log Loss: -14.034641
#
# Train set: Average log loss: -12.5389
#
#
# Test set: Average loss: -12.2502
#
# Current Learning rate 0.0001
# Train Epoch: 104 [0/90000 (0%)]	log Loss: -12.241227
#
# Train set: Average log loss: -11.2443
#
#
# Test set: Average loss: -13.7323
#
# Current Learning rate 0.0001
# Train Epoch: 105 [0/90000 (0%)]	log Loss: -13.718226
#
# Train set: Average log loss: -13.5008
#
#
# Test set: Average loss: -12.5528
#
# Current Learning rate 0.0001
# Train Epoch: 106 [0/90000 (0%)]	log Loss: -12.547811
#
# Train set: Average log loss: -10.8792
#
#
# Test set: Average loss: -13.8407
#
# Current Learning rate 0.0001
# Train Epoch: 107 [0/90000 (0%)]	log Loss: -13.813468
#
# Train set: Average log loss: -13.8312
#
#
# Test set: Average loss: -14.0567
#
# Current Learning rate 0.0001
# Train Epoch: 108 [0/90000 (0%)]	log Loss: -14.054769
#
# Train set: Average log loss: -12.7001
#
#
# Test set: Average loss: -10.5721
#
# Current Learning rate 0.0001
# Train Epoch: 109 [0/90000 (0%)]	log Loss: -10.575435
#
# Train set: Average log loss: -12.0611
#
#
# Test set: Average loss: -11.2088
#
# Current Learning rate 0.0001
# Train Epoch: 110 [0/90000 (0%)]	log Loss: -11.213666
#
# Train set: Average log loss: -11.9576
#
#
# Test set: Average loss: -10.0809
#
# Current Learning rate 0.0001
# Train Epoch: 111 [0/90000 (0%)]	log Loss: -10.086984
#
# Train set: Average log loss: -11.9794
#
#
# Test set: Average loss: -11.1854
#
# Current Learning rate 0.0001
# Train Epoch: 112 [0/90000 (0%)]	log Loss: -11.192304
#
# Train set: Average log loss: -11.7745
#
#
# Test set: Average loss: -10.1890
#
# Current Learning rate 0.0001
# Train Epoch: 113 [0/90000 (0%)]	log Loss: -10.197751
#
# Train set: Average log loss: -12.2277
#
#
# Test set: Average loss: -13.7449
#
# Current Learning rate 0.0001
# Train Epoch: 114 [0/90000 (0%)]	log Loss: -13.739431
#
# Train set: Average log loss: -11.0146
#
#
# Test set: Average loss: -13.9905
#
# Current Learning rate 0.0001
# Train Epoch: 115 [0/90000 (0%)]	log Loss: -13.954660
#
# Train set: Average log loss: -13.8147
#
#
# Test set: Average loss: -14.0060
#
# Current Learning rate 0.0001
# Train Epoch: 116 [0/90000 (0%)]	log Loss: -13.985150
#
# Train set: Average log loss: -12.6434
#
#
# Test set: Average loss: -12.1322
#
# Current Learning rate 0.0001
# Train Epoch: 117 [0/90000 (0%)]	log Loss: -12.134313
#
# Train set: Average log loss: -10.9260
#
#
# Test set: Average loss: -13.8594
#
# Current Learning rate 0.0001
# Train Epoch: 118 [0/90000 (0%)]	log Loss: -13.804233
#
# Train set: Average log loss: -13.8953
#
#
# Test set: Average loss: -14.1193
#
# Current Learning rate 0.0001
# Train Epoch: 119 [0/90000 (0%)]	log Loss: -14.094313
#
# Train set: Average log loss: -12.9294
#
#
# Test set: Average loss: -11.0108
#
# Current Learning rate 0.0001
# Train Epoch: 120 [0/90000 (0%)]	log Loss: -11.018314
#
# Train set: Average log loss: -12.2095
#
#
# Test set: Average loss: -12.8856
#
# Current Learning rate 0.0001
# Train Epoch: 121 [0/90000 (0%)]	log Loss: -12.887804
#
# Train set: Average log loss: -10.8681
#
#
# Test set: Average loss: -13.6116
#
# Current Learning rate 0.0001
# Train Epoch: 122 [0/90000 (0%)]	log Loss: -13.577007
#
# Train set: Average log loss: -13.7708
#
#
# Test set: Average loss: -14.0806
#
# Current Learning rate 0.0001
# Train Epoch: 123 [0/90000 (0%)]	log Loss: -14.056738
#
# Train set: Average log loss: -13.8550
#
#
# Test set: Average loss: -14.1656
#
# Current Learning rate 0.0001
# Train Epoch: 124 [0/90000 (0%)]	log Loss: -14.157907
#
# Train set: Average log loss: -11.2237
#
#
# Test set: Average loss: -13.9414
#
# Current Learning rate 0.0001
# Train Epoch: 125 [0/90000 (0%)]	log Loss: -13.915437
#
# Train set: Average log loss: -13.7475
#
#
# Test set: Average loss: -14.2284
#
# Current Learning rate 0.0001
# Train Epoch: 126 [0/90000 (0%)]	log Loss: -14.212279
#
# Train set: Average log loss: -12.3375
#
#
# Test set: Average loss: -11.7271
#
# Current Learning rate 0.0001
# Train Epoch: 127 [0/90000 (0%)]	log Loss: -11.746136
#
# Train set: Average log loss: -12.0038
#
#
# Test set: Average loss: -11.4075
#
# Current Learning rate 0.0001
# Train Epoch: 128 [0/90000 (0%)]	log Loss: -11.427459
#
# Train set: Average log loss: -12.1156
#
#
# Test set: Average loss: -11.2659
#
# Current Learning rate 0.0001
# Train Epoch: 129 [0/90000 (0%)]	log Loss: -11.283922
#
# Train set: Average log loss: -11.9275
#
#
# Test set: Average loss: -12.8848
#
# Current Learning rate 0.0001
# Train Epoch: 130 [0/90000 (0%)]	log Loss: -12.921714
#
# Train set: Average log loss: -12.1927
#
#
# Test set: Average loss: -13.4033
#
# Current Learning rate 0.0001
# Train Epoch: 131 [0/90000 (0%)]	log Loss: -13.385050
#
# Train set: Average log loss: -11.3251
#
#
# Test set: Average loss: -13.7370
#
# Current Learning rate 0.0001
# Train Epoch: 132 [0/90000 (0%)]	log Loss: -13.737433
#
# Train set: Average log loss: -13.9367
#
#
# Test set: Average loss: -14.2246
#
# Current Learning rate 0.0001
# Train Epoch: 133 [0/90000 (0%)]	log Loss: -14.234424
#
# Train set: Average log loss: -11.6815
#
#
# Test set: Average loss: -14.1756
#
# Current Learning rate 0.0001
# Train Epoch: 134 [0/90000 (0%)]	log Loss: -14.125004
#
# Train set: Average log loss: -12.9628
#
#
# Test set: Average loss: -10.9722
#
# Current Learning rate 0.0001
# Train Epoch: 135 [0/90000 (0%)]	log Loss: -10.989705
#
# Train set: Average log loss: -11.8405
#
#
# Test set: Average loss: -14.2862
#
# Current Learning rate 0.0001
# Train Epoch: 136 [0/90000 (0%)]	log Loss: -14.251447
#
# Train set: Average log loss: -12.2467
#
#
# Test set: Average loss: -13.9935
#
# Current Learning rate 0.0001
# Train Epoch: 137 [0/90000 (0%)]	log Loss: -13.965436
#
# Train set: Average log loss: -11.6591
#
#
# Test set: Average loss: -13.7631
#
# Current Learning rate 0.0001
# Train Epoch: 138 [0/90000 (0%)]	log Loss: -13.709694
#
# Train set: Average log loss: -13.1135
#
#
# Test set: Average loss: -11.7944
#
# Current Learning rate 0.0001
# Train Epoch: 139 [0/90000 (0%)]	log Loss: -11.813549
#
# Train set: Average log loss: -11.4130
#
#
# Test set: Average loss: -14.1871
#
# Current Learning rate 0.0001
# Train Epoch: 140 [0/90000 (0%)]	log Loss: -14.163056
#
# Train set: Average log loss: -13.6847
#
#
# Test set: Average loss: -12.3404
#
# Current Learning rate 0.0001
# Train Epoch: 141 [0/90000 (0%)]	log Loss: -12.367194
#
# Train set: Average log loss: -11.1261
#
#
# Test set: Average loss: -13.9873
#
# Current Learning rate 0.0001
# Train Epoch: 142 [0/90000 (0%)]	log Loss: -13.935421
#
# Train set: Average log loss: -13.9626
#
#
# Test set: Average loss: -13.9121
#
# Current Learning rate 0.0001
# Train Epoch: 143 [0/90000 (0%)]	log Loss: -13.868132
#
# Train set: Average log loss: -13.2691
#
#
# Test set: Average loss: -11.5875
#
# Current Learning rate 0.0001
# Train Epoch: 144 [0/90000 (0%)]	log Loss: -11.608871
#
# Train set: Average log loss: -11.1741
#
#
# Test set: Average loss: -14.2780
#
# Current Learning rate 0.0001
# Train Epoch: 145 [0/90000 (0%)]	log Loss: -14.234432
#
# Train set: Average log loss: -13.7353
#
#
# Test set: Average loss: -13.7966
#
# Current Learning rate 0.0001
# Train Epoch: 146 [0/90000 (0%)]	log Loss: -13.747606
#
# Train set: Average log loss: -13.0684
#
#
# Test set: Average loss: -11.4177
#
# Current Learning rate 0.0001
# Train Epoch: 147 [0/90000 (0%)]	log Loss: -11.436990
#
# Train set: Average log loss: -11.3162
#
#
# Test set: Average loss: -14.1555
#
# Current Learning rate 0.0001
# Train Epoch: 148 [0/90000 (0%)]	log Loss: -14.133996
#
# Train set: Average log loss: -13.8539
#
#
# Test set: Average loss: -14.3952
#
# Current Learning rate 0.0001
# Train Epoch: 149 [0/90000 (0%)]	log Loss: -14.374394
#
# Train set: Average log loss: -12.4353
#
#
# Test set: Average loss: -12.1262
#
# Current Learning rate 0.0001
# Train Epoch: 150 [0/90000 (0%)]	log Loss: -12.156045
#
# Train set: Average log loss: -11.7554
#
#
# Test set: Average loss: -13.2894
#
# Current Learning rate 0.0001
# Train Epoch: 151 [0/90000 (0%)]	log Loss: -13.235026
#
# Train set: Average log loss: -13.0795
#
#
# Test set: Average loss: -11.4973
#
# Current Learning rate 0.0001
# Train Epoch: 152 [0/90000 (0%)]	log Loss: -11.519141
#
# Train set: Average log loss: -11.2568
#
#
# Test set: Average loss: -14.0426
#
# Current Learning rate 0.0001
# Train Epoch: 153 [0/90000 (0%)]	log Loss: -14.038325
#
# Train set: Average log loss: -13.6902
#
#
# Test set: Average loss: -13.8877
#
# Current Learning rate 0.0001
# Train Epoch: 154 [0/90000 (0%)]	log Loss: -13.841346
#
# Train set: Average log loss: -12.8464
#
#
# Test set: Average loss: -11.4125
#
# Current Learning rate 0.0001
# Train Epoch: 155 [0/90000 (0%)]	log Loss: -11.437769
#
# Train set: Average log loss: -11.6062
#
#
# Test set: Average loss: -14.2229
#
# Current Learning rate 0.0001
# Train Epoch: 156 [0/90000 (0%)]	log Loss: -14.207413
#
# Train set: Average log loss: -13.5123
#
#
# Test set: Average loss: -11.6939
#
# Current Learning rate 0.0001
# Train Epoch: 157 [0/90000 (0%)]	log Loss: -11.720597
#
# Train set: Average log loss: -11.2743
#
#
# Test set: Average loss: -14.3130
#
# Current Learning rate 0.0001
# Train Epoch: 158 [0/90000 (0%)]	log Loss: -14.275290
#
# Train set: Average log loss: -13.7287
#
#
# Test set: Average loss: -13.8161
#
# Current Learning rate 0.0001
# Train Epoch: 159 [0/90000 (0%)]	log Loss: -13.776479
#
# Train set: Average log loss: -13.4160
#
#
# Test set: Average loss: -13.2578
#
# Current Learning rate 0.0001
# Train Epoch: 160 [0/90000 (0%)]	log Loss: -13.304264
#
# Train set: Average log loss: -11.2764
#
#
# Test set: Average loss: -14.3633
#
# Current Learning rate 0.0001
# Train Epoch: 161 [0/90000 (0%)]	log Loss: -14.333745
#
# Train set: Average log loss: -13.8926
#
#
# Test set: Average loss: -14.2205
#
# Current Learning rate 0.0001
# Train Epoch: 162 [0/90000 (0%)]	log Loss: -14.203446
#
# Train set: Average log loss: -12.2509
#
#
# Test set: Average loss: -13.8081
#
# Current Learning rate 0.0001
# Train Epoch: 163 [0/90000 (0%)]	log Loss: -13.807443
#
# Train set: Average log loss: -12.7887
#
#
# Test set: Average loss: -12.7576
#
# Current Learning rate 0.0001
# Train Epoch: 164 [0/90000 (0%)]	log Loss: -12.798189
#
# Train set: Average log loss: -11.1564
#
#
# Test set: Average loss: -14.2255
#
# Current Learning rate 0.0001
# Train Epoch: 165 [0/90000 (0%)]	log Loss: -14.183034
#
# Train set: Average log loss: -14.1631
#
#
# Test set: Average loss: -14.4289
#
# Current Learning rate 0.0001
# Train Epoch: 166 [0/90000 (0%)]	log Loss: -14.434476
#
# Train set: Average log loss: -13.9380
#
#
# Test set: Average loss: -13.1177
#
# Current Learning rate 0.0001
# Train Epoch: 167 [0/90000 (0%)]	log Loss: -13.171332
#
# Train set: Average log loss: -11.2136
#
#
# Test set: Average loss: -13.7508
#
# Current Learning rate 0.0001
# Train Epoch: 168 [0/90000 (0%)]	log Loss: -13.704436
#
# Train set: Average log loss: -14.2238
#
#
# Test set: Average loss: -14.3514
#
# Current Learning rate 0.0001
# Train Epoch: 169 [0/90000 (0%)]	log Loss: -14.343596
#
# Train set: Average log loss: -13.8768
#
#
# Test set: Average loss: -12.9975
#
# Current Learning rate 0.0001
# Train Epoch: 170 [0/90000 (0%)]	log Loss: -13.047387
#
# Train set: Average log loss: -11.2001
#
#
# Test set: Average loss: -13.5574
#
# Current Learning rate 0.0001
# Train Epoch: 171 [0/90000 (0%)]	log Loss: -13.551914
#
# Train set: Average log loss: -13.9934
#
#
# Test set: Average loss: -14.4808
#
# Current Learning rate 0.0001
# Train Epoch: 172 [0/90000 (0%)]	log Loss: -14.502243
#
# Train set: Average log loss: -14.0271
#
#
# Test set: Average loss: -13.5947
#
# Current Learning rate 0.0001
# Train Epoch: 173 [0/90000 (0%)]	log Loss: -13.648696
#
# Train set: Average log loss: -11.4845
#
#
# Test set: Average loss: -13.9708
#
# Current Learning rate 0.0001
# Train Epoch: 174 [0/90000 (0%)]	log Loss: -14.002613
#
# Train set: Average log loss: -13.9614
#
#
# Test set: Average loss: -14.4460
#
# Current Learning rate 0.0001
# Train Epoch: 175 [0/90000 (0%)]	log Loss: -14.438089
#
# Train set: Average log loss: -12.6291
#
#
# Test set: Average loss: -11.8711
#
# Current Learning rate 0.0001
# Train Epoch: 176 [0/90000 (0%)]	log Loss: -11.866239
#
# Train set: Average log loss: -12.2827
#
#
# Test set: Average loss: -11.1187
#
# Current Learning rate 0.0001
# Train Epoch: 177 [0/90000 (0%)]	log Loss: -11.144749
#
# Train set: Average log loss: -12.5286
#
#
# Test set: Average loss: -13.3717
#
# Current Learning rate 0.0001
# Train Epoch: 178 [0/90000 (0%)]	log Loss: -13.431686
#
# Train set: Average log loss: -11.9638
#
#
# Test set: Average loss: -13.7937
#
# Current Learning rate 0.0001
# Train Epoch: 179 [0/90000 (0%)]	log Loss: -13.762791
#
# Train set: Average log loss: -13.0128
#
#
# Test set: Average loss: -13.0234
#
# Current Learning rate 0.0001
# Train Epoch: 180 [0/90000 (0%)]	log Loss: -13.013098
#
# Train set: Average log loss: -11.0642
#
#
# Test set: Average loss: -13.9433
#
# Current Learning rate 0.0001
# Train Epoch: 181 [0/90000 (0%)]	log Loss: -13.935636
#
# Train set: Average log loss: -14.1077
#
#
# Test set: Average loss: -14.5424
#
# Current Learning rate 0.0001
# Train Epoch: 182 [0/90000 (0%)]	log Loss: -14.560093
#
# Train set: Average log loss: -14.1062
#
#
# Test set: Average loss: -14.2871
#
# Current Learning rate 0.0001
# Train Epoch: 183 [0/90000 (0%)]	log Loss: -14.266521
#
# Train set: Average log loss: -12.7765
#
#
# Test set: Average loss: -13.1773
#
# Current Learning rate 0.0001
# Train Epoch: 184 [0/90000 (0%)]	log Loss: -13.254193
#
# Train set: Average log loss: -12.1542
#
#
# Test set: Average loss: -14.2984
#
# Current Learning rate 0.0001
# Train Epoch: 185 [0/90000 (0%)]	log Loss: -14.291588
#
# Train set: Average log loss: -12.3942
#
#
# Test set: Average loss: -11.7511
#
# Current Learning rate 0.0001
# Train Epoch: 186 [0/90000 (0%)]	log Loss: -11.746465
#
# Train set: Average log loss: -12.5551
#
#
# Test set: Average loss: -11.8845
#
# Current Learning rate 0.0001
# Train Epoch: 187 [0/90000 (0%)]	log Loss: -11.923344
#
# Train set: Average log loss: -12.7955
#
#
# Test set: Average loss: -14.1901
#
# Current Learning rate 0.0001
# Train Epoch: 188 [0/90000 (0%)]	log Loss: -14.191971
#
# Train set: Average log loss: -11.6482
#
#
# Test set: Average loss: -14.4443
#
# Current Learning rate 0.0001
# Train Epoch: 189 [0/90000 (0%)]	log Loss: -14.481193
#
# Train set: Average log loss: -13.7288
#
#
# Test set: Average loss: -12.5957
#
# Current Learning rate 0.0001
# Train Epoch: 190 [0/90000 (0%)]	log Loss: -12.650034
#
# Train set: Average log loss: -12.2993
#
#
# Test set: Average loss: -14.5804
#
# Current Learning rate 0.0001
# Train Epoch: 191 [0/90000 (0%)]	log Loss: -14.672763
#
# Train set: Average log loss: -12.6784
#
#
# Test set: Average loss: -12.1328
#
# Current Learning rate 0.0001
# Train Epoch: 192 [0/90000 (0%)]	log Loss: -12.174355
#
# Train set: Average log loss: -11.2620
#
#
# Test set: Average loss: -13.9902
#
# Current Learning rate 0.0001
# Train Epoch: 193 [0/90000 (0%)]	log Loss: -13.965218
#
# Train set: Average log loss: -14.3867
#
#
# Test set: Average loss: -14.4628
#
# Current Learning rate 0.0001
# Train Epoch: 194 [0/90000 (0%)]	log Loss: -14.465602
#
# Train set: Average log loss: -13.8553
#
#
# Test set: Average loss: -13.7431
#
# Current Learning rate 0.0001
# Train Epoch: 195 [0/90000 (0%)]	log Loss: -13.831507
#
# Train set: Average log loss: -12.2681
#
#
# Test set: Average loss: -14.5024
#
# Current Learning rate 0.0001
# Train Epoch: 196 [0/90000 (0%)]	log Loss: -14.515275
#
# Train set: Average log loss: -12.1920
#
#
# Test set: Average loss: -14.2005
#
# Current Learning rate 0.0001
# Train Epoch: 197 [0/90000 (0%)]	log Loss: -14.176537
#
# Train set: Average log loss: -12.5226
#
#
# Test set: Average loss: -13.5183
#
# Current Learning rate 0.0001
# Train Epoch: 198 [0/90000 (0%)]	log Loss: -13.593683
#
# Train set: Average log loss: -13.0194
#
#
# Test set: Average loss: -14.2611
#
# Current Learning rate 0.0001
# Train Epoch: 199 [0/90000 (0%)]	log Loss: -14.352035
#
# Train set: Average log loss: -11.8918
#
#
# Test set: Average loss: -13.9397
#
# Current Learning rate 0.0001
# Train Epoch: 200 [0/90000 (0%)]	log Loss: -13.908321
#
# Train set: Average log loss: -12.6237
#
#
# Test set: Average loss: -11.9754
#
# Current Learning rate 0.0001
# Train Epoch: 201 [0/90000 (0%)]	log Loss: -12.022616
#
# Train set: Average log loss: -13.0364
#
#
# Test set: Average loss: -14.3810
#
# Current Learning rate 0.0001
# Train Epoch: 202 [0/90000 (0%)]	log Loss: -14.355419
#
# Train set: Average log loss: -12.1551
#
#
# Test set: Average loss: -13.8918
#
# Current Learning rate 0.0001
# Train Epoch: 203 [0/90000 (0%)]	log Loss: -13.860170
#
# Train set: Average log loss: -12.2923
#
#
# Test set: Average loss: -13.5814
#
# Current Learning rate 0.0001
# Train Epoch: 204 [0/90000 (0%)]	log Loss: -13.546704
#
# Train set: Average log loss: -12.6887
#
#
# Test set: Average loss: -14.5692
#
# Current Learning rate 0.0001
# Train Epoch: 205 [0/90000 (0%)]	log Loss: -14.535487
#
# Train set: Average log loss: -12.5596
#
#
# Test set: Average loss: -13.3549
#
# Current Learning rate 0.0001
# Train Epoch: 206 [0/90000 (0%)]	log Loss: -13.427912
#
# Train set: Average log loss: -12.4482
#
#
# Test set: Average loss: -12.8776
#
# Current Learning rate 0.0001
# Train Epoch: 207 [0/90000 (0%)]	log Loss: -12.833843
#
# Train set: Average log loss: -12.2493
#
#
# Test set: Average loss: -13.5554
#
# Current Learning rate 0.0001
# Train Epoch: 208 [0/90000 (0%)]	log Loss: -13.512589
#
# Train set: Average log loss: -12.8136
#
#
# Test set: Average loss: -12.7885
#
# Current Learning rate 0.0001
# Train Epoch: 209 [0/90000 (0%)]	log Loss: -12.744966
#
# Train set: Average log loss: -11.9389
#
#
# Test set: Average loss: -14.0363
#
# Current Learning rate 0.0001
# Train Epoch: 210 [0/90000 (0%)]	log Loss: -13.977129
#
# Train set: Average log loss: -13.7324
#
#
# Test set: Average loss: -12.7243
#
# Current Learning rate 0.0001
# Train Epoch: 211 [0/90000 (0%)]	log Loss: -12.686579
#
# Train set: Average log loss: -12.2577
#
#
# Test set: Average loss: -14.5999
#
# Current Learning rate 0.0001
# Train Epoch: 212 [0/90000 (0%)]	log Loss: -14.583792
#
# Train set: Average log loss: -12.5689
#
#
# Test set: Average loss: -13.5199
#
# Current Learning rate 0.0001
# Train Epoch: 213 [0/90000 (0%)]	log Loss: -13.457266
#
# Train set: Average log loss: -12.5458
#
#
# Test set: Average loss: -11.4967
#
# Current Learning rate 0.0001
# Train Epoch: 214 [0/90000 (0%)]	log Loss: -11.525844
#
# Train set: Average log loss: -12.4722
#
#
# Test set: Average loss: -12.4543
#
# Current Learning rate 0.0001
# Train Epoch: 215 [0/90000 (0%)]	log Loss: -12.417459
#
# Train set: Average log loss: -12.6408
#
#
# Test set: Average loss: -13.1504
#
# Current Learning rate 0.0001
# Train Epoch: 216 [0/90000 (0%)]	log Loss: -13.116711
#
# Train set: Average log loss: -11.7128
#
#
# Test set: Average loss: -14.5959
#
# Current Learning rate 0.0001
# Train Epoch: 217 [0/90000 (0%)]	log Loss: -14.576990
#
# Train set: Average log loss: -13.9990
#
#
# Test set: Average loss: -13.8217
#
# Current Learning rate 0.0001
# Train Epoch: 218 [0/90000 (0%)]	log Loss: -13.770820
#
# Train set: Average log loss: -12.5841
#
#
# Test set: Average loss: -14.4708
#
# Current Learning rate 0.0001
# Train Epoch: 219 [0/90000 (0%)]	log Loss: -14.388107
#
# Train set: Average log loss: -12.8644
#
#
# Test set: Average loss: -14.7354
#
# Current Learning rate 0.0001
# Train Epoch: 220 [0/90000 (0%)]	log Loss: -14.715339
#
# Train set: Average log loss: -12.4509
#
#
# Test set: Average loss: -12.1953
#
# Current Learning rate 0.0001
# Train Epoch: 221 [0/90000 (0%)]	log Loss: -12.242758
#
# Train set: Average log loss: -12.4660
#
#
# Test set: Average loss: -12.2391
#
# Current Learning rate 0.0001
# Train Epoch: 222 [0/90000 (0%)]	log Loss: -12.216395
#
# Train set: Average log loss: -12.6771
#
#
# Test set: Average loss: -11.9249
#
# Current Learning rate 0.0001
# Train Epoch: 223 [0/90000 (0%)]	log Loss: -11.909417
#
# Train set: Average log loss: -12.6151
#
#
# Test set: Average loss: -12.2845
#
# Current Learning rate 0.0001
# Train Epoch: 224 [0/90000 (0%)]	log Loss: -12.261199
#
# Train set: Average log loss: -11.6561
#
#
# Test set: Average loss: -14.2114
#
# Current Learning rate 0.0001
# Train Epoch: 225 [0/90000 (0%)]	log Loss: -14.175680
#
# Train set: Average log loss: -13.8330
#
#
# Test set: Average loss: -13.1444
#
# Current Learning rate 0.0001
# Train Epoch: 226 [0/90000 (0%)]	log Loss: -13.103855
#
# Train set: Average log loss: -13.5674
#
#
# Test set: Average loss: -14.6902
#
# Current Learning rate 0.0001
# Train Epoch: 227 [0/90000 (0%)]	log Loss: -14.668814
#
# Train set: Average log loss: -12.1207
#
#
# Test set: Average loss: -13.4509
#
# Current Learning rate 0.0001
# Train Epoch: 228 [0/90000 (0%)]	log Loss: -13.421580
#
# Train set: Average log loss: -13.2378
#
#
# Test set: Average loss: -12.9979
#
# Current Learning rate 0.0001
# Train Epoch: 229 [0/90000 (0%)]	log Loss: -13.052676
#
# Train set: Average log loss: -12.4863
#
#
# Test set: Average loss: -13.0614
#
# Current Learning rate 0.0001
# Train Epoch: 230 [0/90000 (0%)]	log Loss: -13.042334
#
# Train set: Average log loss: -11.6479
#
#
# Test set: Average loss: -14.7733
#
# Current Learning rate 0.0001
# Train Epoch: 231 [0/90000 (0%)]	log Loss: -14.758210
#
# Train set: Average log loss: -13.8378
#
#
# Test set: Average loss: -13.2088
#
# Current Learning rate 0.0001
# Train Epoch: 232 [0/90000 (0%)]	log Loss: -13.179034
#
# Train set: Average log loss: -13.8216
#
#
# Test set: Average loss: -14.3539
#
# Current Learning rate 0.0001
# Train Epoch: 233 [0/90000 (0%)]	log Loss: -14.424594
#
# Train set: Average log loss: -12.3506
#
#
# Test set: Average loss: -13.7231
#
# Current Learning rate 0.0001
# Train Epoch: 234 [0/90000 (0%)]	log Loss: -13.698919
#
# Train set: Average log loss: -12.2763
#
#
# Test set: Average loss: -13.5873
#
# Current Learning rate 0.0001
# Train Epoch: 235 [0/90000 (0%)]	log Loss: -13.564983
#
# Train set: Average log loss: -13.5792
#
#
# Test set: Average loss: -13.4888
#
# Current Learning rate 0.0001
# Train Epoch: 236 [0/90000 (0%)]	log Loss: -13.543695
#
# Train set: Average log loss: -12.3950
#
#
# Test set: Average loss: -13.8692
#
# Current Learning rate 0.0001
# Train Epoch: 237 [0/90000 (0%)]	log Loss: -13.850617
#
# Train set: Average log loss: -12.0532
#
#
# Test set: Average loss: -14.6204
#
# Current Learning rate 0.0001
# Train Epoch: 238 [0/90000 (0%)]	log Loss: -14.637657
#
# Train set: Average log loss: -13.9363
#
#
# Test set: Average loss: -14.6710
#
# Current Learning rate 0.0001
# Train Epoch: 239 [0/90000 (0%)]	log Loss: -14.653474
#
# Train set: Average log loss: -12.6513
#
#
# Test set: Average loss: -13.0138
#
# Current Learning rate 0.0001
# Train Epoch: 240 [0/90000 (0%)]	log Loss: -12.992209
#
# Train set: Average log loss: -11.8965
#
#
# Test set: Average loss: -14.7475
#
# Current Learning rate 0.0001
# Train Epoch: 241 [0/90000 (0%)]	log Loss: -14.749058
#
# Train set: Average log loss: -14.0471
#
#
# Test set: Average loss: -13.5339
#
# Current Learning rate 0.0001
# Train Epoch: 242 [0/90000 (0%)]	log Loss: -13.506507
#
# Train set: Average log loss: -12.6271
#
#
# Test set: Average loss: -13.6814
#
# Current Learning rate 0.0001
# Train Epoch: 243 [0/90000 (0%)]	log Loss: -13.654279
#
# Train set: Average log loss: -12.9614
#
#
# Test set: Average loss: -13.1534
#
# Current Learning rate 0.0001
# Train Epoch: 244 [0/90000 (0%)]	log Loss: -13.197053
#
# Train set: Average log loss: -12.6779
#
#
# Test set: Average loss: -14.7233
#
# Current Learning rate 0.0001
# Train Epoch: 245 [0/90000 (0%)]	log Loss: -14.713993
#
# Train set: Average log loss: -12.6564
#
#
# Test set: Average loss: -12.4734
#
# Current Learning rate 0.0001
# Train Epoch: 246 [0/90000 (0%)]	log Loss: -12.506725
#
# Train set: Average log loss: -12.5479
#
#
# Test set: Average loss: -12.7059
#
# Current Learning rate 0.0001
# Train Epoch: 247 [0/90000 (0%)]	log Loss: -12.746706
#
# Train set: Average log loss: -12.4581
#
#
# Test set: Average loss: -12.9562
#
# Current Learning rate 0.0001
# Train Epoch: 248 [0/90000 (0%)]	log Loss: -12.946875
#
# Train set: Average log loss: -13.1371
#
#
# Test set: Average loss: -14.9816
#
# Current Learning rate 0.0001
# Train Epoch: 249 [0/90000 (0%)]	log Loss: -15.014310
#
# Train set: Average log loss: -12.1317
#
#
# Test set: Average loss: -13.3223
#
# Current Learning rate 0.0001
# Train Epoch: 250 [0/90000 (0%)]	log Loss: -13.311156
#
# Train set: Average log loss: -13.7864
#
#
# Test set: Average loss: -15.0133
#
# Current Learning rate 0.0001
# Train Epoch: 251 [0/90000 (0%)]	log Loss: -15.064348
#
# Train set: Average log loss: -11.8515
#
#
# Test set: Average loss: -14.8793
#
# Current Learning rate 0.0001
# Train Epoch: 252 [0/90000 (0%)]	log Loss: -14.910646
#
# Train set: Average log loss: -14.0682
#
#
# Test set: Average loss: -13.1651
#
# Current Learning rate 0.0001
# Train Epoch: 253 [0/90000 (0%)]	log Loss: -13.152363
#
# Train set: Average log loss: -12.2854
#
#
# Test set: Average loss: -13.9054
#
# Current Learning rate 0.0001
# Train Epoch: 254 [0/90000 (0%)]	log Loss: -13.895818
#
# Train set: Average log loss: -13.9714
#
#
# Test set: Average loss: -14.5996
#
# Current Learning rate 0.0001
# Train Epoch: 255 [0/90000 (0%)]	log Loss: -14.674085
#
# Train set: Average log loss: -12.0930
#
#
# Test set: Average loss: -13.9842
#
# Current Learning rate 0.0001
# Train Epoch: 256 [0/90000 (0%)]	log Loss: -13.987219
#
# Train set: Average log loss: -13.8909
#
#
# Test set: Average loss: -14.6026
#
# Current Learning rate 0.0001
# Train Epoch: 257 [0/90000 (0%)]	log Loss: -14.686323
#
# Train set: Average log loss: -12.3598
#
#
# Test set: Average loss: -13.2055
#
# Current Learning rate 0.0001
# Train Epoch: 258 [0/90000 (0%)]	log Loss: -13.199669
#
# Train set: Average log loss: -13.3671
#
#
# Test set: Average loss: -13.5972
#
# Current Learning rate 0.0001
# Train Epoch: 259 [0/90000 (0%)]	log Loss: -13.644118
#
# Train set: Average log loss: -12.2574
#
#
# Test set: Average loss: -13.3057
#
# Current Learning rate 0.0001
# Train Epoch: 260 [0/90000 (0%)]	log Loss: -13.301171
#
# Train set: Average log loss: -13.3841
#
#
# Test set: Average loss: -12.9000
#
# Current Learning rate 0.0001
# Train Epoch: 261 [0/90000 (0%)]	log Loss: -12.935692
#
# Train set: Average log loss: -12.4516
#
#
# Test set: Average loss: -13.4037
#
# Current Learning rate 0.0001
# Train Epoch: 262 [0/90000 (0%)]	log Loss: -13.395221
#
# Train set: Average log loss: -12.0185
#
#
# Test set: Average loss: -14.1295
#
# Current Learning rate 0.0001
# Train Epoch: 263 [0/90000 (0%)]	log Loss: -14.122313
#
# Train set: Average log loss: -13.6955
#
#
# Test set: Average loss: -13.3027
#
# Current Learning rate 0.0001
# Train Epoch: 264 [0/90000 (0%)]	log Loss: -13.289483
#
# Train set: Average log loss: -13.6966
#
#
# Test set: Average loss: -13.7395
#
# Current Learning rate 0.0001
# Train Epoch: 265 [0/90000 (0%)]	log Loss: -13.732671
#
# Train set: Average log loss: -11.7122
#
#
# Test set: Average loss: -14.7860
#
# Current Learning rate 0.0001
# Train Epoch: 266 [0/90000 (0%)]	log Loss: -14.758238
#
# Train set: Average log loss: -13.5938
#
#
# Test set: Average loss: -14.7919
#
# Current Learning rate 0.0001
# Train Epoch: 267 [0/90000 (0%)]	log Loss: -14.782165
#
# Train set: Average log loss: -13.9103
#
#
# Test set: Average loss: -15.0416
#
# Current Learning rate 0.0001
# Train Epoch: 268 [0/90000 (0%)]	log Loss: -15.089964
#
# Train set: Average log loss: -12.8492
#
#
# Test set: Average loss: -12.9639
#
# Current Learning rate 0.0001
# Train Epoch: 269 [0/90000 (0%)]	log Loss: -12.997586
#
# Train set: Average log loss: -12.6247
#
#
# Test set: Average loss: -13.1719
#
# Current Learning rate 0.0001
# Train Epoch: 270 [0/90000 (0%)]	log Loss: -13.222147
#
# Train set: Average log loss: -12.5096
#
#
# Test set: Average loss: -13.5432
#
# Current Learning rate 0.0001
# Train Epoch: 271 [0/90000 (0%)]	log Loss: -13.526708
#
# Train set: Average log loss: -12.9355
#
#
# Test set: Average loss: -12.6593
#
# Current Learning rate 0.0001
# Train Epoch: 272 [0/90000 (0%)]	log Loss: -12.709528
#
# Train set: Average log loss: -12.7846
#
#
# Test set: Average loss: -13.2523
#
# Current Learning rate 0.0001
# Train Epoch: 273 [0/90000 (0%)]	log Loss: -13.231476
#
# Train set: Average log loss: -12.2829
#
#
# Test set: Average loss: -14.7524
#
# Current Learning rate 0.0001
# Train Epoch: 274 [0/90000 (0%)]	log Loss: -14.729642
#
# Train set: Average log loss: -13.8492
#
#
# Test set: Average loss: -14.7959
#
# Current Learning rate 0.0001
# Train Epoch: 275 [0/90000 (0%)]	log Loss: -14.784461
#
# Train set: Average log loss: -12.5122
#
#
# Test set: Average loss: -13.5095
#
# Current Learning rate 0.0001
# Train Epoch: 276 [0/90000 (0%)]	log Loss: -13.500973
#
# Train set: Average log loss: -13.2397
#
#
# Test set: Average loss: -14.5252
#
# Current Learning rate 0.0001
# Train Epoch: 277 [0/90000 (0%)]	log Loss: -14.522005
#
# Train set: Average log loss: -12.6707
#
#
# Test set: Average loss: -13.0135
#
# Current Learning rate 0.0001
# Train Epoch: 278 [0/90000 (0%)]	log Loss: -13.006279
#
# Train set: Average log loss: -11.8421
#
#
# Test set: Average loss: -14.8510
#
# Current Learning rate 0.0001
# Train Epoch: 279 [0/90000 (0%)]	log Loss: -14.847685
#
# Train set: Average log loss: -13.7610
#
#
# Test set: Average loss: -14.9753
#
# Current Learning rate 0.0001
# Train Epoch: 280 [0/90000 (0%)]	log Loss: -14.993540
#
# Train set: Average log loss: -14.2426
#
#
# Test set: Average loss: -13.9124
#
# Current Learning rate 0.0001
# Train Epoch: 281 [0/90000 (0%)]	log Loss: -13.912137
#
# Train set: Average log loss: -12.1483
#
#
# Test set: Average loss: -15.0610
#
# Current Learning rate 0.0001
# Train Epoch: 282 [0/90000 (0%)]	log Loss: -15.102810
#
# Train set: Average log loss: -14.4185
#
#
# Test set: Average loss: -13.7678
#
# Current Learning rate 0.0001
# Train Epoch: 283 [0/90000 (0%)]	log Loss: -13.774306
#
# Train set: Average log loss: -12.5627
#
#
# Test set: Average loss: -13.5705
#
# Current Learning rate 0.0001
# Train Epoch: 284 [0/90000 (0%)]	log Loss: -13.577785
#
# Train set: Average log loss: -12.9978
#
#
# Test set: Average loss: -14.9958
#
# Current Learning rate 0.0001
# Train Epoch: 285 [0/90000 (0%)]	log Loss: -14.991281
#
# Train set: Average log loss: -12.2770
#
#
# Test set: Average loss: -11.6227
#
# Current Learning rate 0.0001
# Train Epoch: 286 [0/90000 (0%)]	log Loss: -11.594894
#
# Train set: Average log loss: -13.1472
#
#
# Test set: Average loss: -13.7439
#
# Current Learning rate 0.0001
# Train Epoch: 287 [0/90000 (0%)]	log Loss: -13.750403
#
# Train set: Average log loss: -13.0395
#
#
# Test set: Average loss: -13.2013
#
# Current Learning rate 0.0001
# Train Epoch: 288 [0/90000 (0%)]	log Loss: -13.237658
#
# Train set: Average log loss: -12.9679
#
#
# Test set: Average loss: -14.1900
#
# Current Learning rate 0.0001
# Train Epoch: 289 [0/90000 (0%)]	log Loss: -14.179952
#
# Train set: Average log loss: -12.7987
#
#
# Test set: Average loss: -12.4355
#
# Current Learning rate 0.0001
# Train Epoch: 290 [0/90000 (0%)]	log Loss: -12.453526
#
# Train set: Average log loss: -12.6526
#
#
# Test set: Average loss: -13.4135
#
# Current Learning rate 0.0001
# Train Epoch: 291 [0/90000 (0%)]	log Loss: -13.431788
#
# Train set: Average log loss: -13.0628
#
#
# Test set: Average loss: -15.1289
#
# Current Learning rate 0.0001
# Train Epoch: 292 [0/90000 (0%)]	log Loss: -15.140213
#
# Train set: Average log loss: -12.8963
#
#
# Test set: Average loss: -14.2838
#
# Current Learning rate 0.0001
# Train Epoch: 293 [0/90000 (0%)]	log Loss: -14.285698
#
# Train set: Average log loss: -12.2080
#
#
# Test set: Average loss: -14.6999
#
# Current Learning rate 0.0001
# Train Epoch: 294 [0/90000 (0%)]	log Loss: -14.665894
#
# Train set: Average log loss: -14.4238
#
#
# Test set: Average loss: -14.0595
#
# Current Learning rate 0.0001
# Train Epoch: 295 [0/90000 (0%)]	log Loss: -14.071361
#
# Train set: Average log loss: -12.0429
#
#
# Test set: Average loss: -14.7196
#
# Current Learning rate 0.0001
# Train Epoch: 296 [0/90000 (0%)]	log Loss: -14.713164
#
# Train set: Average log loss: -14.5530
#
#
# Test set: Average loss: -13.4778
#
# Current Learning rate 0.0001
# Train Epoch: 297 [0/90000 (0%)]	log Loss: -13.501913
#
# Train set: Average log loss: -13.3358
#
#
# Test set: Average loss: -15.1616
#
# Current Learning rate 0.0001
# Train Epoch: 298 [0/90000 (0%)]	log Loss: -15.178249
#
# Train set: Average log loss: -12.4643
#
#
# Test set: Average loss: -13.7302
#
# Current Learning rate 0.0001
# Train Epoch: 299 [0/90000 (0%)]	log Loss: -13.744560
#
# Train set: Average log loss: -13.4047
#
#
# Test set: Average loss: -14.1638
#
# Current Learning rate 0.0001
# Train Epoch: 300 [0/90000 (0%)]	log Loss: -14.182208
#
# Train set: Average log loss: -12.5548
#
#
# Test set: Average loss: -13.6974
#
# Current Learning rate 0.0001
# Train Epoch: 301 [0/90000 (0%)]	log Loss: -13.717163
#
# Train set: Average log loss: -13.1032
#
#
# Test set: Average loss: -12.6288
#
# Current Learning rate 0.0001
# Train Epoch: 302 [0/90000 (0%)]	log Loss: -12.653249
#
# Train set: Average log loss: -12.1943
#
#
# Test set: Average loss: -14.4206
#
# Current Learning rate 0.0001
# Train Epoch: 303 [0/90000 (0%)]	log Loss: -14.375757
#
# Train set: Average log loss: -14.3313
#
#
# Test set: Average loss: -14.2031
#
# Current Learning rate 0.0001
# Train Epoch: 304 [0/90000 (0%)]	log Loss: -14.228114
#
# Train set: Average log loss: -12.1161
#
#
# Test set: Average loss: -14.3229
#
# Current Learning rate 0.0001
# Train Epoch: 305 [0/90000 (0%)]	log Loss: -14.294471
#
# Train set: Average log loss: -14.0892
#
#
# Test set: Average loss: -14.5086
#
# Current Learning rate 0.0001
# Train Epoch: 306 [0/90000 (0%)]	log Loss: -14.554228
#
# ...
#
# Train set: Average log loss: -17.5808
#
#
# Test set: Average loss: -17.3726
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2910 [0/90000 (0%)]	log Loss: -17.592270
#
# Train set: Average log loss: -17.5809
#
#
# Test set: Average loss: -17.3727
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2911 [0/90000 (0%)]	log Loss: -17.592321
#
# Train set: Average log loss: -17.5810
#
#
# Test set: Average loss: -17.3728
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2912 [0/90000 (0%)]	log Loss: -17.592441
#
# Train set: Average log loss: -17.5811
#
#
# Test set: Average loss: -17.3728
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2913 [0/90000 (0%)]	log Loss: -17.592398
#
# Train set: Average log loss: -17.5811
#
#
# Test set: Average loss: -17.3728
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2914 [0/90000 (0%)]	log Loss: -17.592570
#
# Train set: Average log loss: -17.5812
#
#
# Test set: Average loss: -17.3729
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2915 [0/90000 (0%)]	log Loss: -17.592504
#
# Train set: Average log loss: -17.5813
#
#
# Test set: Average loss: -17.3729
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2916 [0/90000 (0%)]	log Loss: -17.592656
#
# Train set: Average log loss: -17.5813
#
#
# Test set: Average loss: -17.3730
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2917 [0/90000 (0%)]	log Loss: -17.592631
#
# Train set: Average log loss: -17.5815
#
#
# Test set: Average loss: -17.3730
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2918 [0/90000 (0%)]	log Loss: -17.592716
#
# Train set: Average log loss: -17.5815
#
#
# Test set: Average loss: -17.3731
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2919 [0/90000 (0%)]	log Loss: -17.592859
#
# Train set: Average log loss: -17.5816
#
#
# Test set: Average loss: -17.3731
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2920 [0/90000 (0%)]	log Loss: -17.592856
#
# Train set: Average log loss: -17.5817
#
#
# Test set: Average loss: -17.3732
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2921 [0/90000 (0%)]	log Loss: -17.592968
#
# Train set: Average log loss: -17.5817
#
#
# Test set: Average loss: -17.3732
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2922 [0/90000 (0%)]	log Loss: -17.593022
#
# Train set: Average log loss: -17.5818
#
#
# Test set: Average loss: -17.3733
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2923 [0/90000 (0%)]	log Loss: -17.593111
#
# Train set: Average log loss: -17.5819
#
#
# Test set: Average loss: -17.3733
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2924 [0/90000 (0%)]	log Loss: -17.592979
#
# Train set: Average log loss: -17.5820
#
#
# Test set: Average loss: -17.3734
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2925 [0/90000 (0%)]	log Loss: -17.593168
#
# Train set: Average log loss: -17.5820
#
#
# Test set: Average loss: -17.3736
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2926 [0/90000 (0%)]	log Loss: -17.593299
#
# Train set: Average log loss: -17.5821
#
#
# Test set: Average loss: -17.3736
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2927 [0/90000 (0%)]	log Loss: -17.593464
#
# Train set: Average log loss: -17.5822
#
#
# Test set: Average loss: -17.3736
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2928 [0/90000 (0%)]	log Loss: -17.593335
#
# Train set: Average log loss: -17.5823
#
#
# Test set: Average loss: -17.3736
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2929 [0/90000 (0%)]	log Loss: -17.593358
#
# Train set: Average log loss: -17.5823
#
#
# Test set: Average loss: -17.3738
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2930 [0/90000 (0%)]	log Loss: -17.593497
#
# Train set: Average log loss: -17.5824
#
#
# Test set: Average loss: -17.3738
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2931 [0/90000 (0%)]	log Loss: -17.593639
#
# Train set: Average log loss: -17.5825
#
#
# Test set: Average loss: -17.3739
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2932 [0/90000 (0%)]	log Loss: -17.593660
#
# Train set: Average log loss: -17.5826
#
#
# Test set: Average loss: -17.3739
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2933 [0/90000 (0%)]	log Loss: -17.593705
#
# Train set: Average log loss: -17.5826
#
#
# Test set: Average loss: -17.3740
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2934 [0/90000 (0%)]	log Loss: -17.593823
#
# Train set: Average log loss: -17.5827
#
#
# Test set: Average loss: -17.3741
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2935 [0/90000 (0%)]	log Loss: -17.593930
#
# Train set: Average log loss: -17.5828
#
#
# Test set: Average loss: -17.3742
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2936 [0/90000 (0%)]	log Loss: -17.594015
#
# Train set: Average log loss: -17.5829
#
#
# Test set: Average loss: -17.3742
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2937 [0/90000 (0%)]	log Loss: -17.594032
#
# Train set: Average log loss: -17.5829
#
#
# Test set: Average loss: -17.3743
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2938 [0/90000 (0%)]	log Loss: -17.594171
#
# Train set: Average log loss: -17.5830
#
#
# Test set: Average loss: -17.3743
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2939 [0/90000 (0%)]	log Loss: -17.594062
#
# Train set: Average log loss: -17.5831
#
#
# Test set: Average loss: -17.3744
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2940 [0/90000 (0%)]	log Loss: -17.594258
#
# Train set: Average log loss: -17.5832
#
#
# Test set: Average loss: -17.3743
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2941 [0/90000 (0%)]	log Loss: -17.593995
#
# Train set: Average log loss: -17.5832
#
#
# Test set: Average loss: -17.3745
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2942 [0/90000 (0%)]	log Loss: -17.594229
#
# Train set: Average log loss: -17.5833
#
#
# Test set: Average loss: -17.3745
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2943 [0/90000 (0%)]	log Loss: -17.594279
#
# Train set: Average log loss: -17.5834
#
#
# Test set: Average loss: -17.3745
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2944 [0/90000 (0%)]	log Loss: -17.594224
#
# Train set: Average log loss: -17.5835
#
#
# Test set: Average loss: -17.3747
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2945 [0/90000 (0%)]	log Loss: -17.594480
#
# Train set: Average log loss: -17.5835
#
#
# Test set: Average loss: -17.3746
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2946 [0/90000 (0%)]	log Loss: -17.594347
#
# Train set: Average log loss: -17.5836
#
#
# Test set: Average loss: -17.3748
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2947 [0/90000 (0%)]	log Loss: -17.594506
#
# Train set: Average log loss: -17.5837
#
#
# Test set: Average loss: -17.3747
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2948 [0/90000 (0%)]	log Loss: -17.594392
#
# Train set: Average log loss: -17.5838
#
#
# Test set: Average loss: -17.3748
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2949 [0/90000 (0%)]	log Loss: -17.594602
#
# Train set: Average log loss: -17.5839
#
#
# Test set: Average loss: -17.3749
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2950 [0/90000 (0%)]	log Loss: -17.594590
#
# Train set: Average log loss: -17.5839
#
#
# Test set: Average loss: -17.3749
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2951 [0/90000 (0%)]	log Loss: -17.594666
#
# Train set: Average log loss: -17.5840
#
#
# Test set: Average loss: -17.3750
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2952 [0/90000 (0%)]	log Loss: -17.594809
#
# Train set: Average log loss: -17.5841
#
#
# Test set: Average loss: -17.3751
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2953 [0/90000 (0%)]	log Loss: -17.594856
#
# Train set: Average log loss: -17.5841
#
#
# Test set: Average loss: -17.3751
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2954 [0/90000 (0%)]	log Loss: -17.594836
#
# Train set: Average log loss: -17.5842
#
#
# Test set: Average loss: -17.3751
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2955 [0/90000 (0%)]	log Loss: -17.594742
#
# Train set: Average log loss: -17.5843
#
#
# Test set: Average loss: -17.3753
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2956 [0/90000 (0%)]	log Loss: -17.595008
#
# Train set: Average log loss: -17.5844
#
#
# Test set: Average loss: -17.3753
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2957 [0/90000 (0%)]	log Loss: -17.594926
#
# Train set: Average log loss: -17.5844
#
#
# Test set: Average loss: -17.3753
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2958 [0/90000 (0%)]	log Loss: -17.594924
#
# Train set: Average log loss: -17.5845
#
#
# Test set: Average loss: -17.3755
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2959 [0/90000 (0%)]	log Loss: -17.595157
#
# Train set: Average log loss: -17.5846
#
#
# Test set: Average loss: -17.3755
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2960 [0/90000 (0%)]	log Loss: -17.595209
#
# Train set: Average log loss: -17.5847
#
#
# Test set: Average loss: -17.3756
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2961 [0/90000 (0%)]	log Loss: -17.595261
#
# Train set: Average log loss: -17.5847
#
#
# Test set: Average loss: -17.3757
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2962 [0/90000 (0%)]	log Loss: -17.595231
#
# Train set: Average log loss: -17.5848
#
#
# Test set: Average loss: -17.3758
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2963 [0/90000 (0%)]	log Loss: -17.595505
#
# Train set: Average log loss: -17.5849
#
#
# Test set: Average loss: -17.3757
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2964 [0/90000 (0%)]	log Loss: -17.595315
#
# Train set: Average log loss: -17.5850
#
#
# Test set: Average loss: -17.3758
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2965 [0/90000 (0%)]	log Loss: -17.595449
#
# Train set: Average log loss: -17.5850
#
#
# Test set: Average loss: -17.3759
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2966 [0/90000 (0%)]	log Loss: -17.595472
#
# Train set: Average log loss: -17.5851
#
#
# Test set: Average loss: -17.3760
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2967 [0/90000 (0%)]	log Loss: -17.595614
#
# Train set: Average log loss: -17.5852
#
#
# Test set: Average loss: -17.3761
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2968 [0/90000 (0%)]	log Loss: -17.595711
#
# Train set: Average log loss: -17.5852
#
#
# Test set: Average loss: -17.3762
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2969 [0/90000 (0%)]	log Loss: -17.595747
#
# Train set: Average log loss: -17.5853
#
#
# Test set: Average loss: -17.3762
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2970 [0/90000 (0%)]	log Loss: -17.595828
#
# Train set: Average log loss: -17.5854
#
#
# Test set: Average loss: -17.3763
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2971 [0/90000 (0%)]	log Loss: -17.595936
#
# Train set: Average log loss: -17.5855
#
#
# Test set: Average loss: -17.3764
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2972 [0/90000 (0%)]	log Loss: -17.596059
#
# Train set: Average log loss: -17.5856
#
#
# Test set: Average loss: -17.3765
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2973 [0/90000 (0%)]	log Loss: -17.596190
#
# Train set: Average log loss: -17.5856
#
#
# Test set: Average loss: -17.3765
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2974 [0/90000 (0%)]	log Loss: -17.596227
#
# Train set: Average log loss: -17.5857
#
#
# Test set: Average loss: -17.3766
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2975 [0/90000 (0%)]	log Loss: -17.596135
#
# Train set: Average log loss: -17.5858
#
#
# Test set: Average loss: -17.3766
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2976 [0/90000 (0%)]	log Loss: -17.596094
#
# Train set: Average log loss: -17.5859
#
#
# Test set: Average loss: -17.3767
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2977 [0/90000 (0%)]	log Loss: -17.596248
#
# Train set: Average log loss: -17.5859
#
#
# Test set: Average loss: -17.3768
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2978 [0/90000 (0%)]	log Loss: -17.596405
#
# Train set: Average log loss: -17.5860
#
#
# Test set: Average loss: -17.3769
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2979 [0/90000 (0%)]	log Loss: -17.596462
#
# Train set: Average log loss: -17.5861
#
#
# Test set: Average loss: -17.3770
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2980 [0/90000 (0%)]	log Loss: -17.596665
#
# Train set: Average log loss: -17.5862
#
#
# Test set: Average loss: -17.3770
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2981 [0/90000 (0%)]	log Loss: -17.596547
#
# Train set: Average log loss: -17.5862
#
#
# Test set: Average loss: -17.3771
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2982 [0/90000 (0%)]	log Loss: -17.596590
#
# Train set: Average log loss: -17.5863
#
#
# Test set: Average loss: -17.3772
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2983 [0/90000 (0%)]	log Loss: -17.596643
#
# Train set: Average log loss: -17.5864
#
#
# Test set: Average loss: -17.3772
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2984 [0/90000 (0%)]	log Loss: -17.596775
#
# Train set: Average log loss: -17.5864
#
#
# Test set: Average loss: -17.3773
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2985 [0/90000 (0%)]	log Loss: -17.596754
#
# Train set: Average log loss: -17.5865
#
#
# Test set: Average loss: -17.3774
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2986 [0/90000 (0%)]	log Loss: -17.596880
#
# Train set: Average log loss: -17.5866
#
#
# Test set: Average loss: -17.3775
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2987 [0/90000 (0%)]	log Loss: -17.596975
#
# Train set: Average log loss: -17.5867
#
#
# Test set: Average loss: -17.3775
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2988 [0/90000 (0%)]	log Loss: -17.597099
#
# Train set: Average log loss: -17.5868
#
#
# Test set: Average loss: -17.3776
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2989 [0/90000 (0%)]	log Loss: -17.597149
#
# Train set: Average log loss: -17.5868
#
#
# Test set: Average loss: -17.3776
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2990 [0/90000 (0%)]	log Loss: -17.597001
#
# Train set: Average log loss: -17.5869
#
#
# Test set: Average loss: -17.3777
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2991 [0/90000 (0%)]	log Loss: -17.597278
#
# Train set: Average log loss: -17.5869
#
#
# Test set: Average loss: -17.3779
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2992 [0/90000 (0%)]	log Loss: -17.597406
#
# Train set: Average log loss: -17.5870
#
#
# Test set: Average loss: -17.3779
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2993 [0/90000 (0%)]	log Loss: -17.597303
#
# Train set: Average log loss: -17.5871
#
#
# Test set: Average loss: -17.3779
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2994 [0/90000 (0%)]	log Loss: -17.597253
#
# Train set: Average log loss: -17.5872
#
#
# Test set: Average loss: -17.3780
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2995 [0/90000 (0%)]	log Loss: -17.597421
#
# Train set: Average log loss: -17.5873
#
#
# Test set: Average loss: -17.3780
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2996 [0/90000 (0%)]	log Loss: -17.597463
#
# Train set: Average log loss: -17.5874
#
#
# Test set: Average loss: -17.3781
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2997 [0/90000 (0%)]	log Loss: -17.597686
#
# Train set: Average log loss: -17.5874
#
#
# Test set: Average loss: -17.3782
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2998 [0/90000 (0%)]	log Loss: -17.597673
#
# Train set: Average log loss: -17.5875
#
#
# Test set: Average loss: -17.3782
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2999 [0/90000 (0%)]	log Loss: -17.597636
#
# Train set: Average log loss: -17.5876
#
#
# Test set: Average loss: -17.3783
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 3000 [0/90000 (0%)]	log Loss: -17.597777
#
# Train set: Average log loss: -17.5876
#
#
# Test set: Average loss: -17.3784
#
# Current Learning rate 1.0000000000000002e-06

# %%
# Plotting the Log(MSE) with respect to the epoch
plt.figure(figsize=(10,7))
plt.plot( np.log(test_losses), label = "test")
plt.plot( np.log(train_losses), label = "train")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Log(MSE)")
plt.title("MSE over Epoch" )
plt.grid()
print("Training WIDE {} VS in the article 8.04e-09".format(train_losses[-1]) )
# Out:
# Training WIDE 2.3003252494251886e-08 VS in the article 8.04e-09

# %%
# Loading model from saved parameters
loaded_BS_ANN = BS_ANN().to(device)
PATH = "ANN_weights/BS_ANN.pt"
loaded_BS_ANN.load_state_dict(torch.load(PATH))
loaded_BS_ANN.eval()
# Out:
# BS_ANN(
#   (fc1): Linear(in_features=4, out_features=400, bias=True)
#   (fc2): Linear(in_features=400, out_features=400, bias=True)
#   (fc3): Linear(in_features=400, out_features=400, bias=True)
#   (fc4): Linear(in_features=400, out_features=400, bias=True)
#   (fc5): Linear(in_features=400, out_features=1, bias=True)
# )

# %%
# Plotting erros histogram
errors = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_BS_ANN(data)
    errors.append((target-output).data.cpu().numpy())
  errors = np.concatenate(errors)
plt.figure(figsize=(10,7))
plt.hist(errors, 50, fill=False)
plt.grid()
plt.xlabel("Difference")
plt.ylabel("Density")
plt.show()
print("MAX ",errors.max())
print("MIN ",errors.min())
# Out:
# MAX  0.00092506036
# MIN  -0.0010469928

# %%
# Printing train and test MSE, MAE, MAPE and R2
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_BS_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_BS_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Train scores----------------
# MSE 2.652397e-08
# MAE 1.207284e-04
# MAPE 1.947651e-01
# R2 9.999994e-01
# -----------Test scores----------------
# MSE 2.647280e-08
# MAE 1.212164e-04
# MAPE 1.242439e-01
# R2 9.999995e-01

# %%
np.sqrt(2.597518e-08)
# Out:
# 0.00016116817303673826

# %%
# Replace this with a matrix
moneyness = np.linspace(0.4,1.4)
tau, r, sigma = 1, .02, .2
prices = bs_moneyness_call(moneyness, tau, r, sigma)

plot_dateset = np.ones((50,4))
plot_dateset[:,0] = moneyness
plot_dateset[:,1] = plot_dateset[:,1]*tau
plot_dateset[:,2] = plot_dateset[:,2]*r
plot_dateset[:,3] = plot_dateset[:,3]*sigma


plt.figure(figsize=(10,7))
plt.plot(moneyness, prices, label="Ground truth", linewidth=5 )


plot_dateset = torch.from_numpy(plot_dateset).type(torch.FloatTensor).to(device)
output = loaded_BS_ANN(plot_dateset)
plt.plot(moneyness, output.data.cpu().numpy(), "--", label="BS-ANN", linewidth=5)

plt.legend()
plt.xlabel("S/K (moneyness)")
plt.ylabel("P/K")
plt.title("Truth vs ANN" )
plt.grid()

# %% [markdown]
# ### Training BS-ANN with DecayLR from $10^{-4}$ to $10^{-6}$ Narrow dataset

# %%
# Training parameters
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}



use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# torch.manual_seed(args["seed"])


# Loading Train / Test Data
l_bounds = [.5, .3, .03, .02]
u_bounds = [1.5, .95, .08, .9]
bs_dataset = bs_LHS_data_generator(n = 10**5,l_bounds=l_bounds, u_bounds=u_bounds)
train_size, test_size = int(bs_dataset.shape[0]*0.9), int(bs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(bs_dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])



print(device)
model = BS_ANN().to(device)
# Adam is found to be the best optimizer in the article
optimizer = optim.Adam(model.parameters(), lr=args["lr"]) 
# Deacreses the Learning rate by .1 every 1000 epoch
scheduler = StepLR(optimizer, step_size=10**3, gamma=args["gamma"]) 

train_losses = []
test_losses = []
# Training loop
for epoch in range(1, args["epochs"] + 1):
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
if args["save_model"] :
  torch.save(model.state_dict(), "BS_ANN_narrow.pt")
# Out:
# ------ INPUT ------
# S/K.......... [0.50 1.50]
# Tau.......... [0.30 0.95]
# r............ [0.03 0.08]
# Sigma........ [0.02 0.90]
# ------ OUTPUT ------
# V/K.......... [0.00 0.73]
# cuda
# Train Epoch: 1 [0/90000 (0%)]	log Loss: -2.623463
#
# Train set: Average log loss: -4.5871
#
#
# Test set: Average loss: -6.9200
#
# Current Learning rate 0.0001
# Train Epoch: 2 [0/90000 (0%)]	log Loss: -6.930228
#
# Train set: Average log loss: -7.5880
#
#
# Test set: Average loss: -8.3521
#
# Current Learning rate 0.0001
# Train Epoch: 3 [0/90000 (0%)]	log Loss: -8.407589
#
# Train set: Average log loss: -8.8279
#
#
# Test set: Average loss: -9.3110
#
# Current Learning rate 0.0001
# Train Epoch: 4 [0/90000 (0%)]	log Loss: -9.395084
#
# Train set: Average log loss: -9.6382
#
#
# Test set: Average loss: -9.8990
#
# Current Learning rate 0.0001
# Train Epoch: 5 [0/90000 (0%)]	log Loss: -9.922584
#
# Train set: Average log loss: -10.1613
#
#
# Test set: Average loss: -10.3838
#
# Current Learning rate 0.0001
# Train Epoch: 6 [0/90000 (0%)]	log Loss: -10.427864
#
# Train set: Average log loss: -10.5330
#
#
# Test set: Average loss: -10.6945
#
# Current Learning rate 0.0001
# Train Epoch: 7 [0/90000 (0%)]	log Loss: -10.664112
#
# Train set: Average log loss: -10.8193
#
#
# Test set: Average loss: -10.9880
#
# Current Learning rate 0.0001
# Train Epoch: 8 [0/90000 (0%)]	log Loss: -10.940951
#
# Train set: Average log loss: -11.0924
#
#
# Test set: Average loss: -11.2773
#
# Current Learning rate 0.0001
# Train Epoch: 9 [0/90000 (0%)]	log Loss: -11.236073
#
# Train set: Average log loss: -11.2245
#
#
# Test set: Average loss: -11.4540
#
# Current Learning rate 0.0001
# Train Epoch: 10 [0/90000 (0%)]	log Loss: -11.436557
#
# Train set: Average log loss: -11.2052
#
#
# Test set: Average loss: -11.2765
#
# Current Learning rate 0.0001
# Train Epoch: 11 [0/90000 (0%)]	log Loss: -11.310536
#
# Train set: Average log loss: -11.1490
#
#
# Test set: Average loss: -11.1444
#
# Current Learning rate 0.0001
# Train Epoch: 12 [0/90000 (0%)]	log Loss: -11.195537
#
# Train set: Average log loss: -11.2126
#
#
# Test set: Average loss: -11.7127
#
# Current Learning rate 0.0001
# Train Epoch: 13 [0/90000 (0%)]	log Loss: -11.747624
#
# Train set: Average log loss: -11.2194
#
#
# Test set: Average loss: -11.9300
#
# Current Learning rate 0.0001
# Train Epoch: 14 [0/90000 (0%)]	log Loss: -11.886530
#
# Train set: Average log loss: -11.2267
#
#
# Test set: Average loss: -11.5998
#
# Current Learning rate 0.0001
# Train Epoch: 15 [0/90000 (0%)]	log Loss: -11.540126
#
# Train set: Average log loss: -11.1743
#
#
# Test set: Average loss: -11.5141
#
# Current Learning rate 0.0001
# Train Epoch: 16 [0/90000 (0%)]	log Loss: -11.458179
#
# Train set: Average log loss: -11.2228
#
#
# Test set: Average loss: -11.4710
#
# Current Learning rate 0.0001
# Train Epoch: 17 [0/90000 (0%)]	log Loss: -11.414327
#
# Train set: Average log loss: -11.1948
#
#
# Test set: Average loss: -11.5868
#
# Current Learning rate 0.0001
# Train Epoch: 18 [0/90000 (0%)]	log Loss: -11.526590
#
# Train set: Average log loss: -11.1984
#
#
# Test set: Average loss: -11.7827
#
# Current Learning rate 0.0001
# Train Epoch: 19 [0/90000 (0%)]	log Loss: -11.718139
#
# Train set: Average log loss: -11.1983
#
#
# Test set: Average loss: -11.9770
#
# Current Learning rate 0.0001
# Train Epoch: 20 [0/90000 (0%)]	log Loss: -11.909210
#
# Train set: Average log loss: -11.1954
#
#
# Test set: Average loss: -12.1278
#
# Current Learning rate 0.0001
# Train Epoch: 21 [0/90000 (0%)]	log Loss: -12.062088
#
# Train set: Average log loss: -11.2030
#
#
# Test set: Average loss: -12.3737
#
# Current Learning rate 0.0001
# Train Epoch: 22 [0/90000 (0%)]	log Loss: -12.316394
#
# Train set: Average log loss: -11.2107
#
#
# Test set: Average loss: -12.5205
#
# Current Learning rate 0.0001
# Train Epoch: 23 [0/90000 (0%)]	log Loss: -12.486900
#
# Train set: Average log loss: -11.2087
#
#
# Test set: Average loss: -12.5023
#
# Current Learning rate 0.0001
# Train Epoch: 24 [0/90000 (0%)]	log Loss: -12.488854
#
# Train set: Average log loss: -11.1977
#
#
# Test set: Average loss: -12.4696
#
# Current Learning rate 0.0001
# Train Epoch: 25 [0/90000 (0%)]	log Loss: -12.466682
#
# Train set: Average log loss: -11.1832
#
#
# Test set: Average loss: -12.5525
#
# Current Learning rate 0.0001
# Train Epoch: 26 [0/90000 (0%)]	log Loss: -12.543578
#
# Train set: Average log loss: -11.2603
#
#
# Test set: Average loss: -12.1766
#
# Current Learning rate 0.0001
# Train Epoch: 27 [0/90000 (0%)]	log Loss: -12.204772
#
# Train set: Average log loss: -11.1718
#
#
# Test set: Average loss: -12.3292
#
# Current Learning rate 0.0001
# Train Epoch: 28 [0/90000 (0%)]	log Loss: -12.351495
#
# Train set: Average log loss: -11.2447
#
#
# Test set: Average loss: -12.2107
#
# Current Learning rate 0.0001
# Train Epoch: 29 [0/90000 (0%)]	log Loss: -12.239618
#
# Train set: Average log loss: -11.2094
#
#
# Test set: Average loss: -12.1288
#
# Current Learning rate 0.0001
# Train Epoch: 30 [0/90000 (0%)]	log Loss: -12.158203
#
# Train set: Average log loss: -11.2303
#
#
# Test set: Average loss: -12.0995
#
# Current Learning rate 0.0001
# Train Epoch: 31 [0/90000 (0%)]	log Loss: -12.130926
#
# Train set: Average log loss: -11.2385
#
#
# Test set: Average loss: -12.0164
#
# Current Learning rate 0.0001
# Train Epoch: 32 [0/90000 (0%)]	log Loss: -12.050319
#
# Train set: Average log loss: -11.2397
#
#
# Test set: Average loss: -11.9965
#
# Current Learning rate 0.0001
# Train Epoch: 33 [0/90000 (0%)]	log Loss: -12.030855
#
# Train set: Average log loss: -11.2629
#
#
# Test set: Average loss: -11.9832
#
# Current Learning rate 0.0001
# Train Epoch: 34 [0/90000 (0%)]	log Loss: -12.017492
#
# Train set: Average log loss: -11.2728
#
#
# Test set: Average loss: -11.8876
#
# Current Learning rate 0.0001
# Train Epoch: 35 [0/90000 (0%)]	log Loss: -11.921847
#
# Train set: Average log loss: -11.2840
#
#
# Test set: Average loss: -11.8653
#
# Current Learning rate 0.0001
# Train Epoch: 36 [0/90000 (0%)]	log Loss: -11.895916
#
# Train set: Average log loss: -11.3003
#
#
# Test set: Average loss: -11.8438
#
# Current Learning rate 0.0001
# Train Epoch: 37 [0/90000 (0%)]	log Loss: -11.873740
#
# Train set: Average log loss: -11.3028
#
#
# Test set: Average loss: -11.8639
#
# Current Learning rate 0.0001
# Train Epoch: 38 [0/90000 (0%)]	log Loss: -11.892288
#
# Train set: Average log loss: -11.3001
#
#
# Test set: Average loss: -11.8739
#
# Current Learning rate 0.0001
# Train Epoch: 39 [0/90000 (0%)]	log Loss: -11.902969
#
# Train set: Average log loss: -11.3336
#
#
# Test set: Average loss: -11.9111
#
# Current Learning rate 0.0001
# Train Epoch: 40 [0/90000 (0%)]	log Loss: -11.940943
#
# Train set: Average log loss: -11.2946
#
#
# Test set: Average loss: -11.8109
#
# Current Learning rate 0.0001
# Train Epoch: 41 [0/90000 (0%)]	log Loss: -11.843605
#
# Train set: Average log loss: -11.3635
#
#
# Test set: Average loss: -11.9369
#
# Current Learning rate 0.0001
# Train Epoch: 42 [0/90000 (0%)]	log Loss: -11.970121
#
# Train set: Average log loss: -11.2455
#
#
# Test set: Average loss: -11.9329
#
# Current Learning rate 0.0001
# Train Epoch: 43 [0/90000 (0%)]	log Loss: -11.968546
#
# Train set: Average log loss: -11.3842
#
#
# Test set: Average loss: -12.1214
#
# Current Learning rate 0.0001
# Train Epoch: 44 [0/90000 (0%)]	log Loss: -12.156378
#
# Train set: Average log loss: -11.3395
#
#
# Test set: Average loss: -12.0236
#
# Current Learning rate 0.0001
# Train Epoch: 45 [0/90000 (0%)]	log Loss: -12.060167
#
# Train set: Average log loss: -11.3420
#
#
# Test set: Average loss: -12.0423
#
# Current Learning rate 0.0001
# Train Epoch: 46 [0/90000 (0%)]	log Loss: -12.080002
#
# Train set: Average log loss: -11.3670
#
#
# Test set: Average loss: -12.1168
#
# Current Learning rate 0.0001
# Train Epoch: 47 [0/90000 (0%)]	log Loss: -12.155687
#
# Train set: Average log loss: -11.3891
#
#
# Test set: Average loss: -12.0971
#
# Current Learning rate 0.0001
# Train Epoch: 48 [0/90000 (0%)]	log Loss: -12.138034
#
# Train set: Average log loss: -11.4151
#
#
# Test set: Average loss: -12.0713
#
# Current Learning rate 0.0001
# Train Epoch: 49 [0/90000 (0%)]	log Loss: -12.111798
#
# Train set: Average log loss: -11.3821
#
#
# Test set: Average loss: -12.0615
#
# Current Learning rate 0.0001
# Train Epoch: 50 [0/90000 (0%)]	log Loss: -12.100205
#
# Train set: Average log loss: -11.4459
#
#
# Test set: Average loss: -12.1411
#
# Current Learning rate 0.0001
# Train Epoch: 51 [0/90000 (0%)]	log Loss: -12.179236
#
# Train set: Average log loss: -11.3632
#
#
# Test set: Average loss: -12.2522
#
# Current Learning rate 0.0001
# Train Epoch: 52 [0/90000 (0%)]	log Loss: -12.289421
#
# Train set: Average log loss: -11.5183
#
#
# Test set: Average loss: -12.2238
#
# Current Learning rate 0.0001
# Train Epoch: 53 [0/90000 (0%)]	log Loss: -12.261822
#
# Train set: Average log loss: -11.3560
#
#
# Test set: Average loss: -12.7458
#
# Current Learning rate 0.0001
# Train Epoch: 54 [0/90000 (0%)]	log Loss: -12.775442
#
# Train set: Average log loss: -11.5375
#
#
# Test set: Average loss: -12.2411
#
# Current Learning rate 0.0001
# Train Epoch: 55 [0/90000 (0%)]	log Loss: -12.277294
#
# Train set: Average log loss: -11.3708
#
#
# Test set: Average loss: -12.7171
#
# Current Learning rate 0.0001
# Train Epoch: 56 [0/90000 (0%)]	log Loss: -12.748752
#
# Train set: Average log loss: -11.5684
#
#
# Test set: Average loss: -12.2860
#
# Current Learning rate 0.0001
# Train Epoch: 57 [0/90000 (0%)]	log Loss: -12.320891
#
# Train set: Average log loss: -11.3878
#
#
# Test set: Average loss: -13.0336
#
# Current Learning rate 0.0001
# Train Epoch: 58 [0/90000 (0%)]	log Loss: -13.056994
#
# Train set: Average log loss: -11.6003
#
#
# Test set: Average loss: -12.4830
#
# Current Learning rate 0.0001
# Train Epoch: 59 [0/90000 (0%)]	log Loss: -12.516269
#
# Train set: Average log loss: -11.4806
#
#
# Test set: Average loss: -12.7295
#
# Current Learning rate 0.0001
# Train Epoch: 60 [0/90000 (0%)]	log Loss: -12.768741
#
# Train set: Average log loss: -11.4230
#
#
# Test set: Average loss: -12.2824
#
# Current Learning rate 0.0001
# Train Epoch: 61 [0/90000 (0%)]	log Loss: -12.305304
#
# Train set: Average log loss: -11.6154
#
#
# Test set: Average loss: -12.5251
#
# Current Learning rate 0.0001
# Train Epoch: 62 [0/90000 (0%)]	log Loss: -12.554659
#
# Train set: Average log loss: -11.4822
#
#
# Test set: Average loss: -12.6354
#
# Current Learning rate 0.0001
# Train Epoch: 63 [0/90000 (0%)]	log Loss: -12.677649
#
# Train set: Average log loss: -11.5599
#
#
# Test set: Average loss: -12.8519
#
# Current Learning rate 0.0001
# Train Epoch: 64 [0/90000 (0%)]	log Loss: -12.873258
#
# Train set: Average log loss: -11.5153
#
#
# Test set: Average loss: -12.3808
#
# Current Learning rate 0.0001
# Train Epoch: 65 [0/90000 (0%)]	log Loss: -12.422725
#
# Train set: Average log loss: -11.5967
#
#
# Test set: Average loss: -13.1710
#
# Current Learning rate 0.0001
# Train Epoch: 66 [0/90000 (0%)]	log Loss: -13.182953
#
# Train set: Average log loss: -11.5758
#
#
# Test set: Average loss: -12.0920
#
# Current Learning rate 0.0001
# Train Epoch: 67 [0/90000 (0%)]	log Loss: -12.130992
#
# Train set: Average log loss: -11.5319
#
#
# Test set: Average loss: -12.5219
#
# Current Learning rate 0.0001
# Train Epoch: 68 [0/90000 (0%)]	log Loss: -12.542293
#
# Train set: Average log loss: -11.5330
#
#
# Test set: Average loss: -12.0935
#
# Current Learning rate 0.0001
# Train Epoch: 69 [0/90000 (0%)]	log Loss: -12.128702
#
# Train set: Average log loss: -11.7568
#
#
# Test set: Average loss: -13.4293
#
# Current Learning rate 0.0001
# Train Epoch: 70 [0/90000 (0%)]	log Loss: -13.407626
#
# Train set: Average log loss: -11.8394
#
#
# Test set: Average loss: -11.9353
#
# Current Learning rate 0.0001
# Train Epoch: 71 [0/90000 (0%)]	log Loss: -11.970169
#
# Train set: Average log loss: -11.0775
#
#
# Test set: Average loss: -13.6437
#
# Current Learning rate 0.0001
# Train Epoch: 72 [0/90000 (0%)]	log Loss: -13.648457
#
# Train set: Average log loss: -12.4244
#
#
# Test set: Average loss: -13.5253
#
# Current Learning rate 0.0001
# Train Epoch: 73 [0/90000 (0%)]	log Loss: -13.552889
#
# Train set: Average log loss: -11.5449
#
#
# Test set: Average loss: -12.8658
#
# Current Learning rate 0.0001
# Train Epoch: 74 [0/90000 (0%)]	log Loss: -12.914400
#
# Train set: Average log loss: -11.1288
#
#
# Test set: Average loss: -12.4953
#
# Current Learning rate 0.0001
# Train Epoch: 75 [0/90000 (0%)]	log Loss: -12.485293
#
# Train set: Average log loss: -12.9328
#
#
# Test set: Average loss: -12.2249
#
# Current Learning rate 0.0001
# Train Epoch: 76 [0/90000 (0%)]	log Loss: -12.257352
#
# Train set: Average log loss: -11.7708
#
#
# Test set: Average loss: -12.2999
#
# Current Learning rate 0.0001
# Train Epoch: 77 [0/90000 (0%)]	log Loss: -12.337526
#
# Train set: Average log loss: -10.9040
#
#
# Test set: Average loss: -13.6829
#
# Current Learning rate 0.0001
# Train Epoch: 78 [0/90000 (0%)]	log Loss: -13.681371
#
# Train set: Average log loss: -13.2180
#
#
# Test set: Average loss: -13.4475
#
# Current Learning rate 0.0001
# Train Epoch: 79 [0/90000 (0%)]	log Loss: -13.484391
#
# Train set: Average log loss: -11.6953
#
#
# Test set: Average loss: -12.5474
#
# Current Learning rate 0.0001
# Train Epoch: 80 [0/90000 (0%)]	log Loss: -12.596716
#
# Train set: Average log loss: -11.7285
#
#
# Test set: Average loss: -13.7618
#
# Current Learning rate 0.0001
# Train Epoch: 81 [0/90000 (0%)]	log Loss: -13.734087
#
# Train set: Average log loss: -11.7628
#
#
# Test set: Average loss: -12.3792
#
# Current Learning rate 0.0001
# Train Epoch: 82 [0/90000 (0%)]	log Loss: -12.414629
#
# Train set: Average log loss: -11.7393
#
#
# Test set: Average loss: -12.8273
#
# Current Learning rate 0.0001
# Train Epoch: 83 [0/90000 (0%)]	log Loss: -12.885595
#
# Train set: Average log loss: -11.7496
#
#
# Test set: Average loss: -13.4227
#
# Current Learning rate 0.0001
# Train Epoch: 84 [0/90000 (0%)]	log Loss: -13.456053
#
# Train set: Average log loss: -11.7917
#
#
# Test set: Average loss: -12.8181
#
# Current Learning rate 0.0001
# Train Epoch: 85 [0/90000 (0%)]	log Loss: -12.877395
#
# Train set: Average log loss: -11.7109
#
#
# Test set: Average loss: -13.6389
#
# Current Learning rate 0.0001
# Train Epoch: 86 [0/90000 (0%)]	log Loss: -13.611746
#
# Train set: Average log loss: -12.0600
#
#
# Test set: Average loss: -13.1033
#
# Current Learning rate 0.0001
# Train Epoch: 87 [0/90000 (0%)]	log Loss: -13.162512
#
# Train set: Average log loss: -10.7609
#
#
# Test set: Average loss: -13.1918
#
# Current Learning rate 0.0001
# Train Epoch: 88 [0/90000 (0%)]	log Loss: -13.217136
#
# Train set: Average log loss: -13.3473
#
#
# Test set: Average loss: -13.4299
#
# Current Learning rate 0.0001
# Train Epoch: 89 [0/90000 (0%)]	log Loss: -13.404630
#
# Train set: Average log loss: -12.9109
#
#
# Test set: Average loss: -14.0710
#
# Current Learning rate 0.0001
# Train Epoch: 90 [0/90000 (0%)]	log Loss: -14.077252
#
# Train set: Average log loss: -11.7381
#
#
# Test set: Average loss: -13.0474
#
# Current Learning rate 0.0001
# Train Epoch: 91 [0/90000 (0%)]	log Loss: -13.030901
#
# Train set: Average log loss: -11.7626
#
#
# Test set: Average loss: -13.7206
#
# Current Learning rate 0.0001
# Train Epoch: 92 [0/90000 (0%)]	log Loss: -13.791116
#
# Train set: Average log loss: -11.8243
#
#
# Test set: Average loss: -13.9668
#
# Current Learning rate 0.0001
# Train Epoch: 93 [0/90000 (0%)]	log Loss: -13.996974
#
# Train set: Average log loss: -11.9016
#
#
# Test set: Average loss: -12.3163
#
# Current Learning rate 0.0001
# Train Epoch: 94 [0/90000 (0%)]	log Loss: -12.358216
#
# Train set: Average log loss: -11.4387
#
#
# Test set: Average loss: -12.4849
#
# Current Learning rate 0.0001
# Train Epoch: 95 [0/90000 (0%)]	log Loss: -12.490588
#
# Train set: Average log loss: -12.4408
#
#
# Test set: Average loss: -12.8321
#
# Current Learning rate 0.0001
# Train Epoch: 96 [0/90000 (0%)]	log Loss: -12.818651
#
# Train set: Average log loss: -11.5778
#
#
# Test set: Average loss: -14.1518
#
# Current Learning rate 0.0001
# Train Epoch: 97 [0/90000 (0%)]	log Loss: -14.154670
#
# Train set: Average log loss: -13.0847
#
#
# Test set: Average loss: -11.2576
#
# Current Learning rate 0.0001
# Train Epoch: 98 [0/90000 (0%)]	log Loss: -11.253519
#
# Train set: Average log loss: -11.0088
#
#
# Test set: Average loss: -14.0005
#
# Current Learning rate 0.0001
# Train Epoch: 99 [0/90000 (0%)]	log Loss: -14.026357
#
# Train set: Average log loss: -13.6287
#
#
# Test set: Average loss: -12.9121
#
# Current Learning rate 0.0001
# Train Epoch: 100 [0/90000 (0%)]	log Loss: -12.945973
#
# Train set: Average log loss: -11.8298
#
#
# Test set: Average loss: -14.2277
#
# Current Learning rate 0.0001
# Train Epoch: 101 [0/90000 (0%)]	log Loss: -14.281444
#
# Train set: Average log loss: -11.2766
#
#
# Test set: Average loss: -12.2270
#
# Current Learning rate 0.0001
# Train Epoch: 102 [0/90000 (0%)]	log Loss: -12.235362
#
# Train set: Average log loss: -13.0207
#
#
# Test set: Average loss: -14.2351
#
# Current Learning rate 0.0001
# Train Epoch: 103 [0/90000 (0%)]	log Loss: -14.276940
#
# Train set: Average log loss: -12.0547
#
#
# Test set: Average loss: -13.1254
#
# Current Learning rate 0.0001
# Train Epoch: 104 [0/90000 (0%)]	log Loss: -13.114979
#
# Train set: Average log loss: -12.2335
#
#
# Test set: Average loss: -12.8785
#
# Current Learning rate 0.0001
# Train Epoch: 105 [0/90000 (0%)]	log Loss: -12.910453
#
# Train set: Average log loss: -12.0041
#
#
# Test set: Average loss: -12.9005
#
# Current Learning rate 0.0001
# Train Epoch: 106 [0/90000 (0%)]	log Loss: -12.936908
#
# Train set: Average log loss: -11.6462
#
#
# Test set: Average loss: -13.3137
#
# Current Learning rate 0.0001
# Train Epoch: 107 [0/90000 (0%)]	log Loss: -13.366831
#
# Train set: Average log loss: -11.9357
#
#
# Test set: Average loss: -13.6203
#
# Current Learning rate 0.0001
# Train Epoch: 108 [0/90000 (0%)]	log Loss: -13.670840
#
# Train set: Average log loss: -11.5465
#
#
# Test set: Average loss: -12.0404
#
# Current Learning rate 0.0001
# Train Epoch: 109 [0/90000 (0%)]	log Loss: -12.041771
#
# Train set: Average log loss: -12.9956
#
#
# Test set: Average loss: -14.3132
#
# Current Learning rate 0.0001
# Train Epoch: 110 [0/90000 (0%)]	log Loss: -14.338062
#
# Train set: Average log loss: -11.4312
#
#
# Test set: Average loss: -12.0121
#
# Current Learning rate 0.0001
# Train Epoch: 111 [0/90000 (0%)]	log Loss: -12.036679
#
# Train set: Average log loss: -12.6862
#
#
# Test set: Average loss: -13.7235
#
# Current Learning rate 0.0001
# Train Epoch: 112 [0/90000 (0%)]	log Loss: -13.778705
#
# Train set: Average log loss: -11.3735
#
#
# Test set: Average loss: -13.5602
#
# Current Learning rate 0.0001
# Train Epoch: 113 [0/90000 (0%)]	log Loss: -13.580225
#
# Train set: Average log loss: -13.3104
#
#
# Test set: Average loss: -13.5029
#
# Current Learning rate 0.0001
# Train Epoch: 114 [0/90000 (0%)]	log Loss: -13.549680
#
# Train set: Average log loss: -11.4282
#
#
# Test set: Average loss: -13.5272
#
# Current Learning rate 0.0001
# Train Epoch: 115 [0/90000 (0%)]	log Loss: -13.533606
#
# Train set: Average log loss: -13.3550
#
#
# Test set: Average loss: -13.4446
#
# Current Learning rate 0.0001
# Train Epoch: 116 [0/90000 (0%)]	log Loss: -13.482867
#
# Train set: Average log loss: -12.0078
#
#
# Test set: Average loss: -13.2378
#
# Current Learning rate 0.0001
# Train Epoch: 117 [0/90000 (0%)]	log Loss: -13.291482
#
# Train set: Average log loss: -12.0163
#
#
# Test set: Average loss: -12.5700
#
# Current Learning rate 0.0001
# Train Epoch: 118 [0/90000 (0%)]	log Loss: -12.574774
#
# Train set: Average log loss: -12.0938
#
#
# Test set: Average loss: -13.2569
#
# Current Learning rate 0.0001
# Train Epoch: 119 [0/90000 (0%)]	log Loss: -13.294212
#
# Train set: Average log loss: -11.8490
#
#
# Test set: Average loss: -14.2028
#
# Current Learning rate 0.0001
# Train Epoch: 120 [0/90000 (0%)]	log Loss: -14.225025
#
# Train set: Average log loss: -12.2393
#
#
# Test set: Average loss: -13.3972
#
# Current Learning rate 0.0001
# Train Epoch: 121 [0/90000 (0%)]	log Loss: -13.435159
#
# Train set: Average log loss: -11.7558
#
#
# Test set: Average loss: -13.1023
#
# Current Learning rate 0.0001
# Train Epoch: 122 [0/90000 (0%)]	log Loss: -13.121457
#
# Train set: Average log loss: -12.1763
#
#
# Test set: Average loss: -11.3572
#
# Current Learning rate 0.0001
# Train Epoch: 123 [0/90000 (0%)]	log Loss: -11.374955
#
# Train set: Average log loss: -12.1160
#
#
# Test set: Average loss: -12.0845
#
# Current Learning rate 0.0001
# Train Epoch: 124 [0/90000 (0%)]	log Loss: -12.115707
#
# Train set: Average log loss: -11.9642
#
#
# Test set: Average loss: -13.1288
#
# Current Learning rate 0.0001
# Train Epoch: 125 [0/90000 (0%)]	log Loss: -13.127976
#
# Train set: Average log loss: -12.4095
#
#
# Test set: Average loss: -11.8707
#
# Current Learning rate 0.0001
# Train Epoch: 126 [0/90000 (0%)]	log Loss: -11.876898
#
# Train set: Average log loss: -12.1880
#
#
# Test set: Average loss: -14.2342
#
# Current Learning rate 0.0001
# Train Epoch: 127 [0/90000 (0%)]	log Loss: -14.259778
#
# Train set: Average log loss: -11.4608
#
#
# Test set: Average loss: -14.0970
#
# Current Learning rate 0.0001
# Train Epoch: 128 [0/90000 (0%)]	log Loss: -14.099213
#
# Train set: Average log loss: -13.7347
#
#
# Test set: Average loss: -14.6519
#
# Current Learning rate 0.0001
# Train Epoch: 129 [0/90000 (0%)]	log Loss: -14.664180
#
# Train set: Average log loss: -11.6932
#
#
# Test set: Average loss: -12.3911
#
# Current Learning rate 0.0001
# Train Epoch: 130 [0/90000 (0%)]	log Loss: -12.402693
#
# Train set: Average log loss: -12.3730
#
#
# Test set: Average loss: -13.4864
#
# Current Learning rate 0.0001
# Train Epoch: 131 [0/90000 (0%)]	log Loss: -13.498192
#
# Train set: Average log loss: -12.3397
#
#
# Test set: Average loss: -14.4341
#
# Current Learning rate 0.0001
# Train Epoch: 132 [0/90000 (0%)]	log Loss: -14.448494
#
# Train set: Average log loss: -11.7022
#
#
# Test set: Average loss: -13.1270
#
# Current Learning rate 0.0001
# Train Epoch: 133 [0/90000 (0%)]	log Loss: -13.133531
#
# Train set: Average log loss: -12.6477
#
#
# Test set: Average loss: -13.7766
#
# Current Learning rate 0.0001
# Train Epoch: 134 [0/90000 (0%)]	log Loss: -13.778116
#
# Train set: Average log loss: -12.2305
#
#
# Test set: Average loss: -14.1505
#
# Current Learning rate 0.0001
# Train Epoch: 135 [0/90000 (0%)]	log Loss: -14.138791
#
# Train set: Average log loss: -12.0429
#
#
# Test set: Average loss: -14.0678
#
# Current Learning rate 0.0001
# Train Epoch: 136 [0/90000 (0%)]	log Loss: -14.088461
#
# Train set: Average log loss: -11.8447
#
#
# Test set: Average loss: -11.8699
#
# Current Learning rate 0.0001
# Train Epoch: 137 [0/90000 (0%)]	log Loss: -11.878062
#
# Train set: Average log loss: -13.1032
#
#
# Test set: Average loss: -12.5151
#
# Current Learning rate 0.0001
# Train Epoch: 138 [0/90000 (0%)]	log Loss: -12.532121
#
# Train set: Average log loss: -12.1504
#
#
# Test set: Average loss: -14.6826
#
# Current Learning rate 0.0001
# Train Epoch: 139 [0/90000 (0%)]	log Loss: -14.686381
#
# Train set: Average log loss: -11.6229
#
#
# Test set: Average loss: -13.6320
#
# Current Learning rate 0.0001
# Train Epoch: 140 [0/90000 (0%)]	log Loss: -13.624820
#
# Train set: Average log loss: -13.3819
#
#
# Test set: Average loss: -12.7241
#
# Current Learning rate 0.0001
# Train Epoch: 141 [0/90000 (0%)]	log Loss: -12.736518
#
# Train set: Average log loss: -11.6874
#
#
# Test set: Average loss: -12.6145
#
# Current Learning rate 0.0001
# Train Epoch: 142 [0/90000 (0%)]	log Loss: -12.621472
#
# Train set: Average log loss: -13.2096
#
#
# Test set: Average loss: -12.3518
#
# Current Learning rate 0.0001
# Train Epoch: 143 [0/90000 (0%)]	log Loss: -12.364634
#
# Train set: Average log loss: -12.1709
#
#
# Test set: Average loss: -14.7467
#
# Current Learning rate 0.0001
# Train Epoch: 144 [0/90000 (0%)]	log Loss: -14.739918
#
# Train set: Average log loss: -11.7586
#
#
# Test set: Average loss: -12.2195
#
# Current Learning rate 0.0001
# Train Epoch: 145 [0/90000 (0%)]	log Loss: -12.228483
#
# Train set: Average log loss: -12.9602
#
#
# Test set: Average loss: -12.3846
#
# Current Learning rate 0.0001
# Train Epoch: 146 [0/90000 (0%)]	log Loss: -12.394916
#
# Train set: Average log loss: -12.3188
#
#
# Test set: Average loss: -14.6567
#
# Current Learning rate 0.0001
# Train Epoch: 147 [0/90000 (0%)]	log Loss: -14.637183
#
# Train set: Average log loss: -12.2252
#
#
# Test set: Average loss: -12.6915
#
# Current Learning rate 0.0001
# Train Epoch: 148 [0/90000 (0%)]	log Loss: -12.693396
#
# Train set: Average log loss: -11.4300
#
#
# Test set: Average loss: -12.7150
#
# Current Learning rate 0.0001
# Train Epoch: 149 [0/90000 (0%)]	log Loss: -12.735471
#
# Train set: Average log loss: -13.7111
#
#
# Test set: Average loss: -13.9892
#
# Current Learning rate 0.0001
# Train Epoch: 150 [0/90000 (0%)]	log Loss: -14.009498
#
# Train set: Average log loss: -12.5196
#
#
# Test set: Average loss: -11.7636
#
# Current Learning rate 0.0001
# Train Epoch: 151 [0/90000 (0%)]	log Loss: -11.775132
#
# Train set: Average log loss: -12.3531
#
#
# Test set: Average loss: -14.4359
#
# Current Learning rate 0.0001
# Train Epoch: 152 [0/90000 (0%)]	log Loss: -14.450694
#
# Train set: Average log loss: -11.6222
#
#
# Test set: Average loss: -13.9884
#
# Current Learning rate 0.0001
# Train Epoch: 153 [0/90000 (0%)]	log Loss: -13.976502
#
# Train set: Average log loss: -13.6537
#
#
# Test set: Average loss: -14.2983
#
# Current Learning rate 0.0001
# Train Epoch: 154 [0/90000 (0%)]	log Loss: -14.282677
#
# Train set: Average log loss: -12.0820
#
#
# Test set: Average loss: -14.7567
#
# Current Learning rate 0.0001
# Train Epoch: 155 [0/90000 (0%)]	log Loss: -14.739474
#
# Train set: Average log loss: -12.4748
#
#
# Test set: Average loss: -13.1025
#
# Current Learning rate 0.0001
# Train Epoch: 156 [0/90000 (0%)]	log Loss: -13.095267
#
# Train set: Average log loss: -12.3952
#
#
# Test set: Average loss: -12.2536
#
# Current Learning rate 0.0001
# Train Epoch: 157 [0/90000 (0%)]	log Loss: -12.254883
#
# Train set: Average log loss: -11.8348
#
#
# Test set: Average loss: -12.9782
#
# Current Learning rate 0.0001
# Train Epoch: 158 [0/90000 (0%)]	log Loss: -12.973313
#
# Train set: Average log loss: -13.0274
#
#
# Test set: Average loss: -12.2074
#
# Current Learning rate 0.0001
# Train Epoch: 159 [0/90000 (0%)]	log Loss: -12.211969
#
# Train set: Average log loss: -11.9452
#
#
# Test set: Average loss: -14.2314
#
# Current Learning rate 0.0001
# Train Epoch: 160 [0/90000 (0%)]	log Loss: -14.206917
#
# Train set: Average log loss: -12.9279
#
#
# Test set: Average loss: -12.8978
#
# Current Learning rate 0.0001
# Train Epoch: 161 [0/90000 (0%)]	log Loss: -12.890957
#
# Train set: Average log loss: -11.7002
#
#
# Test set: Average loss: -14.7139
#
# Current Learning rate 0.0001
# Train Epoch: 162 [0/90000 (0%)]	log Loss: -14.662553
#
# Train set: Average log loss: -13.5059
#
#
# Test set: Average loss: -12.8680
#
# Current Learning rate 0.0001
# Train Epoch: 163 [0/90000 (0%)]	log Loss: -12.865347
#
# Train set: Average log loss: -12.3826
#
#
# Test set: Average loss: -14.6863
#
# Current Learning rate 0.0001
# Train Epoch: 164 [0/90000 (0%)]	log Loss: -14.663372
#
# Train set: Average log loss: -12.0079
#
#
# Test set: Average loss: -13.7186
#
# Current Learning rate 0.0001
# Train Epoch: 165 [0/90000 (0%)]	log Loss: -13.692999
#
# Train set: Average log loss: -12.8318
#
#
# Test set: Average loss: -12.2110
#
# Current Learning rate 0.0001
# Train Epoch: 166 [0/90000 (0%)]	log Loss: -12.212693
#
# Train set: Average log loss: -11.8801
#
#
# Test set: Average loss: -14.5269
#
# Current Learning rate 0.0001
# Train Epoch: 167 [0/90000 (0%)]	log Loss: -14.488502
#
# Train set: Average log loss: -13.6853
#
#
# Test set: Average loss: -14.0566
#
# Current Learning rate 0.0001
# Train Epoch: 168 [0/90000 (0%)]	log Loss: -14.027268
#
# Train set: Average log loss: -12.3583
#
#
# Test set: Average loss: -11.8131
#
# Current Learning rate 0.0001
# Train Epoch: 169 [0/90000 (0%)]	log Loss: -11.812591
#
# Train set: Average log loss: -11.6634
#
#
# Test set: Average loss: -11.8010
#
# Current Learning rate 0.0001
# Train Epoch: 170 [0/90000 (0%)]	log Loss: -11.829845
#
# Train set: Average log loss: -13.5612
#
#
# Test set: Average loss: -14.4492
#
# Current Learning rate 0.0001
# Train Epoch: 171 [0/90000 (0%)]	log Loss: -14.434072
#
# Train set: Average log loss: -11.8199
#
#
# Test set: Average loss: -13.8952
#
# Current Learning rate 0.0001
# Train Epoch: 172 [0/90000 (0%)]	log Loss: -13.880445
#
# Train set: Average log loss: -14.1184
#
#
# Test set: Average loss: -14.3951
#
# Current Learning rate 0.0001
# Train Epoch: 173 [0/90000 (0%)]	log Loss: -14.353182
#
# Train set: Average log loss: -11.5556
#
#
# Test set: Average loss: -12.8141
#
# Current Learning rate 0.0001
# Train Epoch: 174 [0/90000 (0%)]	log Loss: -12.814614
#
# Train set: Average log loss: -14.4311
#
#
# Test set: Average loss: -14.9411
#
# Current Learning rate 0.0001
# Train Epoch: 175 [0/90000 (0%)]	log Loss: -14.912371
#
# Train set: Average log loss: -12.3185
#
#
# Test set: Average loss: -13.9091
#
# Current Learning rate 0.0001
# Train Epoch: 176 [0/90000 (0%)]	log Loss: -13.903702
#
# Train set: Average log loss: -13.4186
#
#
# Test set: Average loss: -11.7828
#
# Current Learning rate 0.0001
# Train Epoch: 177 [0/90000 (0%)]	log Loss: -11.790330
#
# Train set: Average log loss: -12.2418
#
#
# Test set: Average loss: -12.4295
#
# Current Learning rate 0.0001
# Train Epoch: 178 [0/90000 (0%)]	log Loss: -12.432293
#
# Train set: Average log loss: -12.4333
#
#
# Test set: Average loss: -12.4452
#
# Current Learning rate 0.0001
# Train Epoch: 179 [0/90000 (0%)]	log Loss: -12.450564
#
# Train set: Average log loss: -12.4122
#
#
# Test set: Average loss: -11.1342
#
# Current Learning rate 0.0001
# Train Epoch: 180 [0/90000 (0%)]	log Loss: -11.140017
#
# Train set: Average log loss: -12.3250
#
#
# Test set: Average loss: -14.6732
#
# Current Learning rate 0.0001
# Train Epoch: 181 [0/90000 (0%)]	log Loss: -14.610427
#
# Train set: Average log loss: -12.8310
#
#
# Test set: Average loss: -12.1331
#
# Current Learning rate 0.0001
# Train Epoch: 182 [0/90000 (0%)]	log Loss: -12.128658
#
# Train set: Average log loss: -12.1204
#
#
# Test set: Average loss: -14.9410
#
# Current Learning rate 0.0001
# Train Epoch: 183 [0/90000 (0%)]	log Loss: -14.900928
#
# Train set: Average log loss: -12.3325
#
#
# Test set: Average loss: -14.8526
#
# Current Learning rate 0.0001
# Train Epoch: 184 [0/90000 (0%)]	log Loss: -14.779981
#
# Train set: Average log loss: -12.5341
#
#
# Test set: Average loss: -13.9854
#
# Current Learning rate 0.0001
# Train Epoch: 185 [0/90000 (0%)]	log Loss: -13.978919
#
# Train set: Average log loss: -11.8940
#
#
# Test set: Average loss: -14.4305
#
# Current Learning rate 0.0001
# Train Epoch: 186 [0/90000 (0%)]	log Loss: -14.354264
#
# Train set: Average log loss: -13.8199
#
#
# Test set: Average loss: -15.1578
#
# Current Learning rate 0.0001
# Train Epoch: 187 [0/90000 (0%)]	log Loss: -15.096596
#
# Train set: Average log loss: -11.5521
#
#
# Test set: Average loss: -12.5398
#
# Current Learning rate 0.0001
# Train Epoch: 188 [0/90000 (0%)]	log Loss: -12.548315
#
# Train set: Average log loss: -14.2428
#
#
# Test set: Average loss: -14.6259
#
# Current Learning rate 0.0001
# Train Epoch: 189 [0/90000 (0%)]	log Loss: -14.611583
#
# Train set: Average log loss: -13.6326
#
#
# Test set: Average loss: -13.1040
#
# Current Learning rate 0.0001
# Train Epoch: 190 [0/90000 (0%)]	log Loss: -13.112838
#
# Train set: Average log loss: -12.3743
#
#
# Test set: Average loss: -13.4461
#
# Current Learning rate 0.0001
# Train Epoch: 191 [0/90000 (0%)]	log Loss: -13.440833
#
# Train set: Average log loss: -12.3044
#
#
# Test set: Average loss: -14.5680
#
# Current Learning rate 0.0001
# Train Epoch: 192 [0/90000 (0%)]	log Loss: -14.565806
#
# Train set: Average log loss: -12.4005
#
#
# Test set: Average loss: -13.3146
#
# Current Learning rate 0.0001
# Train Epoch: 193 [0/90000 (0%)]	log Loss: -13.361380
#
# Train set: Average log loss: -12.9269
#
#
# Test set: Average loss: -15.1714
#
# Current Learning rate 0.0001
# Train Epoch: 194 [0/90000 (0%)]	log Loss: -15.136455
#
# Train set: Average log loss: -11.9863
#
#
# Test set: Average loss: -13.8250
#
# Current Learning rate 0.0001
# Train Epoch: 195 [0/90000 (0%)]	log Loss: -13.831942
#
# Train set: Average log loss: -13.7191
#
#
# Test set: Average loss: -12.2359
#
# Current Learning rate 0.0001
# Train Epoch: 196 [0/90000 (0%)]	log Loss: -12.244591
#
# Train set: Average log loss: -11.9494
#
#
# Test set: Average loss: -14.1470
#
# Current Learning rate 0.0001
# Train Epoch: 197 [0/90000 (0%)]	log Loss: -14.152043
#
# Train set: Average log loss: -13.8511
#
#
# Test set: Average loss: -12.3148
#
# Current Learning rate 0.0001
# Train Epoch: 198 [0/90000 (0%)]	log Loss: -12.325566
#
# Train set: Average log loss: -12.1342
#
#
# Test set: Average loss: -15.0760
#
# Current Learning rate 0.0001
# Train Epoch: 199 [0/90000 (0%)]	log Loss: -15.048757
#
# Train set: Average log loss: -12.8954
#
#
# Test set: Average loss: -12.2500
#
# Current Learning rate 0.0001
# Train Epoch: 200 [0/90000 (0%)]	log Loss: -12.258186
#
# Train set: Average log loss: -12.7245
#
#
# Test set: Average loss: -14.4248
#
# Current Learning rate 0.0001
# Train Epoch: 201 [0/90000 (0%)]	log Loss: -14.423454
#
# Train set: Average log loss: -12.3253
#
#
# Test set: Average loss: -12.5867
#
# Current Learning rate 0.0001
# Train Epoch: 202 [0/90000 (0%)]	log Loss: -12.593488
#
# Train set: Average log loss: -12.7381
#
#
# Test set: Average loss: -10.6276
#
# Current Learning rate 0.0001
# Train Epoch: 203 [0/90000 (0%)]	log Loss: -10.634830
#
# Train set: Average log loss: -12.7068
#
#
# Test set: Average loss: -12.0390
#
# Current Learning rate 0.0001
# Train Epoch: 204 [0/90000 (0%)]	log Loss: -12.052866
#
# Train set: Average log loss: -12.4525
#
#
# Test set: Average loss: -13.9644
#
# Current Learning rate 0.0001
# Train Epoch: 205 [0/90000 (0%)]	log Loss: -13.977837
#
# Train set: Average log loss: -12.5984
#
#
# Test set: Average loss: -13.9143
#
# Current Learning rate 0.0001
# Train Epoch: 206 [0/90000 (0%)]	log Loss: -13.927991
#
# Train set: Average log loss: -12.4368
#
#
# Test set: Average loss: -14.6263
#
# Current Learning rate 0.0001
# Train Epoch: 207 [0/90000 (0%)]	log Loss: -14.625985
#
# Train set: Average log loss: -12.2354
#
#
# Test set: Average loss: -12.7155
#
# Current Learning rate 0.0001
# Train Epoch: 208 [0/90000 (0%)]	log Loss: -12.744262
#
# Train set: Average log loss: -13.6020
#
#
# Test set: Average loss: -12.7357
#
# Current Learning rate 0.0001
# Train Epoch: 209 [0/90000 (0%)]	log Loss: -12.740633
#
# Train set: Average log loss: -12.1792
#
#
# Test set: Average loss: -13.6078
#
# Current Learning rate 0.0001
# Train Epoch: 210 [0/90000 (0%)]	log Loss: -13.624760
#
# Train set: Average log loss: -13.1337
#
#
# Test set: Average loss: -12.4353
#
# Current Learning rate 0.0001
# Train Epoch: 211 [0/90000 (0%)]	log Loss: -12.459641
#
# Train set: Average log loss: -12.6650
#
#
# Test set: Average loss: -15.2117
#
# Current Learning rate 0.0001
# Train Epoch: 212 [0/90000 (0%)]	log Loss: -15.201219
#
# Train set: Average log loss: -12.2321
#
#
# Test set: Average loss: -14.6002
#
# Current Learning rate 0.0001
# Train Epoch: 213 [0/90000 (0%)]	log Loss: -14.585601
#
# Train set: Average log loss: -12.9483
#
#
# Test set: Average loss: -11.9479
#
# Current Learning rate 0.0001
# Train Epoch: 214 [0/90000 (0%)]	log Loss: -11.939696
#
# Train set: Average log loss: -12.9189
#
#
# Test set: Average loss: -12.1568
#
# Current Learning rate 0.0001
# Train Epoch: 215 [0/90000 (0%)]	log Loss: -12.157056
#
# Train set: Average log loss: -12.0154
#
#
# Test set: Average loss: -14.6805
#
# Current Learning rate 0.0001
# Train Epoch: 216 [0/90000 (0%)]	log Loss: -14.652715
#
# Train set: Average log loss: -13.9187
#
#
# Test set: Average loss: -11.8345
#
# Current Learning rate 0.0001
# Train Epoch: 217 [0/90000 (0%)]	log Loss: -11.830764
#
# Train set: Average log loss: -12.5895
#
#
# Test set: Average loss: -15.2442
#
# Current Learning rate 0.0001
# Train Epoch: 218 [0/90000 (0%)]	log Loss: -15.254122
#
# Train set: Average log loss: -11.6557
#
#
# Test set: Average loss: -11.9763
#
# Current Learning rate 0.0001
# Train Epoch: 219 [0/90000 (0%)]	log Loss: -11.992311
#
# Train set: Average log loss: -14.2228
#
#
# Test set: Average loss: -15.2448
#
# Current Learning rate 0.0001
# Train Epoch: 220 [0/90000 (0%)]	log Loss: -15.195757
#
# Train set: Average log loss: -14.4323
#
#
# Test set: Average loss: -12.4713
#
# Current Learning rate 0.0001
# Train Epoch: 221 [0/90000 (0%)]	log Loss: -12.468089
#
# Train set: Average log loss: -12.4458
#
#
# Test set: Average loss: -15.1567
#
# Current Learning rate 0.0001
# Train Epoch: 222 [0/90000 (0%)]	log Loss: -15.151398
#
# Train set: Average log loss: -12.8686
#
#
# Test set: Average loss: -13.1965
#
# Current Learning rate 0.0001
# Train Epoch: 223 [0/90000 (0%)]	log Loss: -13.212824
#
# Train set: Average log loss: -13.0379
#
#
# Test set: Average loss: -14.6594
#
# Current Learning rate 0.0001
# Train Epoch: 224 [0/90000 (0%)]	log Loss: -14.669220
#
# Train set: Average log loss: -11.7298
#
#
# Test set: Average loss: -15.1711
#
# Current Learning rate 0.0001
# Train Epoch: 225 [0/90000 (0%)]	log Loss: -15.130783
#
# Train set: Average log loss: -15.0166
#
#
# Test set: Average loss: -14.8220
#
# Current Learning rate 0.0001
# Train Epoch: 226 [0/90000 (0%)]	log Loss: -14.817588
#
# Train set: Average log loss: -13.4086
#
#
# Test set: Average loss: -14.2701
#
# Current Learning rate 0.0001
# Train Epoch: 227 [0/90000 (0%)]	log Loss: -14.272747
#
# Train set: Average log loss: -12.3177
#
#
# Test set: Average loss: -14.3603
#
# Current Learning rate 0.0001
# Train Epoch: 228 [0/90000 (0%)]	log Loss: -14.339508
#
# Train set: Average log loss: -12.5855
#
#
# Test set: Average loss: -12.1109
#
# Current Learning rate 0.0001
# Train Epoch: 229 [0/90000 (0%)]	log Loss: -12.100539
#
# Train set: Average log loss: -13.0237
#
#
# Test set: Average loss: -13.8377
#
# Current Learning rate 0.0001
# Train Epoch: 230 [0/90000 (0%)]	log Loss: -13.904428
#
# Train set: Average log loss: -12.1721
#
#
# Test set: Average loss: -13.3277
#
# Current Learning rate 0.0001
# Train Epoch: 231 [0/90000 (0%)]	log Loss: -13.308637
#
# Train set: Average log loss: -13.6391
#
#
# Test set: Average loss: -13.4669
#
# Current Learning rate 0.0001
# Train Epoch: 232 [0/90000 (0%)]	log Loss: -13.454438
#
# Train set: Average log loss: -12.4631
#
#
# Test set: Average loss: -13.4280
#
# Current Learning rate 0.0001
# Train Epoch: 233 [0/90000 (0%)]	log Loss: -13.400366
#
# Train set: Average log loss: -13.1856
#
#
# Test set: Average loss: -11.7732
#
# Current Learning rate 0.0001
# Train Epoch: 234 [0/90000 (0%)]	log Loss: -11.766484
#
# Train set: Average log loss: -12.3787
#
#
# Test set: Average loss: -11.9571
#
# Current Learning rate 0.0001
# Train Epoch: 235 [0/90000 (0%)]	log Loss: -12.002596
#
# Train set: Average log loss: -13.3394
#
#
# Test set: Average loss: -13.4870
#
# Current Learning rate 0.0001
# Train Epoch: 236 [0/90000 (0%)]	log Loss: -13.480257
#
# Train set: Average log loss: -12.0634
#
#
# Test set: Average loss: -13.8110
#
# Current Learning rate 0.0001
# Train Epoch: 237 [0/90000 (0%)]	log Loss: -13.847754
#
# Train set: Average log loss: -14.5173
#
#
# Test set: Average loss: -15.2209
#
# Current Learning rate 0.0001
# Train Epoch: 238 [0/90000 (0%)]	log Loss: -15.221121
#
# Train set: Average log loss: -11.6439
#
#
# Test set: Average loss: -13.3973
#
# Current Learning rate 0.0001
# Train Epoch: 239 [0/90000 (0%)]	log Loss: -13.388342
#
# Train set: Average log loss: -14.4887
#
#
# Test set: Average loss: -15.2281
#
# Current Learning rate 0.0001
# Train Epoch: 240 [0/90000 (0%)]	log Loss: -15.191349
#
# Train set: Average log loss: -14.8682
#
#
# Test set: Average loss: -14.7737
#
# Current Learning rate 0.0001
# Train Epoch: 241 [0/90000 (0%)]	log Loss: -14.754340
#
# Train set: Average log loss: -12.2259
#
#
# Test set: Average loss: -14.8453
#
# Current Learning rate 0.0001
# Train Epoch: 242 [0/90000 (0%)]	log Loss: -14.862491
#
# Train set: Average log loss: -14.6350
#
#
# Test set: Average loss: -13.2930
#
# Current Learning rate 0.0001
# Train Epoch: 243 [0/90000 (0%)]	log Loss: -13.301103
#
# Train set: Average log loss: -12.2150
#
#
# Test set: Average loss: -14.8987
#
# Current Learning rate 0.0001
# Train Epoch: 244 [0/90000 (0%)]	log Loss: -14.903127
#
# Train set: Average log loss: -14.6833
#
#
# Test set: Average loss: -12.5019
#
# Current Learning rate 0.0001
# Train Epoch: 245 [0/90000 (0%)]	log Loss: -12.510246
#
# Train set: Average log loss: -12.8159
#
#
# Test set: Average loss: -13.6453
#
# Current Learning rate 0.0001
# Train Epoch: 246 [0/90000 (0%)]	log Loss: -13.639993
#
# Train set: Average log loss: -12.4431
#
#
# Test set: Average loss: -14.9593
#
# Current Learning rate 0.0001
# Train Epoch: 247 [0/90000 (0%)]	log Loss: -14.964847
#
# Train set: Average log loss: -12.4409
#
#
# Test set: Average loss: -12.8696
#
# Current Learning rate 0.0001
# Train Epoch: 248 [0/90000 (0%)]	log Loss: -12.930845
#
# Train set: Average log loss: -13.7518
#
#
# Test set: Average loss: -14.5157
#
# Current Learning rate 0.0001
# Train Epoch: 249 [0/90000 (0%)]	log Loss: -14.502931
#
# Train set: Average log loss: -12.9034
#
#
# Test set: Average loss: -13.0452
#
# Current Learning rate 0.0001
# Train Epoch: 250 [0/90000 (0%)]	log Loss: -13.038205
#
# Train set: Average log loss: -12.9208
#
#
# Test set: Average loss: -15.3626
#
# Current Learning rate 0.0001
# Train Epoch: 251 [0/90000 (0%)]	log Loss: -15.376232
#
# Train set: Average log loss: -12.7076
#
#
# Test set: Average loss: -12.5989
#
# Current Learning rate 0.0001
# Train Epoch: 252 [0/90000 (0%)]	log Loss: -12.602284
#
# Train set: Average log loss: -12.9275
#
#
# Test set: Average loss: -15.3996
#
# Current Learning rate 0.0001
# Train Epoch: 253 [0/90000 (0%)]	log Loss: -15.372738
#
# Train set: Average log loss: -11.9616
#
#
# Test set: Average loss: -15.1340
#
# Current Learning rate 0.0001
# Train Epoch: 254 [0/90000 (0%)]	log Loss: -15.117431
#
# Train set: Average log loss: -15.0283
#
#
# Test set: Average loss: -15.4850
#
# Current Learning rate 0.0001
# Train Epoch: 255 [0/90000 (0%)]	log Loss: -15.477688
#
# Train set: Average log loss: -13.3438
#
#
# Test set: Average loss: -10.8353
#
# Current Learning rate 0.0001
# Train Epoch: 256 [0/90000 (0%)]	log Loss: -10.841822
#
# Train set: Average log loss: -12.1481
#
#
# Test set: Average loss: -11.9772
#
# Current Learning rate 0.0001
# Train Epoch: 257 [0/90000 (0%)]	log Loss: -12.014526
#
# Train set: Average log loss: -13.9340
#
#
# Test set: Average loss: -14.7848
#
# Current Learning rate 0.0001
# Train Epoch: 258 [0/90000 (0%)]	log Loss: -14.792946
#
# Train set: Average log loss: -13.1539
#
#
# Test set: Average loss: -12.6514
#
# Current Learning rate 0.0001
# Train Epoch: 259 [0/90000 (0%)]	log Loss: -12.655959
#
# Train set: Average log loss: -11.9513
#
#
# Test set: Average loss: -13.4484
#
# Current Learning rate 0.0001
# Train Epoch: 260 [0/90000 (0%)]	log Loss: -13.427565
#
# Train set: Average log loss: -14.9383
#
#
# Test set: Average loss: -15.3080
#
# Current Learning rate 0.0001
# Train Epoch: 261 [0/90000 (0%)]	log Loss: -15.307163
#
# Train set: Average log loss: -12.6660
#
#
# Test set: Average loss: -11.8960
#
# Current Learning rate 0.0001
# Train Epoch: 262 [0/90000 (0%)]	log Loss: -11.913537
#
# Train set: Average log loss: -13.8163
#
#
# Test set: Average loss: -14.4713
#
# Current Learning rate 0.0001
# Train Epoch: 263 [0/90000 (0%)]	log Loss: -14.454698
#
# Train set: Average log loss: -12.9660
#
#
# Test set: Average loss: -15.0147
#
# Current Learning rate 0.0001
# Train Epoch: 264 [0/90000 (0%)]	log Loss: -14.992808
#
# Train set: Average log loss: -13.0556
#
#
# Test set: Average loss: -15.0776
#
# Current Learning rate 0.0001
# Train Epoch: 265 [0/90000 (0%)]	log Loss: -15.071923
#
# Train set: Average log loss: -12.6114
#
#
# Test set: Average loss: -14.9964
#
# Current Learning rate 0.0001
# Train Epoch: 266 [0/90000 (0%)]	log Loss: -14.975895
#
# Train set: Average log loss: -12.3977
#
#
# Test set: Average loss: -14.2980
#
# Current Learning rate 0.0001
# Train Epoch: 267 [0/90000 (0%)]	log Loss: -14.264972
#
# Train set: Average log loss: -14.5321
#
#
# Test set: Average loss: -12.3928
#
# Current Learning rate 0.0001
# Train Epoch: 268 [0/90000 (0%)]	log Loss: -12.398882
#
# Train set: Average log loss: -12.8953
#
#
# Test set: Average loss: -14.1733
#
# Current Learning rate 0.0001
# Train Epoch: 269 [0/90000 (0%)]	log Loss: -14.184047
#
# Train set: Average log loss: -12.5502
#
#
# Test set: Average loss: -15.2458
#
# Current Learning rate 0.0001
# Train Epoch: 270 [0/90000 (0%)]	log Loss: -15.250095
#
# Train set: Average log loss: -13.3695
#
#
# Test set: Average loss: -11.3974
#
# Current Learning rate 0.0001
# Train Epoch: 271 [0/90000 (0%)]	log Loss: -11.406100
#
# Train set: Average log loss: -12.6940
#
#
# Test set: Average loss: -11.7002
#
# Current Learning rate 0.0001
# Train Epoch: 272 [0/90000 (0%)]	log Loss: -11.716310
#
# Train set: Average log loss: -13.0113
#
#
# Test set: Average loss: -12.0051
#
# Current Learning rate 0.0001
# Train Epoch: 273 [0/90000 (0%)]	log Loss: -12.003042
#
# Train set: Average log loss: -12.9170
#
#
# Test set: Average loss: -14.3197
#
# Current Learning rate 0.0001
# Train Epoch: 274 [0/90000 (0%)]	log Loss: -14.284715
#
# Train set: Average log loss: -12.9206
#
#
# Test set: Average loss: -14.7457
#
# Current Learning rate 0.0001
# Train Epoch: 275 [0/90000 (0%)]	log Loss: -14.693809
#
# Train set: Average log loss: -12.4791
#
#
# Test set: Average loss: -14.9119
#
# Current Learning rate 0.0001
# Train Epoch: 276 [0/90000 (0%)]	log Loss: -15.009862
#
# Train set: Average log loss: -13.6425
#
#
# Test set: Average loss: -13.1910
#
# Current Learning rate 0.0001
# Train Epoch: 277 [0/90000 (0%)]	log Loss: -13.174830
#
# Train set: Average log loss: -13.0799
#
#
# Test set: Average loss: -13.1978
#
# Current Learning rate 0.0001
# Train Epoch: 278 [0/90000 (0%)]	log Loss: -13.185397
#
# Train set: Average log loss: -12.8963
#
#
# Test set: Average loss: -14.0335
#
# Current Learning rate 0.0001
# Train Epoch: 279 [0/90000 (0%)]	log Loss: -14.032217
#
# Train set: Average log loss: -12.8903
#
#
# Test set: Average loss: -13.0186
#
# Current Learning rate 0.0001
# Train Epoch: 280 [0/90000 (0%)]	log Loss: -13.011491
#
# Train set: Average log loss: -12.8803
#
#
# Test set: Average loss: -13.4280
#
# Current Learning rate 0.0001
# Train Epoch: 281 [0/90000 (0%)]	log Loss: -13.414354
#
# Train set: Average log loss: -13.1774
#
#
# Test set: Average loss: -12.4533
#
# Current Learning rate 0.0001
# Train Epoch: 282 [0/90000 (0%)]	log Loss: -12.453555
#
# Train set: Average log loss: -12.6388
#
#
# Test set: Average loss: -14.7944
#
# Current Learning rate 0.0001
# Train Epoch: 283 [0/90000 (0%)]	log Loss: -14.884015
#
# Train set: Average log loss: -12.4164
#
#
# Test set: Average loss: -12.5165
#
# Current Learning rate 0.0001
# Train Epoch: 284 [0/90000 (0%)]	log Loss: -12.580261
#
# Train set: Average log loss: -14.0981
#
#
# Test set: Average loss: -15.3293
#
# Current Learning rate 0.0001
# Train Epoch: 285 [0/90000 (0%)]	log Loss: -15.395896
#
# Train set: Average log loss: -12.8121
#
#
# Test set: Average loss: -15.0521
#
# Current Learning rate 0.0001
# Train Epoch: 286 [0/90000 (0%)]	log Loss: -15.027786
#
# Train set: Average log loss: -12.8254
#
#
# Test set: Average loss: -12.9821
#
# Current Learning rate 0.0001
# Train Epoch: 287 [0/90000 (0%)]	log Loss: -13.064699
#
# Train set: Average log loss: -13.7783
#
#
# Test set: Average loss: -15.5092
#
# Current Learning rate 0.0001
# Train Epoch: 288 [0/90000 (0%)]	log Loss: -15.526672
#
# Train set: Average log loss: -12.8612
#
#
# Test set: Average loss: -12.8038
#
# Current Learning rate 0.0001
# Train Epoch: 289 [0/90000 (0%)]	log Loss: -12.851350
#
# Train set: Average log loss: -12.3087
#
#
# Test set: Average loss: -15.0243
#
# Current Learning rate 0.0001
# Train Epoch: 290 [0/90000 (0%)]	log Loss: -15.084804
#
# Train set: Average log loss: -15.3591
#
#
# Test set: Average loss: -15.6820
#
# Current Learning rate 0.0001
# Train Epoch: 291 [0/90000 (0%)]	log Loss: -15.679584
#
# Train set: Average log loss: -12.7292
#
#
# Test set: Average loss: -14.8522
#
# Current Learning rate 0.0001
# Train Epoch: 292 [0/90000 (0%)]	log Loss: -14.924182
#
# Train set: Average log loss: -13.8823
#
#
# Test set: Average loss: -10.8986
#
# Current Learning rate 0.0001
# Train Epoch: 293 [0/90000 (0%)]	log Loss: -10.910287
#
# Train set: Average log loss: -13.1089
#
#
# Test set: Average loss: -12.8369
#
# Current Learning rate 0.0001
# Train Epoch: 294 [0/90000 (0%)]	log Loss: -12.827571
#
# Train set: Average log loss: -12.3516
#
#
# Test set: Average loss: -15.6755
#
# Current Learning rate 0.0001
# Train Epoch: 295 [0/90000 (0%)]	log Loss: -15.690985
#
# Train set: Average log loss: -14.3640
#
#
# Test set: Average loss: -14.5563
#
# Current Learning rate 0.0001
# Train Epoch: 296 [0/90000 (0%)]	log Loss: -14.533551
#
# Train set: Average log loss: -12.5215
#
#
# Test set: Average loss: -15.2020
#
# Current Learning rate 0.0001
# Train Epoch: 297 [0/90000 (0%)]	log Loss: -15.272554
#
# Train set: Average log loss: -13.5577
#
#
# Test set: Average loss: -14.0731
#
# Current Learning rate 0.0001
# Train Epoch: 298 [0/90000 (0%)]	log Loss: -14.139588
#
# Train set: Average log loss: -12.5569
#
#
# Test set: Average loss: -15.3318
#
# Current Learning rate 0.0001
# Train Epoch: 299 [0/90000 (0%)]	log Loss: -15.345641
#
# Train set: Average log loss: -14.4605
#
#
# Test set: Average loss: -14.0068
#
# Current Learning rate 0.0001
# Train Epoch: 300 [0/90000 (0%)]	log Loss: -13.998045
#
# Train set: Average log loss: -12.6010
#
#
# Test set: Average loss: -15.5875
#
# Current Learning rate 0.0001
# Train Epoch: 301 [0/90000 (0%)]	log Loss: -15.684643
#
# Train set: Average log loss: -13.6878
#
#
# Test set: Average loss: -12.8353
#
# Current Learning rate 0.0001
# Train Epoch: 302 [0/90000 (0%)]	log Loss: -12.826862
#
# Train set: Average log loss: -12.9709
#
#
# Test set: Average loss: -14.8905
#
# Current Learning rate 0.0001
# Train Epoch: 303 [0/90000 (0%)]	log Loss: -14.866844
#
# Train set: Average log loss: -13.2505
#
#
# Test set: Average loss: -12.9292
#
# Current Learning rate 0.0001
# Train Epoch: 304 [0/90000 (0%)]	log Loss: -12.931948
#
# Train set: Average log loss: -12.7412
#
#
# Test set: Average loss: -15.4148
#
# Current Learning rate 0.0001
# Train Epoch: 305 [0/90000 (0%)]	log Loss: -15.418460
#
# Train set: Average log loss: -13.0413
#
#
# Test set: Average loss: -13.2378
#
# Current Learning rate 0.0001
# Train Epoch: 306 [0/90000 (0%)]	log Loss: -13.234046
#
# ...
#
# Train set: Average log loss: -18.1035
#
#
# Test set: Average loss: -17.9862
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2910 [0/90000 (0%)]	log Loss: -18.200369
#
# Train set: Average log loss: -18.1036
#
#
# Test set: Average loss: -17.9862
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2911 [0/90000 (0%)]	log Loss: -18.200505
#
# Train set: Average log loss: -18.1036
#
#
# Test set: Average loss: -17.9863
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2912 [0/90000 (0%)]	log Loss: -18.200480
#
# Train set: Average log loss: -18.1037
#
#
# Test set: Average loss: -17.9863
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2913 [0/90000 (0%)]	log Loss: -18.200685
#
# Train set: Average log loss: -18.1038
#
#
# Test set: Average loss: -17.9864
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2914 [0/90000 (0%)]	log Loss: -18.200820
#
# Train set: Average log loss: -18.1039
#
#
# Test set: Average loss: -17.9865
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2915 [0/90000 (0%)]	log Loss: -18.200824
#
# Train set: Average log loss: -18.1039
#
#
# Test set: Average loss: -17.9866
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2916 [0/90000 (0%)]	log Loss: -18.200878
#
# Train set: Average log loss: -18.1040
#
#
# Test set: Average loss: -17.9867
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2917 [0/90000 (0%)]	log Loss: -18.200990
#
# Train set: Average log loss: -18.1041
#
#
# Test set: Average loss: -17.9867
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2918 [0/90000 (0%)]	log Loss: -18.201040
#
# Train set: Average log loss: -18.1041
#
#
# Test set: Average loss: -17.9868
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2919 [0/90000 (0%)]	log Loss: -18.201044
#
# Train set: Average log loss: -18.1042
#
#
# Test set: Average loss: -17.9869
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2920 [0/90000 (0%)]	log Loss: -18.201140
#
# Train set: Average log loss: -18.1043
#
#
# Test set: Average loss: -17.9869
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2921 [0/90000 (0%)]	log Loss: -18.201237
#
# Train set: Average log loss: -18.1044
#
#
# Test set: Average loss: -17.9870
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2922 [0/90000 (0%)]	log Loss: -18.201282
#
# Train set: Average log loss: -18.1045
#
#
# Test set: Average loss: -17.9871
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2923 [0/90000 (0%)]	log Loss: -18.201322
#
# Train set: Average log loss: -18.1045
#
#
# Test set: Average loss: -17.9872
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2924 [0/90000 (0%)]	log Loss: -18.201425
#
# Train set: Average log loss: -18.1046
#
#
# Test set: Average loss: -17.9873
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2925 [0/90000 (0%)]	log Loss: -18.201511
#
# Train set: Average log loss: -18.1047
#
#
# Test set: Average loss: -17.9873
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2926 [0/90000 (0%)]	log Loss: -18.201597
#
# Train set: Average log loss: -18.1047
#
#
# Test set: Average loss: -17.9874
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2927 [0/90000 (0%)]	log Loss: -18.201672
#
# Train set: Average log loss: -18.1048
#
#
# Test set: Average loss: -17.9875
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2928 [0/90000 (0%)]	log Loss: -18.201694
#
# Train set: Average log loss: -18.1049
#
#
# Test set: Average loss: -17.9876
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2929 [0/90000 (0%)]	log Loss: -18.201697
#
# Train set: Average log loss: -18.1050
#
#
# Test set: Average loss: -17.9876
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2930 [0/90000 (0%)]	log Loss: -18.201878
#
# Train set: Average log loss: -18.1050
#
#
# Test set: Average loss: -17.9877
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2931 [0/90000 (0%)]	log Loss: -18.201928
#
# Train set: Average log loss: -18.1051
#
#
# Test set: Average loss: -17.9878
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2932 [0/90000 (0%)]	log Loss: -18.202041
#
# Train set: Average log loss: -18.1052
#
#
# Test set: Average loss: -17.9879
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2933 [0/90000 (0%)]	log Loss: -18.202087
#
# Train set: Average log loss: -18.1052
#
#
# Test set: Average loss: -17.9879
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2934 [0/90000 (0%)]	log Loss: -18.202100
#
# Train set: Average log loss: -18.1053
#
#
# Test set: Average loss: -17.9880
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2935 [0/90000 (0%)]	log Loss: -18.202175
#
# Train set: Average log loss: -18.1054
#
#
# Test set: Average loss: -17.9881
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2936 [0/90000 (0%)]	log Loss: -18.202251
#
# Train set: Average log loss: -18.1055
#
#
# Test set: Average loss: -17.9881
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2937 [0/90000 (0%)]	log Loss: -18.202281
#
# Train set: Average log loss: -18.1055
#
#
# Test set: Average loss: -17.9882
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2938 [0/90000 (0%)]	log Loss: -18.202391
#
# Train set: Average log loss: -18.1056
#
#
# Test set: Average loss: -17.9883
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2939 [0/90000 (0%)]	log Loss: -18.202518
#
# Train set: Average log loss: -18.1057
#
#
# Test set: Average loss: -17.9884
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2940 [0/90000 (0%)]	log Loss: -18.202686
#
# Train set: Average log loss: -18.1058
#
#
# Test set: Average loss: -17.9885
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2941 [0/90000 (0%)]	log Loss: -18.202778
#
# Train set: Average log loss: -18.1058
#
#
# Test set: Average loss: -17.9885
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2942 [0/90000 (0%)]	log Loss: -18.202808
#
# Train set: Average log loss: -18.1059
#
#
# Test set: Average loss: -17.9885
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2943 [0/90000 (0%)]	log Loss: -18.202802
#
# Train set: Average log loss: -18.1060
#
#
# Test set: Average loss: -17.9887
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2944 [0/90000 (0%)]	log Loss: -18.202976
#
# Train set: Average log loss: -18.1060
#
#
# Test set: Average loss: -17.9887
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2945 [0/90000 (0%)]	log Loss: -18.202953
#
# Train set: Average log loss: -18.1062
#
#
# Test set: Average loss: -17.9888
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2946 [0/90000 (0%)]	log Loss: -18.203090
#
# Train set: Average log loss: -18.1062
#
#
# Test set: Average loss: -17.9888
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2947 [0/90000 (0%)]	log Loss: -18.203073
#
# Train set: Average log loss: -18.1063
#
#
# Test set: Average loss: -17.9889
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2948 [0/90000 (0%)]	log Loss: -18.203174
#
# Train set: Average log loss: -18.1064
#
#
# Test set: Average loss: -17.9890
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2949 [0/90000 (0%)]	log Loss: -18.203232
#
# Train set: Average log loss: -18.1064
#
#
# Test set: Average loss: -17.9891
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2950 [0/90000 (0%)]	log Loss: -18.203304
#
# Train set: Average log loss: -18.1065
#
#
# Test set: Average loss: -17.9891
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2951 [0/90000 (0%)]	log Loss: -18.203431
#
# Train set: Average log loss: -18.1066
#
#
# Test set: Average loss: -17.9892
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2952 [0/90000 (0%)]	log Loss: -18.203510
#
# Train set: Average log loss: -18.1066
#
#
# Test set: Average loss: -17.9893
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2953 [0/90000 (0%)]	log Loss: -18.203566
#
# Train set: Average log loss: -18.1067
#
#
# Test set: Average loss: -17.9893
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2954 [0/90000 (0%)]	log Loss: -18.203605
#
# Train set: Average log loss: -18.1068
#
#
# Test set: Average loss: -17.9894
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2955 [0/90000 (0%)]	log Loss: -18.203706
#
# Train set: Average log loss: -18.1068
#
#
# Test set: Average loss: -17.9895
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2956 [0/90000 (0%)]	log Loss: -18.203756
#
# Train set: Average log loss: -18.1069
#
#
# Test set: Average loss: -17.9896
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2957 [0/90000 (0%)]	log Loss: -18.203887
#
# Train set: Average log loss: -18.1070
#
#
# Test set: Average loss: -17.9897
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2958 [0/90000 (0%)]	log Loss: -18.203963
#
# Train set: Average log loss: -18.1070
#
#
# Test set: Average loss: -17.9897
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2959 [0/90000 (0%)]	log Loss: -18.204127
#
# Train set: Average log loss: -18.1071
#
#
# Test set: Average loss: -17.9898
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2960 [0/90000 (0%)]	log Loss: -18.204096
#
# Train set: Average log loss: -18.1072
#
#
# Test set: Average loss: -17.9899
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2961 [0/90000 (0%)]	log Loss: -18.204307
#
# Train set: Average log loss: -18.1073
#
#
# Test set: Average loss: -17.9899
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2962 [0/90000 (0%)]	log Loss: -18.204307
#
# Train set: Average log loss: -18.1074
#
#
# Test set: Average loss: -17.9901
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2963 [0/90000 (0%)]	log Loss: -18.204510
#
# Train set: Average log loss: -18.1074
#
#
# Test set: Average loss: -17.9901
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2964 [0/90000 (0%)]	log Loss: -18.204655
#
# Train set: Average log loss: -18.1075
#
#
# Test set: Average loss: -17.9902
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2965 [0/90000 (0%)]	log Loss: -18.204617
#
# Train set: Average log loss: -18.1076
#
#
# Test set: Average loss: -17.9902
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2966 [0/90000 (0%)]	log Loss: -18.204784
#
# Train set: Average log loss: -18.1076
#
#
# Test set: Average loss: -17.9903
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2967 [0/90000 (0%)]	log Loss: -18.204848
#
# Train set: Average log loss: -18.1077
#
#
# Test set: Average loss: -17.9904
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2968 [0/90000 (0%)]	log Loss: -18.204919
#
# Train set: Average log loss: -18.1078
#
#
# Test set: Average loss: -17.9905
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2969 [0/90000 (0%)]	log Loss: -18.205155
#
# Train set: Average log loss: -18.1078
#
#
# Test set: Average loss: -17.9906
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2970 [0/90000 (0%)]	log Loss: -18.205099
#
# Train set: Average log loss: -18.1079
#
#
# Test set: Average loss: -17.9907
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2971 [0/90000 (0%)]	log Loss: -18.205307
#
# Train set: Average log loss: -18.1079
#
#
# Test set: Average loss: -17.9907
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2972 [0/90000 (0%)]	log Loss: -18.205319
#
# Train set: Average log loss: -18.1080
#
#
# Test set: Average loss: -17.9908
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2973 [0/90000 (0%)]	log Loss: -18.205475
#
# Train set: Average log loss: -18.1081
#
#
# Test set: Average loss: -17.9908
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2974 [0/90000 (0%)]	log Loss: -18.205479
#
# Train set: Average log loss: -18.1082
#
#
# Test set: Average loss: -17.9909
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2975 [0/90000 (0%)]	log Loss: -18.205476
#
# Train set: Average log loss: -18.1082
#
#
# Test set: Average loss: -17.9910
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2976 [0/90000 (0%)]	log Loss: -18.205697
#
# Train set: Average log loss: -18.1083
#
#
# Test set: Average loss: -17.9911
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2977 [0/90000 (0%)]	log Loss: -18.205720
#
# Train set: Average log loss: -18.1083
#
#
# Test set: Average loss: -17.9911
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2978 [0/90000 (0%)]	log Loss: -18.205854
#
# Train set: Average log loss: -18.1084
#
#
# Test set: Average loss: -17.9912
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2979 [0/90000 (0%)]	log Loss: -18.205993
#
# Train set: Average log loss: -18.1085
#
#
# Test set: Average loss: -17.9912
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2980 [0/90000 (0%)]	log Loss: -18.206038
#
# Train set: Average log loss: -18.1086
#
#
# Test set: Average loss: -17.9913
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2981 [0/90000 (0%)]	log Loss: -18.206143
#
# Train set: Average log loss: -18.1087
#
#
# Test set: Average loss: -17.9914
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2982 [0/90000 (0%)]	log Loss: -18.206264
#
# Train set: Average log loss: -18.1087
#
#
# Test set: Average loss: -17.9914
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2983 [0/90000 (0%)]	log Loss: -18.206367
#
# Train set: Average log loss: -18.1087
#
#
# Test set: Average loss: -17.9915
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2984 [0/90000 (0%)]	log Loss: -18.206541
#
# Train set: Average log loss: -18.1089
#
#
# Test set: Average loss: -17.9916
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2985 [0/90000 (0%)]	log Loss: -18.206605
#
# Train set: Average log loss: -18.1089
#
#
# Test set: Average loss: -17.9916
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2986 [0/90000 (0%)]	log Loss: -18.206706
#
# Train set: Average log loss: -18.1089
#
#
# Test set: Average loss: -17.9917
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2987 [0/90000 (0%)]	log Loss: -18.206852
#
# Train set: Average log loss: -18.1090
#
#
# Test set: Average loss: -17.9918
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2988 [0/90000 (0%)]	log Loss: -18.206916
#
# Train set: Average log loss: -18.1091
#
#
# Test set: Average loss: -17.9919
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2989 [0/90000 (0%)]	log Loss: -18.207058
#
# Train set: Average log loss: -18.1092
#
#
# Test set: Average loss: -17.9919
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2990 [0/90000 (0%)]	log Loss: -18.207140
#
# Train set: Average log loss: -18.1092
#
#
# Test set: Average loss: -17.9920
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2991 [0/90000 (0%)]	log Loss: -18.207288
#
# Train set: Average log loss: -18.1093
#
#
# Test set: Average loss: -17.9921
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2992 [0/90000 (0%)]	log Loss: -18.207312
#
# Train set: Average log loss: -18.1093
#
#
# Test set: Average loss: -17.9921
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2993 [0/90000 (0%)]	log Loss: -18.207425
#
# Train set: Average log loss: -18.1094
#
#
# Test set: Average loss: -17.9921
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2994 [0/90000 (0%)]	log Loss: -18.207458
#
# Train set: Average log loss: -18.1095
#
#
# Test set: Average loss: -17.9922
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2995 [0/90000 (0%)]	log Loss: -18.207596
#
# Train set: Average log loss: -18.1096
#
#
# Test set: Average loss: -17.9923
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2996 [0/90000 (0%)]	log Loss: -18.207789
#
# Train set: Average log loss: -18.1096
#
#
# Test set: Average loss: -17.9924
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2997 [0/90000 (0%)]	log Loss: -18.207714
#
# Train set: Average log loss: -18.1096
#
#
# Test set: Average loss: -17.9924
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2998 [0/90000 (0%)]	log Loss: -18.207846
#
# Train set: Average log loss: -18.1097
#
#
# Test set: Average loss: -17.9925
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2999 [0/90000 (0%)]	log Loss: -18.207985
#
# Train set: Average log loss: -18.1098
#
#
# Test set: Average loss: -17.9926
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 3000 [0/90000 (0%)]	log Loss: -18.208182
#
# Train set: Average log loss: -18.1098
#
#
# Test set: Average loss: -17.9926
#
# Current Learning rate 1.0000000000000002e-06

# %%
# Loading model from saved parameters
loaded_BS_ANN = BS_ANN().to(device)
PATH = "ANN_weights/BS_ANN_narrow.pt"
loaded_BS_ANN.load_state_dict(torch.load(PATH))
loaded_BS_ANN.eval()
# Out:
# BS_ANN(
#   (fc1): Linear(in_features=4, out_features=400, bias=True)
#   (fc2): Linear(in_features=400, out_features=400, bias=True)
#   (fc3): Linear(in_features=400, out_features=400, bias=True)
#   (fc4): Linear(in_features=400, out_features=400, bias=True)
#   (fc5): Linear(in_features=400, out_features=1, bias=True)
# )

# %%
# Plotting erros histogram
errors = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_BS_ANN(data)
    errors.append((target-output).data.cpu().numpy())
  errors = np.concatenate(errors)
plt.figure(figsize=(10,7))
plt.hist(errors,50,fill=False)
plt.grid()
plt.xlabel("Difference")
plt.ylabel("Density")
plt.show()
print("MAX ",errors.max())
print("MIN ",errors.min())
# Out:
# MAX  0.0008338839
# MIN  -0.0008913651

# %%
# Printing train and test MSE, MAE, MAPE and R2
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_BS_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_BS_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Train scores----------------
# MSE 1.578677e-08
# MAE 9.406319e-05
# MAPE 9.084946e-02
# R2 9.999995e-01
# -----------Test scores----------------
# MSE 1.529350e-08
# MAE 9.230250e-05
# MAPE 9.723768e-02
# R2 9.999995e-01

# %%
np.sqrt(1.554532e-08)
# Out:
# 0.00012468087263088913

# %% [markdown]
# # 2) Implied volatility network: IV-ANN

# %% [markdown]
# ### Defining class IV-ANN

# %%
class IV_ANN(BS_ANN):
    # The authors of the paper seem to use
    # the same architecture both for BS-ANN and the IV-ANN
    # thus the class inherets from BS_ANN
  pass

# %% [markdown]
# ### Data Generation with log transformation

# %% [markdown]
# Log transformation
#
# $\tilde{V}=V_{t}-\max \left(S_{t}-K e^{-r \tau}, 0\right)$
#
# $\left\{\log (\tilde{V} / K), S_{0} / K, r, \tau\right\}$

# %%
def IV_LHS_data_generator(n = 10**6, l_bounds = [.5, .05, .0, .05], u_bounds = [1.4, 1, .1, 1], log_scale = True):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,5) containig the inputs samples and the volatility as the target.
  Performs a log transormation of V/K.
  The inputs are: Moneyness (S/K), time to maturity (tau), Risk free rate (r), Volatility (sigma).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.
  log_scale: performs log transformation if True.

  """
  sampler = qmc.LatinHypercube(d=4)
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  bs_prices = bs_moneyness_call(sample[:,0], sample[:,1], sample[:,2], sample[:,3]).reshape((-1,1))


  bs_dataset = np.concatenate((sample[:,:-1], bs_prices, sample[:,3].reshape((n,1))),axis=1)
  # log transformation as in section 4.3
  if log_scale : 
    bs_dataset[:,3] = bs_dataset[:,3] - np.maximum(bs_dataset[:,0]-np.exp(-bs_dataset[:,1]*bs_dataset[:,2]),0)
    indecies = np.argwhere(bs_dataset[:,3]< 1e-7)
    bs_dataset = np.delete(bs_dataset, indecies,0)
    bs_dataset[:,3] = np.log(bs_dataset[:,3])

  print("------ INPUT ------")
  print("S/K.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,0]),max(bs_dataset[:,0])))
  print("Tau.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,1]),max(bs_dataset[:,1])))
  print("r............ [{:.2f} {:.2f}]".format(min(bs_dataset[:,2]),max(bs_dataset[:,2])))
  if log_scale : 
    print("log(V/K)..... [{:.2f} {:.2f}]".format(min(bs_dataset[:,3]),max(bs_dataset[:,3])))
  else : 
    print("V/K.......... [{:.2f} {:.2f}]".format(min(bs_dataset[:,3]),max(bs_dataset[:,3])))
  print("------ OUTPUT ------")
  print("Sigma........ [{:.2f} {:.2f}]".format(min(bs_dataset[:,4]),max(bs_dataset[:,4])))
  return torch.FloatTensor(bs_dataset)

bs_dataset = IV_LHS_data_generator(log_scale = True)
# Out:
# ------ INPUT ------
# S/K.......... [0.50 1.40]
# Tau.......... [0.05 1.00]
# r............ [0.00 0.10]
# log(V/K)..... [-16.12 -0.99]
# ------ OUTPUT ------
# Sigma........ [0.05 1.00]

# %% [markdown]
# ### Training IV-ANN with log transofmation

# %%
# Training parameters
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}



use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# torch.manual_seed(args["seed"])

# Loading Train / Test Data
bs_dataset = IV_LHS_data_generator(n = 10**5, log_scale = True)
train_size, test_size = int(bs_dataset.shape[0]*0.9), int(bs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(bs_dataset, [train_size, bs_dataset.shape[0]-train_size])

train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])


# Model training
print(device)
model = IV_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=args["lr"]) # Adam is found to be the best optimizer in the article
scheduler = StepLR(optimizer, step_size=10**3, gamma=args["gamma"]) # Deacreses the Learning rate by .1 every 1000 epoch

train_losses = []
test_losses = []
for epoch in range(1, args["epochs"] + 1):
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
if args["save_model"] :
  torch.save(model.state_dict(), "IV_SCALED_ANN.pt")
# Out:
# ------ INPUT ------
# S/K.......... [0.50 1.40]
# Tau.......... [0.05 1.00]
# r............ [0.00 0.10]
# log(V/K)..... [-16.12 -0.99]
# ------ OUTPUT ------
# Sigma........ [0.05 1.00]
# cuda
# Train Epoch: 1 [0/85187 (0%)]	log Loss: -0.671939
#
# Train set: Average log loss: -2.8045
#
#
# Test set: Average loss: -3.6490
#
# Current Learning rate 0.0001
# Train Epoch: 2 [0/85187 (0%)]	log Loss: -3.637234
#
# Train set: Average log loss: -3.8461
#
#
# Test set: Average loss: -4.0413
#
# Current Learning rate 0.0001
# Train Epoch: 3 [0/85187 (0%)]	log Loss: -4.062339
#
# Train set: Average log loss: -4.2294
#
#
# Test set: Average loss: -4.4881
#
# Current Learning rate 0.0001
# Train Epoch: 4 [0/85187 (0%)]	log Loss: -4.476239
#
# Train set: Average log loss: -4.8251
#
#
# Test set: Average loss: -5.2713
#
# Current Learning rate 0.0001
# Train Epoch: 5 [0/85187 (0%)]	log Loss: -5.229585
#
# Train set: Average log loss: -5.6174
#
#
# Test set: Average loss: -5.9795
#
# Current Learning rate 0.0001
# Train Epoch: 6 [0/85187 (0%)]	log Loss: -5.890696
#
# Train set: Average log loss: -6.1179
#
#
# Test set: Average loss: -6.3128
#
# Current Learning rate 0.0001
# Train Epoch: 7 [0/85187 (0%)]	log Loss: -6.192491
#
# Train set: Average log loss: -6.4218
#
#
# Test set: Average loss: -6.4534
#
# Current Learning rate 0.0001
# Train Epoch: 8 [0/85187 (0%)]	log Loss: -6.311804
#
# Train set: Average log loss: -6.6663
#
#
# Test set: Average loss: -6.6478
#
# Current Learning rate 0.0001
# Train Epoch: 9 [0/85187 (0%)]	log Loss: -6.500089
#
# Train set: Average log loss: -6.8815
#
#
# Test set: Average loss: -6.9759
#
# Current Learning rate 0.0001
# Train Epoch: 10 [0/85187 (0%)]	log Loss: -6.819855
#
# Train set: Average log loss: -7.0670
#
#
# Test set: Average loss: -7.1397
#
# Current Learning rate 0.0001
# Train Epoch: 11 [0/85187 (0%)]	log Loss: -6.991676
#
# Train set: Average log loss: -7.2161
#
#
# Test set: Average loss: -7.1284
#
# Current Learning rate 0.0001
# Train Epoch: 12 [0/85187 (0%)]	log Loss: -6.992783
#
# Train set: Average log loss: -7.3705
#
#
# Test set: Average loss: -7.1923
#
# Current Learning rate 0.0001
# Train Epoch: 13 [0/85187 (0%)]	log Loss: -7.064732
#
# Train set: Average log loss: -7.5108
#
#
# Test set: Average loss: -7.4613
#
# Current Learning rate 0.0001
# Train Epoch: 14 [0/85187 (0%)]	log Loss: -7.334451
#
# Train set: Average log loss: -7.6820
#
#
# Test set: Average loss: -7.3478
#
# Current Learning rate 0.0001
# Train Epoch: 15 [0/85187 (0%)]	log Loss: -7.231622
#
# Train set: Average log loss: -7.8157
#
#
# Test set: Average loss: -7.6230
#
# Current Learning rate 0.0001
# Train Epoch: 16 [0/85187 (0%)]	log Loss: -7.503384
#
# Train set: Average log loss: -7.9320
#
#
# Test set: Average loss: -7.8464
#
# Current Learning rate 0.0001
# Train Epoch: 17 [0/85187 (0%)]	log Loss: -7.726776
#
# Train set: Average log loss: -8.0220
#
#
# Test set: Average loss: -7.9845
#
# Current Learning rate 0.0001
# Train Epoch: 18 [0/85187 (0%)]	log Loss: -7.873665
#
# Train set: Average log loss: -8.1295
#
#
# Test set: Average loss: -8.1712
#
# Current Learning rate 0.0001
# Train Epoch: 19 [0/85187 (0%)]	log Loss: -8.070201
#
# Train set: Average log loss: -8.2264
#
#
# Test set: Average loss: -8.3845
#
# Current Learning rate 0.0001
# Train Epoch: 20 [0/85187 (0%)]	log Loss: -8.298859
#
# Train set: Average log loss: -8.3458
#
#
# Test set: Average loss: -8.5108
#
# Current Learning rate 0.0001
# Train Epoch: 21 [0/85187 (0%)]	log Loss: -8.457233
#
# Train set: Average log loss: -8.4648
#
#
# Test set: Average loss: -8.5321
#
# Current Learning rate 0.0001
# Train Epoch: 22 [0/85187 (0%)]	log Loss: -8.489971
#
# Train set: Average log loss: -8.5277
#
#
# Test set: Average loss: -8.6499
#
# Current Learning rate 0.0001
# Train Epoch: 23 [0/85187 (0%)]	log Loss: -8.622720
#
# Train set: Average log loss: -8.5527
#
#
# Test set: Average loss: -8.7657
#
# Current Learning rate 0.0001
# Train Epoch: 24 [0/85187 (0%)]	log Loss: -8.762155
#
# Train set: Average log loss: -8.6319
#
#
# Test set: Average loss: -8.8222
#
# Current Learning rate 0.0001
# Train Epoch: 25 [0/85187 (0%)]	log Loss: -8.842987
#
# Train set: Average log loss: -8.7238
#
#
# Test set: Average loss: -8.8049
#
# Current Learning rate 0.0001
# Train Epoch: 26 [0/85187 (0%)]	log Loss: -8.840259
#
# Train set: Average log loss: -8.8538
#
#
# Test set: Average loss: -8.9944
#
# Current Learning rate 0.0001
# Train Epoch: 27 [0/85187 (0%)]	log Loss: -9.012276
#
# Train set: Average log loss: -8.8895
#
#
# Test set: Average loss: -8.7455
#
# Current Learning rate 0.0001
# Train Epoch: 28 [0/85187 (0%)]	log Loss: -8.730517
#
# Train set: Average log loss: -8.8336
#
#
# Test set: Average loss: -8.9202
#
# Current Learning rate 0.0001
# Train Epoch: 29 [0/85187 (0%)]	log Loss: -8.926344
#
# Train set: Average log loss: -8.8941
#
#
# Test set: Average loss: -9.0079
#
# Current Learning rate 0.0001
# Train Epoch: 30 [0/85187 (0%)]	log Loss: -9.028872
#
# Train set: Average log loss: -8.9545
#
#
# Test set: Average loss: -9.0434
#
# Current Learning rate 0.0001
# Train Epoch: 31 [0/85187 (0%)]	log Loss: -9.076843
#
# Train set: Average log loss: -8.9756
#
#
# Test set: Average loss: -9.1105
#
# Current Learning rate 0.0001
# Train Epoch: 32 [0/85187 (0%)]	log Loss: -9.162003
#
# Train set: Average log loss: -9.0238
#
#
# Test set: Average loss: -9.1609
#
# Current Learning rate 0.0001
# Train Epoch: 33 [0/85187 (0%)]	log Loss: -9.226076
#
# Train set: Average log loss: -9.0640
#
#
# Test set: Average loss: -9.2146
#
# Current Learning rate 0.0001
# Train Epoch: 34 [0/85187 (0%)]	log Loss: -9.295579
#
# Train set: Average log loss: -9.1151
#
#
# Test set: Average loss: -9.2190
#
# Current Learning rate 0.0001
# Train Epoch: 35 [0/85187 (0%)]	log Loss: -9.301285
#
# Train set: Average log loss: -9.1996
#
#
# Test set: Average loss: -9.1355
#
# Current Learning rate 0.0001
# Train Epoch: 36 [0/85187 (0%)]	log Loss: -9.197370
#
# Train set: Average log loss: -9.3093
#
#
# Test set: Average loss: -9.4777
#
# Current Learning rate 0.0001
# Train Epoch: 37 [0/85187 (0%)]	log Loss: -9.619274
#
# Train set: Average log loss: -9.2055
#
#
# Test set: Average loss: -9.3813
#
# Current Learning rate 0.0001
# Train Epoch: 38 [0/85187 (0%)]	log Loss: -9.520097
#
# Train set: Average log loss: -9.3060
#
#
# Test set: Average loss: -9.5535
#
# Current Learning rate 0.0001
# Train Epoch: 39 [0/85187 (0%)]	log Loss: -9.682854
#
# Train set: Average log loss: -9.0113
#
#
# Test set: Average loss: -9.4441
#
# Current Learning rate 0.0001
# Train Epoch: 40 [0/85187 (0%)]	log Loss: -9.569962
#
# Train set: Average log loss: -9.4084
#
#
# Test set: Average loss: -9.5224
#
# Current Learning rate 0.0001
# Train Epoch: 41 [0/85187 (0%)]	log Loss: -9.662572
#
# Train set: Average log loss: -9.4795
#
#
# Test set: Average loss: -9.3706
#
# Current Learning rate 0.0001
# Train Epoch: 42 [0/85187 (0%)]	log Loss: -9.454830
#
# Train set: Average log loss: -8.8866
#
#
# Test set: Average loss: -9.5994
#
# Current Learning rate 0.0001
# Train Epoch: 43 [0/85187 (0%)]	log Loss: -9.781601
#
# Train set: Average log loss: -9.3899
#
#
# Test set: Average loss: -9.5199
#
# Current Learning rate 0.0001
# Train Epoch: 44 [0/85187 (0%)]	log Loss: -9.655528
#
# Train set: Average log loss: -9.3877
#
#
# Test set: Average loss: -9.5747
#
# Current Learning rate 0.0001
# Train Epoch: 45 [0/85187 (0%)]	log Loss: -9.714020
#
# Train set: Average log loss: -9.5061
#
#
# Test set: Average loss: -9.4079
#
# Current Learning rate 0.0001
# Train Epoch: 46 [0/85187 (0%)]	log Loss: -9.502673
#
# Train set: Average log loss: -9.6606
#
#
# Test set: Average loss: -9.5465
#
# Current Learning rate 0.0001
# Train Epoch: 47 [0/85187 (0%)]	log Loss: -9.662661
#
# Train set: Average log loss: -9.0610
#
#
# Test set: Average loss: -9.7709
#
# Current Learning rate 0.0001
# Train Epoch: 48 [0/85187 (0%)]	log Loss: -9.947436
#
# Train set: Average log loss: -9.5691
#
#
# Test set: Average loss: -9.5804
#
# Current Learning rate 0.0001
# Train Epoch: 49 [0/85187 (0%)]	log Loss: -9.684792
#
# Train set: Average log loss: -9.6366
#
#
# Test set: Average loss: -9.4914
#
# Current Learning rate 0.0001
# Train Epoch: 50 [0/85187 (0%)]	log Loss: -9.594078
#
# Train set: Average log loss: -9.7046
#
#
# Test set: Average loss: -9.3360
#
# Current Learning rate 0.0001
# Train Epoch: 51 [0/85187 (0%)]	log Loss: -9.398420
#
# Train set: Average log loss: -8.9336
#
#
# Test set: Average loss: -9.6225
#
# Current Learning rate 0.0001
# Train Epoch: 52 [0/85187 (0%)]	log Loss: -9.722271
#
# Train set: Average log loss: -9.9402
#
#
# Test set: Average loss: -9.5491
#
# Current Learning rate 0.0001
# Train Epoch: 53 [0/85187 (0%)]	log Loss: -9.618086
#
# Train set: Average log loss: -9.7750
#
#
# Test set: Average loss: -9.7389
#
# Current Learning rate 0.0001
# Train Epoch: 54 [0/85187 (0%)]	log Loss: -9.868166
#
# Train set: Average log loss: -9.5297
#
#
# Test set: Average loss: -9.5816
#
# Current Learning rate 0.0001
# Train Epoch: 55 [0/85187 (0%)]	log Loss: -9.677083
#
# Train set: Average log loss: -9.8243
#
#
# Test set: Average loss: -9.2403
#
# Current Learning rate 0.0001
# Train Epoch: 56 [0/85187 (0%)]	log Loss: -9.289102
#
# Train set: Average log loss: -8.9351
#
#
# Test set: Average loss: -9.5601
#
# Current Learning rate 0.0001
# Train Epoch: 57 [0/85187 (0%)]	log Loss: -9.629069
#
# Train set: Average log loss: -10.1138
#
#
# Test set: Average loss: -9.6279
#
# Current Learning rate 0.0001
# Train Epoch: 58 [0/85187 (0%)]	log Loss: -9.693599
#
# Train set: Average log loss: -9.8971
#
#
# Test set: Average loss: -9.5753
#
# Current Learning rate 0.0001
# Train Epoch: 59 [0/85187 (0%)]	log Loss: -9.657001
#
# Train set: Average log loss: -9.4908
#
#
# Test set: Average loss: -9.2397
#
# Current Learning rate 0.0001
# Train Epoch: 60 [0/85187 (0%)]	log Loss: -9.264019
#
# Train set: Average log loss: -9.7669
#
#
# Test set: Average loss: -9.4102
#
# Current Learning rate 0.0001
# Train Epoch: 61 [0/85187 (0%)]	log Loss: -9.462231
#
# Train set: Average log loss: -9.7822
#
#
# Test set: Average loss: -9.8535
#
# Current Learning rate 0.0001
# Train Epoch: 62 [0/85187 (0%)]	log Loss: -9.967430
#
# Train set: Average log loss: -9.0999
#
#
# Test set: Average loss: -9.9160
#
# Current Learning rate 0.0001
# Train Epoch: 63 [0/85187 (0%)]	log Loss: -10.050150
#
# Train set: Average log loss: -10.0589
#
#
# Test set: Average loss: -9.7736
#
# Current Learning rate 0.0001
# Train Epoch: 64 [0/85187 (0%)]	log Loss: -9.814789
#
# Train set: Average log loss: -9.9493
#
#
# Test set: Average loss: -9.1257
#
# Current Learning rate 0.0001
# Train Epoch: 65 [0/85187 (0%)]	log Loss: -9.135747
#
# Train set: Average log loss: -9.9198
#
#
# Test set: Average loss: -10.2733
#
# Current Learning rate 0.0001
# Train Epoch: 66 [0/85187 (0%)]	log Loss: -10.433538
#
# Train set: Average log loss: -9.0931
#
#
# Test set: Average loss: -9.8226
#
# Current Learning rate 0.0001
# Train Epoch: 67 [0/85187 (0%)]	log Loss: -9.931042
#
# Train set: Average log loss: -10.1922
#
#
# Test set: Average loss: -9.8581
#
# Current Learning rate 0.0001
# Train Epoch: 68 [0/85187 (0%)]	log Loss: -9.890672
#
# Train set: Average log loss: -10.0130
#
#
# Test set: Average loss: -8.8477
#
# Current Learning rate 0.0001
# Train Epoch: 69 [0/85187 (0%)]	log Loss: -8.831100
#
# Train set: Average log loss: -9.9495
#
#
# Test set: Average loss: -10.4290
#
# Current Learning rate 0.0001
# Train Epoch: 70 [0/85187 (0%)]	log Loss: -10.603629
#
# Train set: Average log loss: -9.5269
#
#
# Test set: Average loss: -9.4708
#
# Current Learning rate 0.0001
# Train Epoch: 71 [0/85187 (0%)]	log Loss: -9.482822
#
# Train set: Average log loss: -9.8196
#
#
# Test set: Average loss: -9.1165
#
# Current Learning rate 0.0001
# Train Epoch: 72 [0/85187 (0%)]	log Loss: -9.103946
#
# Train set: Average log loss: -9.9702
#
#
# Test set: Average loss: -9.1248
#
# Current Learning rate 0.0001
# Train Epoch: 73 [0/85187 (0%)]	log Loss: -9.123815
#
# Train set: Average log loss: -9.5852
#
#
# Test set: Average loss: -9.7115
#
# Current Learning rate 0.0001
# Train Epoch: 74 [0/85187 (0%)]	log Loss: -9.739551
#
# Train set: Average log loss: -9.8651
#
#
# Test set: Average loss: -9.0141
#
# Current Learning rate 0.0001
# Train Epoch: 75 [0/85187 (0%)]	log Loss: -8.995067
#
# Train set: Average log loss: -9.9563
#
#
# Test set: Average loss: -9.1577
#
# Current Learning rate 0.0001
# Train Epoch: 76 [0/85187 (0%)]	log Loss: -9.153652
#
# Train set: Average log loss: -9.8928
#
#
# Test set: Average loss: -10.5264
#
# Current Learning rate 0.0001
# Train Epoch: 77 [0/85187 (0%)]	log Loss: -10.665083
#
# Train set: Average log loss: -10.0396
#
#
# Test set: Average loss: -9.0023
#
# Current Learning rate 0.0001
# Train Epoch: 78 [0/85187 (0%)]	log Loss: -8.997056
#
# Train set: Average log loss: -9.1398
#
#
# Test set: Average loss: -9.8646
#
# Current Learning rate 0.0001
# Train Epoch: 79 [0/85187 (0%)]	log Loss: -9.921900
#
# Train set: Average log loss: -10.5476
#
#
# Test set: Average loss: -9.6880
#
# Current Learning rate 0.0001
# Train Epoch: 80 [0/85187 (0%)]	log Loss: -9.697149
#
# Train set: Average log loss: -9.9899
#
#
# Test set: Average loss: -9.1009
#
# Current Learning rate 0.0001
# Train Epoch: 81 [0/85187 (0%)]	log Loss: -9.084055
#
# Train set: Average log loss: -9.9575
#
#
# Test set: Average loss: -9.1952
#
# Current Learning rate 0.0001
# Train Epoch: 82 [0/85187 (0%)]	log Loss: -9.191193
#
# Train set: Average log loss: -10.0775
#
#
# Test set: Average loss: -10.4791
#
# Current Learning rate 0.0001
# Train Epoch: 83 [0/85187 (0%)]	log Loss: -10.574957
#
# Train set: Average log loss: -9.5541
#
#
# Test set: Average loss: -8.5360
#
# Current Learning rate 0.0001
# Train Epoch: 84 [0/85187 (0%)]	log Loss: -8.477813
#
# Train set: Average log loss: -9.5242
#
#
# Test set: Average loss: -10.5230
#
# Current Learning rate 0.0001
# Train Epoch: 85 [0/85187 (0%)]	log Loss: -10.637328
#
# Train set: Average log loss: -10.7650
#
#
# Test set: Average loss: -10.0177
#
# Current Learning rate 0.0001
# Train Epoch: 86 [0/85187 (0%)]	log Loss: -10.065792
#
# Train set: Average log loss: -10.0668
#
#
# Test set: Average loss: -10.3763
#
# Current Learning rate 0.0001
# Train Epoch: 87 [0/85187 (0%)]	log Loss: -10.455117
#
# Train set: Average log loss: -10.2635
#
#
# Test set: Average loss: -10.2650
#
# Current Learning rate 0.0001
# Train Epoch: 88 [0/85187 (0%)]	log Loss: -10.296256
#
# Train set: Average log loss: -10.2410
#
#
# Test set: Average loss: -10.7903
#
# Current Learning rate 0.0001
# Train Epoch: 89 [0/85187 (0%)]	log Loss: -10.901343
#
# Train set: Average log loss: -10.0288
#
#
# Test set: Average loss: -10.5956
#
# Current Learning rate 0.0001
# Train Epoch: 90 [0/85187 (0%)]	log Loss: -10.616612
#
# Train set: Average log loss: -9.3324
#
#
# Test set: Average loss: -9.5148
#
# Current Learning rate 0.0001
# Train Epoch: 91 [0/85187 (0%)]	log Loss: -9.489966
#
# Train set: Average log loss: -10.0997
#
#
# Test set: Average loss: -10.6265
#
# Current Learning rate 0.0001
# Train Epoch: 92 [0/85187 (0%)]	log Loss: -10.748611
#
# Train set: Average log loss: -10.6952
#
#
# Test set: Average loss: -10.7051
#
# Current Learning rate 0.0001
# Train Epoch: 93 [0/85187 (0%)]	log Loss: -10.782823
#
# Train set: Average log loss: -9.9148
#
#
# Test set: Average loss: -8.9118
#
# Current Learning rate 0.0001
# Train Epoch: 94 [0/85187 (0%)]	log Loss: -8.914457
#
# Train set: Average log loss: -9.7209
#
#
# Test set: Average loss: -10.8586
#
# Current Learning rate 0.0001
# Train Epoch: 95 [0/85187 (0%)]	log Loss: -11.001856
#
# Train set: Average log loss: -10.5261
#
#
# Test set: Average loss: -9.8567
#
# Current Learning rate 0.0001
# Train Epoch: 96 [0/85187 (0%)]	log Loss: -9.900130
#
# Train set: Average log loss: -9.2460
#
#
# Test set: Average loss: -10.1322
#
# Current Learning rate 0.0001
# Train Epoch: 97 [0/85187 (0%)]	log Loss: -10.146482
#
# Train set: Average log loss: -10.9871
#
#
# Test set: Average loss: -10.8377
#
# Current Learning rate 0.0001
# Train Epoch: 98 [0/85187 (0%)]	log Loss: -10.942368
#
# Train set: Average log loss: -10.6338
#
#
# Test set: Average loss: -10.1690
#
# Current Learning rate 0.0001
# Train Epoch: 99 [0/85187 (0%)]	log Loss: -10.229935
#
# Train set: Average log loss: -9.2858
#
#
# Test set: Average loss: -10.2592
#
# Current Learning rate 0.0001
# Train Epoch: 100 [0/85187 (0%)]	log Loss: -10.274294
#
# Train set: Average log loss: -10.9489
#
#
# Test set: Average loss: -11.0536
#
# Current Learning rate 0.0001
# Train Epoch: 101 [0/85187 (0%)]	log Loss: -11.176599
#
# Train set: Average log loss: -10.7175
#
#
# Test set: Average loss: -10.2315
#
# Current Learning rate 0.0001
# Train Epoch: 102 [0/85187 (0%)]	log Loss: -10.294218
#
# Train set: Average log loss: -9.4088
#
#
# Test set: Average loss: -10.7478
#
# Current Learning rate 0.0001
# Train Epoch: 103 [0/85187 (0%)]	log Loss: -10.848400
#
# Train set: Average log loss: -10.6511
#
#
# Test set: Average loss: -9.8174
#
# Current Learning rate 0.0001
# Train Epoch: 104 [0/85187 (0%)]	log Loss: -9.818241
#
# Train set: Average log loss: -10.3642
#
#
# Test set: Average loss: -10.1626
#
# Current Learning rate 0.0001
# Train Epoch: 105 [0/85187 (0%)]	log Loss: -10.211316
#
# Train set: Average log loss: -9.8128
#
#
# Test set: Average loss: -11.0572
#
# Current Learning rate 0.0001
# Train Epoch: 106 [0/85187 (0%)]	log Loss: -11.172601
#
# Train set: Average log loss: -10.5895
#
#
# Test set: Average loss: -9.1564
#
# Current Learning rate 0.0001
# Train Epoch: 107 [0/85187 (0%)]	log Loss: -9.129734
#
# Train set: Average log loss: -9.9185
#
#
# Test set: Average loss: -10.3437
#
# Current Learning rate 0.0001
# Train Epoch: 108 [0/85187 (0%)]	log Loss: -10.394376
#
# Train set: Average log loss: -10.1126
#
#
# Test set: Average loss: -9.4833
#
# Current Learning rate 0.0001
# Train Epoch: 109 [0/85187 (0%)]	log Loss: -9.492951
#
# Train set: Average log loss: -10.1941
#
#
# Test set: Average loss: -9.7267
#
# Current Learning rate 0.0001
# Train Epoch: 110 [0/85187 (0%)]	log Loss: -9.755641
#
# Train set: Average log loss: -9.9514
#
#
# Test set: Average loss: -9.7684
#
# Current Learning rate 0.0001
# Train Epoch: 111 [0/85187 (0%)]	log Loss: -9.782956
#
# Train set: Average log loss: -10.2775
#
#
# Test set: Average loss: -10.0303
#
# Current Learning rate 0.0001
# Train Epoch: 112 [0/85187 (0%)]	log Loss: -10.062428
#
# Train set: Average log loss: -10.3654
#
#
# Test set: Average loss: -11.0796
#
# Current Learning rate 0.0001
# Train Epoch: 113 [0/85187 (0%)]	log Loss: -11.205144
#
# Train set: Average log loss: -10.2782
#
#
# Test set: Average loss: -9.6227
#
# Current Learning rate 0.0001
# Train Epoch: 114 [0/85187 (0%)]	log Loss: -9.583768
#
# Train set: Average log loss: -10.0381
#
#
# Test set: Average loss: -11.0776
#
# Current Learning rate 0.0001
# Train Epoch: 115 [0/85187 (0%)]	log Loss: -11.215928
#
# Train set: Average log loss: -9.6126
#
#
# Test set: Average loss: -9.7603
#
# Current Learning rate 0.0001
# Train Epoch: 116 [0/85187 (0%)]	log Loss: -9.780384
#
# Train set: Average log loss: -10.4760
#
#
# Test set: Average loss: -11.0202
#
# Current Learning rate 0.0001
# Train Epoch: 117 [0/85187 (0%)]	log Loss: -11.110186
#
# Train set: Average log loss: -10.9032
#
#
# Test set: Average loss: -10.9159
#
# Current Learning rate 0.0001
# Train Epoch: 118 [0/85187 (0%)]	log Loss: -10.960312
#
# Train set: Average log loss: -9.6084
#
#
# Test set: Average loss: -10.2485
#
# Current Learning rate 0.0001
# Train Epoch: 119 [0/85187 (0%)]	log Loss: -10.269974
#
# Train set: Average log loss: -10.4642
#
#
# Test set: Average loss: -9.9575
#
# Current Learning rate 0.0001
# Train Epoch: 120 [0/85187 (0%)]	log Loss: -9.955608
#
# Train set: Average log loss: -10.5923
#
#
# Test set: Average loss: -11.2639
#
# Current Learning rate 0.0001
# Train Epoch: 121 [0/85187 (0%)]	log Loss: -11.364924
#
# Train set: Average log loss: -9.6537
#
#
# Test set: Average loss: -10.6098
#
# Current Learning rate 0.0001
# Train Epoch: 122 [0/85187 (0%)]	log Loss: -10.650558
#
# Train set: Average log loss: -10.7682
#
#
# Test set: Average loss: -9.3436
#
# Current Learning rate 0.0001
# Train Epoch: 123 [0/85187 (0%)]	log Loss: -9.335144
#
# Train set: Average log loss: -10.5799
#
#
# Test set: Average loss: -11.2845
#
# Current Learning rate 0.0001
# Train Epoch: 124 [0/85187 (0%)]	log Loss: -11.384430
#
# Train set: Average log loss: -9.5569
#
#
# Test set: Average loss: -10.1229
#
# Current Learning rate 0.0001
# Train Epoch: 125 [0/85187 (0%)]	log Loss: -10.065823
#
# Train set: Average log loss: -10.8803
#
#
# Test set: Average loss: -10.9974
#
# Current Learning rate 0.0001
# Train Epoch: 126 [0/85187 (0%)]	log Loss: -11.033829
#
# Train set: Average log loss: -10.3345
#
#
# Test set: Average loss: -8.9661
#
# Current Learning rate 0.0001
# Train Epoch: 127 [0/85187 (0%)]	log Loss: -8.934542
#
# Train set: Average log loss: -10.0053
#
#
# Test set: Average loss: -11.4723
#
# Current Learning rate 0.0001
# Train Epoch: 128 [0/85187 (0%)]	log Loss: -11.570035
#
# Train set: Average log loss: -11.2876
#
#
# Test set: Average loss: -11.4305
#
# Current Learning rate 0.0001
# Train Epoch: 129 [0/85187 (0%)]	log Loss: -11.493941
#
# Train set: Average log loss: -9.1586
#
#
# Test set: Average loss: -9.4923
#
# Current Learning rate 0.0001
# Train Epoch: 130 [0/85187 (0%)]	log Loss: -9.451115
#
# Train set: Average log loss: -10.7586
#
#
# Test set: Average loss: -10.6077
#
# Current Learning rate 0.0001
# Train Epoch: 131 [0/85187 (0%)]	log Loss: -10.608503
#
# Train set: Average log loss: -11.3170
#
#
# Test set: Average loss: -11.5705
#
# Current Learning rate 0.0001
# Train Epoch: 132 [0/85187 (0%)]	log Loss: -11.680416
#
# Train set: Average log loss: -11.1925
#
#
# Test set: Average loss: -11.1165
#
# Current Learning rate 0.0001
# Train Epoch: 133 [0/85187 (0%)]	log Loss: -11.135434
#
# Train set: Average log loss: -9.7013
#
#
# Test set: Average loss: -10.7034
#
# Current Learning rate 0.0001
# Train Epoch: 134 [0/85187 (0%)]	log Loss: -10.722195
#
# Train set: Average log loss: -10.7844
#
#
# Test set: Average loss: -9.1003
#
# Current Learning rate 0.0001
# Train Epoch: 135 [0/85187 (0%)]	log Loss: -9.075501
#
# Train set: Average log loss: -10.3998
#
#
# Test set: Average loss: -9.0425
#
# Current Learning rate 0.0001
# Train Epoch: 136 [0/85187 (0%)]	log Loss: -9.027182
#
# Train set: Average log loss: -10.5486
#
#
# Test set: Average loss: -9.4767
#
# Current Learning rate 0.0001
# Train Epoch: 137 [0/85187 (0%)]	log Loss: -9.480728
#
# Train set: Average log loss: -10.0877
#
#
# Test set: Average loss: -10.2229
#
# Current Learning rate 0.0001
# Train Epoch: 138 [0/85187 (0%)]	log Loss: -10.232334
#
# Train set: Average log loss: -10.7255
#
#
# Test set: Average loss: -10.8612
#
# Current Learning rate 0.0001
# Train Epoch: 139 [0/85187 (0%)]	log Loss: -10.852012
#
# Train set: Average log loss: -10.2261
#
#
# Test set: Average loss: -7.6495
#
# Current Learning rate 0.0001
# Train Epoch: 140 [0/85187 (0%)]	log Loss: -7.608630
#
# Train set: Average log loss: -9.9048
#
#
# Test set: Average loss: -11.5219
#
# Current Learning rate 0.0001
# Train Epoch: 141 [0/85187 (0%)]	log Loss: -11.523024
#
# Train set: Average log loss: -11.0053
#
#
# Test set: Average loss: -11.3806
#
# Current Learning rate 0.0001
# Train Epoch: 142 [0/85187 (0%)]	log Loss: -11.455524
#
# Train set: Average log loss: -9.8762
#
#
# Test set: Average loss: -8.7496
#
# Current Learning rate 0.0001
# Train Epoch: 143 [0/85187 (0%)]	log Loss: -8.759300
#
# Train set: Average log loss: -10.0684
#
#
# Test set: Average loss: -11.6325
#
# Current Learning rate 0.0001
# Train Epoch: 144 [0/85187 (0%)]	log Loss: -11.676837
#
# Train set: Average log loss: -11.0374
#
#
# Test set: Average loss: -10.6219
#
# Current Learning rate 0.0001
# Train Epoch: 145 [0/85187 (0%)]	log Loss: -10.671380
#
# Train set: Average log loss: -10.0999
#
#
# Test set: Average loss: -9.4556
#
# Current Learning rate 0.0001
# Train Epoch: 146 [0/85187 (0%)]	log Loss: -9.417713
#
# Train set: Average log loss: -10.6331
#
#
# Test set: Average loss: -11.4454
#
# Current Learning rate 0.0001
# Train Epoch: 147 [0/85187 (0%)]	log Loss: -11.504485
#
# Train set: Average log loss: -10.5146
#
#
# Test set: Average loss: -10.9839
#
# Current Learning rate 0.0001
# Train Epoch: 148 [0/85187 (0%)]	log Loss: -11.015827
#
# Train set: Average log loss: -10.6718
#
#
# Test set: Average loss: -11.2607
#
# Current Learning rate 0.0001
# Train Epoch: 149 [0/85187 (0%)]	log Loss: -11.331840
#
# Train set: Average log loss: -9.6431
#
#
# Test set: Average loss: -9.9228
#
# Current Learning rate 0.0001
# Train Epoch: 150 [0/85187 (0%)]	log Loss: -9.915261
#
# Train set: Average log loss: -10.7010
#
#
# Test set: Average loss: -11.6659
#
# Current Learning rate 0.0001
# Train Epoch: 151 [0/85187 (0%)]	log Loss: -11.688647
#
# Train set: Average log loss: -10.7141
#
#
# Test set: Average loss: -10.5304
#
# Current Learning rate 0.0001
# Train Epoch: 152 [0/85187 (0%)]	log Loss: -10.570061
#
# Train set: Average log loss: -11.1010
#
#
# Test set: Average loss: -11.3201
#
# Current Learning rate 0.0001
# Train Epoch: 153 [0/85187 (0%)]	log Loss: -11.335513
#
# Train set: Average log loss: -10.3877
#
#
# Test set: Average loss: -8.2506
#
# Current Learning rate 0.0001
# Train Epoch: 154 [0/85187 (0%)]	log Loss: -8.214036
#
# Train set: Average log loss: -10.1274
#
#
# Test set: Average loss: -9.7161
#
# Current Learning rate 0.0001
# Train Epoch: 155 [0/85187 (0%)]	log Loss: -9.713097
#
# Train set: Average log loss: -10.6591
#
#
# Test set: Average loss: -11.2797
#
# Current Learning rate 0.0001
# Train Epoch: 156 [0/85187 (0%)]	log Loss: -11.350051
#
# Train set: Average log loss: -10.2975
#
#
# Test set: Average loss: -8.4293
#
# Current Learning rate 0.0001
# Train Epoch: 157 [0/85187 (0%)]	log Loss: -8.385840
#
# Train set: Average log loss: -9.7004
#
#
# Test set: Average loss: -11.4637
#
# Current Learning rate 0.0001
# Train Epoch: 158 [0/85187 (0%)]	log Loss: -11.468430
#
# Train set: Average log loss: -11.4257
#
#
# Test set: Average loss: -11.6899
#
# Current Learning rate 0.0001
# Train Epoch: 159 [0/85187 (0%)]	log Loss: -11.722867
#
# Train set: Average log loss: -11.5881
#
#
# Test set: Average loss: -11.5569
#
# Current Learning rate 0.0001
# Train Epoch: 160 [0/85187 (0%)]	log Loss: -11.611573
#
# Train set: Average log loss: -10.4656
#
#
# Test set: Average loss: -11.3736
#
# Current Learning rate 0.0001
# Train Epoch: 161 [0/85187 (0%)]	log Loss: -11.412708
#
# Train set: Average log loss: -9.6782
#
#
# Test set: Average loss: -8.6621
#
# Current Learning rate 0.0001
# Train Epoch: 162 [0/85187 (0%)]	log Loss: -8.511718
#
# Train set: Average log loss: -9.8535
#
#
# Test set: Average loss: -10.6791
#
# Current Learning rate 0.0001
# Train Epoch: 163 [0/85187 (0%)]	log Loss: -10.612413
#
# Train set: Average log loss: -11.5368
#
#
# Test set: Average loss: -11.6842
#
# Current Learning rate 0.0001
# Train Epoch: 164 [0/85187 (0%)]	log Loss: -11.727330
#
# Train set: Average log loss: -11.4207
#
#
# Test set: Average loss: -11.2992
#
# Current Learning rate 0.0001
# Train Epoch: 165 [0/85187 (0%)]	log Loss: -11.315420
#
# Train set: Average log loss: -10.1527
#
#
# Test set: Average loss: -11.0965
#
# Current Learning rate 0.0001
# Train Epoch: 166 [0/85187 (0%)]	log Loss: -11.163527
#
# Train set: Average log loss: -10.9980
#
#
# Test set: Average loss: -9.2718
#
# Current Learning rate 0.0001
# Train Epoch: 167 [0/85187 (0%)]	log Loss: -9.253308
#
# Train set: Average log loss: -10.3253
#
#
# Test set: Average loss: -10.4270
#
# Current Learning rate 0.0001
# Train Epoch: 168 [0/85187 (0%)]	log Loss: -10.436694
#
# Train set: Average log loss: -11.0023
#
#
# Test set: Average loss: -10.8271
#
# Current Learning rate 0.0001
# Train Epoch: 169 [0/85187 (0%)]	log Loss: -10.774457
#
# Train set: Average log loss: -10.0861
#
#
# Test set: Average loss: -9.9576
#
# Current Learning rate 0.0001
# Train Epoch: 170 [0/85187 (0%)]	log Loss: -9.969940
#
# Train set: Average log loss: -10.5479
#
#
# Test set: Average loss: -9.7998
#
# Current Learning rate 0.0001
# Train Epoch: 171 [0/85187 (0%)]	log Loss: -9.792858
#
# Train set: Average log loss: -10.5346
#
#
# Test set: Average loss: -9.3481
#
# Current Learning rate 0.0001
# Train Epoch: 172 [0/85187 (0%)]	log Loss: -9.328803
#
# Train set: Average log loss: -10.9132
#
#
# Test set: Average loss: -11.6379
#
# Current Learning rate 0.0001
# Train Epoch: 173 [0/85187 (0%)]	log Loss: -11.688367
#
# Train set: Average log loss: -9.9854
#
#
# Test set: Average loss: -10.9772
#
# Current Learning rate 0.0001
# Train Epoch: 174 [0/85187 (0%)]	log Loss: -10.881957
#
# Train set: Average log loss: -11.0584
#
#
# Test set: Average loss: -9.3484
#
# Current Learning rate 0.0001
# Train Epoch: 175 [0/85187 (0%)]	log Loss: -9.327563
#
# Train set: Average log loss: -10.4419
#
#
# Test set: Average loss: -9.8589
#
# Current Learning rate 0.0001
# Train Epoch: 176 [0/85187 (0%)]	log Loss: -9.847001
#
# Train set: Average log loss: -10.9836
#
#
# Test set: Average loss: -11.2159
#
# Current Learning rate 0.0001
# Train Epoch: 177 [0/85187 (0%)]	log Loss: -11.254728
#
# Train set: Average log loss: -10.6268
#
#
# Test set: Average loss: -9.1308
#
# Current Learning rate 0.0001
# Train Epoch: 178 [0/85187 (0%)]	log Loss: -9.108894
#
# Train set: Average log loss: -9.8273
#
#
# Test set: Average loss: -11.5669
#
# Current Learning rate 0.0001
# Train Epoch: 179 [0/85187 (0%)]	log Loss: -11.546376
#
# Train set: Average log loss: -11.1722
#
#
# Test set: Average loss: -11.6257
#
# Current Learning rate 0.0001
# Train Epoch: 180 [0/85187 (0%)]	log Loss: -11.605301
#
# Train set: Average log loss: -10.9763
#
#
# Test set: Average loss: -11.6228
#
# Current Learning rate 0.0001
# Train Epoch: 181 [0/85187 (0%)]	log Loss: -11.663927
#
# Train set: Average log loss: -10.0647
#
#
# Test set: Average loss: -10.5068
#
# Current Learning rate 0.0001
# Train Epoch: 182 [0/85187 (0%)]	log Loss: -10.466085
#
# Train set: Average log loss: -11.3153
#
#
# Test set: Average loss: -9.6442
#
# Current Learning rate 0.0001
# Train Epoch: 183 [0/85187 (0%)]	log Loss: -9.617035
#
# Train set: Average log loss: -10.4386
#
#
# Test set: Average loss: -11.2552
#
# Current Learning rate 0.0001
# Train Epoch: 184 [0/85187 (0%)]	log Loss: -11.274214
#
# Train set: Average log loss: -10.3043
#
#
# Test set: Average loss: -9.9774
#
# Current Learning rate 0.0001
# Train Epoch: 185 [0/85187 (0%)]	log Loss: -9.931642
#
# Train set: Average log loss: -11.2344
#
#
# Test set: Average loss: -11.6271
#
# Current Learning rate 0.0001
# Train Epoch: 186 [0/85187 (0%)]	log Loss: -11.633653
#
# Train set: Average log loss: -9.8255
#
#
# Test set: Average loss: -10.2149
#
# Current Learning rate 0.0001
# Train Epoch: 187 [0/85187 (0%)]	log Loss: -10.122729
#
# Train set: Average log loss: -10.7564
#
#
# Test set: Average loss: -11.6167
#
# Current Learning rate 0.0001
# Train Epoch: 188 [0/85187 (0%)]	log Loss: -11.622810
#
# Train set: Average log loss: -11.5512
#
#
# Test set: Average loss: -11.7484
#
# Current Learning rate 0.0001
# Train Epoch: 189 [0/85187 (0%)]	log Loss: -11.768649
#
# Train set: Average log loss: -10.2018
#
#
# Test set: Average loss: -11.1122
#
# Current Learning rate 0.0001
# Train Epoch: 190 [0/85187 (0%)]	log Loss: -11.104698
#
# Train set: Average log loss: -11.7002
#
#
# Test set: Average loss: -11.5633
#
# Current Learning rate 0.0001
# Train Epoch: 191 [0/85187 (0%)]	log Loss: -11.561969
#
# Train set: Average log loss: -10.2265
#
#
# Test set: Average loss: -10.7498
#
# Current Learning rate 0.0001
# Train Epoch: 192 [0/85187 (0%)]	log Loss: -10.694882
#
# Train set: Average log loss: -10.8502
#
#
# Test set: Average loss: -11.3847
#
# Current Learning rate 0.0001
# Train Epoch: 193 [0/85187 (0%)]	log Loss: -11.251361
#
# Train set: Average log loss: -10.4727
#
#
# Test set: Average loss: -11.8907
#
# Current Learning rate 0.0001
# Train Epoch: 194 [0/85187 (0%)]	log Loss: -11.881138
#
# Train set: Average log loss: -11.0671
#
#
# Test set: Average loss: -10.5974
#
# Current Learning rate 0.0001
# Train Epoch: 195 [0/85187 (0%)]	log Loss: -10.583628
#
# Train set: Average log loss: -10.2431
#
#
# Test set: Average loss: -9.4990
#
# Current Learning rate 0.0001
# Train Epoch: 196 [0/85187 (0%)]	log Loss: -9.470827
#
# Train set: Average log loss: -10.8959
#
#
# Test set: Average loss: -10.1051
#
# Current Learning rate 0.0001
# Train Epoch: 197 [0/85187 (0%)]	log Loss: -10.100882
#
# Train set: Average log loss: -10.5249
#
#
# Test set: Average loss: -9.2603
#
# Current Learning rate 0.0001
# Train Epoch: 198 [0/85187 (0%)]	log Loss: -9.233188
#
# Train set: Average log loss: -10.7370
#
#
# Test set: Average loss: -9.6062
#
# Current Learning rate 0.0001
# Train Epoch: 199 [0/85187 (0%)]	log Loss: -9.594535
#
# Train set: Average log loss: -10.6248
#
#
# Test set: Average loss: -9.9129
#
# Current Learning rate 0.0001
# Train Epoch: 200 [0/85187 (0%)]	log Loss: -9.906786
#
# Train set: Average log loss: -10.6595
#
#
# Test set: Average loss: -9.5495
#
# Current Learning rate 0.0001
# Train Epoch: 201 [0/85187 (0%)]	log Loss: -9.539384
#
# Train set: Average log loss: -10.5765
#
#
# Test set: Average loss: -9.8422
#
# Current Learning rate 0.0001
# Train Epoch: 202 [0/85187 (0%)]	log Loss: -9.840724
#
# Train set: Average log loss: -10.8440
#
#
# Test set: Average loss: -10.2192
#
# Current Learning rate 0.0001
# Train Epoch: 203 [0/85187 (0%)]	log Loss: -10.224323
#
# Train set: Average log loss: -10.3658
#
#
# Test set: Average loss: -9.2947
#
# Current Learning rate 0.0001
# Train Epoch: 204 [0/85187 (0%)]	log Loss: -9.273741
#
# Train set: Average log loss: -10.6693
#
#
# Test set: Average loss: -10.3299
#
# Current Learning rate 0.0001
# Train Epoch: 205 [0/85187 (0%)]	log Loss: -10.346071
#
# Train set: Average log loss: -10.4637
#
#
# Test set: Average loss: -10.5063
#
# Current Learning rate 0.0001
# Train Epoch: 206 [0/85187 (0%)]	log Loss: -10.360511
#
# Train set: Average log loss: -10.2246
#
#
# Test set: Average loss: -11.8052
#
# Current Learning rate 0.0001
# Train Epoch: 207 [0/85187 (0%)]	log Loss: -11.767387
#
# Train set: Average log loss: -11.1953
#
#
# Test set: Average loss: -9.9894
#
# Current Learning rate 0.0001
# Train Epoch: 208 [0/85187 (0%)]	log Loss: -9.994637
#
# Train set: Average log loss: -10.8002
#
#
# Test set: Average loss: -8.7897
#
# Current Learning rate 0.0001
# Train Epoch: 209 [0/85187 (0%)]	log Loss: -8.761476
#
# Train set: Average log loss: -10.5971
#
#
# Test set: Average loss: -9.7226
#
# Current Learning rate 0.0001
# Train Epoch: 210 [0/85187 (0%)]	log Loss: -9.725562
#
# Train set: Average log loss: -10.8335
#
#
# Test set: Average loss: -10.4776
#
# Current Learning rate 0.0001
# Train Epoch: 211 [0/85187 (0%)]	log Loss: -10.355931
#
# Train set: Average log loss: -10.3334
#
#
# Test set: Average loss: -11.9088
#
# Current Learning rate 0.0001
# Train Epoch: 212 [0/85187 (0%)]	log Loss: -11.873981
#
# Train set: Average log loss: -10.8473
#
#
# Test set: Average loss: -10.3247
#
# Current Learning rate 0.0001
# Train Epoch: 213 [0/85187 (0%)]	log Loss: -10.330181
#
# Train set: Average log loss: -10.3214
#
#
# Test set: Average loss: -10.3064
#
# Current Learning rate 0.0001
# Train Epoch: 214 [0/85187 (0%)]	log Loss: -10.258172
#
# Train set: Average log loss: -11.3529
#
#
# Test set: Average loss: -11.1473
#
# Current Learning rate 0.0001
# Train Epoch: 215 [0/85187 (0%)]	log Loss: -11.147250
#
# Train set: Average log loss: -9.9767
#
#
# Test set: Average loss: -10.1090
#
# Current Learning rate 0.0001
# Train Epoch: 216 [0/85187 (0%)]	log Loss: -10.005010
#
# Train set: Average log loss: -10.6598
#
#
# Test set: Average loss: -10.7973
#
# Current Learning rate 0.0001
# Train Epoch: 217 [0/85187 (0%)]	log Loss: -10.712384
#
# Train set: Average log loss: -11.4220
#
#
# Test set: Average loss: -11.8744
#
# Current Learning rate 0.0001
# Train Epoch: 218 [0/85187 (0%)]	log Loss: -11.839127
#
# Train set: Average log loss: -10.7963
#
#
# Test set: Average loss: -9.8051
#
# Current Learning rate 0.0001
# Train Epoch: 219 [0/85187 (0%)]	log Loss: -9.795524
#
# Train set: Average log loss: -10.8611
#
#
# Test set: Average loss: -9.7945
#
# Current Learning rate 0.0001
# Train Epoch: 220 [0/85187 (0%)]	log Loss: -9.789440
#
# Train set: Average log loss: -10.6986
#
#
# Test set: Average loss: -10.2968
#
# Current Learning rate 0.0001
# Train Epoch: 221 [0/85187 (0%)]	log Loss: -10.313505
#
# Train set: Average log loss: -10.7314
#
#
# Test set: Average loss: -10.4689
#
# Current Learning rate 0.0001
# Train Epoch: 222 [0/85187 (0%)]	log Loss: -10.421445
#
# Train set: Average log loss: -10.9888
#
#
# Test set: Average loss: -11.0836
#
# Current Learning rate 0.0001
# Train Epoch: 223 [0/85187 (0%)]	log Loss: -11.012539
#
# Train set: Average log loss: -10.0370
#
#
# Test set: Average loss: -11.4852
#
# Current Learning rate 0.0001
# Train Epoch: 224 [0/85187 (0%)]	log Loss: -11.391893
#
# Train set: Average log loss: -10.9930
#
#
# Test set: Average loss: -11.7987
#
# Current Learning rate 0.0001
# Train Epoch: 225 [0/85187 (0%)]	log Loss: -11.720093
#
# Train set: Average log loss: -10.7800
#
#
# Test set: Average loss: -10.0508
#
# Current Learning rate 0.0001
# Train Epoch: 226 [0/85187 (0%)]	log Loss: -10.046735
#
# Train set: Average log loss: -10.6010
#
#
# Test set: Average loss: -10.0728
#
# Current Learning rate 0.0001
# Train Epoch: 227 [0/85187 (0%)]	log Loss: -10.076726
#
# Train set: Average log loss: -10.8193
#
#
# Test set: Average loss: -10.3831
#
# Current Learning rate 0.0001
# Train Epoch: 228 [0/85187 (0%)]	log Loss: -10.402599
#
# Train set: Average log loss: -11.1000
#
#
# Test set: Average loss: -11.0284
#
# Current Learning rate 0.0001
# Train Epoch: 229 [0/85187 (0%)]	log Loss: -10.890279
#
# Train set: Average log loss: -10.5680
#
#
# Test set: Average loss: -9.2707
#
# Current Learning rate 0.0001
# Train Epoch: 230 [0/85187 (0%)]	log Loss: -9.246755
#
# Train set: Average log loss: -10.6508
#
#
# Test set: Average loss: -10.8028
#
# Current Learning rate 0.0001
# Train Epoch: 231 [0/85187 (0%)]	log Loss: -10.749933
#
# Train set: Average log loss: -10.9299
#
#
# Test set: Average loss: -10.1082
#
# Current Learning rate 0.0001
# Train Epoch: 232 [0/85187 (0%)]	log Loss: -10.096058
#
# Train set: Average log loss: -10.6752
#
#
# Test set: Average loss: -10.8137
#
# Current Learning rate 0.0001
# Train Epoch: 233 [0/85187 (0%)]	log Loss: -10.826986
#
# Train set: Average log loss: -10.1986
#
#
# Test set: Average loss: -10.7013
#
# Current Learning rate 0.0001
# Train Epoch: 234 [0/85187 (0%)]	log Loss: -10.581386
#
# Train set: Average log loss: -10.4368
#
#
# Test set: Average loss: -10.4569
#
# Current Learning rate 0.0001
# Train Epoch: 235 [0/85187 (0%)]	log Loss: -10.388531
#
# Train set: Average log loss: -11.3089
#
#
# Test set: Average loss: -11.7983
#
# Current Learning rate 0.0001
# Train Epoch: 236 [0/85187 (0%)]	log Loss: -11.764933
#
# Train set: Average log loss: -11.0219
#
#
# Test set: Average loss: -10.3276
#
# Current Learning rate 0.0001
# Train Epoch: 237 [0/85187 (0%)]	log Loss: -10.327949
#
# Train set: Average log loss: -11.4291
#
#
# Test set: Average loss: -11.0461
#
# Current Learning rate 0.0001
# Train Epoch: 238 [0/85187 (0%)]	log Loss: -11.048474
#
# Train set: Average log loss: -9.7895
#
#
# Test set: Average loss: -9.0667
#
# Current Learning rate 0.0001
# Train Epoch: 239 [0/85187 (0%)]	log Loss: -8.994160
#
# Train set: Average log loss: -9.8269
#
#
# Test set: Average loss: -11.8843
#
# Current Learning rate 0.0001
# Train Epoch: 240 [0/85187 (0%)]	log Loss: -11.773092
#
# Train set: Average log loss: -11.8981
#
#
# Test set: Average loss: -10.7372
#
# Current Learning rate 0.0001
# Train Epoch: 241 [0/85187 (0%)]	log Loss: -10.673480
#
# Train set: Average log loss: -11.5535
#
#
# Test set: Average loss: -11.3943
#
# Current Learning rate 0.0001
# Train Epoch: 242 [0/85187 (0%)]	log Loss: -11.366177
#
# Train set: Average log loss: -11.4002
#
#
# Test set: Average loss: -12.1751
#
# Current Learning rate 0.0001
# Train Epoch: 243 [0/85187 (0%)]	log Loss: -12.196800
#
# Train set: Average log loss: -10.9312
#
#
# Test set: Average loss: -10.4716
#
# Current Learning rate 0.0001
# Train Epoch: 244 [0/85187 (0%)]	log Loss: -10.480645
#
# Train set: Average log loss: -11.1831
#
#
# Test set: Average loss: -9.2678
#
# Current Learning rate 0.0001
# Train Epoch: 245 [0/85187 (0%)]	log Loss: -9.229194
#
# Train set: Average log loss: -10.3527
#
#
# Test set: Average loss: -11.8271
#
# Current Learning rate 0.0001
# Train Epoch: 246 [0/85187 (0%)]	log Loss: -11.713804
#
# Train set: Average log loss: -10.8218
#
#
# Test set: Average loss: -10.9820
#
# Current Learning rate 0.0001
# Train Epoch: 247 [0/85187 (0%)]	log Loss: -11.013125
#
# Train set: Average log loss: -10.9610
#
#
# Test set: Average loss: -10.4814
#
# Current Learning rate 0.0001
# Train Epoch: 248 [0/85187 (0%)]	log Loss: -10.497577
#
# Train set: Average log loss: -11.3721
#
#
# Test set: Average loss: -11.9233
#
# Current Learning rate 0.0001
# Train Epoch: 249 [0/85187 (0%)]	log Loss: -11.850573
#
# Train set: Average log loss: -11.1754
#
#
# Test set: Average loss: -10.7259
#
# Current Learning rate 0.0001
# Train Epoch: 250 [0/85187 (0%)]	log Loss: -10.709990
#
# Train set: Average log loss: -11.0270
#
#
# Test set: Average loss: -11.8400
#
# Current Learning rate 0.0001
# Train Epoch: 251 [0/85187 (0%)]	log Loss: -11.851242
#
# Train set: Average log loss: -9.9209
#
#
# Test set: Average loss: -10.2020
#
# Current Learning rate 0.0001
# Train Epoch: 252 [0/85187 (0%)]	log Loss: -10.129458
#
# Train set: Average log loss: -11.1316
#
#
# Test set: Average loss: -11.7054
#
# Current Learning rate 0.0001
# Train Epoch: 253 [0/85187 (0%)]	log Loss: -11.644843
#
# Train set: Average log loss: -11.0635
#
#
# Test set: Average loss: -9.9893
#
# Current Learning rate 0.0001
# Train Epoch: 254 [0/85187 (0%)]	log Loss: -9.981926
#
# Train set: Average log loss: -10.9341
#
#
# Test set: Average loss: -10.7243
#
# Current Learning rate 0.0001
# Train Epoch: 255 [0/85187 (0%)]	log Loss: -10.748206
#
# Train set: Average log loss: -10.3811
#
#
# Test set: Average loss: -10.6624
#
# Current Learning rate 0.0001
# Train Epoch: 256 [0/85187 (0%)]	log Loss: -10.566114
#
# Train set: Average log loss: -10.4738
#
#
# Test set: Average loss: -11.1648
#
# Current Learning rate 0.0001
# Train Epoch: 257 [0/85187 (0%)]	log Loss: -11.086182
#
# Train set: Average log loss: -11.3859
#
#
# Test set: Average loss: -12.0156
#
# Current Learning rate 0.0001
# Train Epoch: 258 [0/85187 (0%)]	log Loss: -11.894940
#
# Train set: Average log loss: -11.3182
#
#
# Test set: Average loss: -11.3356
#
# Current Learning rate 0.0001
# Train Epoch: 259 [0/85187 (0%)]	log Loss: -11.275863
#
# Train set: Average log loss: -10.1949
#
#
# Test set: Average loss: -10.1327
#
# Current Learning rate 0.0001
# Train Epoch: 260 [0/85187 (0%)]	log Loss: -10.032439
#
# Train set: Average log loss: -10.3746
#
#
# Test set: Average loss: -9.9005
#
# Current Learning rate 0.0001
# Train Epoch: 261 [0/85187 (0%)]	log Loss: -9.831756
#
# Train set: Average log loss: -10.7167
#
#
# Test set: Average loss: -10.0908
#
# Current Learning rate 0.0001
# Train Epoch: 262 [0/85187 (0%)]	log Loss: -10.035415
#
# Train set: Average log loss: -10.7809
#
#
# Test set: Average loss: -10.0179
#
# Current Learning rate 0.0001
# Train Epoch: 263 [0/85187 (0%)]	log Loss: -9.966897
#
# Train set: Average log loss: -10.7978
#
#
# Test set: Average loss: -10.1295
#
# Current Learning rate 0.0001
# Train Epoch: 264 [0/85187 (0%)]	log Loss: -10.086552
#
# Train set: Average log loss: -11.0177
#
#
# Test set: Average loss: -11.2378
#
# Current Learning rate 0.0001
# Train Epoch: 265 [0/85187 (0%)]	log Loss: -11.213299
#
# Train set: Average log loss: -11.9799
#
#
# Test set: Average loss: -12.5318
#
# Current Learning rate 0.0001
# Train Epoch: 266 [0/85187 (0%)]	log Loss: -12.523684
#
# Train set: Average log loss: -9.9317
#
#
# Test set: Average loss: -9.3202
#
# Current Learning rate 0.0001
# Train Epoch: 267 [0/85187 (0%)]	log Loss: -9.226930
#
# Train set: Average log loss: -9.9990
#
#
# Test set: Average loss: -12.2678
#
# Current Learning rate 0.0001
# Train Epoch: 268 [0/85187 (0%)]	log Loss: -12.155444
#
# Train set: Average log loss: -12.0462
#
#
# Test set: Average loss: -11.2634
#
# Current Learning rate 0.0001
# Train Epoch: 269 [0/85187 (0%)]	log Loss: -11.217185
#
# Train set: Average log loss: -11.5398
#
#
# Test set: Average loss: -11.0560
#
# Current Learning rate 0.0001
# Train Epoch: 270 [0/85187 (0%)]	log Loss: -11.019936
#
# Train set: Average log loss: -11.9413
#
#
# Test set: Average loss: -12.1345
#
# Current Learning rate 0.0001
# Train Epoch: 271 [0/85187 (0%)]	log Loss: -12.123103
#
# Train set: Average log loss: -11.0827
#
#
# Test set: Average loss: -9.4757
#
# Current Learning rate 0.0001
# Train Epoch: 272 [0/85187 (0%)]	log Loss: -9.454363
#
# Train set: Average log loss: -10.9408
#
#
# Test set: Average loss: -12.3387
#
# Current Learning rate 0.0001
# Train Epoch: 273 [0/85187 (0%)]	log Loss: -12.301789
#
# Train set: Average log loss: -10.5833
#
#
# Test set: Average loss: -12.0159
#
# Current Learning rate 0.0001
# Train Epoch: 274 [0/85187 (0%)]	log Loss: -11.884115
#
# Train set: Average log loss: -11.8835
#
#
# Test set: Average loss: -10.8134
#
# Current Learning rate 0.0001
# Train Epoch: 275 [0/85187 (0%)]	log Loss: -10.778447
#
# Train set: Average log loss: -10.0249
#
#
# Test set: Average loss: -10.4458
#
# Current Learning rate 0.0001
# Train Epoch: 276 [0/85187 (0%)]	log Loss: -10.320939
#
# Train set: Average log loss: -10.5740
#
#
# Test set: Average loss: -11.0042
#
# Current Learning rate 0.0001
# Train Epoch: 277 [0/85187 (0%)]	log Loss: -10.934495
#
# Train set: Average log loss: -11.4117
#
#
# Test set: Average loss: -12.2030
#
# Current Learning rate 0.0001
# Train Epoch: 278 [0/85187 (0%)]	log Loss: -12.172022
#
# Train set: Average log loss: -11.8873
#
#
# Test set: Average loss: -10.6353
#
# Current Learning rate 0.0001
# Train Epoch: 279 [0/85187 (0%)]	log Loss: -10.610350
#
# Train set: Average log loss: -11.1965
#
#
# Test set: Average loss: -12.4506
#
# Current Learning rate 0.0001
# Train Epoch: 280 [0/85187 (0%)]	log Loss: -12.508396
#
# Train set: Average log loss: -10.4129
#
#
# Test set: Average loss: -10.8492
#
# Current Learning rate 0.0001
# Train Epoch: 281 [0/85187 (0%)]	log Loss: -10.767670
#
# Train set: Average log loss: -11.6997
#
#
# Test set: Average loss: -11.9983
#
# Current Learning rate 0.0001
# Train Epoch: 282 [0/85187 (0%)]	log Loss: -11.986796
#
# Train set: Average log loss: -10.3055
#
#
# Test set: Average loss: -10.0238
#
# Current Learning rate 0.0001
# Train Epoch: 283 [0/85187 (0%)]	log Loss: -9.975253
#
# Train set: Average log loss: -11.4990
#
#
# Test set: Average loss: -12.4464
#
# Current Learning rate 0.0001
# Train Epoch: 284 [0/85187 (0%)]	log Loss: -12.432204
#
# Train set: Average log loss: -12.0951
#
#
# Test set: Average loss: -10.9517
#
# Current Learning rate 0.0001
# Train Epoch: 285 [0/85187 (0%)]	log Loss: -10.897544
#
# Train set: Average log loss: -10.7148
#
#
# Test set: Average loss: -11.2521
#
# Current Learning rate 0.0001
# Train Epoch: 286 [0/85187 (0%)]	log Loss: -11.240810
#
# Train set: Average log loss: -10.3172
#
#
# Test set: Average loss: -10.6753
#
# Current Learning rate 0.0001
# Train Epoch: 287 [0/85187 (0%)]	log Loss: -10.493904
#
# Train set: Average log loss: -10.2966
#
#
# Test set: Average loss: -10.4623
#
# Current Learning rate 0.0001
# Train Epoch: 288 [0/85187 (0%)]	log Loss: -10.388516
#
# Train set: Average log loss: -11.0206
#
#
# Test set: Average loss: -11.0291
#
# Current Learning rate 0.0001
# Train Epoch: 289 [0/85187 (0%)]	log Loss: -10.967348
#
# Train set: Average log loss: -11.6467
#
#
# Test set: Average loss: -12.6970
#
# Current Learning rate 0.0001
# Train Epoch: 290 [0/85187 (0%)]	log Loss: -12.676383
#
# Train set: Average log loss: -11.2785
#
#
# Test set: Average loss: -10.4320
#
# Current Learning rate 0.0001
# Train Epoch: 291 [0/85187 (0%)]	log Loss: -10.413735
#
# Train set: Average log loss: -11.2518
#
#
# Test set: Average loss: -10.5651
#
# Current Learning rate 0.0001
# Train Epoch: 292 [0/85187 (0%)]	log Loss: -10.552528
#
# Train set: Average log loss: -10.5360
#
#
# Test set: Average loss: -11.8175
#
# Current Learning rate 0.0001
# Train Epoch: 293 [0/85187 (0%)]	log Loss: -11.695043
#
# Train set: Average log loss: -10.9466
#
#
# Test set: Average loss: -10.6543
#
# Current Learning rate 0.0001
# Train Epoch: 294 [0/85187 (0%)]	log Loss: -10.646973
#
# Train set: Average log loss: -11.4051
#
#
# Test set: Average loss: -10.7180
#
# Current Learning rate 0.0001
# Train Epoch: 295 [0/85187 (0%)]	log Loss: -10.702039
#
# Train set: Average log loss: -10.5006
#
#
# Test set: Average loss: -10.9388
#
# Current Learning rate 0.0001
# Train Epoch: 296 [0/85187 (0%)]	log Loss: -10.818653
#
# Train set: Average log loss: -10.8587
#
#
# Test set: Average loss: -12.0488
#
# Current Learning rate 0.0001
# Train Epoch: 297 [0/85187 (0%)]	log Loss: -11.980565
#
# Train set: Average log loss: -11.1535
#
#
# Test set: Average loss: -11.3455
#
# Current Learning rate 0.0001
# Train Epoch: 298 [0/85187 (0%)]	log Loss: -11.353773
#
# Train set: Average log loss: -11.6738
#
#
# Test set: Average loss: -10.1189
#
# Current Learning rate 0.0001
# Train Epoch: 299 [0/85187 (0%)]	log Loss: -10.092049
#
# Train set: Average log loss: -10.2230
#
#
# Test set: Average loss: -9.8793
#
# Current Learning rate 0.0001
# Train Epoch: 300 [0/85187 (0%)]	log Loss: -9.819813
#
# Train set: Average log loss: -11.2459
#
#
# Test set: Average loss: -11.4759
#
# Current Learning rate 0.0001
# Train Epoch: 301 [0/85187 (0%)]	log Loss: -11.404527
#
# Train set: Average log loss: -11.4249
#
#
# Test set: Average loss: -10.6678
#
# Current Learning rate 0.0001
# Train Epoch: 302 [0/85187 (0%)]	log Loss: -10.652107
#
# Train set: Average log loss: -11.0549
#
#
# Test set: Average loss: -10.0565
#
# Current Learning rate 0.0001
# Train Epoch: 303 [0/85187 (0%)]	log Loss: -10.014062
#
# Train set: Average log loss: -10.6858
#
#
# Test set: Average loss: -12.0422
#
# Current Learning rate 0.0001
# Train Epoch: 304 [0/85187 (0%)]	log Loss: -12.043073
#
# Train set: Average log loss: -11.1795
#
#
# Test set: Average loss: -10.2013
#
# Current Learning rate 0.0001
# Train Epoch: 305 [0/85187 (0%)]	log Loss: -10.179698
#
# Train set: Average log loss: -10.8691
#
#
# Test set: Average loss: -11.0382
#
# Current Learning rate 0.0001
# Train Epoch: 306 [0/85187 (0%)]	log Loss: -10.960670
#
# Train set: Average log loss: -10.8928
#
#
# Test set: Average loss: -10.7695
#
# Current Learning rate 0.0001
# Train Epoch: 307 [0/85187 (0%)]	log Loss: -10.783292
#
# Train set: Average log loss: -11.6460
#
#
# Test set: Average loss: -10.1352
#
# Current Learning rate 0.0001
# Train Epoch: 308 [0/85187 (0%)]	log Loss: -10.119190
#
# Train set: Average log loss: -10.4559
#
#
# ...
#
# Train set: Average log loss: -14.6217
#
#
# Test set: Average loss: -14.3336
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2910 [0/85187 (0%)]	log Loss: -14.563762
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.3339
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2911 [0/85187 (0%)]	log Loss: -14.564421
#
# Train set: Average log loss: -14.6219
#
#
# Test set: Average loss: -14.3338
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2912 [0/85187 (0%)]	log Loss: -14.564213
#
# Train set: Average log loss: -14.6221
#
#
# Test set: Average loss: -14.3340
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2913 [0/85187 (0%)]	log Loss: -14.564198
#
# Train set: Average log loss: -14.6218
#
#
# Test set: Average loss: -14.3340
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2914 [0/85187 (0%)]	log Loss: -14.564384
#
# Train set: Average log loss: -14.6220
#
#
# Test set: Average loss: -14.3340
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2915 [0/85187 (0%)]	log Loss: -14.564771
#
# Train set: Average log loss: -14.6222
#
#
# Test set: Average loss: -14.3340
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2916 [0/85187 (0%)]	log Loss: -14.564288
#
# Train set: Average log loss: -14.6224
#
#
# Test set: Average loss: -14.3341
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2917 [0/85187 (0%)]	log Loss: -14.564668
#
# Train set: Average log loss: -14.6222
#
#
# Test set: Average loss: -14.3343
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2918 [0/85187 (0%)]	log Loss: -14.564749
#
# Train set: Average log loss: -14.6225
#
#
# Test set: Average loss: -14.3343
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2919 [0/85187 (0%)]	log Loss: -14.564585
#
# Train set: Average log loss: -14.6223
#
#
# Test set: Average loss: -14.3342
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2920 [0/85187 (0%)]	log Loss: -14.564549
#
# Train set: Average log loss: -14.6224
#
#
# Test set: Average loss: -14.3343
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2921 [0/85187 (0%)]	log Loss: -14.565000
#
# Train set: Average log loss: -14.6227
#
#
# Test set: Average loss: -14.3345
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2922 [0/85187 (0%)]	log Loss: -14.564770
#
# Train set: Average log loss: -14.6226
#
#
# Test set: Average loss: -14.3343
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2923 [0/85187 (0%)]	log Loss: -14.564969
#
# Train set: Average log loss: -14.6228
#
#
# Test set: Average loss: -14.3344
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2924 [0/85187 (0%)]	log Loss: -14.564841
#
# Train set: Average log loss: -14.6226
#
#
# Test set: Average loss: -14.3346
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2925 [0/85187 (0%)]	log Loss: -14.565147
#
# Train set: Average log loss: -14.6229
#
#
# Test set: Average loss: -14.3346
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2926 [0/85187 (0%)]	log Loss: -14.565049
#
# Train set: Average log loss: -14.6228
#
#
# Test set: Average loss: -14.3346
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2927 [0/85187 (0%)]	log Loss: -14.565299
#
# Train set: Average log loss: -14.6229
#
#
# Test set: Average loss: -14.3348
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2928 [0/85187 (0%)]	log Loss: -14.565364
#
# Train set: Average log loss: -14.6230
#
#
# Test set: Average loss: -14.3347
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2929 [0/85187 (0%)]	log Loss: -14.565341
#
# Train set: Average log loss: -14.6231
#
#
# Test set: Average loss: -14.3348
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2930 [0/85187 (0%)]	log Loss: -14.565166
#
# Train set: Average log loss: -14.6233
#
#
# Test set: Average loss: -14.3348
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2931 [0/85187 (0%)]	log Loss: -14.565626
#
# Train set: Average log loss: -14.6233
#
#
# Test set: Average loss: -14.3349
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2932 [0/85187 (0%)]	log Loss: -14.565548
#
# Train set: Average log loss: -14.6233
#
#
# Test set: Average loss: -14.3348
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2933 [0/85187 (0%)]	log Loss: -14.565600
#
# Train set: Average log loss: -14.6233
#
#
# Test set: Average loss: -14.3351
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2934 [0/85187 (0%)]	log Loss: -14.565518
#
# Train set: Average log loss: -14.6235
#
#
# Test set: Average loss: -14.3349
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2935 [0/85187 (0%)]	log Loss: -14.565616
#
# Train set: Average log loss: -14.6235
#
#
# Test set: Average loss: -14.3352
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2936 [0/85187 (0%)]	log Loss: -14.565485
#
# Train set: Average log loss: -14.6235
#
#
# Test set: Average loss: -14.3352
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2937 [0/85187 (0%)]	log Loss: -14.565721
#
# Train set: Average log loss: -14.6236
#
#
# Test set: Average loss: -14.3351
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2938 [0/85187 (0%)]	log Loss: -14.565745
#
# Train set: Average log loss: -14.6238
#
#
# Test set: Average loss: -14.3352
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2939 [0/85187 (0%)]	log Loss: -14.565870
#
# Train set: Average log loss: -14.6238
#
#
# Test set: Average loss: -14.3354
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2940 [0/85187 (0%)]	log Loss: -14.566027
#
# Train set: Average log loss: -14.6238
#
#
# Test set: Average loss: -14.3354
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2941 [0/85187 (0%)]	log Loss: -14.566133
#
# Train set: Average log loss: -14.6240
#
#
# Test set: Average loss: -14.3354
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2942 [0/85187 (0%)]	log Loss: -14.566084
#
# Train set: Average log loss: -14.6240
#
#
# Test set: Average loss: -14.3353
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2943 [0/85187 (0%)]	log Loss: -14.566170
#
# Train set: Average log loss: -14.6241
#
#
# Test set: Average loss: -14.3356
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2944 [0/85187 (0%)]	log Loss: -14.566280
#
# Train set: Average log loss: -14.6241
#
#
# Test set: Average loss: -14.3355
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2945 [0/85187 (0%)]	log Loss: -14.566318
#
# Train set: Average log loss: -14.6243
#
#
# Test set: Average loss: -14.3355
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2946 [0/85187 (0%)]	log Loss: -14.566120
#
# Train set: Average log loss: -14.6243
#
#
# Test set: Average loss: -14.3356
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2947 [0/85187 (0%)]	log Loss: -14.566387
#
# Train set: Average log loss: -14.6242
#
#
# Test set: Average loss: -14.3357
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2948 [0/85187 (0%)]	log Loss: -14.566212
#
# Train set: Average log loss: -14.6245
#
#
# Test set: Average loss: -14.3359
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2949 [0/85187 (0%)]	log Loss: -14.566539
#
# Train set: Average log loss: -14.6243
#
#
# Test set: Average loss: -14.3358
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2950 [0/85187 (0%)]	log Loss: -14.566782
#
# Train set: Average log loss: -14.6245
#
#
# Test set: Average loss: -14.3358
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2951 [0/85187 (0%)]	log Loss: -14.566347
#
# Train set: Average log loss: -14.6247
#
#
# Test set: Average loss: -14.3359
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2952 [0/85187 (0%)]	log Loss: -14.566712
#
# Train set: Average log loss: -14.6247
#
#
# Test set: Average loss: -14.3361
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2953 [0/85187 (0%)]	log Loss: -14.566946
#
# Train set: Average log loss: -14.6248
#
#
# Test set: Average loss: -14.3359
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2954 [0/85187 (0%)]	log Loss: -14.566378
#
# Train set: Average log loss: -14.6249
#
#
# Test set: Average loss: -14.3361
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2955 [0/85187 (0%)]	log Loss: -14.567088
#
# Train set: Average log loss: -14.6248
#
#
# Test set: Average loss: -14.3362
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2956 [0/85187 (0%)]	log Loss: -14.566947
#
# Train set: Average log loss: -14.6249
#
#
# Test set: Average loss: -14.3361
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2957 [0/85187 (0%)]	log Loss: -14.567120
#
# Train set: Average log loss: -14.6251
#
#
# Test set: Average loss: -14.3363
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2958 [0/85187 (0%)]	log Loss: -14.567088
#
# Train set: Average log loss: -14.6251
#
#
# Test set: Average loss: -14.3362
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2959 [0/85187 (0%)]	log Loss: -14.566986
#
# Train set: Average log loss: -14.6251
#
#
# Test set: Average loss: -14.3364
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2960 [0/85187 (0%)]	log Loss: -14.567040
#
# Train set: Average log loss: -14.6253
#
#
# Test set: Average loss: -14.3364
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2961 [0/85187 (0%)]	log Loss: -14.567266
#
# Train set: Average log loss: -14.6251
#
#
# Test set: Average loss: -14.3364
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2962 [0/85187 (0%)]	log Loss: -14.567350
#
# Train set: Average log loss: -14.6255
#
#
# Test set: Average loss: -14.3365
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2963 [0/85187 (0%)]	log Loss: -14.567391
#
# Train set: Average log loss: -14.6254
#
#
# Test set: Average loss: -14.3366
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2964 [0/85187 (0%)]	log Loss: -14.567383
#
# Train set: Average log loss: -14.6256
#
#
# Test set: Average loss: -14.3365
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2965 [0/85187 (0%)]	log Loss: -14.567379
#
# Train set: Average log loss: -14.6257
#
#
# Test set: Average loss: -14.3367
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2966 [0/85187 (0%)]	log Loss: -14.567640
#
# Train set: Average log loss: -14.6255
#
#
# Test set: Average loss: -14.3366
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2967 [0/85187 (0%)]	log Loss: -14.567397
#
# Train set: Average log loss: -14.6257
#
#
# Test set: Average loss: -14.3369
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2968 [0/85187 (0%)]	log Loss: -14.567827
#
# Train set: Average log loss: -14.6257
#
#
# Test set: Average loss: -14.3368
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2969 [0/85187 (0%)]	log Loss: -14.567625
#
# Train set: Average log loss: -14.6259
#
#
# Test set: Average loss: -14.3367
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2970 [0/85187 (0%)]	log Loss: -14.567779
#
# Train set: Average log loss: -14.6260
#
#
# Test set: Average loss: -14.3370
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2971 [0/85187 (0%)]	log Loss: -14.567897
#
# Train set: Average log loss: -14.6260
#
#
# Test set: Average loss: -14.3370
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2972 [0/85187 (0%)]	log Loss: -14.568071
#
# Train set: Average log loss: -14.6260
#
#
# Test set: Average loss: -14.3370
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2973 [0/85187 (0%)]	log Loss: -14.567948
#
# Train set: Average log loss: -14.6263
#
#
# Test set: Average loss: -14.3371
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2974 [0/85187 (0%)]	log Loss: -14.567859
#
# Train set: Average log loss: -14.6261
#
#
# Test set: Average loss: -14.3371
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2975 [0/85187 (0%)]	log Loss: -14.568122
#
# Train set: Average log loss: -14.6265
#
#
# Test set: Average loss: -14.3372
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2976 [0/85187 (0%)]	log Loss: -14.568221
#
# Train set: Average log loss: -14.6262
#
#
# Test set: Average loss: -14.3371
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2977 [0/85187 (0%)]	log Loss: -14.568200
#
# Train set: Average log loss: -14.6263
#
#
# Test set: Average loss: -14.3372
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2978 [0/85187 (0%)]	log Loss: -14.568572
#
# Train set: Average log loss: -14.6267
#
#
# Test set: Average loss: -14.3373
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2979 [0/85187 (0%)]	log Loss: -14.568153
#
# Train set: Average log loss: -14.6266
#
#
# Test set: Average loss: -14.3374
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2980 [0/85187 (0%)]	log Loss: -14.568485
#
# Train set: Average log loss: -14.6264
#
#
# Test set: Average loss: -14.3375
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2981 [0/85187 (0%)]	log Loss: -14.568490
#
# Train set: Average log loss: -14.6266
#
#
# Test set: Average loss: -14.3373
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2982 [0/85187 (0%)]	log Loss: -14.568506
#
# Train set: Average log loss: -14.6269
#
#
# Test set: Average loss: -14.3375
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2983 [0/85187 (0%)]	log Loss: -14.568587
#
# Train set: Average log loss: -14.6268
#
#
# Test set: Average loss: -14.3376
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2984 [0/85187 (0%)]	log Loss: -14.568935
#
# Train set: Average log loss: -14.6270
#
#
# Test set: Average loss: -14.3376
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2985 [0/85187 (0%)]	log Loss: -14.568686
#
# Train set: Average log loss: -14.6268
#
#
# Test set: Average loss: -14.3376
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2986 [0/85187 (0%)]	log Loss: -14.568993
#
# Train set: Average log loss: -14.6271
#
#
# Test set: Average loss: -14.3377
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2987 [0/85187 (0%)]	log Loss: -14.568959
#
# Train set: Average log loss: -14.6272
#
#
# Test set: Average loss: -14.3378
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2988 [0/85187 (0%)]	log Loss: -14.569118
#
# Train set: Average log loss: -14.6271
#
#
# Test set: Average loss: -14.3378
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2989 [0/85187 (0%)]	log Loss: -14.568981
#
# Train set: Average log loss: -14.6273
#
#
# Test set: Average loss: -14.3379
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2990 [0/85187 (0%)]	log Loss: -14.569265
#
# Train set: Average log loss: -14.6274
#
#
# Test set: Average loss: -14.3379
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2991 [0/85187 (0%)]	log Loss: -14.569216
#
# Train set: Average log loss: -14.6273
#
#
# Test set: Average loss: -14.3380
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2992 [0/85187 (0%)]	log Loss: -14.569416
#
# Train set: Average log loss: -14.6274
#
#
# Test set: Average loss: -14.3381
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2993 [0/85187 (0%)]	log Loss: -14.569455
#
# Train set: Average log loss: -14.6275
#
#
# Test set: Average loss: -14.3381
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2994 [0/85187 (0%)]	log Loss: -14.569301
#
# Train set: Average log loss: -14.6274
#
#
# Test set: Average loss: -14.3382
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2995 [0/85187 (0%)]	log Loss: -14.569385
#
# Train set: Average log loss: -14.6275
#
#
# Test set: Average loss: -14.3381
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2996 [0/85187 (0%)]	log Loss: -14.569593
#
# Train set: Average log loss: -14.6278
#
#
# Test set: Average loss: -14.3383
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2997 [0/85187 (0%)]	log Loss: -14.569923
#
# Train set: Average log loss: -14.6278
#
#
# Test set: Average loss: -14.3383
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2998 [0/85187 (0%)]	log Loss: -14.569632
#
# Train set: Average log loss: -14.6280
#
#
# Test set: Average loss: -14.3384
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2999 [0/85187 (0%)]	log Loss: -14.569706
#
# Train set: Average log loss: -14.6280
#
#
# Test set: Average loss: -14.3384
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 3000 [0/85187 (0%)]	log Loss: -14.569808
#
# Train set: Average log loss: -14.6281
#
#
# Test set: Average loss: -14.3385
#
# Current Learning rate 1.0000000000000002e-06

# %%
# Loading model from saved weights
device = torch.device("cuda")
loaded_IV_ANN = IV_ANN().to(device)
PATH = "ANN_weights/IV_SCALED_ANN.pt"
loaded_IV_ANN.load_state_dict(torch.load(PATH))
loaded_IV_ANN.eval()
# Out:
# IV_ANN(
#   (fc1): Linear(in_features=4, out_features=400, bias=True)
#   (fc2): Linear(in_features=400, out_features=400, bias=True)
#   (fc3): Linear(in_features=400, out_features=400, bias=True)
#   (fc4): Linear(in_features=400, out_features=400, bias=True)
#   (fc5): Linear(in_features=400, out_features=1, bias=True)
# )

# %%
# Plotting erros histogram
errors = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_IV_ANN(data)
    errors.append((target-output).data.cpu().numpy())
  errors = np.concatenate(errors)
plt.figure(figsize=(10,7))
plt.hist(errors,100,fill=False)
plt.grid()
plt.xlabel("Difference")
plt.ylabel("Density")
plt.xlim([-0.005, 0.005])
plt.show()
print("MAX ",errors.max())
print("MIN ",errors.min())
# Out:
# MAX  0.005511403
# MIN  -0.0050005317

# %%
# Printing train and test MSE, MAE, MAPE and R2
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_IV_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_IV_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Train scores----------------
# MSE 6.137644e-07
# MAE 5.638418e-04
# MAPE 1.528163e-03
# R2 9.999912e-01
# -----------Test scores----------------
# MSE 5.863549e-07
# MAE 5.648760e-04
# MAPE 1.545854e-03
# R2 9.999915e-01

# %% [markdown]
# ### Training IV-ANN without log transofmation

# %%
# Training parameters
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}



use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# torch.manual_seed(args["seed"])


# Train / Test Data
bs_dataset = IV_LHS_data_generator(n = 10**5, log_scale = False)
train_size, test_size = int(bs_dataset.shape[0]*0.9), int(bs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(bs_dataset, [train_size, bs_dataset.shape[0]-train_size])

train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])


# Model training
print(device)
model = BS_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=args["lr"]) # Adam is found to be the best optimizer in the article
scheduler = StepLR(optimizer, step_size=10**3, gamma=args["gamma"]) # Deacreses the Learning rate by .1 every 1000 epoch

train_losses = []
test_losses = []
for epoch in range(1, args["epochs"] + 1):
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
if args["save_model"] :
  torch.save(model.state_dict(), "IV_UNSCALED_ANN.pt")
# Out:
# ------ INPUT ------
# S/K.......... [0.50 1.40]
# Tau.......... [0.05 1.00]
# r............ [0.00 0.10]
# V/K.......... [0.00 0.69]
# ------ OUTPUT ------
# Sigma........ [0.05 1.00]
# cuda
# Train Epoch: 1 [0/90000 (0%)]	log Loss: -0.959341
#
# Train set: Average log loss: -2.4540
#
#
# Test set: Average loss: -2.6480
#
# Current Learning rate 0.0001
# Train Epoch: 2 [0/90000 (0%)]	log Loss: -2.619602
#
# Train set: Average log loss: -2.7389
#
#
# Test set: Average loss: -2.9221
#
# Current Learning rate 0.0001
# Train Epoch: 3 [0/90000 (0%)]	log Loss: -2.905974
#
# Train set: Average log loss: -3.2516
#
#
# Test set: Average loss: -3.6121
#
# Current Learning rate 0.0001
# Train Epoch: 4 [0/90000 (0%)]	log Loss: -3.637082
#
# Train set: Average log loss: -3.8467
#
#
# Test set: Average loss: -4.0643
#
# Current Learning rate 0.0001
# Train Epoch: 5 [0/90000 (0%)]	log Loss: -4.068975
#
# Train set: Average log loss: -4.2036
#
#
# Test set: Average loss: -4.3170
#
# Current Learning rate 0.0001
# Train Epoch: 6 [0/90000 (0%)]	log Loss: -4.306699
#
# Train set: Average log loss: -4.3957
#
#
# Test set: Average loss: -4.4977
#
# Current Learning rate 0.0001
# Train Epoch: 7 [0/90000 (0%)]	log Loss: -4.486617
#
# Train set: Average log loss: -4.5248
#
#
# Test set: Average loss: -4.6151
#
# Current Learning rate 0.0001
# Train Epoch: 8 [0/90000 (0%)]	log Loss: -4.597694
#
# Train set: Average log loss: -4.6302
#
#
# Test set: Average loss: -4.7198
#
# Current Learning rate 0.0001
# Train Epoch: 9 [0/90000 (0%)]	log Loss: -4.703101
#
# Train set: Average log loss: -4.7144
#
#
# Test set: Average loss: -4.7878
#
# Current Learning rate 0.0001
# Train Epoch: 10 [0/90000 (0%)]	log Loss: -4.773206
#
# Train set: Average log loss: -4.7846
#
#
# Test set: Average loss: -4.8495
#
# Current Learning rate 0.0001
# Train Epoch: 11 [0/90000 (0%)]	log Loss: -4.836886
#
# Train set: Average log loss: -4.8497
#
#
# Test set: Average loss: -4.9226
#
# Current Learning rate 0.0001
# Train Epoch: 12 [0/90000 (0%)]	log Loss: -4.910385
#
# Train set: Average log loss: -4.9121
#
#
# Test set: Average loss: -4.9836
#
# Current Learning rate 0.0001
# Train Epoch: 13 [0/90000 (0%)]	log Loss: -4.973074
#
# Train set: Average log loss: -4.9661
#
#
# Test set: Average loss: -5.0395
#
# Current Learning rate 0.0001
# Train Epoch: 14 [0/90000 (0%)]	log Loss: -5.029745
#
# Train set: Average log loss: -5.0162
#
#
# Test set: Average loss: -5.0941
#
# Current Learning rate 0.0001
# Train Epoch: 15 [0/90000 (0%)]	log Loss: -5.085849
#
# Train set: Average log loss: -5.0607
#
#
# Test set: Average loss: -5.1388
#
# Current Learning rate 0.0001
# Train Epoch: 16 [0/90000 (0%)]	log Loss: -5.132097
#
# Train set: Average log loss: -5.1023
#
#
# Test set: Average loss: -5.1891
#
# Current Learning rate 0.0001
# Train Epoch: 17 [0/90000 (0%)]	log Loss: -5.182646
#
# Train set: Average log loss: -5.1423
#
#
# Test set: Average loss: -5.2316
#
# Current Learning rate 0.0001
# Train Epoch: 18 [0/90000 (0%)]	log Loss: -5.225812
#
# Train set: Average log loss: -5.1768
#
#
# Test set: Average loss: -5.2727
#
# Current Learning rate 0.0001
# Train Epoch: 19 [0/90000 (0%)]	log Loss: -5.267879
#
# Train set: Average log loss: -5.2101
#
#
# Test set: Average loss: -5.3103
#
# Current Learning rate 0.0001
# Train Epoch: 20 [0/90000 (0%)]	log Loss: -5.307448
#
# Train set: Average log loss: -5.2411
#
#
# Test set: Average loss: -5.3452
#
# Current Learning rate 0.0001
# Train Epoch: 21 [0/90000 (0%)]	log Loss: -5.342865
#
# Train set: Average log loss: -5.2698
#
#
# Test set: Average loss: -5.3784
#
# Current Learning rate 0.0001
# Train Epoch: 22 [0/90000 (0%)]	log Loss: -5.377353
#
# Train set: Average log loss: -5.2976
#
#
# Test set: Average loss: -5.4095
#
# Current Learning rate 0.0001
# Train Epoch: 23 [0/90000 (0%)]	log Loss: -5.409942
#
# Train set: Average log loss: -5.3235
#
#
# Test set: Average loss: -5.4402
#
# Current Learning rate 0.0001
# Train Epoch: 24 [0/90000 (0%)]	log Loss: -5.441042
#
# Train set: Average log loss: -5.3482
#
#
# Test set: Average loss: -5.4689
#
# Current Learning rate 0.0001
# Train Epoch: 25 [0/90000 (0%)]	log Loss: -5.471710
#
# Train set: Average log loss: -5.3735
#
#
# Test set: Average loss: -5.4977
#
# Current Learning rate 0.0001
# Train Epoch: 26 [0/90000 (0%)]	log Loss: -5.502309
#
# Train set: Average log loss: -5.3973
#
#
# Test set: Average loss: -5.5182
#
# Current Learning rate 0.0001
# Train Epoch: 27 [0/90000 (0%)]	log Loss: -5.524898
#
# Train set: Average log loss: -5.4163
#
#
# Test set: Average loss: -5.5452
#
# Current Learning rate 0.0001
# Train Epoch: 28 [0/90000 (0%)]	log Loss: -5.554352
#
# Train set: Average log loss: -5.4378
#
#
# Test set: Average loss: -5.5696
#
# Current Learning rate 0.0001
# Train Epoch: 29 [0/90000 (0%)]	log Loss: -5.579535
#
# Train set: Average log loss: -5.4575
#
#
# Test set: Average loss: -5.5900
#
# Current Learning rate 0.0001
# Train Epoch: 30 [0/90000 (0%)]	log Loss: -5.601182
#
# Train set: Average log loss: -5.4759
#
#
# Test set: Average loss: -5.6140
#
# Current Learning rate 0.0001
# Train Epoch: 31 [0/90000 (0%)]	log Loss: -5.624948
#
# Train set: Average log loss: -5.4934
#
#
# Test set: Average loss: -5.6354
#
# Current Learning rate 0.0001
# Train Epoch: 32 [0/90000 (0%)]	log Loss: -5.646119
#
# Train set: Average log loss: -5.5097
#
#
# Test set: Average loss: -5.6602
#
# Current Learning rate 0.0001
# Train Epoch: 33 [0/90000 (0%)]	log Loss: -5.670963
#
# Train set: Average log loss: -5.5270
#
#
# Test set: Average loss: -5.6806
#
# Current Learning rate 0.0001
# Train Epoch: 34 [0/90000 (0%)]	log Loss: -5.691624
#
# Train set: Average log loss: -5.5441
#
#
# Test set: Average loss: -5.6970
#
# Current Learning rate 0.0001
# Train Epoch: 35 [0/90000 (0%)]	log Loss: -5.707034
#
# Train set: Average log loss: -5.5585
#
#
# Test set: Average loss: -5.7141
#
# Current Learning rate 0.0001
# Train Epoch: 36 [0/90000 (0%)]	log Loss: -5.723221
#
# Train set: Average log loss: -5.5731
#
#
# Test set: Average loss: -5.7319
#
# Current Learning rate 0.0001
# Train Epoch: 37 [0/90000 (0%)]	log Loss: -5.740040
#
# Train set: Average log loss: -5.5872
#
#
# Test set: Average loss: -5.7487
#
# Current Learning rate 0.0001
# Train Epoch: 38 [0/90000 (0%)]	log Loss: -5.756881
#
# Train set: Average log loss: -5.6010
#
#
# Test set: Average loss: -5.7653
#
# Current Learning rate 0.0001
# Train Epoch: 39 [0/90000 (0%)]	log Loss: -5.773520
#
# Train set: Average log loss: -5.6131
#
#
# Test set: Average loss: -5.7835
#
# Current Learning rate 0.0001
# Train Epoch: 40 [0/90000 (0%)]	log Loss: -5.790849
#
# Train set: Average log loss: -5.6265
#
#
# Test set: Average loss: -5.8019
#
# Current Learning rate 0.0001
# Train Epoch: 41 [0/90000 (0%)]	log Loss: -5.809025
#
# Train set: Average log loss: -5.6402
#
#
# Test set: Average loss: -5.8176
#
# Current Learning rate 0.0001
# Train Epoch: 42 [0/90000 (0%)]	log Loss: -5.824645
#
# Train set: Average log loss: -5.6520
#
#
# Test set: Average loss: -5.8321
#
# Current Learning rate 0.0001
# Train Epoch: 43 [0/90000 (0%)]	log Loss: -5.839943
#
# Train set: Average log loss: -5.6656
#
#
# Test set: Average loss: -5.8423
#
# Current Learning rate 0.0001
# Train Epoch: 44 [0/90000 (0%)]	log Loss: -5.851761
#
# Train set: Average log loss: -5.6754
#
#
# Test set: Average loss: -5.8565
#
# Current Learning rate 0.0001
# Train Epoch: 45 [0/90000 (0%)]	log Loss: -5.866449
#
# Train set: Average log loss: -5.6866
#
#
# Test set: Average loss: -5.8689
#
# Current Learning rate 0.0001
# Train Epoch: 46 [0/90000 (0%)]	log Loss: -5.881691
#
# Train set: Average log loss: -5.6983
#
#
# Test set: Average loss: -5.8798
#
# Current Learning rate 0.0001
# Train Epoch: 47 [0/90000 (0%)]	log Loss: -5.892926
#
# Train set: Average log loss: -5.7068
#
#
# Test set: Average loss: -5.8956
#
# Current Learning rate 0.0001
# Train Epoch: 48 [0/90000 (0%)]	log Loss: -5.910055
#
# Train set: Average log loss: -5.7185
#
#
# Test set: Average loss: -5.9065
#
# Current Learning rate 0.0001
# Train Epoch: 49 [0/90000 (0%)]	log Loss: -5.921652
#
# Train set: Average log loss: -5.7265
#
#
# Test set: Average loss: -5.9186
#
# Current Learning rate 0.0001
# Train Epoch: 50 [0/90000 (0%)]	log Loss: -5.934073
#
# Train set: Average log loss: -5.7344
#
#
# Test set: Average loss: -5.9310
#
# Current Learning rate 0.0001
# Train Epoch: 51 [0/90000 (0%)]	log Loss: -5.947714
#
# Train set: Average log loss: -5.7445
#
#
# Test set: Average loss: -5.9424
#
# Current Learning rate 0.0001
# Train Epoch: 52 [0/90000 (0%)]	log Loss: -5.960486
#
# Train set: Average log loss: -5.7546
#
#
# Test set: Average loss: -5.9538
#
# Current Learning rate 0.0001
# Train Epoch: 53 [0/90000 (0%)]	log Loss: -5.970670
#
# Train set: Average log loss: -5.7632
#
#
# Test set: Average loss: -5.9647
#
# Current Learning rate 0.0001
# Train Epoch: 54 [0/90000 (0%)]	log Loss: -5.980512
#
# Train set: Average log loss: -5.7706
#
#
# Test set: Average loss: -5.9765
#
# Current Learning rate 0.0001
# Train Epoch: 55 [0/90000 (0%)]	log Loss: -5.994972
#
# Train set: Average log loss: -5.7775
#
#
# Test set: Average loss: -5.9893
#
# Current Learning rate 0.0001
# Train Epoch: 56 [0/90000 (0%)]	log Loss: -6.005096
#
# Train set: Average log loss: -5.7899
#
#
# Test set: Average loss: -5.9937
#
# Current Learning rate 0.0001
# Train Epoch: 57 [0/90000 (0%)]	log Loss: -6.015488
#
# Train set: Average log loss: -5.7917
#
#
# Test set: Average loss: -6.0069
#
# Current Learning rate 0.0001
# Train Epoch: 58 [0/90000 (0%)]	log Loss: -6.028875
#
# Train set: Average log loss: -5.8027
#
#
# Test set: Average loss: -6.0153
#
# Current Learning rate 0.0001
# Train Epoch: 59 [0/90000 (0%)]	log Loss: -6.036208
#
# Train set: Average log loss: -5.8091
#
#
# Test set: Average loss: -6.0241
#
# Current Learning rate 0.0001
# Train Epoch: 60 [0/90000 (0%)]	log Loss: -6.047754
#
# Train set: Average log loss: -5.8157
#
#
# Test set: Average loss: -6.0328
#
# Current Learning rate 0.0001
# Train Epoch: 61 [0/90000 (0%)]	log Loss: -6.056789
#
# Train set: Average log loss: -5.8239
#
#
# Test set: Average loss: -6.0400
#
# Current Learning rate 0.0001
# Train Epoch: 62 [0/90000 (0%)]	log Loss: -6.066261
#
# Train set: Average log loss: -5.8324
#
#
# Test set: Average loss: -6.0473
#
# Current Learning rate 0.0001
# Train Epoch: 63 [0/90000 (0%)]	log Loss: -6.074071
#
# Train set: Average log loss: -5.8412
#
#
# Test set: Average loss: -6.0555
#
# Current Learning rate 0.0001
# Train Epoch: 64 [0/90000 (0%)]	log Loss: -6.083948
#
# Train set: Average log loss: -5.8477
#
#
# Test set: Average loss: -6.0640
#
# Current Learning rate 0.0001
# Train Epoch: 65 [0/90000 (0%)]	log Loss: -6.093721
#
# Train set: Average log loss: -5.8515
#
#
# Test set: Average loss: -6.0696
#
# Current Learning rate 0.0001
# Train Epoch: 66 [0/90000 (0%)]	log Loss: -6.098595
#
# Train set: Average log loss: -5.8628
#
#
# Test set: Average loss: -6.0778
#
# Current Learning rate 0.0001
# Train Epoch: 67 [0/90000 (0%)]	log Loss: -6.108197
#
# Train set: Average log loss: -5.8648
#
#
# Test set: Average loss: -6.0832
#
# Current Learning rate 0.0001
# Train Epoch: 68 [0/90000 (0%)]	log Loss: -6.113947
#
# Train set: Average log loss: -5.8718
#
#
# Test set: Average loss: -6.0892
#
# Current Learning rate 0.0001
# Train Epoch: 69 [0/90000 (0%)]	log Loss: -6.118698
#
# Train set: Average log loss: -5.8796
#
#
# Test set: Average loss: -6.0957
#
# Current Learning rate 0.0001
# Train Epoch: 70 [0/90000 (0%)]	log Loss: -6.122814
#
# Train set: Average log loss: -5.8842
#
#
# Test set: Average loss: -6.1024
#
# Current Learning rate 0.0001
# Train Epoch: 71 [0/90000 (0%)]	log Loss: -6.131050
#
# Train set: Average log loss: -5.8903
#
#
# Test set: Average loss: -6.1092
#
# Current Learning rate 0.0001
# Train Epoch: 72 [0/90000 (0%)]	log Loss: -6.138408
#
# Train set: Average log loss: -5.8887
#
#
# Test set: Average loss: -6.1095
#
# Current Learning rate 0.0001
# Train Epoch: 73 [0/90000 (0%)]	log Loss: -6.135500
#
# Train set: Average log loss: -5.9017
#
#
# Test set: Average loss: -6.1202
#
# Current Learning rate 0.0001
# Train Epoch: 74 [0/90000 (0%)]	log Loss: -6.145865
#
# Train set: Average log loss: -5.9044
#
#
# Test set: Average loss: -6.1254
#
# Current Learning rate 0.0001
# Train Epoch: 75 [0/90000 (0%)]	log Loss: -6.150304
#
# Train set: Average log loss: -5.9088
#
#
# Test set: Average loss: -6.1272
#
# Current Learning rate 0.0001
# Train Epoch: 76 [0/90000 (0%)]	log Loss: -6.151940
#
# Train set: Average log loss: -5.9151
#
#
# Test set: Average loss: -6.1287
#
# Current Learning rate 0.0001
# Train Epoch: 77 [0/90000 (0%)]	log Loss: -6.152846
#
# Train set: Average log loss: -5.9229
#
#
# Test set: Average loss: -6.1359
#
# Current Learning rate 0.0001
# Train Epoch: 78 [0/90000 (0%)]	log Loss: -6.157961
#
# Train set: Average log loss: -5.9269
#
#
# Test set: Average loss: -6.1408
#
# Current Learning rate 0.0001
# Train Epoch: 79 [0/90000 (0%)]	log Loss: -6.162108
#
# Train set: Average log loss: -5.9281
#
#
# Test set: Average loss: -6.1407
#
# Current Learning rate 0.0001
# Train Epoch: 80 [0/90000 (0%)]	log Loss: -6.162734
#
# Train set: Average log loss: -5.9351
#
#
# Test set: Average loss: -6.1427
#
# Current Learning rate 0.0001
# Train Epoch: 81 [0/90000 (0%)]	log Loss: -6.163732
#
# Train set: Average log loss: -5.9406
#
#
# Test set: Average loss: -6.1442
#
# Current Learning rate 0.0001
# Train Epoch: 82 [0/90000 (0%)]	log Loss: -6.165025
#
# Train set: Average log loss: -5.9502
#
#
# Test set: Average loss: -6.1543
#
# Current Learning rate 0.0001
# Train Epoch: 83 [0/90000 (0%)]	log Loss: -6.173533
#
# Train set: Average log loss: -5.9534
#
#
# Test set: Average loss: -6.1586
#
# Current Learning rate 0.0001
# Train Epoch: 84 [0/90000 (0%)]	log Loss: -6.176299
#
# Train set: Average log loss: -5.9598
#
#
# Test set: Average loss: -6.1717
#
# Current Learning rate 0.0001
# Train Epoch: 85 [0/90000 (0%)]	log Loss: -6.189284
#
# Train set: Average log loss: -5.9580
#
#
# Test set: Average loss: -6.1660
#
# Current Learning rate 0.0001
# Train Epoch: 86 [0/90000 (0%)]	log Loss: -6.184366
#
# Train set: Average log loss: -5.9659
#
#
# Test set: Average loss: -6.1726
#
# Current Learning rate 0.0001
# Train Epoch: 87 [0/90000 (0%)]	log Loss: -6.191516
#
# Train set: Average log loss: -5.9686
#
#
# Test set: Average loss: -6.1710
#
# Current Learning rate 0.0001
# Train Epoch: 88 [0/90000 (0%)]	log Loss: -6.187803
#
# Train set: Average log loss: -5.9725
#
#
# Test set: Average loss: -6.1692
#
# Current Learning rate 0.0001
# Train Epoch: 89 [0/90000 (0%)]	log Loss: -6.186299
#
# Train set: Average log loss: -5.9762
#
#
# Test set: Average loss: -6.1633
#
# Current Learning rate 0.0001
# Train Epoch: 90 [0/90000 (0%)]	log Loss: -6.178375
#
# Train set: Average log loss: -5.9817
#
#
# Test set: Average loss: -6.1703
#
# Current Learning rate 0.0001
# Train Epoch: 91 [0/90000 (0%)]	log Loss: -6.184724
#
# Train set: Average log loss: -5.9821
#
#
# Test set: Average loss: -6.1533
#
# Current Learning rate 0.0001
# Train Epoch: 92 [0/90000 (0%)]	log Loss: -6.170610
#
# Train set: Average log loss: -5.9892
#
#
# Test set: Average loss: -6.1611
#
# Current Learning rate 0.0001
# Train Epoch: 93 [0/90000 (0%)]	log Loss: -6.177462
#
# Train set: Average log loss: -5.9924
#
#
# Test set: Average loss: -6.1605
#
# Current Learning rate 0.0001
# Train Epoch: 94 [0/90000 (0%)]	log Loss: -6.174715
#
# Train set: Average log loss: -5.9954
#
#
# Test set: Average loss: -6.1164
#
# Current Learning rate 0.0001
# Train Epoch: 95 [0/90000 (0%)]	log Loss: -6.132526
#
# Train set: Average log loss: -5.9983
#
#
# Test set: Average loss: -6.1425
#
# Current Learning rate 0.0001
# Train Epoch: 96 [0/90000 (0%)]	log Loss: -6.157048
#
# Train set: Average log loss: -6.0012
#
#
# Test set: Average loss: -6.1388
#
# Current Learning rate 0.0001
# Train Epoch: 97 [0/90000 (0%)]	log Loss: -6.154391
#
# Train set: Average log loss: -6.0072
#
#
# Test set: Average loss: -6.1394
#
# Current Learning rate 0.0001
# Train Epoch: 98 [0/90000 (0%)]	log Loss: -6.152931
#
# Train set: Average log loss: -6.0086
#
#
# Test set: Average loss: -6.1069
#
# Current Learning rate 0.0001
# Train Epoch: 99 [0/90000 (0%)]	log Loss: -6.124070
#
# Train set: Average log loss: -6.0111
#
#
# Test set: Average loss: -6.1030
#
# Current Learning rate 0.0001
# Train Epoch: 100 [0/90000 (0%)]	log Loss: -6.117733
#
# Train set: Average log loss: -6.0180
#
#
# Test set: Average loss: -6.0766
#
# Current Learning rate 0.0001
# Train Epoch: 101 [0/90000 (0%)]	log Loss: -6.092504
#
# Train set: Average log loss: -6.0197
#
#
# Test set: Average loss: -6.0930
#
# Current Learning rate 0.0001
# Train Epoch: 102 [0/90000 (0%)]	log Loss: -6.107993
#
# Train set: Average log loss: -6.0265
#
#
# Test set: Average loss: -6.0808
#
# Current Learning rate 0.0001
# Train Epoch: 103 [0/90000 (0%)]	log Loss: -6.096157
#
# Train set: Average log loss: -6.0283
#
#
# Test set: Average loss: -6.0696
#
# Current Learning rate 0.0001
# Train Epoch: 104 [0/90000 (0%)]	log Loss: -6.086777
#
# Train set: Average log loss: -6.0280
#
#
# Test set: Average loss: -6.0726
#
# Current Learning rate 0.0001
# Train Epoch: 105 [0/90000 (0%)]	log Loss: -6.088522
#
# Train set: Average log loss: -6.0356
#
#
# Test set: Average loss: -6.0698
#
# Current Learning rate 0.0001
# Train Epoch: 106 [0/90000 (0%)]	log Loss: -6.087264
#
# Train set: Average log loss: -6.0349
#
#
# Test set: Average loss: -6.0563
#
# Current Learning rate 0.0001
# Train Epoch: 107 [0/90000 (0%)]	log Loss: -6.072609
#
# Train set: Average log loss: -6.0424
#
#
# Test set: Average loss: -6.0715
#
# Current Learning rate 0.0001
# Train Epoch: 108 [0/90000 (0%)]	log Loss: -6.087461
#
# Train set: Average log loss: -6.0446
#
#
# Test set: Average loss: -6.0556
#
# Current Learning rate 0.0001
# Train Epoch: 109 [0/90000 (0%)]	log Loss: -6.073477
#
# Train set: Average log loss: -6.0445
#
#
# Test set: Average loss: -6.0592
#
# Current Learning rate 0.0001
# Train Epoch: 110 [0/90000 (0%)]	log Loss: -6.074562
#
# Train set: Average log loss: -6.0511
#
#
# Test set: Average loss: -6.0611
#
# Current Learning rate 0.0001
# Train Epoch: 111 [0/90000 (0%)]	log Loss: -6.077067
#
# Train set: Average log loss: -6.0530
#
#
# Test set: Average loss: -6.0598
#
# Current Learning rate 0.0001
# Train Epoch: 112 [0/90000 (0%)]	log Loss: -6.075739
#
# Train set: Average log loss: -6.0569
#
#
# Test set: Average loss: -6.0531
#
# Current Learning rate 0.0001
# Train Epoch: 113 [0/90000 (0%)]	log Loss: -6.069579
#
# Train set: Average log loss: -6.0594
#
#
# Test set: Average loss: -6.0562
#
# Current Learning rate 0.0001
# Train Epoch: 114 [0/90000 (0%)]	log Loss: -6.071885
#
# Train set: Average log loss: -6.0627
#
#
# Test set: Average loss: -6.0516
#
# Current Learning rate 0.0001
# Train Epoch: 115 [0/90000 (0%)]	log Loss: -6.068729
#
# Train set: Average log loss: -6.0665
#
#
# Test set: Average loss: -6.0574
#
# Current Learning rate 0.0001
# Train Epoch: 116 [0/90000 (0%)]	log Loss: -6.075033
#
# Train set: Average log loss: -6.0701
#
#
# Test set: Average loss: -6.0430
#
# Current Learning rate 0.0001
# Train Epoch: 117 [0/90000 (0%)]	log Loss: -6.063115
#
# Train set: Average log loss: -6.0728
#
#
# Test set: Average loss: -6.0344
#
# Current Learning rate 0.0001
# Train Epoch: 118 [0/90000 (0%)]	log Loss: -6.054379
#
# Train set: Average log loss: -6.0749
#
#
# Test set: Average loss: -6.0394
#
# Current Learning rate 0.0001
# Train Epoch: 119 [0/90000 (0%)]	log Loss: -6.059266
#
# Train set: Average log loss: -6.0769
#
#
# Test set: Average loss: -6.0441
#
# Current Learning rate 0.0001
# Train Epoch: 120 [0/90000 (0%)]	log Loss: -6.063551
#
# Train set: Average log loss: -6.0837
#
#
# Test set: Average loss: -6.0449
#
# Current Learning rate 0.0001
# Train Epoch: 121 [0/90000 (0%)]	log Loss: -6.066595
#
# Train set: Average log loss: -6.0854
#
#
# Test set: Average loss: -6.0447
#
# Current Learning rate 0.0001
# Train Epoch: 122 [0/90000 (0%)]	log Loss: -6.068606
#
# Train set: Average log loss: -6.0882
#
#
# Test set: Average loss: -6.0482
#
# Current Learning rate 0.0001
# Train Epoch: 123 [0/90000 (0%)]	log Loss: -6.072067
#
# Train set: Average log loss: -6.0911
#
#
# Test set: Average loss: -6.0498
#
# Current Learning rate 0.0001
# Train Epoch: 124 [0/90000 (0%)]	log Loss: -6.075848
#
# Train set: Average log loss: -6.0928
#
#
# Test set: Average loss: -6.0362
#
# Current Learning rate 0.0001
# Train Epoch: 125 [0/90000 (0%)]	log Loss: -6.062529
#
# Train set: Average log loss: -6.1002
#
#
# Test set: Average loss: -6.0324
#
# Current Learning rate 0.0001
# Train Epoch: 126 [0/90000 (0%)]	log Loss: -6.055977
#
# Train set: Average log loss: -6.0928
#
#
# Test set: Average loss: -6.0233
#
# Current Learning rate 0.0001
# Train Epoch: 127 [0/90000 (0%)]	log Loss: -6.045103
#
# Train set: Average log loss: -6.1058
#
#
# Test set: Average loss: -6.0467
#
# Current Learning rate 0.0001
# Train Epoch: 128 [0/90000 (0%)]	log Loss: -6.068735
#
# Train set: Average log loss: -6.1016
#
#
# Test set: Average loss: -6.0174
#
# Current Learning rate 0.0001
# Train Epoch: 129 [0/90000 (0%)]	log Loss: -6.039652
#
# Train set: Average log loss: -6.1086
#
#
# Test set: Average loss: -6.0223
#
# Current Learning rate 0.0001
# Train Epoch: 130 [0/90000 (0%)]	log Loss: -6.045306
#
# Train set: Average log loss: -6.1068
#
#
# Test set: Average loss: -6.0264
#
# Current Learning rate 0.0001
# Train Epoch: 131 [0/90000 (0%)]	log Loss: -6.046506
#
# Train set: Average log loss: -6.1094
#
#
# Test set: Average loss: -6.0094
#
# Current Learning rate 0.0001
# Train Epoch: 132 [0/90000 (0%)]	log Loss: -6.035779
#
# Train set: Average log loss: -6.1169
#
#
# Test set: Average loss: -6.0395
#
# Current Learning rate 0.0001
# Train Epoch: 133 [0/90000 (0%)]	log Loss: -6.061972
#
# Train set: Average log loss: -6.1160
#
#
# Test set: Average loss: -6.0326
#
# Current Learning rate 0.0001
# Train Epoch: 134 [0/90000 (0%)]	log Loss: -6.056033
#
# Train set: Average log loss: -6.1155
#
#
# Test set: Average loss: -6.0170
#
# Current Learning rate 0.0001
# Train Epoch: 135 [0/90000 (0%)]	log Loss: -6.043500
#
# Train set: Average log loss: -6.1202
#
#
# Test set: Average loss: -6.0032
#
# Current Learning rate 0.0001
# Train Epoch: 136 [0/90000 (0%)]	log Loss: -6.032089
#
# Train set: Average log loss: -6.1187
#
#
# Test set: Average loss: -6.0045
#
# Current Learning rate 0.0001
# Train Epoch: 137 [0/90000 (0%)]	log Loss: -6.030438
#
# Train set: Average log loss: -6.1189
#
#
# Test set: Average loss: -6.0037
#
# Current Learning rate 0.0001
# Train Epoch: 138 [0/90000 (0%)]	log Loss: -6.030994
#
# Train set: Average log loss: -6.1229
#
#
# Test set: Average loss: -5.9938
#
# Current Learning rate 0.0001
# Train Epoch: 139 [0/90000 (0%)]	log Loss: -6.026389
#
# Train set: Average log loss: -6.1323
#
#
# Test set: Average loss: -6.0089
#
# Current Learning rate 0.0001
# Train Epoch: 140 [0/90000 (0%)]	log Loss: -6.039516
#
# Train set: Average log loss: -6.1316
#
#
# Test set: Average loss: -5.9984
#
# Current Learning rate 0.0001
# Train Epoch: 141 [0/90000 (0%)]	log Loss: -6.027958
#
# Train set: Average log loss: -6.1264
#
#
# Test set: Average loss: -5.9987
#
# Current Learning rate 0.0001
# Train Epoch: 142 [0/90000 (0%)]	log Loss: -6.030136
#
# Train set: Average log loss: -6.1341
#
#
# Test set: Average loss: -5.9911
#
# Current Learning rate 0.0001
# Train Epoch: 143 [0/90000 (0%)]	log Loss: -6.021325
#
# Train set: Average log loss: -6.1359
#
#
# Test set: Average loss: -6.0190
#
# Current Learning rate 0.0001
# Train Epoch: 144 [0/90000 (0%)]	log Loss: -6.053649
#
# Train set: Average log loss: -6.1477
#
#
# Test set: Average loss: -6.0256
#
# Current Learning rate 0.0001
# Train Epoch: 145 [0/90000 (0%)]	log Loss: -6.061170
#
# Train set: Average log loss: -6.1512
#
#
# Test set: Average loss: -6.0207
#
# Current Learning rate 0.0001
# Train Epoch: 146 [0/90000 (0%)]	log Loss: -6.056540
#
# Train set: Average log loss: -6.1503
#
#
# Test set: Average loss: -6.0161
#
# Current Learning rate 0.0001
# Train Epoch: 147 [0/90000 (0%)]	log Loss: -6.049887
#
# Train set: Average log loss: -6.1500
#
#
# Test set: Average loss: -6.0240
#
# Current Learning rate 0.0001
# Train Epoch: 148 [0/90000 (0%)]	log Loss: -6.059804
#
# Train set: Average log loss: -6.1547
#
#
# Test set: Average loss: -6.0182
#
# Current Learning rate 0.0001
# Train Epoch: 149 [0/90000 (0%)]	log Loss: -6.055094
#
# Train set: Average log loss: -6.1536
#
#
# Test set: Average loss: -5.9889
#
# Current Learning rate 0.0001
# Train Epoch: 150 [0/90000 (0%)]	log Loss: -6.022730
#
# Train set: Average log loss: -6.1372
#
#
# Test set: Average loss: -6.0241
#
# Current Learning rate 0.0001
# Train Epoch: 151 [0/90000 (0%)]	log Loss: -6.056377
#
# Train set: Average log loss: -6.1590
#
#
# Test set: Average loss: -6.0057
#
# Current Learning rate 0.0001
# Train Epoch: 152 [0/90000 (0%)]	log Loss: -6.042843
#
# Train set: Average log loss: -6.1563
#
#
# Test set: Average loss: -6.0335
#
# Current Learning rate 0.0001
# Train Epoch: 153 [0/90000 (0%)]	log Loss: -6.070744
#
# Train set: Average log loss: -6.1675
#
#
# Test set: Average loss: -5.9975
#
# Current Learning rate 0.0001
# Train Epoch: 154 [0/90000 (0%)]	log Loss: -6.035806
#
# Train set: Average log loss: -6.1574
#
#
# Test set: Average loss: -5.9803
#
# Current Learning rate 0.0001
# Train Epoch: 155 [0/90000 (0%)]	log Loss: -6.014132
#
# Train set: Average log loss: -6.1559
#
#
# Test set: Average loss: -6.0859
#
# Current Learning rate 0.0001
# Train Epoch: 156 [0/90000 (0%)]	log Loss: -6.126153
#
# Train set: Average log loss: -6.1836
#
#
# Test set: Average loss: -6.0260
#
# Current Learning rate 0.0001
# Train Epoch: 157 [0/90000 (0%)]	log Loss: -6.067490
#
# Train set: Average log loss: -6.1721
#
#
# Test set: Average loss: -6.0206
#
# Current Learning rate 0.0001
# Train Epoch: 158 [0/90000 (0%)]	log Loss: -6.062024
#
# Train set: Average log loss: -6.1746
#
#
# Test set: Average loss: -6.0184
#
# Current Learning rate 0.0001
# Train Epoch: 159 [0/90000 (0%)]	log Loss: -6.062647
#
# Train set: Average log loss: -6.1734
#
#
# Test set: Average loss: -6.0044
#
# Current Learning rate 0.0001
# Train Epoch: 160 [0/90000 (0%)]	log Loss: -6.047558
#
# Train set: Average log loss: -6.1729
#
#
# Test set: Average loss: -6.0426
#
# Current Learning rate 0.0001
# Train Epoch: 161 [0/90000 (0%)]	log Loss: -6.087135
#
# Train set: Average log loss: -6.1832
#
#
# Test set: Average loss: -5.9483
#
# Current Learning rate 0.0001
# Train Epoch: 162 [0/90000 (0%)]	log Loss: -5.990295
#
# Train set: Average log loss: -6.1641
#
#
# Test set: Average loss: -6.0985
#
# Current Learning rate 0.0001
# Train Epoch: 163 [0/90000 (0%)]	log Loss: -6.145939
#
# Train set: Average log loss: -6.1972
#
#
# Test set: Average loss: -5.9914
#
# Current Learning rate 0.0001
# Train Epoch: 164 [0/90000 (0%)]	log Loss: -6.038187
#
# Train set: Average log loss: -6.1811
#
#
# Test set: Average loss: -6.0454
#
# Current Learning rate 0.0001
# Train Epoch: 165 [0/90000 (0%)]	log Loss: -6.095297
#
# Train set: Average log loss: -6.1925
#
#
# Test set: Average loss: -5.9676
#
# Current Learning rate 0.0001
# Train Epoch: 166 [0/90000 (0%)]	log Loss: -6.011933
#
# Train set: Average log loss: -6.1799
#
#
# Test set: Average loss: -6.1182
#
# Current Learning rate 0.0001
# Train Epoch: 167 [0/90000 (0%)]	log Loss: -6.161241
#
# Train set: Average log loss: -6.2056
#
#
# Test set: Average loss: -6.0353
#
# Current Learning rate 0.0001
# Train Epoch: 168 [0/90000 (0%)]	log Loss: -6.086612
#
# Train set: Average log loss: -6.1992
#
#
# Test set: Average loss: -6.0058
#
# Current Learning rate 0.0001
# Train Epoch: 169 [0/90000 (0%)]	log Loss: -6.056208
#
# Train set: Average log loss: -6.1939
#
#
# Test set: Average loss: -6.0370
#
# Current Learning rate 0.0001
# Train Epoch: 170 [0/90000 (0%)]	log Loss: -6.091970
#
# Train set: Average log loss: -6.1970
#
#
# Test set: Average loss: -6.0461
#
# Current Learning rate 0.0001
# Train Epoch: 171 [0/90000 (0%)]	log Loss: -6.098054
#
# Train set: Average log loss: -6.2046
#
#
# Test set: Average loss: -6.0033
#
# Current Learning rate 0.0001
# Train Epoch: 172 [0/90000 (0%)]	log Loss: -6.056237
#
# Train set: Average log loss: -6.1962
#
#
# Test set: Average loss: -6.0723
#
# Current Learning rate 0.0001
# Train Epoch: 173 [0/90000 (0%)]	log Loss: -6.125100
#
# Train set: Average log loss: -6.2127
#
#
# Test set: Average loss: -6.0530
#
# Current Learning rate 0.0001
# Train Epoch: 174 [0/90000 (0%)]	log Loss: -6.105179
#
# Train set: Average log loss: -6.2107
#
#
# Test set: Average loss: -6.0092
#
# Current Learning rate 0.0001
# Train Epoch: 175 [0/90000 (0%)]	log Loss: -6.067334
#
# Train set: Average log loss: -6.2002
#
#
# Test set: Average loss: -6.1108
#
# Current Learning rate 0.0001
# Train Epoch: 176 [0/90000 (0%)]	log Loss: -6.167605
#
# Train set: Average log loss: -6.2190
#
#
# Test set: Average loss: -6.0591
#
# Current Learning rate 0.0001
# Train Epoch: 177 [0/90000 (0%)]	log Loss: -6.113657
#
# Train set: Average log loss: -6.2166
#
#
# Test set: Average loss: -6.0456
#
# Current Learning rate 0.0001
# Train Epoch: 178 [0/90000 (0%)]	log Loss: -6.101461
#
# Train set: Average log loss: -6.2102
#
#
# Test set: Average loss: -6.0065
#
# Current Learning rate 0.0001
# Train Epoch: 179 [0/90000 (0%)]	log Loss: -6.060079
#
# Train set: Average log loss: -6.2057
#
#
# Test set: Average loss: -6.1900
#
# Current Learning rate 0.0001
# Train Epoch: 180 [0/90000 (0%)]	log Loss: -6.244799
#
# Train set: Average log loss: -6.2312
#
#
# Test set: Average loss: -6.1346
#
# Current Learning rate 0.0001
# Train Epoch: 181 [0/90000 (0%)]	log Loss: -6.189650
#
# Train set: Average log loss: -6.2297
#
#
# Test set: Average loss: -6.0902
#
# Current Learning rate 0.0001
# Train Epoch: 182 [0/90000 (0%)]	log Loss: -6.146727
#
# Train set: Average log loss: -6.2264
#
#
# Test set: Average loss: -6.1123
#
# Current Learning rate 0.0001
# Train Epoch: 183 [0/90000 (0%)]	log Loss: -6.171453
#
# Train set: Average log loss: -6.2254
#
#
# Test set: Average loss: -6.0584
#
# Current Learning rate 0.0001
# Train Epoch: 184 [0/90000 (0%)]	log Loss: -6.115451
#
# Train set: Average log loss: -6.2248
#
#
# Test set: Average loss: -6.1100
#
# Current Learning rate 0.0001
# Train Epoch: 185 [0/90000 (0%)]	log Loss: -6.166981
#
# Train set: Average log loss: -6.2326
#
#
# Test set: Average loss: -6.0883
#
# Current Learning rate 0.0001
# Train Epoch: 186 [0/90000 (0%)]	log Loss: -6.146848
#
# Train set: Average log loss: -6.2310
#
#
# Test set: Average loss: -6.1122
#
# Current Learning rate 0.0001
# Train Epoch: 187 [0/90000 (0%)]	log Loss: -6.165234
#
# Train set: Average log loss: -6.2314
#
#
# Test set: Average loss: -6.1223
#
# Current Learning rate 0.0001
# Train Epoch: 188 [0/90000 (0%)]	log Loss: -6.181999
#
# Train set: Average log loss: -6.2358
#
#
# Test set: Average loss: -6.1799
#
# Current Learning rate 0.0001
# Train Epoch: 189 [0/90000 (0%)]	log Loss: -6.242876
#
# Train set: Average log loss: -6.2422
#
#
# Test set: Average loss: -6.1523
#
# Current Learning rate 0.0001
# Train Epoch: 190 [0/90000 (0%)]	log Loss: -6.211317
#
# Train set: Average log loss: -6.2416
#
#
# Test set: Average loss: -6.0286
#
# Current Learning rate 0.0001
# Train Epoch: 191 [0/90000 (0%)]	log Loss: -6.090373
#
# Train set: Average log loss: -6.2269
#
#
# Test set: Average loss: -6.2721
#
# Current Learning rate 0.0001
# Train Epoch: 192 [0/90000 (0%)]	log Loss: -6.318790
#
# Train set: Average log loss: -6.2465
#
#
# Test set: Average loss: -6.2195
#
# Current Learning rate 0.0001
# Train Epoch: 193 [0/90000 (0%)]	log Loss: -6.278429
#
# Train set: Average log loss: -6.2489
#
#
# Test set: Average loss: -6.0880
#
# Current Learning rate 0.0001
# Train Epoch: 194 [0/90000 (0%)]	log Loss: -6.145898
#
# Train set: Average log loss: -6.2388
#
#
# Test set: Average loss: -6.1486
#
# Current Learning rate 0.0001
# Train Epoch: 195 [0/90000 (0%)]	log Loss: -6.208316
#
# Train set: Average log loss: -6.2475
#
#
# Test set: Average loss: -6.1897
#
# Current Learning rate 0.0001
# Train Epoch: 196 [0/90000 (0%)]	log Loss: -6.246284
#
# Train set: Average log loss: -6.2500
#
#
# Test set: Average loss: -6.1216
#
# Current Learning rate 0.0001
# Train Epoch: 197 [0/90000 (0%)]	log Loss: -6.182233
#
# Train set: Average log loss: -6.2480
#
#
# Test set: Average loss: -6.1164
#
# Current Learning rate 0.0001
# Train Epoch: 198 [0/90000 (0%)]	log Loss: -6.184343
#
# Train set: Average log loss: -6.2455
#
#
# Test set: Average loss: -6.1533
#
# Current Learning rate 0.0001
# Train Epoch: 199 [0/90000 (0%)]	log Loss: -6.214530
#
# Train set: Average log loss: -6.2551
#
#
# Test set: Average loss: -6.1707
#
# Current Learning rate 0.0001
# Train Epoch: 200 [0/90000 (0%)]	log Loss: -6.236708
#
# Train set: Average log loss: -6.2550
#
#
# Test set: Average loss: -6.1554
#
# Current Learning rate 0.0001
# Train Epoch: 201 [0/90000 (0%)]	log Loss: -6.222372
#
# Train set: Average log loss: -6.2559
#
#
# Test set: Average loss: -6.2169
#
# Current Learning rate 0.0001
# Train Epoch: 202 [0/90000 (0%)]	log Loss: -6.281586
#
# Train set: Average log loss: -6.2663
#
#
# Test set: Average loss: -6.2132
#
# Current Learning rate 0.0001
# Train Epoch: 203 [0/90000 (0%)]	log Loss: -6.287698
#
# Train set: Average log loss: -6.2623
#
#
# Test set: Average loss: -6.1436
#
# Current Learning rate 0.0001
# Train Epoch: 204 [0/90000 (0%)]	log Loss: -6.211738
#
# Train set: Average log loss: -6.2597
#
#
# Test set: Average loss: -6.2512
#
# Current Learning rate 0.0001
# Train Epoch: 205 [0/90000 (0%)]	log Loss: -6.325154
#
# Train set: Average log loss: -6.2744
#
#
# Test set: Average loss: -6.1859
#
# Current Learning rate 0.0001
# Train Epoch: 206 [0/90000 (0%)]	log Loss: -6.262480
#
# Train set: Average log loss: -6.2640
#
#
# Test set: Average loss: -6.2134
#
# Current Learning rate 0.0001
# Train Epoch: 207 [0/90000 (0%)]	log Loss: -6.279065
#
# Train set: Average log loss: -6.2679
#
#
# Test set: Average loss: -6.2376
#
# Current Learning rate 0.0001
# Train Epoch: 208 [0/90000 (0%)]	log Loss: -6.306524
#
# Train set: Average log loss: -6.2726
#
#
# Test set: Average loss: -6.2512
#
# Current Learning rate 0.0001
# Train Epoch: 209 [0/90000 (0%)]	log Loss: -6.314843
#
# Train set: Average log loss: -6.2727
#
#
# Test set: Average loss: -6.2378
#
# Current Learning rate 0.0001
# Train Epoch: 210 [0/90000 (0%)]	log Loss: -6.305900
#
# Train set: Average log loss: -6.2771
#
#
# Test set: Average loss: -6.2037
#
# Current Learning rate 0.0001
# Train Epoch: 211 [0/90000 (0%)]	log Loss: -6.280372
#
# Train set: Average log loss: -6.2714
#
#
# Test set: Average loss: -6.2971
#
# Current Learning rate 0.0001
# Train Epoch: 212 [0/90000 (0%)]	log Loss: -6.356766
#
# Train set: Average log loss: -6.2785
#
#
# Test set: Average loss: -6.2722
#
# Current Learning rate 0.0001
# Train Epoch: 213 [0/90000 (0%)]	log Loss: -6.332060
#
# Train set: Average log loss: -6.2806
#
#
# Test set: Average loss: -6.2912
#
# Current Learning rate 0.0001
# Train Epoch: 214 [0/90000 (0%)]	log Loss: -6.364921
#
# Train set: Average log loss: -6.2782
#
#
# Test set: Average loss: -6.3526
#
# Current Learning rate 0.0001
# Train Epoch: 215 [0/90000 (0%)]	log Loss: -6.411465
#
# Train set: Average log loss: -6.2877
#
#
# Test set: Average loss: -6.3049
#
# Current Learning rate 0.0001
# Train Epoch: 216 [0/90000 (0%)]	log Loss: -6.381152
#
# Train set: Average log loss: -6.2853
#
#
# Test set: Average loss: -6.3149
#
# Current Learning rate 0.0001
# Train Epoch: 217 [0/90000 (0%)]	log Loss: -6.379054
#
# Train set: Average log loss: -6.2857
#
#
# Test set: Average loss: -6.3478
#
# Current Learning rate 0.0001
# Train Epoch: 218 [0/90000 (0%)]	log Loss: -6.407742
#
# Train set: Average log loss: -6.2823
#
#
# Test set: Average loss: -6.3665
#
# Current Learning rate 0.0001
# Train Epoch: 219 [0/90000 (0%)]	log Loss: -6.426793
#
# Train set: Average log loss: -6.2950
#
#
# Test set: Average loss: -6.3710
#
# Current Learning rate 0.0001
# Train Epoch: 220 [0/90000 (0%)]	log Loss: -6.438806
#
# Train set: Average log loss: -6.2945
#
#
# Test set: Average loss: -6.3796
#
# Current Learning rate 0.0001
# Train Epoch: 221 [0/90000 (0%)]	log Loss: -6.444870
#
# Train set: Average log loss: -6.3041
#
#
# Test set: Average loss: -6.4288
#
# Current Learning rate 0.0001
# Train Epoch: 222 [0/90000 (0%)]	log Loss: -6.485777
#
# Train set: Average log loss: -6.3109
#
#
# Test set: Average loss: -6.4563
#
# Current Learning rate 0.0001
# Train Epoch: 223 [0/90000 (0%)]	log Loss: -6.524297
#
# Train set: Average log loss: -6.2596
#
#
# Test set: Average loss: -6.2850
#
# Current Learning rate 0.0001
# Train Epoch: 224 [0/90000 (0%)]	log Loss: -6.364845
#
# Train set: Average log loss: -6.2969
#
#
# Test set: Average loss: -6.4052
#
# Current Learning rate 0.0001
# Train Epoch: 225 [0/90000 (0%)]	log Loss: -6.462097
#
# Train set: Average log loss: -6.3105
#
#
# Test set: Average loss: -6.4648
#
# Current Learning rate 0.0001
# Train Epoch: 226 [0/90000 (0%)]	log Loss: -6.517141
#
# Train set: Average log loss: -6.3078
#
#
# Test set: Average loss: -6.4061
#
# Current Learning rate 0.0001
# Train Epoch: 227 [0/90000 (0%)]	log Loss: -6.496335
#
# Train set: Average log loss: -6.2872
#
#
# Test set: Average loss: -6.2857
#
# Current Learning rate 0.0001
# Train Epoch: 228 [0/90000 (0%)]	log Loss: -6.368479
#
# Train set: Average log loss: -6.2944
#
#
# Test set: Average loss: -6.3993
#
# Current Learning rate 0.0001
# Train Epoch: 229 [0/90000 (0%)]	log Loss: -6.460560
#
# Train set: Average log loss: -6.3008
#
#
# Test set: Average loss: -6.4502
#
# Current Learning rate 0.0001
# Train Epoch: 230 [0/90000 (0%)]	log Loss: -6.486091
#
# Train set: Average log loss: -6.3273
#
#
# Test set: Average loss: -6.4660
#
# Current Learning rate 0.0001
# Train Epoch: 231 [0/90000 (0%)]	log Loss: -6.535899
#
# Train set: Average log loss: -6.2692
#
#
# Test set: Average loss: -6.2968
#
# Current Learning rate 0.0001
# Train Epoch: 232 [0/90000 (0%)]	log Loss: -6.379036
#
# Train set: Average log loss: -6.3052
#
#
# Test set: Average loss: -6.4155
#
# Current Learning rate 0.0001
# Train Epoch: 233 [0/90000 (0%)]	log Loss: -6.471663
#
# Train set: Average log loss: -6.3274
#
#
# Test set: Average loss: -6.4648
#
# Current Learning rate 0.0001
# Train Epoch: 234 [0/90000 (0%)]	log Loss: -6.521303
#
# Train set: Average log loss: -6.2947
#
#
# Test set: Average loss: -6.2621
#
# Current Learning rate 0.0001
# Train Epoch: 235 [0/90000 (0%)]	log Loss: -6.348498
#
# Train set: Average log loss: -6.2976
#
#
# Test set: Average loss: -6.3961
#
# Current Learning rate 0.0001
# Train Epoch: 236 [0/90000 (0%)]	log Loss: -6.450682
#
# Train set: Average log loss: -6.3301
#
#
# Test set: Average loss: -6.4461
#
# Current Learning rate 0.0001
# Train Epoch: 237 [0/90000 (0%)]	log Loss: -6.495181
#
# Train set: Average log loss: -6.3530
#
#
# Test set: Average loss: -6.4760
#
# Current Learning rate 0.0001
# Train Epoch: 238 [0/90000 (0%)]	log Loss: -6.562818
#
# Train set: Average log loss: -6.2776
#
#
# Test set: Average loss: -6.3085
#
# Current Learning rate 0.0001
# Train Epoch: 239 [0/90000 (0%)]	log Loss: -6.384114
#
# Train set: Average log loss: -6.3061
#
#
# Test set: Average loss: -6.4229
#
# Current Learning rate 0.0001
# Train Epoch: 240 [0/90000 (0%)]	log Loss: -6.483065
#
# Train set: Average log loss: -6.3274
#
#
# Test set: Average loss: -6.4693
#
# Current Learning rate 0.0001
# Train Epoch: 241 [0/90000 (0%)]	log Loss: -6.522248
#
# Train set: Average log loss: -6.3476
#
#
# Test set: Average loss: -6.4717
#
# Current Learning rate 0.0001
# Train Epoch: 242 [0/90000 (0%)]	log Loss: -6.563873
#
# Train set: Average log loss: -6.2725
#
#
# Test set: Average loss: -6.4321
#
# Current Learning rate 0.0001
# Train Epoch: 243 [0/90000 (0%)]	log Loss: -6.490607
#
# Train set: Average log loss: -6.3428
#
#
# Test set: Average loss: -6.4221
#
# Current Learning rate 0.0001
# Train Epoch: 244 [0/90000 (0%)]	log Loss: -6.486051
#
# Train set: Average log loss: -6.3397
#
#
# Test set: Average loss: -6.3811
#
# Current Learning rate 0.0001
# Train Epoch: 245 [0/90000 (0%)]	log Loss: -6.476643
#
# Train set: Average log loss: -6.2952
#
#
# Test set: Average loss: -6.2489
#
# Current Learning rate 0.0001
# Train Epoch: 246 [0/90000 (0%)]	log Loss: -6.340422
#
# Train set: Average log loss: -6.3022
#
#
# Test set: Average loss: -6.4961
#
# Current Learning rate 0.0001
# Train Epoch: 247 [0/90000 (0%)]	log Loss: -6.526631
#
# Train set: Average log loss: -6.3658
#
#
# Test set: Average loss: -6.4755
#
# Current Learning rate 0.0001
# Train Epoch: 248 [0/90000 (0%)]	log Loss: -6.559459
#
# Train set: Average log loss: -6.2889
#
#
# Test set: Average loss: -6.4358
#
# Current Learning rate 0.0001
# Train Epoch: 249 [0/90000 (0%)]	log Loss: -6.495159
#
# Train set: Average log loss: -6.3483
#
#
# Test set: Average loss: -6.4498
#
# Current Learning rate 0.0001
# Train Epoch: 250 [0/90000 (0%)]	log Loss: -6.504116
#
# Train set: Average log loss: -6.3520
#
#
# Test set: Average loss: -6.4372
#
# Current Learning rate 0.0001
# Train Epoch: 251 [0/90000 (0%)]	log Loss: -6.532575
#
# Train set: Average log loss: -6.2922
#
#
# Test set: Average loss: -6.3570
#
# Current Learning rate 0.0001
# Train Epoch: 252 [0/90000 (0%)]	log Loss: -6.434516
#
# Train set: Average log loss: -6.3301
#
#
# Test set: Average loss: -6.4008
#
# Current Learning rate 0.0001
# Train Epoch: 253 [0/90000 (0%)]	log Loss: -6.454353
#
# Train set: Average log loss: -6.3452
#
#
# Test set: Average loss: -6.4681
#
# Current Learning rate 0.0001
# Train Epoch: 254 [0/90000 (0%)]	log Loss: -6.520025
#
# Train set: Average log loss: -6.3646
#
#
# Test set: Average loss: -6.4706
#
# Current Learning rate 0.0001
# Train Epoch: 255 [0/90000 (0%)]	log Loss: -6.542864
#
# Train set: Average log loss: -6.2835
#
#
# Test set: Average loss: -6.4656
#
# Current Learning rate 0.0001
# Train Epoch: 256 [0/90000 (0%)]	log Loss: -6.524039
#
# Train set: Average log loss: -6.3603
#
#
# Test set: Average loss: -6.4850
#
# Current Learning rate 0.0001
# Train Epoch: 257 [0/90000 (0%)]	log Loss: -6.538849
#
# Train set: Average log loss: -6.3525
#
#
# Test set: Average loss: -6.3734
#
# Current Learning rate 0.0001
# Train Epoch: 258 [0/90000 (0%)]	log Loss: -6.472194
#
# Train set: Average log loss: -6.3437
#
#
# Test set: Average loss: -6.4482
#
# Current Learning rate 0.0001
# Train Epoch: 259 [0/90000 (0%)]	log Loss: -6.536704
#
# Train set: Average log loss: -6.3145
#
#
# Test set: Average loss: -6.3170
#
# Current Learning rate 0.0001
# Train Epoch: 260 [0/90000 (0%)]	log Loss: -6.402230
#
# Train set: Average log loss: -6.3337
#
#
# Test set: Average loss: -6.4291
#
# Current Learning rate 0.0001
# Train Epoch: 261 [0/90000 (0%)]	log Loss: -6.483108
#
# Train set: Average log loss: -6.3722
#
#
# Test set: Average loss: -6.4808
#
# Current Learning rate 0.0001
# Train Epoch: 262 [0/90000 (0%)]	log Loss: -6.560933
#
# Train set: Average log loss: -6.3029
#
#
# Test set: Average loss: -6.4813
#
# Current Learning rate 0.0001
# Train Epoch: 263 [0/90000 (0%)]	log Loss: -6.530363
#
# Train set: Average log loss: -6.3744
#
#
# Test set: Average loss: -6.4598
#
# Current Learning rate 0.0001
# Train Epoch: 264 [0/90000 (0%)]	log Loss: -6.545269
#
# Train set: Average log loss: -6.3665
#
#
# Test set: Average loss: -6.4136
#
# Current Learning rate 0.0001
# Train Epoch: 265 [0/90000 (0%)]	log Loss: -6.513612
#
# Train set: Average log loss: -6.3634
#
#
# Test set: Average loss: -6.4428
#
# Current Learning rate 0.0001
# Train Epoch: 266 [0/90000 (0%)]	log Loss: -6.539576
#
# Train set: Average log loss: -6.3298
#
#
# Test set: Average loss: -6.2564
#
# Current Learning rate 0.0001
# Train Epoch: 267 [0/90000 (0%)]	log Loss: -6.357617
#
# Train set: Average log loss: -6.3417
#
#
# Test set: Average loss: -6.4593
#
# Current Learning rate 0.0001
# Train Epoch: 268 [0/90000 (0%)]	log Loss: -6.552266
#
# Train set: Average log loss: -6.3411
#
#
# Test set: Average loss: -6.2647
#
# Current Learning rate 0.0001
# Train Epoch: 269 [0/90000 (0%)]	log Loss: -6.366784
#
# Train set: Average log loss: -6.3488
#
#
# Test set: Average loss: -6.4668
#
# Current Learning rate 0.0001
# Train Epoch: 270 [0/90000 (0%)]	log Loss: -6.556692
#
# Train set: Average log loss: -6.3512
#
#
# Test set: Average loss: -6.2938
#
# Current Learning rate 0.0001
# Train Epoch: 271 [0/90000 (0%)]	log Loss: -6.391709
#
# Train set: Average log loss: -6.3485
#
#
# Test set: Average loss: -6.4701
#
# Current Learning rate 0.0001
# Train Epoch: 272 [0/90000 (0%)]	log Loss: -6.550528
#
# Train set: Average log loss: -6.3565
#
#
# Test set: Average loss: -6.2923
#
# Current Learning rate 0.0001
# Train Epoch: 273 [0/90000 (0%)]	log Loss: -6.397873
#
# Train set: Average log loss: -6.3584
#
#
# Test set: Average loss: -6.4821
#
# Current Learning rate 0.0001
# Train Epoch: 274 [0/90000 (0%)]	log Loss: -6.571719
#
# Train set: Average log loss: -6.3430
#
#
# Test set: Average loss: -6.1990
#
# Current Learning rate 0.0001
# Train Epoch: 275 [0/90000 (0%)]	log Loss: -6.300535
#
# Train set: Average log loss: -6.3437
#
#
# Test set: Average loss: -6.4090
#
# Current Learning rate 0.0001
# Train Epoch: 276 [0/90000 (0%)]	log Loss: -6.512990
#
# Train set: Average log loss: -6.3835
#
#
# Test set: Average loss: -6.4804
#
# Current Learning rate 0.0001
# Train Epoch: 277 [0/90000 (0%)]	log Loss: -6.575090
#
# Train set: Average log loss: -6.3345
#
#
# Test set: Average loss: -6.1989
#
# Current Learning rate 0.0001
# Train Epoch: 278 [0/90000 (0%)]	log Loss: -6.297831
#
# Train set: Average log loss: -6.3497
#
#
# Test set: Average loss: -6.3932
#
# Current Learning rate 0.0001
# Train Epoch: 279 [0/90000 (0%)]	log Loss: -6.494632
#
# Train set: Average log loss: -6.3786
#
#
# Test set: Average loss: -6.4881
#
# Current Learning rate 0.0001
# Train Epoch: 280 [0/90000 (0%)]	log Loss: -6.575680
#
# Train set: Average log loss: -6.3449
#
#
# Test set: Average loss: -6.2362
#
# Current Learning rate 0.0001
# Train Epoch: 281 [0/90000 (0%)]	log Loss: -6.343929
#
# Train set: Average log loss: -6.3635
#
#
# Test set: Average loss: -6.4775
#
# Current Learning rate 0.0001
# Train Epoch: 282 [0/90000 (0%)]	log Loss: -6.577007
#
# Train set: Average log loss: -6.3629
#
#
# Test set: Average loss: -6.2550
#
# Current Learning rate 0.0001
# Train Epoch: 283 [0/90000 (0%)]	log Loss: -6.364167
#
# Train set: Average log loss: -6.3618
#
#
# Test set: Average loss: -6.4804
#
# Current Learning rate 0.0001
# Train Epoch: 284 [0/90000 (0%)]	log Loss: -6.579785
#
# Train set: Average log loss: -6.3583
#
#
# Test set: Average loss: -6.2221
#
# Current Learning rate 0.0001
# Train Epoch: 285 [0/90000 (0%)]	log Loss: -6.333621
#
# Train set: Average log loss: -6.3622
#
#
# Test set: Average loss: -6.4419
#
# Current Learning rate 0.0001
# Train Epoch: 286 [0/90000 (0%)]	log Loss: -6.548536
#
# Train set: Average log loss: -6.3965
#
#
# Test set: Average loss: -6.4558
#
# Current Learning rate 0.0001
# Train Epoch: 287 [0/90000 (0%)]	log Loss: -6.559355
#
# Train set: Average log loss: -6.3605
#
#
# Test set: Average loss: -6.2407
#
# Current Learning rate 0.0001
# Train Epoch: 288 [0/90000 (0%)]	log Loss: -6.349225
#
# Train set: Average log loss: -6.3685
#
#
# Test set: Average loss: -6.4688
#
# Current Learning rate 0.0001
# Train Epoch: 289 [0/90000 (0%)]	log Loss: -6.573677
#
# Train set: Average log loss: -6.3718
#
#
# Test set: Average loss: -6.2593
#
# Current Learning rate 0.0001
# Train Epoch: 290 [0/90000 (0%)]	log Loss: -6.373512
#
# Train set: Average log loss: -6.3734
#
#
# Test set: Average loss: -6.4604
#
# Current Learning rate 0.0001
# Train Epoch: 291 [0/90000 (0%)]	log Loss: -6.570974
#
# Train set: Average log loss: -6.3772
#
#
# Test set: Average loss: -6.2885
#
# Current Learning rate 0.0001
# Train Epoch: 292 [0/90000 (0%)]	log Loss: -6.398890
#
# Train set: Average log loss: -6.3786
#
#
# Test set: Average loss: -6.4754
#
# Current Learning rate 0.0001
# Train Epoch: 293 [0/90000 (0%)]	log Loss: -6.584440
#
# Train set: Average log loss: -6.3617
#
#
# Test set: Average loss: -6.2348
#
# Current Learning rate 0.0001
# Train Epoch: 294 [0/90000 (0%)]	log Loss: -6.339651
#
# Train set: Average log loss: -6.3728
#
#
# Test set: Average loss: -6.4344
#
# Current Learning rate 0.0001
# Train Epoch: 295 [0/90000 (0%)]	log Loss: -6.540520
#
# Train set: Average log loss: -6.4010
#
#
# Test set: Average loss: -6.4864
#
# Current Learning rate 0.0001
# Train Epoch: 296 [0/90000 (0%)]	log Loss: -6.591776
#
# Train set: Average log loss: -6.3606
#
#
# Test set: Average loss: -6.2264
#
# Current Learning rate 0.0001
# Train Epoch: 297 [0/90000 (0%)]	log Loss: -6.329716
#
# Train set: Average log loss: -6.3784
#
#
# Test set: Average loss: -6.4364
#
# Current Learning rate 0.0001
# Train Epoch: 298 [0/90000 (0%)]	log Loss: -6.548572
#
# Train set: Average log loss: -6.4045
#
#
# Test set: Average loss: -6.4911
#
# Current Learning rate 0.0001
# Train Epoch: 299 [0/90000 (0%)]	log Loss: -6.594805
#
# Train set: Average log loss: -6.3758
#
#
# Test set: Average loss: -6.2414
#
# Current Learning rate 0.0001
# Train Epoch: 300 [0/90000 (0%)]	log Loss: -6.347363
#
# Train set: Average log loss: -6.3838
#
#
# Test set: Average loss: -6.4532
#
# Current Learning rate 0.0001
# Train Epoch: 301 [0/90000 (0%)]	log Loss: -6.566487
#
# Train set: Average log loss: -6.4052
#
#
# Test set: Average loss: -6.3876
#
# Current Learning rate 0.0001
# Train Epoch: 302 [0/90000 (0%)]	log Loss: -6.500146
#
# Train set: Average log loss: -6.4038
#
#
# Test set: Average loss: -6.4846
#
# Current Learning rate 0.0001
# Train Epoch: 303 [0/90000 (0%)]	log Loss: -6.592406
#
# Train set: Average log loss: -6.3686
#
#
# Test set: Average loss: -6.2442
#
# Current Learning rate 0.0001
# Train Epoch: 304 [0/90000 (0%)]	log Loss: -6.346578
#
# Train set: Average log loss: -6.3826
#
#
# Test set: Average loss: -6.3741
#
# Current Learning rate 0.0001
# Train Epoch: 305 [0/90000 (0%)]	log Loss: -6.486028
#
# Train set: Average log loss: -6.4041
#
#
# Test set: Average loss: -6.4688
#
# Current Learning rate 0.0001
# Train Epoch: 306 [0/90000 (0%)]	log Loss: -6.582513
#
# Train set: Average log loss: -6.3828
#
#
# Test set: Average loss: -6.2443
#
# Current Learning rate 0.0001
# Train Epoch: 307 [0/90000 (0%)]	log Loss: -6.347115
#
# Train set: Average log loss: -6.3885
#
#
# Test set: Average loss: -6.4372
#
# Current Learning rate 0.0001
# Train Epoch: 308 [0/90000 (0%)]	log Loss: -6.551605
#
# Train set: Average log loss: -6.4189
#
#
# Test set: Average loss: -6.4509
#
# Current Learning rate 0.0001
# Train Epoch: 309 [0/90000 (0%)]	log Loss: -6.566894
#
# Train set: Average log loss: -6.4063
#
#
# Test set: Average loss: -6.3770
#
# Current Learning rate 0.0001
# Train Epoch: 310 [0/90000 (0%)]	log Loss: -6.488678
#
# Train set: Average log loss: -6.3964
#
#
# Test set: Average loss: -6.5181
#
# Current Learning rate 0.0001
# Train Epoch: 311 [0/90000 (0%)]	log Loss: -6.615040
#
# Train set: Average log loss: -6.3865
#
#
# Test set: Average loss: -6.3040
#
# Current Learning rate 0.0001
# ...
#
#
# Test set: Average loss: -7.5117
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2908 [0/90000 (0%)]	log Loss: -7.726393
#
# Train set: Average log loss: -7.5572
#
#
# Test set: Average loss: -7.5118
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2909 [0/90000 (0%)]	log Loss: -7.726458
#
# Train set: Average log loss: -7.5572
#
#
# Test set: Average loss: -7.5118
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2910 [0/90000 (0%)]	log Loss: -7.726440
#
# Train set: Average log loss: -7.5573
#
#
# Test set: Average loss: -7.5118
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2911 [0/90000 (0%)]	log Loss: -7.726465
#
# Train set: Average log loss: -7.5573
#
#
# Test set: Average loss: -7.5119
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2912 [0/90000 (0%)]	log Loss: -7.726450
#
# Train set: Average log loss: -7.5573
#
#
# Test set: Average loss: -7.5119
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2913 [0/90000 (0%)]	log Loss: -7.726561
#
# Train set: Average log loss: -7.5574
#
#
# Test set: Average loss: -7.5119
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2914 [0/90000 (0%)]	log Loss: -7.726531
#
# Train set: Average log loss: -7.5574
#
#
# Test set: Average loss: -7.5119
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2915 [0/90000 (0%)]	log Loss: -7.726580
#
# Train set: Average log loss: -7.5574
#
#
# Test set: Average loss: -7.5120
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2916 [0/90000 (0%)]	log Loss: -7.726559
#
# Train set: Average log loss: -7.5574
#
#
# Test set: Average loss: -7.5120
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2917 [0/90000 (0%)]	log Loss: -7.726631
#
# Train set: Average log loss: -7.5575
#
#
# Test set: Average loss: -7.5120
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2918 [0/90000 (0%)]	log Loss: -7.726514
#
# Train set: Average log loss: -7.5575
#
#
# Test set: Average loss: -7.5120
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2919 [0/90000 (0%)]	log Loss: -7.726779
#
# Train set: Average log loss: -7.5576
#
#
# Test set: Average loss: -7.5121
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2920 [0/90000 (0%)]	log Loss: -7.726546
#
# Train set: Average log loss: -7.5576
#
#
# Test set: Average loss: -7.5121
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2921 [0/90000 (0%)]	log Loss: -7.726715
#
# Train set: Average log loss: -7.5576
#
#
# Test set: Average loss: -7.5121
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2922 [0/90000 (0%)]	log Loss: -7.726648
#
# Train set: Average log loss: -7.5576
#
#
# Test set: Average loss: -7.5121
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2923 [0/90000 (0%)]	log Loss: -7.726807
#
# Train set: Average log loss: -7.5576
#
#
# Test set: Average loss: -7.5121
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2924 [0/90000 (0%)]	log Loss: -7.726762
#
# Train set: Average log loss: -7.5577
#
#
# Test set: Average loss: -7.5122
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2925 [0/90000 (0%)]	log Loss: -7.726778
#
# Train set: Average log loss: -7.5577
#
#
# Test set: Average loss: -7.5122
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2926 [0/90000 (0%)]	log Loss: -7.726693
#
# Train set: Average log loss: -7.5578
#
#
# Test set: Average loss: -7.5122
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2927 [0/90000 (0%)]	log Loss: -7.726828
#
# Train set: Average log loss: -7.5578
#
#
# Test set: Average loss: -7.5122
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2928 [0/90000 (0%)]	log Loss: -7.726881
#
# Train set: Average log loss: -7.5578
#
#
# Test set: Average loss: -7.5123
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2929 [0/90000 (0%)]	log Loss: -7.726929
#
# Train set: Average log loss: -7.5578
#
#
# Test set: Average loss: -7.5123
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2930 [0/90000 (0%)]	log Loss: -7.726838
#
# Train set: Average log loss: -7.5578
#
#
# Test set: Average loss: -7.5123
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2931 [0/90000 (0%)]	log Loss: -7.726934
#
# Train set: Average log loss: -7.5579
#
#
# Test set: Average loss: -7.5124
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2932 [0/90000 (0%)]	log Loss: -7.726903
#
# Train set: Average log loss: -7.5579
#
#
# Test set: Average loss: -7.5124
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2933 [0/90000 (0%)]	log Loss: -7.727096
#
# Train set: Average log loss: -7.5580
#
#
# Test set: Average loss: -7.5124
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2934 [0/90000 (0%)]	log Loss: -7.726977
#
# Train set: Average log loss: -7.5580
#
#
# Test set: Average loss: -7.5124
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2935 [0/90000 (0%)]	log Loss: -7.727018
#
# Train set: Average log loss: -7.5580
#
#
# Test set: Average loss: -7.5125
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2936 [0/90000 (0%)]	log Loss: -7.726890
#
# Train set: Average log loss: -7.5580
#
#
# Test set: Average loss: -7.5124
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2937 [0/90000 (0%)]	log Loss: -7.727071
#
# Train set: Average log loss: -7.5581
#
#
# Test set: Average loss: -7.5125
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2938 [0/90000 (0%)]	log Loss: -7.727065
#
# Train set: Average log loss: -7.5581
#
#
# Test set: Average loss: -7.5126
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2939 [0/90000 (0%)]	log Loss: -7.727101
#
# Train set: Average log loss: -7.5582
#
#
# Test set: Average loss: -7.5126
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2940 [0/90000 (0%)]	log Loss: -7.726966
#
# Train set: Average log loss: -7.5581
#
#
# Test set: Average loss: -7.5126
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2941 [0/90000 (0%)]	log Loss: -7.727066
#
# Train set: Average log loss: -7.5582
#
#
# Test set: Average loss: -7.5126
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2942 [0/90000 (0%)]	log Loss: -7.727020
#
# Train set: Average log loss: -7.5582
#
#
# Test set: Average loss: -7.5126
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2943 [0/90000 (0%)]	log Loss: -7.727095
#
# Train set: Average log loss: -7.5583
#
#
# Test set: Average loss: -7.5127
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2944 [0/90000 (0%)]	log Loss: -7.727068
#
# Train set: Average log loss: -7.5583
#
#
# Test set: Average loss: -7.5126
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2945 [0/90000 (0%)]	log Loss: -7.727225
#
# Train set: Average log loss: -7.5583
#
#
# Test set: Average loss: -7.5128
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2946 [0/90000 (0%)]	log Loss: -7.727087
#
# Train set: Average log loss: -7.5584
#
#
# Test set: Average loss: -7.5127
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2947 [0/90000 (0%)]	log Loss: -7.727173
#
# Train set: Average log loss: -7.5584
#
#
# Test set: Average loss: -7.5128
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2948 [0/90000 (0%)]	log Loss: -7.727125
#
# Train set: Average log loss: -7.5585
#
#
# Test set: Average loss: -7.5128
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2949 [0/90000 (0%)]	log Loss: -7.727213
#
# Train set: Average log loss: -7.5585
#
#
# Test set: Average loss: -7.5128
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2950 [0/90000 (0%)]	log Loss: -7.727091
#
# Train set: Average log loss: -7.5585
#
#
# Test set: Average loss: -7.5128
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2951 [0/90000 (0%)]	log Loss: -7.727189
#
# Train set: Average log loss: -7.5585
#
#
# Test set: Average loss: -7.5129
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2952 [0/90000 (0%)]	log Loss: -7.727128
#
# Train set: Average log loss: -7.5586
#
#
# Test set: Average loss: -7.5129
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2953 [0/90000 (0%)]	log Loss: -7.727203
#
# Train set: Average log loss: -7.5586
#
#
# Test set: Average loss: -7.5129
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2954 [0/90000 (0%)]	log Loss: -7.727199
#
# Train set: Average log loss: -7.5587
#
#
# Test set: Average loss: -7.5129
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2955 [0/90000 (0%)]	log Loss: -7.727200
#
# Train set: Average log loss: -7.5586
#
#
# Test set: Average loss: -7.5129
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2956 [0/90000 (0%)]	log Loss: -7.727210
#
# Train set: Average log loss: -7.5587
#
#
# Test set: Average loss: -7.5130
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2957 [0/90000 (0%)]	log Loss: -7.727294
#
# Train set: Average log loss: -7.5588
#
#
# Test set: Average loss: -7.5130
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2958 [0/90000 (0%)]	log Loss: -7.727252
#
# Train set: Average log loss: -7.5588
#
#
# Test set: Average loss: -7.5130
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2959 [0/90000 (0%)]	log Loss: -7.727369
#
# Train set: Average log loss: -7.5588
#
#
# Test set: Average loss: -7.5131
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2960 [0/90000 (0%)]	log Loss: -7.727337
#
# Train set: Average log loss: -7.5588
#
#
# Test set: Average loss: -7.5131
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2961 [0/90000 (0%)]	log Loss: -7.727280
#
# Train set: Average log loss: -7.5588
#
#
# Test set: Average loss: -7.5131
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2962 [0/90000 (0%)]	log Loss: -7.727236
#
# Train set: Average log loss: -7.5589
#
#
# Test set: Average loss: -7.5131
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2963 [0/90000 (0%)]	log Loss: -7.727377
#
# Train set: Average log loss: -7.5589
#
#
# Test set: Average loss: -7.5132
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2964 [0/90000 (0%)]	log Loss: -7.727266
#
# Train set: Average log loss: -7.5590
#
#
# Test set: Average loss: -7.5132
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2965 [0/90000 (0%)]	log Loss: -7.727401
#
# Train set: Average log loss: -7.5590
#
#
# Test set: Average loss: -7.5132
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2966 [0/90000 (0%)]	log Loss: -7.727348
#
# Train set: Average log loss: -7.5590
#
#
# Test set: Average loss: -7.5133
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2967 [0/90000 (0%)]	log Loss: -7.727287
#
# Train set: Average log loss: -7.5591
#
#
# Test set: Average loss: -7.5132
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2968 [0/90000 (0%)]	log Loss: -7.727490
#
# Train set: Average log loss: -7.5591
#
#
# Test set: Average loss: -7.5133
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2969 [0/90000 (0%)]	log Loss: -7.727316
#
# Train set: Average log loss: -7.5592
#
#
# Test set: Average loss: -7.5133
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2970 [0/90000 (0%)]	log Loss: -7.727471
#
# Train set: Average log loss: -7.5592
#
#
# Test set: Average loss: -7.5133
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2971 [0/90000 (0%)]	log Loss: -7.727281
#
# Train set: Average log loss: -7.5592
#
#
# Test set: Average loss: -7.5134
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2972 [0/90000 (0%)]	log Loss: -7.727452
#
# Train set: Average log loss: -7.5593
#
#
# Test set: Average loss: -7.5134
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2973 [0/90000 (0%)]	log Loss: -7.727541
#
# Train set: Average log loss: -7.5593
#
#
# Test set: Average loss: -7.5134
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2974 [0/90000 (0%)]	log Loss: -7.727398
#
# Train set: Average log loss: -7.5593
#
#
# Test set: Average loss: -7.5134
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2975 [0/90000 (0%)]	log Loss: -7.727508
#
# Train set: Average log loss: -7.5593
#
#
# Test set: Average loss: -7.5135
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2976 [0/90000 (0%)]	log Loss: -7.727419
#
# Train set: Average log loss: -7.5594
#
#
# Test set: Average loss: -7.5135
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2977 [0/90000 (0%)]	log Loss: -7.727589
#
# Train set: Average log loss: -7.5594
#
#
# Test set: Average loss: -7.5135
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2978 [0/90000 (0%)]	log Loss: -7.727465
#
# Train set: Average log loss: -7.5594
#
#
# Test set: Average loss: -7.5135
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2979 [0/90000 (0%)]	log Loss: -7.727490
#
# Train set: Average log loss: -7.5594
#
#
# Test set: Average loss: -7.5136
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2980 [0/90000 (0%)]	log Loss: -7.727519
#
# Train set: Average log loss: -7.5595
#
#
# Test set: Average loss: -7.5136
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2981 [0/90000 (0%)]	log Loss: -7.727437
#
# Train set: Average log loss: -7.5595
#
#
# Test set: Average loss: -7.5136
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2982 [0/90000 (0%)]	log Loss: -7.727582
#
# Train set: Average log loss: -7.5595
#
#
# Test set: Average loss: -7.5136
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2983 [0/90000 (0%)]	log Loss: -7.727590
#
# Train set: Average log loss: -7.5596
#
#
# Test set: Average loss: -7.5137
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2984 [0/90000 (0%)]	log Loss: -7.727524
#
# Train set: Average log loss: -7.5596
#
#
# Test set: Average loss: -7.5137
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2985 [0/90000 (0%)]	log Loss: -7.727605
#
# Train set: Average log loss: -7.5596
#
#
# Test set: Average loss: -7.5137
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2986 [0/90000 (0%)]	log Loss: -7.727456
#
# Train set: Average log loss: -7.5597
#
#
# Test set: Average loss: -7.5138
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2987 [0/90000 (0%)]	log Loss: -7.727608
#
# Train set: Average log loss: -7.5597
#
#
# Test set: Average loss: -7.5138
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2988 [0/90000 (0%)]	log Loss: -7.727624
#
# Train set: Average log loss: -7.5597
#
#
# Test set: Average loss: -7.5138
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2989 [0/90000 (0%)]	log Loss: -7.727568
#
# Train set: Average log loss: -7.5597
#
#
# Test set: Average loss: -7.5139
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2990 [0/90000 (0%)]	log Loss: -7.727554
#
# Train set: Average log loss: -7.5598
#
#
# Test set: Average loss: -7.5138
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2991 [0/90000 (0%)]	log Loss: -7.727802
#
# Train set: Average log loss: -7.5598
#
#
# Test set: Average loss: -7.5139
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2992 [0/90000 (0%)]	log Loss: -7.727645
#
# Train set: Average log loss: -7.5598
#
#
# Test set: Average loss: -7.5139
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2993 [0/90000 (0%)]	log Loss: -7.727706
#
# Train set: Average log loss: -7.5599
#
#
# Test set: Average loss: -7.5139
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2994 [0/90000 (0%)]	log Loss: -7.727620
#
# Train set: Average log loss: -7.5599
#
#
# Test set: Average loss: -7.5140
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2995 [0/90000 (0%)]	log Loss: -7.727623
#
# Train set: Average log loss: -7.5599
#
#
# Test set: Average loss: -7.5140
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2996 [0/90000 (0%)]	log Loss: -7.727797
#
# Train set: Average log loss: -7.5600
#
#
# Test set: Average loss: -7.5140
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2997 [0/90000 (0%)]	log Loss: -7.727722
#
# Train set: Average log loss: -7.5600
#
#
# Test set: Average loss: -7.5140
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2998 [0/90000 (0%)]	log Loss: -7.727733
#
# Train set: Average log loss: -7.5600
#
#
# Test set: Average loss: -7.5140
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2999 [0/90000 (0%)]	log Loss: -7.727794
#
# Train set: Average log loss: -7.5601
#
#
# Test set: Average loss: -7.5141
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 3000 [0/90000 (0%)]	log Loss: -7.727753
#
# Train set: Average log loss: -7.5601
#
#
# Test set: Average loss: -7.5141
#
# Current Learning rate 1.0000000000000002e-06

# %%
# Loading model
device = torch.device("cuda")
loaded_IV_ANN_UN = IV_ANN().to(device)
PATH = "ANN_weights/IV_UNSCALED_ANN.pt"
loaded_IV_ANN_UN.load_state_dict(torch.load(PATH))
loaded_IV_ANN_UN.eval()
# Out:
# IV_ANN(
#   (fc1): Linear(in_features=4, out_features=400, bias=True)
#   (fc2): Linear(in_features=400, out_features=400, bias=True)
#   (fc3): Linear(in_features=400, out_features=400, bias=True)
#   (fc4): Linear(in_features=400, out_features=400, bias=True)
#   (fc5): Linear(in_features=400, out_features=1, bias=True)
# )

# %%
# Plotting erros histogram
errors = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_IV_ANN_UN(data)
    errors.append((target-output).data.cpu().numpy())
  errors = np.concatenate(errors)
plt.figure(figsize=(10,7))
h = plt.hist(errors,100)
plt.grid()
print("MAX ",errors.max())
print("MIN ",errors.min())
# Out:
# MAX  0.23030132
# MIN  -0.44819307

# %%
# Printing train and test MSE, MAE, MAPE and R2
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_IV_ANN_UN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_IV_ANN_UN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Train scores----------------
# MSE 6.599748e-04
# MAE 8.277198e-03
# MAPE 3.761932e-02
# R2 9.910348e-01
# -----------Test scores----------------
# MSE 6.838114e-04
# MAE 8.216325e-03
# MAPE 3.740349e-02
# R2 9.906515e-01

# %% [markdown]
# # 3) COS Method

# %% [markdown]
# #### Vanilla call coefficients

# %% [markdown]
# $\begin{aligned} \chi_{k}(c, d):=& \frac{1}{1+\left(\frac{k \pi}{b-a}\right)^{2}}\left[\cos \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\cos \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right.\\ &\left.+\frac{k \pi}{b-a} \sin \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\frac{k \pi}{b-a} \sin \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right] \end{aligned}$

# %% [markdown]
# $\psi_{k}(c, d):= \begin{cases}{\left[\sin \left(k \pi \frac{d-a}{b-a}\right)-\sin \left(k \pi \frac{c-a}{b-a}\right)\right] \frac{b-a}{k \pi},} & k \neq 0, \\ (d-c), & k=0 .\end{cases}$

# %% [markdown]
# $V_{k}^{\text {call }}=\frac{2}{b-a} K\left(\chi_{k}(0, b)-\psi_{k}(0, b)\right)$

# %%
def call_cosine_coef(a, b, c, d, K, N):
  """
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  K: Strike.
  N: summing lenght.
  Returns V_k coefficient for call option.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*K*(chi_k-psi_k)

# %%
def call_cosine_coef_moy(a, b, c, d, N):
  """
  Moyeness version.
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  N: summing lenght.
  Returns V_k coefficient for call option devided by K.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*(chi_k-psi_k)

# %% [markdown]
# #### Charateristic function for Heston model

# %% [markdown]
# $\begin{aligned} \varphi_{h e s}\left(\omega ; u_{0}\right)=& \exp \left(i \omega \mu \Delta t+\frac{u_{0}}{\eta^{2}}\left(\frac{1-e^{-D \Delta t}}{1-G e^{-D \Delta t}}\right)(\lambda-i \rho \eta \omega-D)\right) \\ & \cdot \exp \left(\frac{\lambda \bar{u}}{\eta^{2}}\left(\Delta t(\lambda-i \rho \eta \omega-D)-2 \log \left(\frac{1-G e^{-D \Delta t}}{1-G}\right)\right)\right) \end{aligned}$

# %% [markdown]
# $D=\sqrt{(\lambda-i \rho \eta \omega)^{2}+\left(\omega^{2}+i \omega\right) \eta^{2}} \quad$ and $\quad G=\frac{\lambda-i \rho \eta \omega-D}{\lambda-i \rho \eta \omega+D} $

# %%
def phi_Heston(a ,b ,N ,r, tau, kappa, gamma, vbar, v0, rho):
  """
  Characteristic function of the log-asset price following the Heston model.
  Section 3.3, equation (33).
  a, b: truncation range parameters.
  N: summing lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns Charateristic function vector.
  """
  k = np.arange(N).reshape(1,-1)
  u = np.pi*k/(b-a)
  i = complex(0.0,1.0)
  D = np.sqrt((kappa-gamma*rho*i*u)**2+(u**2+i*u)*gamma**2)
  G = (kappa-gamma*rho*i*u-D)/(kappa-gamma*rho*i*u+D)
  C = v0* (1-np.exp(-D*tau)) / (gamma**2*(1-G*np.exp(-D*tau)))*(kappa-gamma*rho*i*u-D)
  A = r*i*u*tau + kappa*vbar/(gamma**2)*(tau*(kappa-gamma*rho*i*u-D) -2*np.log( (1-G*np.exp(-D*tau))/(1-G) )   ) 
  phi = np.exp( A + C )
  return phi

# %% [markdown]
# #### Heston cumulants

# %% [markdown]
# $c_{1}=\mu T+\left(1-e^{-\lambda T}\right) \frac{\bar{u}-u_{0}}{2 \lambda}-\frac{1}{2} \bar{u} T$

# %% [markdown]
# $\begin{aligned} c_{2}=& \frac{1}{8 \lambda^{3}}\left(\eta T \lambda e^{-\lambda T}\left(u_{0}-\bar{u}\right)(8 \lambda \rho-4 \eta)\right.\\ &+\lambda \rho \eta\left(1-e^{-\lambda T}\right)\left(16 \bar{u}-8 u_{0}\right) \\ &+2 \bar{u} \lambda T\left(-4 \lambda \rho \eta+\eta^{2}+4 \lambda^{2}\right) \\ &+\eta^{2}\left(\left(\bar{u}-2 u_{0}\right) e^{-2 \lambda T}+\bar{u}\left(6 e^{-\lambda T}-7\right)+2 u_{0}\right) \\ &\left.+8 \lambda^{2}\left(u_{0}-\bar{u}\right)\left(1-e^{-\lambda T}\right)\right) \end{aligned}$

# %%
def Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho ):
  """
  Computes Heston cumulants as defined in the appendix A for the Heston model.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns cumulants c1 and c2.
  """
  c1 = r * tau + (1 - np.exp(- kappa * tau)) * (vbar - v0) / (2 * kappa) - 0.5 * vbar * tau
  
  c2 = 0.125 / kappa ** 3 * (gamma * tau * np.exp(- kappa * tau) * (v0 - vbar) * (8 * kappa * rho - 4 * gamma) + \
     kappa * rho * gamma * (1 - np.exp(- kappa * tau)) * (16 * vbar - 8 * v0) + \
     2 * vbar * kappa * tau * (- 4 * kappa * rho * gamma + gamma ** 2 + 4 * kappa ** 2) + \
     gamma ** 2 * ((vbar - 2 * v0) * np.exp(-2 * kappa * tau) + vbar * (6 * np.exp(- kappa * tau) - 7) + 2 * v0) + \
     8 * kappa ** 2 * (v0 - vbar) * (1 - np.exp(-kappa * tau)))
  return c1, c2

# %% [markdown]
# #### Truncation range

# %% [markdown]
# $[a, b]:=\left[c_{1}-L \sqrt{c_{2}+\sqrt{c_{4}}}, \quad c_{1}+L \sqrt{c_{2}+\sqrt{c_{4}}}\right]$

# %%
def Truncation_range(c1, c2, c4, L):
  """
  Computes the truncation range given the cumulants c1, c2, c4 and the truncation lenght L.
  c1, c2, c4: Model cumulants.
  L: truncation lenght.
  Returns tuncation interval sup b and inf a.
  """
  a = c1 - L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) )
  b = c1 + L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) ) 
  return a, b

# %% [markdown]
# #### Exponential coefficient

# %% [markdown]
# $e^{i k \pi \frac{\mathbf{x}-a}{b-a}}$

# %%
def exponential_coef(a, b, N, S0, K):
  """
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  S0: asset initial price.
  K: strike.
  Returns the exponential coefficient vector.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(S0/K)-a)/(b-a))

# %%
def exponential_coef_moy(a, b, N, moyeness):
  """
  Moyeness version.
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  moyeness: S/K.
  Returns the exponential coefficient vector devided by K.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(moyeness)-a)/(b-a))

# %% [markdown]
# #### Vanilla call price

# %% [markdown]
# $v\left(\mathbf{x}, t_{0}, u_{0}\right) \approx \mathbf{K} e^{-r \Delta t} \cdot \operatorname{Re}\left\{\sum_{k=0}^{N-1} \varphi_{h e s}\left(\frac{k \pi}{b-a} ; u_{0}\right) U_{k} \cdot e^{i k \pi \frac{\mathbf{x}-a}{b-a}}\right\}$

# %%
def call_option_Heston(N, L, r, tau, kappa, gamma, vbar, v0, rho, K, S0 ):
  """
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  S0: asset initial price.
  K: strike.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef(a, b, c, d, K, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef(a, b, N, S0, K)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, K = K, S0 = S0)
# Out:
# True
# array([[29.79261082]])

# %%
def call_option_Heston_moy(N, L, r, tau, kappa, gamma, vbar, v0, rho, moyeness ):
  """
  Moyeness version.
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  moyeness: S/K.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef_moy(a, b, c, d, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef_moy(a, b, N, moyeness)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston_moy(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = 1)
# Out:
# True
# array([[0.29792611]])

# %% [markdown]
# # 4) Heston pricing network: Heston-ANN

# %% [markdown]
# ### Generating Data

# %%
eps = 1e-2 # is used to generate open intervals
def Heston_LHS_data_generator(n = 10**6, l_bounds = [.6+eps, .1+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps], u_bounds = [1.4-eps, 1.4-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,9) containig the inputs samples and the value of the call.
  The inputs are: Moyeness (S/K), time to maturity (tau), Risk free rate (r), Correlation (rho), reversion speed (kappa), Long average variance (vbar), Vol of vol (gamma), Initial variance (v0).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.
  """
  sampler = qmc.LatinHypercube(d=8) #, seed = 0
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  indecies = np.argwhere(2*sample[:,4]*sample[:,5]<= sample[:,6]**2)
  sample = np.delete(sample, indecies,0)
  # print(sample.shape)
  # print(2*kappa*vbar>gamma**2)
  hs_prices = call_option_Heston_moy(N = 160, L= 12, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
                                     gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
                                     rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  # hs_prices = call_option_Heston_moy(N = 1500, L= 50, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
  #                                    gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
  #                                    rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  
  hs_dataset = np.concatenate((sample, hs_prices),axis=1)

  print("------ INPUT ------")
  print("S/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,0]),max(hs_dataset[:,0])))
  print("Tau.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,1]),max(hs_dataset[:,1])))
  print("r............ [{:.2f} {:.2f}]".format(min(hs_dataset[:,2]),max(hs_dataset[:,2])))
  print("Corr ........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,3]),max(hs_dataset[:,3])))
  print("Kappa........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,4]),max(hs_dataset[:,4])))
  print("V_bar........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,5]),max(hs_dataset[:,5])))
  print("Gamma........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,6]),max(hs_dataset[:,6])))
  print("V_0 ......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,7]),max(hs_dataset[:,7])))
  print("------ OUTPUT ------")
  print("V/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,-1]),max(hs_dataset[:,-1])))
  # ind_max = np.argmax(hs_dataset[:,-1])
  # print(hs_dataset[ind_max,:])

  return torch.FloatTensor(hs_dataset)

hs_dataset = Heston_LHS_data_generator(10**4)
# Out:
# ------ INPUT ------
# S/K.......... [0.61 1.39]
# Tau.......... [0.11 1.39]
# r............ [0.01 0.09]
# Corr ........ [-0.94 -0.01]
# Kappa........ [0.41 1.99]
# V_bar........ [0.01 0.49]
# Gamma........ [0.01 0.49]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00 0.63]

# %% [markdown]
# ### Defining class Heston-ANN

# %%
class Heston_ANN(BS_ANN):
  def __init__(self):
    """
    Initilize BS-Heston_ANN netwwork. Same architecture as the one used in tge article.
    Weight are initialized using Glorot_uniform also known as Xavier_uniform.
    Takes inputs of size 8.
    """
    super(Heston_ANN, self).__init__()
    self.fc1 = nn.Linear(8, 400)
    self.fc2 = nn.Linear(400, 400)
    self.fc3 = nn.Linear(400, 400)
    self.fc4 = nn.Linear(400, 400)
    self.fc5 = nn.Linear(400, 1)

    torch.nn.init.xavier_uniform_(self.fc1.weight)
    torch.nn.init.xavier_uniform_(self.fc2.weight)
    torch.nn.init.xavier_uniform_(self.fc3.weight)
    torch.nn.init.xavier_uniform_(self.fc4.weight)
    torch.nn.init.xavier_uniform_(self.fc5.weight)

# %% [markdown]
# ### Training Heston-ANN

# %%
# Training parameters
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}



use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# torch.manual_seed(args["seed"])


# Loading Train / Test Data
hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0]-train_size])

train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])


# Model training
print(device)
model = Heston_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=args["lr"]) # Adam is found to be the best optimizer in the article
scheduler = StepLR(optimizer, step_size=10**3, gamma=args["gamma"]) # Deacreses the Learning rate by .1 every 1000 epoch

train_losses = []
test_losses = []
for epoch in range(1, args["epochs"] + 1):
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
if args["save_model"] :
  torch.save(model.state_dict(), "Heston_ANN.pt")
# Out:
# ------ INPUT ------
# S/K.......... [0.61 1.39]
# Tau.......... [0.11 1.39]
# r............ [0.01 0.09]
# Corr ........ [-0.94 -0.01]
# Kappa........ [0.41 1.99]
# V_bar........ [0.01 0.49]
# Gamma........ [0.01 0.49]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00 0.63]
# cuda
# Train Epoch: 1 [0/83759 (0%)]	log Loss: -1.827268
#
# Train set: Average log loss: -4.1918
#
#
# Test set: Average loss: -6.8416
#
# Current Learning rate 0.0001
# Train Epoch: 2 [0/83759 (0%)]	log Loss: -6.777963
#
# Train set: Average log loss: -7.6731
#
#
# Test set: Average loss: -8.5627
#
# Current Learning rate 0.0001
# Train Epoch: 3 [0/83759 (0%)]	log Loss: -8.549292
#
# Train set: Average log loss: -8.9597
#
#
# Test set: Average loss: -9.2408
#
# Current Learning rate 0.0001
# Train Epoch: 4 [0/83759 (0%)]	log Loss: -9.206422
#
# Train set: Average log loss: -9.5062
#
#
# Test set: Average loss: -9.7364
#
# Current Learning rate 0.0001
# Train Epoch: 5 [0/83759 (0%)]	log Loss: -9.710156
#
# Train set: Average log loss: -9.9207
#
#
# Test set: Average loss: -10.0173
#
# Current Learning rate 0.0001
# Train Epoch: 6 [0/83759 (0%)]	log Loss: -10.006079
#
# Train set: Average log loss: -10.1888
#
#
# Test set: Average loss: -10.2165
#
# Current Learning rate 0.0001
# Train Epoch: 7 [0/83759 (0%)]	log Loss: -10.224226
#
# Train set: Average log loss: -10.4273
#
#
# Test set: Average loss: -10.4300
#
# Current Learning rate 0.0001
# Train Epoch: 8 [0/83759 (0%)]	log Loss: -10.457961
#
# Train set: Average log loss: -10.5997
#
#
# Test set: Average loss: -10.6383
#
# Current Learning rate 0.0001
# Train Epoch: 9 [0/83759 (0%)]	log Loss: -10.664148
#
# Train set: Average log loss: -10.7692
#
#
# Test set: Average loss: -10.8281
#
# Current Learning rate 0.0001
# Train Epoch: 10 [0/83759 (0%)]	log Loss: -10.841594
#
# Train set: Average log loss: -10.9081
#
#
# Test set: Average loss: -10.9647
#
# Current Learning rate 0.0001
# Train Epoch: 11 [0/83759 (0%)]	log Loss: -10.968353
#
# Train set: Average log loss: -11.0102
#
#
# Test set: Average loss: -11.0724
#
# Current Learning rate 0.0001
# Train Epoch: 12 [0/83759 (0%)]	log Loss: -11.070846
#
# Train set: Average log loss: -11.0857
#
#
# Test set: Average loss: -11.1901
#
# Current Learning rate 0.0001
# Train Epoch: 13 [0/83759 (0%)]	log Loss: -11.197867
#
# Train set: Average log loss: -11.1742
#
#
# Test set: Average loss: -11.2580
#
# Current Learning rate 0.0001
# Train Epoch: 14 [0/83759 (0%)]	log Loss: -11.269464
#
# Train set: Average log loss: -11.2650
#
#
# Test set: Average loss: -10.9997
#
# Current Learning rate 0.0001
# Train Epoch: 15 [0/83759 (0%)]	log Loss: -11.004853
#
# Train set: Average log loss: -11.3249
#
#
# Test set: Average loss: -11.2480
#
# Current Learning rate 0.0001
# Train Epoch: 16 [0/83759 (0%)]	log Loss: -11.251326
#
# Train set: Average log loss: -11.3483
#
#
# Test set: Average loss: -11.4875
#
# Current Learning rate 0.0001
# Train Epoch: 17 [0/83759 (0%)]	log Loss: -11.494124
#
# Train set: Average log loss: -11.4005
#
#
# Test set: Average loss: -11.6069
#
# Current Learning rate 0.0001
# Train Epoch: 18 [0/83759 (0%)]	log Loss: -11.617056
#
# Train set: Average log loss: -11.4484
#
#
# Test set: Average loss: -11.5559
#
# Current Learning rate 0.0001
# Train Epoch: 19 [0/83759 (0%)]	log Loss: -11.573587
#
# Train set: Average log loss: -11.5382
#
#
# Test set: Average loss: -11.5190
#
# Current Learning rate 0.0001
# Train Epoch: 20 [0/83759 (0%)]	log Loss: -11.540946
#
# Train set: Average log loss: -11.5800
#
#
# Test set: Average loss: -11.6961
#
# Current Learning rate 0.0001
# Train Epoch: 21 [0/83759 (0%)]	log Loss: -11.706063
#
# Train set: Average log loss: -11.6744
#
#
# Test set: Average loss: -11.8201
#
# Current Learning rate 0.0001
# Train Epoch: 22 [0/83759 (0%)]	log Loss: -11.815806
#
# Train set: Average log loss: -11.6422
#
#
# Test set: Average loss: -11.8636
#
# Current Learning rate 0.0001
# Train Epoch: 23 [0/83759 (0%)]	log Loss: -11.867182
#
# Train set: Average log loss: -11.7032
#
#
# Test set: Average loss: -11.9198
#
# Current Learning rate 0.0001
# Train Epoch: 24 [0/83759 (0%)]	log Loss: -11.901718
#
# Train set: Average log loss: -11.6059
#
#
# Test set: Average loss: -11.9245
#
# Current Learning rate 0.0001
# Train Epoch: 25 [0/83759 (0%)]	log Loss: -11.899064
#
# Train set: Average log loss: -11.6257
#
#
# Test set: Average loss: -12.0039
#
# Current Learning rate 0.0001
# Train Epoch: 26 [0/83759 (0%)]	log Loss: -11.981689
#
# Train set: Average log loss: -11.6418
#
#
# Test set: Average loss: -11.9912
#
# Current Learning rate 0.0001
# Train Epoch: 27 [0/83759 (0%)]	log Loss: -11.958931
#
# Train set: Average log loss: -11.6901
#
#
# Test set: Average loss: -11.9903
#
# Current Learning rate 0.0001
# Train Epoch: 28 [0/83759 (0%)]	log Loss: -11.979700
#
# Train set: Average log loss: -11.6634
#
#
# Test set: Average loss: -12.0060
#
# Current Learning rate 0.0001
# Train Epoch: 29 [0/83759 (0%)]	log Loss: -11.999581
#
# Train set: Average log loss: -11.6385
#
#
# Test set: Average loss: -12.1099
#
# Current Learning rate 0.0001
# Train Epoch: 30 [0/83759 (0%)]	log Loss: -12.094851
#
# Train set: Average log loss: -11.6646
#
#
# Test set: Average loss: -12.1138
#
# Current Learning rate 0.0001
# Train Epoch: 31 [0/83759 (0%)]	log Loss: -12.104696
#
# Train set: Average log loss: -11.6425
#
#
# Test set: Average loss: -12.1778
#
# Current Learning rate 0.0001
# Train Epoch: 32 [0/83759 (0%)]	log Loss: -12.165277
#
# Train set: Average log loss: -11.6689
#
#
# Test set: Average loss: -12.1573
#
# Current Learning rate 0.0001
# Train Epoch: 33 [0/83759 (0%)]	log Loss: -12.153582
#
# Train set: Average log loss: -11.6478
#
#
# Test set: Average loss: -12.2275
#
# Current Learning rate 0.0001
# Train Epoch: 34 [0/83759 (0%)]	log Loss: -12.218268
#
# Train set: Average log loss: -11.6635
#
#
# Test set: Average loss: -12.2537
#
# Current Learning rate 0.0001
# Train Epoch: 35 [0/83759 (0%)]	log Loss: -12.246609
#
# Train set: Average log loss: -11.6664
#
#
# Test set: Average loss: -12.2729
#
# Current Learning rate 0.0001
# Train Epoch: 36 [0/83759 (0%)]	log Loss: -12.270298
#
# Train set: Average log loss: -11.6726
#
#
# Test set: Average loss: -12.2851
#
# Current Learning rate 0.0001
# Train Epoch: 37 [0/83759 (0%)]	log Loss: -12.286360
#
# Train set: Average log loss: -11.6822
#
#
# Test set: Average loss: -12.2838
#
# Current Learning rate 0.0001
# Train Epoch: 38 [0/83759 (0%)]	log Loss: -12.292163
#
# Train set: Average log loss: -11.7487
#
#
# Test set: Average loss: -12.3586
#
# Current Learning rate 0.0001
# Train Epoch: 39 [0/83759 (0%)]	log Loss: -12.358563
#
# Train set: Average log loss: -11.4350
#
#
# Test set: Average loss: -12.0955
#
# Current Learning rate 0.0001
# Train Epoch: 40 [0/83759 (0%)]	log Loss: -12.049525
#
# Train set: Average log loss: -11.3085
#
#
# Test set: Average loss: -11.2088
#
# Current Learning rate 0.0001
# Train Epoch: 41 [0/83759 (0%)]	log Loss: -11.256423
#
# Train set: Average log loss: -11.9541
#
#
# Test set: Average loss: -12.3138
#
# Current Learning rate 0.0001
# Train Epoch: 42 [0/83759 (0%)]	log Loss: -12.314268
#
# Train set: Average log loss: -11.6224
#
#
# Test set: Average loss: -12.4107
#
# Current Learning rate 0.0001
# Train Epoch: 43 [0/83759 (0%)]	log Loss: -12.356646
#
# Train set: Average log loss: -11.6464
#
#
# Test set: Average loss: -12.1144
#
# Current Learning rate 0.0001
# Train Epoch: 44 [0/83759 (0%)]	log Loss: -12.142783
#
# Train set: Average log loss: -11.7247
#
#
# Test set: Average loss: -12.4492
#
# Current Learning rate 0.0001
# Train Epoch: 45 [0/83759 (0%)]	log Loss: -12.423786
#
# Train set: Average log loss: -11.8975
#
#
# Test set: Average loss: -12.4755
#
# Current Learning rate 0.0001
# Train Epoch: 46 [0/83759 (0%)]	log Loss: -12.457619
#
# Train set: Average log loss: -11.7830
#
#
# Test set: Average loss: -12.5162
#
# Current Learning rate 0.0001
# Train Epoch: 47 [0/83759 (0%)]	log Loss: -12.496093
#
# Train set: Average log loss: -11.9757
#
#
# Test set: Average loss: -12.0944
#
# Current Learning rate 0.0001
# Train Epoch: 48 [0/83759 (0%)]	log Loss: -12.040660
#
# Train set: Average log loss: -11.2811
#
#
# Test set: Average loss: -12.5259
#
# Current Learning rate 0.0001
# Train Epoch: 49 [0/83759 (0%)]	log Loss: -12.491774
#
# Train set: Average log loss: -11.8584
#
#
# Test set: Average loss: -12.5346
#
# Current Learning rate 0.0001
# Train Epoch: 50 [0/83759 (0%)]	log Loss: -12.533496
#
# Train set: Average log loss: -11.7769
#
#
# Test set: Average loss: -12.5664
#
# Current Learning rate 0.0001
# Train Epoch: 51 [0/83759 (0%)]	log Loss: -12.569346
#
# Train set: Average log loss: -11.6778
#
#
# Test set: Average loss: -12.5833
#
# Current Learning rate 0.0001
# Train Epoch: 52 [0/83759 (0%)]	log Loss: -12.583580
#
# Train set: Average log loss: -11.1248
#
#
# Test set: Average loss: -11.6534
#
# Current Learning rate 0.0001
# Train Epoch: 53 [0/83759 (0%)]	log Loss: -11.731825
#
# Train set: Average log loss: -12.1273
#
#
# Test set: Average loss: -11.8244
#
# Current Learning rate 0.0001
# Train Epoch: 54 [0/83759 (0%)]	log Loss: -11.897571
#
# Train set: Average log loss: -11.7820
#
#
# Test set: Average loss: -12.4610
#
# Current Learning rate 0.0001
# Train Epoch: 55 [0/83759 (0%)]	log Loss: -12.507516
#
# Train set: Average log loss: -11.8520
#
#
# Test set: Average loss: -12.6212
#
# Current Learning rate 0.0001
# Train Epoch: 56 [0/83759 (0%)]	log Loss: -12.608636
#
# Train set: Average log loss: -12.2196
#
#
# Test set: Average loss: -12.5485
#
# Current Learning rate 0.0001
# Train Epoch: 57 [0/83759 (0%)]	log Loss: -12.597078
#
# Train set: Average log loss: -11.1745
#
#
# Test set: Average loss: -11.8628
#
# Current Learning rate 0.0001
# Train Epoch: 58 [0/83759 (0%)]	log Loss: -11.949081
#
# Train set: Average log loss: -11.8361
#
#
# Test set: Average loss: -11.6311
#
# Current Learning rate 0.0001
# Train Epoch: 59 [0/83759 (0%)]	log Loss: -11.716266
#
# Train set: Average log loss: -11.9650
#
#
# Test set: Average loss: -12.6756
#
# Current Learning rate 0.0001
# Train Epoch: 60 [0/83759 (0%)]	log Loss: -12.670228
#
# Train set: Average log loss: -12.1525
#
#
# Test set: Average loss: -12.6701
#
# Current Learning rate 0.0001
# Train Epoch: 61 [0/83759 (0%)]	log Loss: -12.656412
#
# Train set: Average log loss: -11.3295
#
#
# Test set: Average loss: -11.9036
#
# Current Learning rate 0.0001
# Train Epoch: 62 [0/83759 (0%)]	log Loss: -11.998955
#
# Train set: Average log loss: -12.2797
#
#
# Test set: Average loss: -12.3529
#
# Current Learning rate 0.0001
# Train Epoch: 63 [0/83759 (0%)]	log Loss: -12.439646
#
# Train set: Average log loss: -10.8834
#
#
# Test set: Average loss: -11.3870
#
# Current Learning rate 0.0001
# Train Epoch: 64 [0/83759 (0%)]	log Loss: -11.465500
#
# Train set: Average log loss: -12.4223
#
#
# Test set: Average loss: -12.7332
#
# Current Learning rate 0.0001
# Train Epoch: 65 [0/83759 (0%)]	log Loss: -12.744285
#
# Train set: Average log loss: -12.3010
#
#
# Test set: Average loss: -12.0536
#
# Current Learning rate 0.0001
# Train Epoch: 66 [0/83759 (0%)]	log Loss: -12.150613
#
# Train set: Average log loss: -12.3928
#
#
# Test set: Average loss: -11.5263
#
# Current Learning rate 0.0001
# Train Epoch: 67 [0/83759 (0%)]	log Loss: -11.603040
#
# Train set: Average log loss: -11.8120
#
#
# Test set: Average loss: -12.3719
#
# Current Learning rate 0.0001
# Train Epoch: 68 [0/83759 (0%)]	log Loss: -12.297277
#
# Train set: Average log loss: -11.6571
#
#
# Test set: Average loss: -12.4040
#
# Current Learning rate 0.0001
# Train Epoch: 69 [0/83759 (0%)]	log Loss: -12.499147
#
# Train set: Average log loss: -11.4737
#
#
# Test set: Average loss: -12.4609
#
# Current Learning rate 0.0001
# Train Epoch: 70 [0/83759 (0%)]	log Loss: -12.569202
#
# Train set: Average log loss: -11.8990
#
#
# Test set: Average loss: -12.5279
#
# Current Learning rate 0.0001
# Train Epoch: 71 [0/83759 (0%)]	log Loss: -12.621619
#
# Train set: Average log loss: -12.1472
#
#
# Test set: Average loss: -12.5721
#
# Current Learning rate 0.0001
# Train Epoch: 72 [0/83759 (0%)]	log Loss: -12.669853
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -11.9158
#
# Current Learning rate 0.0001
# Train Epoch: 73 [0/83759 (0%)]	log Loss: -12.035539
#
# Train set: Average log loss: -12.4398
#
#
# Test set: Average loss: -12.3792
#
# Current Learning rate 0.0001
# Train Epoch: 74 [0/83759 (0%)]	log Loss: -12.487628
#
# Train set: Average log loss: -12.1600
#
#
# Test set: Average loss: -12.7710
#
# Current Learning rate 0.0001
# Train Epoch: 75 [0/83759 (0%)]	log Loss: -12.837356
#
# Train set: Average log loss: -11.6225
#
#
# Test set: Average loss: -11.5384
#
# Current Learning rate 0.0001
# Train Epoch: 76 [0/83759 (0%)]	log Loss: -11.641636
#
# Train set: Average log loss: -11.9809
#
#
# Test set: Average loss: -12.7022
#
# Current Learning rate 0.0001
# Train Epoch: 77 [0/83759 (0%)]	log Loss: -12.782959
#
# Train set: Average log loss: -12.0596
#
#
# Test set: Average loss: -12.7522
#
# Current Learning rate 0.0001
# Train Epoch: 78 [0/83759 (0%)]	log Loss: -12.833987
#
# Train set: Average log loss: -10.9552
#
#
# Test set: Average loss: -11.0911
#
# Current Learning rate 0.0001
# Train Epoch: 79 [0/83759 (0%)]	log Loss: -11.171145
#
# Train set: Average log loss: -12.4878
#
#
# Test set: Average loss: -12.8634
#
# Current Learning rate 0.0001
# Train Epoch: 80 [0/83759 (0%)]	log Loss: -12.911235
#
# Train set: Average log loss: -12.4963
#
#
# Test set: Average loss: -12.4921
#
# Current Learning rate 0.0001
# Train Epoch: 81 [0/83759 (0%)]	log Loss: -12.596665
#
# Train set: Average log loss: -12.3758
#
#
# Test set: Average loss: -12.7414
#
# Current Learning rate 0.0001
# Train Epoch: 82 [0/83759 (0%)]	log Loss: -12.835770
#
# Train set: Average log loss: -10.9060
#
#
# Test set: Average loss: -12.4453
#
# Current Learning rate 0.0001
# Train Epoch: 83 [0/83759 (0%)]	log Loss: -12.521871
#
# Train set: Average log loss: -12.4153
#
#
# Test set: Average loss: -12.7850
#
# Current Learning rate 0.0001
# Train Epoch: 84 [0/83759 (0%)]	log Loss: -12.873288
#
# Train set: Average log loss: -12.6615
#
#
# Test set: Average loss: -12.8006
#
# Current Learning rate 0.0001
# Train Epoch: 85 [0/83759 (0%)]	log Loss: -12.887825
#
# Train set: Average log loss: -12.3077
#
#
# Test set: Average loss: -12.9193
#
# Current Learning rate 0.0001
# Train Epoch: 86 [0/83759 (0%)]	log Loss: -12.903237
#
# Train set: Average log loss: -12.0756
#
#
# Test set: Average loss: -12.9492
#
# Current Learning rate 0.0001
# Train Epoch: 87 [0/83759 (0%)]	log Loss: -12.987249
#
# Train set: Average log loss: -11.7065
#
#
# Test set: Average loss: -12.6541
#
# Current Learning rate 0.0001
# Train Epoch: 88 [0/83759 (0%)]	log Loss: -12.772784
#
# Train set: Average log loss: -11.9679
#
#
# Test set: Average loss: -12.7602
#
# Current Learning rate 0.0001
# Train Epoch: 89 [0/83759 (0%)]	log Loss: -12.850911
#
# Train set: Average log loss: -12.1389
#
#
# Test set: Average loss: -12.9392
#
# Current Learning rate 0.0001
# Train Epoch: 90 [0/83759 (0%)]	log Loss: -12.924694
#
# Train set: Average log loss: -11.8294
#
#
# Test set: Average loss: -12.8959
#
# Current Learning rate 0.0001
# Train Epoch: 91 [0/83759 (0%)]	log Loss: -12.979731
#
# Train set: Average log loss: -12.4267
#
#
# Test set: Average loss: -12.8226
#
# Current Learning rate 0.0001
# Train Epoch: 92 [0/83759 (0%)]	log Loss: -12.787748
#
# Train set: Average log loss: -11.8231
#
#
# Test set: Average loss: -12.9919
#
# Current Learning rate 0.0001
# Train Epoch: 93 [0/83759 (0%)]	log Loss: -13.022271
#
# Train set: Average log loss: -11.4277
#
#
# Test set: Average loss: -12.9582
#
# Current Learning rate 0.0001
# Train Epoch: 94 [0/83759 (0%)]	log Loss: -13.019640
#
# Train set: Average log loss: -12.1985
#
#
# Test set: Average loss: -12.4670
#
# Current Learning rate 0.0001
# Train Epoch: 95 [0/83759 (0%)]	log Loss: -12.590931
#
# Train set: Average log loss: -11.9715
#
#
# Test set: Average loss: -11.9133
#
# Current Learning rate 0.0001
# Train Epoch: 96 [0/83759 (0%)]	log Loss: -12.022157
#
# Train set: Average log loss: -12.0073
#
#
# Test set: Average loss: -11.8632
#
# Current Learning rate 0.0001
# Train Epoch: 97 [0/83759 (0%)]	log Loss: -11.973029
#
# Train set: Average log loss: -12.0848
#
#
# Test set: Average loss: -12.1504
#
# Current Learning rate 0.0001
# Train Epoch: 98 [0/83759 (0%)]	log Loss: -12.269631
#
# Train set: Average log loss: -12.2421
#
#
# Test set: Average loss: -13.0340
#
# Current Learning rate 0.0001
# Train Epoch: 99 [0/83759 (0%)]	log Loss: -13.069287
#
# Train set: Average log loss: -11.4330
#
#
# Test set: Average loss: -12.0401
#
# Current Learning rate 0.0001
# Train Epoch: 100 [0/83759 (0%)]	log Loss: -11.994782
#
# Train set: Average log loss: -12.2764
#
#
# Test set: Average loss: -12.9848
#
# Current Learning rate 0.0001
# Train Epoch: 101 [0/83759 (0%)]	log Loss: -13.013262
#
# Train set: Average log loss: -12.0115
#
#
# Test set: Average loss: -12.5532
#
# Current Learning rate 0.0001
# Train Epoch: 102 [0/83759 (0%)]	log Loss: -12.693862
#
# Train set: Average log loss: -12.0183
#
#
# Test set: Average loss: -12.8372
#
# Current Learning rate 0.0001
# Train Epoch: 103 [0/83759 (0%)]	log Loss: -12.976906
#
# Train set: Average log loss: -12.0327
#
#
# Test set: Average loss: -12.9719
#
# Current Learning rate 0.0001
# Train Epoch: 104 [0/83759 (0%)]	log Loss: -13.098302
#
# Train set: Average log loss: -12.0799
#
#
# Test set: Average loss: -12.8771
#
# Current Learning rate 0.0001
# Train Epoch: 105 [0/83759 (0%)]	log Loss: -13.020263
#
# Train set: Average log loss: -12.2450
#
#
# Test set: Average loss: -12.8811
#
# Current Learning rate 0.0001
# Train Epoch: 106 [0/83759 (0%)]	log Loss: -13.016287
#
# Train set: Average log loss: -12.7200
#
#
# Test set: Average loss: -12.0116
#
# Current Learning rate 0.0001
# Train Epoch: 107 [0/83759 (0%)]	log Loss: -12.130002
#
# Train set: Average log loss: -11.5223
#
#
# Test set: Average loss: -12.6356
#
# Current Learning rate 0.0001
# Train Epoch: 108 [0/83759 (0%)]	log Loss: -12.582464
#
# Train set: Average log loss: -12.2785
#
#
# Test set: Average loss: -13.0424
#
# Current Learning rate 0.0001
# Train Epoch: 109 [0/83759 (0%)]	log Loss: -13.159938
#
# Train set: Average log loss: -12.7606
#
#
# Test set: Average loss: -12.2188
#
# Current Learning rate 0.0001
# Train Epoch: 110 [0/83759 (0%)]	log Loss: -12.156798
#
# Train set: Average log loss: -11.3904
#
#
# Test set: Average loss: -12.6958
#
# Current Learning rate 0.0001
# Train Epoch: 111 [0/83759 (0%)]	log Loss: -12.669818
#
# Train set: Average log loss: -12.5414
#
#
# Test set: Average loss: -12.9655
#
# Current Learning rate 0.0001
# Train Epoch: 112 [0/83759 (0%)]	log Loss: -13.124623
#
# Train set: Average log loss: -12.7318
#
#
# Test set: Average loss: -11.4919
#
# Current Learning rate 0.0001
# Train Epoch: 113 [0/83759 (0%)]	log Loss: -11.439813
#
# Train set: Average log loss: -11.6262
#
#
# Test set: Average loss: -13.1164
#
# Current Learning rate 0.0001
# Train Epoch: 114 [0/83759 (0%)]	log Loss: -13.201601
#
# Train set: Average log loss: -12.1994
#
#
# Test set: Average loss: -13.0017
#
# Current Learning rate 0.0001
# Train Epoch: 115 [0/83759 (0%)]	log Loss: -13.159857
#
# Train set: Average log loss: -12.4327
#
#
# Test set: Average loss: -13.0773
#
# Current Learning rate 0.0001
# Train Epoch: 116 [0/83759 (0%)]	log Loss: -13.115804
#
# Train set: Average log loss: -11.1247
#
#
# Test set: Average loss: -12.0223
#
# Current Learning rate 0.0001
# Train Epoch: 117 [0/83759 (0%)]	log Loss: -12.146065
#
# Train set: Average log loss: -12.9854
#
#
# Test set: Average loss: -13.1466
#
# Current Learning rate 0.0001
# Train Epoch: 118 [0/83759 (0%)]	log Loss: -13.195818
#
# Train set: Average log loss: -12.7906
#
#
# Test set: Average loss: -13.0243
#
# Current Learning rate 0.0001
# Train Epoch: 119 [0/83759 (0%)]	log Loss: -13.051164
#
# Train set: Average log loss: -12.3539
#
#
# Test set: Average loss: -13.0757
#
# Current Learning rate 0.0001
# Train Epoch: 120 [0/83759 (0%)]	log Loss: -13.104973
#
# Train set: Average log loss: -12.4215
#
#
# Test set: Average loss: -12.6416
#
# Current Learning rate 0.0001
# Train Epoch: 121 [0/83759 (0%)]	log Loss: -12.609232
#
# Train set: Average log loss: -11.6602
#
#
# Test set: Average loss: -13.1797
#
# Current Learning rate 0.0001
# Train Epoch: 122 [0/83759 (0%)]	log Loss: -13.267358
#
# Train set: Average log loss: -12.6578
#
#
# Test set: Average loss: -13.1855
#
# Current Learning rate 0.0001
# Train Epoch: 123 [0/83759 (0%)]	log Loss: -13.253236
#
# Train set: Average log loss: -12.2980
#
#
# Test set: Average loss: -13.1022
#
# Current Learning rate 0.0001
# Train Epoch: 124 [0/83759 (0%)]	log Loss: -13.154672
#
# Train set: Average log loss: -11.2313
#
#
# Test set: Average loss: -12.9616
#
# Current Learning rate 0.0001
# Train Epoch: 125 [0/83759 (0%)]	log Loss: -13.142992
#
# Train set: Average log loss: -13.0283
#
#
# Test set: Average loss: -13.1566
#
# Current Learning rate 0.0001
# Train Epoch: 126 [0/83759 (0%)]	log Loss: -13.207933
#
# Train set: Average log loss: -12.9481
#
#
# Test set: Average loss: -13.2325
#
# Current Learning rate 0.0001
# Train Epoch: 127 [0/83759 (0%)]	log Loss: -13.332981
#
# Train set: Average log loss: -12.4597
#
#
# Test set: Average loss: -12.6182
#
# Current Learning rate 0.0001
# Train Epoch: 128 [0/83759 (0%)]	log Loss: -12.587377
#
# Train set: Average log loss: -11.6632
#
#
# Test set: Average loss: -12.5056
#
# Current Learning rate 0.0001
# Train Epoch: 129 [0/83759 (0%)]	log Loss: -12.501773
#
# Train set: Average log loss: -12.7412
#
#
# Test set: Average loss: -13.2457
#
# Current Learning rate 0.0001
# Train Epoch: 130 [0/83759 (0%)]	log Loss: -13.367080
#
# Train set: Average log loss: -12.4213
#
#
# Test set: Average loss: -13.2071
#
# Current Learning rate 0.0001
# Train Epoch: 131 [0/83759 (0%)]	log Loss: -13.301653
#
# Train set: Average log loss: -11.4504
#
#
# Test set: Average loss: -12.6453
#
# Current Learning rate 0.0001
# Train Epoch: 132 [0/83759 (0%)]	log Loss: -12.809079
#
# Train set: Average log loss: -12.8148
#
#
# Test set: Average loss: -13.2708
#
# Current Learning rate 0.0001
# Train Epoch: 133 [0/83759 (0%)]	log Loss: -13.413478
#
# Train set: Average log loss: -12.8171
#
#
# Test set: Average loss: -13.0319
#
# Current Learning rate 0.0001
# Train Epoch: 134 [0/83759 (0%)]	log Loss: -13.048352
#
# Train set: Average log loss: -12.0104
#
#
# Test set: Average loss: -13.1199
#
# Current Learning rate 0.0001
# Train Epoch: 135 [0/83759 (0%)]	log Loss: -13.292037
#
# Train set: Average log loss: -12.4748
#
#
# Test set: Average loss: -13.1244
#
# Current Learning rate 0.0001
# Train Epoch: 136 [0/83759 (0%)]	log Loss: -13.158214
#
# Train set: Average log loss: -12.4170
#
#
# Test set: Average loss: -11.6836
#
# Current Learning rate 0.0001
# Train Epoch: 137 [0/83759 (0%)]	log Loss: -11.638787
#
# Train set: Average log loss: -11.3815
#
#
# Test set: Average loss: -13.0207
#
# Current Learning rate 0.0001
# Train Epoch: 138 [0/83759 (0%)]	log Loss: -13.092637
#
# Train set: Average log loss: -13.0772
#
#
# Test set: Average loss: -13.2736
#
# Current Learning rate 0.0001
# Train Epoch: 139 [0/83759 (0%)]	log Loss: -13.437507
#
# Train set: Average log loss: -12.8442
#
#
# Test set: Average loss: -13.3171
#
# Current Learning rate 0.0001
# Train Epoch: 140 [0/83759 (0%)]	log Loss: -13.471682
#
# Train set: Average log loss: -12.3952
#
#
# Test set: Average loss: -11.2956
#
# Current Learning rate 0.0001
# Train Epoch: 141 [0/83759 (0%)]	log Loss: -11.248317
#
# Train set: Average log loss: -12.3670
#
#
# Test set: Average loss: -13.1138
#
# Current Learning rate 0.0001
# Train Epoch: 142 [0/83759 (0%)]	log Loss: -13.298642
#
# Train set: Average log loss: -11.9091
#
#
# Test set: Average loss: -12.3412
#
# Current Learning rate 0.0001
# Train Epoch: 143 [0/83759 (0%)]	log Loss: -12.492602
#
# Train set: Average log loss: -12.5016
#
#
# Test set: Average loss: -13.1311
#
# Current Learning rate 0.0001
# Train Epoch: 144 [0/83759 (0%)]	log Loss: -13.330273
#
# Train set: Average log loss: -12.5642
#
#
# Test set: Average loss: -13.3211
#
# Current Learning rate 0.0001
# Train Epoch: 145 [0/83759 (0%)]	log Loss: -13.456795
#
# Train set: Average log loss: -11.7128
#
#
# Test set: Average loss: -13.1699
#
# Current Learning rate 0.0001
# Train Epoch: 146 [0/83759 (0%)]	log Loss: -13.331179
#
# Train set: Average log loss: -12.9089
#
#
# Test set: Average loss: -13.2281
#
# Current Learning rate 0.0001
# Train Epoch: 147 [0/83759 (0%)]	log Loss: -13.433414
#
# Train set: Average log loss: -12.3922
#
#
# Test set: Average loss: -13.2172
#
# Current Learning rate 0.0001
# Train Epoch: 148 [0/83759 (0%)]	log Loss: -13.400739
#
# Train set: Average log loss: -12.1123
#
#
# Test set: Average loss: -13.3466
#
# Current Learning rate 0.0001
# Train Epoch: 149 [0/83759 (0%)]	log Loss: -13.452102
#
# Train set: Average log loss: -12.2150
#
#
# Test set: Average loss: -12.5447
#
# Current Learning rate 0.0001
# Train Epoch: 150 [0/83759 (0%)]	log Loss: -12.711792
#
# Train set: Average log loss: -12.4230
#
#
# Test set: Average loss: -12.8832
#
# Current Learning rate 0.0001
# Train Epoch: 151 [0/83759 (0%)]	log Loss: -13.087192
#
# Train set: Average log loss: -12.7650
#
#
# Test set: Average loss: -12.1442
#
# Current Learning rate 0.0001
# Train Epoch: 152 [0/83759 (0%)]	log Loss: -12.097179
#
# Train set: Average log loss: -11.9358
#
#
# Test set: Average loss: -13.2131
#
# Current Learning rate 0.0001
# Train Epoch: 153 [0/83759 (0%)]	log Loss: -13.290909
#
# Train set: Average log loss: -12.9260
#
#
# Test set: Average loss: -12.2588
#
# Current Learning rate 0.0001
# Train Epoch: 154 [0/83759 (0%)]	log Loss: -12.217886
#
# Train set: Average log loss: -12.1374
#
#
# Test set: Average loss: -13.3589
#
# Current Learning rate 0.0001
# Train Epoch: 155 [0/83759 (0%)]	log Loss: -13.465769
#
# Train set: Average log loss: -12.3034
#
#
# Test set: Average loss: -13.3881
#
# Current Learning rate 0.0001
# Train Epoch: 156 [0/83759 (0%)]	log Loss: -13.580693
#
# Train set: Average log loss: -12.4890
#
#
# Test set: Average loss: -13.2386
#
# Current Learning rate 0.0001
# Train Epoch: 157 [0/83759 (0%)]	log Loss: -13.438190
#
# Train set: Average log loss: -11.0017
#
#
# Test set: Average loss: -12.0940
#
# Current Learning rate 0.0001
# Train Epoch: 158 [0/83759 (0%)]	log Loss: -12.044476
#
# Train set: Average log loss: -13.1013
#
#
# Test set: Average loss: -13.2935
#
# Current Learning rate 0.0001
# Train Epoch: 159 [0/83759 (0%)]	log Loss: -13.370141
#
# Train set: Average log loss: -13.3373
#
#
# Test set: Average loss: -13.4378
#
# Current Learning rate 0.0001
# Train Epoch: 160 [0/83759 (0%)]	log Loss: -13.600697
#
# Train set: Average log loss: -13.1482
#
#
# Test set: Average loss: -13.4295
#
# Current Learning rate 0.0001
# Train Epoch: 161 [0/83759 (0%)]	log Loss: -13.536707
#
# Train set: Average log loss: -13.2797
#
#
# Test set: Average loss: -12.8839
#
# Current Learning rate 0.0001
# Train Epoch: 162 [0/83759 (0%)]	log Loss: -12.887693
#
# Train set: Average log loss: -12.1250
#
#
# Test set: Average loss: -13.3035
#
# Current Learning rate 0.0001
# Train Epoch: 163 [0/83759 (0%)]	log Loss: -13.475729
#
# Train set: Average log loss: -12.5046
#
#
# Test set: Average loss: -13.3662
#
# Current Learning rate 0.0001
# Train Epoch: 164 [0/83759 (0%)]	log Loss: -13.547463
#
# Train set: Average log loss: -12.3629
#
#
# Test set: Average loss: -12.4324
#
# Current Learning rate 0.0001
# Train Epoch: 165 [0/83759 (0%)]	log Loss: -12.574469
#
# Train set: Average log loss: -12.8132
#
#
# Test set: Average loss: -13.2785
#
# Current Learning rate 0.0001
# Train Epoch: 166 [0/83759 (0%)]	log Loss: -13.364388
#
# Train set: Average log loss: -12.0306
#
#
# Test set: Average loss: -13.2637
#
# Current Learning rate 0.0001
# Train Epoch: 167 [0/83759 (0%)]	log Loss: -13.495200
#
# Train set: Average log loss: -12.6466
#
#
# Test set: Average loss: -13.2042
#
# Current Learning rate 0.0001
# Train Epoch: 168 [0/83759 (0%)]	log Loss: -13.422617
#
# Train set: Average log loss: -12.4186
#
#
# Test set: Average loss: -13.3651
#
# Current Learning rate 0.0001
# Train Epoch: 169 [0/83759 (0%)]	log Loss: -13.567587
#
# Train set: Average log loss: -11.7850
#
#
# Test set: Average loss: -13.0452
#
# Current Learning rate 0.0001
# Train Epoch: 170 [0/83759 (0%)]	log Loss: -13.252198
#
# Train set: Average log loss: -12.8291
#
#
# Test set: Average loss: -13.0962
#
# Current Learning rate 0.0001
# Train Epoch: 171 [0/83759 (0%)]	log Loss: -13.106185
#
# Train set: Average log loss: -13.0180
#
#
# Test set: Average loss: -13.3939
#
# Current Learning rate 0.0001
# Train Epoch: 172 [0/83759 (0%)]	log Loss: -13.478083
#
# Train set: Average log loss: -11.9669
#
#
# Test set: Average loss: -13.4734
#
# Current Learning rate 0.0001
# Train Epoch: 173 [0/83759 (0%)]	log Loss: -13.580478
#
# Train set: Average log loss: -12.8034
#
#
# Test set: Average loss: -13.5009
#
# Current Learning rate 0.0001
# Train Epoch: 174 [0/83759 (0%)]	log Loss: -13.693913
#
# Train set: Average log loss: -12.6688
#
#
# Test set: Average loss: -12.6685
#
# Current Learning rate 0.0001
# Train Epoch: 175 [0/83759 (0%)]	log Loss: -12.654934
#
# Train set: Average log loss: -12.0789
#
#
# Test set: Average loss: -12.7947
#
# Current Learning rate 0.0001
# Train Epoch: 176 [0/83759 (0%)]	log Loss: -12.957382
#
# Train set: Average log loss: -12.4406
#
#
# Test set: Average loss: -13.2784
#
# Current Learning rate 0.0001
# Train Epoch: 177 [0/83759 (0%)]	log Loss: -13.335352
#
# Train set: Average log loss: -12.8160
#
#
# Test set: Average loss: -13.5259
#
# Current Learning rate 0.0001
# Train Epoch: 178 [0/83759 (0%)]	log Loss: -13.684352
#
# Train set: Average log loss: -12.2033
#
#
# Test set: Average loss: -13.1804
#
# Current Learning rate 0.0001
# Train Epoch: 179 [0/83759 (0%)]	log Loss: -13.371533
#
# Train set: Average log loss: -12.4634
#
#
# Test set: Average loss: -13.5115
#
# Current Learning rate 0.0001
# Train Epoch: 180 [0/83759 (0%)]	log Loss: -13.694157
#
# Train set: Average log loss: -12.8463
#
#
# Test set: Average loss: -13.1898
#
# Current Learning rate 0.0001
# Train Epoch: 181 [0/83759 (0%)]	log Loss: -13.237437
#
# Train set: Average log loss: -11.0310
#
#
# Test set: Average loss: -13.0526
#
# Current Learning rate 0.0001
# Train Epoch: 182 [0/83759 (0%)]	log Loss: -13.031508
#
# Train set: Average log loss: -13.3113
#
#
# Test set: Average loss: -13.0969
#
# Current Learning rate 0.0001
# Train Epoch: 183 [0/83759 (0%)]	log Loss: -13.128530
#
# Train set: Average log loss: -13.4106
#
#
# Test set: Average loss: -13.5311
#
# Current Learning rate 0.0001
# Train Epoch: 184 [0/83759 (0%)]	log Loss: -13.704037
#
# Train set: Average log loss: -13.2188
#
#
# Test set: Average loss: -13.5550
#
# Current Learning rate 0.0001
# Train Epoch: 185 [0/83759 (0%)]	log Loss: -13.723598
#
# Train set: Average log loss: -13.3127
#
#
# Test set: Average loss: -13.5895
#
# Current Learning rate 0.0001
# Train Epoch: 186 [0/83759 (0%)]	log Loss: -13.754574
#
# Train set: Average log loss: -12.2436
#
#
# Test set: Average loss: -12.7858
#
# Current Learning rate 0.0001
# Train Epoch: 187 [0/83759 (0%)]	log Loss: -12.767584
#
# Train set: Average log loss: -13.2227
#
#
# Test set: Average loss: -13.5532
#
# Current Learning rate 0.0001
# Train Epoch: 188 [0/83759 (0%)]	log Loss: -13.675449
#
# Train set: Average log loss: -11.8696
#
#
# Test set: Average loss: -12.6308
#
# Current Learning rate 0.0001
# Train Epoch: 189 [0/83759 (0%)]	log Loss: -12.582742
#
# Train set: Average log loss: -12.5632
#
#
# Test set: Average loss: -12.3169
#
# Current Learning rate 0.0001
# Train Epoch: 190 [0/83759 (0%)]	log Loss: -12.407311
#
# Train set: Average log loss: -12.7032
#
#
# Test set: Average loss: -13.5232
#
# Current Learning rate 0.0001
# Train Epoch: 191 [0/83759 (0%)]	log Loss: -13.659144
#
# Train set: Average log loss: -13.3691
#
#
# Test set: Average loss: -13.4633
#
# Current Learning rate 0.0001
# Train Epoch: 192 [0/83759 (0%)]	log Loss: -13.534183
#
# Train set: Average log loss: -11.8316
#
#
# Test set: Average loss: -13.2843
#
# Current Learning rate 0.0001
# Train Epoch: 193 [0/83759 (0%)]	log Loss: -13.371278
#
# Train set: Average log loss: -13.0576
#
#
# Test set: Average loss: -13.6095
#
# Current Learning rate 0.0001
# Train Epoch: 194 [0/83759 (0%)]	log Loss: -13.741177
#
# Train set: Average log loss: -13.2215
#
#
# Test set: Average loss: -13.6324
#
# Current Learning rate 0.0001
# Train Epoch: 195 [0/83759 (0%)]	log Loss: -13.799670
#
# Train set: Average log loss: -12.2255
#
#
# Test set: Average loss: -13.5930
#
# Current Learning rate 0.0001
# Train Epoch: 196 [0/83759 (0%)]	log Loss: -13.715586
#
# Train set: Average log loss: -12.7688
#
#
# Test set: Average loss: -13.1723
#
# Current Learning rate 0.0001
# Train Epoch: 197 [0/83759 (0%)]	log Loss: -13.206805
#
# Train set: Average log loss: -12.1118
#
#
# Test set: Average loss: -12.2181
#
# Current Learning rate 0.0001
# Train Epoch: 198 [0/83759 (0%)]	log Loss: -12.296789
#
# Train set: Average log loss: -12.9737
#
#
# Test set: Average loss: -13.6621
#
# Current Learning rate 0.0001
# Train Epoch: 199 [0/83759 (0%)]	log Loss: -13.804487
#
# Train set: Average log loss: -12.8645
#
#
# Test set: Average loss: -13.5097
#
# Current Learning rate 0.0001
# Train Epoch: 200 [0/83759 (0%)]	log Loss: -13.712751
#
# Train set: Average log loss: -11.0623
#
#
# Test set: Average loss: -13.3193
#
# Current Learning rate 0.0001
# Train Epoch: 201 [0/83759 (0%)]	log Loss: -13.382561
#
# Train set: Average log loss: -13.5045
#
#
# Test set: Average loss: -13.3156
#
# Current Learning rate 0.0001
# Train Epoch: 202 [0/83759 (0%)]	log Loss: -13.348643
#
# Train set: Average log loss: -13.5146
#
#
# Test set: Average loss: -13.6282
#
# Current Learning rate 0.0001
# Train Epoch: 203 [0/83759 (0%)]	log Loss: -13.754919
#
# Train set: Average log loss: -13.2321
#
#
# Test set: Average loss: -13.4979
#
# Current Learning rate 0.0001
# Train Epoch: 204 [0/83759 (0%)]	log Loss: -13.573556
#
# Train set: Average log loss: -13.3495
#
#
# Test set: Average loss: -13.5899
#
# Current Learning rate 0.0001
# Train Epoch: 205 [0/83759 (0%)]	log Loss: -13.663937
#
# Train set: Average log loss: -13.4460
#
#
# Test set: Average loss: -11.6946
#
# Current Learning rate 0.0001
# Train Epoch: 206 [0/83759 (0%)]	log Loss: -11.669327
#
# Train set: Average log loss: -12.0291
#
#
# Test set: Average loss: -13.0246
#
# Current Learning rate 0.0001
# Train Epoch: 207 [0/83759 (0%)]	log Loss: -13.129765
#
# Train set: Average log loss: -13.4729
#
#
# Test set: Average loss: -13.3632
#
# Current Learning rate 0.0001
# Train Epoch: 208 [0/83759 (0%)]	log Loss: -13.407857
#
# Train set: Average log loss: -12.1437
#
#
# Test set: Average loss: -12.8639
#
# Current Learning rate 0.0001
# Train Epoch: 209 [0/83759 (0%)]	log Loss: -12.969890
#
# Train set: Average log loss: -13.3116
#
#
# Test set: Average loss: -13.6871
#
# Current Learning rate 0.0001
# Train Epoch: 210 [0/83759 (0%)]	log Loss: -13.789078
#
# Train set: Average log loss: -12.2583
#
#
# Test set: Average loss: -13.5780
#
# Current Learning rate 0.0001
# Train Epoch: 211 [0/83759 (0%)]	log Loss: -13.645957
#
# Train set: Average log loss: -12.9533
#
#
# Test set: Average loss: -13.6771
#
# Current Learning rate 0.0001
# Train Epoch: 212 [0/83759 (0%)]	log Loss: -13.806572
#
# Train set: Average log loss: -12.1425
#
#
# Test set: Average loss: -12.7909
#
# Current Learning rate 0.0001
# Train Epoch: 213 [0/83759 (0%)]	log Loss: -12.900321
#
# Train set: Average log loss: -13.1943
#
#
# Test set: Average loss: -13.5936
#
# Current Learning rate 0.0001
# Train Epoch: 214 [0/83759 (0%)]	log Loss: -13.638869
#
# Train set: Average log loss: -12.8540
#
#
# Test set: Average loss: -13.7062
#
# Current Learning rate 0.0001
# Train Epoch: 215 [0/83759 (0%)]	log Loss: -13.829075
#
# Train set: Average log loss: -11.7077
#
#
# Test set: Average loss: -13.3306
#
# Current Learning rate 0.0001
# Train Epoch: 216 [0/83759 (0%)]	log Loss: -13.469553
#
# Train set: Average log loss: -12.9257
#
#
# Test set: Average loss: -13.3983
#
# Current Learning rate 0.0001
# Train Epoch: 217 [0/83759 (0%)]	log Loss: -13.423143
#
# Train set: Average log loss: -13.2664
#
#
# Test set: Average loss: -13.2668
#
# Current Learning rate 0.0001
# Train Epoch: 218 [0/83759 (0%)]	log Loss: -13.391286
#
# Train set: Average log loss: -13.4000
#
#
# Test set: Average loss: -13.1096
#
# Current Learning rate 0.0001
# Train Epoch: 219 [0/83759 (0%)]	log Loss: -13.099385
#
# Train set: Average log loss: -12.6175
#
#
# Test set: Average loss: -13.5155
#
# Current Learning rate 0.0001
# Train Epoch: 220 [0/83759 (0%)]	log Loss: -13.537792
#
# Train set: Average log loss: -12.6945
#
#
# Test set: Average loss: -13.6539
#
# Current Learning rate 0.0001
# Train Epoch: 221 [0/83759 (0%)]	log Loss: -13.726859
#
# Train set: Average log loss: -12.1458
#
#
# Test set: Average loss: -12.6885
#
# Current Learning rate 0.0001
# Train Epoch: 222 [0/83759 (0%)]	log Loss: -12.779020
#
# Train set: Average log loss: -13.3315
#
#
# Test set: Average loss: -13.6703
#
# Current Learning rate 0.0001
# Train Epoch: 223 [0/83759 (0%)]	log Loss: -13.707443
#
# Train set: Average log loss: -12.5790
#
#
# Test set: Average loss: -13.6412
#
# Current Learning rate 0.0001
# Train Epoch: 224 [0/83759 (0%)]	log Loss: -13.785119
#
# Train set: Average log loss: -12.4325
#
#
# Test set: Average loss: -13.3789
#
# Current Learning rate 0.0001
# Train Epoch: 225 [0/83759 (0%)]	log Loss: -13.514610
#
# Train set: Average log loss: -13.0014
#
#
# Test set: Average loss: -13.4839
#
# Current Learning rate 0.0001
# Train Epoch: 226 [0/83759 (0%)]	log Loss: -13.624690
#
# Train set: Average log loss: -13.0241
#
#
# Test set: Average loss: -12.1435
#
# Current Learning rate 0.0001
# Train Epoch: 227 [0/83759 (0%)]	log Loss: -12.222613
#
# Train set: Average log loss: -11.9905
#
#
# Test set: Average loss: -13.0662
#
# Current Learning rate 0.0001
# Train Epoch: 228 [0/83759 (0%)]	log Loss: -13.190492
#
# Train set: Average log loss: -13.1520
#
#
# Test set: Average loss: -13.7023
#
# Current Learning rate 0.0001
# Train Epoch: 229 [0/83759 (0%)]	log Loss: -13.813407
#
# Train set: Average log loss: -13.0090
#
#
# Test set: Average loss: -13.2143
#
# Current Learning rate 0.0001
# Train Epoch: 230 [0/83759 (0%)]	log Loss: -13.163113
#
# Train set: Average log loss: -12.7247
#
#
# Test set: Average loss: -13.6546
#
# Current Learning rate 0.0001
# Train Epoch: 231 [0/83759 (0%)]	log Loss: -13.782664
#
# Train set: Average log loss: -12.5516
#
#
# Test set: Average loss: -13.6449
#
# Current Learning rate 0.0001
# Train Epoch: 232 [0/83759 (0%)]	log Loss: -13.779714
#
# Train set: Average log loss: -12.5959
#
#
# Test set: Average loss: -13.0668
#
# Current Learning rate 0.0001
# Train Epoch: 233 [0/83759 (0%)]	log Loss: -13.204333
#
# Train set: Average log loss: -12.3450
#
#
# Test set: Average loss: -13.1261
#
# Current Learning rate 0.0001
# Train Epoch: 234 [0/83759 (0%)]	log Loss: -13.241150
#
# Train set: Average log loss: -12.8130
#
#
# Test set: Average loss: -12.8824
#
# Current Learning rate 0.0001
# Train Epoch: 235 [0/83759 (0%)]	log Loss: -12.980393
#
# Train set: Average log loss: -13.0127
#
#
# Test set: Average loss: -13.1485
#
# Current Learning rate 0.0001
# Train Epoch: 236 [0/83759 (0%)]	log Loss: -13.268776
#
# Train set: Average log loss: -12.5664
#
#
# Test set: Average loss: -12.4349
#
# Current Learning rate 0.0001
# Train Epoch: 237 [0/83759 (0%)]	log Loss: -12.538221
#
# Train set: Average log loss: -12.8783
#
#
# Test set: Average loss: -12.1029
#
# Current Learning rate 0.0001
# Train Epoch: 238 [0/83759 (0%)]	log Loss: -12.199343
#
# Train set: Average log loss: -12.2536
#
#
# Test set: Average loss: -13.2733
#
# Current Learning rate 0.0001
# Train Epoch: 239 [0/83759 (0%)]	log Loss: -13.401192
#
# Train set: Average log loss: -12.4570
#
#
# Test set: Average loss: -12.5661
#
# Current Learning rate 0.0001
# Train Epoch: 240 [0/83759 (0%)]	log Loss: -12.529251
#
# Train set: Average log loss: -12.9308
#
#
# Test set: Average loss: -13.7843
#
# Current Learning rate 0.0001
# Train Epoch: 241 [0/83759 (0%)]	log Loss: -13.886660
#
# Train set: Average log loss: -13.0574
#
#
# Test set: Average loss: -13.5228
#
# Current Learning rate 0.0001
# Train Epoch: 242 [0/83759 (0%)]	log Loss: -13.657749
#
# Train set: Average log loss: -13.5936
#
#
# Test set: Average loss: -13.3646
#
# Current Learning rate 0.0001
# Train Epoch: 243 [0/83759 (0%)]	log Loss: -13.348620
#
# Train set: Average log loss: -11.7568
#
#
# Test set: Average loss: -13.6877
#
# Current Learning rate 0.0001
# Train Epoch: 244 [0/83759 (0%)]	log Loss: -13.756801
#
# Train set: Average log loss: -12.5956
#
#
# Test set: Average loss: -13.5388
#
# Current Learning rate 0.0001
# Train Epoch: 245 [0/83759 (0%)]	log Loss: -13.559210
#
# Train set: Average log loss: -12.6865
#
#
# Test set: Average loss: -13.6813
#
# Current Learning rate 0.0001
# Train Epoch: 246 [0/83759 (0%)]	log Loss: -13.759135
#
# Train set: Average log loss: -12.7867
#
#
# Test set: Average loss: -13.2900
#
# Current Learning rate 0.0001
# Train Epoch: 247 [0/83759 (0%)]	log Loss: -13.286752
#
# Train set: Average log loss: -13.0728
#
#
# Test set: Average loss: -13.3330
#
# Current Learning rate 0.0001
# Train Epoch: 248 [0/83759 (0%)]	log Loss: -13.342696
#
# Train set: Average log loss: -13.2976
#
#
# Test set: Average loss: -13.7372
#
# Current Learning rate 0.0001
# Train Epoch: 249 [0/83759 (0%)]	log Loss: -13.881699
#
# Train set: Average log loss: -13.3393
#
#
# Test set: Average loss: -12.9553
#
# Current Learning rate 0.0001
# Train Epoch: 250 [0/83759 (0%)]	log Loss: -12.950907
#
# Train set: Average log loss: -12.6014
#
#
# Test set: Average loss: -13.3020
#
# Current Learning rate 0.0001
# Train Epoch: 251 [0/83759 (0%)]	log Loss: -13.438909
#
# Train set: Average log loss: -12.6941
#
#
# Test set: Average loss: -13.5652
#
# Current Learning rate 0.0001
# Train Epoch: 252 [0/83759 (0%)]	log Loss: -13.699153
#
# Train set: Average log loss: -12.7664
#
#
# Test set: Average loss: -13.5214
#
# Current Learning rate 0.0001
# Train Epoch: 253 [0/83759 (0%)]	log Loss: -13.642115
#
# Train set: Average log loss: -12.5360
#
#
# Test set: Average loss: -13.4618
#
# Current Learning rate 0.0001
# Train Epoch: 254 [0/83759 (0%)]	log Loss: -13.564200
#
# Train set: Average log loss: -13.2118
#
#
# Test set: Average loss: -13.6223
#
# Current Learning rate 0.0001
# Train Epoch: 255 [0/83759 (0%)]	log Loss: -13.634410
#
# Train set: Average log loss: -12.3217
#
#
# Test set: Average loss: -12.9175
#
# Current Learning rate 0.0001
# Train Epoch: 256 [0/83759 (0%)]	log Loss: -13.029398
#
# Train set: Average log loss: -12.7169
#
#
# Test set: Average loss: -13.7905
#
# Current Learning rate 0.0001
# Train Epoch: 257 [0/83759 (0%)]	log Loss: -13.889798
#
# Train set: Average log loss: -12.8350
#
#
# Test set: Average loss: -13.8519
#
# Current Learning rate 0.0001
# Train Epoch: 258 [0/83759 (0%)]	log Loss: -13.985762
#
# Train set: Average log loss: -13.2410
#
#
# Test set: Average loss: -13.9326
#
# Current Learning rate 0.0001
# Train Epoch: 259 [0/83759 (0%)]	log Loss: -14.060986
#
# Train set: Average log loss: -12.0932
#
#
# Test set: Average loss: -12.9225
#
# Current Learning rate 0.0001
# Train Epoch: 260 [0/83759 (0%)]	log Loss: -12.906243
#
# Train set: Average log loss: -12.6306
#
#
# Test set: Average loss: -12.3391
#
# Current Learning rate 0.0001
# Train Epoch: 261 [0/83759 (0%)]	log Loss: -12.314892
#
# Train set: Average log loss: -12.4621
#
#
# Test set: Average loss: -13.5917
#
# Current Learning rate 0.0001
# Train Epoch: 262 [0/83759 (0%)]	log Loss: -13.714615
#
# Train set: Average log loss: -12.6660
#
#
# Test set: Average loss: -13.0553
#
# Current Learning rate 0.0001
# Train Epoch: 263 [0/83759 (0%)]	log Loss: -13.194878
#
# Train set: Average log loss: -12.9031
#
#
# Test set: Average loss: -13.5427
#
# Current Learning rate 0.0001
# Train Epoch: 264 [0/83759 (0%)]	log Loss: -13.710614
#
# Train set: Average log loss: -12.9464
#
#
# Test set: Average loss: -13.5458
#
# Current Learning rate 0.0001
# Train Epoch: 265 [0/83759 (0%)]	log Loss: -13.570310
#
# Train set: Average log loss: -13.4460
#
#
# Test set: Average loss: -13.9331
#
# Current Learning rate 0.0001
# Train Epoch: 266 [0/83759 (0%)]	log Loss: -14.081617
#
# Train set: Average log loss: -13.5406
#
#
# Test set: Average loss: -12.9503
#
# Current Learning rate 0.0001
# Train Epoch: 267 [0/83759 (0%)]	log Loss: -12.928708
#
# Train set: Average log loss: -12.4051
#
#
# Test set: Average loss: -13.5767
#
# Current Learning rate 0.0001
# Train Epoch: 268 [0/83759 (0%)]	log Loss: -13.624218
#
# Train set: Average log loss: -13.2071
#
#
# Test set: Average loss: -13.3347
#
# Current Learning rate 0.0001
# Train Epoch: 269 [0/83759 (0%)]	log Loss: -13.472351
#
# Train set: Average log loss: -12.8612
#
#
# Test set: Average loss: -13.8273
#
# Current Learning rate 0.0001
# Train Epoch: 270 [0/83759 (0%)]	log Loss: -14.024455
#
# Train set: Average log loss: -13.0712
#
#
# Test set: Average loss: -13.3941
#
# Current Learning rate 0.0001
# Train Epoch: 271 [0/83759 (0%)]	log Loss: -13.396248
#
# Train set: Average log loss: -12.6814
#
#
# Test set: Average loss: -12.0877
#
# Current Learning rate 0.0001
# Train Epoch: 272 [0/83759 (0%)]	log Loss: -12.175589
#
# Train set: Average log loss: -12.5052
#
#
# Test set: Average loss: -13.8245
#
# Current Learning rate 0.0001
# Train Epoch: 273 [0/83759 (0%)]	log Loss: -13.932091
#
# Train set: Average log loss: -13.1690
#
#
# Test set: Average loss: -12.9541
#
# Current Learning rate 0.0001
# Train Epoch: 274 [0/83759 (0%)]	log Loss: -13.077798
#
# Train set: Average log loss: -12.3461
#
#
# Test set: Average loss: -12.5207
#
# Current Learning rate 0.0001
# Train Epoch: 275 [0/83759 (0%)]	log Loss: -12.485861
#
# Train set: Average log loss: -13.0376
#
#
# Test set: Average loss: -13.1870
#
# Current Learning rate 0.0001
# Train Epoch: 276 [0/83759 (0%)]	log Loss: -13.201299
#
# Train set: Average log loss: -13.4724
#
#
# Test set: Average loss: -13.3979
#
# Current Learning rate 0.0001
# Train Epoch: 277 [0/83759 (0%)]	log Loss: -13.550898
#
# Train set: Average log loss: -12.6745
#
#
# Test set: Average loss: -13.8521
#
# Current Learning rate 0.0001
# Train Epoch: 278 [0/83759 (0%)]	log Loss: -14.000649
#
# Train set: Average log loss: -13.1310
#
#
# Test set: Average loss: -13.6034
#
# Current Learning rate 0.0001
# Train Epoch: 279 [0/83759 (0%)]	log Loss: -13.777783
#
# Train set: Average log loss: -12.7444
#
#
# Test set: Average loss: -13.9967
#
# Current Learning rate 0.0001
# Train Epoch: 280 [0/83759 (0%)]	log Loss: -14.097302
#
# Train set: Average log loss: -12.6685
#
#
# Test set: Average loss: -13.8304
#
# Current Learning rate 0.0001
# Train Epoch: 281 [0/83759 (0%)]	log Loss: -13.891420
#
# Train set: Average log loss: -13.3129
#
#
# Test set: Average loss: -13.9144
#
# Current Learning rate 0.0001
# Train Epoch: 282 [0/83759 (0%)]	log Loss: -13.994328
#
# Train set: Average log loss: -12.8004
#
#
# Test set: Average loss: -13.6976
#
# Current Learning rate 0.0001
# Train Epoch: 283 [0/83759 (0%)]	log Loss: -13.867063
#
# Train set: Average log loss: -12.4886
#
#
# Test set: Average loss: -13.3890
#
# Current Learning rate 0.0001
# Train Epoch: 284 [0/83759 (0%)]	log Loss: -13.415770
#
# Train set: Average log loss: -13.2603
#
#
# Test set: Average loss: -13.8524
#
# Current Learning rate 0.0001
# Train Epoch: 285 [0/83759 (0%)]	log Loss: -14.031244
#
# Train set: Average log loss: -12.9469
#
#
# Test set: Average loss: -13.4956
#
# Current Learning rate 0.0001
# Train Epoch: 286 [0/83759 (0%)]	log Loss: -13.636232
#
# Train set: Average log loss: -12.8525
#
#
# Test set: Average loss: -12.8851
#
# Current Learning rate 0.0001
# Train Epoch: 287 [0/83759 (0%)]	log Loss: -12.986313
#
# Train set: Average log loss: -12.1008
#
#
# Test set: Average loss: -13.7839
#
# Current Learning rate 0.0001
# Train Epoch: 288 [0/83759 (0%)]	log Loss: -13.942287
#
# Train set: Average log loss: -12.6779
#
#
# Test set: Average loss: -13.8437
#
# Current Learning rate 0.0001
# Train Epoch: 289 [0/83759 (0%)]	log Loss: -13.991962
#
# Train set: Average log loss: -12.7931
#
#
# Test set: Average loss: -13.5774
#
# Current Learning rate 0.0001
# Train Epoch: 290 [0/83759 (0%)]	log Loss: -13.740269
#
# Train set: Average log loss: -12.8874
#
#
# Test set: Average loss: -13.5945
#
# Current Learning rate 0.0001
# Train Epoch: 291 [0/83759 (0%)]	log Loss: -13.766711
#
# Train set: Average log loss: -12.9608
#
#
# Test set: Average loss: -13.9760
#
# Current Learning rate 0.0001
# Train Epoch: 292 [0/83759 (0%)]	log Loss: -14.126993
#
# Train set: Average log loss: -13.2955
#
#
# Test set: Average loss: -13.8947
#
# Current Learning rate 0.0001
# Train Epoch: 293 [0/83759 (0%)]	log Loss: -13.965627
#
# Train set: Average log loss: -13.7344
#
#
# Test set: Average loss: -13.9380
#
# Current Learning rate 0.0001
# Train Epoch: 294 [0/83759 (0%)]	log Loss: -14.121508
#
# Train set: Average log loss: -12.5738
#
#
# Test set: Average loss: -13.9784
#
# Current Learning rate 0.0001
# Train Epoch: 295 [0/83759 (0%)]	log Loss: -14.071507
#
# Train set: Average log loss: -12.9996
#
#
# Test set: Average loss: -13.8219
#
# Current Learning rate 0.0001
# Train Epoch: 296 [0/83759 (0%)]	log Loss: -13.905271
#
# Train set: Average log loss: -13.1250
#
#
# Test set: Average loss: -14.0162
#
# Current Learning rate 0.0001
# Train Epoch: 297 [0/83759 (0%)]	log Loss: -14.149288
#
# Train set: Average log loss: -12.1182
#
#
# Test set: Average loss: -13.5243
#
# Current Learning rate 0.0001
# Train Epoch: 298 [0/83759 (0%)]	log Loss: -13.583392
#
# Train set: Average log loss: -12.9824
#
#
# Test set: Average loss: -14.0026
#
# Current Learning rate 0.0001
# Train Epoch: 299 [0/83759 (0%)]	log Loss: -14.127202
#
# Train set: Average log loss: -12.9350
#
#
# Test set: Average loss: -13.9933
#
# Current Learning rate 0.0001
# Train Epoch: 300 [0/83759 (0%)]	log Loss: -14.100764
#
# Train set: Average log loss: -13.1783
#
#
# Test set: Average loss: -13.6860
#
# Current Learning rate 0.0001
# Train Epoch: 301 [0/83759 (0%)]	log Loss: -13.730870
#
# Train set: Average log loss: -13.5210
#
#
# Test set: Average loss: -14.0214
#
# Current Learning rate 0.0001
# Train Epoch: 302 [0/83759 (0%)]	log Loss: -14.193570
#
# Train set: Average log loss: -12.9080
#
#
# Test set: Average loss: -13.2556
#
# Current Learning rate 0.0001
# Train Epoch: 303 [0/83759 (0%)]	log Loss: -13.256312
#
# Train set: Average log loss: -13.2717
#
#
# Test set: Average loss: -13.5668
#
# Current Learning rate 0.0001
# Train Epoch: 304 [0/83759 (0%)]	log Loss: -13.597352
#
# Train set: Average log loss: -12.6468
#
#
# Test set: Average loss: -12.0729
#
# Current Learning rate 0.0001
# Train Epoch: 305 [0/83759 (0%)]	log Loss: -12.138910
#
# Train set: Average log loss: -12.8572
#
#
# ...
#
# Train set: Average log loss: -16.2987
#
#
# Test set: Average loss: -15.5888
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2910 [0/83759 (0%)]	log Loss: -16.316893
#
# Train set: Average log loss: -16.2988
#
#
# Test set: Average loss: -15.5888
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2911 [0/83759 (0%)]	log Loss: -16.316923
#
# Train set: Average log loss: -16.2988
#
#
# Test set: Average loss: -15.5888
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2912 [0/83759 (0%)]	log Loss: -16.316915
#
# Train set: Average log loss: -16.2989
#
#
# Test set: Average loss: -15.5889
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2913 [0/83759 (0%)]	log Loss: -16.317075
#
# Train set: Average log loss: -16.2990
#
#
# Test set: Average loss: -15.5889
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2914 [0/83759 (0%)]	log Loss: -16.317131
#
# Train set: Average log loss: -16.2990
#
#
# Test set: Average loss: -15.5889
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2915 [0/83759 (0%)]	log Loss: -16.317266
#
# Train set: Average log loss: -16.2991
#
#
# Test set: Average loss: -15.5890
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2916 [0/83759 (0%)]	log Loss: -16.317243
#
# Train set: Average log loss: -16.2991
#
#
# Test set: Average loss: -15.5890
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2917 [0/83759 (0%)]	log Loss: -16.317255
#
# Train set: Average log loss: -16.2992
#
#
# Test set: Average loss: -15.5890
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2918 [0/83759 (0%)]	log Loss: -16.317285
#
# Train set: Average log loss: -16.2993
#
#
# Test set: Average loss: -15.5891
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2919 [0/83759 (0%)]	log Loss: -16.317405
#
# Train set: Average log loss: -16.2993
#
#
# Test set: Average loss: -15.5891
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2920 [0/83759 (0%)]	log Loss: -16.317530
#
# Train set: Average log loss: -16.2994
#
#
# Test set: Average loss: -15.5892
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2921 [0/83759 (0%)]	log Loss: -16.317452
#
# Train set: Average log loss: -16.2995
#
#
# Test set: Average loss: -15.5892
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2922 [0/83759 (0%)]	log Loss: -16.317553
#
# Train set: Average log loss: -16.2995
#
#
# Test set: Average loss: -15.5892
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2923 [0/83759 (0%)]	log Loss: -16.317648
#
# Train set: Average log loss: -16.2996
#
#
# Test set: Average loss: -15.5893
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2924 [0/83759 (0%)]	log Loss: -16.317737
#
# Train set: Average log loss: -16.2996
#
#
# Test set: Average loss: -15.5893
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2925 [0/83759 (0%)]	log Loss: -16.317740
#
# Train set: Average log loss: -16.2997
#
#
# Test set: Average loss: -15.5893
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2926 [0/83759 (0%)]	log Loss: -16.317812
#
# Train set: Average log loss: -16.2997
#
#
# Test set: Average loss: -15.5894
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2927 [0/83759 (0%)]	log Loss: -16.317890
#
# Train set: Average log loss: -16.2998
#
#
# Test set: Average loss: -15.5894
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2928 [0/83759 (0%)]	log Loss: -16.317869
#
# Train set: Average log loss: -16.2999
#
#
# Test set: Average loss: -15.5894
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2929 [0/83759 (0%)]	log Loss: -16.318050
#
# Train set: Average log loss: -16.2999
#
#
# Test set: Average loss: -15.5895
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2930 [0/83759 (0%)]	log Loss: -16.317991
#
# Train set: Average log loss: -16.3000
#
#
# Test set: Average loss: -15.5895
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2931 [0/83759 (0%)]	log Loss: -16.318120
#
# Train set: Average log loss: -16.3000
#
#
# Test set: Average loss: -15.5895
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2932 [0/83759 (0%)]	log Loss: -16.318058
#
# Train set: Average log loss: -16.3001
#
#
# Test set: Average loss: -15.5896
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2933 [0/83759 (0%)]	log Loss: -16.318187
#
# Train set: Average log loss: -16.3002
#
#
# Test set: Average loss: -15.5896
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2934 [0/83759 (0%)]	log Loss: -16.318223
#
# Train set: Average log loss: -16.3002
#
#
# Test set: Average loss: -15.5896
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2935 [0/83759 (0%)]	log Loss: -16.318288
#
# Train set: Average log loss: -16.3003
#
#
# Test set: Average loss: -15.5897
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2936 [0/83759 (0%)]	log Loss: -16.318360
#
# Train set: Average log loss: -16.3003
#
#
# Test set: Average loss: -15.5897
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2937 [0/83759 (0%)]	log Loss: -16.318487
#
# Train set: Average log loss: -16.3004
#
#
# Test set: Average loss: -15.5897
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2938 [0/83759 (0%)]	log Loss: -16.318463
#
# Train set: Average log loss: -16.3005
#
#
# Test set: Average loss: -15.5898
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2939 [0/83759 (0%)]	log Loss: -16.318586
#
# Train set: Average log loss: -16.3005
#
#
# Test set: Average loss: -15.5898
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2940 [0/83759 (0%)]	log Loss: -16.318581
#
# Train set: Average log loss: -16.3006
#
#
# Test set: Average loss: -15.5898
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2941 [0/83759 (0%)]	log Loss: -16.318602
#
# Train set: Average log loss: -16.3006
#
#
# Test set: Average loss: -15.5899
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2942 [0/83759 (0%)]	log Loss: -16.318697
#
# Train set: Average log loss: -16.3007
#
#
# Test set: Average loss: -15.5899
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2943 [0/83759 (0%)]	log Loss: -16.318771
#
# Train set: Average log loss: -16.3008
#
#
# Test set: Average loss: -15.5899
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2944 [0/83759 (0%)]	log Loss: -16.318819
#
# Train set: Average log loss: -16.3008
#
#
# Test set: Average loss: -15.5899
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2945 [0/83759 (0%)]	log Loss: -16.318922
#
# Train set: Average log loss: -16.3009
#
#
# Test set: Average loss: -15.5900
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2946 [0/83759 (0%)]	log Loss: -16.318855
#
# Train set: Average log loss: -16.3010
#
#
# Test set: Average loss: -15.5900
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2947 [0/83759 (0%)]	log Loss: -16.318976
#
# Train set: Average log loss: -16.3010
#
#
# Test set: Average loss: -15.5900
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2948 [0/83759 (0%)]	log Loss: -16.319079
#
# Train set: Average log loss: -16.3011
#
#
# Test set: Average loss: -15.5901
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2949 [0/83759 (0%)]	log Loss: -16.319095
#
# Train set: Average log loss: -16.3011
#
#
# Test set: Average loss: -15.5901
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2950 [0/83759 (0%)]	log Loss: -16.319213
#
# Train set: Average log loss: -16.3012
#
#
# Test set: Average loss: -15.5901
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2951 [0/83759 (0%)]	log Loss: -16.319223
#
# Train set: Average log loss: -16.3012
#
#
# Test set: Average loss: -15.5902
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2952 [0/83759 (0%)]	log Loss: -16.319349
#
# Train set: Average log loss: -16.3013
#
#
# Test set: Average loss: -15.5902
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2953 [0/83759 (0%)]	log Loss: -16.319402
#
# Train set: Average log loss: -16.3014
#
#
# Test set: Average loss: -15.5902
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2954 [0/83759 (0%)]	log Loss: -16.319498
#
# Train set: Average log loss: -16.3014
#
#
# Test set: Average loss: -15.5903
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2955 [0/83759 (0%)]	log Loss: -16.319447
#
# Train set: Average log loss: -16.3015
#
#
# Test set: Average loss: -15.5903
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2956 [0/83759 (0%)]	log Loss: -16.319596
#
# Train set: Average log loss: -16.3016
#
#
# Test set: Average loss: -15.5904
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2957 [0/83759 (0%)]	log Loss: -16.319591
#
# Train set: Average log loss: -16.3016
#
#
# Test set: Average loss: -15.5904
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2958 [0/83759 (0%)]	log Loss: -16.319705
#
# Train set: Average log loss: -16.3017
#
#
# Test set: Average loss: -15.5904
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2959 [0/83759 (0%)]	log Loss: -16.319693
#
# Train set: Average log loss: -16.3017
#
#
# Test set: Average loss: -15.5904
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2960 [0/83759 (0%)]	log Loss: -16.319840
#
# Train set: Average log loss: -16.3018
#
#
# Test set: Average loss: -15.5905
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2961 [0/83759 (0%)]	log Loss: -16.319860
#
# Train set: Average log loss: -16.3018
#
#
# Test set: Average loss: -15.5905
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2962 [0/83759 (0%)]	log Loss: -16.319944
#
# Train set: Average log loss: -16.3019
#
#
# Test set: Average loss: -15.5906
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2963 [0/83759 (0%)]	log Loss: -16.319917
#
# Train set: Average log loss: -16.3020
#
#
# Test set: Average loss: -15.5906
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2964 [0/83759 (0%)]	log Loss: -16.319996
#
# Train set: Average log loss: -16.3020
#
#
# Test set: Average loss: -15.5906
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2965 [0/83759 (0%)]	log Loss: -16.319982
#
# Train set: Average log loss: -16.3021
#
#
# Test set: Average loss: -15.5907
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2966 [0/83759 (0%)]	log Loss: -16.320112
#
# Train set: Average log loss: -16.3021
#
#
# Test set: Average loss: -15.5907
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2967 [0/83759 (0%)]	log Loss: -16.320093
#
# Train set: Average log loss: -16.3022
#
#
# Test set: Average loss: -15.5907
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2968 [0/83759 (0%)]	log Loss: -16.320197
#
# Train set: Average log loss: -16.3023
#
#
# Test set: Average loss: -15.5907
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2969 [0/83759 (0%)]	log Loss: -16.320250
#
# Train set: Average log loss: -16.3023
#
#
# Test set: Average loss: -15.5908
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2970 [0/83759 (0%)]	log Loss: -16.320198
#
# Train set: Average log loss: -16.3024
#
#
# Test set: Average loss: -15.5908
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2971 [0/83759 (0%)]	log Loss: -16.320325
#
# Train set: Average log loss: -16.3024
#
#
# Test set: Average loss: -15.5908
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2972 [0/83759 (0%)]	log Loss: -16.320333
#
# Train set: Average log loss: -16.3025
#
#
# Test set: Average loss: -15.5909
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2973 [0/83759 (0%)]	log Loss: -16.320459
#
# Train set: Average log loss: -16.3026
#
#
# Test set: Average loss: -15.5909
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2974 [0/83759 (0%)]	log Loss: -16.320437
#
# Train set: Average log loss: -16.3026
#
#
# Test set: Average loss: -15.5909
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2975 [0/83759 (0%)]	log Loss: -16.320541
#
# Train set: Average log loss: -16.3027
#
#
# Test set: Average loss: -15.5910
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2976 [0/83759 (0%)]	log Loss: -16.320440
#
# Train set: Average log loss: -16.3027
#
#
# Test set: Average loss: -15.5910
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2977 [0/83759 (0%)]	log Loss: -16.320575
#
# Train set: Average log loss: -16.3028
#
#
# Test set: Average loss: -15.5910
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2978 [0/83759 (0%)]	log Loss: -16.320678
#
# Train set: Average log loss: -16.3029
#
#
# Test set: Average loss: -15.5911
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2979 [0/83759 (0%)]	log Loss: -16.320738
#
# Train set: Average log loss: -16.3029
#
#
# Test set: Average loss: -15.5911
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2980 [0/83759 (0%)]	log Loss: -16.320720
#
# Train set: Average log loss: -16.3030
#
#
# Test set: Average loss: -15.5911
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2981 [0/83759 (0%)]	log Loss: -16.320782
#
# Train set: Average log loss: -16.3030
#
#
# Test set: Average loss: -15.5912
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2982 [0/83759 (0%)]	log Loss: -16.320879
#
# Train set: Average log loss: -16.3031
#
#
# Test set: Average loss: -15.5912
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2983 [0/83759 (0%)]	log Loss: -16.320951
#
# Train set: Average log loss: -16.3032
#
#
# Test set: Average loss: -15.5912
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2984 [0/83759 (0%)]	log Loss: -16.320995
#
# Train set: Average log loss: -16.3032
#
#
# Test set: Average loss: -15.5913
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2985 [0/83759 (0%)]	log Loss: -16.321130
#
# Train set: Average log loss: -16.3033
#
#
# Test set: Average loss: -15.5913
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2986 [0/83759 (0%)]	log Loss: -16.321088
#
# Train set: Average log loss: -16.3033
#
#
# Test set: Average loss: -15.5913
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2987 [0/83759 (0%)]	log Loss: -16.321155
#
# Train set: Average log loss: -16.3034
#
#
# Test set: Average loss: -15.5914
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2988 [0/83759 (0%)]	log Loss: -16.321235
#
# Train set: Average log loss: -16.3035
#
#
# Test set: Average loss: -15.5914
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2989 [0/83759 (0%)]	log Loss: -16.321217
#
# Train set: Average log loss: -16.3035
#
#
# Test set: Average loss: -15.5914
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2990 [0/83759 (0%)]	log Loss: -16.321337
#
# Train set: Average log loss: -16.3036
#
#
# Test set: Average loss: -15.5914
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2991 [0/83759 (0%)]	log Loss: -16.321404
#
# Train set: Average log loss: -16.3036
#
#
# Test set: Average loss: -15.5915
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2992 [0/83759 (0%)]	log Loss: -16.321484
#
# Train set: Average log loss: -16.3037
#
#
# Test set: Average loss: -15.5915
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2993 [0/83759 (0%)]	log Loss: -16.321528
#
# Train set: Average log loss: -16.3038
#
#
# Test set: Average loss: -15.5916
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2994 [0/83759 (0%)]	log Loss: -16.321627
#
# Train set: Average log loss: -16.3038
#
#
# Test set: Average loss: -15.5916
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2995 [0/83759 (0%)]	log Loss: -16.321660
#
# Train set: Average log loss: -16.3039
#
#
# Test set: Average loss: -15.5916
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2996 [0/83759 (0%)]	log Loss: -16.321724
#
# Train set: Average log loss: -16.3039
#
#
# Test set: Average loss: -15.5917
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2997 [0/83759 (0%)]	log Loss: -16.321743
#
# Train set: Average log loss: -16.3040
#
#
# Test set: Average loss: -15.5917
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2998 [0/83759 (0%)]	log Loss: -16.321810
#
# Train set: Average log loss: -16.3041
#
#
# Test set: Average loss: -15.5917
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 2999 [0/83759 (0%)]	log Loss: -16.321879
#
# Train set: Average log loss: -16.3041
#
#
# Test set: Average loss: -15.5917
#
# Current Learning rate 1.0000000000000002e-06
# Train Epoch: 3000 [0/83759 (0%)]	log Loss: -16.322011
#
# Train set: Average log loss: -16.3042
#
#
# Test set: Average loss: -15.5918
#
# Current Learning rate 1.0000000000000002e-06

# %%
# Plotting log(MSE) as a function of epochs
plt.figure(figsize=(10,7))
plt.plot( np.log(test_losses), label = "test")
plt.plot( np.log(train_losses), label = "train")

plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Log(LSE)")
plt.title("MSE over Epoch" )
plt.grid()
print("Training WIDE {} VS in the article 8.04e-09".format(train_losses[-1]) )
# Out:
# Training WIDE 7.775201280321086e-08 VS in the article 8.04e-09

# %%
# Loading model
device = 'cuda'
loaded_Heston_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_ANN.pt"
loaded_Heston_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_ANN.eval()
# Out:
# Heston_ANN(
#   (fc1): Linear(in_features=8, out_features=400, bias=True)
#   (fc2): Linear(in_features=400, out_features=400, bias=True)
#   (fc3): Linear(in_features=400, out_features=400, bias=True)
#   (fc4): Linear(in_features=400, out_features=400, bias=True)
#   (fc5): Linear(in_features=400, out_features=1, bias=True)
# )

# %%
# Loading Train / Test Data
hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0]-train_size])
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}
train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])
# Out:
# ------ INPUT ------
# S/K.......... [0.61 1.39]
# Tau.......... [0.11 1.39]
# r............ [0.01 0.09]
# Corr ........ [-0.94 -0.01]
# Kappa........ [0.41 1.99]
# V_bar........ [0.01 0.49]
# Gamma........ [0.01 0.49]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00 0.64]

# %%
# Plotting erros histogram
errors = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    errors.append((target-output).data.cpu().numpy())
  errors = np.concatenate(errors)
plt.figure(figsize=(10,7))
plt.hist(errors,50,fill=False)
plt.grid()
plt.xlabel("Difference")
plt.ylabel("Density")
plt.xlim([-0.003, 0.003])
plt.show()
print("MAX ",errors.max())
print("MIN ",errors.min())
# Out:
# MAX  0.00266546
# MIN  -0.0030121505

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Train scores----------------
# MSE 1.620948e-07
# MAE 3.069885e-04
# MAPE 1.953139e-02
# R2 9.999926e-01
# -----------Test scores----------------
# MSE 1.664916e-07
# MAE 3.105019e-04
# MAPE 1.748970e-02
# R2 9.999923e-01

# %%
np.sqrt(1.670718e-07)
# Out:
# 0.0004087441742704108

# %% [markdown]
# # 5) BRENT

# %%
from scipy import optimize

def calcimpliedvol(dataset):
    """
    Computes the implied volatilities using the brent method.
    dataset: numpy array containing moneyness, time to maturity, risk free interest rate and V/K.
    Returns a vector of implied volatilities.
    """
    money = np.array(dataset[0])
    T = np.array(dataset[1])
    r = np.array(dataset[2])
    marketoptionPrice = np.array(dataset[3])
    def bs_price(sigma):
      d1 = ( np.log(money) + (r + 0.5 * sigma ** 2) * (T) ) / (sigma * np.sqrt(T))
      d2 = d1 - sigma*np.sqrt(T)
      value_moyeness = money * norm.cdf(d1) - np.exp(-r * (T)) * norm.cdf(d2) 
      fx = value_moyeness - marketoptionPrice
      return fx
    return optimize.brentq(bs_price,-1,1,maxiter=100)

bs_dataset = bs_LHS_data_generator(n=10**4).data
ground_truth_vol = bs_dataset[:,3]
bs_dataset = bs_dataset[:,np.array([0,1,2,4])]
vol_imp = np.apply_along_axis(calcimpliedvol, 1, bs_dataset)
print("MSE ", ((ground_truth_vol - vol_imp)**2).mean().item())
# Out:
# ------ INPUT ------
# S/K.......... [0.40 1.60]
# Tau.......... [0.20 1.10]
# r............ [0.02 0.10]
# Sigma........ [0.01 1.00]
# ------ OUTPUT ------
# V/K.......... [0.00 0.85]
# MSE  0.00014862391368948422

# %% [markdown]
# # 6) Pipeline 1: COS + BRENT

# %%
eps = 1e-2 # is used to generate open intervals
# (S/K), (tau), (r), (rho), (kappa), (vbar), (gamma), (v0).
# CASE 1 in table 11
l_bounds = [.75+eps, .4+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps]
u_bounds = [1.25-eps, 1.-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds = l_bounds, u_bounds=u_bounds)
hs_dataset_data = hs_dataset.data
hs_dataset_data = hs_dataset_data[:,np.array([0,1,2,8])]
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, hs_dataset_data)
# Out:
# ------ INPUT ------
# S/K.......... [0.76 1.24]
# Tau.......... [0.41 0.99]
# r............ [0.01 0.09]
# Corr ........ [-0.94 -0.01]
# Kappa........ [0.41 1.99]
# V_bar........ [0.01 0.49]
# Gamma........ [0.01 0.49]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00 0.47]

# %% [markdown]
# # 7) Pipeline 2: Heston-ANN + IV-ANN

# %%
# Loading model
device = torch.device("cuda")
loaded_Heston_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_ANN.pt"
loaded_Heston_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_ANN.eval()

# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

# Loading model 
device = torch.device("cuda")
loaded_IV_ANN = IV_ANN().to(device)
PATH = "ANN_weights/IV_SCALED_ANN.pt"
loaded_IV_ANN.load_state_dict(torch.load(PATH))
loaded_IV_ANN.eval()


# Plugging in the Heston-ANN prices
hs_dataset2 = hs_dataset.data[:,np.array([0,1,2,8])]
hs_dataset2.data[:,3] = torch.FloatTensor(prices)
loader2 = torch.utils.data.DataLoader(hs_dataset2, 4048)

# Computing IVs
implied_vol = []
indecies_list = []
with torch.no_grad():
  for idx, data in enumerate(loader2):
    data = data.to(device)
    # LOG Transformation
    data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
    data[:,3] = torch.log(data[:,3])
    output = loaded_IV_ANN(data)
    implied_vol.append((output).data.cpu().numpy())
  implied_vol_pipe2 = np.concatenate(implied_vol)
  # indecies_list = np.concatenate(indecies_list).flatten()

# %%
# Eliminating Nan values resulting from prices lower than 1e-7
indecies = np.argwhere(np.isnan(implied_vol_pipe2))
implied_vol_pipe1 = np.delete(implied_vol_pipe1, indecies,0)
implied_vol_pipe2 = np.delete(implied_vol_pipe2, indecies,0)

# %% [markdown]
# # 8) Pipeline 1 VS pipeline 2

# %%
# CASE 1
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Vol scores----------------
# MSE 2.076680e-06
# RMSE 1.441069e-03
# MAE 1.114881e-03
# MAPE 2.357523e-03
# R2 9.997799e-01

# %%
# CASE 2
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Vol scores----------------
# MSE 4.065135e-07
# RMSE 6.375841e-04
# MAE 4.932424e-04
# MAPE 1.574925e-03
# R2 8.757847e-01

# %% [markdown]
# # 9) Volatility surface (COS + IV-ANN)

# %% [markdown]
# ### Initial volatility surface

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
moyeness = np.linspace(moyeness, 1.24,11)
tau = np.linspace(tau, 1, 6)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(66)).reshape((-1, 1))

# %%
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  bs_IV = (output).data.cpu().numpy()

X = X.flatten()
Y = Y.flatten()
Z = bs_IV

x = np.reshape(X, (-1, 6))
y = np.reshape(Y, (-1, 6))
z = np.reshape(Z, (-1, 6))

# %%
from mpl_toolkits import mplot3d
from matplotlib import cm

# %%
# Plotting the initial volatility surface
plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to matuirity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Smoothing the volatility surface

# %%
from scipy import interpolate

# %%
# Smoothing the volatility surface
xnew, ynew = x.copy(), y.copy()
tck = interpolate.bisplrep(x, y, z, s=1.0)
znew = interpolate.bisplev(xnew[:,0], ynew[0,:], tck)

plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(xnew, ynew, znew,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to maturity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Implied volatility difference

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
n_moneyness = 11
n_tau = 6
moyeness = np.linspace(moyeness, 1.24,n_moneyness)
tau = np.linspace(tau, 1, n_tau)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
rho = np.array(rho*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
kappa = np.array(kappa*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
vbar = np.array(vbar*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
gamma = np.array(gamma*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
v0 = np.array(v0*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(n_tau * n_moneyness)).reshape((-1, 1))

# %%
data_ann = np.concatenate((X, Y, r, rho, kappa, vbar, gamma, v0, cos_prices), axis = 1)
data_ann = torch.FloatTensor(data_ann)
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  implied_vol_pipe2 = (output).data.cpu().numpy()

# %%
X = X.flatten()
Y = Y.flatten()
Z = (implied_vol_pipe1 - implied_vol_pipe2).flatten()

x = np.reshape(X, (-1, min(n_moneyness, n_tau)))
y = np.reshape(Y, (-1, min(n_moneyness, n_tau)))
z = np.reshape(Z, (-1, min(n_moneyness, n_tau)))

plt.figure(figsize=(8,8))
plt.pcolormesh(x, y, z, shading='gouraud')
plt.colorbar()
plt.xlabel("Moneyness")
plt.ylabel("Time to maturity")
plt.show()
