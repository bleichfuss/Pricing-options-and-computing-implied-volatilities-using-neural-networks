# %% [markdown]
# # Financial Model Calibration using ANNs (CaNN, Calibration Neural Network)
#
# ##### from "A neural network-based framework for financial model calibration", Liu et al. ([1])
# ##### and "Pricing options and computing implied volatilities using neural networks", Liu et al. ([2])

# %% [markdown]
# # -------------------------------------------------------

# %% [markdown]
# ## The framework consists of 3 Phases, i.e.:
#
# ### 1. Training (Forward pass)
# ### 2. Prediction (Forward pass)
# ### 3. Calibration (Backward pass)

# %% [markdown]
# # -------------------------------------------------------

# %% [markdown]
# Table of contents
#
# ### 1) Forward pass
# ###### a) Preperation
# ###### b) Data generation
# ###### c) Training Heston-IV-ANN
# ###### d) Prediction
# ###### e) Volatility Surface (In doing)
#
# ### 2) Backward pass
# ###### a) Preperation Market Quotes
# ###### b) Differential Evolution (DE)

# %% [markdown]
# # -------------------------------------------------------

# %% [markdown]
# # 1) Forward pass

# %% [markdown]
# ## a) Preperation

# %%
# Basic imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# Updating scipy to use module QMC for Latin hypercube sampling
#!pip install scipy==1.7
from scipy.stats import qmc

# Pytorch imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR, LinearLR, OneCycleLR, LambdaLR

from scipy.optimize import differential_evolution

# %%
# run on GPU
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### Black-Scholes

# %%
def bs_price_call(S, K, T, t, r, sigma):
  """
  Black-Scholes call option value price related to PDE (2). Returns option's price.
  S:     spot price
  K:     strike price
  T:     time to maturity
  t:     spot time
  r:     interest rate
  sigma: volatility of underlying asset
  """

  # Boundary condition of Black-Sholes PDE (2)
  if T == t:
    return np.maximum(0, S - K)  
  # Solution of the PDE (2) on the open interval [t, T)
  else : 
    d1 = ( np.log(S / K) + (r + 0.5 * sigma ** 2) * (T-t) ) / (sigma * np.sqrt(T-t))
    d2 = d1 - sigma*np.sqrt(T-t)
    value = S * norm.cdf(d1) - K * np.exp(-r * (T-t)) * norm.cdf(d2) 
  
  return value

def bs_moneyness_call(moneyness, tau, r, sigma):
  """
  Same function as bs_price_call but in terms of moneyness. Returns V/K and 
  has S/K instead of two seperate paremeters S and K.
  moneyness: S/K
  Tau: time to maturity minus spot time
  r: interest rate
  sigma: volatility of underlying asset
  """

  d1 = ( np.log(moneyness) + (r + 0.5 * sigma ** 2) * (tau) ) / (sigma * np.sqrt(tau))
  d2 = d1 - sigma*np.sqrt(tau)
  value_moneyness = moneyness * norm.cdf(d1) - np.exp(-r * (tau)) * norm.cdf(d2) 
  
  return value_moneyness

# %% [markdown]
# ##### Defining class Heston-IV-ANN

# %%
class Heston_ANN(nn.Module):
  def __init__(self):
    """
    Initilize Heston-IV-ANN netwwork with four hidden layers. 
    Same architecture as the one used in Table (2) [2].
    Weight are initialized using Glorot_uniform also known as Xavier_uniform.
    """
    super(Heston_ANN, self).__init__()
    # 4 layers
    self.fc1 = nn.Linear(8, 200)
    self.fc2 = nn.Linear(200, 200)
    self.fc3 = nn.Linear(200, 200)
    self.fc4 = nn.Linear(200, 200)
    self.fc5 = nn.Linear(200, 1)
    # initilizing the layer's weights
    torch.nn.init.xavier_uniform_(self.fc1.weight) 
    torch.nn.init.xavier_uniform_(self.fc2.weight)
    torch.nn.init.xavier_uniform_(self.fc3.weight)
    torch.nn.init.xavier_uniform_(self.fc4.weight)
    torch.nn.init.xavier_uniform_(self.fc5.weight)


  def forward(self, x):
    """
    Foward pass of the network. 
    Relu activations are used and a linear activation is used in the final layer.
    x: input torch tensor (CUDA or CPU)
    """
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = F.relu(self.fc3(x))
    x = F.relu(self.fc4(x))
    x = self.fc5(x)
    return x.flatten()

  def train_model(self, args, device, train_loader, optimizer, epoch):
    """
    Training over train_loader batches for one epoch.
    Returns average training loss.
    args: training parameters.
    device: CUDA or CPU.
    train_loader: train data loader.
    optimizer: gradient descent optmizer.
    epoch: current epoch.
    """
    # train mode
    self.train()
    train_loss = 0
    # loop over data loader
    for batch_idx, data in enumerate(train_loader):
      # extracting the inputs and target
      data, target = data[:,:-1].to(device), data[:,-1].to(device)
      # zeroing the gradients
      optimizer.zero_grad()
      # foward pass
      output = self(data)
      # computing the loss
      loss = F.mse_loss(output, target)
      train_loss += loss.item() * data.shape[0]
      # back propagation
      loss.backward()
      # updating the optimizer step
      optimizer.step()
      # printing batch information
      if batch_idx % args["log_interval"] == 0:
        print('Train Epoch: {} [{}/{} ({:.0f}%)]\tlog Loss: {:.6f}'.format(
            epoch, int(batch_idx / len(train_loader)*len(train_loader.dataset)), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), np.log(loss.item())))
        if args["dry_run"]:
          break
    train_loss /= len(train_loader.dataset)
    print('\nTrain set: Average log loss: {:.4f}\n'.format(np.log(train_loss))) 
    return train_loss


  def test_model(self, device, test_loader):
    """
    Testing over test_loader batches for one epoch. 
    Returns average test loss.
    device: CUDA or CPU.
    test_loader: test data loader.
    """
    # evaluation mode
    self.eval()
    test_loss = 0
    # freezing the gradients
    with torch.no_grad():
      # looping over the test laoder
      for data in test_loader:
        # extracting the inputs and target
        data, target = data[:,:-1].to(device), data[:,-1].to(device)
        # foward pass
        output = self(data)
        #computing the loss
        test_loss += F.mse_loss(output, target, reduction = 'sum').item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}\n'.format(np.log(test_loss))) 
    return test_loss

# %% [markdown]
# ## b) Data generation

# %% [markdown]
# ### Numerical method here: Heston and COS

# %% [markdown]
# #### COS Method

# %% [markdown]
# #### Vanilla call coefficients

# %% [markdown]
# $\begin{aligned} \chi_{k}(c, d):=& \frac{1}{1+\left(\frac{k \pi}{b-a}\right)^{2}}\left[\cos \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\cos \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right.\\ &\left.+\frac{k \pi}{b-a} \sin \left(k \pi \frac{d-a}{b-a}\right) e^{d}-\frac{k \pi}{b-a} \sin \left(k \pi \frac{c-a}{b-a}\right) e^{c}\right] \end{aligned}$

# %% [markdown]
# $\psi_{k}(c, d):= \begin{cases}{\left[\sin \left(k \pi \frac{d-a}{b-a}\right)-\sin \left(k \pi \frac{c-a}{b-a}\right)\right] \frac{b-a}{k \pi},} & k \neq 0, \\ (d-c), & k=0 .\end{cases}$

# %% [markdown]
# $V_{k}^{\text {call }}=\frac{2}{b-a} K\left(\chi_{k}(0, b)-\psi_{k}(0, b)\right)$

# %%
def call_cosine_coef(a, b, c, d, K, N):
  """
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  K: Strike.
  N: summing lenght.
  Returns V_k coefficient for call option.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*K*(chi_k-psi_k)

# %%
def call_cosine_coef_moy(a, b, c, d, N):
  """
  Moyeness version.
  Coefficient V_k for plain vanilla options. 
  Section 3.1, equations (22) and (23).
  a, b, c, d: truncation range parameters.
  N: summing lenght.
  Returns V_k coefficient for call option devided by K.
  """
  k = np.arange(N).reshape(1,-1)
  bma    = b - a
  uu     = k * np.pi / bma
  chi_k = 1 / (1 + uu **2 ) * \
  ( np.cos(uu * ( d - a))* np.exp(d) - np.cos(uu * (c - a))* np.exp(c) + uu * np.sin(uu * (d - a)) * np.exp(d)- uu * np.sin(uu*(c-a))* np.exp(c) )
  psi_k = uu
  psi_k[:,1:] = 1 / uu[:,1:] * ( np.sin(uu[:,1:] * ( d - a )) - np.sin( uu[:,1:] * ( c - a) ) )
  psi_k[:,0] = (d - c).flatten() #d - c 
  return 2/bma*(chi_k-psi_k)

# %% [markdown]
# #### Charateristic function for Heston model

# %% [markdown]
# $\begin{aligned} \varphi_{h e s}\left(\omega ; u_{0}\right)=& \exp \left(i \omega \mu \Delta t+\frac{u_{0}}{\eta^{2}}\left(\frac{1-e^{-D \Delta t}}{1-G e^{-D \Delta t}}\right)(\lambda-i \rho \eta \omega-D)\right) \\ & \cdot \exp \left(\frac{\lambda \bar{u}}{\eta^{2}}\left(\Delta t(\lambda-i \rho \eta \omega-D)-2 \log \left(\frac{1-G e^{-D \Delta t}}{1-G}\right)\right)\right) \end{aligned}$

# %% [markdown]
# $D=\sqrt{(\lambda-i \rho \eta \omega)^{2}+\left(\omega^{2}+i \omega\right) \eta^{2}} \quad$ and $\quad G=\frac{\lambda-i \rho \eta \omega-D}{\lambda-i \rho \eta \omega+D} $

# %%
def phi_Heston(a ,b ,N ,r, tau, kappa, gamma, vbar, v0, rho):
  """
  Characteristic function of the log-asset price following the Heston model.
  Section 3.3, equation (33).
  a, b: truncation range parameters.
  N: summing lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns Charateristic function vector.
  """
  #if kappa < 1e-4:
  #  print("kapp < 1e-4")
  #  kappa = 1e-5
  k = np.arange(N).reshape(1,-1)
  u = np.pi*k/(b-a)
  i = complex(0.0,1.0)
  D = np.sqrt((kappa-gamma*rho*i*u)**2+(u**2+i*u)*gamma**2)
  G = (kappa-gamma*rho*i*u-D)/(kappa-gamma*rho*i*u+D)
  C = v0* (1-np.exp(-D*tau)) / (gamma**2*(1-G*np.exp(-D*tau)))*(kappa-gamma*rho*i*u-D)
  A = r*i*u*tau + kappa*vbar/(gamma**2)*(tau*(kappa-gamma*rho*i*u-D) -2*np.log( (1-G*np.exp(-D*tau))/(1-G) )   ) 
  phi = np.exp( A + C )
  return phi

# %% [markdown]
# #### Heston cumulants

# %% [markdown]
# $c_{1}=\mu T+\left(1-e^{-\lambda T}\right) \frac{\bar{u}-u_{0}}{2 \lambda}-\frac{1}{2} \bar{u} T$

# %% [markdown]
# $\begin{aligned} c_{2}=& \frac{1}{8 \lambda^{3}}\left(\eta T \lambda e^{-\lambda T}\left(u_{0}-\bar{u}\right)(8 \lambda \rho-4 \eta)\right.\\ &+\lambda \rho \eta\left(1-e^{-\lambda T}\right)\left(16 \bar{u}-8 u_{0}\right) \\ &+2 \bar{u} \lambda T\left(-4 \lambda \rho \eta+\eta^{2}+4 \lambda^{2}\right) \\ &+\eta^{2}\left(\left(\bar{u}-2 u_{0}\right) e^{-2 \lambda T}+\bar{u}\left(6 e^{-\lambda T}-7\right)+2 u_{0}\right) \\ &\left.+8 \lambda^{2}\left(u_{0}-\bar{u}\right)\left(1-e^{-\lambda T}\right)\right) \end{aligned}$

# %%
def Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho ):
  """
  Computes Heston cumulants as defined in the appendix A for the Heston model.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  Returns cumulants c1 and c2.
  """

  #if kappa == 0:
  #  c1 = r * tau + tau * (vbar - v0) / 2 - 0.5 * vbar * tau
  #else: 
  #   c1 = r * tau + (1 - np.exp(- kappa * tau)) * (vbar - v0) / (2 * kappa) - 0.5 * vbar * tau
  
  c1 = r * tau + (1 - np.exp(- kappa * tau)) * (vbar - v0) / (2 * kappa) - 0.5 * vbar * tau


  #safe_kappa = np.max(kappa, 1e-5)
  safe_kappa = kappa
  c2 = 0.125 / safe_kappa ** 3 * (gamma * tau * np.exp(- safe_kappa * tau) * (v0 - vbar) * (8 * safe_kappa * rho - 4 * gamma) + \
     safe_kappa * rho * gamma * (1 - np.exp(- safe_kappa * tau)) * (16 * vbar - 8 * v0) + \
     2 * vbar * safe_kappa * tau * (- 4 * safe_kappa * rho * gamma + gamma ** 2 + 4 * safe_kappa ** 2) + \
     gamma ** 2 * ((vbar - 2 * v0) * np.exp(-2 * safe_kappa * tau) + vbar * (6 * np.exp(- safe_kappa * tau) - 7) + 2 * v0) + \
     8 * safe_kappa ** 2 * (v0 - vbar) * (1 - np.exp(-safe_kappa * tau)))
  return c1, c2

# %% [markdown]
# #### Truncation range

# %% [markdown]
# $[a, b]:=\left[c_{1}-L \sqrt{c_{2}+\sqrt{c_{4}}}, \quad c_{1}+L \sqrt{c_{2}+\sqrt{c_{4}}}\right]$

# %%
def Truncation_range(c1, c2, c4, L):
  """
  Computes the truncation range given the cumulants c1, c2, c4 and the truncation lenght L.
  c1, c2, c4: Model cumulants.
  L: truncation lenght.
  Returns tuncation interval sup b and inf a.
  """
  a = c1 - L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) )
  b = c1 + L * np.sqrt( np.abs( c2 ) + np.sqrt( np.abs(c4) ) ) 
  return a, b

# %% [markdown]
# #### Exponential coefficient

# %% [markdown]
# $e^{i k \pi \frac{\mathbf{x}-a}{b-a}}$

# %%
def exponential_coef(a, b, N, S0, K):
  """
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  S0: asset initial price.
  K: strike.
  Returns the exponential coefficient vector.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(S0/K)-a)/(b-a))

# %%
def exponential_coef_moy(a, b, N, moyeness):
  """
  Moyeness version.
  Computes the exponential coefficient used in the final pricing sum.
  a, b: truncation range.
  N: sum lenght.
  moyeness: S/K.
  Returns the exponential coefficient vector devided by K.
  """
  i = complex(0.0,1.0)
  k = np.arange(N).reshape(1,-1)
  return np.exp(i*k*np.pi*(np.log(moyeness)-a)/(b-a))

# %% [markdown]
# #### Vanilla call price

# %% [markdown]
# $v\left(\mathbf{x}, t_{0}, u_{0}\right) \approx \mathbf{K} e^{-r \Delta t} \cdot \operatorname{Re}\left\{\sum_{k=0}^{N-1} \varphi_{h e s}\left(\frac{k \pi}{b-a} ; u_{0}\right) U_{k} \cdot e^{i k \pi \frac{\mathbf{x}-a}{b-a}}\right\}$

# %%
def call_option_Heston(N, L, r, tau, kappa, gamma, vbar, v0, rho, K, S0 ):
  """
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  S0: asset initial price.
  K: strike.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef(a, b, c, d, K, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef(a, b, N, S0, K)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, K = K, S0 = S0)
# Out:
# True
# array([[29.79261082]])

# %%
def call_option_Heston_moy(N, L, r, tau, kappa, gamma, vbar, v0, rho, moyeness ):
  """
  Moyeness version.
  Computes call option price using COS method.
  N: sum lenght.
  L: truncation lenght.
  r: risk free rate.
  tau: time to maturity.
  kappa: reversion speed .
  gamma: Vol of vol.
  vbar: Long average variance.
  v0: Initial variance.
  rho: Correlation.
  moyeness: S/K.
  Returns option price.
  """
  c1, c2 = Heston_cumulants( r, tau, kappa, gamma, vbar, v0, rho )
  c4 = 0
  a, b = Truncation_range(c1, c2, c4, L)
  c= 0
  d = b
  V_k = call_cosine_coef_moy(a, b, c, d, N)
  phi_k = phi_Heston(a, b, N, r, tau, kappa, gamma, vbar, v0, rho)
  product_k = V_k * phi_k * exponential_coef_moy(a, b, N, moyeness)
  product_k[:,0] = .5 * product_k[:,0]
  return np.exp(-r*tau)*(np.real(  np.sum( product_k,1 )  )).reshape(-1,1)

# %%
# cheking the function
N = 500
L= 12
r= .1
tau= 1.4
rho = -0.95
kappa= 1.4
vbar = .1
gamma = .1
v0 = 0.5
K = 100
S0 = 100
# Feller's condition
print(2*kappa*vbar>gamma**2)
call_option_Heston_moy(N = 1500, L= 12, r= r, tau= tau, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = 1)
# Out:
# True
# array([[0.29792611]])

# %% [markdown]
# # Latin Hypercube Sampling

# %% [markdown]
# ### Generating Data

# %% [markdown]
# #### Sampling range for the Heston parameters (Table (3) in [1])

# %%
# here Table (3) of [1] is used, kappa is numerically sensitive to small values
eps = 1e-2 # is used to generate open intervals
def Heston_LHS_data_generator(n = 10**6, l_bounds = [.6+eps, .05+eps, .0+eps, -0.9+eps, 0.4+eps, .01+eps, .01+eps, .05+eps], u_bounds = [1.4-eps, 3.0-eps, .05-eps, 0.0-eps, 3.0-eps, .5-eps, .8-eps, .5-eps]):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,9) containig the inputs samples and the value of the call.
  The inputs are: Moyeness (S/K), time to maturity (tau), Risk free rate (r), Correlation (rho), reversion speed (kappa), Long average variance (vbar), Vol of vol (gamma), Initial variance (v0).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.
  """
  sampler = qmc.LatinHypercube(d = 8) #, seed = 0
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  indecies = np.argwhere(2*sample[:,4]*sample[:,5] <= sample[:,6]**2)
  sample = np.delete(sample, indecies, 0)
  hs_prices = call_option_Heston_moy(N = 500, L= 12, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa = sample[:,4].reshape((-1,1)),\
                                     gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
                                     rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  #hs_prices = call_option_Heston_moy(N = 1500, L= 50, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
  #                                    gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
  #                                    rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))

  # hs_dataset = np.concatenate((sample, hs_prices),axis=1)

  print("------ INPUT ------")
  print("S/K.......... [{:.2f}, {:.2f}]".format(sample[:,0].min(), sample[:,0].max()))
  print("Tau.......... [{:.2f}, {:.2f}]".format(sample[:,1].min(), sample[:,1].max()))
  print("r............ [{:.2f}, {:.2f}]".format(sample[:,2].min(), sample[:,2].max()))
  print("Corr ........ [{:.2f}, {:.2f}]".format(sample[:,3].min(), sample[:,3].max()))
  print("Kappa........ [{:.2f}, {:.2f}]".format(sample[:,4].min(), sample[:,4].max()))
  print("V_bar........ [{:.2f}, {:.2f}]".format(sample[:,5].min(), sample[:,5].max()))
  print("Gamma........ [{:.2f}, {:.2f}]".format(sample[:,6].min(), sample[:,6].max()))
  print("V_0 ......... [{:.2f}, {:.2f}]".format(sample[:,7].min(), sample[:,7].max()))
  print("------ OUTPUT ------")
  print("V/K.......... [{:.2f}, {:.2f}]".format(hs_prices.min(), hs_prices.max()))

  return sample, hs_prices


testset = Heston_LHS_data_generator(10**4)
# Out:
# ------ INPUT ------
# S/K.......... [0.61, 1.39]
# Tau.......... [0.06, 2.99]
# r............ [0.01, 0.04]
# Corr ........ [-0.89, -0.01]
# Kappa........ [0.41, 2.99]
# V_bar........ [0.02, 0.49]
# Gamma........ [0.02, 0.79]
# V_0 ......... [0.06, 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00, 0.75]

# %% [markdown]
# ## c) Training Heston-IV-ANN

# %% [markdown]
# ### Use Brent to inverse price to implied volatility (IV)

# %%
eps = 1e-2 # is used to generate open intervals
def Heston_LHS_data_generator_OLD(n = 10**6, l_bounds = [.6+eps, .1+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps], u_bounds = [1.4-eps, 1.4-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]):
  """
  Generates samples of call prices using Latin hypercube sampling.
  Returns a torch float tensor of dimension (n,9) containig the inputs samples and the value of the call.
  The inputs are: Moyeness (S/K), time to maturity (tau), Risk free rate (r), Correlation (rho), reversion speed (kappa), Long average variance (vbar), Vol of vol (gamma), Initial variance (v0).
  n: number of samples.
  l_bounds: lower bound for the inputs.  
  u_bounds: upper bound for the inputs.
  """
  sampler = qmc.LatinHypercube(d=8) #, seed = 0
  sample = sampler.random(n)
  sample = qmc.scale(sample, l_bounds, u_bounds)
  indecies = np.argwhere(2*sample[:,4]*sample[:,5]<= sample[:,6]**2)
  sample = np.delete(sample, indecies,0)
  # print(sample.shape)
  # print(2*kappa*vbar>gamma**2)
  hs_prices = call_option_Heston_moy(N = 160, L= 12, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
                                     gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
                                     rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  # hs_prices = call_option_Heston_moy(N = 1500, L= 50, r= sample[:,2].reshape((-1,1)), tau= sample[:,1].reshape((-1,1)), kappa= sample[:,4].reshape((-1,1)),\
  #                                    gamma = sample[:,6].reshape((-1,1)), vbar = sample[:,5].reshape((-1,1)), v0 = sample[:,7].reshape((-1,1)),\
  #                                    rho = sample[:,3].reshape((-1,1)), moyeness = sample[:,0].reshape((-1,1))).reshape((-1,1))
  
  hs_dataset = np.concatenate((sample, hs_prices),axis=1)

  print("------ INPUT ------")
  print("S/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,0]),max(hs_dataset[:,0])))
  print("Tau.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,1]),max(hs_dataset[:,1])))
  print("r............ [{:.2f} {:.2f}]".format(min(hs_dataset[:,2]),max(hs_dataset[:,2])))
  print("Corr ........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,3]),max(hs_dataset[:,3])))
  print("Kappa........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,4]),max(hs_dataset[:,4])))
  print("V_bar........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,5]),max(hs_dataset[:,5])))
  print("Gamma........ [{:.2f} {:.2f}]".format(min(hs_dataset[:,6]),max(hs_dataset[:,6])))
  print("V_0 ......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,7]),max(hs_dataset[:,7])))
  print("------ OUTPUT ------")
  print("V/K.......... [{:.2f} {:.2f}]".format(min(hs_dataset[:,-1]),max(hs_dataset[:,-1])))
  # ind_max = np.argmax(hs_dataset[:,-1])
  # print(hs_dataset[ind_max,:])

  return torch.FloatTensor(hs_dataset)

# %%
from scipy import optimize

def calcimpliedvol_OLD(dataset):
    """
    Computes the implied volatilities using the brent method.
    dataset: numpy array containing moneyness, time to maturity, risk free interest rate and V/K.
    Returns a vector of implied volatilities.
    """
    money = np.array(dataset[0])
    T = np.array(dataset[1])
    r = np.array(dataset[2])
    marketoptionPrice = np.array(dataset[3])
    def bs_price(sigma):
      d1 = ( np.log(money) + (r + 0.5 * sigma ** 2) * (T) ) / (sigma * np.sqrt(T))
      d2 = d1 - sigma*np.sqrt(T)
      value_moyeness = money * norm.cdf(d1) - np.exp(-r * (T)) * norm.cdf(d2) 
      fx = value_moyeness - marketoptionPrice
      return fx
    return optimize.brentq(bs_price,-1,1,maxiter=100)

# %%
eps = 1e-2 # is used to generate open intervals
# (S/K), (tau), (r), (rho), (kappa), (vbar), (gamma), (v0).
# CASE 1 in table 11
l_bounds = [.75+eps, .4+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps]
u_bounds = [1.25-eps, 1.-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]
hs_dataset_OLD = Heston_LHS_data_generator_OLD(10**5, l_bounds = l_bounds, u_bounds=u_bounds)
hs_dataset_OLD_data = hs_dataset_OLD.data
hs_dataset_OLD_data = hs_dataset_OLD_data[:,np.array([0,1,2,8])]
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol_OLD, 1, hs_dataset_OLD_data)
# Out:
# ------ INPUT ------
# S/K.......... [0.76 1.24]
# Tau.......... [0.41 0.99]
# r............ [0.01 0.09]
# Corr ........ [-0.94 -0.01]
# Kappa........ [0.41 1.99]
# V_bar........ [0.01 0.49]
# Gamma........ [0.01 0.49]
# V_0 ......... [0.06 0.49]
# ------ OUTPUT ------
# V/K.......... [0.00 0.46]

# %%
# Print first data point and corresponding implied vol
print("Inputs size:", hs_dataset_OLD_data.shape)
print("Inputs (m, T, r, V/K):", hs_dataset_OLD_data[9330])
print("Implied vol:", implied_vol_pipe1[9330])
# Out:
# Inputs size: torch.Size([93253, 4])
# Inputs (m, T, r, V/K): tensor([1.1673, 0.5640, 0.0654, 0.2382])
# Implied vol: 0.3368300130730295

# %%
from scipy.stats import norm
from scipy.optimize import brentq
import numpy as np

def bs_price(sigma, m, T, r):
    if sigma <= 0:
        return 0.0
    d1 = (np.log(1 / m) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    return np.exp(-r * T) * (norm.cdf(d1) - m * norm.cdf(d2))

def calcimpliedvol(x):  # x = [moneyness, T, r, price]
    m, T, r, price = x
    global counter
    # Avoid division by 0 or invalid prices
    if price <= 1e-8 or m <= 0 or T <= 0:
        return np.nan

    try:
        #counter += 1
        # Quick feasibility check before Brent
        low = bs_price(1e-4, m, T, r)
        high = bs_price(5.0, m, T, r)

        f_low = bs_price(1e-4, m, T, r) - price
        f_high = bs_price(5.0, m, T, r) - price
        #print(f"Brent signs: f(low)={f_low:.4e}, f(high)={f_high:.4e}")
        #print(f"low ={low:.4e}, high={high:.4e}")
        if not (low < price < high):
            return np.nan

        # Brent root finding
        implied_vol = brentq(
            lambda sigma: bs_price(sigma, m, T, r) - price,
            a=1e-4,
            b=10.0,
            maxiter=1000,
            xtol=1e-8
        )
        return implied_vol

    except Exception as e:
        counter = 1
        print(f"⚠️ Brent failed: {e}")
        print(f"Inputs: m={m:.4f}, T={T:.4f}, r={r:.4f}, price={price:.4f}")
        print(f"BS@low= {bs_price(1e-4, m, T, r):.4f}, BS@high= {bs_price(5.0, m, T, r):.4f}")
        return np.nan

# %% [markdown]
# ### Add IV to final data

# %%
sample, hs_prices = Heston_LHS_data_generator(n = 10**5)
# Convert to NumPy for processing
sample_np = sample
hs_prices_np = hs_prices

# Combine required inputs for Brent
brent_input = np.concatenate([sample_np[:, [0, 1, 2]], hs_prices_np], axis=1)  # shape (n, 4)

print("brent_input shape:", brent_input.shape)

# Apply Brent row by row
implied_vols = np.array([
    calcimpliedvol(row) for row in brent_input
])

# Filter out NaNs
valid_idx = ~np.isnan(implied_vols)
sample_np = sample_np[valid_idx]
implied_vols = implied_vols[valid_idx]

# Recombine into final dataset (input + IV target)
final_dataset = np.concatenate([sample_np, implied_vols.reshape(-1, 1)], axis=1)

# Convert to torch Tensor
hs_dataset = torch.FloatTensor(final_dataset)
# Out:
# ------ INPUT ------
# S/K.......... [0.61, 1.39]
# Tau.......... [0.06, 2.99]
# r............ [0.01, 0.04]
# Corr ........ [-0.89, -0.01]
# Kappa........ [0.41, 2.99]
# V_bar........ [0.02, 0.49]
# Gamma........ [0.02, 0.79]
# V_0 ......... [0.06, 0.49]
# ------ OUTPUT ------
# V/K.......... [-0.00, 0.76]
# brent_input shape: (86015, 4)

# %%
print("First sample:\n", hs_dataset[0])
print("sample_np shape:", sample_np.shape)
print("implied_vols shape:", implied_vols.shape)
# Out:
# First sample:
#  tensor([ 1.0599,  2.3217,  0.0210, -0.2505,  2.0677,  0.3603,  0.4920,  0.4635,
#          0.7888])
# sample_np shape: (60222, 8)
# implied_vols shape: (60222,)

# %%
for i in range(25):
    print(f"Row {i}: m={brent_input[i,0]:.2f}, T={brent_input[i,1]:.2f}, r={brent_input[i,2]:.2f}, price={brent_input[i,3]:.4f} → IV={implied_vols[i]:.4f}")
# Out:
# Row 0: m=0.65, T=1.95, r=0.03, price=0.0846 → IV=0.7888
# Row 1: m=1.06, T=2.32, r=0.02, price=0.4151 → IV=0.3257
# Row 2: m=0.87, T=1.75, r=0.04, price=0.2166 → IV=0.3321
# Row 3: m=0.61, T=1.22, r=0.02, price=0.0070 → IV=1.9407
# Row 4: m=0.88, T=1.98, r=0.02, price=0.2277 → IV=1.6789
# Row 5: m=0.67, T=1.59, r=0.04, price=0.0950 → IV=1.1866
# Row 6: m=1.37, T=0.65, r=0.02, price=0.4892 → IV=1.2979
# Row 7: m=1.29, T=0.56, r=0.04, price=0.3936 → IV=0.4468
# Row 8: m=1.20, T=1.07, r=0.02, price=0.4030 → IV=0.5207
# Row 9: m=1.29, T=0.81, r=0.01, price=0.3680 → IV=0.5086
# Row 10: m=0.90, T=0.15, r=0.02, price=0.0538 → IV=0.1704
# Row 11: m=0.97, T=1.49, r=0.02, price=0.2190 → IV=0.7485
# Row 12: m=0.98, T=0.72, r=0.04, price=0.1778 → IV=0.3414
# Row 13: m=0.63, T=1.32, r=0.03, price=0.0560 → IV=1.6360
# Row 14: m=1.08, T=2.81, r=0.03, price=0.2801 → IV=0.7116
# Row 15: m=0.82, T=1.71, r=0.02, price=0.1902 → IV=0.1218
# Row 16: m=1.05, T=0.86, r=0.02, price=0.2509 → IV=1.1810
# Row 17: m=0.89, T=1.45, r=0.02, price=0.2085 → IV=0.9097
# Row 18: m=1.20, T=0.20, r=0.02, price=0.2257 → IV=0.4131
# Row 19: m=0.99, T=1.83, r=0.03, price=0.3542 → IV=0.3549
# Row 20: m=0.87, T=1.49, r=0.02, price=0.1424 → IV=1.8222
# Row 21: m=0.74, T=0.45, r=0.03, price=0.0093 → IV=0.5452
# Row 22: m=1.30, T=1.88, r=0.03, price=0.5015 → IV=1.1516
# Row 23: m=1.11, T=1.62, r=0.02, price=0.3928 → IV=0.4913
# Row 24: m=0.91, T=1.68, r=0.03, price=0.2385 → IV=0.3199

# %%
# Inputs
m = 1.01
T = 2.86
r = 0.02
sigma = 0.5736

# Compute d1, d2
d1 = (np.log(m) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
d2 = d1 - sigma * np.sqrt(T)

# BS price in moneyness form
bs_price = m * norm.cdf(d1) - np.exp(-r * T) * norm.cdf(d2)

print("BS Price:", bs_price)
# Out:
# BS Price: 0.39745370187324625

# %%
plt.figure(figsize=(8, 4))
plt.hist(implied_vols, bins=100, edgecolor='black')
plt.title("Distribution of Implied Volatilities (Brent)")
plt.xlabel("Implied Volatility")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Training of the ANN

# %%
# Training parameters
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 8*10**3,
         "lr": 1e-4,
         "gamma": .5,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}


use_cuda = not args["no_cuda"] and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# torch.manual_seed(args["seed"])

# Loading Train / Test Data
#hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0] - train_size])

train_loader = torch.utils.data.DataLoader(train_dataset, args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])


# Model training
print(device)
model = Heston_ANN().to(device)
optimizer = optim.Adam(model.parameters(), lr=args["lr"]) # Adam is found to be the best optimizer in the article
scheduler = StepLR(optimizer, step_size=500, gamma=args["gamma"]) # Deacreses the Learning rate by .5 every 500 epoch

train_losses = []
test_losses = []
for epoch in range(1, args["epochs"] + 1):
  train_loss = model.train_model(args, device, train_loader, optimizer, epoch)
  test_loss = model.test_model(device, test_loader)
  print("Current Learning rate {}".format(scheduler.get_last_lr()[0]))
  scheduler.step()
  train_losses.append(train_loss)
  test_losses.append(test_loss)
if args["save_model"] :
  torch.save(model.state_dict(), "ANN_weights/Heston_IV_ANN_DE.pt")
# Out:
# cuda
# Train Epoch: 1 [0/54199 (0%)]	log Loss: 0.105497
#
# Train set: Average log loss: -0.9370
#
#
# Test set: Average loss: -1.5066
#
# Current Learning rate 0.0001
# Train Epoch: 2 [0/54199 (0%)]	log Loss: -1.446522
#
# Train set: Average log loss: -1.6310
#
#
# Test set: Average loss: -1.8928
#
# Current Learning rate 0.0001
# Train Epoch: 3 [0/54199 (0%)]	log Loss: -1.886942
#
# Train set: Average log loss: -2.1101
#
#
# Test set: Average loss: -2.6328
#
# Current Learning rate 0.0001
# Train Epoch: 4 [0/54199 (0%)]	log Loss: -2.600007
#
# Train set: Average log loss: -2.9321
#
#
# Test set: Average loss: -3.4318
#
# Current Learning rate 0.0001
# Train Epoch: 5 [0/54199 (0%)]	log Loss: -3.377246
#
# Train set: Average log loss: -3.5283
#
#
# Test set: Average loss: -3.9396
#
# Current Learning rate 0.0001
# Train Epoch: 6 [0/54199 (0%)]	log Loss: -3.905880
#
# Train set: Average log loss: -3.9778
#
#
# Test set: Average loss: -4.3684
#
# Current Learning rate 0.0001
# Train Epoch: 7 [0/54199 (0%)]	log Loss: -4.356246
#
# Train set: Average log loss: -4.3505
#
#
# Test set: Average loss: -4.6999
#
# Current Learning rate 0.0001
# Train Epoch: 8 [0/54199 (0%)]	log Loss: -4.695129
#
# Train set: Average log loss: -4.6459
#
#
# Test set: Average loss: -4.9583
#
# Current Learning rate 0.0001
# Train Epoch: 9 [0/54199 (0%)]	log Loss: -4.967257
#
# Train set: Average log loss: -4.8873
#
#
# Test set: Average loss: -5.1723
#
# Current Learning rate 0.0001
# Train Epoch: 10 [0/54199 (0%)]	log Loss: -5.195078
#
# Train set: Average log loss: -5.0902
#
#
# Test set: Average loss: -5.3545
#
# Current Learning rate 0.0001
# Train Epoch: 11 [0/54199 (0%)]	log Loss: -5.397033
#
# Train set: Average log loss: -5.2692
#
#
# Test set: Average loss: -5.5086
#
# Current Learning rate 0.0001
# Train Epoch: 12 [0/54199 (0%)]	log Loss: -5.567783
#
# Train set: Average log loss: -5.4241
#
#
# Test set: Average loss: -5.6411
#
# Current Learning rate 0.0001
# Train Epoch: 13 [0/54199 (0%)]	log Loss: -5.710719
#
# Train set: Average log loss: -5.5626
#
#
# Test set: Average loss: -5.7608
#
# Current Learning rate 0.0001
# Train Epoch: 14 [0/54199 (0%)]	log Loss: -5.853213
#
# Train set: Average log loss: -5.6883
#
#
# Test set: Average loss: -5.8683
#
# Current Learning rate 0.0001
# Train Epoch: 15 [0/54199 (0%)]	log Loss: -5.986411
#
# Train set: Average log loss: -5.8011
#
#
# Test set: Average loss: -5.9621
#
# Current Learning rate 0.0001
# Train Epoch: 16 [0/54199 (0%)]	log Loss: -6.100064
#
# Train set: Average log loss: -5.9034
#
#
# Test set: Average loss: -6.0500
#
# Current Learning rate 0.0001
# Train Epoch: 17 [0/54199 (0%)]	log Loss: -6.206914
#
# Train set: Average log loss: -5.9977
#
#
# Test set: Average loss: -6.1338
#
# Current Learning rate 0.0001
# Train Epoch: 18 [0/54199 (0%)]	log Loss: -6.308267
#
# Train set: Average log loss: -6.0851
#
#
# Test set: Average loss: -6.2184
#
# Current Learning rate 0.0001
# Train Epoch: 19 [0/54199 (0%)]	log Loss: -6.405347
#
# Train set: Average log loss: -6.1658
#
#
# Test set: Average loss: -6.2974
#
# Current Learning rate 0.0001
# Train Epoch: 20 [0/54199 (0%)]	log Loss: -6.497085
#
# Train set: Average log loss: -6.2410
#
#
# Test set: Average loss: -6.3684
#
# Current Learning rate 0.0001
# Train Epoch: 21 [0/54199 (0%)]	log Loss: -6.582657
#
# Train set: Average log loss: -6.3118
#
#
# Test set: Average loss: -6.4279
#
# Current Learning rate 0.0001
# Train Epoch: 22 [0/54199 (0%)]	log Loss: -6.655519
#
# Train set: Average log loss: -6.3785
#
#
# Test set: Average loss: -6.4805
#
# Current Learning rate 0.0001
# Train Epoch: 23 [0/54199 (0%)]	log Loss: -6.719822
#
# Train set: Average log loss: -6.4417
#
#
# Test set: Average loss: -6.5322
#
# Current Learning rate 0.0001
# Train Epoch: 24 [0/54199 (0%)]	log Loss: -6.782763
#
# Train set: Average log loss: -6.5006
#
#
# Test set: Average loss: -6.5853
#
# Current Learning rate 0.0001
# Train Epoch: 25 [0/54199 (0%)]	log Loss: -6.842723
#
# Train set: Average log loss: -6.5546
#
#
# Test set: Average loss: -6.6279
#
# Current Learning rate 0.0001
# Train Epoch: 26 [0/54199 (0%)]	log Loss: -6.888323
#
# Train set: Average log loss: -6.6035
#
#
# Test set: Average loss: -6.6618
#
# Current Learning rate 0.0001
# Train Epoch: 27 [0/54199 (0%)]	log Loss: -6.920291
#
# Train set: Average log loss: -6.6493
#
#
# Test set: Average loss: -6.6952
#
# Current Learning rate 0.0001
# Train Epoch: 28 [0/54199 (0%)]	log Loss: -6.949287
#
# Train set: Average log loss: -6.6959
#
#
# Test set: Average loss: -6.7271
#
# Current Learning rate 0.0001
# Train Epoch: 29 [0/54199 (0%)]	log Loss: -6.971190
#
# Train set: Average log loss: -6.7413
#
#
# Test set: Average loss: -6.7616
#
# Current Learning rate 0.0001
# Train Epoch: 30 [0/54199 (0%)]	log Loss: -7.002446
#
# Train set: Average log loss: -6.7849
#
#
# Test set: Average loss: -6.7967
#
# Current Learning rate 0.0001
# Train Epoch: 31 [0/54199 (0%)]	log Loss: -7.036691
#
# Train set: Average log loss: -6.8272
#
#
# Test set: Average loss: -6.8379
#
# Current Learning rate 0.0001
# Train Epoch: 32 [0/54199 (0%)]	log Loss: -7.074871
#
# Train set: Average log loss: -6.8711
#
#
# Test set: Average loss: -6.8878
#
# Current Learning rate 0.0001
# Train Epoch: 33 [0/54199 (0%)]	log Loss: -7.124790
#
# Train set: Average log loss: -6.9159
#
#
# Test set: Average loss: -6.9440
#
# Current Learning rate 0.0001
# Train Epoch: 34 [0/54199 (0%)]	log Loss: -7.178249
#
# Train set: Average log loss: -6.9614
#
#
# Test set: Average loss: -6.9964
#
# Current Learning rate 0.0001
# Train Epoch: 35 [0/54199 (0%)]	log Loss: -7.230013
#
# Train set: Average log loss: -7.0044
#
#
# Test set: Average loss: -7.0357
#
# Current Learning rate 0.0001
# Train Epoch: 36 [0/54199 (0%)]	log Loss: -7.265086
#
# Train set: Average log loss: -7.0420
#
#
# Test set: Average loss: -7.0503
#
# Current Learning rate 0.0001
# Train Epoch: 37 [0/54199 (0%)]	log Loss: -7.273265
#
# Train set: Average log loss: -7.0768
#
#
# Test set: Average loss: -7.0506
#
# Current Learning rate 0.0001
# Train Epoch: 38 [0/54199 (0%)]	log Loss: -7.267462
#
# Train set: Average log loss: -7.1128
#
#
# Test set: Average loss: -7.0632
#
# Current Learning rate 0.0001
# Train Epoch: 39 [0/54199 (0%)]	log Loss: -7.272698
#
# Train set: Average log loss: -7.1495
#
#
# Test set: Average loss: -7.0959
#
# Current Learning rate 0.0001
# Train Epoch: 40 [0/54199 (0%)]	log Loss: -7.301134
#
# Train set: Average log loss: -7.1828
#
#
# Test set: Average loss: -7.1299
#
# Current Learning rate 0.0001
# Train Epoch: 41 [0/54199 (0%)]	log Loss: -7.328300
#
# Train set: Average log loss: -7.2110
#
#
# Test set: Average loss: -7.1738
#
# Current Learning rate 0.0001
# Train Epoch: 42 [0/54199 (0%)]	log Loss: -7.368458
#
# Train set: Average log loss: -7.2370
#
#
# Test set: Average loss: -7.2310
#
# Current Learning rate 0.0001
# Train Epoch: 43 [0/54199 (0%)]	log Loss: -7.418199
#
# Train set: Average log loss: -7.2661
#
#
# Test set: Average loss: -7.2697
#
# Current Learning rate 0.0001
# Train Epoch: 44 [0/54199 (0%)]	log Loss: -7.447876
#
# Train set: Average log loss: -7.2929
#
#
# Test set: Average loss: -7.2825
#
# Current Learning rate 0.0001
# Train Epoch: 45 [0/54199 (0%)]	log Loss: -7.456245
#
# Train set: Average log loss: -7.3154
#
#
# Test set: Average loss: -7.2796
#
# Current Learning rate 0.0001
# Train Epoch: 46 [0/54199 (0%)]	log Loss: -7.447269
#
# Train set: Average log loss: -7.3367
#
#
# Test set: Average loss: -7.2755
#
# Current Learning rate 0.0001
# Train Epoch: 47 [0/54199 (0%)]	log Loss: -7.442001
#
# Train set: Average log loss: -7.3585
#
#
# Test set: Average loss: -7.2806
#
# Current Learning rate 0.0001
# Train Epoch: 48 [0/54199 (0%)]	log Loss: -7.443646
#
# Train set: Average log loss: -7.3814
#
#
# Test set: Average loss: -7.2899
#
# Current Learning rate 0.0001
# Train Epoch: 49 [0/54199 (0%)]	log Loss: -7.451508
#
# Train set: Average log loss: -7.4046
#
#
# Test set: Average loss: -7.3108
#
# Current Learning rate 0.0001
# Train Epoch: 50 [0/54199 (0%)]	log Loss: -7.471864
#
# Train set: Average log loss: -7.4284
#
#
# Test set: Average loss: -7.3425
#
# Current Learning rate 0.0001
# Train Epoch: 51 [0/54199 (0%)]	log Loss: -7.499939
#
# Train set: Average log loss: -7.4506
#
#
# Test set: Average loss: -7.3722
#
# Current Learning rate 0.0001
# Train Epoch: 52 [0/54199 (0%)]	log Loss: -7.528230
#
# Train set: Average log loss: -7.4711
#
#
# Test set: Average loss: -7.4044
#
# Current Learning rate 0.0001
# Train Epoch: 53 [0/54199 (0%)]	log Loss: -7.559439
#
# Train set: Average log loss: -7.4907
#
#
# Test set: Average loss: -7.4402
#
# Current Learning rate 0.0001
# Train Epoch: 54 [0/54199 (0%)]	log Loss: -7.590925
#
# Train set: Average log loss: -7.5093
#
#
# Test set: Average loss: -7.4741
#
# Current Learning rate 0.0001
# Train Epoch: 55 [0/54199 (0%)]	log Loss: -7.619500
#
# Train set: Average log loss: -7.5269
#
#
# Test set: Average loss: -7.5091
#
# Current Learning rate 0.0001
# Train Epoch: 56 [0/54199 (0%)]	log Loss: -7.650798
#
# Train set: Average log loss: -7.5468
#
#
# Test set: Average loss: -7.5454
#
# Current Learning rate 0.0001
# Train Epoch: 57 [0/54199 (0%)]	log Loss: -7.680304
#
# Train set: Average log loss: -7.5666
#
#
# Test set: Average loss: -7.5767
#
# Current Learning rate 0.0001
# Train Epoch: 58 [0/54199 (0%)]	log Loss: -7.706362
#
# Train set: Average log loss: -7.5875
#
#
# Test set: Average loss: -7.6015
#
# Current Learning rate 0.0001
# Train Epoch: 59 [0/54199 (0%)]	log Loss: -7.724545
#
# Train set: Average log loss: -7.6087
#
#
# Test set: Average loss: -7.6190
#
# Current Learning rate 0.0001
# Train Epoch: 60 [0/54199 (0%)]	log Loss: -7.732401
#
# Train set: Average log loss: -7.6294
#
#
# Test set: Average loss: -7.6209
#
# Current Learning rate 0.0001
# Train Epoch: 61 [0/54199 (0%)]	log Loss: -7.718995
#
# Train set: Average log loss: -7.6481
#
#
# Test set: Average loss: -7.6190
#
# Current Learning rate 0.0001
# Train Epoch: 62 [0/54199 (0%)]	log Loss: -7.706173
#
# Train set: Average log loss: -7.6622
#
#
# Test set: Average loss: -7.6097
#
# Current Learning rate 0.0001
# Train Epoch: 63 [0/54199 (0%)]	log Loss: -7.683581
#
# Train set: Average log loss: -7.6745
#
#
# Test set: Average loss: -7.6047
#
# Current Learning rate 0.0001
# Train Epoch: 64 [0/54199 (0%)]	log Loss: -7.670202
#
# Train set: Average log loss: -7.6887
#
#
# Test set: Average loss: -7.6068
#
# Current Learning rate 0.0001
# Train Epoch: 65 [0/54199 (0%)]	log Loss: -7.666754
#
# Train set: Average log loss: -7.7035
#
#
# Test set: Average loss: -7.6099
#
# Current Learning rate 0.0001
# Train Epoch: 66 [0/54199 (0%)]	log Loss: -7.665117
#
# Train set: Average log loss: -7.7170
#
#
# Test set: Average loss: -7.6135
#
# Current Learning rate 0.0001
# Train Epoch: 67 [0/54199 (0%)]	log Loss: -7.664571
#
# Train set: Average log loss: -7.7326
#
#
# Test set: Average loss: -7.6239
#
# Current Learning rate 0.0001
# Train Epoch: 68 [0/54199 (0%)]	log Loss: -7.672399
#
# Train set: Average log loss: -7.7476
#
#
# Test set: Average loss: -7.6297
#
# Current Learning rate 0.0001
# Train Epoch: 69 [0/54199 (0%)]	log Loss: -7.675287
#
# Train set: Average log loss: -7.7612
#
#
# Test set: Average loss: -7.6310
#
# Current Learning rate 0.0001
# Train Epoch: 70 [0/54199 (0%)]	log Loss: -7.671199
#
# Train set: Average log loss: -7.7754
#
#
# Test set: Average loss: -7.6335
#
# Current Learning rate 0.0001
# Train Epoch: 71 [0/54199 (0%)]	log Loss: -7.670314
#
# Train set: Average log loss: -7.7883
#
#
# Test set: Average loss: -7.6401
#
# Current Learning rate 0.0001
# Train Epoch: 72 [0/54199 (0%)]	log Loss: -7.674047
#
# Train set: Average log loss: -7.8016
#
#
# Test set: Average loss: -7.6441
#
# Current Learning rate 0.0001
# Train Epoch: 73 [0/54199 (0%)]	log Loss: -7.675019
#
# Train set: Average log loss: -7.8151
#
#
# Test set: Average loss: -7.6476
#
# Current Learning rate 0.0001
# Train Epoch: 74 [0/54199 (0%)]	log Loss: -7.677543
#
# Train set: Average log loss: -7.8274
#
#
# Test set: Average loss: -7.6577
#
# Current Learning rate 0.0001
# Train Epoch: 75 [0/54199 (0%)]	log Loss: -7.687666
#
# Train set: Average log loss: -7.8400
#
#
# Test set: Average loss: -7.6635
#
# Current Learning rate 0.0001
# Train Epoch: 76 [0/54199 (0%)]	log Loss: -7.692220
#
# Train set: Average log loss: -7.8547
#
#
# Test set: Average loss: -7.6780
#
# Current Learning rate 0.0001
# Train Epoch: 77 [0/54199 (0%)]	log Loss: -7.710046
#
# Train set: Average log loss: -7.8667
#
#
# Test set: Average loss: -7.6835
#
# Current Learning rate 0.0001
# Train Epoch: 78 [0/54199 (0%)]	log Loss: -7.714483
#
# Train set: Average log loss: -7.8783
#
#
# Test set: Average loss: -7.6920
#
# Current Learning rate 0.0001
# Train Epoch: 79 [0/54199 (0%)]	log Loss: -7.724683
#
# Train set: Average log loss: -7.8905
#
#
# Test set: Average loss: -7.6954
#
# Current Learning rate 0.0001
# Train Epoch: 80 [0/54199 (0%)]	log Loss: -7.727449
#
# Train set: Average log loss: -7.9021
#
#
# Test set: Average loss: -7.7005
#
# Current Learning rate 0.0001
# Train Epoch: 81 [0/54199 (0%)]	log Loss: -7.731048
#
# Train set: Average log loss: -7.9126
#
#
# Test set: Average loss: -7.7070
#
# Current Learning rate 0.0001
# Train Epoch: 82 [0/54199 (0%)]	log Loss: -7.738251
#
# Train set: Average log loss: -7.9263
#
#
# Test set: Average loss: -7.7195
#
# Current Learning rate 0.0001
# Train Epoch: 83 [0/54199 (0%)]	log Loss: -7.751997
#
# Train set: Average log loss: -7.9366
#
#
# Test set: Average loss: -7.7188
#
# Current Learning rate 0.0001
# Train Epoch: 84 [0/54199 (0%)]	log Loss: -7.750027
#
# Train set: Average log loss: -7.9458
#
#
# Test set: Average loss: -7.7240
#
# Current Learning rate 0.0001
# Train Epoch: 85 [0/54199 (0%)]	log Loss: -7.754201
#
# Train set: Average log loss: -7.9543
#
#
# Test set: Average loss: -7.7287
#
# Current Learning rate 0.0001
# Train Epoch: 86 [0/54199 (0%)]	log Loss: -7.756991
#
# Train set: Average log loss: -7.9642
#
#
# Test set: Average loss: -7.7488
#
# Current Learning rate 0.0001
# Train Epoch: 87 [0/54199 (0%)]	log Loss: -7.783346
#
# Train set: Average log loss: -7.9758
#
#
# Test set: Average loss: -7.7555
#
# Current Learning rate 0.0001
# Train Epoch: 88 [0/54199 (0%)]	log Loss: -7.790954
#
# Train set: Average log loss: -7.9851
#
#
# Test set: Average loss: -7.7590
#
# Current Learning rate 0.0001
# Train Epoch: 89 [0/54199 (0%)]	log Loss: -7.792088
#
# Train set: Average log loss: -7.9937
#
#
# Test set: Average loss: -7.7664
#
# Current Learning rate 0.0001
# Train Epoch: 90 [0/54199 (0%)]	log Loss: -7.799194
#
# Train set: Average log loss: -8.0042
#
#
# Test set: Average loss: -7.7775
#
# Current Learning rate 0.0001
# Train Epoch: 91 [0/54199 (0%)]	log Loss: -7.811214
#
# Train set: Average log loss: -8.0153
#
#
# Test set: Average loss: -7.7894
#
# Current Learning rate 0.0001
# Train Epoch: 92 [0/54199 (0%)]	log Loss: -7.823721
#
# Train set: Average log loss: -8.0259
#
#
# Test set: Average loss: -7.7975
#
# Current Learning rate 0.0001
# Train Epoch: 93 [0/54199 (0%)]	log Loss: -7.832344
#
# Train set: Average log loss: -8.0363
#
#
# Test set: Average loss: -7.8023
#
# Current Learning rate 0.0001
# Train Epoch: 94 [0/54199 (0%)]	log Loss: -7.834229
#
# Train set: Average log loss: -8.0473
#
#
# Test set: Average loss: -7.7998
#
# Current Learning rate 0.0001
# Train Epoch: 95 [0/54199 (0%)]	log Loss: -7.830069
#
# Train set: Average log loss: -8.0549
#
#
# Test set: Average loss: -7.8018
#
# Current Learning rate 0.0001
# Train Epoch: 96 [0/54199 (0%)]	log Loss: -7.829468
#
# Train set: Average log loss: -8.0635
#
#
# Test set: Average loss: -7.8056
#
# Current Learning rate 0.0001
# Train Epoch: 97 [0/54199 (0%)]	log Loss: -7.833705
#
# Train set: Average log loss: -8.0706
#
#
# Test set: Average loss: -7.8135
#
# Current Learning rate 0.0001
# Train Epoch: 98 [0/54199 (0%)]	log Loss: -7.843433
#
# Train set: Average log loss: -8.0814
#
#
# Test set: Average loss: -7.8232
#
# Current Learning rate 0.0001
# Train Epoch: 99 [0/54199 (0%)]	log Loss: -7.855442
#
# Train set: Average log loss: -8.0922
#
#
# Test set: Average loss: -7.8285
#
# Current Learning rate 0.0001
# Train Epoch: 100 [0/54199 (0%)]	log Loss: -7.861033
#
# Train set: Average log loss: -8.0998
#
#
# Test set: Average loss: -7.8300
#
# Current Learning rate 0.0001
# Train Epoch: 101 [0/54199 (0%)]	log Loss: -7.861907
#
# Train set: Average log loss: -8.1069
#
#
# Test set: Average loss: -7.8352
#
# Current Learning rate 0.0001
# Train Epoch: 102 [0/54199 (0%)]	log Loss: -7.867086
#
# Train set: Average log loss: -8.1147
#
#
# Test set: Average loss: -7.8489
#
# Current Learning rate 0.0001
# Train Epoch: 103 [0/54199 (0%)]	log Loss: -7.883631
#
# Train set: Average log loss: -8.1247
#
#
# Test set: Average loss: -7.8664
#
# Current Learning rate 0.0001
# Train Epoch: 104 [0/54199 (0%)]	log Loss: -7.905750
#
# Train set: Average log loss: -8.1362
#
#
# Test set: Average loss: -7.8799
#
# Current Learning rate 0.0001
# Train Epoch: 105 [0/54199 (0%)]	log Loss: -7.922630
#
# Train set: Average log loss: -8.1471
#
#
# Test set: Average loss: -7.8881
#
# Current Learning rate 0.0001
# Train Epoch: 106 [0/54199 (0%)]	log Loss: -7.933211
#
# Train set: Average log loss: -8.1548
#
#
# Test set: Average loss: -7.8866
#
# Current Learning rate 0.0001
# Train Epoch: 107 [0/54199 (0%)]	log Loss: -7.932964
#
# Train set: Average log loss: -8.1633
#
#
# Test set: Average loss: -7.8976
#
# Current Learning rate 0.0001
# Train Epoch: 108 [0/54199 (0%)]	log Loss: -7.947296
#
# Train set: Average log loss: -8.1688
#
#
# Test set: Average loss: -7.9010
#
# Current Learning rate 0.0001
# Train Epoch: 109 [0/54199 (0%)]	log Loss: -7.951765
#
# Train set: Average log loss: -8.1796
#
#
# Test set: Average loss: -7.9191
#
# Current Learning rate 0.0001
# Train Epoch: 110 [0/54199 (0%)]	log Loss: -7.970451
#
# Train set: Average log loss: -8.1864
#
#
# Test set: Average loss: -7.9246
#
# Current Learning rate 0.0001
# Train Epoch: 111 [0/54199 (0%)]	log Loss: -7.975734
#
# Train set: Average log loss: -8.1934
#
#
# Test set: Average loss: -7.9311
#
# Current Learning rate 0.0001
# Train Epoch: 112 [0/54199 (0%)]	log Loss: -7.979134
#
# Train set: Average log loss: -8.2012
#
#
# Test set: Average loss: -7.9478
#
# Current Learning rate 0.0001
# Train Epoch: 113 [0/54199 (0%)]	log Loss: -7.998393
#
# Train set: Average log loss: -8.2111
#
#
# Test set: Average loss: -7.9615
#
# Current Learning rate 0.0001
# Train Epoch: 114 [0/54199 (0%)]	log Loss: -8.010844
#
# Train set: Average log loss: -8.2192
#
#
# Test set: Average loss: -7.9646
#
# Current Learning rate 0.0001
# Train Epoch: 115 [0/54199 (0%)]	log Loss: -8.013391
#
# Train set: Average log loss: -8.2252
#
#
# Test set: Average loss: -7.9741
#
# Current Learning rate 0.0001
# Train Epoch: 116 [0/54199 (0%)]	log Loss: -8.022669
#
# Train set: Average log loss: -8.2343
#
#
# Test set: Average loss: -7.9920
#
# Current Learning rate 0.0001
# Train Epoch: 117 [0/54199 (0%)]	log Loss: -8.043777
#
# Train set: Average log loss: -8.2419
#
#
# Test set: Average loss: -8.0038
#
# Current Learning rate 0.0001
# Train Epoch: 118 [0/54199 (0%)]	log Loss: -8.055363
#
# Train set: Average log loss: -8.2511
#
#
# Test set: Average loss: -8.0218
#
# Current Learning rate 0.0001
# Train Epoch: 119 [0/54199 (0%)]	log Loss: -8.076308
#
# Train set: Average log loss: -8.2603
#
#
# Test set: Average loss: -8.0350
#
# Current Learning rate 0.0001
# Train Epoch: 120 [0/54199 (0%)]	log Loss: -8.091320
#
# Train set: Average log loss: -8.2686
#
#
# Test set: Average loss: -8.0463
#
# Current Learning rate 0.0001
# Train Epoch: 121 [0/54199 (0%)]	log Loss: -8.104517
#
# Train set: Average log loss: -8.2778
#
#
# Test set: Average loss: -8.0570
#
# Current Learning rate 0.0001
# Train Epoch: 122 [0/54199 (0%)]	log Loss: -8.117955
#
# Train set: Average log loss: -8.2884
#
#
# Test set: Average loss: -8.0689
#
# Current Learning rate 0.0001
# Train Epoch: 123 [0/54199 (0%)]	log Loss: -8.131888
#
# Train set: Average log loss: -8.2948
#
#
# Test set: Average loss: -8.0699
#
# Current Learning rate 0.0001
# Train Epoch: 124 [0/54199 (0%)]	log Loss: -8.134083
#
# Train set: Average log loss: -8.3018
#
#
# Test set: Average loss: -8.0736
#
# Current Learning rate 0.0001
# Train Epoch: 125 [0/54199 (0%)]	log Loss: -8.137783
#
# Train set: Average log loss: -8.3088
#
#
# Test set: Average loss: -8.0797
#
# Current Learning rate 0.0001
# Train Epoch: 126 [0/54199 (0%)]	log Loss: -8.143856
#
# Train set: Average log loss: -8.3171
#
#
# Test set: Average loss: -8.0906
#
# Current Learning rate 0.0001
# Train Epoch: 127 [0/54199 (0%)]	log Loss: -8.156188
#
# Train set: Average log loss: -8.3263
#
#
# Test set: Average loss: -8.0921
#
# Current Learning rate 0.0001
# Train Epoch: 128 [0/54199 (0%)]	log Loss: -8.157611
#
# Train set: Average log loss: -8.3349
#
#
# Test set: Average loss: -8.0952
#
# Current Learning rate 0.0001
# Train Epoch: 129 [0/54199 (0%)]	log Loss: -8.158565
#
# Train set: Average log loss: -8.3418
#
#
# Test set: Average loss: -8.0968
#
# Current Learning rate 0.0001
# Train Epoch: 130 [0/54199 (0%)]	log Loss: -8.160193
#
# Train set: Average log loss: -8.3457
#
#
# Test set: Average loss: -8.1017
#
# Current Learning rate 0.0001
# Train Epoch: 131 [0/54199 (0%)]	log Loss: -8.165308
#
# Train set: Average log loss: -8.3555
#
#
# Test set: Average loss: -8.1135
#
# Current Learning rate 0.0001
# Train Epoch: 132 [0/54199 (0%)]	log Loss: -8.177205
#
# Train set: Average log loss: -8.3639
#
#
# Test set: Average loss: -8.1190
#
# Current Learning rate 0.0001
# Train Epoch: 133 [0/54199 (0%)]	log Loss: -8.182546
#
# Train set: Average log loss: -8.3714
#
#
# Test set: Average loss: -8.1178
#
# Current Learning rate 0.0001
# Train Epoch: 134 [0/54199 (0%)]	log Loss: -8.179244
#
# Train set: Average log loss: -8.3793
#
#
# Test set: Average loss: -8.1208
#
# Current Learning rate 0.0001
# Train Epoch: 135 [0/54199 (0%)]	log Loss: -8.181700
#
# Train set: Average log loss: -8.3876
#
#
# Test set: Average loss: -8.1266
#
# Current Learning rate 0.0001
# Train Epoch: 136 [0/54199 (0%)]	log Loss: -8.187507
#
# Train set: Average log loss: -8.3954
#
#
# Test set: Average loss: -8.1282
#
# Current Learning rate 0.0001
# Train Epoch: 137 [0/54199 (0%)]	log Loss: -8.188386
#
# Train set: Average log loss: -8.4019
#
#
# Test set: Average loss: -8.1356
#
# Current Learning rate 0.0001
# Train Epoch: 138 [0/54199 (0%)]	log Loss: -8.195483
#
# Train set: Average log loss: -8.4117
#
#
# Test set: Average loss: -8.1471
#
# Current Learning rate 0.0001
# Train Epoch: 139 [0/54199 (0%)]	log Loss: -8.206990
#
# Train set: Average log loss: -8.4188
#
#
# Test set: Average loss: -8.1446
#
# Current Learning rate 0.0001
# Train Epoch: 140 [0/54199 (0%)]	log Loss: -8.203013
#
# Train set: Average log loss: -8.4276
#
#
# Test set: Average loss: -8.1499
#
# Current Learning rate 0.0001
# Train Epoch: 141 [0/54199 (0%)]	log Loss: -8.207913
#
# Train set: Average log loss: -8.4368
#
#
# Test set: Average loss: -8.1539
#
# Current Learning rate 0.0001
# Train Epoch: 142 [0/54199 (0%)]	log Loss: -8.211421
#
# Train set: Average log loss: -8.4433
#
#
# Test set: Average loss: -8.1562
#
# Current Learning rate 0.0001
# Train Epoch: 143 [0/54199 (0%)]	log Loss: -8.212802
#
# Train set: Average log loss: -8.4536
#
#
# Test set: Average loss: -8.1590
#
# Current Learning rate 0.0001
# Train Epoch: 144 [0/54199 (0%)]	log Loss: -8.215278
#
# Train set: Average log loss: -8.4605
#
#
# Test set: Average loss: -8.1634
#
# Current Learning rate 0.0001
# Train Epoch: 145 [0/54199 (0%)]	log Loss: -8.219180
#
# Train set: Average log loss: -8.4737
#
#
# Test set: Average loss: -8.1692
#
# Current Learning rate 0.0001
# Train Epoch: 146 [0/54199 (0%)]	log Loss: -8.224764
#
# Train set: Average log loss: -8.4917
#
#
# Test set: Average loss: -8.1977
#
# Current Learning rate 0.0001
# Train Epoch: 147 [0/54199 (0%)]	log Loss: -8.258152
#
# Train set: Average log loss: -8.5150
#
#
# Test set: Average loss: -8.2419
#
# Current Learning rate 0.0001
# Train Epoch: 148 [0/54199 (0%)]	log Loss: -8.309578
#
# Train set: Average log loss: -8.5541
#
#
# Test set: Average loss: -8.3257
#
# Current Learning rate 0.0001
# Train Epoch: 149 [0/54199 (0%)]	log Loss: -8.410142
#
# Train set: Average log loss: -8.5994
#
#
# Test set: Average loss: -8.4076
#
# Current Learning rate 0.0001
# Train Epoch: 150 [0/54199 (0%)]	log Loss: -8.511273
#
# Train set: Average log loss: -8.6352
#
#
# Test set: Average loss: -8.4413
#
# Current Learning rate 0.0001
# Train Epoch: 151 [0/54199 (0%)]	log Loss: -8.552689
#
# Train set: Average log loss: -8.6502
#
#
# Test set: Average loss: -8.4612
#
# Current Learning rate 0.0001
# Train Epoch: 152 [0/54199 (0%)]	log Loss: -8.576623
#
# Train set: Average log loss: -8.6496
#
#
# Test set: Average loss: -8.5435
#
# Current Learning rate 0.0001
# Train Epoch: 153 [0/54199 (0%)]	log Loss: -8.681196
#
# Train set: Average log loss: -8.6432
#
#
# Test set: Average loss: -8.6221
#
# Current Learning rate 0.0001
# Train Epoch: 154 [0/54199 (0%)]	log Loss: -8.786947
#
# Train set: Average log loss: -8.6222
#
#
# Test set: Average loss: -8.6500
#
# Current Learning rate 0.0001
# Train Epoch: 155 [0/54199 (0%)]	log Loss: -8.824330
#
# Train set: Average log loss: -8.5939
#
#
# Test set: Average loss: -8.6697
#
# Current Learning rate 0.0001
# Train Epoch: 156 [0/54199 (0%)]	log Loss: -8.854761
#
# Train set: Average log loss: -8.5775
#
#
# Test set: Average loss: -8.6775
#
# Current Learning rate 0.0001
# Train Epoch: 157 [0/54199 (0%)]	log Loss: -8.862886
#
# Train set: Average log loss: -8.5783
#
#
# Test set: Average loss: -8.6866
#
# Current Learning rate 0.0001
# Train Epoch: 158 [0/54199 (0%)]	log Loss: -8.873049
#
# Train set: Average log loss: -8.5835
#
#
# Test set: Average loss: -8.6941
#
# Current Learning rate 0.0001
# Train Epoch: 159 [0/54199 (0%)]	log Loss: -8.880643
#
# Train set: Average log loss: -8.5901
#
#
# Test set: Average loss: -8.7025
#
# Current Learning rate 0.0001
# Train Epoch: 160 [0/54199 (0%)]	log Loss: -8.889641
#
# Train set: Average log loss: -8.5979
#
#
# Test set: Average loss: -8.7106
#
# Current Learning rate 0.0001
# Train Epoch: 161 [0/54199 (0%)]	log Loss: -8.897501
#
# Train set: Average log loss: -8.6087
#
#
# Test set: Average loss: -8.7169
#
# Current Learning rate 0.0001
# Train Epoch: 162 [0/54199 (0%)]	log Loss: -8.905477
#
# Train set: Average log loss: -8.6097
#
#
# Test set: Average loss: -8.7243
#
# Current Learning rate 0.0001
# Train Epoch: 163 [0/54199 (0%)]	log Loss: -8.914919
#
# Train set: Average log loss: -8.6228
#
#
# Test set: Average loss: -8.7333
#
# Current Learning rate 0.0001
# Train Epoch: 164 [0/54199 (0%)]	log Loss: -8.923776
#
# Train set: Average log loss: -8.6274
#
#
# Test set: Average loss: -8.7419
#
# Current Learning rate 0.0001
# Train Epoch: 165 [0/54199 (0%)]	log Loss: -8.933812
#
# Train set: Average log loss: -8.6307
#
#
# Test set: Average loss: -8.7494
#
# Current Learning rate 0.0001
# Train Epoch: 166 [0/54199 (0%)]	log Loss: -8.941637
#
# Train set: Average log loss: -8.6387
#
#
# Test set: Average loss: -8.7568
#
# Current Learning rate 0.0001
# Train Epoch: 167 [0/54199 (0%)]	log Loss: -8.949409
#
# Train set: Average log loss: -8.6421
#
#
# Test set: Average loss: -8.7638
#
# Current Learning rate 0.0001
# Train Epoch: 168 [0/54199 (0%)]	log Loss: -8.956207
#
# Train set: Average log loss: -8.6555
#
#
# Test set: Average loss: -8.7726
#
# Current Learning rate 0.0001
# Train Epoch: 169 [0/54199 (0%)]	log Loss: -8.964380
#
# Train set: Average log loss: -8.6541
#
#
# Test set: Average loss: -8.7782
#
# Current Learning rate 0.0001
# Train Epoch: 170 [0/54199 (0%)]	log Loss: -8.968170
#
# Train set: Average log loss: -8.6602
#
#
# Test set: Average loss: -8.7857
#
# Current Learning rate 0.0001
# Train Epoch: 171 [0/54199 (0%)]	log Loss: -8.975632
#
# Train set: Average log loss: -8.6667
#
#
# Test set: Average loss: -8.7920
#
# Current Learning rate 0.0001
# Train Epoch: 172 [0/54199 (0%)]	log Loss: -8.978019
#
# Train set: Average log loss: -8.6740
#
#
# Test set: Average loss: -8.7992
#
# Current Learning rate 0.0001
# Train Epoch: 173 [0/54199 (0%)]	log Loss: -8.983302
#
# Train set: Average log loss: -8.6785
#
#
# Test set: Average loss: -8.8056
#
# Current Learning rate 0.0001
# Train Epoch: 174 [0/54199 (0%)]	log Loss: -8.985152
#
# Train set: Average log loss: -8.6880
#
#
# Test set: Average loss: -8.8120
#
# Current Learning rate 0.0001
# Train Epoch: 175 [0/54199 (0%)]	log Loss: -8.989812
#
# Train set: Average log loss: -8.6954
#
#
# Test set: Average loss: -8.8169
#
# Current Learning rate 0.0001
# Train Epoch: 176 [0/54199 (0%)]	log Loss: -8.993147
#
# Train set: Average log loss: -8.7037
#
#
# Test set: Average loss: -8.8240
#
# Current Learning rate 0.0001
# Train Epoch: 177 [0/54199 (0%)]	log Loss: -9.001651
#
# Train set: Average log loss: -8.7061
#
#
# Test set: Average loss: -8.8275
#
# Current Learning rate 0.0001
# Train Epoch: 178 [0/54199 (0%)]	log Loss: -9.001949
#
# Train set: Average log loss: -8.7121
#
#
# Test set: Average loss: -8.8361
#
# Current Learning rate 0.0001
# Train Epoch: 179 [0/54199 (0%)]	log Loss: -9.012162
#
# Train set: Average log loss: -8.7241
#
#
# Test set: Average loss: -8.8430
#
# Current Learning rate 0.0001
# Train Epoch: 180 [0/54199 (0%)]	log Loss: -9.017907
#
# Train set: Average log loss: -8.7254
#
#
# Test set: Average loss: -8.8502
#
# Current Learning rate 0.0001
# Train Epoch: 181 [0/54199 (0%)]	log Loss: -9.024145
#
# Train set: Average log loss: -8.7265
#
#
# Test set: Average loss: -8.8591
#
# Current Learning rate 0.0001
# Train Epoch: 182 [0/54199 (0%)]	log Loss: -9.032849
#
# Train set: Average log loss: -8.7391
#
#
# Test set: Average loss: -8.8651
#
# Current Learning rate 0.0001
# Train Epoch: 183 [0/54199 (0%)]	log Loss: -9.039946
#
# Train set: Average log loss: -8.7464
#
#
# Test set: Average loss: -8.8735
#
# Current Learning rate 0.0001
# Train Epoch: 184 [0/54199 (0%)]	log Loss: -9.049493
#
# Train set: Average log loss: -8.7493
#
#
# Test set: Average loss: -8.8778
#
# Current Learning rate 0.0001
# Train Epoch: 185 [0/54199 (0%)]	log Loss: -9.051226
#
# Train set: Average log loss: -8.7595
#
#
# Test set: Average loss: -8.8841
#
# Current Learning rate 0.0001
# Train Epoch: 186 [0/54199 (0%)]	log Loss: -9.055980
#
# Train set: Average log loss: -8.7608
#
#
# Test set: Average loss: -8.8890
#
# Current Learning rate 0.0001
# Train Epoch: 187 [0/54199 (0%)]	log Loss: -9.061902
#
# Train set: Average log loss: -8.7681
#
#
# Test set: Average loss: -8.8969
#
# Current Learning rate 0.0001
# Train Epoch: 188 [0/54199 (0%)]	log Loss: -9.069160
#
# Train set: Average log loss: -8.7752
#
#
# Test set: Average loss: -8.9029
#
# Current Learning rate 0.0001
# Train Epoch: 189 [0/54199 (0%)]	log Loss: -9.074749
#
# Train set: Average log loss: -8.7903
#
#
# Test set: Average loss: -8.9091
#
# Current Learning rate 0.0001
# Train Epoch: 190 [0/54199 (0%)]	log Loss: -9.081360
#
# Train set: Average log loss: -8.7888
#
#
# Test set: Average loss: -8.9222
#
# Current Learning rate 0.0001
# Train Epoch: 191 [0/54199 (0%)]	log Loss: -9.096022
#
# Train set: Average log loss: -8.7998
#
#
# Test set: Average loss: -8.9277
#
# Current Learning rate 0.0001
# Train Epoch: 192 [0/54199 (0%)]	log Loss: -9.101571
#
# Train set: Average log loss: -8.8036
#
#
# Test set: Average loss: -8.9358
#
# Current Learning rate 0.0001
# Train Epoch: 193 [0/54199 (0%)]	log Loss: -9.109873
#
# Train set: Average log loss: -8.8098
#
#
# Test set: Average loss: -8.9419
#
# Current Learning rate 0.0001
# Train Epoch: 194 [0/54199 (0%)]	log Loss: -9.115461
#
# Train set: Average log loss: -8.8147
#
#
# Test set: Average loss: -8.9516
#
# Current Learning rate 0.0001
# Train Epoch: 195 [0/54199 (0%)]	log Loss: -9.125372
#
# Train set: Average log loss: -8.8216
#
#
# Test set: Average loss: -8.9555
#
# Current Learning rate 0.0001
# Train Epoch: 196 [0/54199 (0%)]	log Loss: -9.130016
#
# Train set: Average log loss: -8.8267
#
#
# Test set: Average loss: -8.9658
#
# Current Learning rate 0.0001
# Train Epoch: 197 [0/54199 (0%)]	log Loss: -9.139592
#
# Train set: Average log loss: -8.8399
#
#
# Test set: Average loss: -8.9726
#
# Current Learning rate 0.0001
# Train Epoch: 198 [0/54199 (0%)]	log Loss: -9.148775
#
# Train set: Average log loss: -8.8410
#
#
# Test set: Average loss: -8.9805
#
# Current Learning rate 0.0001
# Train Epoch: 199 [0/54199 (0%)]	log Loss: -9.158191
#
# Train set: Average log loss: -8.8549
#
#
# Test set: Average loss: -8.9859
#
# Current Learning rate 0.0001
# Train Epoch: 200 [0/54199 (0%)]	log Loss: -9.168311
#
# Train set: Average log loss: -8.8500
#
#
# Test set: Average loss: -8.9917
#
# Current Learning rate 0.0001
# Train Epoch: 201 [0/54199 (0%)]	log Loss: -9.171830
#
# Train set: Average log loss: -8.8651
#
#
# Test set: Average loss: -8.9964
#
# Current Learning rate 0.0001
# Train Epoch: 202 [0/54199 (0%)]	log Loss: -9.180414
#
# Train set: Average log loss: -8.8599
#
#
# Test set: Average loss: -9.0021
#
# Current Learning rate 0.0001
# Train Epoch: 203 [0/54199 (0%)]	log Loss: -9.183743
#
# Train set: Average log loss: -8.8756
#
#
# Test set: Average loss: -9.0077
#
# Current Learning rate 0.0001
# Train Epoch: 204 [0/54199 (0%)]	log Loss: -9.191820
#
# Train set: Average log loss: -8.8738
#
#
# Test set: Average loss: -9.0091
#
# Current Learning rate 0.0001
# Train Epoch: 205 [0/54199 (0%)]	log Loss: -9.191971
#
# Train set: Average log loss: -8.8895
#
#
# Test set: Average loss: -9.0147
#
# Current Learning rate 0.0001
# Train Epoch: 206 [0/54199 (0%)]	log Loss: -9.200661
#
# Train set: Average log loss: -8.8816
#
#
# Test set: Average loss: -9.0194
#
# Current Learning rate 0.0001
# Train Epoch: 207 [0/54199 (0%)]	log Loss: -9.203697
#
# Train set: Average log loss: -8.9006
#
#
# Test set: Average loss: -9.0149
#
# Current Learning rate 0.0001
# Train Epoch: 208 [0/54199 (0%)]	log Loss: -9.198091
#
# Train set: Average log loss: -8.8916
#
#
# Test set: Average loss: -9.0309
#
# Current Learning rate 0.0001
# Train Epoch: 209 [0/54199 (0%)]	log Loss: -9.216154
#
# Train set: Average log loss: -8.9070
#
#
# Test set: Average loss: -9.0229
#
# Current Learning rate 0.0001
# Train Epoch: 210 [0/54199 (0%)]	log Loss: -9.204964
#
# Train set: Average log loss: -8.9085
#
#
# Test set: Average loss: -9.0396
#
# Current Learning rate 0.0001
# Train Epoch: 211 [0/54199 (0%)]	log Loss: -9.224093
#
# Train set: Average log loss: -8.9171
#
#
# Test set: Average loss: -9.0333
#
# Current Learning rate 0.0001
# Train Epoch: 212 [0/54199 (0%)]	log Loss: -9.213644
#
# Train set: Average log loss: -8.9198
#
#
# Test set: Average loss: -9.0423
#
# Current Learning rate 0.0001
# Train Epoch: 213 [0/54199 (0%)]	log Loss: -9.224848
#
# Train set: Average log loss: -8.9286
#
#
# Test set: Average loss: -9.0385
#
# Current Learning rate 0.0001
# Train Epoch: 214 [0/54199 (0%)]	log Loss: -9.215970
#
# Train set: Average log loss: -8.9434
#
#
# Test set: Average loss: -9.0249
#
# Current Learning rate 0.0001
# Train Epoch: 215 [0/54199 (0%)]	log Loss: -9.200935
#
# Train set: Average log loss: -8.9402
#
#
# Test set: Average loss: -9.0389
#
# Current Learning rate 0.0001
# Train Epoch: 216 [0/54199 (0%)]	log Loss: -9.220691
#
# Train set: Average log loss: -8.9318
#
#
# Test set: Average loss: -9.0660
#
# Current Learning rate 0.0001
# Train Epoch: 217 [0/54199 (0%)]	log Loss: -9.248762
#
# Train set: Average log loss: -8.9484
#
#
# Test set: Average loss: -9.0524
#
# Current Learning rate 0.0001
# Train Epoch: 218 [0/54199 (0%)]	log Loss: -9.228589
#
# Train set: Average log loss: -8.9729
#
#
# Test set: Average loss: -9.0366
#
# Current Learning rate 0.0001
# Train Epoch: 219 [0/54199 (0%)]	log Loss: -9.214916
#
# Train set: Average log loss: -8.9664
#
#
# Test set: Average loss: -9.0254
#
# Current Learning rate 0.0001
# Train Epoch: 220 [0/54199 (0%)]	log Loss: -9.202923
#
# Train set: Average log loss: -8.9614
#
#
# Test set: Average loss: -9.0547
#
# Current Learning rate 0.0001
# Train Epoch: 221 [0/54199 (0%)]	log Loss: -9.235800
#
# Train set: Average log loss: -8.9459
#
#
# Test set: Average loss: -9.0900
#
# Current Learning rate 0.0001
# Train Epoch: 222 [0/54199 (0%)]	log Loss: -9.270979
#
# Train set: Average log loss: -8.9590
#
#
# Test set: Average loss: -9.0483
#
# Current Learning rate 0.0001
# Train Epoch: 223 [0/54199 (0%)]	log Loss: -9.223109
#
# Train set: Average log loss: -9.0213
#
#
# Test set: Average loss: -9.0488
#
# Current Learning rate 0.0001
# Train Epoch: 224 [0/54199 (0%)]	log Loss: -9.219803
#
# Train set: Average log loss: -9.0209
#
#
# Test set: Average loss: -8.8997
#
# Current Learning rate 0.0001
# Train Epoch: 225 [0/54199 (0%)]	log Loss: -9.049981
#
# Train set: Average log loss: -9.0363
#
#
# Test set: Average loss: -8.5338
#
# Current Learning rate 0.0001
# Train Epoch: 226 [0/54199 (0%)]	log Loss: -8.637874
#
# Train set: Average log loss: -9.0234
#
#
# Test set: Average loss: -8.2956
#
# Current Learning rate 0.0001
# Train Epoch: 227 [0/54199 (0%)]	log Loss: -8.377868
#
# Train set: Average log loss: -8.9465
#
#
# Test set: Average loss: -8.5413
#
# Current Learning rate 0.0001
# Train Epoch: 228 [0/54199 (0%)]	log Loss: -8.654008
#
# Train set: Average log loss: -8.8816
#
#
# Test set: Average loss: -9.1326
#
# Current Learning rate 0.0001
# Train Epoch: 229 [0/54199 (0%)]	log Loss: -9.307614
#
# Train set: Average log loss: -8.9591
#
#
# Test set: Average loss: -8.7507
#
# Current Learning rate 0.0001
# Train Epoch: 230 [0/54199 (0%)]	log Loss: -8.871573
#
# Train set: Average log loss: -9.0471
#
#
# Test set: Average loss: -8.8592
#
# Current Learning rate 0.0001
# Train Epoch: 231 [0/54199 (0%)]	log Loss: -8.993043
#
# Train set: Average log loss: -9.0434
#
#
# Test set: Average loss: -8.9706
#
# Current Learning rate 0.0001
# Train Epoch: 232 [0/54199 (0%)]	log Loss: -9.119941
#
# Train set: Average log loss: -9.0462
#
#
# Test set: Average loss: -9.0418
#
# Current Learning rate 0.0001
# Train Epoch: 233 [0/54199 (0%)]	log Loss: -9.197178
#
# Train set: Average log loss: -9.0258
#
#
# Test set: Average loss: -9.0538
#
# Current Learning rate 0.0001
# Train Epoch: 234 [0/54199 (0%)]	log Loss: -9.209907
#
# Train set: Average log loss: -9.0203
#
#
# Test set: Average loss: -9.0098
#
# Current Learning rate 0.0001
# Train Epoch: 235 [0/54199 (0%)]	log Loss: -9.159377
#
# Train set: Average log loss: -9.0508
#
#
# Test set: Average loss: -9.0010
#
# Current Learning rate 0.0001
# Train Epoch: 236 [0/54199 (0%)]	log Loss: -9.148940
#
# Train set: Average log loss: -9.0727
#
#
# Test set: Average loss: -9.0485
#
# Current Learning rate 0.0001
# Train Epoch: 237 [0/54199 (0%)]	log Loss: -9.201007
#
# Train set: Average log loss: -9.0785
#
#
# Test set: Average loss: -9.0483
#
# Current Learning rate 0.0001
# Train Epoch: 238 [0/54199 (0%)]	log Loss: -9.199525
#
# Train set: Average log loss: -9.0864
#
#
# Test set: Average loss: -9.0121
#
# Current Learning rate 0.0001
# Train Epoch: 239 [0/54199 (0%)]	log Loss: -9.156369
#
# Train set: Average log loss: -9.1257
#
#
# Test set: Average loss: -8.7693
#
# Current Learning rate 0.0001
# Train Epoch: 240 [0/54199 (0%)]	log Loss: -8.883564
#
# Train set: Average log loss: -9.2060
#
#
# Test set: Average loss: -9.1088
#
# Current Learning rate 0.0001
# Train Epoch: 241 [0/54199 (0%)]	log Loss: -9.264356
#
# Train set: Average log loss: -8.9609
#
#
# Test set: Average loss: -8.7936
#
# Current Learning rate 0.0001
# Train Epoch: 242 [0/54199 (0%)]	log Loss: -8.901831
#
# Train set: Average log loss: -9.0213
#
#
# Test set: Average loss: -8.9097
#
# Current Learning rate 0.0001
# Train Epoch: 243 [0/54199 (0%)]	log Loss: -9.033517
#
# Train set: Average log loss: -9.0146
#
#
# Test set: Average loss: -8.5560
#
# Current Learning rate 0.0001
# Train Epoch: 244 [0/54199 (0%)]	log Loss: -8.649264
#
# Train set: Average log loss: -8.7275
#
#
# Test set: Average loss: -8.4318
#
# Current Learning rate 0.0001
# Train Epoch: 245 [0/54199 (0%)]	log Loss: -8.525573
#
# Train set: Average log loss: -8.7716
#
#
# Test set: Average loss: -9.0050
#
# Current Learning rate 0.0001
# Train Epoch: 246 [0/54199 (0%)]	log Loss: -9.107334
#
# Train set: Average log loss: -9.0964
#
#
# Test set: Average loss: -9.2264
#
# Current Learning rate 0.0001
# Train Epoch: 247 [0/54199 (0%)]	log Loss: -9.375475
#
# Train set: Average log loss: -9.0704
#
#
# Test set: Average loss: -9.2318
#
# Current Learning rate 0.0001
# Train Epoch: 248 [0/54199 (0%)]	log Loss: -9.384100
#
# Train set: Average log loss: -9.0692
#
#
# Test set: Average loss: -9.2381
#
# Current Learning rate 0.0001
# Train Epoch: 249 [0/54199 (0%)]	log Loss: -9.391104
#
# Train set: Average log loss: -9.0602
#
#
# Test set: Average loss: -9.2377
#
# Current Learning rate 0.0001
# Train Epoch: 250 [0/54199 (0%)]	log Loss: -9.387331
#
# Train set: Average log loss: -9.0675
#
#
# Test set: Average loss: -9.2366
#
# Current Learning rate 0.0001
# Train Epoch: 251 [0/54199 (0%)]	log Loss: -9.382710
#
# Train set: Average log loss: -9.0713
#
#
# Test set: Average loss: -9.2282
#
# Current Learning rate 0.0001
# Train Epoch: 252 [0/54199 (0%)]	log Loss: -9.371494
#
# Train set: Average log loss: -9.0722
#
#
# Test set: Average loss: -9.2234
#
# Current Learning rate 0.0001
# Train Epoch: 253 [0/54199 (0%)]	log Loss: -9.364353
#
# Train set: Average log loss: -9.0726
#
#
# Test set: Average loss: -9.2197
#
# Current Learning rate 0.0001
# Train Epoch: 254 [0/54199 (0%)]	log Loss: -9.361231
#
# Train set: Average log loss: -9.0722
#
#
# Test set: Average loss: -9.2071
#
# Current Learning rate 0.0001
# Train Epoch: 255 [0/54199 (0%)]	log Loss: -9.345722
#
# Train set: Average log loss: -9.0713
#
#
# Test set: Average loss: -9.1992
#
# Current Learning rate 0.0001
# Train Epoch: 256 [0/54199 (0%)]	log Loss: -9.337669
#
# Train set: Average log loss: -9.0750
#
#
# Test set: Average loss: -9.1856
#
# Current Learning rate 0.0001
# Train Epoch: 257 [0/54199 (0%)]	log Loss: -9.321151
#
# Train set: Average log loss: -9.0742
#
#
# Test set: Average loss: -9.1637
#
# Current Learning rate 0.0001
# Train Epoch: 258 [0/54199 (0%)]	log Loss: -9.298955
#
# Train set: Average log loss: -9.0690
#
#
# Test set: Average loss: -9.1537
#
# Current Learning rate 0.0001
# Train Epoch: 259 [0/54199 (0%)]	log Loss: -9.283198
#
# Train set: Average log loss: -9.0769
#
#
# Test set: Average loss: -9.1328
#
# Current Learning rate 0.0001
# Train Epoch: 260 [0/54199 (0%)]	log Loss: -9.262475
#
# Train set: Average log loss: -9.0718
#
#
# Test set: Average loss: -9.1128
#
# Current Learning rate 0.0001
# Train Epoch: 261 [0/54199 (0%)]	log Loss: -9.240460
#
# Train set: Average log loss: -9.0968
#
#
# Test set: Average loss: -9.1099
#
# Current Learning rate 0.0001
# Train Epoch: 262 [0/54199 (0%)]	log Loss: -9.235605
#
# Train set: Average log loss: -9.1347
#
#
# Test set: Average loss: -9.1412
#
# Current Learning rate 0.0001
# Train Epoch: 263 [0/54199 (0%)]	log Loss: -9.266018
#
# Train set: Average log loss: -9.1932
#
#
# Test set: Average loss: -9.2040
#
# Current Learning rate 0.0001
# Train Epoch: 264 [0/54199 (0%)]	log Loss: -9.334577
#
# Train set: Average log loss: -9.1686
#
#
# Test set: Average loss: -9.2288
#
# Current Learning rate 0.0001
# Train Epoch: 265 [0/54199 (0%)]	log Loss: -9.361569
#
# Train set: Average log loss: -9.0924
#
#
# Test set: Average loss: -9.2278
#
# Current Learning rate 0.0001
# Train Epoch: 266 [0/54199 (0%)]	log Loss: -9.355422
#
# Train set: Average log loss: -9.0685
#
#
# Test set: Average loss: -9.1777
#
# Current Learning rate 0.0001
# Train Epoch: 267 [0/54199 (0%)]	log Loss: -9.300192
#
# Train set: Average log loss: -9.0754
#
#
# Test set: Average loss: -9.1543
#
# Current Learning rate 0.0001
# Train Epoch: 268 [0/54199 (0%)]	log Loss: -9.274967
#
# Train set: Average log loss: -9.0812
#
#
# Test set: Average loss: -9.1815
#
# Current Learning rate 0.0001
# Train Epoch: 269 [0/54199 (0%)]	log Loss: -9.306102
#
# Train set: Average log loss: -9.0822
#
#
# Test set: Average loss: -9.1917
#
# Current Learning rate 0.0001
# Train Epoch: 270 [0/54199 (0%)]	log Loss: -9.315896
#
# Train set: Average log loss: -9.0566
#
#
# Test set: Average loss: -9.1155
#
# Current Learning rate 0.0001
# Train Epoch: 271 [0/54199 (0%)]	log Loss: -9.226774
#
# Train set: Average log loss: -9.0131
#
#
# Test set: Average loss: -8.9860
#
# Current Learning rate 0.0001
# Train Epoch: 272 [0/54199 (0%)]	log Loss: -9.078792
#
# Train set: Average log loss: -9.0345
#
#
# Test set: Average loss: -9.0911
#
# Current Learning rate 0.0001
# Train Epoch: 273 [0/54199 (0%)]	log Loss: -9.197240
#
# Train set: Average log loss: -9.0803
#
#
# Test set: Average loss: -9.0958
#
# Current Learning rate 0.0001
# Train Epoch: 274 [0/54199 (0%)]	log Loss: -9.200154
#
# Train set: Average log loss: -9.0303
#
#
# Test set: Average loss: -8.9819
#
# Current Learning rate 0.0001
# Train Epoch: 275 [0/54199 (0%)]	log Loss: -9.065084
#
# Train set: Average log loss: -9.0257
#
#
# Test set: Average loss: -9.0248
#
# Current Learning rate 0.0001
# Train Epoch: 276 [0/54199 (0%)]	log Loss: -9.113611
#
# Train set: Average log loss: -9.0841
#
#
# Test set: Average loss: -9.0164
#
# Current Learning rate 0.0001
# Train Epoch: 277 [0/54199 (0%)]	log Loss: -9.099992
#
# Train set: Average log loss: -9.1022
#
#
# Test set: Average loss: -9.0183
#
# Current Learning rate 0.0001
# Train Epoch: 278 [0/54199 (0%)]	log Loss: -9.104737
#
# Train set: Average log loss: -9.1091
#
#
# Test set: Average loss: -9.0158
#
# Current Learning rate 0.0001
# Train Epoch: 279 [0/54199 (0%)]	log Loss: -9.101893
#
# Train set: Average log loss: -9.1233
#
#
# Test set: Average loss: -9.0324
#
# Current Learning rate 0.0001
# Train Epoch: 280 [0/54199 (0%)]	log Loss: -9.120398
#
# Train set: Average log loss: -9.1575
#
#
# Test set: Average loss: -9.1088
#
# Current Learning rate 0.0001
# Train Epoch: 281 [0/54199 (0%)]	log Loss: -9.211471
#
# Train set: Average log loss: -9.1830
#
#
# Test set: Average loss: -9.2189
#
# Current Learning rate 0.0001
# Train Epoch: 282 [0/54199 (0%)]	log Loss: -9.347539
#
# Train set: Average log loss: -9.1617
#
#
# Test set: Average loss: -9.2367
#
# Current Learning rate 0.0001
# Train Epoch: 283 [0/54199 (0%)]	log Loss: -9.368062
#
# Train set: Average log loss: -9.1835
#
#
# Test set: Average loss: -9.1853
#
# Current Learning rate 0.0001
# Train Epoch: 284 [0/54199 (0%)]	log Loss: -9.306173
#
# Train set: Average log loss: -9.1802
#
#
# Test set: Average loss: -9.2492
#
# Current Learning rate 0.0001
# Train Epoch: 285 [0/54199 (0%)]	log Loss: -9.385693
#
# Train set: Average log loss: -9.1311
#
#
# Test set: Average loss: -9.3515
#
# Current Learning rate 0.0001
# Train Epoch: 286 [0/54199 (0%)]	log Loss: -9.520045
#
# Train set: Average log loss: -9.1828
#
#
# Test set: Average loss: -8.9019
#
# Current Learning rate 0.0001
# Train Epoch: 287 [0/54199 (0%)]	log Loss: -8.980960
#
# Train set: Average log loss: -9.0234
#
#
# Test set: Average loss: -9.2912
#
# Current Learning rate 0.0001
# Train Epoch: 288 [0/54199 (0%)]	log Loss: -9.438887
#
# Train set: Average log loss: -9.1935
#
#
# Test set: Average loss: -9.2028
#
# Current Learning rate 0.0001
# Train Epoch: 289 [0/54199 (0%)]	log Loss: -9.337482
#
# Train set: Average log loss: -9.2437
#
#
# Test set: Average loss: -9.1870
#
# Current Learning rate 0.0001
# Train Epoch: 290 [0/54199 (0%)]	log Loss: -9.320031
#
# Train set: Average log loss: -9.3128
#
#
# Test set: Average loss: -9.3420
#
# Current Learning rate 0.0001
# Train Epoch: 291 [0/54199 (0%)]	log Loss: -9.512907
#
# Train set: Average log loss: -9.1395
#
#
# Test set: Average loss: -9.3497
#
# Current Learning rate 0.0001
# Train Epoch: 292 [0/54199 (0%)]	log Loss: -9.526703
#
# Train set: Average log loss: -9.2829
#
#
# Test set: Average loss: -9.0288
#
# Current Learning rate 0.0001
# Train Epoch: 293 [0/54199 (0%)]	log Loss: -9.137847
#
# Train set: Average log loss: -9.2774
#
#
# Test set: Average loss: -9.2268
#
# Current Learning rate 0.0001
# Train Epoch: 294 [0/54199 (0%)]	log Loss: -9.369147
#
# Train set: Average log loss: -9.1310
#
#
# Test set: Average loss: -9.2644
#
# Current Learning rate 0.0001
# Train Epoch: 295 [0/54199 (0%)]	log Loss: -9.441063
#
# Train set: Average log loss: -9.2553
#
#
# Test set: Average loss: -8.7000
#
# Current Learning rate 0.0001
# Train Epoch: 296 [0/54199 (0%)]	log Loss: -8.771832
#
# Train set: Average log loss: -9.0049
#
#
# Test set: Average loss: -9.3877
#
# Current Learning rate 0.0001
# Train Epoch: 297 [0/54199 (0%)]	log Loss: -9.575361
#
# Train set: Average log loss: -9.3246
#
#
# Test set: Average loss: -9.3816
#
# Current Learning rate 0.0001
# Train Epoch: 298 [0/54199 (0%)]	log Loss: -9.560835
#
# Train set: Average log loss: -9.3641
#
#
# Test set: Average loss: -9.3886
#
# Current Learning rate 0.0001
# Train Epoch: 299 [0/54199 (0%)]	log Loss: -9.570618
#
# Train set: Average log loss: -9.4384
#
#
# Test set: Average loss: -9.1856
#
# Current Learning rate 0.0001
# Train Epoch: 300 [0/54199 (0%)]	log Loss: -9.325905
#
# Train set: Average log loss: -9.0500
#
#
# Test set: Average loss: -9.4097
#
# Current Learning rate 0.0001
# Train Epoch: 301 [0/54199 (0%)]	log Loss: -9.598863
#
# Train set: Average log loss: -9.3338
#
#
# Test set: Average loss: -9.3522
#
# Current Learning rate 0.0001
# Train Epoch: 302 [0/54199 (0%)]	log Loss: -9.523362
#
# Train set: Average log loss: -9.2913
#
#
# Test set: Average loss: -9.0307
#
# Current Learning rate 0.0001
# Train Epoch: 303 [0/54199 (0%)]	log Loss: -9.147204
#
# Train set: Average log loss: -9.2899
#
#
# Test set: Average loss: -9.2858
#
# Current Learning rate 0.0001
# Train Epoch: 304 [0/54199 (0%)]	log Loss: -9.445261
#
# Train set: Average log loss: -9.2817
#
#
# Test set: Average loss: -9.3629
#
# Current Learning rate 0.0001
# Train Epoch: 305 [0/54199 (0%)]	log Loss: -9.538658
#
# Train set: Average log loss: -9.2830
#
#
# Test set: Average loss: -9.2163
#
# Current Learning rate 0.0001
# Train Epoch: 306 [0/54199 (0%)]	log Loss: -9.367479
#
# Train set: Average log loss: -9.0687
#
#
# Test set: Average loss: -8.9022
#
# Current Learning rate 0.0001
# Train Epoch: 307 [0/54199 (0%)]	log Loss: -8.990684
#
# Train set: Average log loss: -9.1191
#
#
# Test set: Average loss: -9.3563
#
# Current Learning rate 0.0001
# Train Epoch: 308 [0/54199 (0%)]	log Loss: -9.542048
#
# Train set: Average log loss: -9.2017
#
#
# Test set: Average loss: -8.9306
#
# Current Learning rate 0.0001
# Train Epoch: 309 [0/54199 (0%)]	log Loss: -9.044503
#
# Train set: Average log loss: -9.1658
#
#
# Test set: Average loss: -8.6073
#
# Current Learning rate 0.0001
# Train Epoch: 310 [0/54199 (0%)]	log Loss: -8.681653
#
# Train set: Average log loss: -9.2265
#
#
# Test set: Average loss: -8.9088
#
# Current Learning rate 0.0001
# Train Epoch: 311 [0/54199 (0%)]	log Loss: -9.014343
#
# Train set: Average log loss: -9.2809
#
#
# Test set: Average loss: -8.9320
#
# Current Learning rate 0.0001
# Train Epoch: 312 [0/54199 (0%)]	log Loss: -9.041318
#
# Train set: Average log loss: -9.3163
#
#
# Test set: Average loss: -8.9190
#
# Current Learning rate 0.0001
# Train Epoch: 313 [0/54199 (0%)]	log Loss: -9.026161
#
# ...
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7906 [0/54199 (0%)]	log Loss: -11.197723
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7907 [0/54199 (0%)]	log Loss: -11.197723
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7908 [0/54199 (0%)]	log Loss: -11.197720
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7909 [0/54199 (0%)]	log Loss: -11.197719
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7910 [0/54199 (0%)]	log Loss: -11.197722
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7911 [0/54199 (0%)]	log Loss: -11.197717
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7912 [0/54199 (0%)]	log Loss: -11.197716
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7913 [0/54199 (0%)]	log Loss: -11.197718
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7914 [0/54199 (0%)]	log Loss: -11.197716
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7915 [0/54199 (0%)]	log Loss: -11.197715
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7916 [0/54199 (0%)]	log Loss: -11.197719
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7917 [0/54199 (0%)]	log Loss: -11.197719
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7918 [0/54199 (0%)]	log Loss: -11.197718
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7919 [0/54199 (0%)]	log Loss: -11.197722
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7920 [0/54199 (0%)]	log Loss: -11.197720
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7921 [0/54199 (0%)]	log Loss: -11.197720
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7922 [0/54199 (0%)]	log Loss: -11.197722
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7923 [0/54199 (0%)]	log Loss: -11.197722
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7924 [0/54199 (0%)]	log Loss: -11.197721
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7925 [0/54199 (0%)]	log Loss: -11.197725
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7926 [0/54199 (0%)]	log Loss: -11.197721
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7927 [0/54199 (0%)]	log Loss: -11.197725
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7928 [0/54199 (0%)]	log Loss: -11.197724
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7929 [0/54199 (0%)]	log Loss: -11.197726
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7930 [0/54199 (0%)]	log Loss: -11.197720
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7931 [0/54199 (0%)]	log Loss: -11.197725
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7932 [0/54199 (0%)]	log Loss: -11.197725
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7933 [0/54199 (0%)]	log Loss: -11.197725
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7934 [0/54199 (0%)]	log Loss: -11.197725
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7935 [0/54199 (0%)]	log Loss: -11.197724
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7936 [0/54199 (0%)]	log Loss: -11.197720
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7937 [0/54199 (0%)]	log Loss: -11.197723
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7938 [0/54199 (0%)]	log Loss: -11.197720
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7939 [0/54199 (0%)]	log Loss: -11.197724
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7940 [0/54199 (0%)]	log Loss: -11.197728
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7941 [0/54199 (0%)]	log Loss: -11.197726
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7942 [0/54199 (0%)]	log Loss: -11.197728
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7943 [0/54199 (0%)]	log Loss: -11.197726
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7944 [0/54199 (0%)]	log Loss: -11.197727
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7945 [0/54199 (0%)]	log Loss: -11.197723
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7946 [0/54199 (0%)]	log Loss: -11.197723
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7947 [0/54199 (0%)]	log Loss: -11.197724
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7948 [0/54199 (0%)]	log Loss: -11.197726
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7949 [0/54199 (0%)]	log Loss: -11.197726
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7950 [0/54199 (0%)]	log Loss: -11.197725
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7951 [0/54199 (0%)]	log Loss: -11.197725
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7952 [0/54199 (0%)]	log Loss: -11.197729
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7953 [0/54199 (0%)]	log Loss: -11.197728
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7954 [0/54199 (0%)]	log Loss: -11.197730
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7955 [0/54199 (0%)]	log Loss: -11.197731
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7956 [0/54199 (0%)]	log Loss: -11.197726
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7957 [0/54199 (0%)]	log Loss: -11.197732
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7958 [0/54199 (0%)]	log Loss: -11.197735
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7959 [0/54199 (0%)]	log Loss: -11.197731
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7960 [0/54199 (0%)]	log Loss: -11.197734
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7961 [0/54199 (0%)]	log Loss: -11.197733
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7962 [0/54199 (0%)]	log Loss: -11.197732
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7963 [0/54199 (0%)]	log Loss: -11.197732
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7964 [0/54199 (0%)]	log Loss: -11.197735
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7965 [0/54199 (0%)]	log Loss: -11.197729
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7966 [0/54199 (0%)]	log Loss: -11.197731
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7967 [0/54199 (0%)]	log Loss: -11.197733
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7968 [0/54199 (0%)]	log Loss: -11.197732
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7969 [0/54199 (0%)]	log Loss: -11.197734
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7970 [0/54199 (0%)]	log Loss: -11.197733
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7971 [0/54199 (0%)]	log Loss: -11.197734
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7972 [0/54199 (0%)]	log Loss: -11.197735
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7973 [0/54199 (0%)]	log Loss: -11.197735
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7974 [0/54199 (0%)]	log Loss: -11.197735
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7975 [0/54199 (0%)]	log Loss: -11.197735
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7976 [0/54199 (0%)]	log Loss: -11.197730
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7977 [0/54199 (0%)]	log Loss: -11.197732
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7978 [0/54199 (0%)]	log Loss: -11.197730
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7979 [0/54199 (0%)]	log Loss: -11.197734
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7980 [0/54199 (0%)]	log Loss: -11.197733
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7981 [0/54199 (0%)]	log Loss: -11.197736
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7982 [0/54199 (0%)]	log Loss: -11.197739
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7983 [0/54199 (0%)]	log Loss: -11.197738
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7984 [0/54199 (0%)]	log Loss: -11.197743
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7985 [0/54199 (0%)]	log Loss: -11.197740
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7986 [0/54199 (0%)]	log Loss: -11.197740
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7987 [0/54199 (0%)]	log Loss: -11.197742
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7988 [0/54199 (0%)]	log Loss: -11.197739
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7989 [0/54199 (0%)]	log Loss: -11.197740
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7990 [0/54199 (0%)]	log Loss: -11.197738
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7991 [0/54199 (0%)]	log Loss: -11.197744
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7992 [0/54199 (0%)]	log Loss: -11.197740
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7993 [0/54199 (0%)]	log Loss: -11.197741
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7994 [0/54199 (0%)]	log Loss: -11.197739
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7995 [0/54199 (0%)]	log Loss: -11.197744
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7996 [0/54199 (0%)]	log Loss: -11.197739
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7997 [0/54199 (0%)]	log Loss: -11.197736
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7998 [0/54199 (0%)]	log Loss: -11.197735
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 7999 [0/54199 (0%)]	log Loss: -11.197737
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09
# Train Epoch: 8000 [0/54199 (0%)]	log Loss: -11.197741
#
# Train set: Average log loss: -11.1733
#
#
# Test set: Average loss: -10.6433
#
# Current Learning rate 3.0517578125e-09

# %%
# Plotting log(MSE) as a function of epochs
plt.figure(figsize=(10,7))
plt.plot( np.log(test_losses), label = "test")
plt.plot( np.log(train_losses), label = "train")

plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Log(LSE)")
plt.title("MSE over Epoch" )
plt.grid()
print("Training WIDE {} VS in the article 8.04e-09".format(train_losses[-1]) )
# Out:
# Training WIDE 1.4044312676504856e-05 VS in the article 8.04e-09

# %% [markdown]
# ## d) Prediction
# #### Load the ANN

# %%
# Loading model
device = 'cuda'
loaded_Heston_IV_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_IV_ANN_DE.pt"
loaded_Heston_IV_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_IV_ANN.eval()
# Out:
# Heston_ANN(
#   (fc1): Linear(in_features=8, out_features=200, bias=True)
#   (fc2): Linear(in_features=200, out_features=200, bias=True)
#   (fc3): Linear(in_features=200, out_features=200, bias=True)
#   (fc4): Linear(in_features=200, out_features=200, bias=True)
#   (fc5): Linear(in_features=200, out_features=1, bias=True)
# )

# %%
x = hs_dataset[0, :-1].unsqueeze(0).to(device)  # input shape (1, 8)
true_iv = hs_dataset[0, -1].item()

# %%
with torch.no_grad():
    predicted_iv = model(x).item()
    predicted_iv2 = loaded_Heston_IV_ANN(x)

# %%
print(f"True IV:      {true_iv:.4f}")
print(f"Predicted IV: {predicted_iv:.4f}")
# Out:
# True IV:      0.7888
# Predicted IV: 0.7887

# %%
with torch.no_grad():
    predicted_iv1 = model(x)
    predicted_iv2 = loaded_Heston_IV_ANN(x)

print("Are both predictions equal? ", torch.allclose(predicted_iv1, predicted_iv2, atol=1e-6))
print(f"Model(x):              {predicted_iv1.item():.6f}")
print(f"Loaded_Heston_ANN(x):  {predicted_iv2.item():.6f}")
# Out:
# Are both predictions equal?  True
# Model(x):              0.788713
# Loaded_Heston_ANN(x):  0.788713

# %% [markdown]
# #### This table shows similar trained forward performance as shown in Table (4) from [1]

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_IV_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_IV_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )
# Out:
# -----------Train scores----------------
# MSE 1.404407e-05
# MAE 2.804469e-03
# MAPE 5.419249e-03
# R2 9.999504e-01
# -----------Test scores----------------
# MSE 2.385971e-05
# MAE 3.264583e-03
# MAPE 6.411667e-03
# R2 9.999102e-01

# %%
plt.scatter(targets, outputs, alpha=0.1)
plt.xlabel("True IV")
plt.ylabel("Predicted IV")
plt.title("Heston-IV-ANN Fit")
plt.grid(True)
plt.show()

# %% [markdown]
# # 2) Backward pass

# %% [markdown]
# ## a) Preperation Market Quotes

# %% [markdown]
# ### Reference Heston parameter

# %%
# Effect of individual parameters
# Section 4.1.1 in [1]
T = 2 
S0 = 100
kappa = 0.1
gamma = 0.1  # Volatility of variance
nu_bar = 0.1
rho = -0.75
nu_0 = 0.05
r = 0.05

# %%
# Grid setup: 7 maturities × 5 moneynesses = 35
moneyness = np.linspace(0.85, 1.15, 5)
maturity = np.linspace(0.5, 2.0, 7)
m_grid, t_grid = np.meshgrid(moneyness, maturity)
m_flat = m_grid.flatten()
t_flat = t_grid.flatten()
r_flat = np.full_like(m_flat, r)

# Step 1: COS Heston → option prices (V/K)
prices = call_option_Heston_moy(
    N=300,
    L=12,
    r=r_flat.reshape(-1, 1),
    tau=t_flat.reshape(-1, 1),
    kappa=np.full_like(m_flat, kappa).reshape(-1, 1),
    gamma=np.full_like(m_flat, gamma).reshape(-1, 1),
    vbar=np.full_like(m_flat, vbar).reshape(-1, 1),
    v0=np.full_like(m_flat, nu_0).reshape(-1, 1),
    rho=np.full_like(m_flat, rho).reshape(-1, 1),
    moyeness=m_flat.reshape(-1, 1)
).flatten()

#prices = np.maximum(prices, 1e-5)

# Step 2: Brent inversion → implied vols
brent_input = np.column_stack([m_flat, t_flat, r_flat, prices])
implied_vols = np.array([calcimpliedvol(row) for row in brent_input])
invalid = np.isnan(implied_vols)
print(f"Invalid IVs: {np.sum(invalid)} / {len(implied_vols)}")


# Step 3: Final market quote table
market_quotes = np.column_stack([m_flat, t_flat, r_flat, implied_vols])

# Print for verification
print("Market Quotes (35):")
for q in market_quotes:
    print(f"m={q[0]:.2f}, tau={q[1]:.2f}, r={q[2]:.2f}, IV={q[3]:.4f}")

print("calcimpliedvol calls:", counter)
# Out:
# Invalid IVs: 10 / 35
# Market Quotes (35):
# m=0.85, tau=0.50, r=0.05, IV=nan
# m=0.92, tau=0.50, r=0.05, IV=nan
# m=1.00, tau=0.50, r=0.05, IV=0.2795
# m=1.07, tau=0.50, r=0.05, IV=0.5739
# m=1.15, tau=0.50, r=0.05, IV=0.8837
# m=0.85, tau=0.75, r=0.05, IV=nan
# m=0.92, tau=0.75, r=0.05, IV=nan
# m=1.00, tau=0.75, r=0.05, IV=0.2954
# m=1.07, tau=0.75, r=0.05, IV=0.5387
# m=1.15, tau=0.75, r=0.05, IV=0.7908
# m=0.85, tau=1.00, r=0.05, IV=nan
# m=0.92, tau=1.00, r=0.05, IV=nan
# m=1.00, tau=1.00, r=0.05, IV=0.3097
# m=1.07, tau=1.00, r=0.05, IV=0.5235
# m=1.15, tau=1.00, r=0.05, IV=0.7431
# m=0.85, tau=1.25, r=0.05, IV=nan
# m=0.92, tau=1.25, r=0.05, IV=0.1146
# m=1.00, tau=1.25, r=0.05, IV=0.3232
# m=1.07, tau=1.25, r=0.05, IV=0.5173
# m=1.15, tau=1.25, r=0.05, IV=0.7157
# m=0.85, tau=1.50, r=0.05, IV=nan
# m=0.92, tau=1.50, r=0.05, IV=0.1475
# m=1.00, tau=1.50, r=0.05, IV=0.3360
# m=1.07, tau=1.50, r=0.05, IV=0.5160
# m=1.15, tau=1.50, r=0.05, IV=0.6994
# m=0.85, tau=1.75, r=0.05, IV=nan
# m=0.92, tau=1.75, r=0.05, IV=0.1733
# m=1.00, tau=1.75, r=0.05, IV=0.3484
# m=1.07, tau=1.75, r=0.05, IV=0.5177
# m=1.15, tau=1.75, r=0.05, IV=0.6900
# m=0.85, tau=2.00, r=0.05, IV=nan
# m=0.92, tau=2.00, r=0.05, IV=0.1953
# m=1.00, tau=2.00, r=0.05, IV=0.3604
# m=1.07, tau=2.00, r=0.05, IV=0.5214
# m=1.15, tau=2.00, r=0.05, IV=0.6852
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 40
#      37 for q in market_quotes:
#      38     print(f"m={q[0]:.2f}, tau={q[1]:.2f}, r={q[2]:.2f}, IV={q[3]:.4f}")
# ---> 40 print("calcimpliedvol calls:", counter)
#
# NameError: name 'counter' is not defined

# %%
print("Total IVs:    ", len(implied_vols))
print("Failures (NaN):", np.sum(np.isnan(implied_vols)))
print("Successes:    ", np.sum(~np.isnan(implied_vols)))
# Out:
# Total IVs:     35
# Failures (NaN): 1
# Successes:     34

# %%
import matplotlib.pyplot as plt

plt.hist(prices, bins=15, edgecolor='black')
plt.title("Histogram of Market Prices (V/K)")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
for i, p in enumerate(prices):
    if p < 0.1:
        print(f"#{i:2d}: m={m_flat[i]:.2f}, tau={t_flat[i]:.2f}, price={p:.4f}")

# %%
# Grid of 35 quotes
moneyness = np.linspace(0.85, 1.15, 5)
maturity  = np.linspace(0.5, 2.0, 7)
m_grid, t_grid = np.meshgrid(moneyness, maturity)
m_flat, t_flat = m_grid.flatten(), t_grid.flatten()
r_flat = np.full_like(m_flat, r)

# Input for IV-ANN
market_input = np.column_stack([
    m_flat, t_flat, r_flat,
    np.full_like(m_flat, rho),
    np.full_like(m_flat, kappa),
    np.full_like(m_flat, vbar),
    np.full_like(m_flat, gamma),
    np.full_like(m_flat, nu_0)
])
market_tensor = torch.FloatTensor(market_input).to(device)

# Predict market IVs
with torch.no_grad():
    market_iv = loaded_Heston_IV_ANN(market_tensor).cpu().numpy().flatten()

# Step 3: Final market quote table
market_quotes = np.column_stack([m_flat, t_flat, r_flat, market_iv])

print("Market Quotes (35):")
for q in market_quotes:
    print(f"m={q[0]:.2f}, tau={q[1]:.2f}, r={q[2]:.2f}, IV={q[3]:.4f}")
# Out:
# Market Quotes (35):
# m=0.85, tau=0.50, r=0.05, IV=-0.4577
# m=0.92, tau=0.50, r=0.05, IV=-0.0027
# m=1.00, tau=0.50, r=0.05, IV=0.3203
# m=1.07, tau=0.50, r=0.05, IV=0.6112
# m=1.15, tau=0.50, r=0.05, IV=0.9039
# m=0.85, tau=0.75, r=0.05, IV=-0.3293
# m=0.92, tau=0.75, r=0.05, IV=0.0697
# m=1.00, tau=0.75, r=0.05, IV=0.3421
# m=1.07, tau=0.75, r=0.05, IV=0.5762
# m=1.15, tau=0.75, r=0.05, IV=0.8166
# m=0.85, tau=1.00, r=0.05, IV=-0.2057
# m=0.92, tau=1.00, r=0.05, IV=0.1283
# m=1.00, tau=1.00, r=0.05, IV=0.3474
# m=1.07, tau=1.00, r=0.05, IV=0.5490
# m=1.15, tau=1.00, r=0.05, IV=0.7622
# m=0.85, tau=1.25, r=0.05, IV=-0.1312
# m=0.92, tau=1.25, r=0.05, IV=0.1586
# m=1.00, tau=1.25, r=0.05, IV=0.3537
# m=1.07, tau=1.25, r=0.05, IV=0.5364
# m=1.15, tau=1.25, r=0.05, IV=0.7297
# m=0.85, tau=1.50, r=0.05, IV=-0.0946
# m=0.92, tau=1.50, r=0.05, IV=0.1777
# m=1.00, tau=1.50, r=0.05, IV=0.3621
# m=1.07, tau=1.50, r=0.05, IV=0.5392
# m=1.15, tau=1.50, r=0.05, IV=0.7192
# m=0.85, tau=1.75, r=0.05, IV=-0.0547
# m=0.92, tau=1.75, r=0.05, IV=0.1945
# m=1.00, tau=1.75, r=0.05, IV=0.3753
# m=1.07, tau=1.75, r=0.05, IV=0.5397
# m=1.15, tau=1.75, r=0.05, IV=0.7110
# m=0.85, tau=2.00, r=0.05, IV=-0.0065
# m=0.92, tau=2.00, r=0.05, IV=0.2147
# m=1.00, tau=2.00, r=0.05, IV=0.3851
# m=1.07, tau=2.00, r=0.05, IV=0.5452
# m=1.15, tau=2.00, r=0.05, IV=0.6993

# %% [markdown]
# ### 1 single Market quote

# %%
price = call_option_Heston_moy(
    N=1000, L=20,
    r=0.05,
    tau=np.array([[1.0]]),
    kappa=np.array([[0.1]]),
    gamma=np.array([[0.1]]),
    vbar=np.array([[0.1]]),
    v0=np.array([[0.05]]),
    rho=np.array([[-0.75]]),
    moyeness=np.array([[1.0]])
).item()

iv = calcimpliedvol([1.0, 1.0, 0.05, price])

input_tensor = torch.FloatTensor([[1.0, 1.0, 0.05, -0.75, 0.1, 0.1, 0.1, 0.05]]).to(device)
with torch.no_grad():
    iv_test = loaded_Heston_IV_ANN(input_tensor).item()

print(price)
print(iv)
print(iv_test)
# Out:
# 0.11556168412475808
# 0.30971752102183253
# 0.34737056493759155

# %% [markdown]
# ### Market quotes (Table (5))

# %%
# Grid setup: 7 maturities × 5 moneynesses = 35
moneyness = np.linspace(0.85, 1.15, 5)
maturity = np.linspace(0.5, 2.0, 7)
m_grid, t_grid = np.meshgrid(moneyness, maturity)
m_flat = m_grid.flatten()
t_flat = t_grid.flatten()
r_flat = np.full_like(m_flat, r)

# Step 1: COS Heston → option prices (V/K)
prices = call_option_Heston_moy(
    N=300,
    L=12,
    r=r_flat.reshape(-1, 1),
    tau=t_flat.reshape(-1, 1),
    kappa=np.full_like(m_flat, kappa).reshape(-1, 1),
    gamma=np.full_like(m_flat, gamma).reshape(-1, 1),
    vbar=np.full_like(m_flat, vbar).reshape(-1, 1),
    v0=np.full_like(m_flat, v0).reshape(-1, 1),
    rho=np.full_like(m_flat, rho).reshape(-1, 1),
    moyeness=m_flat.reshape(-1, 1)
).flatten()

print(min(prices), max(prices), np.any(prices <= 0))


# Step 2: Brent inversion → implied vols
brent_input = np.column_stack([m_flat, t_flat, r_flat, prices])
implied_vols = np.array([calcimpliedvol(row) for row in brent_input])

# Step 3: Final market quote table
market_quotes = np.column_stack([m_flat, t_flat, r_flat, implied_vols])

print("Market Quotes (35):")
for q in market_quotes:
    print(f"m={q[0]:.2f}, tau={q[1]:.2f}, r={q[2]:.2f}, IV={q[3]:.4f}")
# Out:
# 0.12074269836632713 0.5111237727460437 False
# Market Quotes (35):
# m=0.85, tau=0.50, r=0.05, IV=nan
# m=0.92, tau=0.50, r=0.05, IV=0.4577
# m=1.00, tau=0.50, r=0.05, IV=0.7544
# m=1.07, tau=0.50, r=0.05, IV=1.0358
# m=1.15, tau=0.50, r=0.05, IV=1.3167
# m=0.85, tau=0.75, r=0.05, IV=0.2113
# m=0.92, tau=0.75, r=0.05, IV=0.5204
# m=1.00, tau=0.75, r=0.05, IV=0.7669
# m=1.07, tau=0.75, r=0.05, IV=1.0038
# m=1.15, tau=0.75, r=0.05, IV=1.2406
# m=0.85, tau=1.00, r=0.05, IV=0.3113
# m=0.92, tau=1.00, r=0.05, IV=0.5602
# m=1.00, tau=1.00, r=0.05, IV=0.7785
# m=1.07, tau=1.00, r=0.05, IV=0.9903
# m=1.15, tau=1.00, r=0.05, IV=1.2028
# m=0.85, tau=1.25, r=0.05, IV=0.3698
# m=0.92, tau=1.25, r=0.05, IV=0.5896
# m=1.00, tau=1.25, r=0.05, IV=0.7896
# m=1.07, tau=1.25, r=0.05, IV=0.9854
# m=1.15, tau=1.25, r=0.05, IV=1.1830
# m=0.85, tau=1.50, r=0.05, IV=0.4120
# m=0.92, tau=1.50, r=0.05, IV=0.6136
# m=1.00, tau=1.50, r=0.05, IV=0.8009
# m=1.07, tau=1.50, r=0.05, IV=0.9857
# m=1.15, tau=1.50, r=0.05, IV=1.1737
# m=0.85, tau=1.75, r=0.05, IV=0.4458
# m=0.92, tau=1.75, r=0.05, IV=0.6345
# m=1.00, tau=1.75, r=0.05, IV=0.8127
# m=1.07, tau=1.75, r=0.05, IV=0.9902
# m=1.15, tau=1.75, r=0.05, IV=1.1716
# m=0.85, tau=2.00, r=0.05, IV=0.4755
# m=0.92, tau=2.00, r=0.05, IV=0.6561
# m=1.00, tau=2.00, r=0.05, IV=0.8267
# m=1.07, tau=2.00, r=0.05, IV=1.0031
# m=1.15, tau=2.00, r=0.05, IV=1.1762

# %% [markdown]
# ### Objective function

# %%
def calibration_objective(theta, inputs, market_iv, iv_ann):
    # theta: [rho, kappa, vbar, gamma, v0]
    # inputs: [moneyness, maturity, r] fixed per quote
    input_tensor = torch.tensor(np.column_stack([
        inputs,  # shape (N, 3)
        np.tile(theta, (inputs.shape[0], 1))
    ]), dtype=torch.float32).to(device)

    with torch.no_grad():
        pred_iv = iv_ann(input_tensor).cpu().numpy().flatten()

    return np.mean((pred_iv - market_iv) ** 2)

# %%
inputs = market_quotes[:, :3]         # [moneyness, maturity, r]
market_iv = market_quotes[:, 3]       # true IVs
iv_ann = loaded_Heston_IV_ANN         # trained and set to eval()

# %% [markdown]
# ### Differential Evolution (DE)

# %%
# Bounds from Section 4.1.1
bounds = [(-0.85, 0.05), (0.05, 0.45), (0.05, 0.75), (0.05, 0.45), (0.1, 2.0)]

# --- Run DE optimization ---
result = differential_evolution(
    func=calibration_objective,
    bounds=bounds,
    args=(inputs, market_iv, iv_ann),
    strategy="best1bin",
    popsize=15,
    tol=1e-5,
    maxiter=1000,
    updating="deferred"
)


print("Calibrated parameters:", result.x)
print("Final MSE loss:", result.fun)
# Out:
# Calibrated parameters: [-0.3770595   0.05000015  0.05000003  0.44999897  0.10000001]
# Final MSE loss: 0.00022523468937090752

# %%
target_iv = implied_vols

# Use the contract terms (moneyness, maturity, r) from market quotes
fixed_contracts = market_quotes[:, :3]  # shape (35, 3)

# --- Loss function ---
def calibration_objective(theta):
    rho, kappa, vbar, gamma, v0 = theta

    

    # Build full input matrix (35 rows, 8 features)
    input_matrix = np.hstack([
        fixed_contracts,
        np.full((fixed_contracts.shape[0], 1), rho),
        np.full((fixed_contracts.shape[0], 1), kappa),
        np.full((fixed_contracts.shape[0], 1), vbar),
        np.full((fixed_contracts.shape[0], 1), gamma),
        np.full((fixed_contracts.shape[0], 1), v0),
    ])
    input_tensor = torch.FloatTensor(input_matrix).to(device)

    # Predict prices with Heston-ANN
    with torch.no_grad():
        prices = loaded_Heston_ANN(input_tensor).cpu().numpy().flatten()

    # Ensure prices > intrinsic value for Brent to work
    intrinsic = fixed_contracts[:, 0] - np.exp(-fixed_contracts[:, 1] * fixed_contracts[:, 2])
    prices = np.maximum(prices, intrinsic + 1e-4)
    print("Input params:", theta)
    #print("Prices shape:", prices.shape)
    #print("Input prices:", prices)
    #print("Target IV shape:", target_iv.shape)
    assert prices is not None, "Heston-ANN returned None!"

    # Compute Brent IVs
    brent_inputs = np.column_stack([fixed_contracts, prices])
    predicted_iv = np.apply_along_axis(calcimpliedvol, 1, brent_inputs)

    # Check for NaNs
    if np.any(np.isnan(predicted_iv)):
        return 1e3  # penalize invalid parameter sets

    # Compute MSE loss
    return np.mean((predicted_iv - target_iv)**2)

# %%
# --- Bounds from Section 4.1.1 ---
bounds = [(-0.85, 0.05), (0.05, 0.45), (0.05, 0.75), (0.05, 0.45), (0.1, 2.0)]

# --- Run DE optimization ---
result = differential_evolution(
    calibration_objective,
    bounds,
    strategy="best1bin",
    popsize=15,
    tol=1e-5,
    maxiter=1000,
    #polish=True,
    workers=1,
    updating="deferred"
)

print("Calibrated parameters:", result.x)
print("Final MSE loss:", result.fun)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 5
#       2 bounds = [(-0.85, 0.05), (0.05, 0.45), (0.05, 0.75), (0.05, 0.45), (0.1, 2.0)]
#       4 # --- Run DE optimization ---
# ----> 5 result = differential_evolution(
#       6     calibration_objective,
#       7     bounds,
#       8     strategy="best1bin",
#       9     popsize=15,
#      10     tol=1e-5,
#      11     maxiter=1000,
#      12     #polish=True,
#      13     workers=1,
#      14     updating="deferred"
#      15 )
#      17 print("Calibrated parameters:", result.x)
#      18 print("Final MSE loss:", result.fun)
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:397, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     380 # using a context manager means that any created Pool objects are
#     381 # cleared up.
#     382 with DifferentialEvolutionSolver(func, bounds, args=args,
#     383                                  strategy=strategy,
#     384                                  maxiter=maxiter,
#    (...)
#     395                                  integrality=integrality,
#     396                                  vectorized=vectorized) as solver:
# --> 397     ret = solver.solve()
#     399 return ret
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:989, in DifferentialEvolutionSolver.solve(self)
#     984     self.feasible, self.constraint_violation = (
#     985         self._calculate_population_feasibilities(self.population))
#     987     # only work out population energies for feasible solutions
#     988     self.population_energies[self.feasible] = (
# --> 989         self._calculate_population_energies(
#     990             self.population[self.feasible]))
#     992     self._promote_lowest_energy()
#     994 # do the optimization.
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\optimize\_differentialevolution.py:1122, in DifferentialEvolutionSolver._calculate_population_energies(self, population)
#    1120 parameters_pop = self._scale_parameters(population)
#    1121 try:
# -> 1122     calc_energies = list(
#    1123         self._mapwrapper(self.func, parameters_pop[0:S])
#    1124     )
#    1125     calc_energies = np.squeeze(calc_energies)
#    1126 except (TypeError, ValueError) as e:
#    1127     # wrong number of arguments for _mapwrapper
#    1128     # or wrong length returned from the mapper
#
# File c:\Users\Dominik\anaconda3\envs\ANN_Solver\lib\site-packages\scipy\_lib\_util.py:372, in _FunctionWrapper.__call__(self, x)
#     371 def __call__(self, x):
# --> 372     return self.f(x, *self.args)
#
# Cell In[69], line 25, in calibration_objective(theta)
#      23 # Predict prices with Heston-ANN
#      24 with torch.no_grad():
# ---> 25     prices = loaded_Heston_ANN(input_tensor).cpu().numpy().flatten()
#      27 # Ensure prices > intrinsic value for Brent to work
#      28 intrinsic = fixed_contracts[:, 0] - np.exp(-fixed_contracts[:, 1] * fixed_contracts[:, 2])
#
# NameError: name 'loaded_Heston_ANN' is not defined

# %%
# EXAMPLE DE

import numpy as np
from scipy.optimize import differential_evolution

# Synthetic model: true IV is a known function of moneyness and maturity
def true_iv(m, t, rho, gamma):
    return 0.2 + 0.1 * (m - 1)**2 + 0.05 * t + 0.02 * abs(rho) + 0.01 * gamma

# Generate synthetic market quotes
moneyness = np.linspace(0.85, 1.15, 5)
maturity = np.linspace(0.5, 2.0, 7)
m_grid, t_grid = np.meshgrid(moneyness, maturity)
m_flat = m_grid.flatten()
t_flat = t_grid.flatten()

true_params = (-0.75, 0.2)
target_iv = true_iv(m_flat, t_flat, *true_params)

# Objective to minimize
def calibration_objective(params):
    rho, gamma = params
    predicted_iv = true_iv(m_flat, t_flat, rho, gamma)
    return np.mean((predicted_iv - target_iv)**2)

# Run DE
bounds = [(-0.85, 0.05), (0.05, 0.45)]
result = differential_evolution(calibration_objective, bounds)

print("Calibrated parameters:", result.x)
print("True parameters:", true_params)
print("Final loss:", result.fun)
# Out:
# Calibrated parameters: [-0.82250742  0.05498515]
# True parameters: (-0.75, 0.2)
# Final loss: 0.0

# %%
import numpy as np

# Observed market implied volatilities (target data)

observed_vols = np.linspace(0.2, 0.5, 35)  # Generates 35 equally spaced values

# Moneyness and time-to-maturity of the observed data
moneyness = np.linspace(0.85, 1.15, 5)  # Moneyness
maturities = np.linspace(0.5, 2.0, 7)   # Time to maturity
r = 0.03
#params = 



# Pre-trained ANN that maps Heston parameters to implied volatilities
def heston_ann(parameters):
    """
    A mock function representing the ANN (pre-trained forward pass).
    In real scenarios, this will return ANN-predicted implied volatilities.
    """
    # Example: Simple mapping for illustration
    rho, kappa, gamma, nu_bar, nu_0 = parameters
    return 0.25 + 0.05 * (moneyness - 1.0) + 0.02 * (maturities - 1.0)

# Objective function for DE calibration
def calibration_objective(parameters):
    """
    Calculates the mean squared error between ANN-predicted
    and observed market volatilities.
    """
    predicted_vols = implied_vols
    error = np.mean((predicted_vols - observed_vols) ** 2)
    return error

# %% [markdown]
# # DOWN FROM HERE EVERYTHING IS ONLY FOR LOOK UP PURPOSES

# %%
import numpy as np
import itertools

# Define Heston parameter bounds
bounds = {
    "rho": (-0.9, 0.0),         # Correlation coefficient
    "kappa": (0.1, 3.0),        # Speed of mean reversion
    "gamma": (0.01, 0.8),       # Volatility of variance
    "nu_0": (0.01, 0.5),        # Initial variance
    "nu_bar": (0.01, 0.5)       # Long-term variance
}

# Number of discrete points to sample within each parameter's range
points_per_param = 5

# Generate equally spaced points for each parameter within its bounds
parameter_points = {param: np.linspace(lower, upper, points_per_param)
                    for param, (lower, upper) in bounds.items()}

# Combine the points to form a grid of all possible parameter combinations
grid = list(itertools.product(
    parameter_points["rho"],
    parameter_points["kappa"],
    parameter_points["gamma"],
    parameter_points["nu_0"],
    parameter_points["nu_bar"]
))

# Convert the grid into a NumPy array for convenience
parameter_grid = np.array(grid)

# Display the grid details
print(f"Search space dimensions: {len(parameter_points)} parameters")
print(f"Total combinations: {parameter_grid.shape[0]}")
print("Example combinations (first 5 rows):")
print(parameter_grid[:5])

# Optional: Save to a file for later use
np.savetxt("heston_search_space.csv", parameter_grid, delimiter=",",
           header="rho,kappa,gamma,nu_0,nu_bar", comments="")

# %%
import torch
import numpy as np
from scipy.optimize import differential_evolution

def calibrate_with_de(loaded_ANN, moneyness, maturities, r, observed_vols, device="cuda"):
    """
    Calibrates Heston parameters using differential evolution and a trained ANN.
    
    Parameters:
    - loaded_ANN: Trained PyTorch ANN (set to .eval())
    - moneyness: 1D array of moneyness values (e.g., shape (5,))
    - maturities: 1D array of maturities (e.g., shape (7,))
    - r: risk-free rate (scalar)
    - observed_vols: flattened vector of observed implied vols (shape (len(moneyness) * len(maturities),))
    - device: "cuda" or "cpu"
    
    Returns:
    - result.x: optimal Heston parameters [rho, kappa, gamma, nu_bar, nu_0]
    - result.fun: final objective value (MSE)
    """

    # Make sure model is in eval mode
    loaded_ANN.eval()

    # Create full input grid for calibration
    def heston_ann(parameters):
        rho, kappa, gamma, nu_bar, nu_0 = parameters
        inputs = []

        for m in moneyness:
            for t in maturities:
                inputs.append([m, t, r, rho, kappa, nu_bar, gamma, nu_0])

        inputs = torch.tensor(inputs, dtype=torch.float32).to(device)

        with torch.no_grad():
            preds = loaded_ANN(inputs).cpu().numpy().flatten()
        return preds

    # Objective function to minimize
    def calibration_objective(parameters):
        predicted_vols = heston_ann(parameters)
        return np.mean((predicted_vols - observed_vols) ** 2)

    # Bounds for DE (adjust to your actual model/training setup)
    bounds = [
        (-0.85, 0.0),     # rho
        (0.1, 3.0),      # kappa
        (0.01, 0.8),     # gamma
        (0.01, 0.5),     # nu_bar
        (0.01, 0.5),     # nu_0
    ]

    # Run differential evolution
    result = differential_evolution(
        calibration_objective,
        bounds,
        strategy="best1bin",
        popsize=50,
        mutation=(0.5, 1.0),
        recombination=0.7,
        tol=0.001,
        disp=True
    )

    return result.x, result.fun

# %%
# Inputs
moneyness = np.linspace(0.85, 1.15, 5)
maturities = np.linspace(0.5, 2.0, 7)
r = 0.03

# Observed vols must be flat vector of shape (35,)
observed_vols = np.linspace(0.2, 0.5, 35)

# Run calibration
opt_params, final_loss = calibrate_with_de(loaded_Heston_ANN, moneyness, maturities, r, observed_vols)

print("Optimal Heston parameters:")
print(f"rho={opt_params[0]:.4f}, kappa={opt_params[1]:.4f}, gamma={opt_params[2]:.4f}, "
      f"nu_bar={opt_params[3]:.4f}, nu_0={opt_params[4]:.4f}")
print(f"Final MSE: {final_loss:.6e}")
# Out:
# differential_evolution step 1: f(x)= 0.00392477
# differential_evolution step 2: f(x)= 0.00392477
# differential_evolution step 3: f(x)= 0.00379698
# differential_evolution step 4: f(x)= 0.00376597
# differential_evolution step 5: f(x)= 0.00376597
# differential_evolution step 6: f(x)= 0.00376597
# differential_evolution step 7: f(x)= 0.0036891
# differential_evolution step 8: f(x)= 0.00364717
# differential_evolution step 9: f(x)= 0.00364717
# differential_evolution step 10: f(x)= 0.00364717
# differential_evolution step 11: f(x)= 0.00364717
# differential_evolution step 12: f(x)= 0.00364717
# differential_evolution step 13: f(x)= 0.00364717
# differential_evolution step 14: f(x)= 0.00364717
# differential_evolution step 15: f(x)= 0.00364717
# differential_evolution step 16: f(x)= 0.00364717
# differential_evolution step 17: f(x)= 0.00364717
# differential_evolution step 18: f(x)= 0.0036225
# differential_evolution step 19: f(x)= 0.0036225
# differential_evolution step 20: f(x)= 0.0036225
# differential_evolution step 21: f(x)= 0.0036225
# differential_evolution step 22: f(x)= 0.0036225
# differential_evolution step 23: f(x)= 0.0036225
# differential_evolution step 24: f(x)= 0.0036225
# differential_evolution step 25: f(x)= 0.00362203
# differential_evolution step 26: f(x)= 0.00362061
# differential_evolution step 27: f(x)= 0.00362061
# differential_evolution step 28: f(x)= 0.00361841
# differential_evolution step 29: f(x)= 0.00361841
# differential_evolution step 30: f(x)= 0.00361841
# differential_evolution step 31: f(x)= 0.00361681
# differential_evolution step 32: f(x)= 0.00361562
# differential_evolution step 33: f(x)= 0.00361163
# differential_evolution step 34: f(x)= 0.00361163
# differential_evolution step 35: f(x)= 0.00361021
# differential_evolution step 36: f(x)= 0.00361001
# differential_evolution step 37: f(x)= 0.00361001
# differential_evolution step 38: f(x)= 0.00361001
# differential_evolution step 39: f(x)= 0.0036084
# differential_evolution step 40: f(x)= 0.0036084
# differential_evolution step 41: f(x)= 0.0036084
# differential_evolution step 42: f(x)= 0.0036084
# differential_evolution step 43: f(x)= 0.0036084
# differential_evolution step 44: f(x)= 0.00360806
# differential_evolution step 45: f(x)= 0.00360787
# differential_evolution step 46: f(x)= 0.00360778
# differential_evolution step 47: f(x)= 0.00360765
# Polishing solution with 'L-BFGS-B'
# Optimal Heston parameters:
# rho=-0.1873, kappa=0.1609, gamma=0.2718, nu_bar=0.4995, nu_0=0.5000
# Final MSE: 3.607652e-03

# %%
import numpy as np

# Observed market implied volatilities (target data)

observed_vols = np.linspace(0.2, 0.5, 35)  # Generates 35 equally spaced values

# Moneyness and time-to-maturity of the observed data
moneyness = np.linspace(0.85, 1.15, 5)  # Moneyness
maturities = np.linspace(0.5, 2.0, 7)   # Time to maturity
r = 0.03
#params = 



# Pre-trained ANN that maps Heston parameters to implied volatilities
def heston_ann(parameters):
    """
    A mock function representing the ANN (pre-trained forward pass).
    In real scenarios, this will return ANN-predicted implied volatilities.
    """
    # Example: Simple mapping for illustration
    rho, kappa, gamma, nu_bar, nu_0 = parameters
    return 0.25 + 0.05 * (moneyness - 1.0) + 0.02 * (maturities - 1.0)

# Objective function for DE calibration
def calibration_objective(parameters):
    """
    Calculates the mean squared error between ANN-predicted
    and observed market volatilities.
    """
    predicted_vols = implied_vol_pipe2
    error = np.mean((predicted_vols - observed_vols) ** 2)
    return error

# %%
bounds = [
    (-0.75, -0.25),   # rho (correlation)
    (0.5, 1.0),    # kappa (mean reversion speed)
    (0.3, 0.5),   # gamma (volatility of variance)
    (0.15, 0.35),   # nu_bar (long-run variance)
    (0.5, 1.0)    # nu_0 (initial variance)
]

# %%
from scipy.optimize import differential_evolution

# Run DE to calibrate the Heston parameters
result = differential_evolution(
    calibration_objective,  # Objective function
    bounds,                 # Parameter bounds
    strategy="best1bin",    # Strategy for mutation
    popsize=50,             # Population size
    mutation=(0.5, 1.0),    # Mutation range
    recombination=0.7,      # Crossover probability
    tol=0.01,               # Convergence tolerance
    disp=True               # Display optimization progress
)

# Display calibrated parameters
print("Calibrated Parameters:", result.x)
print("Objective Function Value:", result.fun)

# %%
# Function to calculate implied volatility using Brent's method
def calc_implied_vol(dataset):
    """
    Computes implied volatilities using the Brent method.
    :param dataset: numpy array containing [S/K, T, r, OptionPrice].
    :return: A single implied volatility value.
    """
    money, T, r, market_price = dataset

    def bs_price(sigma):
        """Black-Scholes option price difference function."""
        d1 = (np.log(money) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
        d2 = d1 - sigma * np.sqrt(T)
        theoretical_price = money * norm.cdf(d1) - np.exp(-r * T) * norm.cdf(d2)
        return theoretical_price - market_price

    # Solve for implied volatility
    try:
        return optimize.brentq(bs_price, 1e-5, 5, maxiter=100)
    except ValueError:
        return np.nan  # Return NaN if Brent fails to converge

# Data generation or loading
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds=l_bounds, u_bounds=u_bounds)
hs_data_loader = DataLoader(hs_dataset, batch_size=4048)

# Step 1: Compute prices using Heston-ANN
predicted_prices = []
with torch.no_grad():
    for data in hs_data_loader:
        inputs = data[:, :-1].to(device)  # Exclude the last column if it's labels
        outputs = loaded_Heston_ANN(inputs)
        predicted_prices.append(outputs.cpu().numpy())
predicted_prices = np.concatenate(predicted_prices)

# Step 2: Prepare the dataset for Brent's method
# Combine predicted prices with necessary inputs for implied volatility calculation
# Assuming hs_dataset.data contains [S/K, T, r, actual_price]:
hs_dataset_data = hs_dataset.data[:, np.array([0, 1, 2])]  # Extract relevant columns
hs_dataset_data = np.hstack((hs_dataset_data, predicted_prices.reshape(-1, 1)))

# Step 3: Calculate implied volatilities
implied_volatilities = np.apply_along_axis(calc_implied_vol, 1, hs_dataset_data)

# Step 4: Evaluate results
# Assuming you have ground-truth implied volatilities for comparison
ground_truth_vol = hs_dataset.data[:, 3]  # Replace with actual column for ground truth
mse = ((ground_truth_vol - implied_volatilities) ** 2).mean()
print(f"MSE: {mse:.6e}")

# %%
# Loading Train / Test Data
hs_dataset = Heston_LHS_data_generator(n = 10**5)
train_size, test_size = int(hs_dataset.shape[0]*0.9), int(hs_dataset.shape[0]*0.1 ) # 10% SPLIT
train_dataset, test_dataset = torch.utils.data.random_split(hs_dataset, [train_size, hs_dataset.shape[0]-train_size])
args =  {"batch_size": 1024,
         "test_batch_size": 4048,
         "epochs" : 3*10**3,
         "lr": 1e-4,
         "gamma": .1,
         "no_cuda" : False,
         "run_dry": False,
         "seed": 0,
         "log_interval" : 100,
         "dry_run" : False,
         "save_model": True}
train_loader = torch.utils.data.DataLoader(train_dataset,args["batch_size"])
test_loader = torch.utils.data.DataLoader(test_dataset, args["test_batch_size"])

# %%
# printing train and test erros MSE, MAE, MAPE, R2.
outputs = []
targets = []
with torch.no_grad():
  for data in train_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Train scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs, targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs, targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs, targets)) )
print("R2 {:e}".format(r2_score(outputs, targets)) )


outputs = []
targets = []
with torch.no_grad():
  for data in test_loader:
    data, target = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    outputs.append((output).data.cpu().numpy())
    targets.append((target).data.cpu().numpy())
  outputs = np.concatenate(outputs)
  targets = np.concatenate(targets)

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
print("-----------Test scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs, targets)) )
print("MAE {:e}".format(mean_absolute_error(outputs, targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs, targets)) )
print("R2 {:e}".format(r2_score(outputs, targets)) )

# %%
np.sqrt(1.670718e-07)
print("MSE {:e}".format(np.sqrt(1.670718e-07)) )

# %% [markdown]
# # DOWN FROM HERE EVERYTHING IS ONLY FOR LOOK UP PURPOSES

# %% [markdown]
# # 5) BRENT

# %% [markdown]
# # 6) Pipeline 1: COS + BRENT

# %%
eps = 1e-2 # is used to generate open intervals
# (S/K), (tau), (r), (rho), (kappa), (vbar), (gamma), (v0).
# CASE 1 in table 11
l_bounds = [.75+eps, .4+eps, .0+eps, -0.95+eps, .4+eps, .0+eps, .0+eps, .05+eps]
u_bounds = [1.25-eps, 1.0-eps, .1-eps, 0.0-eps, 2.0-eps, .5-eps, .5-eps, .5-eps]
hs_dataset = Heston_LHS_data_generator(10**5, l_bounds = l_bounds, u_bounds=u_bounds)
hs_dataset_data = hs_dataset.data
hs_dataset_data = hs_dataset_data[:,np.array([0,1,2,8])]
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, hs_dataset_data)

# %% [markdown]
# # 7) Pipeline 2: Heston-ANN + IV-ANN

# %%
# Loading model
device = torch.device("cuda")
loaded_Heston_ANN = Heston_ANN().to(device)
PATH = "ANN_weights/Heston_ANN.pt"
loaded_Heston_ANN.load_state_dict(torch.load(PATH))
loaded_Heston_ANN.eval()

# data loader 
loader = torch.utils.data.DataLoader(hs_dataset, 4048)
# Computing prices
prices = []
with torch.no_grad():
  for data in loader:
    data, _ = data[:,:-1].to(device), data[:,-1].to(device)
    output = loaded_Heston_ANN(data)
    prices.append((output).data.cpu().numpy())
  prices = np.concatenate(prices)

# Loading model 
device = torch.device("cuda")
loaded_IV_ANN = IV_ANN().to(device)
PATH = "ANN_weights/IV_SCALED_ANN.pt"
loaded_IV_ANN.load_state_dict(torch.load(PATH))
loaded_IV_ANN.eval()


# Plugging in the Heston-ANN prices
hs_dataset2 = hs_dataset.data[:,np.array([0,1,2,8])]
hs_dataset2.data[:,3] = torch.FloatTensor(prices)
loader2 = torch.utils.data.DataLoader(hs_dataset2, 4048)

# Computing IVs
implied_vol = []
indecies_list = []
with torch.no_grad():
  for idx, data in enumerate(loader2):
    data = data.to(device)
    # LOG Transformation
    data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
    data[:,3] = torch.log(data[:,3])
    output = loaded_IV_ANN(data)
    implied_vol.append((output).data.cpu().numpy())
  implied_vol_pipe2 = np.concatenate(implied_vol)
  # indecies_list = np.concatenate(indecies_list).flatten()

# %%
# Eliminating Nan values resulting from prices lower than 1e-7
indecies = np.argwhere(np.isnan(implied_vol_pipe2))
implied_vol_pipe1 = np.delete(implied_vol_pipe1, indecies,0)
implied_vol_pipe2 = np.delete(implied_vol_pipe2, indecies,0)

# %% [markdown]
# # 8) Pipeline 1 VS pipeline 2

# %%
# CASE 1
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
#targets = vol_imp
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )

# %%
# CASE 2
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
outputs = implied_vol_pipe2
targets = implied_vol_pipe1
print("-----------Vol scores----------------")
print("MSE {:e}".format(mean_squared_error(outputs,targets)) )
print("RMSE {:e}".format(np.sqrt(mean_squared_error(outputs,targets))) )
print("MAE {:e}".format(mean_absolute_error(outputs,targets)) )
print("MAPE {:e}".format(mean_absolute_percentage_error(outputs,targets)) )
print("R2 {:e}".format(r2_score(outputs,targets)) )

# %% [markdown]
# # 9) Volatility surface (COS + IV-ANN)

# %% [markdown]
# ### Initial volatility surface

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
moyeness = np.linspace(moyeness, 1.24,11)
tau = np.linspace(tau, 1, 6)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(66)).reshape((-1, 1))

# %%
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  bs_IV = (output).data.cpu().numpy()

X = X.flatten()
Y = Y.flatten()
Z = bs_IV

x = np.reshape(X, (-1, 6))
y = np.reshape(Y, (-1, 6))
z = np.reshape(Z, (-1, 6))

# %%
from mpl_toolkits import mplot3d
from matplotlib import cm

# %%
# Plotting the initial volatility surface
plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to matuirity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Smoothing the volatility surface

# %%
from scipy import interpolate

# %%
# Smoothing the volatility surface
xnew, ynew = x.copy(), y.copy()
tck = interpolate.bisplrep(x, y, z, s=1.0)
znew = interpolate.bisplev(xnew[:,0], ynew[0,:], tck)

plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=20, azim=60)
ax.plot_surface(xnew, ynew, znew,cmap='viridis', edgecolor='none', antialiased=True)
ax.set_xlabel('Moyeness')
ax.set_ylabel('Time to maturity')
ax.set_zlabel('Implied volatility')
plt.show()

# %% [markdown]
# ### Implied volatility difference

# %%
# Generating the surface points
r= .02
tau= 0.5
rho = -0.05
kappa= 1.5
vbar = .1
gamma = .3
v0 = 0.1
moyeness = 0.74
n_moneyness = 11
n_tau = 6
moyeness = np.linspace(moyeness, 1.24,n_moneyness)
tau = np.linspace(tau, 1, n_tau)

cos_prices = []
X = []
Y = []
for m in moyeness:
  for t in tau:
    X.append(m)
    Y.append(t)
    cos_prices.append(call_option_Heston_moy(N = 160, L= 12, r= r, tau= t, kappa= kappa, gamma = gamma, vbar = vbar, v0 = v0, rho = rho, moyeness = m))

# %%
rho = np.array(rho*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
kappa = np.array(kappa*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
vbar = np.array(vbar*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
gamma = np.array(gamma*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
v0 = np.array(v0*np.ones(n_tau * n_moneyness)).reshape((-1, 1))
# Reshaping for torch tensor dataset
cos_prices = np.array(cos_prices).reshape((-1, 1))
X = np.array(X).reshape((-1, 1))
Y = np.array(Y).reshape((-1, 1))
r = np.array(r*np.ones(n_tau * n_moneyness)).reshape((-1, 1))

# %%
data_ann = np.concatenate((X, Y, r, rho, kappa, vbar, gamma, v0, cos_prices), axis = 1)
data_ann = torch.FloatTensor(data_ann)
# Creating a torch dataset
data = np.concatenate((X, Y, r, cos_prices), axis = 1)
data = torch.FloatTensor(data)

# %%
implied_vol_pipe1 = np.apply_along_axis(calcimpliedvol, 1, data)

# %%
# Getting the implied volatility from the dataset
with torch.no_grad():
  data = data.to(device)
  data[:,3] = data[:,3] - torch.maximum(data[:,0]-torch.exp(-data[:,1]*data[:,2]),torch.zeros(data[:,0].shape).to(device))
  data[:,3] = torch.log(data[:,3])
  output = loaded_IV_ANN(data)
  implied_vol_pipe2 = (output).data.cpu().numpy()

# %%
X = X.flatten()
Y = Y.flatten()
Z = (implied_vol_pipe1 - implied_vol_pipe2).flatten()

x = np.reshape(X, (-1, min(n_moneyness, n_tau)))
y = np.reshape(Y, (-1, min(n_moneyness, n_tau)))
z = np.reshape(Z, (-1, min(n_moneyness, n_tau)))

plt.figure(figsize=(8,8))
plt.pcolormesh(x, y, z, shading='gouraud')
plt.colorbar()
plt.xlabel("Moneyness")
plt.ylabel("Time to maturity")
plt.show()

# %%
# Re-import necessary libraries and re-define the setup after reset
from scipy.optimize import differential_evolution
import numpy as np

# Define the objective function
def objective_function(x):
    # Example: A simple quadratic function
    return x[0]**2 + x[1]**2 + x[2]**2

# Define the bounds for each variable
bounds = [(-10, 10), (-10, 10), (-10, 10)]  # Variable bounds for a 3D problem

# Run Differential Evolution with the specified settings
result_custom_de = differential_evolution(
    objective_function,  # Objective function
    bounds,             # Variable bounds
    strategy="best1bin",  # Strategy
    popsize=50,          # Population size
    mutation=(0.5, 1.0), # Mutation range
    recombination=0.7,   # Crossover probability
    tol=0.01,            # Convergence tolerance
    disp=False           # Suppress output during the run
)

# Display the result
result_custom_de
